# %% [markdown]
# ### Import modules and packages. define functions

# %%
import numpy as np
import os
from nd2reader import ND2Reader
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib_scalebar.scalebar import ScaleBar
import scipy.ndimage as ndi
from skimage.filters import rank 
from scipy.signal import butter, lfilter
import scipy.misc as misc
from skimage import exposure
from PIL import Image
import colorcet as cc
from scipy.misc import toimage
import matplotlib.colors as clr
import pandas as pd
import seaborn as sns
from scipy import stats
import cv2
from pyspark import SparkContext, SparkConf
import skimage
from pathlib import Path
# %matplotlib inline

def mean2(x):
    y = np.sum(x) / np.size(x);
    return y

def corr2(a,b):
    a = a - mean2(a)
    b = b - mean2(b)

    r = (a*b).sum() / np.sqrt((a*a).sum() * (b*b).sum());
    return r

# %%
stacks=np.load('/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20181002_TNR_STED/autoimaging_attempts/01/STEDstack.np.npy')

# %%
stacks1=stacks[0,:,:,:]
stacks1.shape
# Out:
# (10, 1000, 1000)

# %%
import vtk
from vtk.util import numpy_support

NumPy_data=stacks1
VTK_data = numpy_support.numpy_to_vtk(num_array=NumPy_data.ravel(), deep=True, array_type=vtk.VTK_FLOAT)
# Out:
# /anaconda3/lib/python3.6/site-packages/vtk/util/numpy_support.py:137: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   assert not numpy.issubdtype(z.dtype, complex), \

# %%
from pyevtk.hl import imageToVTK
import numpy as np

# Dimensions
nx, ny, nz = 1000, 1000, 10
ncells = nx * ny * nz
npoints = (nx + 1) * (ny + 1) * (nz + 1)

# Variables
pressure = np.random.rand(ncells).reshape( (nx, ny, nz), order = 'C')
temp = np.random.rand(npoints).reshape( (nx + 1, ny + 1, nz + 1))

imageToVTK("./image", cellData = stacks )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ae4c8c852a00> in <module>()
#       4 juliaStacked = np.dstack([stacks1]*noSlices)
#       5
# ----> 6 x = np.arange(0, w+1)
#       7 y = np.arange(0, h+1)
#       8 z = np.arange(0, noSlices+1)
#
# NameError: name 'w' is not defined

# %%
rois=pd.read_csv('/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20181002_TNR_STED/autoimaging_attempts/save/points.csv',sep=';')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-5466d6b4d1f1> in <module>()
# ----> 1 rois=pd.read_csv('/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20181002_TNR_STED/autoimaging_attempts/save/shapes.csv',sep=';')
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     447
#     448     # Create the parser.
# --> 449     parser = TextFileReader(filepath_or_buffer, **kwds)
#     450
#     451     if chunksize or iterator:
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     816             self.options['has_index_names'] = kwds['has_index_names']
#     817
# --> 818         self._make_engine(self.engine)
#     819
#     820     def close(self):
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1047     def _make_engine(self, engine='c'):
#    1048         if engine == 'c':
# -> 1049             self._engine = CParserWrapper(self.f, **self.options)
#    1050         else:
#    1051             if engine == 'python':
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1693         kwds['allow_leading_cols'] = self.index_col is not False
#    1694
# -> 1695         self._reader = parsers.TextReader(src, **kwds)
#    1696
#    1697         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20181002_TNR_STED/autoimaging_attempts/save/shapes.csv' does not exist

# %%
rois.head()
# Out:
#   Detection #  Surface           x       y    z    t  min intensity  \
# 0           0      1.0  882.000000  999.00  9.0  0.0            4.0
# 1           1      6.0  553.500000  999.00  9.0  0.0            3.0
# 2           2     10.0  439.300000  991.90  9.0  0.0            1.0
# 3           3      5.0   84.800000  957.60  9.0  0.0            2.0
# 4           4     24.0  260.666667  958.25  9.0  0.0            2.0
#
#    max intensity  average intensity
# 0            4.0           4.000000
# 1            5.0           3.666667
# 2            6.0           3.500000
# 3            7.0           4.200000
# 4           14.0           6.416667

# %%
coordinates=rois[['x','y','z']]

# %%
coordinates.head()§b
§
# Out:
#             x       y    z
# 0  882.000000  999.00  9.0
# 1  553.500000  999.00  9.0
# 2  439.300000  991.90  9.0
# 3   84.800000  957.60  9.0
# 4  260.666667  958.25  9.0

# %%
rois=pd.read_csv('/Users/taldankovich/Downloads/shapes.csv',sep=';')

# %%
rois.head()
# Out:
#                        Obj                 Seq  Volume (unit)  Volume (pix)  \
# 0  HK-Means detection #218  ExpControl Ch1 {0}        0.02584           323
# 1  HK-Means detection #194  ExpControl Ch1 {0}        0.10280          1285
# 2   HK-Means detection #71  ExpControl Ch1 {0}        0.01544           193
# 3   HK-Means detection #55  ExpControl Ch1 {0}        0.02120           265
# 4  HK-Means detection #229  ExpControl Ch1 {0}        0.02200           275
#
#    Area (unit)  Area (pix)  Feret (unit) Mean DC (unit) Min DC (unit)  \
# 0       2.5672        1000      0.894651          #NUM!         #NUM!
# 1      12.5392        4726      1.943708    0.412669214   0.059954572
# 2       1.8368         704      1.051665    0.202872744   0.018817066
# 3       2.3352         924      1.036340    0.202439788   0.016677879
# 4       2.4672         948      1.081665          #NUM!         #NUM!
#
#   Max DC (unit)  Compactness (pix)  Sphericity (pix)  CompactnessCorr (pix)  \
# 0         #NUM!           0.011799          0.227660               0.063067
# 1   1.469171709           0.001769          0.120947               0.015293
# 2   0.795107895           0.012074          0.229412               0.103828
# 3   0.818934672           0.010068          0.215929               0.081778
# 4         #NUM!           0.010039          0.215724               0.060906
#
#    SphericityCorr (pix)  Compactness (unit)  Sphericity (unit)  \
# 0              0.398048            0.004463           0.164647
# 1              0.248216            0.000606           0.084634
# 2              0.470007            0.004351           0.163251
# 3              0.434056            0.003992           0.158630
# 4              0.393448            0.003645           0.153897
#
#    CompDiscrete (pix)  Elongation (unit)  Flatness (unit)  Ratio Ell (unit)
# 0            0.566582           1.561737         3.019185          0.395516
# 1            0.426235           1.301389         1.860398          0.189311
# 2            0.474092           3.140475         1.152626          0.354701
# 3            0.496105           2.503242         1.230557          0.423992
# 4            0.502768           3.302528         1.393265          0.304095

# %%
roisnclean=rois[['Volume (unit)', 'Volume (pix)', 'Area (unit)',
       'Area (pix)', 'Feret (unit)', 'Compactness (pix)', 'Sphericity (pix)',
       'CompactnessCorr (pix)', 'SphericityCorr (pix)', 'Compactness (unit)',
       'Sphericity (unit)', 'CompDiscrete (pix)', 'Elongation (unit)',
       'Flatness (unit)', 'Ratio Ell (unit)']]

# %%
roisnclean=roisnclean.replace(to_replace='#NUM!',value=np.nan)

# %%
vars2plot=roisnclean.columns

# %%
for var in vars2plot:
    roisnclean.hist(column=var)

# %% [markdown]
# ### Specify experiment directory, condtions and image details
# #### Makes dictionary for later storage of results

# %%
expdir='/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/' #master folder

# %% [markdown]
# ### for multiple directories

# %%
results = {"filename":[],"expdate"
           "earlychannelno":[],"latechannelno":[],"synapsechannelno":[],"Autofluorescencedir":[],
           "Earlycontroldir":[],"Latecontroldir":[],
           "Early colour - spots mask":[],
           "Late colour - spots mask":[],
           "Late plus early colour - spots mask":[],
           "Synapse colour - spots mask":[],
           "exp condition":[],
           "Early colour - Raw mean intensity":[],
           "Late colour - Raw mean intensity":[],
           "Synapse colour - Raw mean intensity":[],
           "Global Mean colour bias of a pixel (early=-1<x<1=late)":[],
           "Global Mean colour bias of a pixel (early=-1<x<1=late) Raw":[],
           "Global Mean colour bias of a pixel (early=-1<x<1=late) Normd":[],
           "Mean correlation coefficient early/late":[],
           "Early colour - Mean intensity of spots":[], #based on spot segmentation mask
           "Late colour - Mean intensity of spots":[], #based on spot segmentation mask
           "Synapse colour - Mean intensity of spots":[], #based on spot segmentation mask
           "Early colour - Total no. of spots in FOV":[],#based on spot segmentation mask
           "Late colour - Total no. of spots in FOV":[],#based on spot segmentation mask
           "Synapse colour - Total no. of spots in FOV":[],#based on spot segmentation mask
           "Early colour - Mean spot area [nm]":[],#based on spot segmentation mask
           "Late colour - Mean spot area [nm]":[],#based on spot segmentation mask
           "Synapse colour - Mean spot area [nm]":[],#based on spot segmentation mask
           "Early colour - masked by synapses":[],#based on synapse spot segmentation mask
           "Late colour - masked by synapses":[],#based on synapse spot segmentation mask
           "Mean colour bias of a pixel (early=-1<x<1=late)":[],#based on early spot segmentation mask
           "Mean colour bias of a pixel (early=-1<x<1=late) Raw":[],#based on early spot segmentation mask
           "Mean colour bias of a pixel (early=-1<x<1=late) Normd":[],#based on early spot segmentation mask
           "Mean colour bias of a pixel (early=-1<x<1=late) Normd Minus AutoF":[],#based on early spot segmentation mask
           "Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late)":[], #based on synapse spot segmentation mask
           "Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Raw":[],#based on synapse spot segmentation mask
           "Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd":[],#based on synapse spot segmentation mask
           "Early colour/Synapse colour corr (Mean intensity of spots)":[],
           "Late colour/Synapse colour corr (Mean intensity of spots)":[],
           "Mean colour bias of a pixel - shifted to pos values (early=0)":[],
           "Correlation between colour bias (0 shifted) and synapse intensity":[],
           "Early colour - Mean intensity of spots Normd to ctrls":[],
           "Late colour - Mean intensity of spots Normd to ctrls":[],
           "Early colour Normd to ctrl - masked by synapses":[],
           "Late colour Normd to ctrl - masked by synapses":[],
           "Mean colour bias of a pixel (early=-1<x<1=late) Normd to ctrls":[],
           "Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd to ctrls":[],
           "Early colour - Mean intensity Normd to ctrls":[],
           "Late colour - Mean intensity Normd to ctrls":[],
           "Global Mean colour bias of a pixel (early=-1<x<1=late) Normd to ctrls":[],
           "Early colour/Synapse colour corr (Mean intensity of spots norm to ctrl)":[],
           "Late colour/Synapse colour corr (Mean intensity of spots norm to ctrl)":[]}

histogram_results={"filename":[],"exp condition":[],
           "Early colour - Flattened histogram":[],
           "Early colour - Flattened histogram of image normd to internal max":[],
           "Late colour - Flattened histogram":[],
           "Late colour - Flattened histogram of image normd to internal max":[],
           "Synapse colour - Flattened histogram":[],
           "Synapse colour - Flattened histogram of image normd to internal max":[],
           "Early colour - Flattened histogram of image normd to internal max":[],
           "Late colour - Flattened histogram of image normd to internal max":[],
           "Synapse colour - Flattened histogram of image normd to internal max":[],
           "Global Colour bias of a pixel (early=-1<x<1=late) - Histogram":[],
           "Global Colour bias of a pixel (early=-1<x<1=late) Raw - Histogram":[],
           "Global Colour bias of a pixel (early=-1<x<1=late) Normd - Histogram":[],  
           "Colour bias of a pixel (early=-1<x<1=late) - Histogram":[],#based on early spot segmentation mask
           "Colour bias of a pixel (early=-1<x<1=late) Raw - Histogram":[],#based on early spot segmentation mask
           "Colour bias of a pixel (early=-1<x<1=late) Normd - Histogram":[],#based on early spot segmentation mask  
           "Colour bias of a pixel (early=-1<x<1=late) Normd Minus AutoF - Histogram":[],#based on early spot segmentation mask  
           "Colour bias of a pixel, masked by synapses (early=-1<x<1=late) - Histogram":[],#based on synapse spot segmentation mask
           "Colour bias of a pixel, masked by synapses (early=-1<x<1=late) Raw - Histogram":[],#based on synapse spot segmentation mask
           "Colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd - Histogram":[],#based on synapse spot segmentation mask
           "Colour bias of a pixel (early=-1<x<1=late) Normd to ctrls - Histogram":[],
           "Colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd to ctrls - Histogram":[],
           "Global Colour bias of a pixel (early=-1<x<1=late) Normd to ctrls - Histogram":[]}
                   
regionprops_results={"filename":[],
           "exp condition":[],"Early colour - regionprops":[],
           "Late colour - regionprops":[],
           "Synapse colour - regionprops":[],
           "Late + early colour combined - regionprops":[]}
    
synapse_results={"filename":[],
           "exp condition":[],
           "Early colour - Mean intensity":[], #based on spot segmentation
           "Late colour - Mean intensity":[],#based on spot segmentation
           "Synapse colour - Mean intensity":[],#based on spot segmentation
           "Synapse Area":[], 
           "Mean colour bias of synapse (early=-1<x<1=late)":[],
           "Is new synapse (1=new, 0=old)":[],
           "Correlation between late colour and synapse intensity":[]}

path = os.path.dirname(expdir)  
outputFolder = os.path.dirname(expdir + "/new/")
filelist = []
for root, _, filenames in os.walk(path):
     for filename in filenames:
         filelist.append(os.path.join(root, filename))
        
for i in range(0,len(filelist)):
    if "_use" in str(filelist[i]):
        if ("Agg" in str(filelist[i]))==False:
            if filelist[i].endswith(".nd2"): #& ("60x" in str(filelist[i]))==True:
                results["filename"].append(filelist[i])
                histogram_results["filename"].append(filelist[i])
                regionprops_results["filename"].append(filelist[i])
                results["exp condition"].append(filelist[i].split('/')[-2])
                histogram_results["exp condition"].append(filelist[i].split('/')[-2])
                regionprops_results["exp condition"].append(filelist[i].split('/')[-2])
                channeldir="/".join(filelist[i].split("/")[:-2])
                exec(open(channeldir+"/channels.txt").read())
                results["earlychannelno"].append(earlychannelno)
                results["latechannelno"].append(latechannelno)
                results["synapsechannelno"].append(synapsechannelno)
                autofdir=channeldir+"/Ctrl_Autofluorescence"
                autofdircheck=Path(channeldir+"/Ctrl_Autofluorescence")
                if autofdircheck.exists():
                    results["Autofluorescencedir"].append(autofdir)
                else:
                    results["Autofluorescencedir"].append(0) 
                earlycontrolcheck=Path(channeldir+"/Livectrl_early_immediatemount")
                if earlycontrolcheck.exists():
                    results["Earlycontroldir"].append(channeldir+"/Livectrl_early_immediatemount")
                else:
                    results["Earlycontroldir"].append(channeldir+"/Fixedctrl_early_immediatemount")
                latecontrolcheck=Path(channeldir+"/Livectrl_onlysecondcolour_1day")
                if latecontrolcheck.exists():
                    results["Latecontroldir"].append(channeldir+"/Livectrl_onlysecondcolour_1day")
                else:
                    results["Latecontroldir"].append(channeldir+"/Fixedctrl_onlysecondcolour_1day")

# %%
results["Latecontroldir"][150]
# Out:
# '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Livectrl_onlysecondcolour_1day'

# %%
len(results["filename"])
len(df2)
# Out:
# 1350

# %% [markdown]
# ### Find the spots: Segmentation masked made by adaptive thresholding followed by binary morphology
# #### Play with sigma gauss and i (struct shape) to optimize first

# %%
fig=plt.figure(figsize=(20,50))
figno=1
for im in range(0,3):
    randomno=np.random.randint(1,len(results["filename"]))
    early_channel_no=results["earlychannelno"][randomno]
    late_channel_no=results["latechannelno"][randomno]
    synapse_channel_no=results["synapsechannelno"][randomno]
    with ND2Reader(results["filename"][randomno]) as images:
        print(results["filename"][randomno])
        early_image=images[early_channel_no-1]
        late_image=images[late_channel_no-1]
        if synapse_channel_no>0:
            synapse_image=images[synapse_channel_no-1]
            [channel1name, channel2name, channel3name]=early_image.metadata['channels']
            if early_channel_no==1:
                early_channelname=channel1name
                if late_channel_no==2:
                    late_channelname=channel2name
                    synapse_channelname=channel3name
                else:
                    late_channelname=channel3name
                    synapse_channelname=channel2name
            if early_channel_no==2:
                early_channelname=channel2name
                if late_channel_no==3:
                    late_channelname=channel3name
                    synapse_channelname=channel1name
                else:
                    late_channelname=channel1name
                    synapse_channelname=channel3name
            if early_channel_no==3:
                early_channelname=channel3name
                if late_channel_no==2:
                    late_channelname=channel2name
                    synapse_channelname=channel1name
                else:
                    late_channelname=channel1name
                    synapse_channelname=channel2name
        else:
            synapse_image=np.zeros((512,512))        
            [channel1name, channel2name]=early_image.metadata['channels']
        if early_channel_no==1:
            early_channelname=channel1name
            late_channelname=channel2name
        else:
            early_channelname=channel2name
            late_channelname=channel1name
            synapse_channelname='No staining'
    #smoothing with gaussian filter for noise reduction
    #can play with sigma
    sigmagauss=2.5 #should be roughly half the size of the object you are detecting
    early_smooth = ndi.filters.gaussian_filter(early_image,sigmagauss)
    late_smooth = ndi.filters.gaussian_filter(late_image,sigmagauss)
    synapse_smooth=ndi.filters.gaussian_filter(synapse_image,sigmagauss)
    #adaptive thresholding - bg found by mean filter with SE
    istruct=51 #for SE
    struct = (np.mgrid[:istruct,:istruct][0] - np.floor(istruct/2))**2 + (np.mgrid[:istruct,:istruct][1] - np.floor(istruct/2))**2 <= np.floor(istruct/2)**2
    bg_early = rank.mean(early_smooth, selem=struct)
    bg_late = rank.mean(late_smooth, selem=struct)
    bg_synapse = rank.mean(synapse_smooth, selem=struct)
    early_spots = early_smooth >= bg_early
    late_spots = late_smooth >= bg_late
    synapse_spots = synapse_smooth >= bg_synapse
    lateplusearly_spots = np.add(late_spots,early_spots)
    lateplusearly_spots[lateplusearly_spots==2]=1
    #improve with binary hole filling
    #early_spots_holes_filled = ndi.binary_fill_holes(np.logical_not(early_spots))
    #late_spots_holes_filled = ndi.binary_fill_holes(np.logical_not(late_spots))
    #improve with binary closing
    #i2 = 3
    #struct2 = (np.mgrid[:i2,:i2][0] - np.floor(i2/2))**2 + (np.mgrid[:i2,:i2][1] - np.floor(i2/2))**2 <= np.floor(i2/2)**2
    #pad_size = i+2 #pad the spots image to avoid artifacts at the edges
    #padded_early_spots = np.pad(early_spots_holes_filled,pad_size,mode='reflect')
    #padded_late_spots = np.pad(late_spots_holes_filled,pad_size,mode='reflect')
    #early_spots_final = ndi.binary_closing(np.logical_not(padded_early_spots),structure=struct2)
    #late_spots_final = ndi.binary_closing(np.logical_not(padded_late_spots),structure=struct2)
    #remove the padding from before
    #early_spots_final = early_spots_final[pad_size:-pad_size,pad_size:-pad_size]
    #late_spots_final = late_spots_final[pad_size:-pad_size,pad_size:-pad_size]
    #figures    
    fig.add_subplot(6,4,figno)
    plt.imshow(early_image,interpolation='none',cmap='hot',vmin=1.5*early_image.min(),vmax=0.95*early_image.max())
    plt.title('Early raw: '+early_channelname)
    ax=plt.gca()
    ax.grid(color='none')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    fig.add_subplot(6,4,figno+1)
    plt.imshow(late_image,interpolation='none',cmap='hot')
    plt.title('Late raw: '+late_channelname)
    ax=plt.gca()
    ax.grid(color='none')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    fig.add_subplot(6,4,figno+2)
    plt.imshow(synapse_image,interpolation='none',cmap='hot')
    plt.title('Synapse raw: '+synapse_channelname)
    ax=plt.gca()
    ax.grid(color='none')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    fig.add_subplot(6,4,figno+4)
    plt.imshow(early_spots,interpolation='none',cmap='gray')
    plt.title('Early spots')
    ax=plt.gca()
    ax.grid(color='none')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    fig.add_subplot(6,4,figno+5)
    plt.imshow(late_spots,interpolation='none',cmap='gray')
    plt.title('Late spots')
    ax=plt.gca()
    ax.grid(color='none')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    fig.add_subplot(6,4,figno+6)
    plt.imshow(synapse_spots,interpolation='none',cmap='gray')
    plt.title('Synapse spots')
    ax=plt.gca()
    ax.grid(color='none')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    fig.add_subplot(6,4,figno+7)
    plt.imshow(lateplusearly_spots,interpolation='none',cmap='gray')
    plt.title('Early plus Late spots')
    ax=plt.gca()
    ax.grid(color='none')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    figno=figno+8
# Out:
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180620_Turnover_Bic_TNR_Timepoints_nb635first_580second_use/2hr_Bic/20180620_14_003.nd2
# /anaconda3/lib/python3.6/site-packages/skimage/filters/rank/generic.py:102: UserWarning: Bitdepth of 12 may result in bad rank filter performance due to large number of bins.
#   "performance due to large number of bins." % bitdepth)
# /anaconda3/lib/python3.6/site-packages/skimage/filters/rank/generic.py:102: UserWarning: Bitdepth of 11 may result in bad rank filter performance due to large number of bins.
#   "performance due to large number of bins." % bitdepth)
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/Fixedctrl_early_immediatemount/20180501_TNR_03_006.nd2
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180602_Turnover_Bic_Timepoints_nb635first_580second_use/Fixedctrl_early_immediatemount/20180602_01_02_003.nd2

# %% [markdown]
# #### After optimizing, run below to make segmentation masks for all images

# %%
print('Total number of images: ' + str(len(results['filename'])))

for im in range(0,len(results["filename"])): 
    print('Calculating image no ' + str(im+1) + 'of ' + str(len(results['filename'])))
    early_channel_no=results["earlychannelno"][im]
    late_channel_no=results["latechannelno"][im]
    synapse_channel_no=results["synapsechannelno"][im]
    with ND2Reader(results["filename"][im]) as images:
        early_image=images[early_channel_no-1]
        late_image=images[late_channel_no-1]
        if synapse_channel_no>0:
            synapse_image=images[synapse_channel_no-1]
        else:
            synapse_image=np.zeros((512,512))       
    #smoothing with gaussian filter for noise reduction
    #can play with sigma
    # sigmagauss=3 #taken from previous cell
    early_smooth = ndi.filters.gaussian_filter(early_image,sigmagauss)
    late_smooth = ndi.filters.gaussian_filter(late_image,sigmagauss)
    synapse_smooth = ndi.filters.gaussian_filter(synapse_image,sigmagauss)
    early_image=np.divide(early_image,16383.)
    late_image=np.divide(late_image,16383.)
    synapse_image=np.divide(synapse_image,16383.)
    #adaptive thresholding - bg found by mean filter with SE
    bg_early = rank.mean(early_smooth, selem=struct)
    bg_late = rank.mean(late_smooth, selem=struct)
    bg_synapse = rank.mean(synapse_smooth, selem=struct)
    early_spots = early_smooth >= bg_early
    late_spots = late_smooth >= bg_late
    synapse_spots = synapse_smooth >= bg_synapse
    lateplusearly_spots = np.add(late_spots,early_spots)
    lateplusearly_spots[lateplusearly_spots==2]=1
    #improve with binary hole filling
    #early_spots_holes_filled = ndi.binary_fill_holes(np.logical_not(early_spots))
    #late_spots_holes_filled = ndi.binary_fill_holes(np.logical_not(late_spots))
    #improve with binary closing
    #i2 = 3
    #struct2 = (np.mgrid[:i2,:i2][0] - np.floor(i2/2))**2 + (np.mgrid[:i2,:i2][1] - np.floor(i2/2))**2 <= np.floor(i2/2)**2
    #pad_size = i+2 #pad the spots image to avoid artifacts at the edges
    #padded_early_spots = np.pad(early_spots_holes_filled,pad_size,mode='reflect')
    #padded_late_spots = np.pad(late_spots_holes_filled,pad_size,mode='reflect')
    #early_spots_final = ndi.binary_closing(np.logical_not(padded_early_spots),structure=struct2)
    #late_spots_final = ndi.binary_closing(np.logical_not(padded_late_spots),structure=struct2)
    #remove the padding from before
    #early_spots_final = early_spots_final[pad_size:-pad_size,pad_size:-pad_size]
    #late_spots_final = late_spots_final[pad_size:-pad_size,pad_size:-pad_size]
    results["Early colour - spots mask"].append(early_spots)
    results["Late colour - spots mask"].append(late_spots)
    results["Synapse colour - spots mask"].append(synapse_spots)
    results["Late plus early colour - spots mask"].append(lateplusearly_spots)          
os.system('say "Segmentation complete"')
# Out:
# Total number of images: 1904
# Calculating image no 1of 1904
# /anaconda3/lib/python3.6/site-packages/skimage/filters/rank/generic.py:102: UserWarning: Bitdepth of 11 may result in bad rank filter performance due to large number of bins.
#   "performance due to large number of bins." % bitdepth)
# /anaconda3/lib/python3.6/site-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# Calculating image no 2of 1904
# Calculating image no 3of 1904
# Calculating image no 4of 1904
# /anaconda3/lib/python3.6/site-packages/skimage/filters/rank/generic.py:102: UserWarning: Bitdepth of 12 may result in bad rank filter performance due to large number of bins.
#   "performance due to large number of bins." % bitdepth)
# Calculating image no 5of 1904
# Calculating image no 6of 1904
# Calculating image no 7of 1904
# Calculating image no 8of 1904
# Calculating image no 9of 1904
# Calculating image no 10of 1904
# Calculating image no 11of 1904
# Calculating image no 12of 1904
# Calculating image no 13of 1904
# Calculating image no 14of 1904
# Calculating image no 15of 1904
# /anaconda3/lib/python3.6/site-packages/skimage/filters/rank/generic.py:102: UserWarning: Bitdepth of 13 may result in bad rank filter performance due to large number of bins.
#   "performance due to large number of bins." % bitdepth)
# Calculating image no 16of 1904
# Calculating image no 17of 1904
# Calculating image no 18of 1904
# Calculating image no 19of 1904
# Calculating image no 20of 1904
# Calculating image no 21of 1904
# Calculating image no 22of 1904
# Calculating image no 23of 1904
# Calculating image no 24of 1904
# Calculating image no 25of 1904
# Calculating image no 26of 1904
# Calculating image no 27of 1904
# Calculating image no 28of 1904
# Calculating image no 29of 1904
# Calculating image no 30of 1904
# Calculating image no 31of 1904
# Calculating image no 32of 1904
# Calculating image no 33of 1904
# Calculating image no 34of 1904
# Calculating image no 35of 1904
# Calculating image no 36of 1904
# Calculating image no 37of 1904
# Calculating image no 38of 1904
# Calculating image no 39of 1904
# Calculating image no 40of 1904
# Calculating image no 41of 1904
# Calculating image no 42of 1904
# Calculating image no 43of 1904
# Calculating image no 44of 1904
# Calculating image no 45of 1904
# Calculating image no 46of 1904
# Calculating image no 47of 1904
# Calculating image no 48of 1904
# Calculating image no 49of 1904
# Calculating image no 50of 1904
# Calculating image no 51of 1904
# Calculating image no 52of 1904
# Calculating image no 53of 1904
# Calculating image no 54of 1904
# Calculating image no 55of 1904
# Calculating image no 56of 1904
# Calculating image no 57of 1904
# Calculating image no 58of 1904
# Calculating image no 59of 1904
# Calculating image no 60of 1904
# Calculating image no 61of 1904
# Calculating image no 62of 1904
# Calculating image no 63of 1904
# Calculating image no 64of 1904
# Calculating image no 65of 1904
# Calculating image no 66of 1904
# Calculating image no 67of 1904
# Calculating image no 68of 1904
# Calculating image no 69of 1904
# Calculating image no 70of 1904
# Calculating image no 71of 1904
# Calculating image no 72of 1904
# Calculating image no 73of 1904
# Calculating image no 74of 1904
# Calculating image no 75of 1904
# Calculating image no 76of 1904
# Calculating image no 77of 1904
# Calculating image no 78of 1904
# Calculating image no 79of 1904
# Calculating image no 80of 1904
# Calculating image no 81of 1904
# Calculating image no 82of 1904
# Calculating image no 83of 1904
# Calculating image no 84of 1904
# Calculating image no 85of 1904
# Calculating image no 86of 1904
# Calculating image no 87of 1904
# Calculating image no 88of 1904
# Calculating image no 89of 1904
# Calculating image no 90of 1904
# Calculating image no 91of 1904
# Calculating image no 92of 1904
# Calculating image no 93of 1904
# Calculating image no 94of 1904
# Calculating image no 95of 1904
# Calculating image no 96of 1904
# Calculating image no 97of 1904
# Calculating image no 98of 1904
# Calculating image no 99of 1904
# Calculating image no 100of 1904
# Calculating image no 101of 1904
# Calculating image no 102of 1904
# Calculating image no 103of 1904
# Calculating image no 104of 1904
# Calculating image no 105of 1904
# Calculating image no 106of 1904
# Calculating image no 107of 1904
# Calculating image no 108of 1904
# Calculating image no 109of 1904
# Calculating image no 110of 1904
# Calculating image no 111of 1904
# Calculating image no 112of 1904
# Calculating image no 113of 1904
# Calculating image no 114of 1904
# Calculating image no 115of 1904
# Calculating image no 116of 1904
# Calculating image no 117of 1904
# Calculating image no 118of 1904
# Calculating image no 119of 1904
# Calculating image no 120of 1904
# Calculating image no 121of 1904
# Calculating image no 122of 1904
# Calculating image no 123of 1904
# Calculating image no 124of 1904
# Calculating image no 125of 1904
# Calculating image no 126of 1904
# Calculating image no 127of 1904
# Calculating image no 128of 1904
# Calculating image no 129of 1904
# Calculating image no 130of 1904
# Calculating image no 131of 1904
# Calculating image no 132of 1904
# Calculating image no 133of 1904
# Calculating image no 134of 1904
# Calculating image no 135of 1904
# Calculating image no 136of 1904
# Calculating image no 137of 1904
# Calculating image no 138of 1904
# Calculating image no 139of 1904
# Calculating image no 140of 1904
# Calculating image no 141of 1904
# Calculating image no 142of 1904
# Calculating image no 143of 1904
# Calculating image no 144of 1904
# Calculating image no 145of 1904
# Calculating image no 146of 1904
# Calculating image no 147of 1904
# Calculating image no 148of 1904
# Calculating image no 149of 1904
# Calculating image no 150of 1904
# Calculating image no 151of 1904
# Calculating image no 152of 1904
# Calculating image no 153of 1904
# Calculating image no 154of 1904
# Calculating image no 155of 1904
# Calculating image no 156of 1904
# Calculating image no 157of 1904
# Calculating image no 158of 1904
# Calculating image no 159of 1904
# Calculating image no 160of 1904
# Calculating image no 161of 1904
# Calculating image no 162of 1904
# Calculating image no 163of 1904
# Calculating image no 164of 1904
# Calculating image no 165of 1904
# Calculating image no 166of 1904
# Calculating image no 167of 1904
# Calculating image no 168of 1904
# Calculating image no 169of 1904
# Calculating image no 170of 1904
# Calculating image no 171of 1904
# Calculating image no 172of 1904
# Calculating image no 173of 1904
# Calculating image no 174of 1904
# Calculating image no 175of 1904
# Calculating image no 176of 1904
# Calculating image no 177of 1904
# Calculating image no 178of 1904
# Calculating image no 179of 1904
# Calculating image no 180of 1904
# Calculating image no 181of 1904
# Calculating image no 182of 1904
# Calculating image no 183of 1904
# Calculating image no 184of 1904
# Calculating image no 185of 1904
# Calculating image no 186of 1904
# Calculating image no 187of 1904
# Calculating image no 188of 1904
# Calculating image no 189of 1904
# Calculating image no 190of 1904
# Calculating image no 191of 1904
# Calculating image no 192of 1904
# Calculating image no 193of 1904
# Calculating image no 194of 1904
# Calculating image no 195of 1904
# Calculating image no 196of 1904
# Calculating image no 197of 1904
# Calculating image no 198of 1904
# Calculating image no 199of 1904
# Calculating image no 200of 1904
# Calculating image no 201of 1904
# Calculating image no 202of 1904
# Calculating image no 203of 1904
# Calculating image no 204of 1904
# Calculating image no 205of 1904
# Calculating image no 206of 1904
# Calculating image no 207of 1904
# Calculating image no 208of 1904
# Calculating image no 209of 1904
# Calculating image no 210of 1904
# Calculating image no 211of 1904
# Calculating image no 212of 1904
# Calculating image no 213of 1904
# Calculating image no 214of 1904
# Calculating image no 215of 1904
# Calculating image no 216of 1904
# Calculating image no 217of 1904
# Calculating image no 218of 1904
# Calculating image no 219of 1904
# Calculating image no 220of 1904
# Calculating image no 221of 1904
# Calculating image no 222of 1904
# Calculating image no 223of 1904
# Calculating image no 224of 1904
# Calculating image no 225of 1904
# Calculating image no 226of 1904
# Calculating image no 227of 1904
# Calculating image no 228of 1904
# Calculating image no 229of 1904
# Calculating image no 230of 1904
# Calculating image no 231of 1904
# Calculating image no 232of 1904
# Calculating image no 233of 1904
# Calculating image no 234of 1904
# Calculating image no 235of 1904
# Calculating image no 236of 1904
# Calculating image no 237of 1904
# Calculating image no 238of 1904
# Calculating image no 239of 1904
# Calculating image no 240of 1904
# Calculating image no 241of 1904
# Calculating image no 242of 1904
# Calculating image no 243of 1904
# Calculating image no 244of 1904
# Calculating image no 245of 1904
# Calculating image no 246of 1904
# Calculating image no 247of 1904
# Calculating image no 248of 1904
# Calculating image no 249of 1904
# Calculating image no 250of 1904
# Calculating image no 251of 1904
# Calculating image no 252of 1904
# Calculating image no 253of 1904
# Calculating image no 254of 1904
# Calculating image no 255of 1904
# Calculating image no 256of 1904
# Calculating image no 257of 1904
# Calculating image no 258of 1904
# Calculating image no 259of 1904
# Calculating image no 260of 1904
# Calculating image no 261of 1904
# Calculating image no 262of 1904
# Calculating image no 263of 1904
# Calculating image no 264of 1904
# Calculating image no 265of 1904
# Calculating image no 266of 1904
# Calculating image no 267of 1904
# Calculating image no 268of 1904
# Calculating image no 269of 1904
# Calculating image no 270of 1904
# Calculating image no 271of 1904
# Calculating image no 272of 1904
# Calculating image no 273of 1904
# Calculating image no 274of 1904
# Calculating image no 275of 1904
# Calculating image no 276of 1904
# Calculating image no 277of 1904
# Calculating image no 278of 1904
# Calculating image no 279of 1904
# Calculating image no 280of 1904
# Calculating image no 281of 1904
# Calculating image no 282of 1904
# Calculating image no 283of 1904
# Calculating image no 284of 1904
# Calculating image no 285of 1904
# Calculating image no 286of 1904
# Calculating image no 287of 1904
# Calculating image no 288of 1904
# Calculating image no 289of 1904
# Calculating image no 290of 1904
# Calculating image no 291of 1904
# Calculating image no 292of 1904
# Calculating image no 293of 1904
# Calculating image no 294of 1904
# Calculating image no 295of 1904
# Calculating image no 296of 1904
# Calculating image no 297of 1904
# Calculating image no 298of 1904
# Calculating image no 299of 1904
# Calculating image no 300of 1904
# Calculating image no 301of 1904
# Calculating image no 302of 1904
# Calculating image no 303of 1904
# Calculating image no 304of 1904
# Calculating image no 305of 1904
# Calculating image no 306of 1904
# Calculating image no 307of 1904
# Calculating image no 308of 1904
# Calculating image no 309of 1904
# Calculating image no 310of 1904
# Calculating image no 311of 1904
# Calculating image no 312of 1904
# Calculating image no 313of 1904
# Calculating image no 314of 1904
# Calculating image no 315of 1904
# Calculating image no 316of 1904
# Calculating image no 317of 1904
# Calculating image no 318of 1904
# Calculating image no 319of 1904
# Calculating image no 320of 1904
# Calculating image no 321of 1904
# Calculating image no 322of 1904
# Calculating image no 323of 1904
# Calculating image no 324of 1904
# Calculating image no 325of 1904
# Calculating image no 326of 1904
# Calculating image no 327of 1904
# Calculating image no 328of 1904
# Calculating image no 329of 1904
# Calculating image no 330of 1904
# Calculating image no 331of 1904
# Calculating image no 332of 1904
# Calculating image no 333of 1904
# Calculating image no 334of 1904
# Calculating image no 335of 1904
# Calculating image no 336of 1904
# Calculating image no 337of 1904
# Calculating image no 338of 1904
# Calculating image no 339of 1904
# Calculating image no 340of 1904
# Calculating image no 341of 1904
# Calculating image no 342of 1904
# Calculating image no 343of 1904
# Calculating image no 344of 1904
# Calculating image no 345of 1904
# Calculating image no 346of 1904
# Calculating image no 347of 1904
# Calculating image no 348of 1904
# Calculating image no 349of 1904
# Calculating image no 350of 1904
# Calculating image no 351of 1904
# Calculating image no 352of 1904
# Calculating image no 353of 1904
# Calculating image no 354of 1904
# Calculating image no 355of 1904
# Calculating image no 356of 1904
# Calculating image no 357of 1904
# Calculating image no 358of 1904
# Calculating image no 359of 1904
# Calculating image no 360of 1904
# Calculating image no 361of 1904
# Calculating image no 362of 1904
# Calculating image no 363of 1904
# Calculating image no 364of 1904
# Calculating image no 365of 1904
# Calculating image no 366of 1904
# Calculating image no 367of 1904
# Calculating image no 368of 1904
# Calculating image no 369of 1904
# Calculating image no 370of 1904
# Calculating image no 371of 1904
# Calculating image no 372of 1904
# Calculating image no 373of 1904
# Calculating image no 374of 1904
# Calculating image no 375of 1904
# Calculating image no 376of 1904
# Calculating image no 377of 1904
# Calculating image no 378of 1904
# Calculating image no 379of 1904
# Calculating image no 380of 1904
# Calculating image no 381of 1904
# Calculating image no 382of 1904
# Calculating image no 383of 1904
# Calculating image no 384of 1904
# Calculating image no 385of 1904
# Calculating image no 386of 1904
# Calculating image no 387of 1904
# Calculating image no 388of 1904
# Calculating image no 389of 1904
# Calculating image no 390of 1904
# Calculating image no 391of 1904
# Calculating image no 392of 1904
# Calculating image no 393of 1904
# Calculating image no 394of 1904
# Calculating image no 395of 1904
# Calculating image no 396of 1904
# Calculating image no 397of 1904
# Calculating image no 398of 1904
# Calculating image no 399of 1904
# Calculating image no 400of 1904
# Calculating image no 401of 1904
# Calculating image no 402of 1904
# Calculating image no 403of 1904
# Calculating image no 404of 1904
# Calculating image no 405of 1904
# Calculating image no 406of 1904
# Calculating image no 407of 1904
# Calculating image no 408of 1904
# Calculating image no 409of 1904
# Calculating image no 410of 1904
# Calculating image no 411of 1904
# Calculating image no 412of 1904
# Calculating image no 413of 1904
# Calculating image no 414of 1904
# Calculating image no 415of 1904
# Calculating image no 416of 1904
# Calculating image no 417of 1904
# Calculating image no 418of 1904
# Calculating image no 419of 1904
# Calculating image no 420of 1904
# Calculating image no 421of 1904
# Calculating image no 422of 1904
# Calculating image no 423of 1904
# Calculating image no 424of 1904
# Calculating image no 425of 1904
# Calculating image no 426of 1904
# Calculating image no 427of 1904
# Calculating image no 428of 1904
# Calculating image no 429of 1904
# Calculating image no 430of 1904
# Calculating image no 431of 1904
# Calculating image no 432of 1904
# Calculating image no 433of 1904
# Calculating image no 434of 1904
# Calculating image no 435of 1904
# Calculating image no 436of 1904
# Calculating image no 437of 1904
# Calculating image no 438of 1904
# Calculating image no 439of 1904
# Calculating image no 440of 1904
# Calculating image no 441of 1904
# Calculating image no 442of 1904
# Calculating image no 443of 1904
# Calculating image no 444of 1904
# Calculating image no 445of 1904
# Calculating image no 446of 1904
# Calculating image no 447of 1904
# Calculating image no 448of 1904
# Calculating image no 449of 1904
# Calculating image no 450of 1904
# Calculating image no 451of 1904
# Calculating image no 452of 1904
# Calculating image no 453of 1904
# Calculating image no 454of 1904
# Calculating image no 455of 1904
# Calculating image no 456of 1904
# Calculating image no 457of 1904
# Calculating image no 458of 1904
# Calculating image no 459of 1904
# Calculating image no 460of 1904
# Calculating image no 461of 1904
# Calculating image no 462of 1904
# Calculating image no 463of 1904
# Calculating image no 464of 1904
# Calculating image no 465of 1904
# Calculating image no 466of 1904
# Calculating image no 467of 1904
# Calculating image no 468of 1904
# Calculating image no 469of 1904
# Calculating image no 470of 1904
# Calculating image no 471of 1904
# Calculating image no 472of 1904
# Calculating image no 473of 1904
# Calculating image no 474of 1904
# Calculating image no 475of 1904
# Calculating image no 476of 1904
# Calculating image no 477of 1904
# Calculating image no 478of 1904
# Calculating image no 479of 1904
# Calculating image no 480of 1904
# Calculating image no 481of 1904
# Calculating image no 482of 1904
# Calculating image no 483of 1904
# Calculating image no 484of 1904
# Calculating image no 485of 1904
# Calculating image no 486of 1904
# Calculating image no 487of 1904
# Calculating image no 488of 1904
# Calculating image no 489of 1904
# Calculating image no 490of 1904
# Calculating image no 491of 1904
# Calculating image no 492of 1904
# Calculating image no 493of 1904
# Calculating image no 494of 1904
# Calculating image no 495of 1904
# Calculating image no 496of 1904
# Calculating image no 497of 1904
# Calculating image no 498of 1904
# Calculating image no 499of 1904
# Calculating image no 500of 1904
# Calculating image no 501of 1904
# Calculating image no 502of 1904
# Calculating image no 503of 1904
# Calculating image no 504of 1904
# Calculating image no 505of 1904
# Calculating image no 506of 1904
# Calculating image no 507of 1904
# Calculating image no 508of 1904
# Calculating image no 509of 1904
# Calculating image no 510of 1904
# Calculating image no 511of 1904
# Calculating image no 512of 1904
# Calculating image no 513of 1904
# Calculating image no 514of 1904
# Calculating image no 515of 1904
# Calculating image no 516of 1904
# Calculating image no 517of 1904
# Calculating image no 518of 1904
# Calculating image no 519of 1904
# Calculating image no 520of 1904
# Calculating image no 521of 1904
# Calculating image no 522of 1904
# Calculating image no 523of 1904
# Calculating image no 524of 1904
# Calculating image no 525of 1904
# Calculating image no 526of 1904
# Calculating image no 527of 1904
# Calculating image no 528of 1904
# Calculating image no 529of 1904
# Calculating image no 530of 1904
# Calculating image no 531of 1904
# Calculating image no 532of 1904
# Calculating image no 533of 1904
# Calculating image no 534of 1904
# Calculating image no 535of 1904
# Calculating image no 536of 1904
# Calculating image no 537of 1904
# Calculating image no 538of 1904
# Calculating image no 539of 1904
# Calculating image no 540of 1904
# Calculating image no 541of 1904
# Calculating image no 542of 1904
# Calculating image no 543of 1904
# Calculating image no 544of 1904
# Calculating image no 545of 1904
# Calculating image no 546of 1904
# Calculating image no 547of 1904
# Calculating image no 548of 1904
# Calculating image no 549of 1904
# Calculating image no 550of 1904
# Calculating image no 551of 1904
# Calculating image no 552of 1904
# Calculating image no 553of 1904
# Calculating image no 554of 1904
# Calculating image no 555of 1904
# Calculating image no 556of 1904
# Calculating image no 557of 1904
# Calculating image no 558of 1904
# Calculating image no 559of 1904
# Calculating image no 560of 1904
# Calculating image no 561of 1904
# Calculating image no 562of 1904
# Calculating image no 563of 1904
# Calculating image no 564of 1904
# Calculating image no 565of 1904
# Calculating image no 566of 1904
# Calculating image no 567of 1904
# Calculating image no 568of 1904
# Calculating image no 569of 1904
# Calculating image no 570of 1904
# Calculating image no 571of 1904
# Calculating image no 572of 1904
# Calculating image no 573of 1904
# Calculating image no 574of 1904
# Calculating image no 575of 1904
# Calculating image no 576of 1904
# Calculating image no 577of 1904
# Calculating image no 578of 1904
# Calculating image no 579of 1904
# Calculating image no 580of 1904
# Calculating image no 581of 1904
# Calculating image no 582of 1904
# Calculating image no 583of 1904
# Calculating image no 584of 1904
# Calculating image no 585of 1904
# Calculating image no 586of 1904
# Calculating image no 587of 1904
# Calculating image no 588of 1904
# Calculating image no 589of 1904
# Calculating image no 590of 1904
# Calculating image no 591of 1904
# Calculating image no 592of 1904
# Calculating image no 593of 1904
# Calculating image no 594of 1904
# Calculating image no 595of 1904
# Calculating image no 596of 1904
# Calculating image no 597of 1904
# Calculating image no 598of 1904
# Calculating image no 599of 1904
# Calculating image no 600of 1904
# Calculating image no 601of 1904
# Calculating image no 602of 1904
# Calculating image no 603of 1904
# Calculating image no 604of 1904
# Calculating image no 605of 1904
# Calculating image no 606of 1904
# Calculating image no 607of 1904
# Calculating image no 608of 1904
# Calculating image no 609of 1904
# Calculating image no 610of 1904
# Calculating image no 611of 1904
# Calculating image no 612of 1904
# Calculating image no 613of 1904
# Calculating image no 614of 1904
# Calculating image no 615of 1904
# Calculating image no 616of 1904
# Calculating image no 617of 1904
# Calculating image no 618of 1904
# Calculating image no 619of 1904
# Calculating image no 620of 1904
# Calculating image no 621of 1904
# Calculating image no 622of 1904
# Calculating image no 623of 1904
# Calculating image no 624of 1904
# Calculating image no 625of 1904
# Calculating image no 626of 1904
# Calculating image no 627of 1904
# Calculating image no 628of 1904
# Calculating image no 629of 1904
# Calculating image no 630of 1904
# Calculating image no 631of 1904
# Calculating image no 632of 1904
# Calculating image no 633of 1904
# Calculating image no 634of 1904
# Calculating image no 635of 1904
# Calculating image no 636of 1904
# Calculating image no 637of 1904
# Calculating image no 638of 1904
# Calculating image no 639of 1904
# Calculating image no 640of 1904
# Calculating image no 641of 1904
# Calculating image no 642of 1904
# Calculating image no 643of 1904
# Calculating image no 644of 1904
# Calculating image no 645of 1904
# Calculating image no 646of 1904
# Calculating image no 647of 1904
# Calculating image no 648of 1904
# Calculating image no 649of 1904
# Calculating image no 650of 1904
# Calculating image no 651of 1904
# Calculating image no 652of 1904
# Calculating image no 653of 1904
# Calculating image no 654of 1904
# Calculating image no 655of 1904
# Calculating image no 656of 1904
# Calculating image no 657of 1904
# Calculating image no 658of 1904
# Calculating image no 659of 1904
# Calculating image no 660of 1904
# Calculating image no 661of 1904
# Calculating image no 662of 1904
# Calculating image no 663of 1904
# Calculating image no 664of 1904
# Calculating image no 665of 1904
# Calculating image no 666of 1904
# Calculating image no 667of 1904
# Calculating image no 668of 1904
# Calculating image no 669of 1904
# Calculating image no 670of 1904
# Calculating image no 671of 1904
# Calculating image no 672of 1904
# Calculating image no 673of 1904
# Calculating image no 674of 1904
# Calculating image no 675of 1904
# Calculating image no 676of 1904
# Calculating image no 677of 1904
# Calculating image no 678of 1904
# Calculating image no 679of 1904
# Calculating image no 680of 1904
# Calculating image no 681of 1904
# Calculating image no 682of 1904
# Calculating image no 683of 1904
# Calculating image no 684of 1904
# Calculating image no 685of 1904
# Calculating image no 686of 1904
# Calculating image no 687of 1904
# Calculating image no 688of 1904
# Calculating image no 689of 1904
# Calculating image no 690of 1904
# Calculating image no 691of 1904
# Calculating image no 692of 1904
# Calculating image no 693of 1904
# Calculating image no 694of 1904
# Calculating image no 695of 1904
# Calculating image no 696of 1904
# Calculating image no 697of 1904
# Calculating image no 698of 1904
# Calculating image no 699of 1904
# Calculating image no 700of 1904
# Calculating image no 701of 1904
# Calculating image no 702of 1904
# Calculating image no 703of 1904
# Calculating image no 704of 1904
# Calculating image no 705of 1904
# Calculating image no 706of 1904
# Calculating image no 707of 1904
# Calculating image no 708of 1904
# Calculating image no 709of 1904
# Calculating image no 710of 1904
# Calculating image no 711of 1904
# Calculating image no 712of 1904
# Calculating image no 713of 1904
# Calculating image no 714of 1904
# Calculating image no 715of 1904
# Calculating image no 716of 1904
# Calculating image no 717of 1904
# Calculating image no 718of 1904
# Calculating image no 719of 1904
# Calculating image no 720of 1904
# Calculating image no 721of 1904
# Calculating image no 722of 1904
# Calculating image no 723of 1904
# Calculating image no 724of 1904
# Calculating image no 725of 1904
# Calculating image no 726of 1904
# Calculating image no 727of 1904
# Calculating image no 728of 1904
# Calculating image no 729of 1904
# Calculating image no 730of 1904
# Calculating image no 731of 1904
# Calculating image no 732of 1904
# Calculating image no 733of 1904
# Calculating image no 734of 1904
# Calculating image no 735of 1904
# Calculating image no 736of 1904
# Calculating image no 737of 1904
# Calculating image no 738of 1904
# Calculating image no 739of 1904
# Calculating image no 740of 1904
# Calculating image no 741of 1904
# Calculating image no 742of 1904
# Calculating image no 743of 1904
# Calculating image no 744of 1904
# Calculating image no 745of 1904
# Calculating image no 746of 1904
# Calculating image no 747of 1904
# Calculating image no 748of 1904
# Calculating image no 749of 1904
# Calculating image no 750of 1904
# Calculating image no 751of 1904
# Calculating image no 752of 1904
# Calculating image no 753of 1904
# Calculating image no 754of 1904
# Calculating image no 755of 1904
# Calculating image no 756of 1904
# Calculating image no 757of 1904
# Calculating image no 758of 1904
# Calculating image no 759of 1904
# Calculating image no 760of 1904
# Calculating image no 761of 1904
# Calculating image no 762of 1904
# Calculating image no 763of 1904
# Calculating image no 764of 1904
# Calculating image no 765of 1904
# Calculating image no 766of 1904
# Calculating image no 767of 1904
# Calculating image no 768of 1904
# Calculating image no 769of 1904
# Calculating image no 770of 1904
# Calculating image no 771of 1904
# Calculating image no 772of 1904
# Calculating image no 773of 1904
# Calculating image no 774of 1904
# Calculating image no 775of 1904
# Calculating image no 776of 1904
# Calculating image no 777of 1904
# Calculating image no 778of 1904
# Calculating image no 779of 1904
# Calculating image no 780of 1904
# Calculating image no 781of 1904
# Calculating image no 782of 1904
# Calculating image no 783of 1904
# Calculating image no 784of 1904
# Calculating image no 785of 1904
# Calculating image no 786of 1904
# Calculating image no 787of 1904
# Calculating image no 788of 1904
# Calculating image no 789of 1904
# Calculating image no 790of 1904
# Calculating image no 791of 1904
# Calculating image no 792of 1904
# Calculating image no 793of 1904
# Calculating image no 794of 1904
# Calculating image no 795of 1904
# Calculating image no 796of 1904
# Calculating image no 797of 1904
# Calculating image no 798of 1904
# Calculating image no 799of 1904
# Calculating image no 800of 1904
# Calculating image no 801of 1904
# Calculating image no 802of 1904
# Calculating image no 803of 1904
# Calculating image no 804of 1904
# Calculating image no 805of 1904
# Calculating image no 806of 1904
# Calculating image no 807of 1904
# Calculating image no 808of 1904
# Calculating image no 809of 1904
# Calculating image no 810of 1904
# Calculating image no 811of 1904
# Calculating image no 812of 1904
# Calculating image no 813of 1904
# Calculating image no 814of 1904
# Calculating image no 815of 1904
# Calculating image no 816of 1904
# Calculating image no 817of 1904
# Calculating image no 818of 1904
# Calculating image no 819of 1904
# Calculating image no 820of 1904
# Calculating image no 821of 1904
# Calculating image no 822of 1904
# Calculating image no 823of 1904
# Calculating image no 824of 1904
# Calculating image no 825of 1904
# Calculating image no 826of 1904
# Calculating image no 827of 1904
# Calculating image no 828of 1904
# Calculating image no 829of 1904
# Calculating image no 830of 1904
# Calculating image no 831of 1904
# Calculating image no 832of 1904
# Calculating image no 833of 1904
# Calculating image no 834of 1904
# Calculating image no 835of 1904
# Calculating image no 836of 1904
# Calculating image no 837of 1904
# Calculating image no 838of 1904
# Calculating image no 839of 1904
# Calculating image no 840of 1904
# Calculating image no 841of 1904
# Calculating image no 842of 1904
# Calculating image no 843of 1904
# Calculating image no 844of 1904
# Calculating image no 845of 1904
# Calculating image no 846of 1904
# Calculating image no 847of 1904
# Calculating image no 848of 1904
# Calculating image no 849of 1904
# Calculating image no 850of 1904
# Calculating image no 851of 1904
# Calculating image no 852of 1904
# Calculating image no 853of 1904
# Calculating image no 854of 1904
# Calculating image no 855of 1904
# Calculating image no 856of 1904
# Calculating image no 857of 1904
# Calculating image no 858of 1904
# Calculating image no 859of 1904
# Calculating image no 860of 1904
# Calculating image no 861of 1904
# Calculating image no 862of 1904
# Calculating image no 863of 1904
# Calculating image no 864of 1904
# Calculating image no 865of 1904
# Calculating image no 866of 1904
# Calculating image no 867of 1904
# Calculating image no 868of 1904
# Calculating image no 869of 1904
# Calculating image no 870of 1904
# Calculating image no 871of 1904
# Calculating image no 872of 1904
# Calculating image no 873of 1904
# Calculating image no 874of 1904
# Calculating image no 875of 1904
# Calculating image no 876of 1904
# Calculating image no 877of 1904
# Calculating image no 878of 1904
# Calculating image no 879of 1904
# Calculating image no 880of 1904
# Calculating image no 881of 1904
# Calculating image no 882of 1904
# Calculating image no 883of 1904
# Calculating image no 884of 1904
# Calculating image no 885of 1904
# Calculating image no 886of 1904
# Calculating image no 887of 1904
# Calculating image no 888of 1904
# Calculating image no 889of 1904
# Calculating image no 890of 1904
# Calculating image no 891of 1904
# Calculating image no 892of 1904
# Calculating image no 893of 1904
# Calculating image no 894of 1904
# Calculating image no 895of 1904
# Calculating image no 896of 1904
# Calculating image no 897of 1904
# Calculating image no 898of 1904
# Calculating image no 899of 1904
# Calculating image no 900of 1904
# Calculating image no 901of 1904
# Calculating image no 902of 1904
# Calculating image no 903of 1904
# Calculating image no 904of 1904
# Calculating image no 905of 1904
# Calculating image no 906of 1904
# Calculating image no 907of 1904
# Calculating image no 908of 1904
# Calculating image no 909of 1904
# Calculating image no 910of 1904
# Calculating image no 911of 1904
# Calculating image no 912of 1904
# Calculating image no 913of 1904
# Calculating image no 914of 1904
# Calculating image no 915of 1904
# Calculating image no 916of 1904
# Calculating image no 917of 1904
# Calculating image no 918of 1904
# Calculating image no 919of 1904
# Calculating image no 920of 1904
# Calculating image no 921of 1904
# Calculating image no 922of 1904
# Calculating image no 923of 1904
# Calculating image no 924of 1904
# Calculating image no 925of 1904
# Calculating image no 926of 1904
# Calculating image no 927of 1904
# Calculating image no 928of 1904
# Calculating image no 929of 1904
# Calculating image no 930of 1904
# Calculating image no 931of 1904
# Calculating image no 932of 1904
# Calculating image no 933of 1904
# Calculating image no 934of 1904
# Calculating image no 935of 1904
# Calculating image no 936of 1904
# Calculating image no 937of 1904
# Calculating image no 938of 1904
# Calculating image no 939of 1904
# Calculating image no 940of 1904
# Calculating image no 941of 1904
# Calculating image no 942of 1904
# Calculating image no 943of 1904
# Calculating image no 944of 1904
# Calculating image no 945of 1904
# Calculating image no 946of 1904
# Calculating image no 947of 1904
# Calculating image no 948of 1904
# Calculating image no 949of 1904
# Calculating image no 950of 1904
# Calculating image no 951of 1904
# Calculating image no 952of 1904
# Calculating image no 953of 1904
# Calculating image no 954of 1904
# Calculating image no 955of 1904
# Calculating image no 956of 1904
# Calculating image no 957of 1904
# Calculating image no 958of 1904
# Calculating image no 959of 1904
# Calculating image no 960of 1904
# Calculating image no 961of 1904
# Calculating image no 962of 1904
# Calculating image no 963of 1904
# Calculating image no 964of 1904
# Calculating image no 965of 1904
# Calculating image no 966of 1904
# Calculating image no 967of 1904
# Calculating image no 968of 1904
# Calculating image no 969of 1904
# Calculating image no 970of 1904
# Calculating image no 971of 1904
# Calculating image no 972of 1904
# Calculating image no 973of 1904
# Calculating image no 974of 1904
# Calculating image no 975of 1904
# Calculating image no 976of 1904
# Calculating image no 977of 1904
# Calculating image no 978of 1904
# Calculating image no 979of 1904
# Calculating image no 980of 1904
# Calculating image no 981of 1904
# Calculating image no 982of 1904
# Calculating image no 983of 1904
# Calculating image no 984of 1904
# Calculating image no 985of 1904
# Calculating image no 986of 1904
# Calculating image no 987of 1904
# Calculating image no 988of 1904
# Calculating image no 989of 1904
# Calculating image no 990of 1904
# Calculating image no 991of 1904
# Calculating image no 992of 1904
# Calculating image no 993of 1904
# Calculating image no 994of 1904
# Calculating image no 995of 1904
# Calculating image no 996of 1904
# Calculating image no 997of 1904
# Calculating image no 998of 1904
# Calculating image no 999of 1904
# Calculating image no 1000of 1904
# Calculating image no 1001of 1904
# Calculating image no 1002of 1904
# Calculating image no 1003of 1904
# Calculating image no 1004of 1904
# Calculating image no 1005of 1904
# Calculating image no 1006of 1904
# Calculating image no 1007of 1904
# Calculating image no 1008of 1904
# Calculating image no 1009of 1904
# Calculating image no 1010of 1904
# Calculating image no 1011of 1904
# Calculating image no 1012of 1904
# Calculating image no 1013of 1904
# Calculating image no 1014of 1904
# Calculating image no 1015of 1904
# Calculating image no 1016of 1904
# Calculating image no 1017of 1904
# Calculating image no 1018of 1904
# Calculating image no 1019of 1904
# Calculating image no 1020of 1904
# Calculating image no 1021of 1904
# Calculating image no 1022of 1904
# Calculating image no 1023of 1904
# Calculating image no 1024of 1904
# Calculating image no 1025of 1904
# Calculating image no 1026of 1904
# Calculating image no 1027of 1904
# Calculating image no 1028of 1904
# Calculating image no 1029of 1904
# Calculating image no 1030of 1904
# Calculating image no 1031of 1904
# Calculating image no 1032of 1904
# Calculating image no 1033of 1904
# Calculating image no 1034of 1904
# Calculating image no 1035of 1904
# Calculating image no 1036of 1904
# Calculating image no 1037of 1904
# Calculating image no 1038of 1904
# Calculating image no 1039of 1904
# Calculating image no 1040of 1904
# Calculating image no 1041of 1904
# Calculating image no 1042of 1904
# Calculating image no 1043of 1904
# Calculating image no 1044of 1904
# Calculating image no 1045of 1904
# Calculating image no 1046of 1904
# Calculating image no 1047of 1904
# Calculating image no 1048of 1904
# Calculating image no 1049of 1904
# Calculating image no 1050of 1904
# Calculating image no 1051of 1904
# Calculating image no 1052of 1904
# Calculating image no 1053of 1904
# Calculating image no 1054of 1904
# Calculating image no 1055of 1904
# Calculating image no 1056of 1904
# Calculating image no 1057of 1904
# Calculating image no 1058of 1904
# Calculating image no 1059of 1904
# Calculating image no 1060of 1904
# Calculating image no 1061of 1904
# Calculating image no 1062of 1904
# Calculating image no 1063of 1904
# Calculating image no 1064of 1904
# Calculating image no 1065of 1904
# Calculating image no 1066of 1904
# Calculating image no 1067of 1904
# Calculating image no 1068of 1904
# Calculating image no 1069of 1904
# Calculating image no 1070of 1904
# Calculating image no 1071of 1904
# Calculating image no 1072of 1904
# Calculating image no 1073of 1904
# Calculating image no 1074of 1904
# Calculating image no 1075of 1904
# Calculating image no 1076of 1904
# Calculating image no 1077of 1904
# Calculating image no 1078of 1904
# Calculating image no 1079of 1904
# Calculating image no 1080of 1904
# Calculating image no 1081of 1904
# Calculating image no 1082of 1904
# Calculating image no 1083of 1904
# Calculating image no 1084of 1904
# Calculating image no 1085of 1904
# Calculating image no 1086of 1904
# Calculating image no 1087of 1904
# Calculating image no 1088of 1904
# Calculating image no 1089of 1904
# Calculating image no 1090of 1904
# Calculating image no 1091of 1904
# Calculating image no 1092of 1904
# Calculating image no 1093of 1904
# Calculating image no 1094of 1904
# Calculating image no 1095of 1904
# Calculating image no 1096of 1904
# Calculating image no 1097of 1904
# Calculating image no 1098of 1904
# Calculating image no 1099of 1904
# Calculating image no 1100of 1904
# Calculating image no 1101of 1904
# Calculating image no 1102of 1904
# Calculating image no 1103of 1904
# Calculating image no 1104of 1904
# Calculating image no 1105of 1904
# Calculating image no 1106of 1904
# Calculating image no 1107of 1904
# Calculating image no 1108of 1904
# Calculating image no 1109of 1904
# Calculating image no 1110of 1904
# Calculating image no 1111of 1904
# Calculating image no 1112of 1904
# Calculating image no 1113of 1904
# Calculating image no 1114of 1904
# Calculating image no 1115of 1904
# Calculating image no 1116of 1904
# Calculating image no 1117of 1904
# Calculating image no 1118of 1904
# Calculating image no 1119of 1904
# Calculating image no 1120of 1904
# Calculating image no 1121of 1904
# Calculating image no 1122of 1904
# Calculating image no 1123of 1904
# Calculating image no 1124of 1904
# Calculating image no 1125of 1904
# Calculating image no 1126of 1904
# Calculating image no 1127of 1904
# Calculating image no 1128of 1904
# Calculating image no 1129of 1904
# Calculating image no 1130of 1904
# Calculating image no 1131of 1904
# Calculating image no 1132of 1904
# Calculating image no 1133of 1904
# Calculating image no 1134of 1904
# Calculating image no 1135of 1904
# Calculating image no 1136of 1904
# Calculating image no 1137of 1904
# Calculating image no 1138of 1904
# Calculating image no 1139of 1904
# Calculating image no 1140of 1904
# Calculating image no 1141of 1904
# Calculating image no 1142of 1904
# Calculating image no 1143of 1904
# Calculating image no 1144of 1904
# Calculating image no 1145of 1904
# Calculating image no 1146of 1904
# Calculating image no 1147of 1904
# Calculating image no 1148of 1904
# Calculating image no 1149of 1904
# Calculating image no 1150of 1904
# Calculating image no 1151of 1904
# Calculating image no 1152of 1904
# Calculating image no 1153of 1904
# Calculating image no 1154of 1904
# Calculating image no 1155of 1904
# Calculating image no 1156of 1904
# Calculating image no 1157of 1904
# Calculating image no 1158of 1904
# Calculating image no 1159of 1904
# Calculating image no 1160of 1904
# Calculating image no 1161of 1904
# Calculating image no 1162of 1904
# Calculating image no 1163of 1904
# Calculating image no 1164of 1904
# Calculating image no 1165of 1904
# Calculating image no 1166of 1904
# Calculating image no 1167of 1904
# Calculating image no 1168of 1904
# Calculating image no 1169of 1904
# Calculating image no 1170of 1904
# Calculating image no 1171of 1904
# Calculating image no 1172of 1904
# Calculating image no 1173of 1904
# Calculating image no 1174of 1904
# Calculating image no 1175of 1904
# Calculating image no 1176of 1904
# Calculating image no 1177of 1904
# Calculating image no 1178of 1904
# Calculating image no 1179of 1904
# Calculating image no 1180of 1904
# Calculating image no 1181of 1904
# Calculating image no 1182of 1904
# Calculating image no 1183of 1904
# Calculating image no 1184of 1904
# Calculating image no 1185of 1904
# Calculating image no 1186of 1904
# Calculating image no 1187of 1904
# Calculating image no 1188of 1904
# Calculating image no 1189of 1904
# Calculating image no 1190of 1904
# Calculating image no 1191of 1904
# Calculating image no 1192of 1904
# Calculating image no 1193of 1904
# Calculating image no 1194of 1904
# Calculating image no 1195of 1904
# Calculating image no 1196of 1904
# Calculating image no 1197of 1904
# Calculating image no 1198of 1904
# Calculating image no 1199of 1904
# Calculating image no 1200of 1904
# Calculating image no 1201of 1904
# Calculating image no 1202of 1904
# Calculating image no 1203of 1904
# Calculating image no 1204of 1904
# Calculating image no 1205of 1904
# Calculating image no 1206of 1904
# Calculating image no 1207of 1904
# Calculating image no 1208of 1904
# Calculating image no 1209of 1904
# Calculating image no 1210of 1904
# Calculating image no 1211of 1904
# Calculating image no 1212of 1904
# Calculating image no 1213of 1904
# Calculating image no 1214of 1904
# Calculating image no 1215of 1904
# Calculating image no 1216of 1904
# Calculating image no 1217of 1904
# Calculating image no 1218of 1904
# Calculating image no 1219of 1904
# Calculating image no 1220of 1904
# Calculating image no 1221of 1904
# Calculating image no 1222of 1904
# Calculating image no 1223of 1904
# Calculating image no 1224of 1904
# Calculating image no 1225of 1904
# Calculating image no 1226of 1904
# Calculating image no 1227of 1904
# Calculating image no 1228of 1904
# Calculating image no 1229of 1904
# Calculating image no 1230of 1904
# Calculating image no 1231of 1904
# Calculating image no 1232of 1904
# Calculating image no 1233of 1904
# Calculating image no 1234of 1904
# Calculating image no 1235of 1904
# Calculating image no 1236of 1904
# Calculating image no 1237of 1904
# Calculating image no 1238of 1904
# Calculating image no 1239of 1904
# Calculating image no 1240of 1904
# Calculating image no 1241of 1904
# Calculating image no 1242of 1904
# Calculating image no 1243of 1904
# Calculating image no 1244of 1904
# Calculating image no 1245of 1904
# Calculating image no 1246of 1904
# Calculating image no 1247of 1904
# Calculating image no 1248of 1904
# Calculating image no 1249of 1904
# Calculating image no 1250of 1904
# Calculating image no 1251of 1904
# Calculating image no 1252of 1904
# Calculating image no 1253of 1904
# Calculating image no 1254of 1904
# Calculating image no 1255of 1904
# Calculating image no 1256of 1904
# Calculating image no 1257of 1904
# Calculating image no 1258of 1904
# Calculating image no 1259of 1904
# Calculating image no 1260of 1904
# Calculating image no 1261of 1904
# Calculating image no 1262of 1904
# Calculating image no 1263of 1904
# Calculating image no 1264of 1904
# Calculating image no 1265of 1904
# Calculating image no 1266of 1904
# Calculating image no 1267of 1904
# Calculating image no 1268of 1904
# Calculating image no 1269of 1904
# Calculating image no 1270of 1904
# Calculating image no 1271of 1904
# Calculating image no 1272of 1904
# Calculating image no 1273of 1904
# Calculating image no 1274of 1904
# Calculating image no 1275of 1904
# Calculating image no 1276of 1904
# Calculating image no 1277of 1904
# Calculating image no 1278of 1904
# Calculating image no 1279of 1904
# Calculating image no 1280of 1904
# Calculating image no 1281of 1904
# Calculating image no 1282of 1904
# Calculating image no 1283of 1904
# Calculating image no 1284of 1904
# Calculating image no 1285of 1904
# Calculating image no 1286of 1904
# Calculating image no 1287of 1904
# Calculating image no 1288of 1904
# Calculating image no 1289of 1904
# Calculating image no 1290of 1904
# Calculating image no 1291of 1904
# Calculating image no 1292of 1904
# Calculating image no 1293of 1904
# Calculating image no 1294of 1904
# Calculating image no 1295of 1904
# Calculating image no 1296of 1904
# Calculating image no 1297of 1904
# Calculating image no 1298of 1904
# Calculating image no 1299of 1904
# Calculating image no 1300of 1904
# Calculating image no 1301of 1904
# Calculating image no 1302of 1904
# Calculating image no 1303of 1904
# Calculating image no 1304of 1904
# Calculating image no 1305of 1904
# Calculating image no 1306of 1904
# Calculating image no 1307of 1904
# Calculating image no 1308of 1904
# Calculating image no 1309of 1904
# Calculating image no 1310of 1904
# Calculating image no 1311of 1904
# Calculating image no 1312of 1904
# Calculating image no 1313of 1904
# Calculating image no 1314of 1904
# Calculating image no 1315of 1904
# Calculating image no 1316of 1904
# Calculating image no 1317of 1904
# Calculating image no 1318of 1904
# Calculating image no 1319of 1904
# Calculating image no 1320of 1904
# Calculating image no 1321of 1904
# Calculating image no 1322of 1904
# Calculating image no 1323of 1904
# Calculating image no 1324of 1904
# Calculating image no 1325of 1904
# Calculating image no 1326of 1904
# Calculating image no 1327of 1904
# Calculating image no 1328of 1904
# Calculating image no 1329of 1904
# Calculating image no 1330of 1904
# Calculating image no 1331of 1904
# Calculating image no 1332of 1904
# Calculating image no 1333of 1904
# Calculating image no 1334of 1904
# Calculating image no 1335of 1904
# Calculating image no 1336of 1904
# Calculating image no 1337of 1904
# Calculating image no 1338of 1904
# Calculating image no 1339of 1904
# Calculating image no 1340of 1904
# Calculating image no 1341of 1904
# Calculating image no 1342of 1904
# Calculating image no 1343of 1904
# Calculating image no 1344of 1904
# Calculating image no 1345of 1904
# Calculating image no 1346of 1904
# Calculating image no 1347of 1904
# Calculating image no 1348of 1904
# Calculating image no 1349of 1904
# Calculating image no 1350of 1904
# Calculating image no 1351of 1904
# Calculating image no 1352of 1904
# Calculating image no 1353of 1904
# Calculating image no 1354of 1904
# Calculating image no 1355of 1904
# Calculating image no 1356of 1904
# Calculating image no 1357of 1904
# Calculating image no 1358of 1904
# Calculating image no 1359of 1904
# Calculating image no 1360of 1904
# Calculating image no 1361of 1904
# Calculating image no 1362of 1904
# Calculating image no 1363of 1904
# Calculating image no 1364of 1904
# Calculating image no 1365of 1904
# Calculating image no 1366of 1904
# Calculating image no 1367of 1904
# Calculating image no 1368of 1904
# Calculating image no 1369of 1904
# Calculating image no 1370of 1904
# Calculating image no 1371of 1904
# Calculating image no 1372of 1904
# Calculating image no 1373of 1904
# Calculating image no 1374of 1904
# Calculating image no 1375of 1904
# Calculating image no 1376of 1904
# Calculating image no 1377of 1904
# Calculating image no 1378of 1904
# Calculating image no 1379of 1904
# Calculating image no 1380of 1904
# Calculating image no 1381of 1904
# Calculating image no 1382of 1904
# Calculating image no 1383of 1904
# Calculating image no 1384of 1904
# Calculating image no 1385of 1904
# Calculating image no 1386of 1904
# Calculating image no 1387of 1904
# Calculating image no 1388of 1904
# Calculating image no 1389of 1904
# Calculating image no 1390of 1904
# Calculating image no 1391of 1904
# Calculating image no 1392of 1904
# Calculating image no 1393of 1904
# Calculating image no 1394of 1904
# Calculating image no 1395of 1904
# Calculating image no 1396of 1904
# Calculating image no 1397of 1904
# Calculating image no 1398of 1904
# Calculating image no 1399of 1904
# Calculating image no 1400of 1904
# Calculating image no 1401of 1904
# Calculating image no 1402of 1904
# Calculating image no 1403of 1904
# Calculating image no 1404of 1904
# Calculating image no 1405of 1904
# Calculating image no 1406of 1904
# Calculating image no 1407of 1904
# Calculating image no 1408of 1904
# Calculating image no 1409of 1904
# Calculating image no 1410of 1904
# Calculating image no 1411of 1904
# Calculating image no 1412of 1904
# Calculating image no 1413of 1904
# Calculating image no 1414of 1904
# Calculating image no 1415of 1904
# Calculating image no 1416of 1904
# Calculating image no 1417of 1904
# Calculating image no 1418of 1904
# Calculating image no 1419of 1904
# Calculating image no 1420of 1904
# Calculating image no 1421of 1904
# Calculating image no 1422of 1904
# Calculating image no 1423of 1904
# Calculating image no 1424of 1904
# Calculating image no 1425of 1904
# Calculating image no 1426of 1904
# Calculating image no 1427of 1904
# Calculating image no 1428of 1904
# Calculating image no 1429of 1904
# Calculating image no 1430of 1904
# Calculating image no 1431of 1904
# Calculating image no 1432of 1904
# Calculating image no 1433of 1904
# Calculating image no 1434of 1904
# Calculating image no 1435of 1904
# Calculating image no 1436of 1904
# Calculating image no 1437of 1904
# Calculating image no 1438of 1904
# Calculating image no 1439of 1904
# Calculating image no 1440of 1904
# Calculating image no 1441of 1904
# Calculating image no 1442of 1904
# Calculating image no 1443of 1904
# Calculating image no 1444of 1904
# Calculating image no 1445of 1904
# Calculating image no 1446of 1904
# Calculating image no 1447of 1904
# Calculating image no 1448of 1904
# Calculating image no 1449of 1904
# Calculating image no 1450of 1904
# Calculating image no 1451of 1904
# Calculating image no 1452of 1904
# Calculating image no 1453of 1904
# Calculating image no 1454of 1904
# Calculating image no 1455of 1904
# Calculating image no 1456of 1904
# Calculating image no 1457of 1904
# Calculating image no 1458of 1904
# Calculating image no 1459of 1904
# Calculating image no 1460of 1904
# Calculating image no 1461of 1904
# Calculating image no 1462of 1904
# Calculating image no 1463of 1904
# Calculating image no 1464of 1904
# Calculating image no 1465of 1904
# Calculating image no 1466of 1904
# Calculating image no 1467of 1904
# Calculating image no 1468of 1904
# Calculating image no 1469of 1904
# Calculating image no 1470of 1904
# Calculating image no 1471of 1904
# Calculating image no 1472of 1904
# Calculating image no 1473of 1904
# Calculating image no 1474of 1904
# Calculating image no 1475of 1904
# Calculating image no 1476of 1904
# Calculating image no 1477of 1904
# Calculating image no 1478of 1904
# Calculating image no 1479of 1904
# Calculating image no 1480of 1904
# Calculating image no 1481of 1904
# Calculating image no 1482of 1904
# Calculating image no 1483of 1904
# Calculating image no 1484of 1904
# Calculating image no 1485of 1904
# Calculating image no 1486of 1904
# Calculating image no 1487of 1904
# Calculating image no 1488of 1904
# Calculating image no 1489of 1904
# Calculating image no 1490of 1904
# Calculating image no 1491of 1904
# Calculating image no 1492of 1904
# Calculating image no 1493of 1904
# Calculating image no 1494of 1904
# Calculating image no 1495of 1904
# Calculating image no 1496of 1904
# Calculating image no 1497of 1904
# Calculating image no 1498of 1904
# Calculating image no 1499of 1904
# Calculating image no 1500of 1904
# Calculating image no 1501of 1904
# Calculating image no 1502of 1904
# Calculating image no 1503of 1904
# Calculating image no 1504of 1904
# Calculating image no 1505of 1904
# Calculating image no 1506of 1904
# Calculating image no 1507of 1904
# Calculating image no 1508of 1904
# Calculating image no 1509of 1904
# Calculating image no 1510of 1904
# Calculating image no 1511of 1904
# Calculating image no 1512of 1904
# Calculating image no 1513of 1904
# Calculating image no 1514of 1904
# Calculating image no 1515of 1904
# Calculating image no 1516of 1904
# Calculating image no 1517of 1904
# Calculating image no 1518of 1904
# Calculating image no 1519of 1904
# Calculating image no 1520of 1904
# Calculating image no 1521of 1904
# Calculating image no 1522of 1904
# Calculating image no 1523of 1904
# Calculating image no 1524of 1904
# Calculating image no 1525of 1904
# Calculating image no 1526of 1904
# Calculating image no 1527of 1904
# Calculating image no 1528of 1904
# Calculating image no 1529of 1904
# Calculating image no 1530of 1904
# Calculating image no 1531of 1904
# Calculating image no 1532of 1904
# Calculating image no 1533of 1904
# Calculating image no 1534of 1904
# Calculating image no 1535of 1904
# Calculating image no 1536of 1904
# Calculating image no 1537of 1904
# Calculating image no 1538of 1904
# Calculating image no 1539of 1904
# Calculating image no 1540of 1904
# Calculating image no 1541of 1904
# Calculating image no 1542of 1904
# Calculating image no 1543of 1904
# Calculating image no 1544of 1904
# Calculating image no 1545of 1904
# Calculating image no 1546of 1904
# Calculating image no 1547of 1904
# Calculating image no 1548of 1904
# Calculating image no 1549of 1904
# Calculating image no 1550of 1904
# Calculating image no 1551of 1904
# Calculating image no 1552of 1904
# Calculating image no 1553of 1904
# Calculating image no 1554of 1904
# Calculating image no 1555of 1904
# Calculating image no 1556of 1904
# Calculating image no 1557of 1904
# Calculating image no 1558of 1904
# Calculating image no 1559of 1904
# Calculating image no 1560of 1904
# Calculating image no 1561of 1904
# Calculating image no 1562of 1904
# Calculating image no 1563of 1904
# Calculating image no 1564of 1904
# Calculating image no 1565of 1904
# Calculating image no 1566of 1904
# Calculating image no 1567of 1904
# Calculating image no 1568of 1904
# Calculating image no 1569of 1904
# Calculating image no 1570of 1904
# Calculating image no 1571of 1904
# Calculating image no 1572of 1904
# Calculating image no 1573of 1904
# Calculating image no 1574of 1904
# Calculating image no 1575of 1904
# Calculating image no 1576of 1904
# Calculating image no 1577of 1904
# Calculating image no 1578of 1904
# Calculating image no 1579of 1904
# Calculating image no 1580of 1904
# Calculating image no 1581of 1904
# Calculating image no 1582of 1904
# Calculating image no 1583of 1904
# Calculating image no 1584of 1904
# Calculating image no 1585of 1904
# Calculating image no 1586of 1904
# Calculating image no 1587of 1904
# Calculating image no 1588of 1904
# Calculating image no 1589of 1904
# Calculating image no 1590of 1904
# Calculating image no 1591of 1904
# Calculating image no 1592of 1904
# Calculating image no 1593of 1904
# Calculating image no 1594of 1904
# Calculating image no 1595of 1904
# Calculating image no 1596of 1904
# Calculating image no 1597of 1904
# Calculating image no 1598of 1904
# Calculating image no 1599of 1904
# Calculating image no 1600of 1904
# Calculating image no 1601of 1904
# Calculating image no 1602of 1904
# Calculating image no 1603of 1904
# Calculating image no 1604of 1904
# Calculating image no 1605of 1904
# Calculating image no 1606of 1904
# Calculating image no 1607of 1904
# Calculating image no 1608of 1904
# Calculating image no 1609of 1904
# Calculating image no 1610of 1904
# Calculating image no 1611of 1904
# Calculating image no 1612of 1904
# Calculating image no 1613of 1904
# Calculating image no 1614of 1904
# Calculating image no 1615of 1904
# Calculating image no 1616of 1904
# Calculating image no 1617of 1904
# Calculating image no 1618of 1904
# Calculating image no 1619of 1904
# Calculating image no 1620of 1904
# Calculating image no 1621of 1904
# Calculating image no 1622of 1904
# Calculating image no 1623of 1904
# Calculating image no 1624of 1904
# Calculating image no 1625of 1904
# Calculating image no 1626of 1904
# Calculating image no 1627of 1904
# Calculating image no 1628of 1904
# Calculating image no 1629of 1904
# Calculating image no 1630of 1904
# Calculating image no 1631of 1904
# Calculating image no 1632of 1904
# Calculating image no 1633of 1904
# Calculating image no 1634of 1904
# Calculating image no 1635of 1904
# Calculating image no 1636of 1904
# Calculating image no 1637of 1904
# Calculating image no 1638of 1904
# Calculating image no 1639of 1904
# Calculating image no 1640of 1904
# Calculating image no 1641of 1904
# Calculating image no 1642of 1904
# Calculating image no 1643of 1904
# Calculating image no 1644of 1904
# Calculating image no 1645of 1904
# Calculating image no 1646of 1904
# Calculating image no 1647of 1904
# Calculating image no 1648of 1904
# Calculating image no 1649of 1904
# Calculating image no 1650of 1904
# Calculating image no 1651of 1904
# Calculating image no 1652of 1904
# Calculating image no 1653of 1904
# Calculating image no 1654of 1904
# Calculating image no 1655of 1904
# Calculating image no 1656of 1904
# Calculating image no 1657of 1904
# Calculating image no 1658of 1904
# Calculating image no 1659of 1904
# Calculating image no 1660of 1904
# Calculating image no 1661of 1904
# Calculating image no 1662of 1904
# Calculating image no 1663of 1904
# Calculating image no 1664of 1904
# Calculating image no 1665of 1904
# Calculating image no 1666of 1904
# Calculating image no 1667of 1904
# Calculating image no 1668of 1904
# Calculating image no 1669of 1904
# Calculating image no 1670of 1904
# Calculating image no 1671of 1904
# Calculating image no 1672of 1904
# Calculating image no 1673of 1904
# Calculating image no 1674of 1904
# Calculating image no 1675of 1904
# Calculating image no 1676of 1904
# Calculating image no 1677of 1904
# Calculating image no 1678of 1904
# Calculating image no 1679of 1904
# Calculating image no 1680of 1904
# Calculating image no 1681of 1904
# Calculating image no 1682of 1904
# Calculating image no 1683of 1904
# Calculating image no 1684of 1904
# Calculating image no 1685of 1904
# Calculating image no 1686of 1904
# Calculating image no 1687of 1904
# Calculating image no 1688of 1904
# Calculating image no 1689of 1904
# Calculating image no 1690of 1904
# Calculating image no 1691of 1904
# Calculating image no 1692of 1904
# Calculating image no 1693of 1904
# Calculating image no 1694of 1904
# Calculating image no 1695of 1904
# Calculating image no 1696of 1904
# Calculating image no 1697of 1904
# Calculating image no 1698of 1904
# Calculating image no 1699of 1904
# Calculating image no 1700of 1904
# Calculating image no 1701of 1904
# Calculating image no 1702of 1904
# Calculating image no 1703of 1904
# Calculating image no 1704of 1904
# Calculating image no 1705of 1904
# Calculating image no 1706of 1904
# Calculating image no 1707of 1904
# Calculating image no 1708of 1904
# Calculating image no 1709of 1904
# Calculating image no 1710of 1904
# Calculating image no 1711of 1904
# Calculating image no 1712of 1904
# Calculating image no 1713of 1904
# Calculating image no 1714of 1904
# Calculating image no 1715of 1904
# Calculating image no 1716of 1904
# Calculating image no 1717of 1904
# Calculating image no 1718of 1904
# Calculating image no 1719of 1904
# Calculating image no 1720of 1904
# Calculating image no 1721of 1904
# Calculating image no 1722of 1904
# Calculating image no 1723of 1904
# Calculating image no 1724of 1904
# Calculating image no 1725of 1904
# Calculating image no 1726of 1904
# Calculating image no 1727of 1904
# Calculating image no 1728of 1904
# Calculating image no 1729of 1904
# Calculating image no 1730of 1904
# Calculating image no 1731of 1904
# Calculating image no 1732of 1904
# Calculating image no 1733of 1904
# Calculating image no 1734of 1904
# Calculating image no 1735of 1904
# Calculating image no 1736of 1904
# Calculating image no 1737of 1904
# Calculating image no 1738of 1904
# Calculating image no 1739of 1904
# Calculating image no 1740of 1904
# Calculating image no 1741of 1904
# Calculating image no 1742of 1904
# Calculating image no 1743of 1904
# Calculating image no 1744of 1904
# Calculating image no 1745of 1904
# Calculating image no 1746of 1904
# Calculating image no 1747of 1904
# Calculating image no 1748of 1904
# Calculating image no 1749of 1904
# Calculating image no 1750of 1904
# Calculating image no 1751of 1904
# Calculating image no 1752of 1904
# Calculating image no 1753of 1904
# Calculating image no 1754of 1904
# Calculating image no 1755of 1904
# Calculating image no 1756of 1904
# Calculating image no 1757of 1904
# Calculating image no 1758of 1904
# Calculating image no 1759of 1904
# Calculating image no 1760of 1904
# Calculating image no 1761of 1904
# Calculating image no 1762of 1904
# Calculating image no 1763of 1904
# Calculating image no 1764of 1904
# Calculating image no 1765of 1904
# Calculating image no 1766of 1904
# Calculating image no 1767of 1904
# Calculating image no 1768of 1904
# Calculating image no 1769of 1904
# Calculating image no 1770of 1904
# Calculating image no 1771of 1904
# Calculating image no 1772of 1904
# Calculating image no 1773of 1904
# Calculating image no 1774of 1904
# Calculating image no 1775of 1904
# Calculating image no 1776of 1904
# Calculating image no 1777of 1904
# Calculating image no 1778of 1904
# Calculating image no 1779of 1904
# Calculating image no 1780of 1904
# Calculating image no 1781of 1904
# Calculating image no 1782of 1904
# Calculating image no 1783of 1904
# Calculating image no 1784of 1904
# Calculating image no 1785of 1904
# Calculating image no 1786of 1904
# Calculating image no 1787of 1904
# Calculating image no 1788of 1904
# Calculating image no 1789of 1904
# Calculating image no 1790of 1904
# Calculating image no 1791of 1904
# Calculating image no 1792of 1904
# Calculating image no 1793of 1904
# Calculating image no 1794of 1904
# Calculating image no 1795of 1904
# Calculating image no 1796of 1904
# Calculating image no 1797of 1904
# Calculating image no 1798of 1904
# Calculating image no 1799of 1904
# Calculating image no 1800of 1904
# Calculating image no 1801of 1904
# Calculating image no 1802of 1904
# Calculating image no 1803of 1904
# Calculating image no 1804of 1904
# Calculating image no 1805of 1904
# Calculating image no 1806of 1904
# Calculating image no 1807of 1904
# Calculating image no 1808of 1904
# Calculating image no 1809of 1904
# Calculating image no 1810of 1904
# Calculating image no 1811of 1904
# Calculating image no 1812of 1904
# Calculating image no 1813of 1904
# Calculating image no 1814of 1904
# Calculating image no 1815of 1904
# Calculating image no 1816of 1904
# Calculating image no 1817of 1904
# Calculating image no 1818of 1904
# Calculating image no 1819of 1904
# Calculating image no 1820of 1904
# Calculating image no 1821of 1904
# Calculating image no 1822of 1904
# Calculating image no 1823of 1904
# Calculating image no 1824of 1904
# Calculating image no 1825of 1904
# Calculating image no 1826of 1904
# Calculating image no 1827of 1904
# Calculating image no 1828of 1904
# Calculating image no 1829of 1904
# Calculating image no 1830of 1904
# Calculating image no 1831of 1904
# Calculating image no 1832of 1904
# Calculating image no 1833of 1904
# Calculating image no 1834of 1904
# Calculating image no 1835of 1904
# Calculating image no 1836of 1904
# Calculating image no 1837of 1904
# Calculating image no 1838of 1904
# Calculating image no 1839of 1904
# Calculating image no 1840of 1904
# Calculating image no 1841of 1904
# Calculating image no 1842of 1904
# Calculating image no 1843of 1904
# Calculating image no 1844of 1904
# Calculating image no 1845of 1904
# Calculating image no 1846of 1904
# Calculating image no 1847of 1904
# Calculating image no 1848of 1904
# Calculating image no 1849of 1904
# Calculating image no 1850of 1904
# Calculating image no 1851of 1904
# Calculating image no 1852of 1904
# Calculating image no 1853of 1904
# Calculating image no 1854of 1904
# Calculating image no 1855of 1904
# Calculating image no 1856of 1904
# Calculating image no 1857of 1904
# Calculating image no 1858of 1904
# Calculating image no 1859of 1904
# Calculating image no 1860of 1904
# Calculating image no 1861of 1904
# Calculating image no 1862of 1904
# Calculating image no 1863of 1904
# Calculating image no 1864of 1904
# Calculating image no 1865of 1904
# Calculating image no 1866of 1904
# Calculating image no 1867of 1904
# Calculating image no 1868of 1904
# Calculating image no 1869of 1904
# Calculating image no 1870of 1904
# Calculating image no 1871of 1904
# Calculating image no 1872of 1904
# Calculating image no 1873of 1904
# Calculating image no 1874of 1904
# Calculating image no 1875of 1904
# Calculating image no 1876of 1904
# Calculating image no 1877of 1904
# Calculating image no 1878of 1904
# Calculating image no 1879of 1904
# Calculating image no 1880of 1904
# Calculating image no 1881of 1904
# Calculating image no 1882of 1904
# Calculating image no 1883of 1904
# Calculating image no 1884of 1904
# Calculating image no 1885of 1904
# Calculating image no 1886of 1904
# Calculating image no 1887of 1904
# Calculating image no 1888of 1904
# Calculating image no 1889of 1904
# Calculating image no 1890of 1904
# Calculating image no 1891of 1904
# Calculating image no 1892of 1904
# Calculating image no 1893of 1904
# Calculating image no 1894of 1904
# Calculating image no 1895of 1904
# Calculating image no 1896of 1904
# Calculating image no 1897of 1904
# Calculating image no 1898of 1904
# Calculating image no 1899of 1904
# Calculating image no 1900of 1904
# Calculating image no 1901of 1904
# Calculating image no 1902of 1904
# Calculating image no 1903of 1904
# Calculating image no 1904of 1904
# 0

# %% [markdown]
# ### Make folder for results and save segmentation

# %%
os.mkdir(expdir+'results/')

# %%
len(results["filename"])
# Out:
# 1904

# %%
from copy import deepcopy
resultsbackup2=deepcopy(results)

# %%
results=np.load('/Users/taldankovich/Downloads/myresults.npy')

# %%
results=deepcopy(resultsbackup2)

# %%
len(results["Early Image - Raw ean intensity"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-55f9d7048e53> in <module>()
# ----> 1 len(results["Early Image - Raw ean intensity"])
#
# KeyError: 'Early Image - Raw ean intensity'

# %%
#save segmentation results
np.save(expdir+'/results/EarlySpots.npy',results["Early colour - spots mask"])
np.save(expdir+'/results/LateSpots.npy',results["Late colour - spots mask"])
np.save(expdir+'/results/SynapseSpots.npy',results["Synapse colour - spots mask"])
np.save(expdir+'/results/EarlyPlusLateSpots.npy',results["Late plus early colour - spots mask"])

# %%
#load segmentation results
EarlySpots=np.load(expdir+'/results/EarlySpots.npy')
LateSpots=np.load(expdir+'/results/LateSpots.npy')
SynapseSpots=np.load(expdir+'/results/SynapseSpots.npy')
EarlyPlusLateSpots=np.load(expdir+'/results/EarlyPlusLateSpots.npy')
results["Early colour - spots mask"]=EarlySpots
results["Late colour - spots mask"]=LateSpots
results["Synapse colour - spots mask"]=SynapseSpots
results["Late plus early colour - spots mask"]=EarlyPlusLateSpots

# %%
results["filename"]

# %% [markdown]
# ### Batch analyse images, after creating the segmentation masks

# %%
print('Total number of images: ' + str(len(results['filename'])))

#for i in range(0,len(results["filename"])): 
for i in range(1289,len(results["filename"])):
    print('Calculating image no ' + str(i+1) + ' out of' + str(len(results["filename"])))
    early_channel_no=results["earlychannelno"][i]
    late_channel_no=results["latechannelno"][i]
    synapse_channel_no=results["synapsechannelno"][i]
    if synapse_channel_no>0:
        synapse_flag=True
        print('has synapse values')
    else:
        synapse_flag=False
    with ND2Reader(results["filename"][i]) as images:
        #read the images
        early_image=images[early_channel_no-1]
        late_image=images[late_channel_no-1]
        if synapse_flag:
            synapse_image=images[synapse_channel_no-1]
    #convert to array
    early_image=early_image.astype(np.int16)
    late_image=late_image.astype(np.int16)
    if synapse_flag:
        synapse_image=synapse_image.astype(np.int16)
    #preserve the raw images
    early_image_raw = deepcopy(early_image)
    late_image_raw=deepcopy(late_image)
    if synapse_flag:
        synapse_image_raw=deepcopy(synapse_image)
    spots_late_minus_early_int_raw=early_image_raw+late_image_raw
    #normalize intensity to value between 0 and 1
    early_image=np.divide(early_image,16383.)
    late_image=np.divide(late_image,16383.)
    if synapse_flag:
        synapse_image=np.divide(synapse_image,16383.)
    #make normalized image;divide each pixel by max in the channel in that image
    early_image_norm=deepcopy(early_image)
    early_image_norm=early_image_norm-np.mean(early_image_norm)
    late_image_norm=deepcopy(late_image)
    late_image_norm=late_image_norm-np.mean(late_image_norm)
    if synapse_flag:
        synapse_image_norm=deepcopy(synapse_image)
        synapse_image_norm=synapse_image_norm-np.mean(synapse_image_norm)
    #small detour to calculate the mean fluorescence of controls - early or late colour alone
    #1- earlycolour
    ctrlearlys={"filename":[]}
    ctrlearly=results["Earlycontroldir"][i]
    pathearly = os.path.dirname(ctrlearly+"/")
    filelistearly = []
    for root, _, filenames in os.walk(pathearly):
         for filename in filenames:
             filelistearly.append(os.path.join(root, filename))
    for l in range(0,len(filelistearly)):
        if filelistearly[l].endswith(".nd2"): 
            ctrlearlys["filename"].append(filelistearly[l])
    earlycolour_ctrls=np.zeros((len(ctrlearlys["filename"]),1))
    for im in range(0,len(ctrlearlys["filename"])):
        with ND2Reader(ctrlearlys["filename"][im]) as images:
            early_image_ctrl=images[early_channel_no-1]
        #convert to array
        early_image_ctrl=early_image_ctrl.astype(np.int16)
        #normalize intensity to value between 0 and 1
        early_image_ctrl=np.divide(early_image_ctrl,16383.)
        #append mean intensity
        earlycolour_ctrls[im]=np.mean(early_image_ctrl)
    #2- latecolour
    ctrllates={"filename":[]}
    ctrllate=results["Latecontroldir"][i]
    pathlate = os.path.dirname(ctrllate+"/")
    filelistlate = []
    for root, _, filenames in os.walk(pathlate):
         for filename in filenames:
             filelistlate.append(os.path.join(root, filename))
    for l in range(0,len(filelistlate)):
        if filelistlate[l].endswith(".nd2"): 
            ctrllates["filename"].append(filelistearly[l])
    latecolour_ctrls=np.zeros((len(ctrllates["filename"]),1))
    for im in range(0,len(ctrllates["filename"])):
        with ND2Reader(ctrllates["filename"][im]) as images:
            late_image_ctrl=images[late_channel_no-1]
        #convert to array
        late_image_ctrl=late_image_ctrl.astype(np.int16)
        #normalize intensity to value between 0 and 1
        late_image_ctrl=np.divide(late_image_ctrl,16383.)
        #append mean intensity
        latecolour_ctrls[im]=np.mean(late_image_ctrl)
    #average the vectors
    early_ctrl_mean=np.mean(earlycolour_ctrls)
    late_ctrl_mean=np.mean(latecolour_ctrls)
    #make image normalized to the control
    early_image_normtoctrl=deepcopy(early_image)
    early_image_normtoctrl=np.divide(early_image_normtoctrl,early_ctrl_mean)
    late_image_normtoctrl=deepcopy(late_image)
    late_image_normtoctrl=np.divide(late_image_normtoctrl,late_ctrl_mean)
    #small detour to calculate the autofluorescence
    autof={"filename":[]}
    autofpath=results["Autofluorescencedir"][i]
    if autofpath==0:
        early_autoint_mean=0
        late_autoint_mean=0
        if synapse_flag:
            synapse_autoint_mean=0
    else:
        pathy = os.path.dirname(autofpath+"/")  
        autoffilelist = []
        for root, _, filenames in os.walk(pathy):
             for filename in filenames:
                 autoffilelist.append(os.path.join(root, filename))
        for l in range(0,len(autoffilelist)):
            if autoffilelist[l].endswith(".nd2"): 
                autof["filename"].append(autoffilelist[l])
        earlycolour_autoint=np.zeros((len(autof["filename"]),1))
        latecolour_autoint=np.zeros((len(autof["filename"]),1))
        if synapse_flag:
            synapsecolour_autoint=np.zeros((len(autof["filename"]),1))
        for im in range(0,len(autof["filename"])):
            with ND2Reader(autof["filename"][im]) as images:
                early_image_auto=images[early_channel_no-1]
                late_image_auto=images[late_channel_no-1]
                if synapse_flag:
                    synapse_image_auto=images[synapse_channel_no-1]
            #convert to array
            early_image_auto=early_image_auto.astype(np.int16)
            late_image_auto=late_image_auto.astype(np.int16)
            if synapse_flag:
                synapse_image_auto=synapse_image_auto.astype(np.int16)
            #normalize intensity to value between 0 and 1
            early_image_auto=np.divide(early_image_auto,16383.)
            late_image_auto=np.divide(late_image_auto,16383.)
            if synapse_flag:
                synapse_image_auto=np.divide(synapse_image_auto,16383.)
            #append mean intensity
            earlycolour_autoint[im]=np.mean(early_image_auto)
            latecolour_autoint[im]=np.mean(late_image_auto)  
            if synapse_flag:
                synapsecolour_autoint[im]=np.mean(synapse_image_auto)
        #average the vectors
        early_autoint_mean=np.mean(earlycolour_autoint)
        late_autoint_mean=np.mean(latecolour_autoint)
        if synapse_flag:
            synapse_autoint_mean=np.mean(synapsecolour_autoint)   
    #make image histograms before subtracting autofluorescence
    early_hist,_ = np.histogram(early_image,bins=np.linspace(0.,1.,50))
    late_hist,_ = np.histogram(late_image,bins=np.linspace(0.,1.,50))
    if synapse_flag:
        synapse_hist,_ = np.histogram(synapse_image,bins=np.linspace(0.,1.,50))
    early_hist_norm,_ = np.histogram(early_image_norm,bins=np.linspace(0.,1.,50))
    late_hist_norm,_ = np.histogram(late_image_norm,bins=np.linspace(0.,1.,50))
    if synapse_flag:
        synapse_hist_norm,_ = np.histogram(synapse_image_norm,bins=np.linspace(0.,1.,50))
    #subtract autofluorescence in each channel; subtract the normalized pixel value times the max autofluorescence int
    early_image=np.subtract(early_image,early_autoint_mean)
    early_image[early_image<0]=0
    late_image=np.subtract(late_image,late_autoint_mean)
    late_image[late_image<0]=0
    if synapse_flag:
        synapse_image=np.subtract(synapse_image,synapse_autoint_mean)
        synapse_image[synapse_image<0]=0
    early_image_norm_minusauto=np.subtract(early_image_norm,early_autoint_mean) 
    early_image_norm_minusauto[early_image_norm_minusauto<0]=0
    late_image_norm_minusauto=np.subtract(late_image_norm,late_autoint_mean)
    late_image_norm_minusauto[late_image_norm_minusauto<0]=0
    if synapse_flag:
        synapse_image_norm_minusauto=np.subtract(synapse_image_norm,synapse_autoint_mean)
        synapse_image_norm_minusauto[synapse_image_norm_minusauto<0]=0            
    #read spots masks
    early_spots=results["Early colour - spots mask"][i]
    late_spots=results["Late colour - spots mask"][i]
    lateplusearly_spots=results["Late plus early colour - spots mask"][i]
    if synapse_flag:
        synapse_spots=results["Synapse colour - spots mask"][i]
    #label the spots
    spots_early_labels,_ = ndi.label(early_spots)
    spots_late_labels,_ = ndi.label(late_spots)
    spots_earlypluslate_labels,_ = ndi.label(lateplusearly_spots)
    if synapse_flag:
        spots_synapse_labels,_ = ndi.label(synapse_spots)

    #calculate results
    #make empty vectors                                   
    early_spots_intensities=np.zeros((len(np.unique(spots_early_labels)),1))
    early_spots_intensities_normtoctrl=np.zeros((len(np.unique(spots_early_labels)),1))
    early_spots_areas=np.zeros((len(np.unique(spots_early_labels)),1))
    late_spots_intensities=np.zeros((len(np.unique(spots_late_labels)),1))
    late_spots_intensities_normtoctrl=np.zeros((len(np.unique(spots_late_labels)),1))
    late_spots_areas=np.zeros((len(np.unique(spots_late_labels)),1))
    spots_late_minus_early_int=np.zeros((len(np.unique(spots_early_labels)),1))
    spots_late_minus_early_int_norm=np.zeros((len(np.unique(spots_early_labels)),1))
    spots_late_minus_early_int_raw=np.zeros((len(np.unique(spots_early_labels)),1))
    spots_late_minus_early_int_norm_minusauto=np.zeros((len(np.unique(spots_early_labels)),1))
    spots_late_minus_early_int_normtoctrl=np.zeros((len(np.unique(spots_early_labels)),1))
    spots_bias_image_hists=np.zeros((len(np.unique(spots_early_labels)),49))
    spots_bias_image_hists_raw=np.zeros((len(np.unique(spots_early_labels)),49))
    spots_bias_image_hists_norm=np.zeros((len(np.unique(spots_early_labels)),49))
    spots_bias_image_hists_norm_minusauto=np.zeros((len(np.unique(spots_early_labels)),49))
    spots_bias_image_hists_normtoctrl=np.zeros((len(np.unique(spots_early_labels)),49))
    if synapse_flag:
        synapse_spots_intensities=np.zeros((len(np.unique(spots_synapse_labels)),1))
        synapse_spots_areas=np.zeros((len(np.unique(spots_synapse_labels)),1))
        early_atsynapses_intensities=np.zeros((len(np.unique(spots_synapse_labels)),1))   
        late_atsynapses_intensities=np.zeros((len(np.unique(spots_synapse_labels)),1)) 
        early_atsynapses_intensities_normtoctrl=np.zeros((len(np.unique(spots_synapse_labels)),1))   
        late_atsynapses_intensities_normtoctrl=np.zeros((len(np.unique(spots_synapse_labels)),1)) 
        spots_late_minus_early_atsynapses_int=np.zeros((len(np.unique(spots_synapse_labels)),1))
        spots_late_minus_early_int_raw_syn=np.zeros((len(np.unique(spots_synapse_labels)),1))
        spots_late_minus_early_int_norm_minusauto_syn=np.zeros((len(np.unique(spots_synapse_labels)),1))
        spots_late_minus_early_int_norm_syn=np.zeros((len(np.unique(spots_synapse_labels)),1))
        spots_late_minus_early_int_syn=np.zeros((len(np.unique(spots_synapse_labels)),1))
        spots_late_minus_early_int_normtoctrl_syn=np.zeros((len(np.unique(spots_synapse_labels)),1))
        spots_bias_image_hists_syn=np.zeros((len(np.unique(spots_synapse_labels)),49))
        spots_bias_image_hists_raw_syn=np.zeros((len(np.unique(spots_synapse_labels)),49))
        spots_bias_image_hists_norm_syn=np.zeros((len(np.unique(spots_synapse_labels)),49))  
        spots_bias_image_hists_norm_minusauto_syn=np.zeros((len(np.unique(spots_synapse_labels)),49))  
        spots_bias_image_hists_normtoctrl_syn=np.zeros((len(np.unique(spots_synapse_labels)),49))     
    #loop over early spots
    print('no early spots = ' +str(len(np.unique(spots_early_labels))))
    for spotno in np.unique(spots_early_labels)[1:]:
        early_spots_mask = spots_early_labels==spotno
        early_spots_intensities[spotno]=np.nanmean(early_image[early_spots_mask])
        early_spots_intensities_normtoctrl[spotno]=np.nanmean(early_image_normtoctrl[early_spots_mask])
        early_spots_areas[spotno]=np.sum(early_spots_mask)
        #bias image calculation for fluorescence subtracted
        a=late_image[early_spots_mask]
        b=early_image[early_spots_mask]
        spots_bias_image=np.divide([a-b],[a+b])                               
        spots_late_minus_early_int[spotno]=np.nanmean(spots_bias_image)
        spots_bias_image_hist,_= np.histogram([spots_bias_image[~np.isnan(spots_bias_image)]],bins=np.linspace(-1.,1.,50))
        spots_bias_image_hists[spotno]=spots_bias_image_hist                               
        #bias image calculation for raw images
        a=late_image_raw[early_spots_mask]
        b=early_image_raw[early_spots_mask]
        spots_bias_image_raw=np.divide([a-b],[a+b])                               
        spots_late_minus_early_int_raw[spotno]=np.nanmean(spots_bias_image_raw)
        spots_bias_image_hist_raw,_= np.histogram([spots_bias_image_raw[~np.isnan(spots_bias_image_raw)]],bins=np.linspace(-1.,1.,50)) 
        spots_bias_image_hists_raw[spotno]=spots_bias_image_hist_raw    
        #bias image calculation for normalized images
        a=late_image_norm[early_spots_mask]
        b=early_image_norm[early_spots_mask]
        spots_bias_image_norm=np.divide([a-b],[a+b])                               
        spots_late_minus_early_int_norm[spotno]=np.nanmean(spots_bias_image_norm)
        spots_bias_image_hist_norm,_= np.histogram([spots_bias_image_norm[~np.isnan(spots_bias_image_norm)]],bins=np.linspace(-1.,1.,50))
        spots_bias_image_hists_norm[spotno]=spots_bias_image_hist_norm
        #biased images for norm minus autofluorescence 
        a=late_image_norm_minusauto[early_spots_mask]
        b=early_image_norm_minusauto[early_spots_mask]
        spots_bias_image_norm_minusauto=np.divide([a-b],[a+b])                               
        spots_late_minus_early_int_norm_minusauto[spotno]=np.nanmean(spots_bias_image_norm_minusauto)
        spots_bias_image_hist_norm_minusauto,_= np.histogram([spots_bias_image_norm_minusauto[~np.isnan(spots_bias_image_norm_minusauto)]],bins=np.linspace(-1.,1.,50)) 
        spots_bias_image_hists_norm_minusauto[spotno]=spots_bias_image_hist_norm_minusauto 
        #biased images for norm to ctrl 
        a=late_image_normtoctrl[early_spots_mask]
        b=early_image_normtoctrl[early_spots_mask]
        spots_bias_image_normtoctrl=np.divide([a-b],[a+b])                               
        spots_late_minus_early_int_normtoctrl[spotno]=np.nanmean(spots_bias_image_normtoctrl)
        spots_bias_image_hist_normtoctrl,_= np.histogram([spots_bias_image_normtoctrl[~np.isnan(spots_bias_image_normtoctrl)]],bins=np.linspace(-1.,1.,50)) 
        spots_bias_image_hists_normtoctrl[spotno]=spots_bias_image_hist_normtoctrl
    #loop over late spots
    print('no late spots = ' +str(len(np.unique(spots_late_labels))))
    for spotnol in np.unique(spots_late_labels)[1:]:
        late_spots_mask= spots_late_labels==spotnol
        late_spots_intensities[spotnol]=np.nanmean(late_image[late_spots_mask])
        late_spots_intensities_normtoctrl[spotnol]=np.nanmean(late_image_normtoctrl[late_spots_mask])
        late_spots_areas[spotnol]=np.sum(late_spots_mask)
    #loop over synapse spots   
    if synapse_flag:
        print('no synapse spots = ' +str(len(np.unique(spots_synapse_labels))))
        for spotnos in np.unique(spots_synapse_labels)[1:]:
            synapse_spots_mask= spots_synapse_labels==spotnos
            synapse_spots_intensities[spotnos]=np.nanmean(synapse_image[synapse_spots_mask])
            synapse_spots_areas[spotnos]=np.sum(synapse_spots_mask)
            #intensities masked by synapses, calculation
            early_atsynapses_intensities[spotnos]=np.nanmean(early_image[synapse_spots_mask])
            late_atsynapses_intensities[spotnos]=np.nanmean(late_image[synapse_spots_mask])
            early_atsynapses_intensities_normtoctrl[spotnos]=np.nanmean(early_image_normtoctrl[synapse_spots_mask])
            late_atsynapses_intensities_normtoctrl[spotnos]=np.nanmean(late_image_normtoctrl[synapse_spots_mask])
            #calculate bias image at synapses
            #bias image calculation for fluorescence subtracted
            a=late_image[synapse_spots_mask]
            b=early_image[synapse_spots_mask]
            spots_bias_image=np.divide([a-b],[a+b])                               
            spots_late_minus_early_int_syn[spotnos]=np.nanmean(spots_bias_image)
            spots_bias_image_hist,_= np.histogram([spots_bias_image[~np.isnan(spots_bias_image)]],bins=np.linspace(-1.,1.,50)) 
            spots_bias_image_hists_syn[spotnos]=spots_bias_image_hist
            #bias image calculation for raw images
            a=late_image_raw[early_spots_mask]
            b=early_image_raw[early_spots_mask]
            spots_bias_image_raw=np.divide([a-b],[a+b])                               
            spots_late_minus_early_int_raw_syn[spotnos]=np.nanmean(spots_bias_image_raw)
            spots_bias_image_hist_raw,_= np.histogram([spots_bias_image_raw[~np.isnan(spots_bias_image_raw)]],bins=np.linspace(-1.,1.,50)) 
            spots_bias_image_hists_raw_syn[spotnos]=spots_bias_image_hist_raw
            #bias image calculation for normalized images
            a=late_image_norm[early_spots_mask]
            b=early_image_norm[early_spots_mask]
            spots_bias_image_norm=np.divide([a-b],[a+b])                               
            spots_late_minus_early_int_norm_syn[spotnos]=np.nanmean(spots_bias_image_norm)
            spots_bias_image_hist_norm,_= np.histogram([spots_bias_image_norm[~np.isnan(spots_bias_image_norm)]],bins=np.linspace(-1.,1.,50)) 
            spots_bias_image_hists_norm_syn[spotnos]=spots_bias_image_hist_norm                               
            ###biased images for norm minus autofluorescence 
            a=late_image_norm_minusauto[early_spots_mask]
            b=early_image_norm_minusauto[early_spots_mask]
            spots_bias_image_norm_minusauto=np.divide([a-b],[a+b])                               
            spots_late_minus_early_int_norm_minusauto_syn[spotnos]=np.nanmean(spots_bias_image_norm_minusauto)
            spots_bias_image_hist_norm_minusauto,_= np.histogram([spots_bias_image_norm_minusauto[~np.isnan(spots_bias_image_norm_minusauto)]],bins=np.linspace(-1.,1.,50)) 
            spots_bias_image_hists_norm_minusauto_syn[spotnos]=spots_bias_image_hist_norm_minusauto  
            ###biased images for norm to ctrl 
            a=late_image_normtoctrl[early_spots_mask]
            b=early_image_normtoctrl[early_spots_mask]
            spots_bias_image_normtoctrl=np.divide([a-b],[a+b])                               
            spots_late_minus_early_int_normtoctrl_syn[spotnos]=np.nanmean(spots_bias_image_normtoctrl)
            spots_bias_image_hist_normtoctrl,_= np.histogram([spots_bias_image_normtoctrl[~np.isnan(spots_bias_image_normtoctrl)]],bins=np.linspace(-1.,1.,50)) 
            spots_bias_image_hists_normtoctrl_syn[spotnos]=spots_bias_image_hist_normtoctrl  
    #final results calculation:
    #results based on spot segmentation    
    results["Early colour - Mean intensity of spots"].append(np.nanmean(early_spots_intensities))
    results["Late colour - Mean intensity of spots"].append(np.nanmean(late_spots_intensities))
    results["Early colour - Mean intensity of spots Normd to ctrls"].append(np.nanmean(early_spots_intensities_normtoctrl))
    results["Late colour - Mean intensity of spots Normd to ctrls"].append(np.nanmean(late_spots_intensities_normtoctrl))
    if synapse_flag:
        results["Synapse colour - Mean intensity of spots"].append(np.nanmean(synapse_spots_intensities))
    else:
        results["Synapse colour - Mean intensity of spots"].append(np.nan) 
    results["Early colour - Total no. of spots in FOV"].append(len(early_spots_intensities))
    results["Late colour - Total no. of spots in FOV"].append(len(late_spots_intensities))
    if synapse_flag:
        results["Synapse colour - Total no. of spots in FOV"].append(len(synapse_spots_intensities))
    else:
        results["Synapse colour - Total no. of spots in FOV"].append(np.nan)
    results["Early colour - Mean spot area [nm]"].append(np.nanmean(early_spots_areas))
    results["Late colour - Mean spot area [nm]"].append(np.nanmean(late_spots_areas))
    if synapse_flag:
        results["Synapse colour - Mean spot area [nm]"].append(np.nanmean(synapse_spots_areas))
        results["Early colour - masked by synapses"].append(np.nanmean(early_atsynapses_intensities))
        results["Early colour Normd to ctrl - masked by synapses"].append(np.nanmean(early_atsynapses_intensities_normtoctrl))
        results["Late colour - masked by synapses"].append(np.nanmean(late_atsynapses_intensities))
        results["Late colour Normd to ctrl - masked by synapses"].append(np.nanmean(late_atsynapses_intensities_normtoctrl))
    else:
        results["Synapse colour - Mean spot area [nm]"].append(np.nan)
        results["Early colour - masked by synapses"].append(np.nan)
        results["Early colour Normd to ctrl - masked by synapses"].append(np.nan)
        results["Late colour - masked by synapses"].append(np.nan)
        results["Late colour Normd to ctrl - masked by synapses"].append(np.nan)
    results["Mean colour bias of a pixel (early=-1<x<1=late)"].append(np.nanmean(spots_late_minus_early_int))
    histogram_results["Colour bias of a pixel (early=-1<x<1=late) - Histogram"].append(np.nanmean(spots_bias_image_hists,axis=0))                                   
    results["Mean colour bias of a pixel (early=-1<x<1=late) Raw"].append(np.nanmean(spots_late_minus_early_int_raw))
    histogram_results["Colour bias of a pixel (early=-1<x<1=late) Raw - Histogram"].append(np.nanmean(spots_bias_image_hists_raw,axis=0))                                   
    results["Mean colour bias of a pixel (early=-1<x<1=late) Normd"].append(np.nanmean(spots_late_minus_early_int_norm))
    histogram_results["Colour bias of a pixel (early=-1<x<1=late) Normd - Histogram"].append(np.nanmean(spots_bias_image_hists_norm,axis=0))                                   
    results["Mean colour bias of a pixel (early=-1<x<1=late) Normd Minus AutoF"].append(np.nanmean(spots_late_minus_early_int_norm_minusauto))
    histogram_results["Colour bias of a pixel (early=-1<x<1=late) Normd Minus AutoF - Histogram"].append(np.nanmean(spots_bias_image_hists_norm_minusauto,axis=0))                                   
    results["Mean colour bias of a pixel (early=-1<x<1=late) Normd to ctrls"].append(np.nanmean(spots_late_minus_early_int_normtoctrl))
    histogram_results["Colour bias of a pixel (early=-1<x<1=late) Normd to ctrls - Histogram"].append(np.nanmean(spots_bias_image_hists_normtoctrl,axis=0))                                   
    if synapse_flag:
        results["Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late)"].append(np.nanmean(spots_late_minus_early_int_syn))
        histogram_results["Colour bias of a pixel, masked by synapses (early=-1<x<1=late) - Histogram"].append(np.nanmean(spots_bias_image_hists_syn,axis=0))
        results["Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Raw"].append(np.nanmean(spots_late_minus_early_int_raw_syn))
        histogram_results["Colour bias of a pixel, masked by synapses (early=-1<x<1=late) Raw - Histogram"].append(np.nanmean(spots_bias_image_hists_raw_syn,axis=0))
        results["Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd"].append(np.nanmean(spots_late_minus_early_int_norm_syn))
        histogram_results["Colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd - Histogram"].append(np.nanmean(spots_bias_image_hists_norm_syn,axis=0)) 
        results["Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd to ctrls"].append(np.nanmean(spots_late_minus_early_int_normtoctrl_syn))
        histogram_results["Colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd to ctrls - Histogram"].append(np.nanmean(spots_bias_image_hists_normtoctrl_syn,axis=0)) 
    else:
        results["Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late)"].append(np.nan)
        histogram_results["Colour bias of a pixel, masked by synapses (early=-1<x<1=late) - Histogram"].append(np.nan)
        results["Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Raw"].append(np.nan)
        histogram_results["Colour bias of a pixel, masked by synapses (early=-1<x<1=late) Raw - Histogram"].append(np.nan)
        results["Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd"].append(np.nan)
        histogram_results["Colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd - Histogram"].append(np.nan)
        results["Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd to ctrls"].append(np.nan)
        histogram_results["Colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd to ctrls - Histogram"].append(np.nan)
    temp_bias_image_full=np.divide([late_image-early_image],[late_image+early_image])
    temp_bias_image_zerosfornans=temp_bias_image_full.copy()
    temp_bias_image_zerosfornans[np.isnan(temp_bias_image_zerosfornans)] = 0
    temp_bias_image = temp_bias_image_full[~np.isnan(temp_bias_image_full)]
    pos_late_minus_early=np.subtract(temp_bias_image,np.min(temp_bias_image))     
    results["Mean colour bias of a pixel - shifted to pos values (early=0)"].append(np.nanmean(pos_late_minus_early))
    if synapse_flag:
        results["Correlation between colour bias (0 shifted) and synapse intensity"].append(corr2(temp_bias_image_zerosfornans,synapse_image))
    else:
        results["Correlation between colour bias (0 shifted) and synapse intensity"].append(np.nan)
    earlyprops=skimage.measure.regionprops(spots_early_labels)
    lateprops=skimage.measure.regionprops(spots_late_labels)
    if synapse_flag:
        synapseprops=skimage.measure.regionprops(spots_synapse_labels)                                 
    earlypluslateprops=skimage.measure.regionprops(spots_earlypluslate_labels)
    regionprops_results["Early colour - regionprops"].append(earlyprops)
    regionprops_results["Late colour - regionprops"].append(lateprops)
    if synapse_flag:
        regionprops_results["Synapse colour - regionprops"].append(synapseprops)
    else:
        regionprops_results["Synapse colour - regionprops"].append(np.nan)
    regionprops_results["Late + early colour combined - regionprops"].append(earlypluslateprops)
    #global results
    results["Early colour - Raw mean intensity"].append(np.nanmean(early_image_raw))
    results["Late colour - Raw mean intensity"].append(np.nanmean(late_image_raw))
    results["Early colour - Mean intensity Normd to ctrls"].append(np.nanmean(early_image_normtoctrl))
    results["Late colour - Mean intensity Normd to ctrls"].append(np.nanmean(late_image_normtoctrl))
    if synapse_flag:
        results["Synapse colour - Raw mean intensity"].append(np.nanmean(synapse_image_raw))
    else:
        results["Synapse colour - Raw mean intensity"].append(np.nan)
    histogram_results["Early colour - Flattened histogram"].append(early_hist) 
    histogram_results["Late colour - Flattened histogram"].append(late_hist)
    if synapse_flag:
        histogram_results["Synapse colour - Flattened histogram"].append(synapse_hist)
    else:
        histogram_results["Synapse colour - Flattened histogram"].append(np.nan)
    histogram_results["Early colour - Flattened histogram of image normd to internal max"].append(early_hist_norm) 
    histogram_results["Late colour - Flattened histogram of image normd to internal max"].append(late_hist_norm) 
    if synapse_flag:
        histogram_results["Synapse colour - Flattened histogram of image normd to internal max"].append(synapse_hist_norm) 
    else:
        histogram_results["Synapse colour - Flattened histogram of image normd to internal max"].append(np.nan)
    bias_image_full=np.divide([late_image-early_image],[late_image+early_image])
    bias_image = bias_image_full[~np.isnan(bias_image_full)]
    bias_image_hist,_=np.histogram(bias_image,bins=np.linspace(-1.,1.,50))
    bias_image_raw_full=np.divide([late_image_raw-early_image_raw],[late_image_raw+early_image_raw])
    bias_image_raw = bias_image_raw_full[~np.isnan(bias_image_raw_full)]
    bias_image_hist_raw,_=np.histogram(bias_image_raw,bins=np.linspace(-1.,1.,50))
    bias_image_norm_full=np.divide([late_image_norm-early_image_norm],[late_image_norm+early_image_norm])
    bias_image_norm = bias_image_norm_full[~np.isnan(bias_image_norm_full)]
    bias_image_hist_norm,_=np.histogram(bias_image_norm,bins=np.linspace(-1.,1.,50))
    bias_image_normtoctrl_full=np.divide([late_image_normtoctrl-early_image_normtoctrl],[late_image_normtoctrl+early_image_normtoctrl])
    bias_image_normtoctrl_full = bias_image_normtoctrl_full[~np.isnan(bias_image_normtoctrl_full)]
    bias_image_hist_normtoctrl,_=np.histogram(bias_image_normtoctrl_full,bins=np.linspace(-1.,1.,50))
    results["Global Mean colour bias of a pixel (early=-1<x<1=late)"].append(np.nanmean(bias_image_full))
    histogram_results["Global Colour bias of a pixel (early=-1<x<1=late) - Histogram"].append(bias_image_hist)                                   
    results["Global Mean colour bias of a pixel (early=-1<x<1=late) Raw"].append(np.nanmean(bias_image_raw_full))
    histogram_results["Global Colour bias of a pixel (early=-1<x<1=late) Raw - Histogram"].append(bias_image_hist_raw)                                   
    results["Global Mean colour bias of a pixel (early=-1<x<1=late) Normd"].append(np.nanmean(bias_image_norm_full))
    histogram_results["Global Colour bias of a pixel (early=-1<x<1=late) Normd - Histogram"].append(bias_image_hist_norm)                                   
    histogram_results["Global Colour bias of a pixel (early=-1<x<1=late) Raw - Histogram"].append(bias_image_hist_raw)                                   
    results["Global Mean colour bias of a pixel (early=-1<x<1=late) Normd to ctrls"].append(np.nanmean(bias_image_normtoctrl_full))
    histogram_results["Global Colour bias of a pixel (early=-1<x<1=late) Normd to ctrls - Histogram"].append(bias_image_hist_normtoctrl)                                   
    results["Mean correlation coefficient early/late"].append(corr2(early_image,late_image))
    if synapse_flag:
        results["Early colour/Synapse colour corr (Mean intensity of spots)"].append(corr2(early_image,synapse_image))
        results["Late colour/Synapse colour corr (Mean intensity of spots)"].append(corr2(late_image,synapse_image))
        results["Early colour/Synapse colour corr (Mean intensity of spots norm to ctrl)"].append(corr2(early_image_normtoctrl,synapse_image))
        results["Late colour/Synapse colour corr (Mean intensity of spots norm to ctrl)"].append(corr2(late_image_normtoctrl,synapse_image))
    else:
        results["Early colour/Synapse colour corr (Mean intensity of spots)"].append(np.nan)
        results["Late colour/Synapse colour corr (Mean intensity of spots)"].append(np.nan)
        results["Early colour/Synapse colour corr (Mean intensity of spots norm to ctrl)"].append(np.nan)
        results["Late colour/Synapse colour corr (Mean intensity of spots norm to ctrl)"].append(np.nan)
os.system('say "Finished batch analyzing"')
# Out:
# Total number of images: 1904
# Calculating image no 1290 out of1904
# has synapse values
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# no early spots = 98
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:246: RuntimeWarning: invalid value encountered in true_divide
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:254: RuntimeWarning: Mean of empty slice
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:247: RuntimeWarning: Mean of empty slice
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:225: RuntimeWarning: invalid value encountered in true_divide
# no late spots = 80
# no synapse spots = 92
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:262: RuntimeWarning: Mean of empty slice
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:275: RuntimeWarning: Mean of empty slice
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:301: RuntimeWarning: invalid value encountered in true_divide
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:302: RuntimeWarning: Mean of empty slice
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:309: RuntimeWarning: Mean of empty slice
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:280: RuntimeWarning: invalid value encountered in true_divide
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:370: RuntimeWarning: invalid value encountered in true_divide
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:396: RuntimeWarning: Mean of empty slice
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:413: RuntimeWarning: invalid value encountered in true_divide
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:432: RuntimeWarning: Mean of empty slice
# Calculating image no 1291 out of1904
# has synapse values
# no early spots = 104
# no late spots = 74
# no synapse spots = 79
# Calculating image no 1292 out of1904
# has synapse values
# no early spots = 149
# no late spots = 140
# no synapse spots = 123
# Calculating image no 1293 out of1904
# has synapse values
# no early spots = 140
# no late spots = 109
# no synapse spots = 104
# Calculating image no 1294 out of1904
# has synapse values
# no early spots = 130
# no late spots = 131
# no synapse spots = 104
# Calculating image no 1295 out of1904
# has synapse values
# no early spots = 165
# no late spots = 128
# no synapse spots = 120
# Calculating image no 1296 out of1904
# has synapse values
# no early spots = 129
# no late spots = 96
# no synapse spots = 113
# Calculating image no 1297 out of1904
# has synapse values
# no early spots = 91
# no late spots = 66
# no synapse spots = 75
# Calculating image no 1298 out of1904
# has synapse values
# no early spots = 102
# no late spots = 61
# no synapse spots = 73
# Calculating image no 1299 out of1904
# has synapse values
# no early spots = 112
# no late spots = 92
# no synapse spots = 94
# Calculating image no 1300 out of1904
# has synapse values
# no early spots = 133
# no late spots = 106
# no synapse spots = 98
# Calculating image no 1301 out of1904
# has synapse values
# no early spots = 84
# no late spots = 102
# no synapse spots = 91
# Calculating image no 1302 out of1904
# has synapse values
# no early spots = 142
# no late spots = 108
# no synapse spots = 126
# Calculating image no 1303 out of1904
# has synapse values
# no early spots = 117
# no late spots = 97
# no synapse spots = 79
# Calculating image no 1304 out of1904
# has synapse values
# no early spots = 109
# no late spots = 73
# no synapse spots = 87
# Calculating image no 1305 out of1904
# has synapse values
# no early spots = 159
# no late spots = 177
# no synapse spots = 135
# Calculating image no 1306 out of1904
# has synapse values
# no early spots = 134
# no late spots = 149
# no synapse spots = 116
# Calculating image no 1307 out of1904
# has synapse values
# no early spots = 130
# no late spots = 115
# no synapse spots = 114
# Calculating image no 1308 out of1904
# has synapse values
# no early spots = 145
# no late spots = 136
# no synapse spots = 133
# Calculating image no 1309 out of1904
# has synapse values
# no early spots = 160
# no late spots = 138
# no synapse spots = 133
# Calculating image no 1310 out of1904
# has synapse values
# no early spots = 73
# no late spots = 71
# no synapse spots = 77
# Calculating image no 1311 out of1904
# has synapse values
# no early spots = 144
# no late spots = 124
# no synapse spots = 97
# Calculating image no 1312 out of1904
# has synapse values
# no early spots = 141
# no late spots = 116
# no synapse spots = 122
# Calculating image no 1313 out of1904
# has synapse values
# no early spots = 139
# no late spots = 113
# no synapse spots = 122
# Calculating image no 1314 out of1904
# has synapse values
# no early spots = 141
# no late spots = 119
# no synapse spots = 149
# Calculating image no 1315 out of1904
# has synapse values
# no early spots = 143
# no late spots = 111
# no synapse spots = 111
# Calculating image no 1316 out of1904
# has synapse values
# no early spots = 134
# no late spots = 129
# no synapse spots = 135
# Calculating image no 1317 out of1904
# has synapse values
# no early spots = 136
# no late spots = 127
# no synapse spots = 113
# Calculating image no 1318 out of1904
# has synapse values
# no early spots = 138
# no late spots = 124
# no synapse spots = 140
# Calculating image no 1319 out of1904
# has synapse values
# no early spots = 134
# no late spots = 163
# no synapse spots = 137
# Calculating image no 1320 out of1904
# has synapse values
# no early spots = 122
# no late spots = 165
# no synapse spots = 103
# Calculating image no 1321 out of1904
# has synapse values
# no early spots = 103
# no late spots = 106
# no synapse spots = 96
# Calculating image no 1322 out of1904
# has synapse values
# no early spots = 159
# no late spots = 144
# no synapse spots = 131
# Calculating image no 1323 out of1904
# has synapse values
# no early spots = 76
# no late spots = 71
# no synapse spots = 68
# Calculating image no 1324 out of1904
# has synapse values
# no early spots = 135
# no late spots = 125
# no synapse spots = 120
# Calculating image no 1325 out of1904
# has synapse values
# no early spots = 117
# no late spots = 113
# no synapse spots = 99
# Calculating image no 1326 out of1904
# has synapse values
# no early spots = 229
# no late spots = 203
# no synapse spots = 161
# Calculating image no 1327 out of1904
# has synapse values
# no early spots = 177
# no late spots = 174
# no synapse spots = 126
# Calculating image no 1328 out of1904
# has synapse values
# no early spots = 157
# no late spots = 131
# no synapse spots = 153
# Calculating image no 1329 out of1904
# has synapse values
# no early spots = 182
# no late spots = 176
# no synapse spots = 190
# Calculating image no 1330 out of1904
# has synapse values
# no early spots = 133
# no late spots = 124
# no synapse spots = 116
# Calculating image no 1331 out of1904
# has synapse values
# no early spots = 116
# no late spots = 114
# no synapse spots = 92
# Calculating image no 1332 out of1904
# has synapse values
# no early spots = 104
# no late spots = 132
# no synapse spots = 94
# Calculating image no 1333 out of1904
# has synapse values
# no early spots = 167
# no late spots = 189
# no synapse spots = 118
# Calculating image no 1334 out of1904
# has synapse values
# no early spots = 165
# no late spots = 162
# no synapse spots = 141
# Calculating image no 1335 out of1904
# has synapse values
# no early spots = 213
# no late spots = 233
# no synapse spots = 155
# Calculating image no 1336 out of1904
# has synapse values
# no early spots = 162
# no late spots = 132
# no synapse spots = 105
# Calculating image no 1337 out of1904
# has synapse values
# no early spots = 146
# no late spots = 122
# no synapse spots = 127
# Calculating image no 1338 out of1904
# has synapse values
# no early spots = 130
# no late spots = 107
# no synapse spots = 111
# Calculating image no 1339 out of1904
# has synapse values
# no early spots = 146
# no late spots = 117
# no synapse spots = 131
# Calculating image no 1340 out of1904
# has synapse values
# no early spots = 129
# no late spots = 130
# no synapse spots = 92
# Calculating image no 1341 out of1904
# has synapse values
# no early spots = 195
# no late spots = 153
# no synapse spots = 143
# Calculating image no 1342 out of1904
# has synapse values
# no early spots = 129
# no late spots = 113
# no synapse spots = 101
# Calculating image no 1343 out of1904
# has synapse values
# no early spots = 99
# no late spots = 102
# no synapse spots = 99
# Calculating image no 1344 out of1904
# has synapse values
# no early spots = 164
# no late spots = 121
# no synapse spots = 130
# Calculating image no 1345 out of1904
# has synapse values
# no early spots = 153
# no late spots = 125
# no synapse spots = 135
# Calculating image no 1346 out of1904
# has synapse values
# no early spots = 183
# no late spots = 151
# no synapse spots = 131
# Calculating image no 1347 out of1904
# has synapse values
# no early spots = 114
# no late spots = 107
# no synapse spots = 85
# Calculating image no 1348 out of1904
# has synapse values
# no early spots = 125
# no late spots = 107
# no synapse spots = 103
# Calculating image no 1349 out of1904
# has synapse values
# no early spots = 145
# no late spots = 133
# no synapse spots = 84
# Calculating image no 1350 out of1904
# has synapse values
# no early spots = 114
# no late spots = 145
# no synapse spots = 123
# Calculating image no 1351 out of1904
# has synapse values
# no early spots = 220
# no late spots = 184
# no synapse spots = 190
# Calculating image no 1352 out of1904
# has synapse values
# no early spots = 153
# no late spots = 165
# no synapse spots = 120
# Calculating image no 1353 out of1904
# has synapse values
# no early spots = 161
# no late spots = 163
# no synapse spots = 150
# Calculating image no 1354 out of1904
# has synapse values
# no early spots = 158
# no late spots = 149
# no synapse spots = 170
# Calculating image no 1355 out of1904
# has synapse values
# no early spots = 245
# no late spots = 251
# no synapse spots = 136
# Calculating image no 1356 out of1904
# has synapse values
# no early spots = 130
# no late spots = 162
# no synapse spots = 135
# Calculating image no 1357 out of1904
# has synapse values
# no early spots = 175
# no late spots = 202
# no synapse spots = 165
# Calculating image no 1358 out of1904
# has synapse values
# no early spots = 197
# no late spots = 199
# no synapse spots = 139
# Calculating image no 1359 out of1904
# has synapse values
# no early spots = 146
# no late spots = 137
# no synapse spots = 122
# Calculating image no 1360 out of1904
# has synapse values
# no early spots = 218
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:226: RuntimeWarning: Mean of empty slice
# no late spots = 171
# no synapse spots = 146
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:281: RuntimeWarning: Mean of empty slice
# Calculating image no 1361 out of1904
# has synapse values
# no early spots = 237
# no late spots = 144
# no synapse spots = 156
# Calculating image no 1362 out of1904
# has synapse values
# no early spots = 199
# no late spots = 195
# no synapse spots = 162
# Calculating image no 1363 out of1904
# has synapse values
# no early spots = 256
# no late spots = 139
# no synapse spots = 136
# Calculating image no 1364 out of1904
# has synapse values
# no early spots = 258
# no late spots = 162
# no synapse spots = 180
# Calculating image no 1365 out of1904
# has synapse values
# no early spots = 216
# no late spots = 144
# no synapse spots = 145
# Calculating image no 1366 out of1904
# has synapse values
# no early spots = 207
# no late spots = 114
# no synapse spots = 125
# Calculating image no 1367 out of1904
# has synapse values
# no early spots = 185
# no late spots = 206
# no synapse spots = 205
# Calculating image no 1368 out of1904
# has synapse values
# no early spots = 263
# no late spots = 148
# no synapse spots = 191
# Calculating image no 1369 out of1904
# has synapse values
# no early spots = 181
# no late spots = 116
# no synapse spots = 150
# Calculating image no 1370 out of1904
# has synapse values
# no early spots = 250
# no late spots = 148
# no synapse spots = 146
# Calculating image no 1371 out of1904
# has synapse values
# no early spots = 238
# no late spots = 151
# no synapse spots = 135
# Calculating image no 1372 out of1904
# has synapse values
# no early spots = 251
# no late spots = 142
# no synapse spots = 89
# Calculating image no 1373 out of1904
# has synapse values
# no early spots = 197
# no late spots = 125
# no synapse spots = 111
# Calculating image no 1374 out of1904
# has synapse values
# no early spots = 261
# no late spots = 160
# no synapse spots = 109
# Calculating image no 1375 out of1904
# has synapse values
# no early spots = 243
# no late spots = 146
# no synapse spots = 122
# Calculating image no 1376 out of1904
# has synapse values
# no early spots = 234
# no late spots = 173
# no synapse spots = 131
# Calculating image no 1377 out of1904
# has synapse values
# no early spots = 221
# no late spots = 140
# no synapse spots = 107
# Calculating image no 1378 out of1904
# has synapse values
# no early spots = 245
# no late spots = 154
# no synapse spots = 142
# Calculating image no 1379 out of1904
# has synapse values
# no early spots = 206
# no late spots = 201
# no synapse spots = 199
# Calculating image no 1380 out of1904
# has synapse values
# no early spots = 271
# no late spots = 209
# no synapse spots = 190
# Calculating image no 1381 out of1904
# has synapse values
# no early spots = 154
# no late spots = 147
# no synapse spots = 145
# Calculating image no 1382 out of1904
# has synapse values
# no early spots = 177
# no late spots = 104
# no synapse spots = 137
# Calculating image no 1383 out of1904
# has synapse values
# no early spots = 193
# no late spots = 176
# no synapse spots = 203
# Calculating image no 1384 out of1904
# has synapse values
# no early spots = 156
# no late spots = 106
# no synapse spots = 126
# Calculating image no 1385 out of1904
# has synapse values
# no early spots = 127
# no late spots = 95
# no synapse spots = 128
# Calculating image no 1386 out of1904
# has synapse values
# no early spots = 170
# no late spots = 133
# no synapse spots = 126
# Calculating image no 1387 out of1904
# has synapse values
# no early spots = 158
# no late spots = 115
# no synapse spots = 166
# Calculating image no 1388 out of1904
# has synapse values
# no early spots = 224
# no late spots = 169
# no synapse spots = 207
# Calculating image no 1389 out of1904
# has synapse values
# no early spots = 120
# no late spots = 117
# no synapse spots = 147
# Calculating image no 1390 out of1904
# has synapse values
# no early spots = 119
# no late spots = 140
# no synapse spots = 156
# Calculating image no 1391 out of1904
# has synapse values
# no early spots = 169
# no late spots = 227
# no synapse spots = 129
# Calculating image no 1392 out of1904
# has synapse values
# no early spots = 233
# no late spots = 251
# no synapse spots = 142
# Calculating image no 1393 out of1904
# has synapse values
# no early spots = 200
# no late spots = 258
# no synapse spots = 153
# Calculating image no 1394 out of1904
# has synapse values
# no early spots = 156
# no late spots = 160
# no synapse spots = 109
# Calculating image no 1395 out of1904
# has synapse values
# no early spots = 151
# no late spots = 195
# no synapse spots = 113
# Calculating image no 1396 out of1904
# has synapse values
# no early spots = 217
# no late spots = 266
# no synapse spots = 108
# Calculating image no 1397 out of1904
# has synapse values
# no early spots = 173
# no late spots = 172
# no synapse spots = 81
# Calculating image no 1398 out of1904
# has synapse values
# no early spots = 183
# no late spots = 262
# no synapse spots = 116
# Calculating image no 1399 out of1904
# has synapse values
# no early spots = 185
# no late spots = 301
# no synapse spots = 164
# Calculating image no 1400 out of1904
# has synapse values
# no early spots = 183
# no late spots = 239
# no synapse spots = 124
# Calculating image no 1401 out of1904
# has synapse values
# no early spots = 97
# no late spots = 92
# no synapse spots = 85
# Calculating image no 1402 out of1904
# has synapse values
# no early spots = 113
# no late spots = 117
# no synapse spots = 91
# Calculating image no 1403 out of1904
# has synapse values
# no early spots = 101
# no late spots = 93
# no synapse spots = 67
# Calculating image no 1404 out of1904
# has synapse values
# no early spots = 166
# no late spots = 138
# no synapse spots = 88
# Calculating image no 1405 out of1904
# has synapse values
# no early spots = 135
# no late spots = 120
# no synapse spots = 92
# Calculating image no 1406 out of1904
# has synapse values
# no early spots = 124
# no late spots = 115
# no synapse spots = 92
# Calculating image no 1407 out of1904
# has synapse values
# no early spots = 99
# no late spots = 119
# no synapse spots = 82
# Calculating image no 1408 out of1904
# has synapse values
# no early spots = 136
# no late spots = 136
# no synapse spots = 108
# Calculating image no 1409 out of1904
# has synapse values
# no early spots = 134
# no late spots = 136
# no synapse spots = 91
# Calculating image no 1410 out of1904
# has synapse values
# no early spots = 140
# no late spots = 132
# no synapse spots = 128
# Calculating image no 1411 out of1904
# has synapse values
# no early spots = 121
# no late spots = 123
# no synapse spots = 102
# Calculating image no 1412 out of1904
# has synapse values
# no early spots = 114
# no late spots = 111
# no synapse spots = 113
# Calculating image no 1413 out of1904
# has synapse values
# no early spots = 116
# no late spots = 88
# no synapse spots = 82
# Calculating image no 1414 out of1904
# has synapse values
# no early spots = 92
# no late spots = 108
# no synapse spots = 87
# Calculating image no 1415 out of1904
# has synapse values
# no early spots = 84
# no late spots = 62
# no synapse spots = 52
# Calculating image no 1416 out of1904
# has synapse values
# no early spots = 104
# no late spots = 113
# no synapse spots = 78
# Calculating image no 1417 out of1904
# has synapse values
# no early spots = 163
# no late spots = 171
# no synapse spots = 134
# Calculating image no 1418 out of1904
# has synapse values
# no early spots = 97
# no late spots = 85
# no synapse spots = 75
# Calculating image no 1419 out of1904
# has synapse values
# no early spots = 89
# no late spots = 72
# no synapse spots = 54
# Calculating image no 1420 out of1904
# has synapse values
# no early spots = 133
# no late spots = 115
# no synapse spots = 89
# Calculating image no 1421 out of1904
# has synapse values
# no early spots = 80
# no late spots = 88
# no synapse spots = 73
# Calculating image no 1422 out of1904
# has synapse values
# no early spots = 98
# no late spots = 115
# no synapse spots = 70
# Calculating image no 1423 out of1904
# has synapse values
# no early spots = 151
# no late spots = 154
# no synapse spots = 112
# Calculating image no 1424 out of1904
# has synapse values
# no early spots = 139
# no late spots = 142
# no synapse spots = 112
# Calculating image no 1425 out of1904
# has synapse values
# no early spots = 101
# no late spots = 157
# no synapse spots = 93
# Calculating image no 1426 out of1904
# has synapse values
# no early spots = 129
# no late spots = 176
# no synapse spots = 129
# Calculating image no 1427 out of1904
# has synapse values
# no early spots = 171
# no late spots = 163
# no synapse spots = 137
# Calculating image no 1428 out of1904
# has synapse values
# no early spots = 154
# no late spots = 158
# no synapse spots = 91
# Calculating image no 1429 out of1904
# has synapse values
# no early spots = 141
# no late spots = 142
# no synapse spots = 115
# Calculating image no 1430 out of1904
# has synapse values
# no early spots = 152
# no late spots = 157
# no synapse spots = 124
# Calculating image no 1431 out of1904
# has synapse values
# no early spots = 170
# no late spots = 207
# no synapse spots = 109
# Calculating image no 1432 out of1904
# has synapse values
# no early spots = 113
# no late spots = 112
# no synapse spots = 96
# Calculating image no 1433 out of1904
# has synapse values
# no early spots = 124
# no late spots = 130
# no synapse spots = 131
# Calculating image no 1434 out of1904
# has synapse values
# no early spots = 158
# no late spots = 186
# no synapse spots = 103
# Calculating image no 1435 out of1904
# has synapse values
# no early spots = 191
# no late spots = 168
# no synapse spots = 97
# Calculating image no 1436 out of1904
# has synapse values
# no early spots = 194
# no late spots = 190
# no synapse spots = 125
# Calculating image no 1437 out of1904
# has synapse values
# no early spots = 146
# no late spots = 135
# no synapse spots = 98
# Calculating image no 1438 out of1904
# has synapse values
# no early spots = 129
# no late spots = 117
# no synapse spots = 122
# Calculating image no 1439 out of1904
# has synapse values
# no early spots = 172
# no late spots = 120
# no synapse spots = 109
# Calculating image no 1440 out of1904
# has synapse values
# no early spots = 115
# no late spots = 107
# no synapse spots = 85
# Calculating image no 1441 out of1904
# has synapse values
# no early spots = 97
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:220: RuntimeWarning: Mean of empty slice
# no late spots = 221
# no synapse spots = 153
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:274: RuntimeWarning: Mean of empty slice
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:395: RuntimeWarning: Mean of empty slice
# Calculating image no 1442 out of1904
# has synapse values
# no early spots = 136
# no late spots = 223
# no synapse spots = 156
# Calculating image no 1443 out of1904
# has synapse values
# no early spots = 107
# no late spots = 214
# no synapse spots = 95
# Calculating image no 1444 out of1904
# has synapse values
# no early spots = 136
# no late spots = 244
# no synapse spots = 150
# Calculating image no 1445 out of1904
# has synapse values
# no early spots = 144
# no late spots = 261
# no synapse spots = 149
# Calculating image no 1446 out of1904
# has synapse values
# no early spots = 181
# no late spots = 238
# no synapse spots = 177
# Calculating image no 1447 out of1904
# has synapse values
# no early spots = 97
# no late spots = 183
# no synapse spots = 122
# Calculating image no 1448 out of1904
# has synapse values
# no early spots = 110
# no late spots = 228
# no synapse spots = 164
# Calculating image no 1449 out of1904
# has synapse values
# no early spots = 96
# no late spots = 227
# no synapse spots = 122
# Calculating image no 1450 out of1904
# has synapse values
# no early spots = 152
# no late spots = 205
# no synapse spots = 152
# Calculating image no 1451 out of1904
# has synapse values
# no early spots = 147
# no late spots = 148
# no synapse spots = 170
# Calculating image no 1452 out of1904
# has synapse values
# no early spots = 138
# no late spots = 127
# no synapse spots = 143
# Calculating image no 1453 out of1904
# has synapse values
# no early spots = 124
# no late spots = 114
# no synapse spots = 131
# Calculating image no 1454 out of1904
# has synapse values
# no early spots = 180
# no late spots = 164
# no synapse spots = 154
# Calculating image no 1455 out of1904
# has synapse values
# no early spots = 169
# no late spots = 223
# no synapse spots = 211
# Calculating image no 1456 out of1904
# has synapse values
# no early spots = 153
# no late spots = 141
# no synapse spots = 156
# Calculating image no 1457 out of1904
# has synapse values
# no early spots = 137
# no late spots = 134
# no synapse spots = 146
# Calculating image no 1458 out of1904
# has synapse values
# no early spots = 199
# no late spots = 244
# no synapse spots = 167
# Calculating image no 1459 out of1904
# has synapse values
# no early spots = 186
# no late spots = 185
# no synapse spots = 169
# Calculating image no 1460 out of1904
# has synapse values
# no early spots = 175
# no late spots = 170
# no synapse spots = 148
# Calculating image no 1461 out of1904
# has synapse values
# no early spots = 164
# no late spots = 191
# no synapse spots = 185
# Calculating image no 1462 out of1904
# has synapse values
# no early spots = 180
# no late spots = 175
# no synapse spots = 155
# Calculating image no 1463 out of1904
# has synapse values
# no early spots = 128
# no late spots = 145
# no synapse spots = 158
# Calculating image no 1464 out of1904
# has synapse values
# no early spots = 200
# no late spots = 221
# no synapse spots = 166
# Calculating image no 1465 out of1904
# has synapse values
# no early spots = 138
# no late spots = 166
# no synapse spots = 119
# Calculating image no 1466 out of1904
# has synapse values
# no early spots = 147
# no late spots = 156
# no synapse spots = 108
# Calculating image no 1467 out of1904
# has synapse values
# no early spots = 87
# no late spots = 100
# no synapse spots = 104
# Calculating image no 1468 out of1904
# has synapse values
# no early spots = 133
# no late spots = 148
# no synapse spots = 132
# Calculating image no 1469 out of1904
# has synapse values
# no early spots = 156
# no late spots = 173
# no synapse spots = 121
# Calculating image no 1470 out of1904
# has synapse values
# no early spots = 133
# no late spots = 148
# no synapse spots = 112
# Calculating image no 1471 out of1904
# has synapse values
# no early spots = 103
# no late spots = 124
# no synapse spots = 112
# Calculating image no 1472 out of1904
# has synapse values
# no early spots = 129
# no late spots = 128
# no synapse spots = 106
# Calculating image no 1473 out of1904
# has synapse values
# no early spots = 105
# no late spots = 104
# no synapse spots = 99
# Calculating image no 1474 out of1904
# has synapse values
# no early spots = 118
# no late spots = 107
# no synapse spots = 128
# Calculating image no 1475 out of1904
# has synapse values
# no early spots = 126
# no late spots = 125
# no synapse spots = 137
# Calculating image no 1476 out of1904
# has synapse values
# no early spots = 134
# no late spots = 139
# no synapse spots = 148
# Calculating image no 1477 out of1904
# has synapse values
# no early spots = 98
# no late spots = 108
# no synapse spots = 120
# Calculating image no 1478 out of1904
# has synapse values
# no early spots = 96
# no late spots = 117
# no synapse spots = 100
# Calculating image no 1479 out of1904
# has synapse values
# no early spots = 116
# no late spots = 106
# no synapse spots = 126
# Calculating image no 1480 out of1904
# has synapse values
# no early spots = 72
# no late spots = 117
# no synapse spots = 94
# Calculating image no 1481 out of1904
# has synapse values
# no early spots = 137
# no late spots = 163
# no synapse spots = 159
# Calculating image no 1482 out of1904
# has synapse values
# no early spots = 108
# no late spots = 113
# no synapse spots = 142
# Calculating image no 1483 out of1904
# has synapse values
# no early spots = 98
# no late spots = 127
# no synapse spots = 121
# Calculating image no 1484 out of1904
# has synapse values
# no early spots = 144
# no late spots = 154
# no synapse spots = 180
# Calculating image no 1485 out of1904
# has synapse values
# no early spots = 139
# no late spots = 139
# no synapse spots = 151
# Calculating image no 1486 out of1904
# has synapse values
# no early spots = 117
# no late spots = 121
# no synapse spots = 147
# Calculating image no 1487 out of1904
# has synapse values
# no early spots = 107
# no late spots = 125
# no synapse spots = 153
# Calculating image no 1488 out of1904
# has synapse values
# no early spots = 146
# no late spots = 182
# no synapse spots = 172
# Calculating image no 1489 out of1904
# has synapse values
# no early spots = 133
# no late spots = 155
# no synapse spots = 196
# Calculating image no 1490 out of1904
# has synapse values
# no early spots = 118
# no late spots = 100
# no synapse spots = 194
# Calculating image no 1491 out of1904
# has synapse values
# no early spots = 149
# no late spots = 159
# no synapse spots = 152
# Calculating image no 1492 out of1904
# has synapse values
# no early spots = 134
# no late spots = 144
# no synapse spots = 162
# Calculating image no 1493 out of1904
# has synapse values
# no early spots = 86
# no late spots = 88
# no synapse spots = 120
# Calculating image no 1494 out of1904
# has synapse values
# no early spots = 138
# no late spots = 157
# no synapse spots = 182
# Calculating image no 1495 out of1904
# has synapse values
# no early spots = 159
# no late spots = 160
# no synapse spots = 206
# Calculating image no 1496 out of1904
# has synapse values
# no early spots = 137
# no late spots = 163
# no synapse spots = 173
# Calculating image no 1497 out of1904
# has synapse values
# no early spots = 151
# no late spots = 171
# no synapse spots = 132
# Calculating image no 1498 out of1904
# has synapse values
# no early spots = 128
# no late spots = 143
# no synapse spots = 146
# Calculating image no 1499 out of1904
# has synapse values
# no early spots = 126
# no late spots = 139
# no synapse spots = 177
# Calculating image no 1500 out of1904
# has synapse values
# no early spots = 107
# no late spots = 103
# no synapse spots = 108
# Calculating image no 1501 out of1904
# has synapse values
# no early spots = 118
# no late spots = 125
# no synapse spots = 152
# Calculating image no 1502 out of1904
# has synapse values
# no early spots = 107
# no late spots = 124
# no synapse spots = 112
# Calculating image no 1503 out of1904
# has synapse values
# no early spots = 136
# no late spots = 135
# no synapse spots = 197
# Calculating image no 1504 out of1904
# has synapse values
# no early spots = 99
# no late spots = 113
# no synapse spots = 134
# Calculating image no 1505 out of1904
# has synapse values
# no early spots = 187
# no late spots = 202
# no synapse spots = 213
# Calculating image no 1506 out of1904
# has synapse values
# no early spots = 150
# no late spots = 163
# no synapse spots = 208
# Calculating image no 1507 out of1904
# has synapse values
# no early spots = 104
# no late spots = 101
# no synapse spots = 143
# Calculating image no 1508 out of1904
# has synapse values
# no early spots = 153
# no late spots = 156
# no synapse spots = 149
# Calculating image no 1509 out of1904
# has synapse values
# no early spots = 153
# no late spots = 163
# no synapse spots = 183
# Calculating image no 1510 out of1904
# has synapse values
# no early spots = 125
# no late spots = 157
# no synapse spots = 140
# Calculating image no 1511 out of1904
# has synapse values
# no early spots = 101
# no late spots = 95
# no synapse spots = 133
# Calculating image no 1512 out of1904
# has synapse values
# no early spots = 115
# no late spots = 108
# no synapse spots = 199
# Calculating image no 1513 out of1904
# has synapse values
# no early spots = 111
# no late spots = 117
# no synapse spots = 181
# Calculating image no 1514 out of1904
# has synapse values
# no early spots = 91
# no late spots = 87
# no synapse spots = 161
# Calculating image no 1515 out of1904
# has synapse values
# no early spots = 96
# no late spots = 104
# no synapse spots = 134
# Calculating image no 1516 out of1904
# has synapse values
# no early spots = 88
# no late spots = 96
# no synapse spots = 141
# Calculating image no 1517 out of1904
# has synapse values
# no early spots = 87
# no late spots = 105
# no synapse spots = 120
# Calculating image no 1518 out of1904
# has synapse values
# no early spots = 121
# no late spots = 143
# no synapse spots = 153
# Calculating image no 1519 out of1904
# has synapse values
# no early spots = 115
# no late spots = 120
# no synapse spots = 146
# Calculating image no 1520 out of1904
# has synapse values
# no early spots = 91
# no late spots = 95
# no synapse spots = 110
# Calculating image no 1521 out of1904
# has synapse values
# no early spots = 127
# no late spots = 120
# no synapse spots = 117
# Calculating image no 1522 out of1904
# has synapse values
# no early spots = 124
# no late spots = 122
# no synapse spots = 135
# Calculating image no 1523 out of1904
# has synapse values
# no early spots = 111
# no late spots = 132
# no synapse spots = 115
# Calculating image no 1524 out of1904
# has synapse values
# no early spots = 144
# no late spots = 138
# no synapse spots = 120
# Calculating image no 1525 out of1904
# has synapse values
# no early spots = 95
# no late spots = 88
# no synapse spots = 121
# Calculating image no 1526 out of1904
# has synapse values
# no early spots = 93
# no late spots = 88
# no synapse spots = 104
# Calculating image no 1527 out of1904
# has synapse values
# no early spots = 107
# no late spots = 120
# no synapse spots = 109
# Calculating image no 1528 out of1904
# has synapse values
# no early spots = 116
# no late spots = 129
# no synapse spots = 123
# Calculating image no 1529 out of1904
# has synapse values
# no early spots = 158
# no late spots = 150
# no synapse spots = 135
# Calculating image no 1530 out of1904
# has synapse values
# no early spots = 130
# no late spots = 162
# no synapse spots = 148
# Calculating image no 1531 out of1904
# has synapse values
# no early spots = 134
# no late spots = 175
# no synapse spots = 148
# Calculating image no 1532 out of1904
# has synapse values
# no early spots = 151
# no late spots = 178
# no synapse spots = 139
# Calculating image no 1533 out of1904
# has synapse values
# no early spots = 132
# no late spots = 173
# no synapse spots = 124
# Calculating image no 1534 out of1904
# has synapse values
# no early spots = 146
# no late spots = 154
# no synapse spots = 123
# Calculating image no 1535 out of1904
# has synapse values
# no early spots = 175
# no late spots = 176
# no synapse spots = 160
# Calculating image no 1536 out of1904
# has synapse values
# no early spots = 183
# no late spots = 206
# no synapse spots = 136
# Calculating image no 1537 out of1904
# has synapse values
# no early spots = 115
# no late spots = 145
# no synapse spots = 132
# Calculating image no 1538 out of1904
# has synapse values
# no early spots = 130
# no late spots = 143
# no synapse spots = 98
# Calculating image no 1539 out of1904
# has synapse values
# no early spots = 179
# no late spots = 195
# no synapse spots = 140
# Calculating image no 1540 out of1904
# has synapse values
# no early spots = 187
# no late spots = 190
# no synapse spots = 164
# Calculating image no 1541 out of1904
# has synapse values
# no early spots = 168
# no late spots = 200
# no synapse spots = 199
# Calculating image no 1542 out of1904
# has synapse values
# no early spots = 118
# no late spots = 129
# no synapse spots = 177
# Calculating image no 1543 out of1904
# has synapse values
# no early spots = 124
# no late spots = 133
# no synapse spots = 184
# Calculating image no 1544 out of1904
# has synapse values
# no early spots = 127
# no late spots = 138
# no synapse spots = 163
# Calculating image no 1545 out of1904
# has synapse values
# no early spots = 137
# no late spots = 127
# no synapse spots = 170
# Calculating image no 1546 out of1904
# has synapse values
# no early spots = 151
# no late spots = 144
# no synapse spots = 161
# Calculating image no 1547 out of1904
# has synapse values
# no early spots = 122
# no late spots = 118
# no synapse spots = 155
# Calculating image no 1548 out of1904
# has synapse values
# no early spots = 141
# no late spots = 167
# no synapse spots = 179
# Calculating image no 1549 out of1904
# has synapse values
# no early spots = 127
# no late spots = 144
# no synapse spots = 159
# Calculating image no 1550 out of1904
# has synapse values
# no early spots = 102
# no late spots = 128
# no synapse spots = 169
# Calculating image no 1551 out of1904
# has synapse values
# no early spots = 149
# no late spots = 156
# no synapse spots = 149
# Calculating image no 1552 out of1904
# has synapse values
# no early spots = 165
# no late spots = 182
# no synapse spots = 165
# Calculating image no 1553 out of1904
# has synapse values
# no early spots = 107
# no late spots = 104
# no synapse spots = 151
# Calculating image no 1554 out of1904
# has synapse values
# no early spots = 112
# no late spots = 129
# no synapse spots = 108
# Calculating image no 1555 out of1904
# has synapse values
# no early spots = 116
# no late spots = 132
# no synapse spots = 169
# Calculating image no 1556 out of1904
# has synapse values
# no early spots = 155
# no late spots = 151
# no synapse spots = 173
# Calculating image no 1557 out of1904
# has synapse values
# no early spots = 121
# no late spots = 113
# no synapse spots = 131
# Calculating image no 1558 out of1904
# has synapse values
# no early spots = 141
# no late spots = 150
# no synapse spots = 136
# Calculating image no 1559 out of1904
# has synapse values
# no early spots = 197
# no late spots = 206
# no synapse spots = 182
# Calculating image no 1560 out of1904
# has synapse values
# no early spots = 90
# no late spots = 117
# no synapse spots = 116
# Calculating image no 1561 out of1904
# has synapse values
# no early spots = 141
# no late spots = 155
# no synapse spots = 149
# Calculating image no 1562 out of1904
# has synapse values
# no early spots = 114
# no late spots = 117
# no synapse spots = 138
# Calculating image no 1563 out of1904
# has synapse values
# no early spots = 126
# no late spots = 121
# no synapse spots = 140
# Calculating image no 1564 out of1904
# has synapse values
# no early spots = 103
# no late spots = 98
# no synapse spots = 95
# Calculating image no 1565 out of1904
# has synapse values
# no early spots = 150
# no late spots = 146
# no synapse spots = 146
# Calculating image no 1566 out of1904
# has synapse values
# no early spots = 177
# no late spots = 174
# no synapse spots = 167
# Calculating image no 1567 out of1904
# has synapse values
# no early spots = 120
# no late spots = 158
# no synapse spots = 155
# Calculating image no 1568 out of1904
# has synapse values
# no early spots = 150
# no late spots = 171
# no synapse spots = 202
# Calculating image no 1569 out of1904
# has synapse values
# no early spots = 158
# no late spots = 160
# no synapse spots = 170
# Calculating image no 1570 out of1904
# has synapse values
# no early spots = 151
# no late spots = 143
# no synapse spots = 128
# Calculating image no 1571 out of1904
# has synapse values
# no early spots = 91
# no late spots = 126
# no synapse spots = 138
# Calculating image no 1572 out of1904
# has synapse values
# no early spots = 144
# no late spots = 139
# no synapse spots = 145
# Calculating image no 1573 out of1904
# has synapse values
# no early spots = 190
# no late spots = 210
# no synapse spots = 150
# Calculating image no 1574 out of1904
# has synapse values
# no early spots = 127
# no late spots = 132
# no synapse spots = 110
# Calculating image no 1575 out of1904
# has synapse values
# no early spots = 128
# no late spots = 162
# no synapse spots = 137
# Calculating image no 1576 out of1904
# has synapse values
# no early spots = 125
# no late spots = 154
# no synapse spots = 106
# Calculating image no 1577 out of1904
# has synapse values
# no early spots = 128
# no late spots = 151
# no synapse spots = 140
# Calculating image no 1578 out of1904
# has synapse values
# no early spots = 158
# no late spots = 167
# no synapse spots = 135
# Calculating image no 1579 out of1904
# has synapse values
# no early spots = 121
# no late spots = 123
# no synapse spots = 138
# Calculating image no 1580 out of1904
# has synapse values
# no early spots = 159
# no late spots = 181
# no synapse spots = 127
# Calculating image no 1581 out of1904
# has synapse values
# no early spots = 147
# no late spots = 166
# no synapse spots = 128
# Calculating image no 1582 out of1904
# has synapse values
# no early spots = 160
# no late spots = 177
# no synapse spots = 144
# Calculating image no 1583 out of1904
# has synapse values
# no early spots = 125
# no late spots = 124
# no synapse spots = 114
# Calculating image no 1584 out of1904
# has synapse values
# no early spots = 158
# no late spots = 136
# no synapse spots = 119
# Calculating image no 1585 out of1904
# has synapse values
# no early spots = 106
# no late spots = 137
# no synapse spots = 120
# Calculating image no 1586 out of1904
# has synapse values
# no early spots = 142
# no late spots = 136
# no synapse spots = 143
# Calculating image no 1587 out of1904
# has synapse values
# no early spots = 125
# no late spots = 135
# no synapse spots = 133
# Calculating image no 1588 out of1904
# has synapse values
# no early spots = 151
# no late spots = 162
# no synapse spots = 167
# Calculating image no 1589 out of1904
# has synapse values
# no early spots = 82
# no late spots = 106
# no synapse spots = 109
# Calculating image no 1590 out of1904
# has synapse values
# no early spots = 104
# no late spots = 108
# no synapse spots = 135
# Calculating image no 1591 out of1904
# has synapse values
# no early spots = 150
# no late spots = 151
# no synapse spots = 174
# Calculating image no 1592 out of1904
# has synapse values
# no early spots = 139
# no late spots = 143
# no synapse spots = 171
# Calculating image no 1593 out of1904
# has synapse values
# no early spots = 120
# no late spots = 111
# no synapse spots = 121
# Calculating image no 1594 out of1904
# has synapse values
# no early spots = 100
# no late spots = 103
# no synapse spots = 106
# Calculating image no 1595 out of1904
# has synapse values
# no early spots = 103
# no late spots = 115
# no synapse spots = 112
# Calculating image no 1596 out of1904
# has synapse values
# no early spots = 133
# no late spots = 147
# no synapse spots = 115
# Calculating image no 1597 out of1904
# has synapse values
# no early spots = 137
# no late spots = 143
# no synapse spots = 151
# Calculating image no 1598 out of1904
# has synapse values
# no early spots = 135
# no late spots = 184
# no synapse spots = 201
# Calculating image no 1599 out of1904
# has synapse values
# no early spots = 92
# no late spots = 96
# no synapse spots = 99
# Calculating image no 1600 out of1904
# has synapse values
# no early spots = 106
# no late spots = 145
# no synapse spots = 130
# Calculating image no 1601 out of1904
# has synapse values
# no early spots = 114
# no late spots = 118
# no synapse spots = 142
# Calculating image no 1602 out of1904
# has synapse values
# no early spots = 87
# no late spots = 95
# no synapse spots = 144
# Calculating image no 1603 out of1904
# has synapse values
# no early spots = 85
# no late spots = 91
# no synapse spots = 136
# Calculating image no 1604 out of1904
# has synapse values
# no early spots = 141
# no late spots = 139
# no synapse spots = 181
# Calculating image no 1605 out of1904
# has synapse values
# no early spots = 145
# no late spots = 146
# no synapse spots = 168
# Calculating image no 1606 out of1904
# has synapse values
# no early spots = 159
# no late spots = 148
# no synapse spots = 171
# Calculating image no 1607 out of1904
# has synapse values
# no early spots = 117
# no late spots = 123
# no synapse spots = 121
# Calculating image no 1608 out of1904
# has synapse values
# no early spots = 142
# no late spots = 120
# no synapse spots = 165
# Calculating image no 1609 out of1904
# has synapse values
# no early spots = 109
# no late spots = 93
# no synapse spots = 145
# Calculating image no 1610 out of1904
# has synapse values
# no early spots = 106
# no late spots = 130
# no synapse spots = 155
# Calculating image no 1611 out of1904
# has synapse values
# no early spots = 116
# no late spots = 118
# no synapse spots = 151
# Calculating image no 1612 out of1904
# has synapse values
# no early spots = 188
# no late spots = 187
# no synapse spots = 162
# Calculating image no 1613 out of1904
# has synapse values
# no early spots = 176
# no late spots = 165
# no synapse spots = 163
# Calculating image no 1614 out of1904
# has synapse values
# no early spots = 128
# no late spots = 136
# no synapse spots = 150
# Calculating image no 1615 out of1904
# has synapse values
# no early spots = 112
# no late spots = 110
# no synapse spots = 146
# Calculating image no 1616 out of1904
# has synapse values
# no early spots = 235
# no late spots = 230
# no synapse spots = 211
# Calculating image no 1617 out of1904
# has synapse values
# no early spots = 136
# no late spots = 133
# no synapse spots = 116
# Calculating image no 1618 out of1904
# has synapse values
# no early spots = 164
# no late spots = 169
# no synapse spots = 139
# Calculating image no 1619 out of1904
# has synapse values
# no early spots = 144
# no late spots = 120
# no synapse spots = 119
# Calculating image no 1620 out of1904
# has synapse values
# no early spots = 102
# no late spots = 120
# no synapse spots = 143
# Calculating image no 1621 out of1904
# has synapse values
# no early spots = 152
# no late spots = 159
# no synapse spots = 178
# Calculating image no 1622 out of1904
# has synapse values
# no early spots = 130
# no late spots = 114
# no synapse spots = 126
# Calculating image no 1623 out of1904
# has synapse values
# no early spots = 115
# no late spots = 131
# no synapse spots = 145
# Calculating image no 1624 out of1904
# has synapse values
# no early spots = 159
# no late spots = 147
# no synapse spots = 149
# Calculating image no 1625 out of1904
# has synapse values
# no early spots = 123
# no late spots = 132
# no synapse spots = 121
# Calculating image no 1626 out of1904
# has synapse values
# no early spots = 153
# no late spots = 166
# no synapse spots = 160
# Calculating image no 1627 out of1904
# has synapse values
# no early spots = 92
# no late spots = 91
# no synapse spots = 134
# Calculating image no 1628 out of1904
# has synapse values
# no early spots = 99
# no late spots = 101
# no synapse spots = 128
# Calculating image no 1629 out of1904
# has synapse values
# no early spots = 125
# no late spots = 100
# no synapse spots = 96
# Calculating image no 1630 out of1904
# has synapse values
# no early spots = 150
# no late spots = 156
# no synapse spots = 154
# Calculating image no 1631 out of1904
# has synapse values
# no early spots = 119
# no late spots = 130
# no synapse spots = 152
# Calculating image no 1632 out of1904
# has synapse values
# no early spots = 209
# no late spots = 202
# no synapse spots = 198
# Calculating image no 1633 out of1904
# has synapse values
# no early spots = 158
# no late spots = 171
# no synapse spots = 120
# Calculating image no 1634 out of1904
# has synapse values
# no early spots = 135
# no late spots = 131
# no synapse spots = 139
# Calculating image no 1635 out of1904
# has synapse values
# no early spots = 137
# no late spots = 152
# no synapse spots = 159
# Calculating image no 1636 out of1904
# has synapse values
# no early spots = 129
# no late spots = 143
# no synapse spots = 158
# Calculating image no 1637 out of1904
# has synapse values
# no early spots = 180
# no late spots = 150
# no synapse spots = 176
# Calculating image no 1638 out of1904
# has synapse values
# no early spots = 195
# no late spots = 202
# no synapse spots = 204
# Calculating image no 1639 out of1904
# has synapse values
# no early spots = 126
# no late spots = 122
# no synapse spots = 175
# Calculating image no 1640 out of1904
# has synapse values
# no early spots = 137
# no late spots = 171
# no synapse spots = 161
# Calculating image no 1641 out of1904
# has synapse values
# no early spots = 195
# no late spots = 201
# no synapse spots = 182
# Calculating image no 1642 out of1904
# has synapse values
# no early spots = 153
# no late spots = 156
# no synapse spots = 126
# Calculating image no 1643 out of1904
# has synapse values
# no early spots = 198
# no late spots = 216
# no synapse spots = 248
# Calculating image no 1644 out of1904
# has synapse values
# no early spots = 109
# no late spots = 111
# no synapse spots = 174
# Calculating image no 1645 out of1904
# has synapse values
# no early spots = 175
# no late spots = 183
# no synapse spots = 146
# Calculating image no 1646 out of1904
# has synapse values
# no early spots = 165
# no late spots = 194
# no synapse spots = 111
# Calculating image no 1647 out of1904
# has synapse values
# no early spots = 272
# no late spots = 276
# no synapse spots = 175
# Calculating image no 1648 out of1904
# has synapse values
# no early spots = 174
# no late spots = 180
# no synapse spots = 154
# Calculating image no 1649 out of1904
# has synapse values
# no early spots = 147
# no late spots = 162
# no synapse spots = 127
# Calculating image no 1650 out of1904
# has synapse values
# no early spots = 154
# no late spots = 168
# no synapse spots = 172
# Calculating image no 1651 out of1904
# has synapse values
# no early spots = 104
# no late spots = 120
# no synapse spots = 130
# Calculating image no 1652 out of1904
# has synapse values
# no early spots = 162
# no late spots = 153
# no synapse spots = 188
# Calculating image no 1653 out of1904
# has synapse values
# no early spots = 152
# no late spots = 156
# no synapse spots = 162
# Calculating image no 1654 out of1904
# has synapse values
# no early spots = 93
# no late spots = 105
# no synapse spots = 135
# Calculating image no 1655 out of1904
# has synapse values
# no early spots = 151
# no late spots = 172
# no synapse spots = 143
# Calculating image no 1656 out of1904
# has synapse values
# no early spots = 139
# no late spots = 182
# no synapse spots = 155
# Calculating image no 1657 out of1904
# has synapse values
# no early spots = 101
# no late spots = 109
# no synapse spots = 123
# Calculating image no 1658 out of1904
# has synapse values
# no early spots = 170
# no late spots = 183
# no synapse spots = 127
# Calculating image no 1659 out of1904
# has synapse values
# no early spots = 120
# no late spots = 124
# no synapse spots = 130
# Calculating image no 1660 out of1904
# has synapse values
# no early spots = 164
# no late spots = 195
# no synapse spots = 159
# Calculating image no 1661 out of1904
# has synapse values
# no early spots = 136
# no late spots = 142
# no synapse spots = 181
# Calculating image no 1662 out of1904
# has synapse values
# no early spots = 163
# no late spots = 147
# no synapse spots = 154
# Calculating image no 1663 out of1904
# has synapse values
# no early spots = 130
# no late spots = 126
# no synapse spots = 168
# Calculating image no 1664 out of1904
# has synapse values
# no early spots = 185
# no late spots = 176
# no synapse spots = 216
# Calculating image no 1665 out of1904
# has synapse values
# no early spots = 183
# no late spots = 155
# no synapse spots = 188
# Calculating image no 1666 out of1904
# has synapse values
# no early spots = 204
# no late spots = 196
# no synapse spots = 202
# Calculating image no 1667 out of1904
# has synapse values
# no early spots = 213
# no late spots = 178
# no synapse spots = 190
# Calculating image no 1668 out of1904
# has synapse values
# no early spots = 111
# no late spots = 75
# no synapse spots = 152
# Calculating image no 1669 out of1904
# has synapse values
# no early spots = 206
# no late spots = 187
# no synapse spots = 208
# Calculating image no 1670 out of1904
# has synapse values
# no early spots = 208
# no late spots = 204
# no synapse spots = 175
# ...
# Calculating image no 1724 out of1904
# has synapse values
# no early spots = 137
# no late spots = 170
# no synapse spots = 158
# Calculating image no 1725 out of1904
# has synapse values
# no early spots = 114
# no late spots = 135
# no synapse spots = 123
# Calculating image no 1726 out of1904
# has synapse values
# no early spots = 158
# no late spots = 177
# no synapse spots = 146
# Calculating image no 1727 out of1904
# has synapse values
# no early spots = 126
# no late spots = 123
# no synapse spots = 134
# Calculating image no 1728 out of1904
# has synapse values
# no early spots = 147
# no late spots = 166
# no synapse spots = 129
# Calculating image no 1729 out of1904
# has synapse values
# no early spots = 148
# no late spots = 159
# no synapse spots = 166
# Calculating image no 1730 out of1904
# has synapse values
# no early spots = 150
# no late spots = 173
# no synapse spots = 126
# Calculating image no 1731 out of1904
# has synapse values
# no early spots = 210
# no late spots = 220
# no synapse spots = 187
# Calculating image no 1732 out of1904
# has synapse values
# no early spots = 162
# no late spots = 190
# no synapse spots = 110
# Calculating image no 1733 out of1904
# has synapse values
# no early spots = 195
# no late spots = 185
# no synapse spots = 153
# Calculating image no 1734 out of1904
# has synapse values
# no early spots = 162
# no late spots = 200
# no synapse spots = 162
# Calculating image no 1735 out of1904
# has synapse values
# no early spots = 134
# no late spots = 159
# no synapse spots = 172
# Calculating image no 1736 out of1904
# has synapse values
# no early spots = 166
# no late spots = 177
# no synapse spots = 142
# Calculating image no 1737 out of1904
# has synapse values
# no early spots = 152
# no late spots = 140
# no synapse spots = 153
# Calculating image no 1738 out of1904
# has synapse values
# no early spots = 117
# no late spots = 130
# no synapse spots = 152
# Calculating image no 1739 out of1904
# has synapse values
# no early spots = 142
# no late spots = 137
# no synapse spots = 169
# Calculating image no 1740 out of1904
# has synapse values
# no early spots = 143
# no late spots = 151
# no synapse spots = 147
# Calculating image no 1741 out of1904
# has synapse values
# no early spots = 121
# no late spots = 102
# no synapse spots = 115
# Calculating image no 1742 out of1904
# has synapse values
# no early spots = 154
# no late spots = 153
# no synapse spots = 160
# Calculating image no 1743 out of1904
# has synapse values
# no early spots = 184
# no late spots = 171
# no synapse spots = 188
# Calculating image no 1744 out of1904
# has synapse values
# no early spots = 134
# no late spots = 148
# no synapse spots = 125
# Calculating image no 1745 out of1904
# has synapse values
# no early spots = 150
# no late spots = 150
# no synapse spots = 184
# Calculating image no 1746 out of1904
# has synapse values
# no early spots = 117
# no late spots = 110
# no synapse spots = 130
# Calculating image no 1747 out of1904
# has synapse values
# no early spots = 85
# no late spots = 93
# no synapse spots = 112
# Calculating image no 1748 out of1904
# has synapse values
# no early spots = 163
# no late spots = 188
# no synapse spots = 138
# Calculating image no 1749 out of1904
# has synapse values
# no early spots = 131
# no late spots = 146
# no synapse spots = 158
# Calculating image no 1750 out of1904
# has synapse values
# no early spots = 125
# no late spots = 123
# no synapse spots = 119
# Calculating image no 1751 out of1904
# has synapse values
# no early spots = 127
# no late spots = 132
# no synapse spots = 146
# Calculating image no 1752 out of1904
# has synapse values
# no early spots = 97
# no late spots = 78
# no synapse spots = 105
# Calculating image no 1753 out of1904
# has synapse values
# no early spots = 134
# no late spots = 156
# no synapse spots = 141
# Calculating image no 1754 out of1904
# has synapse values
# no early spots = 128
# no late spots = 119
# no synapse spots = 137
# Calculating image no 1755 out of1904
# has synapse values
# no early spots = 135
# no late spots = 130
# no synapse spots = 119
# Calculating image no 1756 out of1904
# has synapse values
# no early spots = 202
# no late spots = 205
# no synapse spots = 170
# Calculating image no 1757 out of1904
# has synapse values
# no early spots = 122
# no late spots = 134
# no synapse spots = 127
# Calculating image no 1758 out of1904
# has synapse values
# no early spots = 140
# no late spots = 111
# no synapse spots = 141
# Calculating image no 1759 out of1904
# has synapse values
# no early spots = 127
# no late spots = 136
# no synapse spots = 161
# Calculating image no 1760 out of1904
# has synapse values
# no early spots = 162
# no late spots = 156
# no synapse spots = 157
# Calculating image no 1761 out of1904
# has synapse values
# no early spots = 165
# no late spots = 295
# no synapse spots = 190
# Calculating image no 1762 out of1904
# has synapse values
# no early spots = 180
# no late spots = 198
# no synapse spots = 154
# Calculating image no 1763 out of1904
# has synapse values
# no early spots = 155
# no late spots = 175
# no synapse spots = 126
# Calculating image no 1764 out of1904
# has synapse values
# no early spots = 114
# no late spots = 130
# no synapse spots = 121
# Calculating image no 1765 out of1904
# has synapse values
# no early spots = 125
# no late spots = 127
# no synapse spots = 124
# Calculating image no 1766 out of1904
# has synapse values
# no early spots = 150
# no late spots = 162
# no synapse spots = 159
# Calculating image no 1767 out of1904
# has synapse values
# no early spots = 179
# no late spots = 232
# no synapse spots = 153
# Calculating image no 1768 out of1904
# has synapse values
# no early spots = 141
# no late spots = 202
# no synapse spots = 135
# Calculating image no 1769 out of1904
# has synapse values
# no early spots = 168
# no late spots = 158
# no synapse spots = 148
# Calculating image no 1770 out of1904
# no early spots = 145
# no late spots = 121
# Calculating image no 1771 out of1904
# no early spots = 91
# no late spots = 88
# Calculating image no 1772 out of1904
# no early spots = 71
# no late spots = 71
# Calculating image no 1773 out of1904
# no early spots = 89
# no late spots = 88
# Calculating image no 1774 out of1904
# no early spots = 181
# no late spots = 158
# Calculating image no 1775 out of1904
# no early spots = 97
# no late spots = 80
# Calculating image no 1776 out of1904
# no early spots = 106
# no late spots = 100
# Calculating image no 1777 out of1904
# no early spots = 138
# no late spots = 124
# Calculating image no 1778 out of1904
# no early spots = 88
# no late spots = 90
# Calculating image no 1779 out of1904
# no early spots = 106
# no late spots = 107
# Calculating image no 1780 out of1904
# no early spots = 166
# no late spots = 147
# Calculating image no 1781 out of1904
# no early spots = 114
# no late spots = 95
# Calculating image no 1782 out of1904
# no early spots = 101
# no late spots = 72
# Calculating image no 1783 out of1904
# no early spots = 111
# no late spots = 109
# Calculating image no 1784 out of1904
# no early spots = 160
# no late spots = 120
# Calculating image no 1785 out of1904
# no early spots = 143
# no late spots = 136
# Calculating image no 1786 out of1904
# no early spots = 111
# no late spots = 90
# Calculating image no 1787 out of1904
# no early spots = 160
# no late spots = 137
# Calculating image no 1788 out of1904
# no early spots = 117
# no late spots = 74
# Calculating image no 1789 out of1904
# no early spots = 106
# no late spots = 100
# Calculating image no 1790 out of1904
# no early spots = 149
# no late spots = 126
# Calculating image no 1791 out of1904
# no early spots = 110
# no late spots = 88
# Calculating image no 1792 out of1904
# no early spots = 126
# no late spots = 94
# Calculating image no 1793 out of1904
# no early spots = 137
# no late spots = 103
# Calculating image no 1794 out of1904
# no early spots = 177
# no late spots = 136
# Calculating image no 1795 out of1904
# no early spots = 100
# no late spots = 83
# Calculating image no 1796 out of1904
# no early spots = 101
# no late spots = 97
# Calculating image no 1797 out of1904
# no early spots = 124
# no late spots = 147
# Calculating image no 1798 out of1904
# no early spots = 92
# no late spots = 83
# Calculating image no 1799 out of1904
# no early spots = 199
# no late spots = 141
# Calculating image no 1800 out of1904
# no early spots = 221
# no late spots = 201
# Calculating image no 1801 out of1904
# no early spots = 156
# no late spots = 132
# Calculating image no 1802 out of1904
# no early spots = 184
# no late spots = 154
# Calculating image no 1803 out of1904
# no early spots = 129
# no late spots = 120
# Calculating image no 1804 out of1904
# no early spots = 122
# no late spots = 108
# Calculating image no 1805 out of1904
# no early spots = 189
# no late spots = 174
# Calculating image no 1806 out of1904
# no early spots = 220
# no late spots = 227
# Calculating image no 1807 out of1904
# no early spots = 103
# no late spots = 109
# Calculating image no 1808 out of1904
# no early spots = 138
# no late spots = 114
# Calculating image no 1809 out of1904
# no early spots = 227
# no late spots = 220
# Calculating image no 1810 out of1904
# no early spots = 206
# no late spots = 204
# Calculating image no 1811 out of1904
# no early spots = 170
# no late spots = 157
# Calculating image no 1812 out of1904
# no early spots = 231
# no late spots = 216
# Calculating image no 1813 out of1904
# no early spots = 163
# no late spots = 154
# Calculating image no 1814 out of1904
# no early spots = 233
# no late spots = 187
# Calculating image no 1815 out of1904
# no early spots = 133
# no late spots = 124
# Calculating image no 1816 out of1904
# no early spots = 216
# no late spots = 198
# Calculating image no 1817 out of1904
# no early spots = 157
# no late spots = 126
# Calculating image no 1818 out of1904
# no early spots = 268
# no late spots = 245
# Calculating image no 1819 out of1904
# no early spots = 184
# no late spots = 151
# Calculating image no 1820 out of1904
# no early spots = 181
# no late spots = 163
# Calculating image no 1821 out of1904
# no early spots = 193
# no late spots = 156
# Calculating image no 1822 out of1904
# no early spots = 172
# no late spots = 155
# Calculating image no 1823 out of1904
# no early spots = 213
# no late spots = 152
# Calculating image no 1824 out of1904
# no early spots = 93
# no late spots = 93
# Calculating image no 1825 out of1904
# no early spots = 179
# no late spots = 154
# Calculating image no 1826 out of1904
# no early spots = 220
# no late spots = 161
# Calculating image no 1827 out of1904
# no early spots = 154
# no late spots = 150
# Calculating image no 1828 out of1904
# no early spots = 207
# no late spots = 185
# Calculating image no 1829 out of1904
# no early spots = 205
# no late spots = 173
# Calculating image no 1830 out of1904
# no early spots = 210
# no late spots = 150
# Calculating image no 1831 out of1904
# no early spots = 209
# no late spots = 152
# Calculating image no 1832 out of1904
# no early spots = 263
# no late spots = 195
# Calculating image no 1833 out of1904
# no early spots = 225
# no late spots = 191
# Calculating image no 1834 out of1904
# no early spots = 190
# no late spots = 130
# Calculating image no 1835 out of1904
# no early spots = 186
# no late spots = 164
# Calculating image no 1836 out of1904
# no early spots = 226
# no late spots = 114
# Calculating image no 1837 out of1904
# no early spots = 158
# no late spots = 131
# Calculating image no 1838 out of1904
# no early spots = 121
# no late spots = 88
# Calculating image no 1839 out of1904
# no early spots = 261
# no late spots = 156
# Calculating image no 1840 out of1904
# no early spots = 228
# no late spots = 184
# Calculating image no 1841 out of1904
# no early spots = 215
# no late spots = 202
# Calculating image no 1842 out of1904
# no early spots = 196
# no late spots = 160
# Calculating image no 1843 out of1904
# no early spots = 221
# no late spots = 145
# Calculating image no 1844 out of1904
# no early spots = 178
# no late spots = 121
# Calculating image no 1845 out of1904
# no early spots = 200
# no late spots = 174
# Calculating image no 1846 out of1904
# no early spots = 93
# no late spots = 70
# Calculating image no 1847 out of1904
# no early spots = 98
# no late spots = 94
# Calculating image no 1848 out of1904
# no early spots = 217
# no late spots = 154
# Calculating image no 1849 out of1904
# no early spots = 173
# no late spots = 141
# Calculating image no 1850 out of1904
# no early spots = 130
# no late spots = 106
# Calculating image no 1851 out of1904
# no early spots = 126
# no late spots = 125
# Calculating image no 1852 out of1904
# no early spots = 130
# no late spots = 126
# Calculating image no 1853 out of1904
# no early spots = 132
# no late spots = 116
# Calculating image no 1854 out of1904
# no early spots = 151
# no late spots = 107
# Calculating image no 1855 out of1904
# no early spots = 160
# no late spots = 117
# Calculating image no 1856 out of1904
# no early spots = 118
# no late spots = 94
# Calculating image no 1857 out of1904
# no early spots = 146
# no late spots = 101
# Calculating image no 1858 out of1904
# no early spots = 216
# no late spots = 163
# Calculating image no 1859 out of1904
# no early spots = 253
# no late spots = 229
# Calculating image no 1860 out of1904
# no early spots = 112
# no late spots = 118
# Calculating image no 1861 out of1904
# no early spots = 104
# no late spots = 71
# Calculating image no 1862 out of1904
# no early spots = 83
# no late spots = 99
# Calculating image no 1863 out of1904
# no early spots = 123
# no late spots = 112
# Calculating image no 1864 out of1904
# no early spots = 133
# no late spots = 127
# Calculating image no 1865 out of1904
# no early spots = 126
# no late spots = 105
# Calculating image no 1866 out of1904
# no early spots = 133
# no late spots = 84
# Calculating image no 1867 out of1904
# no early spots = 111
# no late spots = 93
# Calculating image no 1868 out of1904
# no early spots = 129
# no late spots = 90
# Calculating image no 1869 out of1904
# no early spots = 102
# no late spots = 83
# Calculating image no 1870 out of1904
# no early spots = 102
# no late spots = 86
# Calculating image no 1871 out of1904
# no early spots = 100
# no late spots = 88
# Calculating image no 1872 out of1904
# no early spots = 178
# no late spots = 140
# Calculating image no 1873 out of1904
# no early spots = 103
# no late spots = 100
# Calculating image no 1874 out of1904
# no early spots = 107
# no late spots = 99
# Calculating image no 1875 out of1904
# no early spots = 112
# no late spots = 236
# Calculating image no 1876 out of1904
# no early spots = 209
# no late spots = 181
# Calculating image no 1877 out of1904
# no early spots = 147
# no late spots = 227
# Calculating image no 1878 out of1904
# no early spots = 105
# no late spots = 209
# Calculating image no 1879 out of1904
# no early spots = 81
# no late spots = 238
# Calculating image no 1880 out of1904
# no early spots = 220
# no late spots = 144
# Calculating image no 1881 out of1904
# no early spots = 110
# no late spots = 256
# Calculating image no 1882 out of1904
# no early spots = 104
# no late spots = 297
# Calculating image no 1883 out of1904
# no early spots = 75
# no late spots = 363
# Calculating image no 1884 out of1904
# no early spots = 97
# no late spots = 313
# Calculating image no 1885 out of1904
# no early spots = 118
# no late spots = 88
# Calculating image no 1886 out of1904
# no early spots = 120
# no late spots = 72
# Calculating image no 1887 out of1904
# no early spots = 134
# no late spots = 84
# Calculating image no 1888 out of1904
# no early spots = 137
# no late spots = 82
# Calculating image no 1889 out of1904
# no early spots = 130
# no late spots = 110
# Calculating image no 1890 out of1904
# no early spots = 83
# no late spots = 77
# Calculating image no 1891 out of1904
# no early spots = 67
# no late spots = 59
# Calculating image no 1892 out of1904
# no early spots = 92
# no late spots = 78
# Calculating image no 1893 out of1904
# no early spots = 115
# no late spots = 80
# Calculating image no 1894 out of1904
# no early spots = 150
# no late spots = 106
# Calculating image no 1895 out of1904
# no early spots = 134
# no late spots = 128
# Calculating image no 1896 out of1904
# no early spots = 123
# no late spots = 131
# Calculating image no 1897 out of1904
# no early spots = 108
# no late spots = 106
# Calculating image no 1898 out of1904
# no early spots = 101
# no late spots = 115
# Calculating image no 1899 out of1904
# no early spots = 174
# no late spots = 167
# Calculating image no 1900 out of1904
# no early spots = 77
# no late spots = 84
# Calculating image no 1901 out of1904
# no early spots = 128
# no late spots = 118
# Calculating image no 1902 out of1904
# no early spots = 142
# no late spots = 140
# Calculating image no 1903 out of1904
# no early spots = 104
# no late spots = 105
# Calculating image no 1904 out of1904
# no early spots = 90
# no late spots = 87
# 0

# %%
spots_early_labels,_ = ndi.label(early_spots)
len(np.unique(spots_early_labels))

# %% [markdown]
# ### Plots

# %%
for key in results.keys():
    print(key)
    print(len(results[key]))
# Out:
# filename
# 1904
# earlychannelno
# 1904
# latechannelno
# 1904
# synapsechannelno
# 1904
# Autofluorescencedir
# 1904
# Earlycontroldir
# 1904
# Latecontroldir
# 1904
# Early colour - spots mask
# 1904
# Late colour - spots mask
# 1904
# Late plus early colour - spots mask
# 1904
# Synapse colour - spots mask
# 1904
# exp condition
# 1904
# Early colour - Raw mean intensity
# 1904
# Late colour - Raw mean intensity
# 1904
# Synapse colour - Raw mean intensity
# 1904
# Global Mean colour bias of a pixel (early=-1<x<1=late)
# 1904
# Global Mean colour bias of a pixel (early=-1<x<1=late) Raw
# 1904
# Global Mean colour bias of a pixel (early=-1<x<1=late) Normd
# 1904
# Mean correlation coefficient early/late
# 1904
# Early colour - Mean intensity of spots
# 1904
# Late colour - Mean intensity of spots
# 1904
# Synapse colour - Mean intensity of spots
# 1904
# Early colour - Total no. of spots in FOV
# 1904
# Late colour - Total no. of spots in FOV
# 1904
# Synapse colour - Total no. of spots in FOV
# 1904
# Early colour - Mean spot area [nm]
# 1904
# Late colour - Mean spot area [nm]
# 1904
# Synapse colour - Mean spot area [nm]
# 1904
# Early colour - masked by synapses
# 1904
# Late colour - masked by synapses
# 1904
# Mean colour bias of a pixel (early=-1<x<1=late)
# 1904
# Mean colour bias of a pixel (early=-1<x<1=late) Raw
# 1904
# Mean colour bias of a pixel (early=-1<x<1=late) Normd
# 1904
# Mean colour bias of a pixel (early=-1<x<1=late) Normd Minus AutoF
# 1904
# Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late)
# 1904
# Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Raw
# 1904
# Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd
# 1904
# Early colour/Synapse colour corr (Mean intensity of spots)
# 1904
# Late colour/Synapse colour corr (Mean intensity of spots)
# 1904
# Mean colour bias of a pixel - shifted to pos values (early=0)
# 1904
# Correlation between colour bias (0 shifted) and synapse intensity
# 1904
# Early colour - Mean intensity of spots Normd to ctrls
# 1904
# Late colour - Mean intensity of spots Normd to ctrls
# 1904
# Early colour Normd to ctrl - masked by synapses
# 1904
# Late colour Normd to ctrl - masked by synapses
# 1904
# Mean colour bias of a pixel (early=-1<x<1=late) Normd to ctrls
# 1904
# Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd to ctrls
# 1904
# Early colour - Mean intensity Normd to ctrls
# 1904
# Late colour - Mean intensity Normd to ctrls
# 1904
# Global Mean colour bias of a pixel (early=-1<x<1=late) Normd to ctrls
# 1904
# Early colour/Synapse colour corr (Mean intensity of spots norm to ctrl)
# 1904
# Late colour/Synapse colour corr (Mean intensity of spots norm to ctrl)
# 1904

# %%
df=pd.DataFrame(results)
#dfhists=pd.DataFrame(histogram_results)
#dfregionprops=pd.DataFrame(regionprops_results)
df.to_csv(path_or_buf=expdir+'/results/results.csv')
#dfhists.to_csv(path_or_buf=expdir+'/results/histogram_results_180801.csv')
#dfregionprops.to_csv(path_or_buf=expdir+'/results/regionprops_results_180801.csv')

# %%
for item in results.keys():
    print(item,len(results[item]))

# %%
df=pd.read_csv(expdir+'results/results.csv')
dfhists=pd.read_csv(expdir+'results/histogram_results.csv')

# %%
from matplotlib.backends.backend_pdf import PdfPages
def multipage(filename, figs=None, dpi=200):
    pp = PdfPages(filename)
    if figs is None:
        figs = [plt.figure(n) for n in plt.get_fignums()]
    for fig in figs:
        fig.savefig(pp, format='pdf')
    pp.close()
    
sns.set(font_scale=1.3)

fig1=plt.figure()
d=sns.barplot(x="Early colour - Raw mean intensity", y="exp condition",data=df,ci='sd')
d=sns.swarmplot(x="Early colour - Raw mean intensity", y="exp condition",data=df,color='black')
fig1.savefig(expdir+'/results/plot01_1.png',bbox_inches='tight')
fig=plt.figure() #
ax1=fig.add_subplot(111)
histogrouped=dfhists.groupby('exp condition')["Early colour - Flattened histogram"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Early colour - Flattened histogram"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Early colour - Flattened histogram')
fig.savefig(expdir+'/results/plot01_hist1.png',bbox_inches='tight')
fig=plt.figure() #
ax1=fig.add_subplot(111)
histogrouped=dfhists.groupby('exp condition')["Early colour - Flattened histogram of image normd to internal max"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Early colour - Flattened histogram of image normd to internal max"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Early colour - Flattened histogram of image normd to internal max')
fig.savefig(expdir+'/results/plot01_hist2.png',bbox_inches='tight')
fig3=plt.figure() #
d=sns.barplot(x='Early colour - Mean intensity of spots', y='exp condition',data=df, ci='sd')
d=sns.swarmplot(x="Early colour - Mean intensity of spots", y="exp condition",data=df,color='black')
fig3.savefig(expdir+'/results/plot01_2.png',bbox_inches='tight')
fig6=plt.figure()#
d=sns.barplot(x='Early colour - masked by synapses', y='exp condition',data=df, ci='sd')
d=sns.swarmplot(x="Early colour - masked by synapses", y="exp condition",data=df,color='black')
fig6.savefig(expdir+'/results/plot01_5.png',bbox_inches='tight')
d=sns.barplot(x='Early colour - Total no. of spots in FOV', y='exp condition',data=df, ci='sd')
d=sns.swarmplot(x="Early colour - Total no. of spots in FOV", y="exp condition",data=df,color='black')
fig5.savefig(expdir+'/results/plot01_3.png',bbox_inches='tight')
fig7=plt.figure()
d=sns.barplot(x='Early colour - Mean spot area [nm]', y='exp condition',data=df, ci='sd')
d=sns.swarmplot(x="Early colour - Mean spot area [nm]", y="exp condition",data=df,color='black')
fig7.savefig(expdir+'/results/plot01_4.png',bbox_inches='tight')


fig2=plt.figure()
d=sns.barplot(x='Late colour - Raw mean intensity', y='exp condition',data=df, ci='sd')
d=sns.swarmplot(x="Late colour - Raw mean intensity", y="exp condition",data=df,color='black')
fig2.savefig(expdir+'/results/plot02_1.png',bbox_inches='tight')
fig=plt.figure() #
ax1=fig.add_subplot(111)
histogrouped=dfhists.groupby('exp condition')["Late colour - Flattened histogram"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Late colour - Flattened histogram"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Late colour - Flattened histogram')
fig.savefig(expdir+'/results/plot02_hist1.png',bbox_inches='tight')
fig=plt.figure() #
ax1=fig.add_subplot(111)
histogrouped=dfhists.groupby('exp condition')["Late colour - Flattened histogram of image normd to internal max"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Late colour - Flattened histogram of image normd to internal max"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Late colour - Flattened histogram of image normd to internal max')
fig.savefig(expdir+'/results/plot02_hist2.png',bbox_inches='tight')
fig4=plt.figure() #
d=sns.barplot(x='Late colour - Mean intensity of spots', y='exp condition',data=df, ci='sd')
d=sns.swarmplot(x="Late colour - Mean intensity of spots", y="exp condition",data=df,color='black')
fig4.savefig(expdir+'/results/plot02_2.png',bbox_inches='tight')
fig6=plt.figure()
d=sns.barplot(x='Late colour - masked by synapses', y='exp condition',data=df, ci='sd')
d=sns.swarmplot(x="Late colour - masked by synapses", y="exp condition",data=df,color='black')
fig6.savefig(expdir+'/results/plot02_5.png',bbox_inches='tight')
fig6=plt.figure()
d=sns.barplot(x='Late colour - Total no. of spots in FOV', y='exp condition',data=df, ci='sd')
d=sns.swarmplot(x="Late colour - Total no. of spots in FOV", y="exp condition",data=df,color='black')
fig6.savefig(expdir+'/results/plot02_3.png',bbox_inches='tight')
fig8=plt.figure()
d=sns.barplot(x='Late colour - Mean spot area [nm]', y='exp condition',data=df, ci='sd')
d=sns.swarmplot(x="Late colour - Mean spot area [nm]", y="exp condition",data=df,color='black')
fig8.savefig(expdir+'/results/plot02_4.png',bbox_inches='tight')

fig2_=plt.figure()
d=sns.barplot(x='Synapse colour - Raw mean intensity', y='exp condition',data=df, ci='sd')
d=sns.swarmplot(x="Synapse colour - Raw mean intensity", y="exp condition",data=df,color='black')
fig2_.savefig(expdir+'/results/plot03_1.png',bbox_inches='tight')
fig=plt.figure() #
ax1=fig.add_subplot(111)
histogrouped=dfhists.groupby('exp condition')["Synapse colour - Flattened histogram"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Synapse colour - Flattened histogram"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Synapse colour - Flattened histogram')
fig.savefig(expdir+'/results/plot03_hist1.png',bbox_inches='tight')
fig=plt.figure() #
ax1=fig.add_subplot(111)
histogrouped=dfhists.groupby('exp condition')["Synapse colour - Flattened histogram of image normd to internal max"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Synapse colour - Flattened histogram of image normd to internal max"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Synapse colour - Flattened histogram of image normd to internal max')
fig.savefig(expdir+'/results/plot03_hist2.png',bbox_inches='tight')
fig4_=plt.figure() #
d=sns.barplot(x='Synapse colour - Mean intensity of spots', y='exp condition',data=df, ci='sd')
d=sns.swarmplot(x="Synapse colour - Mean intensity of spots", y="exp condition",data=df,color='black')
fig4_.savefig(expdir+'/results/plot03_2.png',bbox_inches='tight')
fig6_=plt.figure()
d=sns.barplot(x='Synapse colour - Total no. of spots in FOV', y='exp condition',data=df, ci='sd')
d=sns.swarmplot(x="Synapse colour - Total no. of spots in FOV", y="exp condition",data=df,color='black')
fig6_.savefig(expdir+'/results/plot03_3.png',bbox_inches='tight')
fig8_=plt.figure()
d=sns.barplot(x='Synapse colour - Mean spot area [nm]', y='exp condition',data=df, ci='sd')
d=sns.swarmplot(x="Synapse colour - Mean spot area [nm]", y="exp condition",data=df,color='black')
fig8_.savefig(expdir+'/results/plot03_4_.png',bbox_inches='tight')

fig10=plt.figure()
d=sns.barplot(x='Global Mean colour bias of a pixel (early=-1<x<1=late)', y='exp condition',data=df, ci='sd')
d=sns.swarmplot(x='Global Mean colour bias of a pixel (early=-1<x<1=late)', y='exp condition',data=df,color='black')
fig10.savefig(expdir+'/results/plot04.png',bbox_inches='tight')
fig=plt.figure() #
ax1=fig.add_subplot(111)
histogrouped=dfhists.groupby('exp condition')["Global Colour bias of a pixel (early=-1<x<1=late) - Histogram"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Global Colour bias of a pixel (early=-1<x<1=late) - Histogram"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Global Colour bias of a pixel (early=-1<x<1=late) - Histogram')
fig.savefig(expdir+'/results/plot04_hist.png',bbox_inches='tight')
fig10=plt.figure() #
d=sns.barplot(x='Global Mean colour bias of a pixel (early=-1<x<1=late) Raw', y='exp condition',data=df, ci='sd')
d=sns.swarmplot(x='Global Mean colour bias of a pixel (early=-1<x<1=late) Raw', y='exp condition',data=df,color='black')
fig10.savefig(expdir+'/results/plot05.png',bbox_inches='tight')
fig=plt.figure() #
ax1=fig.add_subplot(111)
histogrouped=dfhists.groupby('exp condition')["Global Colour bias of a pixel (early=-1<x<1=late) Raw - Histogram"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Global Colour bias of a pixel (early=-1<x<1=late) Raw - Histogram"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Global Colour bias of a pixel (early=-1<x<1=late) Raw - Histogram')
fig.savefig(expdir+'/results/plot05_hist.png',bbox_inches='tight')
fig10=plt.figure() #
d=sns.barplot(x='Global Mean colour bias of a pixel (early=-1<x<1=late) Normd', y='exp condition',data=df, ci='sd')
d=sns.swarmplot(x='Global Mean colour bias of a pixel (early=-1<x<1=late) Normd', y='exp condition',data=df,color='black')
fig10.savefig(expdir+'/results/plot06.png',bbox_inches='tight')
fig=plt.figure() #
ax1=fig.add_subplot(111)
histogrouped=dfhists.groupby('exp condition')["Global Colour bias of a pixel (early=-1<x<1=late) Normd - Histogram"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Global Colour bias of a pixel (early=-1<x<1=late) Normd - Histogram"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Global Colour bias of a pixel (early=-1<x<1=late) Normd - Histogram')
fig.savefig(expdir+'/results/plot06_hist.png',bbox_inches='tight')
fig10=plt.figure() #
d=sns.barplot(x='Mean colour bias of a pixel (early=-1<x<1=late)', y='exp condition',data=df, ci='sd')
d=sns.swarmplot(x='Mean colour bias of a pixel (early=-1<x<1=late)', y='exp condition',data=df,color='black')
fig10.savefig(expdir+'/results/plot07.png',bbox_inches='tight')
fig=plt.figure() #
ax1=fig.add_subplot(111)
histogrouped=dfhists.groupby('exp condition')["Colour bias of a pixel (early=-1<x<1=late) - Histogram"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Colour bias of a pixel (early=-1<x<1=late) - Histogram"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Colour bias of a pixel (early=-1<x<1=late) - Histogram')
fig.savefig(expdir+'/results/plot07_hist.png',bbox_inches='tight')
fig10=plt.figure() #
d=sns.barplot(x='Mean colour bias of a pixel (early=-1<x<1=late) Raw', y='exp condition',data=df, ci='sd')
d=sns.swarmplot(x='Mean colour bias of a pixel (early=-1<x<1=late) Raw', y='exp condition',data=df,color='black')
fig10.savefig(expdir+'/results/plot08.png',bbox_inches='tight')
fig=plt.figure() #
ax1=fig.add_subplot(111)
histogrouped=dfhists.groupby('exp condition')["Colour bias of a pixel (early=-1<x<1=late) Raw - Histogram"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Colour bias of a pixel (early=-1<x<1=late) Raw - Histogram"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Colour bias of a pixel (early=-1<x<1=late) Raw - Histogram')
fig.savefig(expdir+'/results/plot08_hist.png',bbox_inches='tight')
fig10=plt.figure()#
d=sns.barplot(x='Mean colour bias of a pixel (early=-1<x<1=late) Normd', y='exp condition',data=df, ci='sd')
d=sns.swarmplot(x='Mean colour bias of a pixel (early=-1<x<1=late) Normd', y='exp condition',data=df,color='black')
fig10.savefig(expdir+'/results/plot09.png',bbox_inches='tight')
fig=plt.figure() #
ax1=fig.add_subplot(111)
histogrouped=dfhists.groupby('exp condition')["Colour bias of a pixel (early=-1<x<1=late) Normd - Histogram"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Colour bias of a pixel (early=-1<x<1=late) Normd - Histogram"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Colour bias of a pixel (early=-1<x<1=late) Normd - Histogram')
fig.savefig(expdir+'/results/plot09_hist.png',bbox_inches='tight')
fig10=plt.figure()#
d=sns.barplot(x='Mean colour bias of a pixel (early=-1<x<1=late) Normd Minus AutoF', y='exp condition',data=df, ci='sd')
d=sns.swarmplot(x='Mean colour bias of a pixel (early=-1<x<1=late) Normd Minus AutoF', y='exp condition',data=df,color='black')
fig10.savefig(expdir+'/results/plot10.png',bbox_inches='tight')
fig=plt.figure() #
ax1=fig.add_subplot(111)
histogrouped=dfhists.groupby('exp condition')["Colour bias of a pixel (early=-1<x<1=late) Normd Minus AutoF - Histogram"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Colour bias of a pixel (early=-1<x<1=late) Normd Minus AutoF - Histogram"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Colour bias of a pixel (early=-1<x<1=late) Normd Minus AutoF - Histogram')
fig.savefig(expdir+'/results/plot10_hist.png',bbox_inches='tight')
fig10=plt.figure()#
d=sns.barplot(x='Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late)', y='exp condition',data=df, ci='sd')
d=sns.swarmplot(x='Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late)', y='exp condition',data=df,color='black')
fig10.savefig(expdir+'/results/plot11.png',bbox_inches='tight')
fig=plt.figure() #
ax1=fig.add_subplot(111)
histogrouped=dfhists.groupby('exp condition')["Colour bias of a pixel, masked by synapses (early=-1<x<1=late) - Histogram"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Colour bias of a pixel, masked by synapses (early=-1<x<1=late) - Histogram"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Colour bias of a pixel, masked by synapses (early=-1<x<1=late) - Histogram')
fig.savefig(expdir+'/results/plot11_hist.png',bbox_inches='tight')
fig10=plt.figure()#
d=sns.barplot(x='Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Raw', y='exp condition',data=df, ci='sd')
d=sns.swarmplot(x='Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Raw', y='exp condition',data=df,color='black')
fig10.savefig(expdir+'/results/plot12.png',bbox_inches='tight')
fig=plt.figure() #
ax1=fig.add_subplot(111)
histogrouped=dfhists.groupby('exp condition')["Colour bias of a pixel, masked by synapses (early=-1<x<1=late) Raw - Histogram"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Colour bias of a pixel, masked by synapses (early=-1<x<1=late) Raw - Histogram"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Colour bias of a pixel, masked by synapses (early=-1<x<1=late) Raw - Histogram')
fig.savefig(expdir+'/results/plot12_hist.png',bbox_inches='tight')
fig10=plt.figure()#
d=sns.barplot(x='Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd', y='exp condition',data=df, ci='sd')
d=sns.swarmplot(x='Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd', y='exp condition',data=df,color='black')
fig10.savefig(expdir+'/results/plot13.png',bbox_inches='tight')
fig=plt.figure() #
ax1=fig.add_subplot(111)
histogrouped=dfhists.groupby('exp condition')["Colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd - Histogram"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd - Histogram"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd - Histogram')
fig.savefig(expdir+'/results/plot12_hist.png',bbox_inches='tight')
fig10=plt.figure()#
d=sns.barplot(x='Mean colour bias of a pixel - shifted to pos values (early=0)', y='exp condition',data=df, ci='sd')
d=sns.swarmplot(x='Mean colour bias of a pixel - shifted to pos values (early=0)', y='exp condition',data=df,color='black')
fig10.savefig(expdir+'/results/plot14.png',bbox_inches='tight')
fig10=plt.figure()
d=sns.barplot(x='Early colour/Synapse colour corr (Mean intensity of spots)', y='exp condition',data=df, ci='sd')
d=sns.swarmplot(x='Early colour/Synapse colour corr (Mean intensity of spots)', y='exp condition',data=df,color='black')
fig10.savefig(expdir+'/results/plot15.png',bbox_inches='tight')
fig10=plt.figure()
d=sns.barplot(x='Late colour/Synapse colour corr (Mean intensity of spots)', y='exp condition',data=df, ci='sd')
d=sns.swarmplot(x='Late colour/Synapse colour corr (Mean intensity of spots)', y='exp condition',data=df,color='black')
fig10.savefig(expdir+'/results/plot16.png',bbox_inches='tight')
fig10=plt.figure()
d=sns.barplot(x='Correlation between colour bias (0 shifted) and synapse intensity', y='exp condition',data=df, ci='sd')
d=sns.swarmplot(x='Correlation between colour bias (0 shifted) and synapse intensity', y='exp condition',data=df,color='black')
fig10.savefig(expdir+'/results/plot16.png',bbox_inches='tight')



'''fig10=plt.figure()
Nobic = df[df['exp condition'] == '1Day_DMSO']['Mean colour bias of a pixel (early=-1<x<1=late)']
Bic = df[df['exp condition'] == '1Day_Bic']['Mean colour bias of a pixel (early=-1<x<1=late)']
[stat,pval]=stats.ttest_ind(Nobic, Bic)
print(pval)
d=sns.barplot(x='Mean colour bias of a pixel (early=-1<x<1=late)', y='exp condition',data=df[df['exp condition'].isin(['1Day', '2Day'])], ci='sd')
d=sns.swarmplot(x='Mean colour bias of a pixel (early=-1<x<1=late)', y='exp condition',data=df[df['exp condition'].isin(['1Day', '2Day'])],color='black')
fig10.savefig(expdir+'/results/plot10.png',bbox_inches='tight')'''

'''Nobic = df[df['exp condition'] == '1Day_DMSO']['Mean colour bias of a pixel (early=-1<x<1=late)']
Bic = df[df['exp condition'] == '1Day_Bic']['Mean colour bias of a pixel (early=-1<x<1=late)']
[stat,pval]=stats.ttest_ind(Nobic, Bic)
print(pval)'''

# %% [markdown]
# ### Plot without controls "ctrl" in bla ==false or "Ctrl"

# %%
from copy import deepcopy
df3=deepcopy(df)
df2=deepcopy(df)
#dfhists3=deepcopy(dfhists)
#dfhists2=deepcopy(dfhists)

# %%
df2[df2[""]]

# %%
df2regionprops=deepcopy(dfregionprops)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-a26ced408456> in <module>()
# ----> 1 df2regionprops=deepcopy(dfregionprops)
#
# NameError: name 'dfregionprops' is not defined

# %%
#os.mkdir(expdir+'results_noctrls/')
df2=df2[df2["exp condition"].str.contains('ctrl|Ctrl')==False]
#dfhists2=dfhists2[dfhists2["exp condition"].str.contains('ctrl|Ctrl')==False]
df2=df2[df2["exp condition"].str.contains('TTX')==False]
#dfhists2=dfhists2[dfhists2["exp condition"].str.contains('TTX')==False]
df2.to_csv(path_or_buf=expdir+'/results_noctrls/results.csv')
#dfhists2.to_csv(path_or_buf=expdir+'/results_noctrls/histogram_results.csv')

# %%
#os.mkdir(expdir+'results_noctrls/')
df2regionprops=df2regionprops[df2regionprops["exp condition"].str.contains('ctrl|Ctrl')==False]
df2regionprops=df2regionprops[df2regionprops["exp condition"].str.contains('TTX')==False]

df2regionprops.to_csv(path_or_buf=expdir+'/results_noctrls/results_regionprops.csv')

# %%
df2.to_csv(path_or_buf=expdir+'/results_noctrls/results_180801.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-0d5ed2c3a010> in <module>()
# ----> 1 df2.to_csv(path_or_buf=expdir+'/results_noctrls/results_180801.csv')
#       2
#
# NameError: name 'df2' is not defined

# %%
df=pd.read_csv(expdir+'/results/results.csv')

# %%
df2=pd.read_csv(expdir+'/results_noctrls/results.csv')

# %%
df2=pd.read_csv(expdir+'/results_noctrls/results_180801.csv')

# %%
onedaylabel='17_24hr'
onedaybiclabel='18_24hr_Bic'
onehourlabel='03_01hr'
onehourbiclabel='04_1hr_Bic'
sevenhourlabel='007hr'
sevenhourbiclabel='007hr_Bic'
thirtyminslabel='01_30mis'
thirtyminsbiclabel='02_30mins_Bic'
twohourlabel='05_2hr'
twohourbiclabel='06_2hr_Bic'
sixhourlabel='09_6hr'
sixhourbiclabel='10_6hr_Bic'
ninehourlabel='13_9hr'
ninehourbiclabel='14_9hr_Bic'
threehourlabel='07_3hr'
threehourbiclabel='08_3hr_Bic'
twelvehourlabel='15_12hr'
twelvehourbiclabel='16_12hr_Bic'
eighthourlabel='11_8hr'
eighthourbiclabel='12_8hr_Bic'
twodaylabel='19_48hr'
twodaybiclabel='20_48hr_Bic'
threedaylabel='21_72hr'
threedaybiclabel='22_72hr_Bic'

# %%
df2=df2.replace(to_replace='1Day_Untreated', value=onedaylabel)
df2=df2.replace(to_replace='1DayBic', value=onedaybiclabel)
df2=df2.replace(to_replace='1day_Untreated', value=onedaylabel)
df2=df2.replace(to_replace='1daybic', value=onedaybiclabel)
df2=df2.replace(to_replace='1Day_DMSO', value=onedaylabel)
df2=df2.replace(to_replace='1Day_Bic', value=onedaybiclabel)
df2=df2.replace(to_replace='1hr_DMSO', value=onehourlabel)
df2=df2.replace(to_replace='1hr_Bic', value=onehourbiclabel)
df2=df2.replace(to_replace='7hr_DMSO', value=sevenhourlabel)
df2=df2.replace(to_replace='7hr_Bic', value=sevenhourbiclabel)
df2=df2.replace(to_replace='30mins_DMSO', value=thirtyminslabel)
df2=df2.replace(to_replace='30mins_Bic', value=thirtyminsbiclabel)
df2=df2.replace(to_replace='2hr_DMSO', value=twohourlabel)
df2=df2.replace(to_replace='2hr_Bic', value=twohourbiclabel)
df2=df2.replace(to_replace='6hr_DMSO', value=sixhourlabel)
df2=df2.replace(to_replace='6hr_Bic', value=sixhourbiclabel)
df2=df2.replace(to_replace='9hr_DMSO', value=ninehourlabel)
df2=df2.replace(to_replace='9hr_Bic', value=ninehourbiclabel)
df2=df2.replace(to_replace='3hr_DMSO', value=threehourlabel)
df2=df2.replace(to_replace='3hr_Bic', value=threehourbiclabel)
df2=df2.replace(to_replace='12hr_DMSO', value=twelvehourlabel)
df2=df2.replace(to_replace='12hr_Bic', value=twelvehourbiclabel)
df2=df2.replace(to_replace='8hr_DMSO', value=eighthourlabel)
df2=df2.replace(to_replace='8hr_Bic', value=eighthourbiclabel)
df2=df2.replace(to_replace='2Day', value=twodaylabel)
df2=df2.replace(to_replace='2DayBic', value=twodaybiclabel)
df2=df2.replace(to_replace='3Day', value=threedaylabel)
df2=df2.replace(to_replace='3DayBic', value=threedaybiclabel)

# %%
df2regionprops=df2regionprops.replace(to_replace='1Day_Untreated', value=onedaylabel)
df2regionprops=df2regionprops.replace(to_replace='1DayBic', value=onedaybiclabel)
df2regionprops=df2regionprops.replace(to_replace='1day_Untreated', value=onedaylabel)
df2regionprops=df2regionprops.replace(to_replace='1daybic', value=onedaybiclabel)
df2regionprops=df2regionprops.replace(to_replace='1Day_DMSO', value=onedaylabel)
df2regionprops=df2regionprops.replace(to_replace='1Day_Bic', value=onedaybiclabel)
df2regionprops=df2regionprops.replace(to_replace='1hr_DMSO', value=onehourlabel)
df2regionprops=df2regionprops.replace(to_replace='1hr_Bic', value=onehourbiclabel)
df2regionprops=df2regionprops.replace(to_replace='7hr_DMSO', value=sevenhourlabel)
df2regionprops=df2regionprops.replace(to_replace='7hr_Bic', value=sevenhourbiclabel)
df2regionprops=df2regionprops.replace(to_replace='30mins_DMSO', value=thirtyminslabel)
df2regionprops=df2regionprops.replace(to_replace='30mins_Bic', value=thirtyminsbiclabel)
df2regionprops=df2regionprops.replace(to_replace='2hr_DMSO', value=twohourlabel)
df2regionprops=df2regionprops.replace(to_replace='2hr_Bic', value=twohourbiclabel)
df2regionprops=df2regionprops.replace(to_replace='6hr_DMSO', value=sixhourlabel)
df2regionprops=df2regionprops.replace(to_replace='6hr_Bic', value=sixhourbiclabel)
df2regionprops=df2regionprops.replace(to_replace='9hr_DMSO', value=ninehourlabel)
df2regionprops=df2regionprops.replace(to_replace='9hr_Bic', value=ninehourbiclabel)
df2regionprops=df2regionprops.replace(to_replace='3hr_DMSO', value=threehourlabel)
df2regionprops=df2regionprops.replace(to_replace='3hr_Bic', value=threehourbiclabel)
df2regionprops=df2regionprops.replace(to_replace='12hr_DMSO', value=twelvehourlabel)
df2regionprops=df2regionprops.replace(to_replace='12hr_Bic', value=twelvehourbiclabel)
df2regionprops=df2regionprops.replace(to_replace='8hr_DMSO', value=eighthourlabel)
df2regionprops=df2regionprops.replace(to_replace='8hr_Bic', value=eighthourbiclabel)
df2regionprops=df2regionprops.replace(to_replace='2Day', value=twodaylabel)
df2regionprops=df2regionprops.replace(to_replace='2DayBic', value=twodaybiclabel)
df2regionprops=df2regionprops.replace(to_replace='3Day', value=threedaylabel)
df2regionprops=df2regionprops.replace(to_replace='3DayBic', value=threedaybiclabel)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3e3564597cc8> in <module>()
# ----> 1 df2regionprops=df2regionprops.replace(to_replace='1Day_Untreated', value=onedaylabel)
#       2 df2regionprops=df2regionprops.replace(to_replace='1DayBic', value=onedaybiclabel)
#       3 df2regionprops=df2regionprops.replace(to_replace='1day_Untreated', value=onedaylabel)
#       4 df2regionprops=df2regionprops.replace(to_replace='1daybic', value=onedaybiclabel)
#       5 df2regionprops=df2regionprops.replace(to_replace='1Day_DMSO', value=onedaylabel)
#
# NameError: name 'df2regionprops' is not defined

# %%
dfhists2=dfhists2.replace(to_replace='1Day_Untreated', value=onedaylabel)
dfhists2=dfhists2.replace(to_replace='1DayBic', value=onedaybiclabel)
dfhists2=dfhists2.replace(to_replace='1day_Untreated', value=onedaylabel)
dfhists2=dfhists2.replace(to_replace='1daybic', value=onedaybiclabel)
dfhists2=dfhists2.replace(to_replace='1Day_DMSO', value=onedaylabel)
dfhists2=dfhists2.replace(to_replace='1Day_Bic', value=onedaybiclabel)
dfhists2=dfhists2.replace(to_replace='1hr_DMSO', value=onehourlabel)
dfhists2=dfhists2.replace(to_replace='1hr_Bic', value=onehourbiclabel)
dfhists2=dfhists2.replace(to_replace='7hr_DMSO', value=sevenhourlabel)
dfhists2=dfhists2.replace(to_replace='7hr_Bic', value=sevenhourbiclabel)
dfhists2=dfhists2.replace(to_replace='30mins_DMSO', value=thirtyminslabel)
dfhists2=dfhists2.replace(to_replace='30mins_Bic', value=thirtyminsbiclabel)
dfhists2=dfhists2.replace(to_replace='2hr_DMSO', value=twohourlabel)
dfhists2=dfhists2.replace(to_replace='2hr_Bic', value=twohourbiclabel)
dfhists2=dfhists2.replace(to_replace='6hr_DMSO', value=sixhourlabel)
dfhists2=dfhists2.replace(to_replace='6hr_Bic', value=sixhourbiclabel)
dfhists2=dfhists2.replace(to_replace='9hr_DMSO', value=ninehourlabel)
dfhists2=dfhists2.replace(to_replace='9hr_Bic', value=ninehourbiclabel)
dfhists2=dfhists2.replace(to_replace='3hr_DMSO', value=threehourlabel)
dfhists2=dfhists2.replace(to_replace='3hr_Bic', value=threehourbiclabel)
dfhists2=dfhists2.replace(to_replace='12hr_DMSO', value=twelvehourlabel)
dfhists2=dfhists2.replace(to_replace='12hr_Bic', value=twelvehourbiclabel)
dfhists2=dfhists2.replace(to_replace='8hr_DMSO', value=eighthourlabel)
dfhists2=dfhists2.replace(to_replace='8hr_Bic', value=eighthourbiclabel)
dfhists2=dfhists2.replace(to_replace='2Day', value=twodaylabel)
dfhists2=dfhists2.replace(to_replace='2DayBic', value=twodaybiclabel)
dfhists2=dfhists2.replace(to_replace='3Day', value=threedaylabel)
dfhists2=dfhists2.replace(to_replace='3DayBic', value=threedaybiclabel)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-b13d67a776bf> in <module>()
# ----> 1 dfhists2=dfhists2.replace(to_replace='1Day_Untreated', value=onedaylabel)
#       2 dfhists2=dfhists2.replace(to_replace='1DayBic', value=onedaybiclabel)
#       3 dfhists2=dfhists2.replace(to_replace='1day_Untreated', value=onedaylabel)
#       4 dfhists2=dfhists2.replace(to_replace='1daybic', value=onedaybiclabel)
#       5 dfhists2=dfhists2.replace(to_replace='1Day_DMSO', value=onedaylabel)
#
# NameError: name 'dfhists2' is not defined

# %%
from matplotlib.backends.backend_pdf import PdfPages
def multipage(filename, figs=None, dpi=200):
    pp = PdfPages(filename)
    if figs is None:
        figs = [plt.figure(n) for n in plt.get_fignums()]
    for fig in figs:
        fig.savefig(pp, format='pdf')
    pp.close()
    
sns.set(font_scale=1.3)

fig1=plt.figure(figsize=(30,10))
d=sns.barplot(x="Early colour - Raw mean intensity", y="exp condition",data=df2,ci='sd')
#d=sns.swarmplot(x="Early colour - Raw mean intensity", y="exp condition",data=df2,color='black')
fig1.savefig(expdir+'/results/plot01_1.png',bbox_inches='tight')
fig=plt.figure(figsize=(30,10)) #
ax1=fig.add_subplot(111)
histogrouped=dfhists2.groupby('exp condition')["Early colour - Flattened histogram"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Early colour - Flattened histogram"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Early colour - Flattened histogram')
fig.savefig(expdir+'/results/plot01_hist1.png',bbox_inches='tight')
fig=plt.figure(figsize=(30,10)) #
ax1=fig.add_subplot(111)
histogrouped=dfhists2.groupby('exp condition')["Early colour - Flattened histogram of image normd to internal max"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Early colour - Flattened histogram of image normd to internal max"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Early colour - Flattened histogram of image normd to internal max')
fig.savefig(expdir+'/results/plot01_hist2.png',bbox_inches='tight')
fig3=plt.figure(figsize=(30,10)) #
d=sns.barplot(x='Early colour - Mean intensity of spots', y='exp condition',data=df2, ci='sd')
#d=sns.swarmplot(x="Early colour - Mean intensity of spots", y="exp condition",data=df2,color='black')
fig3.savefig(expdir+'/results/plot01_2.png',bbox_inches='tight')
fig6=plt.figure(figsize=(30,10))#
d=sns.barplot(x='Early colour - masked by synapses', y='exp condition',data=df2.dropna(), ci='sd')
#d=sns.swarmplot(x="Early colour - masked by synapses", y="exp condition",data=df2.dropna(),color='black')
fig6.savefig(expdir+'/results/plot01_5.png',bbox_inches='tight')
fig5=plt.figure(figsize=(30,10))#
d=sns.barplot(x='Early colour - Total no. of spots in FOV', y='exp condition',data=df2, ci='sd')
#d=sns.swarmplot(x="Early colour - Total no. of spots in FOV", y="exp condition",data=df2,color='black')
fig5.savefig(expdir+'/results/plot01_3.png',bbox_inches='tight')
fig7=plt.figure(figsize=(30,10))#
d=sns.barplot(x='Early colour - Mean spot area [nm]', y='exp condition',data=df2, ci='sd')
#d=sns.swarmplot(x="Early colour - Mean spot area [nm]", y="exp condition",data=df2,color='black')
fig7.savefig(expdir+'/results/plot01_4.png',bbox_inches='tight')


fig2=plt.figure(figsize=(30,10))
d=sns.barplot(x='Late colour - Raw mean intensity', y='exp condition',data=df2, ci='sd')
#d=sns.swarmplot(x="Late colour - Raw mean intensity", y="exp condition",data=df2,color='black')
fig2.savefig(expdir+'/results/plot02_1.png',bbox_inches='tight')
fig=plt.figure(figsize=(30,10)) #
ax1=fig.add_subplot(111)
histogrouped=dfhists2.groupby('exp condition')["Late colour - Flattened histogram"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Late colour - Flattened histogram"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Late colour - Flattened histogram')
fig.savefig(expdir+'/results/plot02_hist1.png',bbox_inches='tight')
fig=plt.figure(figsize=(30,10)) #
ax1=fig.add_subplot(111)
histogrouped=dfhists2.groupby('exp condition')["Late colour - Flattened histogram of image normd to internal max"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Late colour - Flattened histogram of image normd to internal max"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Late colour - Flattened histogram of image normd to internal max')
fig.savefig(expdir+'/results/plot02_hist2.png',bbox_inches='tight')
fig4=plt.figure(figsize=(30,10)) #
d=sns.barplot(x='Late colour - Mean intensity of spots', y='exp condition',data=df2, ci='sd')
#d=sns.swarmplot(x="Late colour - Mean intensity of spots", y="exp condition",data=df2,color='black')
fig4.savefig(expdir+'/results/plot02_2.png',bbox_inches='tight')
fig6=plt.figure(figsize=(30,10))
d=sns.barplot(x='Late colour - masked by synapses', y='exp condition',data=df2.dropna(), ci='sd')
#d=sns.swarmplot(x="Late colour - masked by synapses", y="exp condition",data=df2.dropna(),color='black')
fig6.savefig(expdir+'/results/plot02_5.png',bbox_inches='tight')
fig6=plt.figure(figsize=(30,10))
d=sns.barplot(x='Late colour - Total no. of spots in FOV', y='exp condition',data=df2, ci='sd')
#d=sns.swarmplot(x="Late colour - Total no. of spots in FOV", y="exp condition",data=df2,color='black')
fig6.savefig(expdir+'/results/plot02_3.png',bbox_inches='tight')
fig8=plt.figure(figsize=(30,10))
d=sns.barplot(x='Late colour - Mean spot area [nm]', y='exp condition',data=df2, ci='sd')
#d=sns.swarmplot(x="Late colour - Mean spot area [nm]", y="exp condition",data=df2,color='black')
fig8.savefig(expdir+'/results/plot02_4.png',bbox_inches='tight')

fig2_=plt.figure(figsize=(30,10))
d=sns.barplot(x='Synapse colour - Raw mean intensity', y='exp condition',data=df2.dropna(), ci='sd')
#d=sns.swarmplot(x="Synapse colour - Raw mean intensity", y="exp condition",data=df2.dropna(),color='black')
fig2_.savefig(expdir+'/results/plot03_1.png',bbox_inches='tight')
fig=plt.figure(figsize=(30,10)) #
ax1=fig.add_subplot(111)
histogrouped=dfhists2.dropna()
histogrouped=histogrouped.groupby('exp condition')["Synapse colour - Flattened histogram"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Synapse colour - Flattened histogram"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Synapse colour - Flattened histogram')
fig.savefig(expdir+'/results/plot03_hist1.png',bbox_inches='tight')
fig=plt.figure(figsize=(30,10)) #
ax1=fig.add_subplot(111)
histogrouped=dfhists2.dropna()
histogrouped=histogrouped.groupby('exp condition')["Synapse colour - Flattened histogram of image normd to internal max"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Synapse colour - Flattened histogram of image normd to internal max"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Synapse colour - Flattened histogram of image normd to internal max')
fig.savefig(expdir+'/results/plot03_hist2.png',bbox_inches='tight')
fig4_=plt.figure(figsize=(30,10)) #
d=sns.barplot(x='Synapse colour - Mean intensity of spots', y='exp condition',data=df2.dropna(), ci='sd')
#d=sns.swarmplot(x="Synapse colour - Mean intensity of spots", y="exp condition",data=df2.dropna(),color='black')
fig4_.savefig(expdir+'/results/plot03_2.png',bbox_inches='tight')
fig6_=plt.figure(figsize=(30,10))
d=sns.barplot(x='Synapse colour - Total no. of spots in FOV', y='exp condition',data=df2.dropna(), ci='sd')
#d=sns.swarmplot(x="Synapse colour - Total no. of spots in FOV", y="exp condition",data=df2.dropna(),color='black')
fig6_.savefig(expdir+'/results/plot03_3.png',bbox_inches='tight')
fig8_=plt.figure(figsize=(30,10))
d=sns.barplot(x='Synapse colour - Mean spot area [nm]', y='exp condition',data=df2.dropna(), ci='sd')
#d=sns.swarmplot(x="Synapse colour - Mean spot area [nm]", y="exp condition",data=df2.dropna(),color='black')
fig8_.savefig(expdir+'/results/plot03_4_.png',bbox_inches='tight')

fig10=plt.figure(figsize=(30,10))
d=sns.barplot(x='Global Mean colour bias of a pixel (early=-1<x<1=late)', y='exp condition',data=df2, ci='sd')
#d=sns.swarmplot(x='Global Mean colour bias of a pixel (early=-1<x<1=late)', y='exp condition',data=df2,color='black')
fig10.savefig(expdir+'/results/plot04.png',bbox_inches='tight')
fig=plt.figure(figsize=(30,10)) #
ax1=fig.add_subplot(111)
histogrouped=dfhists2.groupby('exp condition')["Global Colour bias of a pixel (early=-1<x<1=late) - Histogram"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Global Colour bias of a pixel (early=-1<x<1=late) - Histogram"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Global Colour bias of a pixel (early=-1<x<1=late) - Histogram')
fig.savefig(expdir+'/results/plot04_hist.png',bbox_inches='tight')
fig10=plt.figure(figsize=(30,10)) #
d=sns.barplot(x='Global Mean colour bias of a pixel (early=-1<x<1=late) Raw', y='exp condition',data=df2, ci='sd')
#d=sns.swarmplot(x='Global Mean colour bias of a pixel (early=-1<x<1=late) Raw', y='exp condition',data=df2,color='black')
fig10.savefig(expdir+'/results/plot05.png',bbox_inches='tight')
fig=plt.figure(figsize=(30,10)) #
ax1=fig.add_subplot(111)
histogrouped=dfhists2.groupby('exp condition')["Global Colour bias of a pixel (early=-1<x<1=late) Raw - Histogram"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Global Colour bias of a pixel (early=-1<x<1=late) Raw - Histogram"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Global Colour bias of a pixel (early=-1<x<1=late) Raw - Histogram')
fig.savefig(expdir+'/results/plot05_hist.png',bbox_inches='tight')
fig10=plt.figure(figsize=(30,10)) #
d=sns.barplot(x='Global Mean colour bias of a pixel (early=-1<x<1=late) Normd', y='exp condition',data=df2, ci='sd')
#d=sns.swarmplot(x='Global Mean colour bias of a pixel (early=-1<x<1=late) Normd', y='exp condition',data=df2,color='black')
fig10.savefig(expdir+'/results/plot06.png',bbox_inches='tight')
fig=plt.figure(figsize=(30,10)) #
ax1=fig.add_subplot(111)
histogrouped=dfhists2.groupby('exp condition')["Global Colour bias of a pixel (early=-1<x<1=late) Normd - Histogram"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Global Colour bias of a pixel (early=-1<x<1=late) Normd - Histogram"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Global Colour bias of a pixel (early=-1<x<1=late) Normd - Histogram')
fig.savefig(expdir+'/results/plot06_hist.png',bbox_inches='tight')
fig10=plt.figure(figsize=(30,10)) #
d=sns.barplot(x='Mean colour bias of a pixel (early=-1<x<1=late)', y='exp condition',data=df2, ci='sd')
#d=sns.swarmplot(x='Mean colour bias of a pixel (early=-1<x<1=late)', y='exp condition',data=df2,color='black')
fig10.savefig(expdir+'/results/plot07.png',bbox_inches='tight')
fig=plt.figure(figsize=(30,10)) #
ax1=fig.add_subplot(111)
histogrouped=dfhists2.groupby('exp condition')["Colour bias of a pixel (early=-1<x<1=late) - Histogram"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Colour bias of a pixel (early=-1<x<1=late) - Histogram"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Colour bias of a pixel (early=-1<x<1=late) - Histogram')
fig.savefig(expdir+'/results/plot07_hist.png',bbox_inches='tight')
fig10=plt.figure(figsize=(30,10)) #
d=sns.barplot(x='Mean colour bias of a pixel (early=-1<x<1=late) Raw', y='exp condition',data=df2, ci='sd')
#d=sns.swarmplot(x='Mean colour bias of a pixel (early=-1<x<1=late) Raw', y='exp condition',data=df2,color='black')
fig10.savefig(expdir+'/results/plot08.png',bbox_inches='tight')
fig=plt.figure(figsize=(30,10)) #
ax1=fig.add_subplot(111)
histogrouped=dfhists2.groupby('exp condition')["Colour bias of a pixel (early=-1<x<1=late) Raw - Histogram"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Colour bias of a pixel (early=-1<x<1=late) Raw - Histogram"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Colour bias of a pixel (early=-1<x<1=late) Raw - Histogram')
fig.savefig(expdir+'/results/plot08_hist.png',bbox_inches='tight')
fig10=plt.figure(figsize=(30,10))#
d=sns.barplot(x='Mean colour bias of a pixel (early=-1<x<1=late) Normd', y='exp condition',data=df2, ci='sd')
#d=sns.swarmplot(x='Mean colour bias of a pixel (early=-1<x<1=late) Normd', y='exp condition',data=df2,color='black')
fig10.savefig(expdir+'/results/plot09.png',bbox_inches='tight')
fig=plt.figure(figsize=(30,10)) #
ax1=fig.add_subplot(111)
histogrouped=dfhists2.groupby('exp condition')["Colour bias of a pixel (early=-1<x<1=late) Normd - Histogram"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Colour bias of a pixel (early=-1<x<1=late) Normd - Histogram"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Colour bias of a pixel (early=-1<x<1=late) Normd - Histogram')
fig.savefig(expdir+'/results/plot09_hist.png',bbox_inches='tight')
fig10=plt.figure(figsize=(30,10))#
d=sns.barplot(x='Mean colour bias of a pixel (early=-1<x<1=late) Normd Minus AutoF', y='exp condition',data=df2, ci='sd')
#d=sns.swarmplot(x='Mean colour bias of a pixel (early=-1<x<1=late) Normd Minus AutoF', y='exp condition',data=df2,color='black')
fig10.savefig(expdir+'/results/plot10.png',bbox_inches='tight')
fig=plt.figure(figsize=(30,10)) #
ax1=fig.add_subplot(111)
histogrouped=dfhists2.groupby('exp condition')["Colour bias of a pixel (early=-1<x<1=late) Normd Minus AutoF - Histogram"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Colour bias of a pixel (early=-1<x<1=late) Normd Minus AutoF - Histogram"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Colour bias of a pixel (early=-1<x<1=late) Normd Minus AutoF - Histogram')
fig.savefig(expdir+'/results/plot10_hist.png',bbox_inches='tight')
fig10=plt.figure(figsize=(30,10))#
d=sns.barplot(x='Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late)', y='exp condition',data=df2.dropna(), ci='sd')
#d=sns.swarmplot(x='Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late)', y='exp condition',data=df2.dropna(),color='black')
fig10.savefig(expdir+'/results/plot11.png',bbox_inches='tight')
fig=plt.figure(figsize=(30,10)) #
ax1=fig.add_subplot(111)
histogrouped=dfhists2.dropna()
histogrouped=histogrouped.groupby('exp condition')["Colour bias of a pixel, masked by synapses (early=-1<x<1=late) - Histogram"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Colour bias of a pixel, masked by synapses (early=-1<x<1=late) - Histogram"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Colour bias of a pixel, masked by synapses (early=-1<x<1=late) - Histogram')
fig.savefig(expdir+'/results/plot11_hist.png',bbox_inches='tight')
fig10=plt.figure(figsize=(30,10))#
d=sns.barplot(x='Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Raw', y='exp condition',data=df2.dropna(), ci='sd')
#d=sns.swarmplot(x='Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Raw', y='exp condition',data=df2.dropna(),color='black')
fig10.savefig(expdir+'/results/plot12.png',bbox_inches='tight')
fig=plt.figure(figsize=(30,10)) #
ax1=fig.add_subplot(111)
histogrouped=dfhists2.dropna()
histogrouped=histogrouped.groupby('exp condition')["Colour bias of a pixel, masked by synapses (early=-1<x<1=late) Raw - Histogram"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Colour bias of a pixel, masked by synapses (early=-1<x<1=late) Raw - Histogram"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Colour bias of a pixel, masked by synapses (early=-1<x<1=late) Raw - Histogram')
fig.savefig(expdir+'/results/plot12_hist.png',bbox_inches='tight')
fig10=plt.figure(figsize=(30,10))#
d=sns.barplot(x='Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd', y='exp condition',data=df2.dropna(), ci='sd')
#d=sns.swarmplot(x='Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd', y='exp condition',data=df2.dropna(),color='black')
fig10.savefig(expdir+'/results/plot13.png',bbox_inches='tight')
fig=plt.figure(figsize=(30,10)) #
ax1=fig.add_subplot(111)
histogrouped=dfhists2.dropna()
histogrouped=histogrouped.groupby('exp condition')["Colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd - Histogram"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
for i in range(len(histogrouped)):
   c=next(color)
   ax1.plot(np.log10(histogrouped["Colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd - Histogram"][i]),c=c,label=histogrouped["exp condition"][i])
ax1.legend(loc='upper right',bbox_to_anchor=(1.8, 1.1))
ax1.set_title('Colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd - Histogram')
fig.savefig(expdir+'/results/plot12_hist.png',bbox_inches='tight')
fig10=plt.figure(figsize=(30,10))#
d=sns.barplot(x='Mean colour bias of a pixel - shifted to pos values (early=0)', y='exp condition',data=df2, ci='sd')
#d=sns.swarmplot(x='Mean colour bias of a pixel - shifted to pos values (early=0)', y='exp condition',data=df2,color='black')
fig10.savefig(expdir+'/results/plot14.png',bbox_inches='tight')
fig10=plt.figure(figsize=(30,10))
d=sns.barplot(x='Early colour/Synapse colour corr (Mean intensity of spots)', y='exp condition',data=df2.dropna(), ci='sd')
#d=sns.swarmplot(x='Early colour/Synapse colour corr (Mean intensity of spots)', y='exp condition',data=df2.dropna(),color='black')
fig10.savefig(expdir+'/results/plot15.png',bbox_inches='tight')
fig10=plt.figure(figsize=(30,10))
d=sns.barplot(x='Late colour/Synapse colour corr (Mean intensity of spots)', y='exp condition',data=df2.dropna(), ci='sd')
#d=sns.swarmplot(x='Late colour/Synapse colour corr (Mean intensity of spots)', y='exp condition',data=df2.dropna(),color='black')
fig10.savefig(expdir+'/results/plot16.png',bbox_inches='tight')
fig10=plt.figure(figsize=(30,10))
d=sns.barplot(x='Correlation between colour bias (0 shifted) and synapse intensity', y='exp condition',data=df2.dropna(), ci='sd')
#d=sns.swarmplot(x='Correlation between colour bias (0 shifted) and synapse intensity', y='exp condition',data=df2.dropna(),color='black')
fig10.savefig(expdir+'/results/plot16.png',bbox_inches='tight')



'''fig10=plt.figure(figsize=(30,10))
Nobic = df2[df2['exp condition'] == '1Day_DMSO']['Mean colour bias of a pixel (early=-1<x<1=late)']
Bic = df2[df2['exp condition'] == '1Day_Bic']['Mean colour bias of a pixel (early=-1<x<1=late)']
[stat,pval]=stats.ttest_ind(Nobic, Bic)
print(pval)
d=sns.barplot(x='Mean colour bias of a pixel (early=-1<x<1=late)', y='exp condition',data=df2[df2['exp condition'].isin(['1Day', '2Day'])], ci='sd')
#d=sns.swarmplot(x='Mean colour bias of a pixel (early=-1<x<1=late)', y='exp condition',data=df2[df2['exp condition'].isin(['1Day', '2Day'])],color='black')
fig10.savefig(expdir+'/results/plot10.png',bbox_inches='tight')'''

'''Nobic = df2[df2['exp condition'] == '1Day_DMSO']['Mean colour bias of a pixel (early=-1<x<1=late)']
Bic = df2[df2['exp condition'] == '1Day_Bic']['Mean colour bias of a pixel (early=-1<x<1=late)']
[stat,pval]=stats.ttest_ind(Nobic, Bic)
print(pval)'''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9b0053a4fa6b> in <module>()
#      16 fig=plt.figure(figsize=(30,10)) #
#      17 ax1=fig.add_subplot(111)
# ---> 18 histogrouped=dfhists2.groupby('exp condition')["Early colour - Flattened histogram"].apply(lambda g: np.mean(g.values.tolist(), axis=0)).reset_index()
#      19 color=iter(cm.rainbow(np.linspace(0,1,len(histogrouped))))
#      20 for i in range(len(histogrouped)):
#
# NameError: name 'dfhists2' is not defined

# %%
#other plots

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'Autofluorescencedir',
#        'Correlation between colour bias (0 shifted) and synapse intensity',
#        'Early colour - Mean intensity Normd to ctrls',
#        'Early colour - Mean intensity of spots',
#        'Early colour - Mean intensity of spots Normd to ctrls',
#        'Early colour - Mean spot area [nm]',
#        'Early colour - Raw mean intensity',
#        'Early colour - Total no. of spots in FOV',
#        'Early colour - masked by synapses', 'Early colour - spots mask',
#        'Early colour Normd to ctrl - masked by synapses',
#        'Early colour/Synapse colour corr (Mean intensity of spots norm to ctrl)',
#        'Early colour/Synapse colour corr (Mean intensity of spots)',
#        'Earlycontroldir',
#        'Global Mean colour bias of a pixel (early=-1<x<1=late)',
#        'Global Mean colour bias of a pixel (early=-1<x<1=late) Normd',
#        'Global Mean colour bias of a pixel (early=-1<x<1=late) Normd to ctrls',
#        'Global Mean colour bias of a pixel (early=-1<x<1=late) Raw',
#        'Late colour - Mean intensity Normd to ctrls',
#        'Late colour - Mean intensity of spots',
#        'Late colour - Mean intensity of spots Normd to ctrls',
#        'Late colour - Mean spot area [nm]', 'Late colour - Raw mean intensity',
#        'Late colour - Total no. of spots in FOV',
#        'Late colour - masked by synapses', 'Late colour - spots mask',
#        'Late colour Normd to ctrl - masked by synapses',
#        'Late colour/Synapse colour corr (Mean intensity of spots norm to ctrl)',
#        'Late colour/Synapse colour corr (Mean intensity of spots)',
#        'Late plus early colour - spots mask', 'Latecontroldir',
#        'Mean colour bias of a pixel (early=-1<x<1=late)',
#        'Mean colour bias of a pixel (early=-1<x<1=late) Normd',
#        'Mean colour bias of a pixel (early=-1<x<1=late) Normd Minus AutoF',
#        'Mean colour bias of a pixel (early=-1<x<1=late) Normd to ctrls',
#        'Mean colour bias of a pixel (early=-1<x<1=late) Raw',
#        'Mean colour bias of a pixel - shifted to pos values (early=0)',
#        'Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late)',
#        'Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd',
#        'Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd to ctrls',
#        'Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Raw',
#        'Mean correlation coefficient early/late',
#        'Synapse colour - Mean intensity of spots',
#        'Synapse colour - Mean spot area [nm]',
#        'Synapse colour - Raw mean intensity',
#        'Synapse colour - Total no. of spots in FOV',
#        'Synapse colour - spots mask', 'earlychannelno', 'exp condition',
#        'filename', 'latechannelno', 'synapsechannelno'],
#       dtype='object')

# %%
vari='Early colour - Mean intensity of spots Normd to ctrls'
mean_1daybic=np.mean(df2[df2['exp condition']==onedaybiclabel][vari])
mean_1day=np.mean(df2[df2['exp condition']==onedaylabel][vari])
mean_1hourbic=np.mean(df2[df2['exp condition']==onehourbiclabel][vari])
mean_1hour=np.mean(df2[df2['exp condition']==onehourlabel][vari])
mean_7hourbic=np.mean(df2[df2['exp condition']==sevenhourbiclabel][vari])
mean_7hour=np.mean(df2[df2['exp condition']==sevenhourlabel][vari])
mean30minbic=np.mean(df2[df2['exp condition']==thirtyminsbiclabel][vari])
mean_30min=np.mean(df2[df2['exp condition']==thirtyminslabel][vari])
#mean_2hourbic=np.mean(df2[df2['exp condition']==twohourbiclabel][vari])
#mean_2hour=np.mean(df2[df2['exp condition']==twohourlabel][vari])
mean_6hourbic=np.mean(df2[df2['exp condition']==sixhourbiclabel][vari])
mean_6hour=np.mean(df2[df2['exp condition']==sixhourlabel][vari])
mean_9hourbic=np.mean(df2[df2['exp condition']==ninehourbiclabel][vari])
mean_9hour=np.mean(df2[df2['exp condition']==ninehourlabel][vari])
mean_3hourbic=np.mean(df2[df2['exp condition']==threehourbiclabel][vari])
mean_3hour=np.mean(df2[df2['exp condition']==threehourlabel][vari])
mean_12hourbic=np.mean(df2[df2['exp condition']==twelvehourbiclabel][vari])
mean_12hour=np.mean(df2[df2['exp condition']==twelvehourlabel][vari])
mean_8hourbic=np.mean(df2[df2['exp condition']==eighthourbiclabel][vari])
mean_8hour=np.mean(df2[df2['exp condition']==eighthourlabel][vari])
mean_48hourbic=np.mean(df2[df2['exp condition']==twodaybiclabel][vari])
mean_48hour=np.mean(df2[df2['exp condition']==twodaylabel][vari])
mean_72hourbic=np.mean(df2[df2['exp condition']==threedaybiclabel][vari])
mean_72hour=np.mean(df2[df2['exp condition']==threedaylabel][vari])


ratiohalfhour=mean30minbic/mean_30min
ratio1hr=mean_1hourbic/mean_1hour
#ratio2hr=mean_2hourbic/mean_2hour
ratio3hr=mean_3hourbic/mean_3hour
ratio6hr=mean_6hourbic/mean_6hour
ratio7hr=mean_7hourbic/mean_7hour
ratio8hr=mean_8hourbic/mean_8hour
ratio9hr=mean_9hourbic/mean_9hour
ratio12hr=mean_12hourbic/mean_12hour
ratio24hr=mean_1daybic/mean_1day
ratio48hr=mean_48hourbic/mean_48hour
ratio72hr=mean_72hourbic/mean_72hour

mean_1day
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-156-4ad77e3e94d6> in <module>()
#      29 ratio1hr=mean_1hourbic/mean_1hour
#      30 #ratio2hr=mean_2hourbic/mean_2hour
# ---> 31 ratio3hr=mean_3hourbic/mean_3hour
#      32 ratio6hr=mean_6hourbic/mean_6hour
#      33 ratio7hr=mean_7hourbic/mean_7hour
#
# ZeroDivisionError: float division by zero

# %%
y=[ratiohalfhour,ratio1hr,ratio2hr,ratio3hr,ratio6hr,ratio7hr,ratio8hr,ratio9hr,ratio12hr,ratio24hr]
x=np.arange(1,len(y)+1)
labels=['30mins','1','2','3','6','7','8','9','12','24']
plt.bar(x,height=np.log(y))
plt.xticks(x,labels)
plt.title('Bic induced shift of late colour bias')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-053602fc05f0> in <module>()
# ----> 1 y=[ratiohalfhour,ratio1hr,ratio2hr,ratio3hr,ratio6hr,ratio7hr,ratio8hr,ratio9hr,ratio12hr,ratio24hr]
#       2 x=np.arange(1,len(y)+1)
#       3 labels=['30mins','1','2','3','6','7','8','9','12','24']
#       4 plt.bar(x,height=np.log(y))
#       5 plt.xticks(x,labels)
#
# NameError: name 'ratio2hr' is not defined

# %%
df2['Time']='None'
df2.loc[df2['exp condition'].str.contains('30'), 'Time'] = '30mins'
df2.loc[df2['exp condition'].str.contains('1hr'), 'Time'] = '1hr'
df2.loc[df2['exp condition'].str.contains('2hr'), 'Time'] = '2hr'
df2.loc[df2['exp condition'].str.contains('3hr'), 'Time'] = '3hr'
df2.loc[df2['exp condition'].str.contains('6hr'), 'Time'] = '6hr'
df2.loc[df2['exp condition'].str.contains('7hr'), 'Time'] = '7hr'
df2.loc[df2['exp condition'].str.contains('8hr'), 'Time'] = '8hr'
df2.loc[df2['exp condition'].str.contains('9hr'), 'Time'] = '9hr'
df2.loc[df2['exp condition'].str.contains('12hr'), 'Time'] = '12hr'
df2.loc[df2['exp condition'].str.contains('24hr'), 'Time'] = '24hr'

# %%
df2regionprops['Time']='None'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('30'), 'Time'] = '30mins'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('1hr'), 'Time'] = '1hr'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('2hr'), 'Time'] = '2hr'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('3hr'), 'Time'] = '3hr'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('6hr'), 'Time'] = '6hr'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('7hr'), 'Time'] = '7hr'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('8hr'), 'Time'] = '8hr'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('9hr'), 'Time'] = '9hr'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('12hr'), 'Time'] = '12hr'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('24hr'), 'Time'] = '24hr'
df2regionprops['Timeframe']='None'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('30'), 'Timeframe'] = np.nan
df2regionprops.loc[df2regionprops['exp condition'].str.contains('1hr'), 'Timeframe'] = '1-3hrs'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('2hr'), 'Timeframe'] = '1-3hrs'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('3hr'), 'Timeframe'] = '1-3hrs'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('6hr'), 'Timeframe'] = '6-9hrs'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('7hr'), 'Timeframe'] = '6-9hrs'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('8hr'), 'Timeframe'] = '6-9hrs'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('9hr'), 'Timeframe'] = '6-9hrs'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('12hr'), 'Timeframe'] = '12hrs'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('24hr'), 'Timeframe'] = '24hrs'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-5d541b7741c1> in <module>()
# ----> 1 df2regionprops['Time']='None'
#       2 df2regionprops.loc[df2regionprops['exp condition'].str.contains('30'), 'Time'] = '30mins'
#       3 df2regionprops.loc[df2regionprops['exp condition'].str.contains('1hr'), 'Time'] = '1hr'
#       4 df2regionprops.loc[df2regionprops['exp condition'].str.contains('2hr'), 'Time'] = '2hr'
#       5 df2regionprops.loc[df2regionprops['exp condition'].str.contains('3hr'), 'Time'] = '3hr'
#
# NameError: name 'df2regionprops' is not defined

# %%
df2['Timeframe']='None'
df2.loc[df2['exp condition'].str.contains('30'), 'Timeframe'] = np.nan
df2.loc[df2['exp condition'].str.contains('1hr'), 'Timeframe'] = '1-3hrs'
df2.loc[df2['exp condition'].str.contains('2hr'), 'Timeframe'] = '1-3hrs'
df2.loc[df2['exp condition'].str.contains('3hr'), 'Timeframe'] = '1-3hrs'
df2.loc[df2['exp condition'].str.contains('6hr'), 'Timeframe'] = '6-9hrs'
df2.loc[df2['exp condition'].str.contains('7hr'), 'Timeframe'] = '6-9hrs'
df2.loc[df2['exp condition'].str.contains('8hr'), 'Timeframe'] = '6-9hrs'
df2.loc[df2['exp condition'].str.contains('9hr'), 'Timeframe'] = '6-9hrs'
df2.loc[df2['exp condition'].str.contains('12hr'), 'Timeframe'] = '12hrs'
df2.loc[df2['exp condition'].str.contains('24hr'), 'Timeframe'] = '24hrs'

# %%
df2['Drug']='None'
df2.loc[df2['exp condition'].str.contains('Bic'), 'Drug'] = 'Bic'

# %%
df2regionprops['Drug']='None'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('Bic'), 'Drug'] = 'Bic'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-160-cb533658c9cb> in <module>()
# ----> 1 df2regionprops['Drug']='None'
#       2 df2regionprops.loc[df2regionprops['exp condition'].str.contains('Bic'), 'Drug'] = 'Bic'
#
# NameError: name 'df2regionprops' is not defined

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'Autofluorescencedir',
#        'Correlation between colour bias (0 shifted) and synapse intensity',
#        'Early colour - Mean intensity Normd to ctrls',
#        'Early colour - Mean intensity of spots',
#        'Early colour - Mean intensity of spots Normd to ctrls',
#        'Early colour - Mean spot area [nm]',
#        'Early colour - Raw mean intensity',
#        'Early colour - Total no. of spots in FOV',
#        'Early colour - masked by synapses', 'Early colour - spots mask',
#        'Early colour Normd to ctrl - masked by synapses',
#        'Early colour/Synapse colour corr (Mean intensity of spots norm to ctrl)',
#        'Early colour/Synapse colour corr (Mean intensity of spots)',
#        'Earlycontroldir',
#        'Global Mean colour bias of a pixel (early=-1<x<1=late)',
#        'Global Mean colour bias of a pixel (early=-1<x<1=late) Normd',
#        'Global Mean colour bias of a pixel (early=-1<x<1=late) Normd to ctrls',
#        'Global Mean colour bias of a pixel (early=-1<x<1=late) Raw',
#        'Late colour - Mean intensity Normd to ctrls',
#        'Late colour - Mean intensity of spots',
#        'Late colour - Mean intensity of spots Normd to ctrls',
#        'Late colour - Mean spot area [nm]', 'Late colour - Raw mean intensity',
#        'Late colour - Total no. of spots in FOV',
#        'Late colour - masked by synapses', 'Late colour - spots mask',
#        'Late colour Normd to ctrl - masked by synapses',
#        'Late colour/Synapse colour corr (Mean intensity of spots norm to ctrl)',
#        'Late colour/Synapse colour corr (Mean intensity of spots)',
#        'Late plus early colour - spots mask', 'Latecontroldir',
#        'Mean colour bias of a pixel (early=-1<x<1=late)',
#        'Mean colour bias of a pixel (early=-1<x<1=late) Normd',
#        'Mean colour bias of a pixel (early=-1<x<1=late) Normd Minus AutoF',
#        'Mean colour bias of a pixel (early=-1<x<1=late) Normd to ctrls',
#        'Mean colour bias of a pixel (early=-1<x<1=late) Raw',
#        'Mean colour bias of a pixel - shifted to pos values (early=0)',
#        'Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late)',
#        'Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd',
#        'Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd to ctrls',
#        'Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Raw',
#        'Mean correlation coefficient early/late',
#        'Synapse colour - Mean intensity of spots',
#        'Synapse colour - Mean spot area [nm]',
#        'Synapse colour - Raw mean intensity',
#        'Synapse colour - Total no. of spots in FOV',
#        'Synapse colour - spots mask', 'earlychannelno', 'exp condition',
#        'filename', 'latechannelno', 'synapsechannelno', 'Time', 'Timeframe',
#        'Drug'],
#       dtype='object')

# %%
len(df2[(df2["Drug"]=="None") & (df2["Timeframe"]=="24hrs")])
# Out:
# 202

# %%
vari="Late colour - Raw mean intensity"

'''mean30minbic=df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="30mins")].mean()
n30minbic=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="30mins")])
mean30min=df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="30mins")].mean()
n30min=len(df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="30mins")])

mean_1hourbic=df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="1hr")].mean()
n1hrbic=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="1hr")])
mean_1hour=df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="1hr")].mean()
n1hr=len(df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="1hr")])

mean_2hourbic=df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="2hr")].mean()
n2hrbic=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="2hr")])
mean_2hour=df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="2hr")].mean()
n2hr=len(df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="2hr")])

mean_3hourbic=df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="3hr")].mean()
n3hrbic=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="3hr")])
mean_3hour=df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="3hr")].mean()
n3hr=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="3hr")])

mean_6hourbic=df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="6hr")].mean()
n6hrbic=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="6hr")])
mean_6hour=df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="6hr")].mean()
n6hr=len(df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="6hr")])

mean_7hourbic=df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="7hr")].mean()
n7hrbic=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="7hr")])
mean_7hour=df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="7hr")].mean()
n7hr=len(df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="7hr")])

mean_8hourbic=df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="8hr")].mean()
n8hrbic=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="8hr")])
mean_8hour=df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="8hr")].mean()
n8hr=len(df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="8hr")])

mean_9hourbic=df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="9hr")].mean()
n9hrbic=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="9hr")])
mean_9hour=df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="9hr")].mean()
n9hr=len(df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="9hr")])

mean_12hourbic=df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="12hr")].mean()
n12hrbic=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="12hr")])
mean_12hour=df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="12hr")].mean()
n12hr=len(df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="12hr")])

mean_24hourbic=df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="24hr")].mean()
n24hrbic=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="24hr")])
mean_24hour=df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="24hr")].mean()
n24hr=len(df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="24hr")])'''

mean1to3bic=df2[vari][(df2["Drug"]=="Bic") & (df2["Timeframe"]=="1-3hrs")].mean()
n1to3bic=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Timeframe"]=="1-3hrs")])
mean1to3=df2[vari][(df2["Drug"]=="None") & (df2["Timeframe"]=="1-3hrs")].mean()
n1to3=len(df2[vari][(df2["Drug"]=="None") & (df2["Timeframe"]=="1-3hrs")])
mean6to9bic=df2[vari][(df2["Drug"]=="Bic") & (df2["Timeframe"]=="6-9hrs")].mean()
n6to9bic=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Timeframe"]=="6-9hrs")])
mean6to9=df2[vari][(df2["Drug"]=="None") & (df2["Timeframe"]=="6-9hrs")].mean()
n6to9=len(df2[vari][(df2["Drug"]=="None") & (df2["Timeframe"]=="6-9hrs")])
mean12bic=df2[vari][(df2["Drug"]=="Bic") & (df2["Timeframe"]=="12hrs")].mean()
n12bic=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Timeframe"]=="12hrs")])
mean12=df2[vari][(df2["Drug"]=="None") & (df2["Timeframe"]=="12hrs")].mean()
n12=len(df2[vari][(df2["Drug"]=="None") & (df2["Timeframe"]=="12hrs")])
mean24bic=df2[vari][(df2["Drug"]=="Bic") & (df2["Timeframe"]=="24hrs")].mean()
n24bic=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Timeframe"]=="24hrs")])
mean24=df2[vari][(df2["Drug"]=="None") & (df2["Timeframe"]=="24hrs")].mean()
n24=len(df2[vari][(df2["Drug"]=="None") & (df2["Timeframe"]=="24hrs")])
ratio1to3=mean1to3bic/mean1to3
ratio6to9=mean6to9bic/mean6to9
#ratio12=mean12bic/mean12
ratio24=mean24bic/mean24



diff30=mean30minbic-mean30min
diff1=mean_1hourbic-mean_1hour
diff2=mean_2hourbic-mean_2hour
diff3=mean_3hourbic-mean_3hour
diff6=mean_6hourbic-mean_6hour
diff7=mean_7hourbic-mean_7hour
diff8=mean_8hourbic-mean_8hour
diff9=mean_9hourbic-mean_9hour
diff12=mean_12hourbic-mean_12hour
diff24=mean_24hourbic-mean_24hour

'''ratiohalfhour=mean30minbic/mean30min
ratio1hr=mean_1hourbic/mean_1hour
#ratio2hr=mean_2hourbic/mean_2hour
ratio3hr=mean_3hourbic/mean_3hour
ratio6hr=mean_6hourbic/mean_6hour
ratio7hr=mean_7hourbic/mean_7hour
ratio8hr=mean_8hourbic/mean_8hour
ratio9hr=mean_9hourbic/mean_9hour
ratio12hr=mean_12hourbic/mean_12hour
ratio24hr=mean_24hourbic/mean_24hour'''

twofoldchange_halfhour=np.log2(mean30minbic)-np.log2(mean30min)
twofoldchange_1hr=np.log2(mean_1hourbic)-np.log2(mean_1hour)
twofoldchange_2hr=np.log2(mean_2hourbic)-np.log2(mean_2hour)
twofoldchange_3hr=np.log2(mean_3hourbic)-np.log2(mean_3hour)
twofoldchange_6hr=np.log2(mean_6hourbic)-np.log2(mean_6hour)
twofoldchange_7hr=np.log2(mean_7hourbic)-np.log2(mean_7hour)
twofoldchange_8hr=np.log2(mean_8hourbic)-np.log2(mean_8hour)
twofoldchange_9hr=np.log2(mean_9hourbic)-np.log2(mean_9hour)
twofoldchange_12hr=np.log2(mean_12hourbic)-np.log2(mean_12hour)
twofoldchange_24hr=np.log2(mean_24hourbic)-np.log2(mean_24hour)


#ns=[n1hr+n1hrbic,n2hr+n2hrbic,n3hr+n3hrbic,n6hr+n6hrbic,n7hr+n7hrbic,n8hr+n8hrbic,n9hr+n9hrbic,n12hr+n12hrbic,n24hr+n24hrbic]
ns=[n1to3bic+n1to3,n6to9bic+n6to9,n24+n24bic]

print(ratiohalfhour,ratio1hr,ratio2hr,ratio3hr,mean_2hour,mean_3hourbic,mean_3hour,mean_6hourbic,mean_6hour,
     mean_7hourbic,mean_7hour,mean_8hourbic,mean_8hour,mean_9hourbic,mean_9hour,mean_12hourbic,mean_12hour,
     mean_24hourbic,mean_24hour)

print(twofoldchange_halfhour,twofoldchange_1hr,twofoldchange_2hr,twofoldchange_3hr,twofoldchange_6hr,
     twofoldchange_7hr,twofoldchange_8hr,twofoldchange_9hr,twofoldchange_12hr,twofoldchange_24hr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-7ac1f5ced50d> in <module>()
#      74
#      75
# ---> 76 diff30=mean30minbic-mean30min
#      77 diff1=mean_1hourbic-mean_1hour
#      78 diff2=mean_2hourbic-mean_2hour
#
# NameError: name 'mean30min' is not defined

# %%
y1 = np.log2([ratio1to3,ratio6to9,ratio12hr,ratio24hr])
print(y1)
# Out:
# [ 0.19756489 -0.21211017         nan         nan]

# %%
sns.set(style="white", context="talk")
# Set up the matplotlib figure
f, ax1 = plt.subplots(1, 1, figsize=(9, 5))

# Generate some sequential data
y2 = np.log2([ratio1hr,ratio2hr,ratio3hr,ratio6hr,ratio7hr,ratio8hr,ratio9hr,ratio12hr,ratio24hr])
#labels=['1hr','2hr','3hr','6hr','7hr','8hr','9hr','12hr','24hr']
labels=['1-3hrs','6-9hrs','24hrs']
y1 = ([twofoldchange_1hr,twofoldchange_2hr,twofoldchange_3hr,twofoldchange_6hr,
     twofoldchange_7hr,twofoldchange_8hr,twofoldchange_9hr,twofoldchange_24hr])
y1=([diff1,diff2,diff3,diff6,diff7,diff8,diff9,diff12,diff24])
y3 = np.log2([ratio1to3,ratio6to9,ratio24])


x1 = np.array(labels)
sns.barplot(x=x1, y=y3, palette="GnBu_d", ax=ax1)
ax1.axhline(0, color="k", clip_on=False)
ax1.set_ylabel("log(Bic/Ctrl)")
plt.xticks(rotation=45)
ax1.set_title('Bic-induced change in '+vari)
ax1.set_ylim(top=np.max(y3)+0.2,bottom=np.min(y3)-0.2)
#ax1.set_xlim(left=0,right=5)
ax2=plt.bar(x=np.arange(0,len(y3)),height=y3,visible=False)
counter=0
for i in ax2:
    samples=ns[counter]
    counter=counter+1
    height=i.get_height()
    print(height)
    ax1.text(i.get_x() + i.get_width()/2.0, height+np.sign(height)*0.05, str(samples), ha='center',va='bottom',
             fontsize=15,fontstyle='italic')

sns.despine(bottom=True)
plt.tight_layout(h_pad=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-175-0842de212779> in <module>()
#       4
#       5 # Generate some sequential data
# ----> 6 y2 = np.log2([ratio1hr,ratio2hr,ratio3hr,ratio6hr,ratio7hr,ratio8hr,ratio9hr,ratio12hr,ratio24hr])
#       7 #labels=['1hr','2hr','3hr','6hr','7hr','8hr','9hr','12hr','24hr']
#       8 labels=['1-3hrs','6-9hrs','24hrs']
#
# NameError: name 'ratio2hr' is not defined

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'Autofluorescencedir',
#        'Correlation between colour bias (0 shifted) and synapse intensity',
#        'Early colour - Mean intensity Normd to ctrls',
#        'Early colour - Mean intensity of spots',
#        'Early colour - Mean intensity of spots Normd to ctrls',
#        'Early colour - Mean spot area [nm]',
#        'Early colour - Raw mean intensity',
#        'Early colour - Total no. of spots in FOV',
#        'Early colour - masked by synapses', 'Early colour - spots mask',
#        'Early colour Normd to ctrl - masked by synapses',
#        'Early colour/Synapse colour corr (Mean intensity of spots norm to ctrl)',
#        'Early colour/Synapse colour corr (Mean intensity of spots)',
#        'Earlycontroldir',
#        'Global Mean colour bias of a pixel (early=-1<x<1=late)',
#        'Global Mean colour bias of a pixel (early=-1<x<1=late) Normd',
#        'Global Mean colour bias of a pixel (early=-1<x<1=late) Normd to ctrls',
#        'Global Mean colour bias of a pixel (early=-1<x<1=late) Raw',
#        'Late colour - Mean intensity Normd to ctrls',
#        'Late colour - Mean intensity of spots',
#        'Late colour - Mean intensity of spots Normd to ctrls',
#        'Late colour - Mean spot area [nm]', 'Late colour - Raw mean intensity',
#        'Late colour - Total no. of spots in FOV',
#        'Late colour - masked by synapses', 'Late colour - spots mask',
#        'Late colour Normd to ctrl - masked by synapses',
#        'Late colour/Synapse colour corr (Mean intensity of spots norm to ctrl)',
#        'Late colour/Synapse colour corr (Mean intensity of spots)',
#        'Late plus early colour - spots mask', 'Latecontroldir',
#        'Mean colour bias of a pixel (early=-1<x<1=late)',
#        'Mean colour bias of a pixel (early=-1<x<1=late) Normd',
#        'Mean colour bias of a pixel (early=-1<x<1=late) Normd Minus AutoF',
#        'Mean colour bias of a pixel (early=-1<x<1=late) Normd to ctrls',
#        'Mean colour bias of a pixel (early=-1<x<1=late) Raw',
#        'Mean colour bias of a pixel - shifted to pos values (early=0)',
#        'Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late)',
#        'Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd',
#        'Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd to ctrls',
#        'Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Raw',
#        'Mean correlation coefficient early/late',
#        'Synapse colour - Mean intensity of spots',
#        'Synapse colour - Mean spot area [nm]',
#        'Synapse colour - Raw mean intensity',
#        'Synapse colour - Total no. of spots in FOV',
#        'Synapse colour - spots mask', 'earlychannelno', 'exp condition',
#        'filename', 'latechannelno', 'synapsechannelno', 'Time', 'Timeframe',
#        'Drug'],
#       dtype='object')

# %%
def expname(x):
    return("/".join(x.split("/")[:-2]))

# %%
df2=df2.drop(columns=['Unnamed: 0'])

# %%
df2.head()
# Out:
#   Autofluorescencedir  \
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
#
#    Correlation between colour bias (0 shifted) and synapse intensity  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Early colour - Mean intensity Normd to ctrls  \
# 0                                      0.488173
# 1                                      0.475664
# 2                                      0.474806
# 3                                      0.601526
# 4                                      0.669915
#
#    Early colour - Mean intensity of spots  \
# 0                                0.027979
# 1                                0.031037
# 2                                0.031481
# 3                                0.045113
# 4                                0.045734
#
#    Early colour - Mean intensity of spots Normd to ctrls  \
# 0                                           0.425376
# 1                                           0.471874
# 2                                           0.478620
# 3                                           0.685870
# 4                                           0.695313
#
#    Early colour - Mean spot area [nm]  Early colour - Raw mean intensity  \
# 0                          795.725191                         526.045177
# 1                          409.684466                         512.566029
# 2                          410.487310                         511.641884
# 3                          582.555556                         648.192471
# 4                          846.658537                         721.887157
#
#    Early colour - Total no. of spots in FOV  \
# 0                                       131
# 1                                       206
# 2                                       197
# 3                                       162
# 4                                       123
#
#    Early colour - masked by synapses  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#                            Early colour - spots mask   ...     earlychannelno  \
# 0  [[ True  True  True ... False False False]\n [...   ...                  2
# 1  [[False False False ...  True  True  True]\n [...   ...                  2
# 2  [[False False False ...  True  True  True]\n [...   ...                  2
# 3  [[ True  True  True ...  True  True  True]\n [...   ...                  2
# 4  [[False False False ... False False False]\n [...   ...                  2
#
#    exp condition                                           filename  \
# 0    18_24hr_Bic  /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/C...
# 1    18_24hr_Bic  /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/C...
# 2    18_24hr_Bic  /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/C...
# 3    18_24hr_Bic  /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/C...
# 4    18_24hr_Bic  /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/C...
#
#   latechannelno  synapsechannelno  Time  Timeframe  Drug  channeldir  expdate
# 0             1                 0  24hr      24hrs   Bic
# 1             1                 0  24hr      24hrs   Bic
# 2             1                 0  24hr      24hrs   Bic
# 3             1                 0  24hr      24hrs   Bic
# 4             1                 0  24hr      24hrs   Bic
#
# [5 rows x 57 columns]

# %%
df2["expdate"]=df2.apply(lambda row: expname(row["filename"]),axis=1)

# %%
df2["expdate"].unique()
# Out:
# array(['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180602_Turnover_Bic_Timepoints_nb635first_580second_use',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180214_Turnover_Bic_TNR_nb580first_nb653psecond_use',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180620_Turnover_Bic_TNR_Timepoints_nb635first_580second_use',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180705_Turnover_Bic_TNR_Timepoints_nb580first_635second_use',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use'],
#       dtype=object)

# %%
df2=df2.append({'Timeframe':'Total','Early colour - Mean intensity Normd to ctrls':1.,'Late colour - Mean intensity Normd to ctrls':1.,'Drug':'Bic'},ignore_index=True)

# %%
df2['Early colour - Mean intensity of spots norm2max'] = df2["Early colour - Mean intensity of spots"]/df2.groupby(["expid"])["Early colour - Mean intensity of spots"].transform('max')
df2['Late colour - Mean intensity of spots norm2max'] = df2["Late colour - Mean intensity of spots"]/df2.groupby(["expid"])["Late colour - Mean intensity of spots"].transform('max')

# %%
df2[df2["Late colour - Mean intensity Normd to ctrls"]>1].iloc[100]["Latecontroldir"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-56feba107ec2> in <module>()
# ----> 1 df2[df2["Late colour - Mean intensity Normd to ctrls"]>1].iloc[100]["Latecontroldir"]
#
# NameError: name 'df2' is not defined

# %%
df2.loc[df2['expdate'].str.contains("20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use"), 'expid'] = "20180220"
df2.loc[df2['expdate'].str.contains("20180511_Turnover_Bic_nb580first_635psecond_use/TNR"), 'expid'] = "20180511"
df2.loc[df2['expdate'].str.contains("20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second"), 'expid'] = "20180710_TP"
df2.loc[df2['expdate'].str.contains("20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second"), 'expid'] = "20180710_TP2"
df2.loc[df2['expdate'].str.contains("20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR"), 'expid'] = "20180501"
df2.loc[df2['expdate'].str.contains("20180602_Turnover_Bic_Timepoints_nb635first_580second_use"), 'expid'] = "20180602_TP"
df2.loc[df2['expdate'].str.contains("20180214_Turnover_Bic_TNR_nb580first_nb653psecond_use"), 'expid'] = "20180214"
df2.loc[df2['expdate'].str.contains("20180620_Turnover_Bic_TNR_Timepoints_nb635first_580second_use"), 'expid'] = "20180620_TP"
df2.loc[df2['expdate'].str.contains("20180705_Turnover_Bic_TNR_Timepoints_nb580first_635second_use"), 'expid'] = "20180705_TP"
df2.loc[df2['expdate'].str.contains("20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use"), 'expid'] = "20180426"

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'Autofluorescencedir',
#        'Correlation between colour bias (0 shifted) and synapse intensity',
#        'Early colour - Mean intensity Normd to ctrls',
#        'Early colour - Mean intensity of spots',
#        'Early colour - Mean intensity of spots Normd to ctrls',
#        'Early colour - Mean spot area [nm]',
#        'Early colour - Raw mean intensity',
#        'Early colour - Total no. of spots in FOV',
#        'Early colour - masked by synapses', 'Early colour - spots mask',
#        'Early colour Normd to ctrl - masked by synapses',
#        'Early colour/Synapse colour corr (Mean intensity of spots norm to ctrl)',
#        'Early colour/Synapse colour corr (Mean intensity of spots)',
#        'Earlycontroldir',
#        'Global Mean colour bias of a pixel (early=-1<x<1=late)',
#        'Global Mean colour bias of a pixel (early=-1<x<1=late) Normd',
#        'Global Mean colour bias of a pixel (early=-1<x<1=late) Normd to ctrls',
#        'Global Mean colour bias of a pixel (early=-1<x<1=late) Raw',
#        'Late colour - Mean intensity Normd to ctrls',
#        'Late colour - Mean intensity of spots',
#        'Late colour - Mean intensity of spots Normd to ctrls',
#        'Late colour - Mean spot area [nm]', 'Late colour - Raw mean intensity',
#        'Late colour - Total no. of spots in FOV',
#        'Late colour - masked by synapses', 'Late colour - spots mask',
#        'Late colour Normd to ctrl - masked by synapses',
#        'Late colour/Synapse colour corr (Mean intensity of spots norm to ctrl)',
#        'Late colour/Synapse colour corr (Mean intensity of spots)',
#        'Late plus early colour - spots mask', 'Latecontroldir',
#        'Mean colour bias of a pixel (early=-1<x<1=late)',
#        'Mean colour bias of a pixel (early=-1<x<1=late) Normd',
#        'Mean colour bias of a pixel (early=-1<x<1=late) Normd Minus AutoF',
#        'Mean colour bias of a pixel (early=-1<x<1=late) Normd to ctrls',
#        'Mean colour bias of a pixel (early=-1<x<1=late) Raw',
#        'Mean colour bias of a pixel - shifted to pos values (early=0)',
#        'Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late)',
#        'Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd',
#        'Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd to ctrls',
#        'Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Raw',
#        'Mean correlation coefficient early/late',
#        'Synapse colour - Mean intensity of spots',
#        'Synapse colour - Mean spot area [nm]',
#        'Synapse colour - Raw mean intensity',
#        'Synapse colour - Total no. of spots in FOV',
#        'Synapse colour - spots mask', 'earlychannelno', 'exp condition',
#        'filename', 'latechannelno', 'synapsechannelno', 'Time', 'Timeframe',
#        'Drug', 'expdate', 'expid',
#        'Early colour - Mean intensity of spots norm2mean',
#        'Late colour - Mean intensity of spots norm2mean',
#        'Early colour - Mean intensity of spots norm2max',
#        'Late colour - Mean intensity of spots norm2max'],
#       dtype='object')

# %%
vari="Early colour - Mean intensity of spots Normd to ctrls"
vari2="Late colour - Mean intensity of spots Normd to ctrls"


sns.set(font_scale=1)


#orderlab=['30mins','1hr','2hr','3hr','6hr','7hr','8hr','9hr','12hr','24hr']
orderlab=['Total','1-3hrs','6-9hrs','24hrs']
orderlabfull=['1hr','2hr','3hr','6hr','7hr','8hr','9hr','12hr','24hr']
fig10=plt.figure(figsize=(30,20))#

#sns.pointplot('size', 'total_bill', 'sex', tips, dodge=True)
d=sns.pointplot(y=vari, x='Timeframe',data=df2[(df2["expid"].str.contains("TP"))&(df2["Drug"]=="Bic")],hue='expid',
                 ci=None,
                 order=orderlab)
d=sns.pointplot(y=vari, x='Timeframe',data=df2[(df2["expid"].str.contains("TP"))&(df2["Drug"]=="None")],hue='expid',
                 ci=None,
                 order=orderlab,)

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'Autofluorescencedir',
#        'Correlation between colour bias (0 shifted) and synapse intensity',
#        'Early colour - Mean intensity Normd to ctrls',
#        'Early colour - Mean intensity of spots',
#        'Early colour - Mean intensity of spots Normd to ctrls',
#        'Early colour - Mean spot area [nm]',
#        'Early colour - Raw mean intensity',
#        'Early colour - Total no. of spots in FOV',
#        'Early colour - masked by synapses', 'Early colour - spots mask',
#        'Early colour Normd to ctrl - masked by synapses',
#        'Early colour/Synapse colour corr (Mean intensity of spots norm to ctrl)',
#        'Early colour/Synapse colour corr (Mean intensity of spots)',
#        'Earlycontroldir',
#        'Global Mean colour bias of a pixel (early=-1<x<1=late)',
#        'Global Mean colour bias of a pixel (early=-1<x<1=late) Normd',
#        'Global Mean colour bias of a pixel (early=-1<x<1=late) Normd to ctrls',
#        'Global Mean colour bias of a pixel (early=-1<x<1=late) Raw',
#        'Late colour - Mean intensity Normd to ctrls',
#        'Late colour - Mean intensity of spots',
#        'Late colour - Mean intensity of spots Normd to ctrls',
#        'Late colour - Mean spot area [nm]', 'Late colour - Raw mean intensity',
#        'Late colour - Total no. of spots in FOV',
#        'Late colour - masked by synapses', 'Late colour - spots mask',
#        'Late colour Normd to ctrl - masked by synapses',
#        'Late colour/Synapse colour corr (Mean intensity of spots norm to ctrl)',
#        'Late colour/Synapse colour corr (Mean intensity of spots)',
#        'Late plus early colour - spots mask', 'Latecontroldir',
#        'Mean colour bias of a pixel (early=-1<x<1=late)',
#        'Mean colour bias of a pixel (early=-1<x<1=late) Normd',
#        'Mean colour bias of a pixel (early=-1<x<1=late) Normd Minus AutoF',
#        'Mean colour bias of a pixel (early=-1<x<1=late) Normd to ctrls',
#        'Mean colour bias of a pixel (early=-1<x<1=late) Raw',
#        'Mean colour bias of a pixel - shifted to pos values (early=0)',
#        'Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late)',
#        'Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd',
#        'Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Normd to ctrls',
#        'Mean colour bias of a pixel, masked by synapses (early=-1<x<1=late) Raw',
#        'Mean correlation coefficient early/late',
#        'Synapse colour - Mean intensity of spots',
#        'Synapse colour - Mean spot area [nm]',
#        'Synapse colour - Raw mean intensity',
#        'Synapse colour - Total no. of spots in FOV',
#        'Synapse colour - spots mask', 'earlychannelno', 'exp condition',
#        'filename', 'latechannelno', 'synapsechannelno', 'Time', 'Timeframe',
#        'Drug', 'expdate', 'expid',
#        'Early colour - Mean intensity of spots norm2mean',
#        'Late colour - Mean intensity of spots norm2mean',
#        'Early colour - Mean intensity of spots norm2max',
#        'Late colour - Mean intensity of spots norm2max'],
#       dtype='object')

# %%
vari="Early colour - Mean intensity Normd to ctrls"

vari2="Late colour - Mean intensity Normd to ctrls"

sns.set(font_scale=1)

early1to3=df2[df2["Timeframe"]=="1-3hrs"][vari]
late1to3=df2[df2["Timeframe"]=="1-3hrs"][vari2]
early6to9=df2[df2["Timeframe"]=="6-9hrs"][vari]
late6to9=df2[df2["Timeframe"]=="6-9hrs"][vari2]
early24=df2[df2["Timeframe"]=="24hrs"][vari]
late24=df2[df2["Timeframe"]=="24hrs"][vari2]

earlyBic1to3=df2[(df2["Drug"]=="Bic")&(df2["Timeframe"]=="1-3hrs")][vari]
earlyNoBic1to3=df2[(df2["Drug"]=="None")&(df2["Timeframe"]=="1-3hrs")][vari]
lateBic1to3=df2[(df2["Drug"]=="Bic")&(df2["Timeframe"]=="1-3hrs")][vari2]
lateNoBic1to3=df2[(df2["Drug"]=="None")&(df2["Timeframe"]=="1-3hrs")][vari2]
earlyBic6to9=df2[(df2["Drug"]=="Bic")&(df2["Timeframe"]=="6-9hrs")][vari]
earlyNoBic6to9=df2[(df2["Drug"]=="None")&(df2["Timeframe"]=="6-9hrs")][vari]
lateBic6to9=df2[(df2["Drug"]=="Bic")&(df2["Timeframe"]=="6-9hrs")][vari2]
lateNoBic6to9=df2[(df2["Drug"]=="None")&(df2["Timeframe"]=="6-9hrs")][vari2]
earlyBic24=df2[(df2["Drug"]=="Bic")&(df2["Timeframe"]=="24hrs")][vari]
earlyNoBic24=df2[(df2["Drug"]=="None")&(df2["Timeframe"]=="24hrs")][vari]
lateBic24=df2[(df2["Drug"]=="Bic")&(df2["Timeframe"]=="24hrs")][vari2]
lateNoBic24=df2[(df2["Drug"]=="None")&(df2["Timeframe"]=="24hrs")][vari2]
#all
#orderlab=['30mins','1hr','2hr','3hr','6hr','7hr','8hr','9hr','12hr','24hr']
orderlab=['Total','1-3hrs','6-9hrs','24hrs']
orderlabfull=['1hr','2hr','3hr','6hr','7hr','8hr','9hr','12hr','24hr']

fig10=plt.figure(figsize=(10,10))#
fig10.add_subplot(221)
d=sns.barplot(y=vari, x='Timeframe',data=df2,ci=None,
                 order=orderlab)
plt.errorbar(x=[1,2,3],
             y=[early1to3.mean(),early6to9.mean(),early24.mean()],
             yerr=[early1to3.sem(),early6to9.sem(),early24.sem()],xerr=None,ecolor='orange',fmt='none',capsize=2)

fig10.add_subplot(222)
d=sns.barplot(y=vari2, x='Timeframe',data=df2,ci=None,
                 order=orderlab)
plt.errorbar(x=[1,2,3],
             y=[late1to3.mean(),late6to9.mean(),late24.mean()],
             yerr=[late1to3.sem(),late6to9.sem(),late24.sem()],xerr=None,ecolor='orange',fmt='none',capsize=2)

fig10.add_subplot(223)
d=sns.barplot(y=vari, x='Timeframe',data=df2,hue="Drug",hue_order=["None","Bic"],ci=None,
                 order=orderlab)
plt.errorbar(x=[.8,1.2,1.8,2.2,2.8,3.2],
             y=[earlyNoBic1to3.mean(),earlyBic1to3.mean(),earlyNoBic6to9.mean(),earlyBic6to9.mean(),earlyNoBic24.mean(),earlyBic24.mean()],
             yerr=[earlyNoBic1to3.sem(),earlyBic1to3.sem(),earlyNoBic6to9.sem(),earlyBic6to9.sem(),earlyNoBic24.sem(),earlyBic24.sem()],
             xerr=None,ecolor='orange',fmt='none',capsize=2)

fig10.add_subplot(224)
d=sns.barplot(y=vari2, x='Timeframe',data=df2,hue="Drug",hue_order=["None","Bic"],ci=None,
                 order=orderlab)
plt.errorbar(x=[.8,1.2,1.8,2.2,2.8,3.2],
             y=[lateNoBic1to3.mean(),lateBic1to3.mean(),lateNoBic6to9.mean(),lateBic6to9.mean(),lateNoBic24.mean(),lateBic24.mean()],
             yerr=[lateNoBic1to3.sem(),lateBic1to3.sem(),lateNoBic6to9.sem(),lateBic6to9.sem(),lateNoBic24.sem(),lateBic24.sem()],
             xerr=None,ecolor='orange',fmt='none',capsize=2)
# Out:
# <Container object of 3 artists>

# %%
vari="Early colour - Mean intensity of spots Normd to ctrls"

vari2="Late colour - Mean intensity of spots Normd to ctrls"


sns.set(font_scale=2)


#orderlab=['30mins','1hr','2hr','3hr','6hr','7hr','8hr','9hr','12hr','24hr']
orderlab=['Total','1-3hrs','6-9hrs','24hrs']
orderlabfull=['1hr','2hr','3hr','6hr','7hr','8hr','9hr','12hr','24hr']
fig10=plt.figure(figsize=(30,20))#
fig10.add_subplot(121)
#sns.pointplot('size', 'total_bill', 'sex', tips, dodge=True)
d=sns.catplot(y=vari, x='Time',data=df2[df2["expdate"].str.contains("Timepoints")],hue='Drug',
                 hue_order=['None','Bic'],ci=None,
                 split=True,order=orderlabfull,legend_out=True)

NoBic0=1
Bic0=1
Bic1to3=df2[(df2["Drug"]=="Bic")&(df2["Timeframe"]=="1-3hrs")][vari]
NoBic1to3=df2[(df2["Drug"]=="None")&(df2["Timeframe"]=="1-3hrs")][vari]
Bic6to9=df2[(df2["Drug"]=="Bic")&(df2["Timeframe"]=="6-9hrs")][vari]
NoBic6to9=df2[(df2["Drug"]=="None")&(df2["Timeframe"]=="6-9hrs")][vari]
#Bic12=df2[(df2["Drug"]=="Bic")&(df2["Timeframe"]=="12hrs")][vari]
#NoBic12=df2[(df2["Drug"]=="None")&(df2["Timeframe"]=="12hrs")][vari]
Bic24=df2[(df2["Drug"]=="Bic")&(df2["Timeframe"]=="24hrs")][vari]
NoBic24=df2[(df2["Drug"]=="None")&(df2["Timeframe"]=="24hrs")][vari]

yerrorsbic=[Bic1to3.sem(),Bic6to9.sem(),Bic24.sem()]
yerrorsnobic=[NoBic1to3.sem(),NoBic6to9.sem(),NoBic24.sem()]

plt.errorbar(x=[1,2,3],
             y=[Bic1to3.mean(),Bic6to9.mean(),Bic24.mean()],
             yerr=yerrorsbic,xerr=None,ecolor='orange',fmt='none',capsize=2)
plt.errorbar(x=[1,2,3],
             y=[NoBic1to3.mean(),NoBic6to9.mean(),NoBic24.mean()],
             yerr=yerrorsnobic,xerr=None,ecolor='blue',fmt='none',capsize=2)

fig10.add_subplot(122)
d=sns.pointplot(y=vari2, x='Time',data=df2[df2["expdate"].str.contains("Timepoints")],hue='Drug',
                 hue_order=['None','Bic'],ci=None,
                 split=True,order=orderlabfull,legend_out=True,row="expdate")

NoBic0=1
Bic0=1
aBic1to3=df2[(df2["Drug"]=="Bic")&(df2["Timeframe"]=="1-3hrs")][vari2]
aNoBic1to3=df2[(df2["Drug"]=="None")&(df2["Timeframe"]=="1-3hrs")][vari2]
aBic6to9=df2[(df2["Drug"]=="Bic")&(df2["Timeframe"]=="6-9hrs")][vari2]
aNoBic6to9=df2[(df2["Drug"]=="None")&(df2["Timeframe"]=="6-9hrs")][vari2]
aBic12=df2[(df2["Drug"]=="Bic")&(df2["Timeframe"]=="12hrs")][vari]
aNoBic12=df2[(df2["Drug"]=="None")&(df2["Timeframe"]=="12hrs")][vari]
aBic24=df2[(df2["Drug"]=="Bic")&(df2["Timeframe"]=="24hrs")][vari2]
aNoBic24=df2[(df2["Drug"]=="None")&(df2["Timeframe"]=="24hrs")][vari2]

yerrorsbic=[aBic1to3.sem(),aBic6to9.sem(),aBic24.sem()]
yerrorsnobic=[aNoBic1to3.sem(),aNoBic6to9.sem(),aNoBic24.sem()]

plt.errorbar(x=[1,2,3],
             y=[aBic1to3.mean(),aBic6to9.mean(),aBic24.mean()],
             yerr=yerrorsbic,xerr=None,ecolor='orange',fmt='none',capsize=2)
plt.errorbar(x=[1,2,3],
             y=[aNoBic1to3.mean(),aNoBic6to9.mean(),aNoBic24.mean()],
             yerr=yerrorsnobic,xerr=None,ecolor='blue',fmt='none',capsize=2)
# Out:
# /anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:2775: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# <Container object of 3 artists>

# %%
df2[df2["Timeframe"]=="24hrs"]["Earlycontroldir"][0]

# %%
vari1="Late colour - Mean intensity Normd to ctrls"
vari2="Synapse colour - Mean intensity of spots"

sns.set(font_scale=1)


#orderlab=['30mins','1hr','2hr','3hr','6hr','7hr','8hr','9hr','12hr','24hr']
orderlab=['1-3hrs','6-9hrs','12hrs','24hrs']
plt.figure(figsize=(60,30)) #
#sns.pointplot('size', 'total_bill', 'sex', tips, dodge=True)
d=sns.relplot(x=vari1, y=vari2,col="Timeframe",data=df2,
                  hue='Drug',col_order=orderlab)

# %%
sns.set(font_scale=1)
varib="Mean colour bias of a pixel (early=-1<x<1=late) Normd to ctrls"

orderlab=['30mins','1hr','2hr','3hr','6hr','7hr','8hr','9hr','12hr','24hr']

fig10=plt.figure(figsize=(4,4)) #
#sns.pointplot('size', 'total_bill', 'sex', tips, dodge=True)
d=sns.barplot(y=varib, x='Drug',data=df2[df2["Timeframe"]=="24hrs"],ci=90,)
Nobic = df2[(df2["Timeframe"]=="24hrs") & (df2["Drug"]=="None")][varib]
Bic = df2[(df2["Timeframe"]=="24hrs") & (df2["Drug"]=="Bic")][varib]
[stat,pval]=stats.ttest_ind(Nobic, Bic,nan_policy='omit')
print(pval)
x1, x2 = 0, 1   # columns 'HFS' and 'LFS'
y, h, col = df2[df2["Timeframe"]=="24hrs"][varib].mean() + 0.15, 0.001, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
if pval<0.001:
    plt.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col)
elif pval<0.01:
    plt.text((x1+x2)*.5, y+h, "**", ha='center', va='bottom', color=col)
elif pval<0.05:
    plt.text((x1+x2)*.5, y+h, "*", ha='center', va='bottom', color=col)
else:
    plt.text((x1+x2)*.5, y+h, "ns", ha='center', va='bottom', color=col)
# Out:
# 0.5676761175199059

# %%
sns.set(font_scale=2)


orderlab=['30mins','1hr','2hr','3hr','6hr','7hr','8hr','9hr','12hr','24hr']

fig10=plt.figure(figsize=(30,10)) #
#sns.pointplot('size', 'total_bill', 'sex', tips, dodge=True)
d=sns.pointplot(y='Late colour - Raw mean intensity', x='Time',data=df2,hue='Drug',
                 order=orderlab,hue_order=['None','Bic'],
                 split=True)
#d=sns.swarmplot(x='Mean colour bias of a pixel (early=-1<x<1=late) Raw', y='exp condition',data=df2,color='black')

# %%
sns.set(font_scale=2)


orderlab=['30mins','1hr','2hr','3hr','6hr','7hr','8hr','9hr','12hr','24hr']

fig10=plt.figure(figsize=(30,10)) #
#sns.pointplot('size', 'total_bill', 'sex', tips, dodge=True)
d=sns.pointplot(y='Late colour - Mean intensity of spots', x='Time',data=df2,hue='Drug',
                 order=orderlab,hue_order=['None','Bic'],
                 split=True)
#d=sns.swarmplot(x='Mean colour bias of a pixel (early=-1<x<1=late) Raw', y='exp condition',data=df2,color='black')

# %%
mean_1daybic=np.mean(df2[df2['exp condition']==onedaybiclabel]['Late colour - Mean intensity of spots'])
mean_1day=np.mean(df2[df2['exp condition']==onedaylabel]['Late colour - Mean intensity of spots'])
mean_1hourbic=np.mean(df2[df2['exp condition']==onehourbiclabel]['Late colour - Mean intensity of spots'])
mean_1hour=np.mean(df2[df2['exp condition']==onehourlabel]['Late colour - Mean intensity of spots'])
mean_7hourbic=np.mean(df2[df2['exp condition']==sevenhourbiclabel]['Late colour - Mean intensity of spots'])
mean_7hour=np.mean(df2[df2['exp condition']==sevenhourlabel]['Late colour - Mean intensity of spots'])
mean30minbic=np.mean(df2[df2['exp condition']==thirtyminsbiclabel]['Late colour - Mean intensity of spots'])
mean_30min=np.mean(df2[df2['exp condition']==thirtyminslabel]['Late colour - Mean intensity of spots'])
mean_2hourbic=np.mean(df2[df2['exp condition']==twohourbiclabel]['Late colour - Mean intensity of spots'])
mean_2hour=np.mean(df2[df2['exp condition']==twohourlabel]['Late colour - Mean intensity of spots'])
mean_6hourbic=np.mean(df2[df2['exp condition']==sixhourbiclabel]['Late colour - Mean intensity of spots'])
mean_6hour=np.mean(df2[df2['exp condition']==sixhourlabel]['Late colour - Mean intensity of spots'])
mean_9hourbic=np.mean(df2[df2['exp condition']==ninehourbiclabel]['Late colour - Mean intensity of spots'])
mean_9hour=np.mean(df2[df2['exp condition']==ninehourlabel]['Late colour - Mean intensity of spots'])
mean_3hourbic=np.mean(df2[df2['exp condition']==threehourbiclabel]['Late colour - Mean intensity of spots'])
mean_3hour=np.mean(df2[df2['exp condition']==threehourlabel]['Late colour - Mean intensity of spots'])
mean_12hourbic=np.mean(df2[df2['exp condition']==twelvehourbiclabel]['Late colour - Mean intensity of spots'])
mean_12hour=np.mean(df2[df2['exp condition']==twelvehourlabel]['Late colour - Mean intensity of spots'])
mean_8hourbic=np.mean(df2[df2['exp condition']==eighthourbiclabel]['Late colour - Mean intensity of spots'])
mean_8hour=np.mean(df2[df2['exp condition']==eighthourlabel]['Late colour - Mean intensity of spots'])
mean_48hourbic=np.mean(df2[df2['exp condition']==twodaybiclabel]['Late colour - Mean intensity of spots'])
mean_48hour=np.mean(df2[df2['exp condition']==twodaylabel]['Late colour - Mean intensity of spots'])
mean_72hourbic=np.mean(df2[df2['exp condition']==threedaybiclabel]['Late colour - Mean intensity of spots'])
mean_72hour=np.mean(df2[df2['exp condition']==threedaylabel]['Late colour - Mean intensity of spots'])


ratiohalfhour=mean30minbic/mean_30min
ratio1hr=mean_1hourbic/mean_1hour
ratio2hr=mean_2hourbic/mean_2hour
ratio3hr=mean_3hourbic/mean_3hour
ratio6hr=mean_6hourbic/mean_6hour
ratio7hr=mean_7hourbic/mean_7hour
ratio8hr=mean_8hourbic/mean_8hour
ratio9hr=mean_9hourbic/mean_9hour
ratio12hr=mean_12hourbic/mean_12hour
ratio24hr=mean_1daybic/mean_1day
ratio48hr=mean_48hourbic/mean_48hour
ratio72hr=mean_72hourbic/mean_72hour

y=[ratiohalfhour,ratio1hr,ratio2hr,ratio3hr,ratio6hr,ratio7hr,ratio8hr,ratio9hr,ratio12hr,ratio24hr]
x=np.arange(1,len(x)+1)
labels=['30mins','1','2','3','6','7','8','9','12','24']
plt.bar(x,height=np.log10(y))
plt.xticks(x,labels)
plt.title('Bic induced shift of Late colour bias')

# %%
props=df2regionprops["Early colour - regionprops"].iloc[0]

# %%
df3regionprops.columns

# %%
df3regionprops=deepcopy(df2regionprops)

# %%
for j in range(0,len(props)):
    print(props[j].perimeter)

# %%
df3regionprops['Eccentricity early']=[list() for x in range(len(df3regionprops.index))]
df3regionprops['Eccentricity late']=[list() for x in range(len(df3regionprops.index))]
df3regionprops['Eccentricity early plus late']=[list() for x in range(len(df3regionprops.index))]

# %%
for i in range(0,len(df3regionprops)):
    #empty vecs
    
    props_early=df3regionprops["Early colour - regionprops"].iloc[i]
    props_early_perim=np.zeros((len(props_early),1))
    for j in range(0,len(props_early)):
        props_early_perim[j]=props_early[j].perimeter
    df3regionprops['Perimeter early'].iloc[i]=props_early_perim
    
    props_late=df3regionprops["Late colour - regionprops"].iloc[i]
    props_late_perim=np.zeros((len(props_late),1))
    for j in range(0,len(props_late)):
        props_late_perim[j]=props_late[j].perimeter
    df3regionprops['Perimeter late'].iloc[i]=props_late_perim
    
    props_earlylate=df3regionprops["Late + early colour combined - regionprops"].iloc[i]
    props_earlylate_perim=np.zeros((len(props_earlylate),1))
    for j in range(0,len(props_earlylate)):
        props_earlylate_perim[j]=props_earlylate[j].perimeter
    df3regionprops['Perimeter early plus late'].iloc[i]=props_earlylate_perim

# %% [markdown]
# ### Regionprops plots

# %%
df3regionprops['Eccentricity early plus late mean']=np.nan

# %%
for i in range(0,len(df3regionprops)):
    
    df3regionprops['Perimeter early plus late mean'].iloc[i]=df3regionprops["Perimeter early plus late"].iloc[i].mean()

# %%
sns.set(font_scale=1)
varib1=df3regionprops["Perimeter early mean"].values.tolist()
varib2=df3regionprops["Perimeter early plus late mean"].values.tolist()

sns.kdeplot(varib1, shade=True, cut=0, label="early")
sns.kdeplot(varib2, shade=True, cut=0,label="early+late")

# %%
sns.set(font_scale=1)
varib="Perimeter early mean"

orderlab=['30mins','1hr','2hr','3hr','6hr','7hr','8hr','9hr','12hr','24hr']

fig10=plt.figure(figsize=(4,4)) #
#sns.pointplot('size', 'total_bill', 'sex', tips, dodge=True)
d=sns.barplot(y=varib, x='Drug',data=df3regionprops,hue="Timeframe",ci=90,)
Nobic = df3regionprops[(df3regionprops["Timeframe"]=="24hrs") & (df3regionprops["Drug"]=="None")][varib]
Bic = df3regionprops[(df3regionprops["Timeframe"]=="24hrs") & (df3regionprops["Drug"]=="Bic")][varib]
[stat,pval]=stats.ttest_ind(Nobic, Bic,nan_policy='omit')
print(pval)
x1, x2 = 0, 1   # columns 'HFS' and 'LFS'
y, h, col = df3regionprops[df3regionprops["Timeframe"]=="24hrs"][varib].mean() + 0.15, 0.001, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
if pval<0.001:
    plt.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col)
elif pval<0.01:
    plt.text((x1+x2)*.5, y+h, "**", ha='center', va='bottom', color=col)
elif pval<0.05:
    plt.text((x1+x2)*.5, y+h, "*", ha='center', va='bottom', color=col)
else:
    plt.text((x1+x2)*.5, y+h, "ns", ha='center', va='bottom', color=col)

# %%
sns.set(font_scale=1)
varib="Perimeter early mean"

orderlab=['30mins','1hr','2hr','3hr','6hr','7hr','8hr','9hr','12hr','24hr']

fig10=plt.figure(figsize=(4,4)) #
#sns.pointplot('size', 'total_bill', 'sex', tips, dodge=True)
d=sns.barplot(y=varib, x='Drug',data=df3regionprops[df3regionprops["Timeframe"]=="1-3hrs"],ci=None,)
Nobic = df3regionprops[(df3regionprops["Timeframe"]=="1-3hrs") & (df3regionprops["Drug"]=="None")][varib]
Bic = df3regionprops[(df3regionprops["Timeframe"]=="1-3hrs") & (df3regionprops["Drug"]=="Bic")][varib]
[stat,pval]=stats.ttest_ind(Nobic, Bic,nan_policy='omit')
print(pval)
x1, x2 = 0, 1   # columns 'HFS' and 'LFS'
y, h, col = df3regionprops[df3regionprops["Timeframe"]=="1-3hrs"][varib].mean() + 50, 0.001, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
#plt.errorbar(theta, E, yerr=0.09, xerr=0.023, capsize=0, color='#0000ff', fmt='none')

if pval<0.001:
    plt.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col)
elif pval<0.01:
    plt.text((x1+x2)*.5, y+h, "**", ha='center', va='bottom', color=col)
elif pval<0.05:
    plt.text((x1+x2)*.5, y+h, "*", ha='center', va='bottom', color=col)
else:
    plt.text((x1+x2)*.5, y+h, "ns", ha='center', va='bottom', color=col)


    
#ax2=plt.bar(x=[0,1],height=[Nobic.mean(),Bic.mean()],visible=False)
yerrors=[Nobic.sem(),Bic.sem()]
plt.errorbar(x=[0,1],y=[Nobic.mean(),Bic.mean()],yerr=yerrors,xerr=None,ecolor='black',fmt='none',capsize=2)

# %%
yerrors

# %% [markdown]
# ### Make bias image files for printing

# %%
from matplotlib.backends.backend_pdf import PdfPages


'''for condition in np.unique(df["exp condition"]):
    pdf_pages = PdfPages(expdir+'/results/'+condition + '_images_print.pdf')

    #make dictionary for files in this condition only
    exp_condition_images = [df["filename"][idx] for idx, x in enumerate(df["exp condition"]) if x == condition ]
    exp_condition_images=np.unique(exp_condition_images)
    no_images_cond=len(exp_condition_images)

    figno=1
    fig=plt.figure(figsize=(20,70))'''

for i in range(1600,1601):    
    print('Calculating image no ' + str(i+1) + ' out of' + str(len(results["filename"])))
    early_channel_no=results["earlychannelno"][i]
    late_channel_no=results["latechannelno"][i]
    synapse_channel_no=results["synapsechannelno"][i]
    with ND2Reader(results["filename"][i]) as images:
        #read the images
        early_image=images[early_channel_no-1]
        late_image=images[late_channel_no-1]
        #convert to array
        early_image=early_image.astype(np.int16)
        late_image=late_image.astype(np.int16)
        #normalize intensity to value between 0 and 1
        early_image=np.divide(early_image,16383.)
        late_image=np.divide(late_image,16383.)
        #small detour to calculate the autofluorescence
        autof={"filename":[]}
        autofpath=results["Autofluorescencedir"][i]
        if autofpath==0:
            early_autoint_mean=0
            late_autoint_mean=0
            if synapse_flag:
                synapse_autoint_mean=0
        else:
            pathy = os.path.dirname(autofpath+"/")  
            autoffilelist = []
            for root, _, filenames in os.walk(pathy):
                 for filename in filenames:
                     autoffilelist.append(os.path.join(root, filename))
            for i in range(0,len(autoffilelist)):
                if autoffilelist[i].endswith(".nd2"): 
                    autof["filename"].append(autoffilelist[i])
            earlycolour_autoint=np.zeros((len(autof["filename"]),1))
            latecolour_autoint=np.zeros((len(autof["filename"]),1))
            if synapse_flag:
                synapsecolour_autoint=np.zeros((len(autof["filename"]),1))
            for im in range(0,len(autof["filename"])):
                with ND2Reader(autof["filename"][im]) as images:
                    early_image=images[early_channel_no-1]
                    late_image=images[late_channel_no-1]
                    if synapse_flag:
                        synapse_image=images[synapse_channel_no-1]
                    #convert to array
                    early_image=early_image.astype(np.int16)
                    late_image=late_image.astype(np.int16)
                    if synapse_flag:
                        synapse_image=synapse_image.astype(np.int16)
                    #normalize intensity to value between 0 and 1
                    early_image=np.divide(early_image,16383.)
                    late_image=np.divide(late_image,16383.)
                    if synapse_flag:
                        synapse_image=np.divide(synapse_image,16383.)
                    #append mean intensity
                    earlycolour_autoint[i]=np.mean(early_image)
                    latecolour_autoint[i]=np.mean(late_image)  
                    if synapse_flag:
                        synapsecolour_autoint[i]=np.mean(synapse_image)
            #average the vectors
            early_autoint_mean=np.mean(earlycolour_autoint)
            late_autoint_mean=np.mean(latecolour_autoint) 
        #subtract autofluorescence in each channel; subtract the normalized pixel value times the max autofluorescence int
        early_image=np.subtract(early_image,early_autoint_mean)
        early_image[early_image<0]=0
        late_image=np.subtract(late_image,late_autoint_mean)
        late_image[late_image<0]=0
        #read spots masks
        early_spots=results["Early colour - spots mask"][i]
        late_spots=results["Late colour - spots mask"][i]
        lateplusearly_spots=results["Late plus early colour - spots mask"][i]
        a=late_image#[lateplusearly_spots]
        b=early_image#[lateplusearly_spots]
        spots_bias_image=(a-b)/(a+b)
        biastoearly=deepcopy(spots_bias_image)
        biasonlylate_image=deepcopy(spots_bias_image)
        biasonlylate_image=biasonlylate_image-biasonlylate_image.min()
        biasonlylate_image[~lateplusearly_spots]=0
        biasonlylate_image[biasonlylate_image<0.6*biasonlylate_image.max()]=0
        biasonlylate_mask=biasonlylate_image>0
        earlyimageverylatebias=deepcopy(early_image)
        earlyimageverylatebias[biasonlylate_mask]=np.nan

# %%
cmap = plt.cm.jet
cmap.set_bad('r',1.)
plt.imshow(earlyimageverylatebias, interpolation='none', cmap=cmap,
           vmin=3*early_image.min(),
           vmax=0.65*early_image.max())

# %%
fig=plt.figure()
fig.add_subplot(121)
plt.imshow(verybiased,cmap='gray',vmin=verybiased.min(),vmax=verybiased.max())
plt.colorbar()
fig.add_subplot(122)
plt.imshow(early_image,interpolation='none',cmap='gray')

# %%
    
sns.set(font_scale=1.3)


fig1=plt.figure()
d=sns.barplot(y="Early colour - Raw mean intensity", x="exp condition",data=df_corrected.loc[df_corrected['exp condition'].isin(['1Day','1DayBic'])],ci=95)
#d=sns.swarmplot(y="Early colour - Raw mean intensity", x="exp condition",data=df_corrected.loc[df_corrected['exp condition'].isin(['1Day','1DayBic'])],color='black')
#ig1.savefig(expdir+'plot1.png',bbox_inches='tight')
Nobic = df_corrected[df_corrected['exp condition'] == '1Day']['Early colour - Raw mean intensity']
Bic = df_corrected[df_corrected['exp condition'] == '1DayBic']['Early colour - Raw mean intensity']
[stat,pval]=stats.ttest_ind(Nobic, Bic,nan_policy='omit')
print(pval)
x1, x2 = 0, 1   # columns 'HFS' and 'LFS'
y, h, col = df_corrected['Early colour - Raw mean intensity'].mean() + 0.005, 0.001, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
if pval<0.001:
    plt.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col)
elif pval<0.01:
    plt.text((x1+x2)*.5, y+h, "**", ha='center', va='bottom', color=col)
elif pval<0.05:
    plt.text((x1+x2)*.5, y+h, "*", ha='center', va='bottom', color=col)
else:
    plt.text((x1+x2)*.5, y+h, "ns", ha='center', va='bottom', color=col)

fig2=plt.figure()
d=sns.barplot(y="Late colour - Raw mean intensity", x="exp condition",data=df_corrected.loc[df_corrected['exp condition'].isin(['1Day','1DayBic'])],ci=95)
#d=sns.swarmplot(y="Late colour - Raw mean intensity", x="exp condition",data=df_corrected.loc[df_corrected['exp condition'].isin(['1Day','1DayBic'])],color='black')
#ig1.savefig(expdir+'plot1.png',bbox_inches='tight')
Nobic = df_corrected[df_corrected['exp condition'] == '1Day']['Late colour - Raw mean intensity']
Bic = df_corrected[df_corrected['exp condition'] == '1DayBic']['Late colour - Raw mean intensity']
[stat,pval]=stats.ttest_ind(Nobic, Bic,nan_policy='omit')
print(pval)
x1, x2 = 0, 1   # columns 'HFS' and 'LFS'
y, h, col = df_corrected['Late colour - Raw mean intensity'].mean() + 0.005, 0.001, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
if pval<0.001:
    plt.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col)
elif pval<0.01:
    plt.text((x1+x2)*.5, y+h, "**", ha='center', va='bottom', color=col)
elif pval<0.05:
    plt.text((x1+x2)*.5, y+h, "*", ha='center', va='bottom', color=col)
else:
    plt.text((x1+x2)*.5, y+h, "ns", ha='center', va='bottom', color=col)
#fig2.savefig(expdir+'plot2.png',bbox_inches='tight')

fig10=plt.figure()
Nobic = df_corrected[df_corrected['exp condition'] == '1Day']['Mean colour bias of a pixel (early=-1<x<1=late)']
Bic = df_corrected[df_corrected['exp condition'] == '1DayBic']['Mean colour bias of a pixel (early=-1<x<1=late)']
[stat,pval]=stats.ttest_ind(Nobic, Bic,nan_policy='omit')
print(pval)
d=sns.barplot(y="Mean colour bias of a pixel (early=-1<x<1=late)", x="exp condition",data=df_corrected.loc[df_corrected['exp condition'].isin(['1Day','1DayBic'])],ci=95)
#d=sns.swarmplot(y="Mean colour bias of a pixel (early=-1<x<1=late)", x="exp condition",data=df_corrected,color='black')
#fig10.savefig(expdir+'plot10.png',bbox_inches='tight')
x1, x2 = 0, 1   # columns 'HFS' and 'LFS'
y, h, col = df_corrected['Mean colour bias of a pixel (early=-1<x<1=late)'].mean() + 0.25, 0.01, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
if pval<0.001:
    plt.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col)
elif pval<0.01:
    plt.text((x1+x2)*.5, y+h, "**", ha='center', va='bottom', color=col)
elif pval<0.05:
    plt.text((x1+x2)*.5, y+h, "*", ha='center', va='bottom', color=col)
else:
    plt.text((x1+x2)*.5, y+h, "ns", ha='center', va='bottom', color=col)

# %%
data=df_corrected.loc[df_corrected['exp condition'].isin(['1Day','1DayBic'])]

# %%
'''fig10=plt.figure()
Nobic = df[df['exp condition'] == '1Day']['Mean colour bias of a pixel (early=-1<x<1=late)']
Bic = df[df['exp condition'] == '2Day']['Mean colour bias of a pixel (early=-1<x<1=late)']
[stat,pval]=stats.ttest_ind(Nobic, Bic)
print(pval)
d=sns.barplot(x='Mean colour bias of a pixel (early=-1<x<1=late)', y='exp condition',data=df_corrected[df_corrected['exp condition'].isin(['1Day', '2Day'])], ci='sd')
d=sns.swarmplot(x='Mean colour bias of a pixel (early=-1<x<1=late)', y='exp condition',data=df_corrected[df_corrected['exp condition'].isin(['1Day', '2Day'])],color='black')
fig10.savefig(expdir+'plot10.png',bbox_inches='tight')'''


fig10=plt.figure()
Nobic = df_corrected[df_corrected['exp condition'] == '1Day']['Mean colour bias of a pixel (early=-1<x<1=late)']
Bic = df_corrected[df_corrected['exp condition'] == '2Day']['Mean colour bias of a pixel (early=-1<x<1=late)']
[stat,pval]=stats.ttest_ind(Nobic, Bic,nan_policy='omit')
print(pval)
d=sns.barplot(y="Mean colour bias of a pixel (early=-1<x<1=late)", x="exp condition",data=df_corrected.loc[df_corrected['exp condition'].isin(['1Day','2Day'])])
#d=sns.swarmplot(y="Mean colour bias of a pixel (early=-1<x<1=late)", x="exp condition",data=df_corrected,color='black')
#fig10.savefig(expdir+'plot10.png',bbox_inches='tight')
x1, x2 = 0, 1   # columns 'HFS' and 'LFS'
y, h, col = df_corrected['Mean colour bias of a pixel (early=-1<x<1=late)'].mean() + 0.8, 0.01, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
if pval<0.001:
    plt.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col)
elif pval<0.01:
    plt.text((x1+x2)*.5, y+h, "**", ha='center', va='bottom', color=col)
elif pval<0.05:
    plt.text((x1+x2)*.5, y+h, "*", ha='center', va='bottom', color=col)
else:
    plt.text((x1+x2)*.5, y+h, "ns", ha='center', va='bottom', color=col)
