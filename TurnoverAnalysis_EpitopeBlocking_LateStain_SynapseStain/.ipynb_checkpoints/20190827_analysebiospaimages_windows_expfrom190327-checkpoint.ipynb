# %%
import numpy as np
import os
from nd2reader import ND2Reader
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib_scalebar.scalebar import ScaleBar
import scipy.ndimage as ndi
from skimage.filters import rank 
from scipy.signal import butter, lfilter
import scipy.misc as misc
from skimage import exposure
from PIL import Image
import colorcet as cc
from scipy.misc import toimage
import matplotlib.colors as clr
import pandas as pd
import seaborn as sns
from scipy import stats
import cv2
from pyspark import SparkContext, SparkConf
import skimage
from pathlib import Path

def mean2(x):
    y = np.sum(x) / np.size(x);
    return y
def corr2(a,b):
    a = a - mean2(a)
    b = b - mean2(b)

    r = (a*b).sum() / np.sqrt((a*a).sum() * (b*b).sum());
    return r
from copy import deepcopy
from skimage.filters import threshold_otsu,threshold_li
import glob
from IPython.display import clear_output
import scipy.io as spio
import matplotlib.ticker as ticker
import pims
import fnmatch
from skimage import io

# %%
expdir='Y:\\user\\tdanko\\Imaging\\1_ECM\\Live Culture\\Cytation_biospa\\20190327_Tal_TNR550\\190327_181156_Plate 1\\' #master folder
protein="TNR" #TNR,Agg,WFA,HABP

# %%
results={"filename":[],
         "exp name":[],
        "condition":[],
        "namestem before channel":[],
         "namestem after channel":[],
        "timepoint":[],
        "analyse":[]}

path = os.path.dirname(expdir)  
filelist = []
for root, _, filenames in os.walk(path):
     for filename in filenames:
         filelist.append(os.path.join(root, filename))      
for i in range(0,len(filelist)):
    if ("montage" in str(filelist[i]))==False:
        
        if filelist[i].endswith(".tif"): 
            results["filename"].append(filelist[i])
            results["analyse"].append(False)
            results["exp name"].append(filelist[i][:-12].split('\\')[-2])
            results["namestem before channel"].append('\\'.join(filelist[i].split('\\')[:-1])+'\\'+'_'.join(filelist[i].split('\\')[-1].split('_')[:-4]))
            results["namestem after channel"].append('_'.join(filelist[i].split('\\')[-1].split('_')[-3:-1]))
            results["timepoint"].append(filelist[i][-7:-4])
            if len(fnmatch.filter([filelist[i]],'*A?_*'))>0:
                results["condition"].append("Unblocked")
            elif len(fnmatch.filter([filelist[i]],'*B?_*'))>0:
                results["condition"].append("Blocked")
            elif len(fnmatch.filter([filelist[i]],'*C?_*'))>0:
                results["condition"].append("Blocked")
            
            elif len(fnmatch.filter([filelist[i]],'*D1_*'))>0:
                results["condition"].append("Blocked")
            elif len(fnmatch.filter([filelist[i]],'*D2_*'))>0:
                results["condition"].append("Blocked")
            elif len(fnmatch.filter([filelist[i]],'*D3_*'))>0:
                results["condition"].append("Blocked")
            
            elif len(fnmatch.filter([filelist[i]],'*D4_*'))>0:
                results["condition"].append("Autofluorescence")
            elif len(fnmatch.filter([filelist[i]],'*D5_*'))>0:
                results["condition"].append("Autofluorescence")
            elif len(fnmatch.filter([filelist[i]],'*D6_*'))>0:
                results["condition"].append("Autofluorescence")
            else:
                results["condition"].append('Unspecified')

# %%
df=pd.DataFrame(results)

# %%
df
# Out:
#                                                 filename  \
# 0      Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 1      Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 2      Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 3      Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 4      Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 5      Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 6      Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 7      Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 8      Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 9      Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 10     Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 11     Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 12     Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 13     Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 14     Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 15     Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 16     Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 17     Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 18     Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 19     Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 20     Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 21     Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 22     Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 23     Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 24     Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 25     Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 26     Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 27     Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 28     Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 29     Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# ...                                                  ...
# 53730  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53731  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53732  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53733  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53734  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53735  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53736  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53737  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53738  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53739  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53740  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53741  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53742  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53743  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53744  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53745  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53746  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53747  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53748  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53749  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53750  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53751  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53752  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53753  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53754  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53755  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53756  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53757  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53758  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
# 53759  Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cyta...
#
#                     exp name  condition  \
# 0      190327_181156_Plate 1  Unblocked
# 1      190327_181156_Plate 1  Unblocked
# 2      190327_181156_Plate 1  Unblocked
# 3      190327_181156_Plate 1  Unblocked
# 4      190327_181156_Plate 1  Unblocked
# 5      190327_181156_Plate 1  Unblocked
# 6      190327_181156_Plate 1  Unblocked
# 7      190327_181156_Plate 1  Unblocked
# 8      190327_181156_Plate 1  Unblocked
# 9      190327_181156_Plate 1  Unblocked
# 10     190327_181156_Plate 1  Unblocked
# 11     190327_181156_Plate 1  Unblocked
# 12     190327_181156_Plate 1  Unblocked
# 13     190327_181156_Plate 1  Unblocked
# 14     190327_181156_Plate 1  Unblocked
# 15     190327_181156_Plate 1  Unblocked
# 16     190327_181156_Plate 1  Unblocked
# 17     190327_181156_Plate 1  Unblocked
# 26         12_Phase Contrast       003    False
# 27         12_Phase Contrast       004    False
# 28         12_Phase Contrast       005    False
# 29         12_Phase Contrast       006    False
# ...                      ...       ...      ...
# 53730                  9_RFP       041    False
# 53731                  9_RFP       042    False
# 53732                  9_RFP       043    False
# 53733                  9_RFP       044    False
# 53734                  9_RFP       045    False
# 53735                  9_RFP       046    False
# 53736                  9_RFP       047    False
# 53737                  9_RFP       048    False
# 53738                  9_RFP       049    False
# 53739                  9_RFP       050    False
# 53740                  9_RFP       051    False
# 53741                  9_RFP       052    False
# 53742                  9_RFP       053    False
# 53743                  9_RFP       054    False
# 53744                  9_RFP       055    False
# 53745                  9_RFP       056    False
# 53746                  9_RFP       057    False
# 53747                  9_RFP       058    False
# 53748                  9_RFP       059    False
# 53749                  9_RFP       060    False
# 53750                  9_RFP       061    False
# 53751                  9_RFP       062    False
# 53752                  9_RFP       063    False
# 53753                  9_RFP       064    False
# 53754                  9_RFP       065    False
# 53755                  9_RFP       066    False
# 53756                  9_RFP       067    False
# 53757                  9_RFP       068    False
# 53758                  9_RFP       069    False
# 53759                  9_RFP       070    False
#
# [53760 rows x 7 columns]

# %% [markdown]
# ## Throw out images with no cells

# %%
no_image_fields=int(len(df)/2/int(df["timepoint"].max())) #divide by no channels and timepoints

# %%
no_image_fields
# Out:
# 384

# %%
toanalyse={"namestem":images_list,"analyse":[]}
for i in range(0,len(images_list)):
    toanalyse["analyse"].append(False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-6350775d2787> in <module>()
# ----> 1 toanalyse={"namestem":images_list,"analyse":[]}
#       2 for i in range(0,len(images_list)):
#       3     toanalyse["analyse"].append(False)
#
# NameError: name 'images_list' is not defined

# %%
import ipywidgets as widgets
from ipywidgets import interact



#load first image

ecm_image_name=df["filename"][indexes[0]]
ecm_image = io.imread(ecm_image_name)


def f(Threshold,Image_no):
    
    ii=Image_no
    ecm_image_name=df["filename"][indexes[ii]]
    ecm_image = io.imread(ecm_image_name)

    if Threshold=="Keep":
        df["analyse"][indexes[ii]]=True
    
    fig=plt.figure(figsize=(10,10))
    plt.imshow(ecm_image,cmap='inferno')
    plt.title(ecm_image_name)
    

#widgets
Threshold=widgets.Dropdown(options=["Keep","Toss"])
Image_no=widgets.IntText(min=0,max=len(images_list),value=0)

w=interact(f,Threshold=Threshold,
           Image_no=Image_no)
# Out:
# interactive(children=(Dropdown(description='Threshold', options=('Keep', 'Toss'), value='Keep'), IntText(value…

# %%
indexes=df.loc[df["filename"].str.contains("Phase Contrast_001")].index
timepoints=df["timepoint"].unique()

intensities={"namestem":[],
            "condition":[],
            "intensities vector":[],
            "intensities vector bgsub":[]}
counter=0
for i in indexes:
    counter+=1
    print(str(counter)+' out of ' +str(len(indexes)))
    name=df["filename"][i]
    print(name)
    namestem='\\'.join(name.split('\\')[:-1])+'\\'+'_'.join(name.split('\\')[-1].split('_')[:-4])+'_2_'+name.split('_')[-3]+'_RFP_'
    print(namestem)
    intensities["namestem"].append(namestem)
    intensities["condition"].append(df["condition"][i])
    intensities_vect=[]
    intensities_vect_bgsubtracted=[]
    for time in timepoints:
        print(time)
        fullname=namestem+time+'.tif'
        #read image
        ecm_image = io.imread(fullname)
        intensities_vect.append(ecm_image.mean())
        #bg
        bg=np.mean(ndi.median_filter(ecm_image,size=5))+0*np.std(ndi.median_filter(ecm_image,size=5))
        ecm_bgreduced=np.subtract(ecm_image,bg)
        ecm_bgreduced[ecm_bgreduced<0]=0
        intensities_vect_bgsubtracted.append(ecm_bgreduced.mean())
    intensities["intensities vector"].append(intensities_vect)
    intensities["intensities vector bgsub"].append(intensities_vect_bgsubtracted)
# Out:
# 1 out of 384
# Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cytation_biospa\20190327_Tal_TNR550\190327_181156_Plate 1\A1_02_1_10_Phase Contrast_001.tif
# Y:\user\tdanko\Imaging\1_ECM\Live Culture\Cytation_biospa\20190327_Tal_TNR550\190327_181156_Plate 1\A1_02_2_10_RFP_
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 013
# 014
# 015
# 016
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-5792b93f7488> in <module>()
#      25         intensities_vect.append(ecm_image.mean())
#      26         #bg
# ---> 27         bg=np.mean(ndi.median_filter(ecm_image,size=5))+0*np.std(ndi.median_filter(ecm_image,size=5))
#      28         ecm_bgreduced=np.subtract(ecm_image,bg)
#      29         ecm_bgreduced[ecm_bgreduced<0]=0
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\ndimage\filters.py in median_filter(input, size, footprint, output, mode, cval, origin)
#    1222     """
#    1223     return _rank_filter(input, 0, size, footprint, output, mode, cval,
# -> 1224                         origin, 'median')
#    1225
#    1226
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\ndimage\filters.py in _rank_filter(input, rank, size, footprint, output, mode, cval, origin, operation)
#    1143         mode = _ni_support._extend_mode_to_code(mode)
#    1144         _nd_image.rank_filter(input, rank, footprint, output, mode, cval,
# -> 1145                               origins)
#    1146         return output
#    1147
#
# KeyboardInterrupt:

# %%
for key in intensities.keys():
    print(key)
    print(len(intensities[key]))
# Out:
# namestem
# 384
# condition
# 384
# intensities vector
# 384
# intensities vector bgsub
# 384

# %%
dfint=pd.DataFrame(intensities)

# %%
dfint.columns
# Out:
# Index(['namestem', 'condition', 'intensities vector',
#        'intensities vector bgsub'],
#       dtype='object')

# %%
#df2plot=df2plot.reset_index()
np.mean(df2plot[toplot].tolist(),axis=0)
# Out:
# array([ 613.02734966,  702.1370665 ,  805.99000302,  888.56570966,
#         954.98300118, 1010.27061358, 1053.59097318, 1083.96694808,
#        1107.40594097, 1127.05595029, 1145.11111165, 1161.75880295,
#        1168.69409529, 1177.14193835, 1182.71913236, 1180.61479903,
#        1180.78134592, 1162.37641643, 1166.5037429 , 1160.02802803,
#        1151.18229584, 1182.16719222, 1134.97866492, 1122.84816972,
#        1103.87125493, 1102.30424185, 1089.5850397 , 1080.86931644,
#        1071.89005638, 1060.34252291, 1047.42519384, 1035.15665769,
#        1014.15368684, 1013.63868679, 1010.77099367, 1004.0379343 ,
#         983.59029713,  969.52934406,  970.93930592,  953.64174536,
#         929.83851635,  917.42786255,  949.25909394,  902.8460288 ,
#         899.52295839,  890.82398415,  886.66020222,  856.6997638 ,
#         872.70624123,  873.00706428,  868.47734977,  860.9674097 ,
#         868.78234879,  863.48279563,  834.43204758,  849.68765972,
#         907.8910608 ,  895.25401513,  830.14586889,  877.2189362 ,
#         900.86993156,  861.51387675,  876.26573561,  857.44635325,
#         895.81859774,  879.74737416,  923.6784109 ,  914.53524335,
#         921.0951551 ,  928.59520996])

# %%
# Out:
# array(['Unblocked', 'Blocked', 'Autofluorescence'], dtype=object)

# %%
toplot="intensities vector bgsub"
conditioni=df["condition"].unique()
for condition in dfint["condition"].unique():
    
    df2plot=dfint[dfint["condition"]==condition]
    plt.plot(np.mean(df2plot[toplot].tolist(),axis=0))
    plt.legend(conditioni)

# %%
dfint.to_pickle(expdir+'longterm_intensities.pkl')
