# %% [markdown]
# ## Import modules

# %%
import numpy as np
import os
from nd2reader import ND2Reader
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib_scalebar.scalebar import ScaleBar
import scipy.ndimage as ndi
from skimage.filters import rank 
from scipy.signal import butter, lfilter
import scipy.misc as misc
from skimage import exposure
from PIL import Image
import colorcet as cc
from scipy.misc import toimage
import matplotlib.colors as clr
import pandas as pd
import seaborn as sns
from scipy import stats
import cv2
from pyspark import SparkContext, SparkConf
import skimage
from pathlib import Path
# %matplotlib inline
def mean2(x):
    y = np.sum(x) / np.size(x);
    return y
def corr2(a,b):
    a = a - mean2(a)
    b = b - mean2(b)

    r = (a*b).sum() / np.sqrt((a*a).sum() * (b*b).sum());
    return r
from copy import deepcopy
from skimage.filters import threshold_otsu,threshold_li
import glob
from IPython.display import clear_output
import scipy.io as spio
import pims

# %% [markdown]
# ## Specify experiment directory

# %%
expdir='/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/'
protein="TNR" #TNR,Agg,WFA,HABP

# %% [markdown]
# ## Make results dict and load aligned images from matlab GUI

# %%
#make synapse results dictionary

spots={"filename":[]}

path = os.path.dirname(expdir)  
outputFolder = os.path.dirname(expdir + "/new/")
filelist = []
for root, _, filenames in os.walk(path):
     for filename in filenames:
         filelist.append(os.path.join(root, filename))      
for i in range(0,len(filelist)):
    #if "_analyse" in str(filelist[i]):        
        if ("samecell" in str(filelist[i]))==True:
            if ("output_classification" in str(filelist[i]))==True:
                if (protein in str(filelist[i]))==True:
                    if ("backup" in str(filelist[i]))==False:
                        if filelist[i].endswith(".txt"): 
                            #if str(filelist[i][:-12]) not in str(spots["filename"]):
                                spots["filename"].append(filelist[i])


synapses_results={"spots classification filename":[],
                "sted spot":[],
                "vglut spot":[],
                "dio spot":[],
                "sted spot aligned":[],
                "vglut spot aligned":[],
                "dio spot aligned":[],
                 "sted spot aligned no back":[],
                "vglut spot aligned no back":[],
                "dio spot aligned no back":[],
                "Exp name":[],
                "Cell number":[],
                "unique id (expname_cell number)":[],
                "classification":[],
                  "mean ecm intensity sted":[],
                  "ecm intensity sted, bg subtracted":[],
                  "mean ecm intensity sted noback":[],
                  "ecm intensity sted noback bg subtracted":[],
                  "mean vglut intensity sted":[],
                  "vglut intensity sted, bg subtracted":[],
                  "mean vglut intensity sted noback":[],
                  "vglut intensity sted noback bg subtracted":[],
                  "mean vglut size (sum of pixels)":[],
                  "mean vglut size (sum of pixels) from noback":[],
                  "exp condition":[]}
                  
for spot in range(0,len(spots["filename"])):
    print(spots["filename"][spot])
    firstpart='/'.join(spots["filename"][spot].split("/")[:-1])
    lastpart=spots["filename"][spot].split("classification")[-1]
    synapses_results["spots classification filename"].append(spots["filename"][spot])
    file2read=firstpart+'/output_sted_'+lastpart
    synapses_results["sted spot"].append(np.asarray(np.loadtxt(file2read,delimiter=',')))
    file2read=firstpart+'/output_homer_'+lastpart
    synapses_results["vglut spot"].append(np.asarray(np.loadtxt(file2read,delimiter=',')))
    file2read=firstpart+'/output_dio_'+lastpart
    synapses_results["dio spot"].append(np.asarray(np.loadtxt(file2read,delimiter=',')))
    file2read=firstpart+'/output_sted_aligned_'+lastpart
    synapses_results["sted spot aligned"].append(np.asarray(np.loadtxt(file2read,delimiter=',')))
    file2read=firstpart+'/output_homer_aligned_'+lastpart
    synapses_results["vglut spot aligned"].append(np.asarray(np.loadtxt(file2read,delimiter=',')))
    file2read=firstpart+'/output_dio_aligned_'+lastpart
    synapses_results["dio spot aligned"].append(np.asarray(np.loadtxt(file2read,delimiter=',')))
    file2read=firstpart+'/output_sted_aligned_noback_'+lastpart
    synapses_results["sted spot aligned no back"].append(np.asarray(np.loadtxt(file2read,delimiter=',')))
    file2read=firstpart+'/output_homer_aligned_noback_'+lastpart
    synapses_results["vglut spot aligned no back"].append(np.asarray(np.loadtxt(file2read,delimiter=',')))
    file2read=firstpart+'/output_dio_aligned_noback_'+lastpart
    synapses_results["dio spot aligned no back"].append(np.asarray(np.loadtxt(file2read,delimiter=',')))
    
    synapses_results["Exp name"].append(file2read.split("2019")[-1][0:4])
    synapses_results["Cell number"].append(lastpart[-9:-4])
    synapses_results["unique id (expname_cell number)"].append(file2read.split("2019")[-1][0:4]+'_'+lastpart[-9:-4])
    synapses_results["classification"].append(np.loadtxt(spots["filename"][spot]))
    synapses_results["exp condition"].append(synapses_results["spots classification filename"][spot].split("TIFs")[-1].split('/')[1])
    
    synapses_results["mean ecm intensity sted"].append(np.nan)
    synapses_results["ecm intensity sted, bg subtracted"].append(np.nan)
    synapses_results["mean ecm intensity sted noback"].append(np.nan)
    synapses_results["ecm intensity sted noback bg subtracted"].append(np.nan)
    synapses_results["mean vglut intensity sted"].append(np.nan)
    synapses_results["vglut intensity sted, bg subtracted"].append(np.nan)
    synapses_results["mean vglut intensity sted noback"].append(np.nan)
    synapses_results["vglut intensity sted noback bg subtracted"].append(np.nan)
    synapses_results["mean vglut size (sum of pixels)"].append(np.nan)
    synapses_results["mean vglut size (sum of pixels) from noback"].append(np.nan)
# Out:
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification2_11_03_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification3_12_03_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification8_17_03_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification10_20_03_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification15_25_03_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification23_9_03_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification25_11_03_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification28_14_03_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification30_16_03_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification36_21_03_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification37_22_03_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification42_27_03_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification44_29_03_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification46_31_03_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification49_34_03_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification52_37_03_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification67_16_03_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification73_22_03_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification76_25_03_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification78_27_03_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification79_28_03_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification83_31_03_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification85_35_03_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification86_37_03_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification87_39_03_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification89_40_03_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification90_4_03_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification92_6_03_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification93_7_03_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification94_8_03_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification95_9_03_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification97_11_03_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification98_12_03_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification102_16_03_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification107_6_03_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification108_7_03_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification111_10_03_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification114_13_03_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification125_25_03_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification135_34_03_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification136_36_03_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification139_3_03_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification140_40_03_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification142_5_03_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification146_9_03_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification158_20_03_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification161_2_03_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification169_10_03_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification172_13_03_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification176_3_03_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification177_4_03_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification178_5_03_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification179_6_03_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification180_8_03_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification190_18_03_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification202_10_03_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification213_22_03_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification214_23_03_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification218_27_03_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification221_2_03_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification223_31_03_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification225_34_03_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification228_37_03_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification229_38_03_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification234_42_03_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification235_43_03_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification237_45_03_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification240_48_03_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification241_49_03_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification250_57_03_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification258_64_03_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification260_66_03_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification264_7_03_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification265_8_03_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification272_6_03_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification274_10_03_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification279_15_03_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification280_16_03_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification288_24_03_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification292_28_03_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification300_36_03_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification302_38_03_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification303_39_03_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification306_41_03_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification307_42_03_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification318_14_04_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification322_7_04_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification323_8_04_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification324_9_04_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification325_10_04_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification326_11_04_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification336_24_04_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification344_4_04_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification346_6_04_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification350_1_04_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification351_2_04_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification352_3_04_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification353_4_04_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification357_13_04_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification360_16_04_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification361_17_04_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification364_1_04_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification369_25_04_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification370_27_04_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification373_2_04_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification377_34_04_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification391_11_04_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification393_13_04_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification394_14_04_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification396_2_04_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification399_5_04_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification400_6_04_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification413_19_04_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification423_4_04_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification426_7_04_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification432_4_04_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification433_5_04_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification434_10_04_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification438_14_04_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification442_1_04_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification444_22_04_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification445_23_04_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification447_25_04_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification449_27_04_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification451_29_04_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification454_31_04_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification457_5_04_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification459_7_04_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification460_8_04_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification461_10_04_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification462_11_04_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification463_12_04_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification464_13_04_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification465_14_04_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification466_15_04_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification467_16_04_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification469_18_04_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification470_19_04_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification471_1_04_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification473_21_04_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification475_23_04_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification476_24_04_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification478_3_04_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification479_4_04_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification480_5_04_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification481_6_04_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification489_6_04_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_DMSO/output_classification491_8_04_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification1_1_05_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification10_10_05_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification12_12_05_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification14_14_05_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification15_15_05_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification16_16_05_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification22_21_05_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification23_22_05_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification31_10_05_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification35_1_05_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification37_3_05_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification38_4_05_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification45_12_05_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification46_13_05_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification51_18_05_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification62_2_05_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification66_6_05_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification73_13_05_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification82_4_05_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification83_5_05_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification85_7_05_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification88_10_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification91_13_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification101_4_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification103_6_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification106_9_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification107_10_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification111_16_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification112_17_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification116_21_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification117_22_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification118_23_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification126_7_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification137_18_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification138_19_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification146_12_05_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification149_15_05_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification150_16_05_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification152_18_05_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification154_1_05_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification155_20_05_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification159_24_05_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification161_26_05_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification163_28_05_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification167_32_05_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification173_4_05_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification177_8_05_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification192_23_05_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification196_27_05_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification199_5_05_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification203_9_05_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification211_2_05_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification212_3_05_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification213_4_05_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification227_18_05_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification232_22_05_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification236_26_05_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification247_4_06_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification248_5_06_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification249_6_06_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification254_12_06_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification277_10_06_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification279_12_06_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification281_14_06_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification291_23_06_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification292_24_06_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification301_32_06_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification317_1_06_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification319_3_06_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification321_5_06_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification324_9_06_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification327_12_06_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification330_15_06_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification336_21_06_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification338_23_06_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification348_8_06_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification352_12_06_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification354_2_06_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification361_9_06_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification374_12_06_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190225_TNR647_VGlut580_DiO/Images_axonsdendrites_fromsamecell_try2/TIFs_analyse_samecellonly/12hr_Bic/output_classification379_17_06_04.txt
# ...
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification84_9_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification85_10_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification88_13_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification89_14_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification90_15_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification91_16_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification92_17_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification93_18_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification94_19_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification96_21_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification99_24_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification100_25_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification102_27_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification103_28_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification108_34_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification109_36_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification110_38_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification113_41_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification115_43_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification116_44_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification117_45_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification118_46_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification119_47_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification121_49_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification122_50_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification123_51_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification126_54_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification132_60_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification133_61_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification136_65_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification137_67_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification138_69_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification139_70_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification141_73_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification147_79_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification151_83_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification153_85_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification158_9_05_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification161_12_05_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification164_15_05_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification166_2_05_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification168_4_05_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification173_9_05_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification182_18_06_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification189_10_06_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification193_14_06_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification198_19_06_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification209_29_06_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification211_30_06_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification232_4_06_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification249_8_06_01.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification251_10_06_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification254_13_06_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification256_15_06_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification263_2_06_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification269_8_06_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification270_9_06_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification273_12_06_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification280_19_06_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification281_1_06_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification289_27_06_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification301_6_06_02.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification306_19_06_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification310_11_06_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification312_13_06_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification314_15_06_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification318_19_06_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification321_22_06_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification322_23_06_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification323_24_06_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification326_27_06_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification329_30_06_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification330_31_06_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification333_34_06_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification335_37_06_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification338_40_06_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification340_44_06_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification341_45_06_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification342_46_06_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification348_9_06_03.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification349_10_06_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification350_11_06_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification372_11_06_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification385_28_06_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification391_34_06_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification397_3_06_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification401_43_06_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification416_5_06_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification427_6_06_04.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification444_1_06_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification449_6_06_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification455_12_06_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification461_18_06_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification462_19_06_05.txt
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed Culture/STEDBIN/20190307_TNR647_VGlut580_DiO_analyse_samecell/12hr_Bic/TIF_imp/output_classification471_9_06_05.txt

# %% [markdown]
# <a id='loadingprocessinganalysing'></a>
# ## Loading, processing and batch analyzing the images
# **Let's start by loading a random image and looking at the ECM channel:**

# %% [markdown]
# ## Spot analysis

# %%
for spotno in range(0,len(synapses_results["spots classification filename"])):
    synapses_results["mean ecm intensity sted"][spotno]=np.nanmean(synapses_results["sted spot aligned"][spotno])
    synapses_results["mean ecm intensity sted noback"][spotno]=np.nanmean(synapses_results["sted spot aligned no back"][spotno])
    synapses_results["mean vglut intensity sted"][spotno]=np.nanmean(synapses_results["vglut spot aligned"][spotno])
    synapses_results["mean vglut intensity sted noback"][spotno]=np.nanmean(synapses_results["vglut spot aligned no back"][spotno])
    synapses_results["mean vglut size (sum of pixels)"][spotno]=np.sum(synapses_results["vglut spot aligned"][spotno])
    synapses_results["mean vglut size (sum of pixels) from noback"][spotno]=np.sum(synapses_results["vglut spot aligned no back"][spotno])

    #bg subtraction
    ecm_around_spot_bgsub=np.array(deepcopy(synapses_results["sted spot aligned"][spotno]))
    bg_ecm=np.mean(ndi.median_filter(ecm_around_spot_bgsub,size=5))+0*np.std(ndi.median_filter(ecm_around_spot_bgsub,size=5))
    ecm_around_spot_bgsub=np.subtract(ecm_around_spot_bgsub,bg_ecm)
    ecm_around_spot_bgsub[ecm_around_spot_bgsub<0]=0
    synapses_results["ecm intensity sted, bg subtracted"][spotno]=(ecm_around_spot_bgsub)
    
    ecm_around_spot_bgsub=np.array(deepcopy(synapses_results["sted spot aligned no back"][spotno]))
    bg_ecm=np.mean(ndi.median_filter(ecm_around_spot_bgsub,size=5))+0*np.std(ndi.median_filter(ecm_around_spot_bgsub,size=5))
    ecm_around_spot_bgsub=np.subtract(ecm_around_spot_bgsub,bg_ecm)
    ecm_around_spot_bgsub[ecm_around_spot_bgsub<0]=0
    synapses_results["ecm intensity sted noback bg subtracted"][spotno]=(ecm_around_spot_bgsub)
    
    ecm_around_spot_bgsub=np.array(deepcopy(synapses_results["vglut spot aligned"][spotno]))
    bg_ecm=np.mean(ndi.median_filter(ecm_around_spot_bgsub,size=5))+0*np.std(ndi.median_filter(ecm_around_spot_bgsub,size=5))
    ecm_around_spot_bgsub=np.subtract(ecm_around_spot_bgsub,bg_ecm)
    ecm_around_spot_bgsub[ecm_around_spot_bgsub<0]=0
    synapses_results["vglut intensity sted, bg subtracted"][spotno]=(ecm_around_spot_bgsub)
    
    ecm_around_spot_bgsub=np.array(deepcopy(synapses_results["vglut spot aligned no back"][spotno]))
    bg_ecm=np.mean(ndi.median_filter(ecm_around_spot_bgsub,size=5))+0*np.std(ndi.median_filter(ecm_around_spot_bgsub,size=5))
    ecm_around_spot_bgsub=np.subtract(ecm_around_spot_bgsub,bg_ecm)
    ecm_around_spot_bgsub[ecm_around_spot_bgsub<0]=0
    synapses_results["vglut intensity sted noback bg subtracted"][spotno]=(ecm_around_spot_bgsub)

# %% [markdown]
# ## Make average images

# %%
df=pd.DataFrame(synapses_results)

# %% [markdown]
# ## Plot a random spot image

# %%
randomno=np.random.randint(1,len(df))
fig=plt.figure(figsize=(20,20))
fig.add_subplot(131)
plt.imshow(df["vglut spot aligned"][randomno],cmap='inferno')
plt.xticks(visible=False)
plt.yticks(visible=False)
plt.gca().set(aspect='equal',adjustable='box')
plt.grid(False)
plt.title('VGlut spot')
fig.add_subplot(132)
plt.imshow(df["sted spot aligned"][randomno],cmap='inferno')
plt.xticks(visible=False)
plt.yticks(visible=False)
plt.gca().set(aspect='equal',adjustable='box')
plt.grid(False)
plt.title('ECM around synapse spot')
fig.add_subplot(133)
plt.imshow(df["dio spot aligned"][randomno],cmap='jet')
plt.xticks(visible=False)
plt.yticks(visible=False)
plt.gca().set(aspect='equal',adjustable='box')
plt.grid(False)
plt.title('dio around synapse spot')
# Out:
# Text(0.5, 1.0, 'dio around synapse spot')

# %% [markdown]
# ### Add radial average

# %%
## radial_average version 2 - define function
def radial_average(image):
    import numpy as np
    import scipy
    from scipy import ndimage
    import matplotlib.pyplot as plt

    f = image
    sx, sy = f.shape
    X, Y = np.ogrid[0:sx, 0:sy]


    r = np.hypot(X - sx/2, Y - sy/2)

    rbin = (20* r/r.max()).astype(np.int) ##30 rings --> r-
    radial_mean = ndimage.mean(f, labels=rbin, index=np.arange(1, rbin.max() +1))
    return radial_mean

##add radial average
df['radial_average_ecm']=''
df['radial_average_ecm_bgsubtracted']=''
df['radial_average_dio']=''
df['radial_average_vglut']=''
df['radial_average_vglut_bgsubtracted']=''
for i in range(0,len(df['radial_average_ecm_bgsubtracted'])):
    df['radial_average_ecm_bgsubtracted'][i]=radial_average(df["ecm intensity sted, bg subtracted"][i])
    df['radial_average_ecm'][i]=radial_average(df["sted spot aligned"][i])
    df['radial_average_vglut'][i]=radial_average(df["vglut spot aligned"][i])
    df['radial_average_vglut_bgsubtracted'][i]=radial_average(df["vglut intensity sted, bg subtracted"][i])
    df['radial_average_dio'][i]=radial_average(df["dio spot aligned"][i])
# Out:
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### Add meaningful columns to the df

# %%
#make df, which also contains column names for plotting (drug, condition)
df['Time']='None'
df.loc[df['spots classification filename'].str.contains('12hr'), 'Time'] = '12hrs'
df.loc[df['spots classification filename'].str.contains('Ctrl'), 'Time'] = 'Unblocked Control'
df.loc[df['spots classification filename'].str.contains('Control'), 'Time'] = 'Unblocked Control'

df["Drug"]='None'
df.loc[df['spots classification filename'].str.contains('Bic'), 'Drug'] = 'Bic'
df.loc[df['spots classification filename'].str.contains('bic'), 'Drug'] = 'Bic'
df.loc[df['spots classification filename'].str.contains('DMSO'), 'Drug'] = 'DMSO'
df.loc[df['spots classification filename'].str.contains('Ctrl'), 'Drug'] = 'DMSO'
df.loc[df['spots classification filename'].str.contains('Control'), 'Drug'] = 'DMSO'

#nicely written treatment condition for plotting
df['Condition']='None'
df.loc[df['spots classification filename'].str.contains('12hr_Bic'), 'Condition'] = '12hr + Bic'
df.loc[df['spots classification filename'].str.contains('12hr_DMSO'), 'Condition'] = '12hr'
df.loc[df['spots classification filename'].str.contains('Control'), 'Condition'] = 'Unblocked Control'
df.loc[df['spots classification filename'].str.contains('12hrs_Bic'), 'Condition'] = '12hr + Bic'
df.loc[df['spots classification filename'].str.contains('12hrs_DMSO'), 'Condition'] = '12hr'

# %% [markdown]
# ## Add means and divide by median

# %%
df["Exp name"].unique()
# Out:
# array(['0225', '0302', '0307'], dtype=object)

# %%
df["mean ecm intensity sted, bg subtracted"]=np.nan
df["mean vglut intensity sted, bg subtracted"]=np.nan
for i in range(0,len(df)):
    df["mean ecm intensity sted, bg subtracted"][i]=df["ecm intensity sted, bg subtracted"][i].mean()
    df["mean vglut intensity sted, bg subtracted"][i]=df["vglut intensity sted, bg subtracted"][i].mean()

    
expnam=[]
medtnr=[]
medvglut=[]   
for exp in df["Exp name"].unique():
    dfexp=df[df["Exp name"]==exp]
    med_tnr=dfexp["mean ecm intensity sted, bg subtracted"].median()
    med_vglut=dfexp["mean vglut intensity sted, bg subtracted"].median()
    print(exp+' - med tnr: '+str(med_tnr)+' - med vglut: '+str(med_vglut))
    expnam.append(exp)
    medtnr.append(med_tnr)
    medvglut.append(med_vglut)
df["ecm mean int norm2med"]=np.nan
df["vglut mean int norm2med"]=np.nan
# Out:
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# 0225 - med tnr: 0.07265037547943168 - med vglut: 1.080055683250208
# 0302 - med tnr: 0.1061154624645971 - med vglut: 0.6236793832649349
# 0307 - med tnr: 0.22207896580905692 - med vglut: 0.5101576644743427

# %%
for i in range(0,len(df)):
    if df["Exp name"][i]==expnam[0]:
        df["ecm mean int norm2med"][i]=df["mean ecm intensity sted, bg subtracted"][i]/medtnr[0]
        df["vglut mean int norm2med"][i]=df["mean vglut intensity sted, bg subtracted"][i]/medvglut[0]
    if df["Exp name"][i]==expnam[1]:
        df["ecm mean int norm2med"][i]=df["mean ecm intensity sted, bg subtracted"][i]/medtnr[1]
        df["vglut mean int norm2med"][i]=df["mean vglut intensity sted, bg subtracted"][i]/medvglut[1]
    if df["Exp name"][i]==expnam[2]:
        df["ecm mean int norm2med"][i]=df["mean ecm intensity sted, bg subtracted"][i]/medtnr[2]
        df["vglut mean int norm2med"][i]=df["mean vglut intensity sted, bg subtracted"][i]/medvglut[2]
# Out:
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# ## Calculate a ratio for each cell

# %%
dict_cellratios={"cell id":[],"Exp name":[],"time":[], "drug":[],"condition":[],
                 "axon mean int bg subtracted":[],"axon mean int bg subtracted norm2med":[],
                "dendrite mean int bg subtracted":[],
                "dendrite mean int bg subtracted norm2med":[],
                "mushroom mean int bg subtracted":[],
                "mushroom mean int bg subtracted norm2med":[],
                "flat mean int bg subtracted":[],
                "flat mean int bg subtracted norm2med":[],
                 "ratio axon to dendrite":[],
                 "ratio axon to dendrite norm2meds":[],
                 "ratio axon to mushroom":[],
                 "ratio axon to mushroom norm2meds":[],
                 "ratio axon to flat":[],
                 "ratio axon to flat norm2meds":[]
                }

for cellid in df["unique id (expname_cell number)"].unique():
    dfcell=df[df["unique id (expname_cell number)"]==cellid]
    dict_cellratios["cell id"].append(cellid)
    dict_cellratios["Exp name"].append(dfcell["Exp name"].unique()[0])
    dict_cellratios["time"].append(dfcell["Time"].unique()[0])
    dict_cellratios["drug"].append(dfcell["Drug"].unique()[0])
    dict_cellratios["condition"].append(dfcell["Condition"].unique()[0])
    
    axonmean=dfcell[dfcell["classification"]==3]["mean ecm intensity sted, bg subtracted"].mean()
    axonnorm2medmean=dfcell[dfcell["classification"]==3]["ecm mean int norm2med"].mean()
    dendritemean=dfcell[(dfcell["classification"]!=3)&(dfcell["classification"]!=4)]["mean ecm intensity sted, bg subtracted"].mean()
    dendritenorm2medmean=dfcell[(dfcell["classification"]!=3)&(dfcell["classification"]!=4)]["ecm mean int norm2med"].mean()
    mushroommean=dfcell[dfcell["classification"]==1]["mean ecm intensity sted, bg subtracted"].mean()
    mushroomnorm2medmean=dfcell[dfcell["classification"]==1]["ecm mean int norm2med"].mean()
    flatmean=dfcell[dfcell["classification"]==2]["mean ecm intensity sted, bg subtracted"].mean()
    flatnorm2medmean=dfcell[dfcell["classification"]==2]["ecm mean int norm2med"].mean()
    
    ratioaxdendrite=axonmean/dendritemean
    ratioaxdendritenorm2meds=axonnorm2medmean/dendritenorm2medmean
    ratioaxmush=axonmean/mushroommean
    ratioaxmushnorm2med=axonnorm2medmean/mushroomnorm2medmean
    ratioaxflat=axonmean/flatmean
    ratioaxflatnorm2med=axonnorm2medmean/flatnorm2medmean
    
    dict_cellratios["axon mean int bg subtracted"].append(axonmean)
    dict_cellratios["axon mean int bg subtracted norm2med"].append(axonnorm2medmean)

    dict_cellratios["dendrite mean int bg subtracted"].append(dendritemean)
    dict_cellratios["dendrite mean int bg subtracted norm2med"].append(dendritenorm2medmean)
    
    dict_cellratios["mushroom mean int bg subtracted"].append(mushroommean)
    dict_cellratios["mushroom mean int bg subtracted norm2med"].append(mushroomnorm2medmean)
    
    dict_cellratios["flat mean int bg subtracted"].append(flatmean)
    dict_cellratios["flat mean int bg subtracted norm2med"].append(flatnorm2medmean)
    
    dict_cellratios["ratio axon to dendrite"].append(ratioaxdendrite)
    dict_cellratios["ratio axon to dendrite norm2meds"].append(ratioaxdendritenorm2meds)
    dict_cellratios["ratio axon to mushroom"].append(ratioaxmush)
    dict_cellratios["ratio axon to mushroom norm2meds"].append(ratioaxmushnorm2med)
    dict_cellratios["ratio axon to flat"].append(ratioaxflat)
    dict_cellratios["ratio axon to flat norm2meds"].append(ratioaxflatnorm2med)

# %%
dfcells=pd.DataFrame(dict_cellratios)

# %% [markdown]
# ## save the pickle

# %%
dfcells.to_pickle(expdir+'dfcells.pkl')

# %% [markdown]
# ## Plot ratios

# %%
vari=["axon mean int bg subtracted norm2med",
      "dendrite mean int bg subtracted norm2med",
      "mushroom mean int bg subtracted norm2med",
      "flat mean int bg subtracted norm2med",
      "ratio axon to dendrite",
      "ratio axon to mushroom norm2meds",
      "ratio axon to flat norm2meds"
     ]

for vary in range(0,len(vari)):
    var=vari[vary]
    plt.figure()
    plt.title(var)
    i=-1
    colors=["red","green","blue"]
    for exp in dfcells["Exp name"].unique():
        #print(exp)
        dfexp=dfcells[dfcells["Exp name"]==exp]
        #print(dfexp[var].mean())
        i+=1

        #g=sns.scatterplot(y=var,x="drug",
        #                data=dfexp,color=colors[i])
        g=sns.swarmplot(y=var,
                        data=dfexp,color=colors[i])
        #plt.ylim([0,2])

# %%
dfplot=dfcells.dropna()
dfplot=dfplot[dfplot["dendrite mean int bg subtracted norm2med"]<dfplot["dendrite mean int bg subtracted norm2med"].quantile(0.99)]

# %%
#sns.violinplot(x="condition",y="ratio axon to dendrite norm2meds",data=dfcells)
g=sns.swarmplot(x="condition",y="ratio axon to dendrite norm2meds",data=dfcells,color='black')
g=sns.boxplot(x="condition",y="ratio axon to dendrite norm2meds",data=dfcells,color='grey',showfliers=False)
plt.ylim([0,3])
plt.ylabel('Ratio axon to dendrite',fontsize=16)
plt.xlabel('')
plt.xticks(g.get_xticks(),fontsize=16,rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x1289ef5f8>,
#   <matplotlib.axis.XTick at 0x128bf1cf8>,
#   <matplotlib.axis.XTick at 0x128bf1390>],
#  <a list of 3 Text xticklabel objects>)

# %%
i=0
fig=plt.figure(figsize=(9,3))
for condition in dfplot["condition"].unique():
    print(condition)
    i+=1
    
    fig.add_subplot(1,3,i)
    plt.title(condition,fontsize=18)
    df2plot=dfplot[dfplot["condition"]==condition]
    sns.kdeplot(df2plot["axon mean int bg subtracted norm2med"],
                df2plot["dendrite mean int bg subtracted norm2med"])
    sns.scatterplot(y=df2plot["axon mean int bg subtracted norm2med"],
                x=df2plot["dendrite mean int bg subtracted norm2med"])
    plt.ylim([-1,5])
    plt.xlim([-1,5])
    plt.xlabel('')
    plt.ylabel('')
    if i==1:
        plt.ylabel('Axon mean intensity', fontsize=16)
    if i==2:
        plt.xlabel('Dendrite mean intensity', fontsize=16)
# Out:
# 12hr
# 12hr + Bic
# Unblocked Control

# %%
g=sns.scatterplot(x="axon mean int bg subtracted norm2med",
              y="dendrite mean int bg subtracted norm2med",
              data=dfplot)
#plt.xlim([0,5])
#plt.ylim([0,5])

# %%
dfplot["condition"].unique()
# Out:
# array(['12hr', '12hr + Bic', 'Unblocked Control'], dtype=object)

# %% [markdown]
# ## nice plot - norm2meds 12hr dmso

# %%
df2plot=dfplot[dfplot["condition"]=="12hr"]
sns.set(font_scale=2.5)
sns.set(font="Arial")
sns.set_style("ticks")
sns.despine()
sns.set_palette("Set2")

#y="intensity normd 0 to 1"
var="mean tnr"
#y="intensity raw"
#y="raw intensity normd to dio mean"
fig=plt.figure(figsize=(5,5))
#order=['2hrs','4hrs','12hrs','No Blocking']
#palette ={"No Blocking":"gray","2hrs":"magenta","4hrs":"magenta","12hrs":"magenta"}


g=sns.scatterplot(x="dendrite mean int bg subtracted norm2med",
              y="axon mean int bg subtracted norm2med",
                data=df2plot,s=100,color="#2F67F8",linewidth=1,edgecolor='grey')

'''g=sns.barplot(x="mean vglut int in bin overall",y="mean tnr",
                data=dfmeans,alpha=0.3,ci=None,color="#2F67F8")'''



'''plt.errorbar(x = dfmeans["mean vglut int in bin overall"].unique()
,
             y=[dfmeans[dfmeans["bin number"]==0][var].mean(),
                dfmeans[dfmeans["bin number"]==1][var].mean(),
                dfmeans[dfmeans["bin number"]==2][var].mean(),
                dfmeans[dfmeans["bin number"]==3][var].mean(),
                dfmeans[dfmeans["bin number"]==4][var].mean()],
             yerr=[dfmeans[dfmeans["bin number"]==0][var].sem(),
                   dfmeans[dfmeans["bin number"]==1][var].sem(),
                   dfmeans[dfmeans["bin number"]==2][var].sem(),
                   dfmeans[dfmeans["bin number"]==3][var].sem(),
                   dfmeans[dfmeans["bin number"]==4][var].sem()],
             xerr=None,ecolor='black',fmt='none',capsize=10,linewidth=3,capthick=3,alpha=.7,)

plt.errorbar(x = dfmeans["mean vglut int in bin overall"].unique()
,
             y=[dfmeans[dfmeans["bin number"]==0][var].mean(),
                dfmeans[dfmeans["bin number"]==1][var].mean(),
                dfmeans[dfmeans["bin number"]==2][var].mean(),
                dfmeans[dfmeans["bin number"]==3][var].mean(),
                dfmeans[dfmeans["bin number"]==4][var].mean()],
             yerr=None,
             xerr=[.14,.14,.14,.14,.14],ecolor='black',fmt='none',capsize=0,linewidth=3,capthick=3,alpha=.7,)'''



#plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Helvetica'

g.grid(False)
plt.ylim([0,4])
plt.xlim([0,2.5])



x=df2plot["dendrite mean int bg subtracted norm2med"]
y=df2plot["axon mean int bg subtracted norm2med"]
m,b = np.polyfit(x, y, 1) 

plt.plot( x, m*x+b, 'k',alpha=.4,linewidth=5) 

#plt.xticks(dfmeans["mean vglut int in bin overall"].unique(),size=18)

g.xaxis.set_tick_params(width=3)
g.yaxis.set_tick_params(width=3)

#plt.axhline(dfmeans[dfmeans["bin number"]==0][var].mean(),xmin=0.057,xmax=0.17, color='black',alpha=.7,linewidth=3)
#plt.axhline(dfmeans[dfmeans["bin number"]==1][var].mean(),xmin=0.15,xmax=0.3, color='black',alpha=.7,linewidth=3)
#plt.axhline(dfmeans[dfmeans["bin number"]==2][var].mean(),xmin=0.26,xmax=0.41, color='black',alpha=.7,linewidth=3)
#plt.axhline(dfmeans[dfmeans["bin number"]==3][var].mean(),xmin=0.42,xmax=0.59, color='black',alpha=.7,linewidth=3)
#plt.axhline(dfmeans[dfmeans["bin number"]==4][var].mean(),xmin=0.8,xmax=0.97, color='black',alpha=.7,linewidth=3)




for axis in ['top','bottom','left','right']:
  g.spines[axis].set_linewidth(4)
  g.spines[axis].set_color('#333333')
  g.spines[axis].set_alpha(1)


offsets={"left":10,"bottom":0}
trims={"left":True,"bottom":True,"right":False}
sns.despine(ax=g,right=True,top=True,bottom=False,trim=False,offset=offsets)


#g.set_ylabel('TNR Normalised\nFluorescence intensity',
#             size=24,weight ='bold',labelpad=20,color='#333333')
#g.set_xlabel('vglut1 Normalised\nFluorescence intensity',
#             size=24,weight ='bold',labelpad=20,color='#333333')
g.set_ylabel('')
g.set_xlabel('')
plt.yticks([0,2,4],color='#333333',size=24)
plt.xticks([0,1,2],color='#333333',size=24)




diri="/Volumes/Macintosh HD/Users/taldankovich/Downloads/figures/"
fig.savefig(diri+'supp_axon_dendrite_ratio_12hrdmso.svg', bbox_inches='tight', format='svg')
# Out:
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
from pydoc import help
from scipy.stats.stats import pearsonr
[pearson, pval]=pearsonr(x,y)
print(str(pearson**2))
print(pval)
print(pearson)
print('slope = '+str(m))
# Out:
# 0.15699607005776328
# 0.09307124200909449
# 0.3962272959524158
# slope = 0.6068216540318211

# %% [markdown]
# ## nice plot - bic

# %%
df2plot=dfplot[dfplot["condition"]=="12hr + Bic"]
sns.set(font_scale=2.5)
sns.set(font="Arial")
sns.set_style("ticks")
sns.despine()
sns.set_palette("Set2")

#y="intensity normd 0 to 1"
var="mean tnr"
#y="intensity raw"
#y="raw intensity normd to dio mean"
fig=plt.figure(figsize=(5,5))
#order=['2hrs','4hrs','12hrs','No Blocking']
#palette ={"No Blocking":"gray","2hrs":"magenta","4hrs":"magenta","12hrs":"magenta"}


g=sns.scatterplot(x="dendrite mean int bg subtracted norm2med",
              y="axon mean int bg subtracted norm2med",
                data=df2plot,s=100,color="#2F67F8",linewidth=1,edgecolor='grey')

'''g=sns.barplot(x="mean vglut int in bin overall",y="mean tnr",
                data=dfmeans,alpha=0.3,ci=None,color="#2F67F8")'''



'''plt.errorbar(x = dfmeans["mean vglut int in bin overall"].unique()
,
             y=[dfmeans[dfmeans["bin number"]==0][var].mean(),
                dfmeans[dfmeans["bin number"]==1][var].mean(),
                dfmeans[dfmeans["bin number"]==2][var].mean(),
                dfmeans[dfmeans["bin number"]==3][var].mean(),
                dfmeans[dfmeans["bin number"]==4][var].mean()],
             yerr=[dfmeans[dfmeans["bin number"]==0][var].sem(),
                   dfmeans[dfmeans["bin number"]==1][var].sem(),
                   dfmeans[dfmeans["bin number"]==2][var].sem(),
                   dfmeans[dfmeans["bin number"]==3][var].sem(),
                   dfmeans[dfmeans["bin number"]==4][var].sem()],
             xerr=None,ecolor='black',fmt='none',capsize=10,linewidth=3,capthick=3,alpha=.7,)

plt.errorbar(x = dfmeans["mean vglut int in bin overall"].unique()
,
             y=[dfmeans[dfmeans["bin number"]==0][var].mean(),
                dfmeans[dfmeans["bin number"]==1][var].mean(),
                dfmeans[dfmeans["bin number"]==2][var].mean(),
                dfmeans[dfmeans["bin number"]==3][var].mean(),
                dfmeans[dfmeans["bin number"]==4][var].mean()],
             yerr=None,
             xerr=[.14,.14,.14,.14,.14],ecolor='black',fmt='none',capsize=0,linewidth=3,capthick=3,alpha=.7,)'''



#plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Helvetica'

g.grid(False)
plt.ylim([0,3])
plt.xlim([0,3])



x=df2plot["dendrite mean int bg subtracted norm2med"]
y=df2plot["axon mean int bg subtracted norm2med"]
m,b = np.polyfit(x, y, 1) 

plt.plot( x, m*x+b, 'k',linestyle='dashed',alpha=.4,linewidth=5) 

#plt.xticks(dfmeans["mean vglut int in bin overall"].unique(),size=18)

g.xaxis.set_tick_params(width=3)
g.yaxis.set_tick_params(width=3)

#plt.axhline(dfmeans[dfmeans["bin number"]==0][var].mean(),xmin=0.057,xmax=0.17, color='black',alpha=.7,linewidth=3)
#plt.axhline(dfmeans[dfmeans["bin number"]==1][var].mean(),xmin=0.15,xmax=0.3, color='black',alpha=.7,linewidth=3)
#plt.axhline(dfmeans[dfmeans["bin number"]==2][var].mean(),xmin=0.26,xmax=0.41, color='black',alpha=.7,linewidth=3)
#plt.axhline(dfmeans[dfmeans["bin number"]==3][var].mean(),xmin=0.42,xmax=0.59, color='black',alpha=.7,linewidth=3)
#plt.axhline(dfmeans[dfmeans["bin number"]==4][var].mean(),xmin=0.8,xmax=0.97, color='black',alpha=.7,linewidth=3)




for axis in ['top','bottom','left','right']:
  g.spines[axis].set_linewidth(4)
  g.spines[axis].set_color('#333333')
  g.spines[axis].set_alpha(1)


offsets={"left":10,"bottom":0}
trims={"left":True,"bottom":True,"right":False}
sns.despine(ax=g,right=True,top=True,bottom=False,trim=False,offset=offsets)


#g.set_ylabel('TNR Normalised\nFluorescence intensity',
#             size=24,weight ='bold',labelpad=20,color='#333333')
#g.set_xlabel('vglut1 Normalised\nFluorescence intensity',
#             size=24,weight ='bold',labelpad=20,color='#333333')
g.set_ylabel('')
g.set_xlabel('')
plt.yticks([0,1,2,3],color='#333333',size=24)
plt.xticks([0,1,2,3],color='#333333',size=24)




diri="/Volumes/Macintosh HD/Users/taldankovich/Downloads/figures/"
fig.savefig(diri+'supp_axon_dendrite_ratio_12hrbic.svg', bbox_inches='tight', format='svg')

# %%
from pydoc import help
from scipy.stats.stats import pearsonr
[pearson, pval]=pearsonr(x,y)
print(str(pearson**2))
print(pval)
print(pearson)
print('slope = '+str(m))
# Out:
# 0.13786801999479942
# 0.23470024944684276
# 0.37130583081174395
# slope = 0.3781304531376259

# %% [markdown]
# ## nice plot norm2med - unblocked

# %%
df2plot=dfplot[dfplot["condition"]=="Unblocked Control"]
sns.set(font_scale=2.5)
sns.set(font="Arial")
sns.set_style("ticks")
sns.despine()
sns.set_palette("Set2")

#y="intensity normd 0 to 1"
var="mean tnr"
#y="intensity raw"
#y="raw intensity normd to dio mean"
fig=plt.figure(figsize=(5,5))
#order=['2hrs','4hrs','12hrs','No Blocking']
#palette ={"No Blocking":"gray","2hrs":"magenta","4hrs":"magenta","12hrs":"magenta"}


g=sns.scatterplot(x="dendrite mean int bg subtracted norm2med",
              y="axon mean int bg subtracted norm2med",
                data=df2plot,s=100,color="#2F67F8",linewidth=1,edgecolor='grey')

'''g=sns.barplot(x="mean vglut int in bin overall",y="mean tnr",
                data=dfmeans,alpha=0.3,ci=None,color="#2F67F8")'''



'''plt.errorbar(x = dfmeans["mean vglut int in bin overall"].unique()
,
             y=[dfmeans[dfmeans["bin number"]==0][var].mean(),
                dfmeans[dfmeans["bin number"]==1][var].mean(),
                dfmeans[dfmeans["bin number"]==2][var].mean(),
                dfmeans[dfmeans["bin number"]==3][var].mean(),
                dfmeans[dfmeans["bin number"]==4][var].mean()],
             yerr=[dfmeans[dfmeans["bin number"]==0][var].sem(),
                   dfmeans[dfmeans["bin number"]==1][var].sem(),
                   dfmeans[dfmeans["bin number"]==2][var].sem(),
                   dfmeans[dfmeans["bin number"]==3][var].sem(),
                   dfmeans[dfmeans["bin number"]==4][var].sem()],
             xerr=None,ecolor='black',fmt='none',capsize=10,linewidth=3,capthick=3,alpha=.7,)

plt.errorbar(x = dfmeans["mean vglut int in bin overall"].unique()
,
             y=[dfmeans[dfmeans["bin number"]==0][var].mean(),
                dfmeans[dfmeans["bin number"]==1][var].mean(),
                dfmeans[dfmeans["bin number"]==2][var].mean(),
                dfmeans[dfmeans["bin number"]==3][var].mean(),
                dfmeans[dfmeans["bin number"]==4][var].mean()],
             yerr=None,
             xerr=[.14,.14,.14,.14,.14],ecolor='black',fmt='none',capsize=0,linewidth=3,capthick=3,alpha=.7,)'''



#plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Helvetica'

g.grid(False)
plt.ylim([0,4])
plt.xlim([0,3])



x=df2plot["dendrite mean int bg subtracted norm2med"]
y=df2plot["axon mean int bg subtracted norm2med"]
m,b = np.polyfit(x, y, 1) 

plt.plot( x, m*x+b, 'k',alpha=.4,linewidth=5) 

#plt.xticks(dfmeans["mean vglut int in bin overall"].unique(),size=18)

g.xaxis.set_tick_params(width=3)
g.yaxis.set_tick_params(width=3)

#plt.axhline(dfmeans[dfmeans["bin number"]==0][var].mean(),xmin=0.057,xmax=0.17, color='black',alpha=.7,linewidth=3)
#plt.axhline(dfmeans[dfmeans["bin number"]==1][var].mean(),xmin=0.15,xmax=0.3, color='black',alpha=.7,linewidth=3)
#plt.axhline(dfmeans[dfmeans["bin number"]==2][var].mean(),xmin=0.26,xmax=0.41, color='black',alpha=.7,linewidth=3)
#plt.axhline(dfmeans[dfmeans["bin number"]==3][var].mean(),xmin=0.42,xmax=0.59, color='black',alpha=.7,linewidth=3)
#plt.axhline(dfmeans[dfmeans["bin number"]==4][var].mean(),xmin=0.8,xmax=0.97, color='black',alpha=.7,linewidth=3)




for axis in ['top','bottom','left','right']:
  g.spines[axis].set_linewidth(4)
  g.spines[axis].set_color('#333333')
  g.spines[axis].set_alpha(1)


offsets={"left":10,"bottom":0}
trims={"left":True,"bottom":True,"right":False}
sns.despine(ax=g,right=True,top=True,bottom=False,trim=False,offset=offsets)


#g.set_ylabel('TNR Normalised\nFluorescence intensity',
#             size=24,weight ='bold',labelpad=20,color='#333333')
#g.set_xlabel('vglut1 Normalised\nFluorescence intensity',
#             size=24,weight ='bold',labelpad=20,color='#333333')
g.set_ylabel('')
g.set_xlabel('')
plt.yticks([0,2,4],color='#333333',size=24)
plt.xticks([0,1,2,3],color='#333333',size=24)




diri="/Volumes/Macintosh HD/Users/taldankovich/Downloads/figures/"
fig.savefig(diri+'supp_axon_dendrite_ratio_unblocked.svg', bbox_inches='tight', format='svg')

# %%
from pydoc import help
from scipy.stats.stats import pearsonr
[pearson, pval]=pearsonr(x,y)
print(str(pearson**2))
print(pval)
print(pearson)
print('slope = '+str(m))
# Out:
# 0.4464204349639499
# 0.03471289985459847
# 0.668147015980727
# slope = 1.2898868274423458
