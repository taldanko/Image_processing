# %%
import numpy as np
import os
from nd2reader import ND2Reader
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib_scalebar.scalebar import ScaleBar
import scipy.ndimage as ndi
from skimage.filters import rank 
from scipy.signal import butter, lfilter
import scipy.misc as misc
from skimage import exposure
from PIL import Image
import colorcet as cc
from scipy.misc import toimage
import matplotlib.colors as clr
import pandas as pd
import seaborn as sns
from scipy import stats
import cv2
from pyspark import SparkContext, SparkConf
import skimage
from pathlib import Path

def mean2(x):
    y = np.sum(x) / np.size(x);
    return y
def corr2(a,b):
    a = a - mean2(a)
    b = b - mean2(b)

    r = (a*b).sum() / np.sqrt((a*a).sum() * (b*b).sum());
    return r
from copy import deepcopy
from skimage.filters import threshold_otsu,threshold_li
import glob
from IPython.display import clear_output
import scipy.io as spio
import pims
import fnmatch
from skimage import io
import os.path, time

# %%
expdir='/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/' #master folder
protein="int" #TNR,Agg,WFA,HABP

# %%
results = {"calcium recording filename":[], "corresponding syt/clumps filename":[],
           "clumpschannelno":[],"synapsechannelno":[],
           "spontaneous or stimulation":[],
           "magnification":[],
           "Manual mask from matlab GUI":[],
           
           "calcium mean intensity whole frame":[],
           "calcium mean intensity in rois":[],
           "calcium [f(t)-f(0)]/f(0) in rois":[],
           "total calcium influx (AOC of [f(t)-f(0)]/f(0) in rois)":[],
           "calcium slope downwards":[],
           
           #"synapse mask (dilated syt1)":[],
           #"df/f under dilated syt mask":[],
           
           "synchronicity (pearson)":[],
           "synchronicity (no. of peaks)":[]}

path = os.path.dirname(expdir)  
filelist = []
for root, _, filenames in os.walk(path):
     for filename in filenames:
         filelist.append(os.path.join(root, filename))      
for i in range(0,len(filelist)):
    
    if ("ignore for analysis" in str(filelist[i]))==False:
        #if ("20191029" in str(filelist[i]))==False:
            if ("syt" in str(filelist[i]))==False:

                if filelist[i].endswith(".tif"): 
                    print(filelist[i])
                    results["calcium recording filename"].append(filelist[i])


                    channeldir="/".join(filelist[i].split("/")[:-2])
                    exec(open(channeldir+"/channels.txt").read())
                    results["clumpschannelno"].append(clumpschannelno)
                    results["synapsechannelno"].append(synapsechannelno)
                    
                    if ('spontaneous' in str(filelist[i]))==True:
                        results["spontaneous or stimulation"].append('spontaneous')
                        print('spont')

                    else:
                        results["spontaneous or stimulation"].append('stim')
                        print('stim')
                    if "60x" in str(filelist[i]):
                        results["magnification"].append('60x')
                    else:
                        results["magnification"].append('20x')

                    #add syt image if exists
                    a=filelist[i]
                    no=a.split('field')[-1][0]

                    filelist_syt = []
                    syt_image=[]
                    for root, _, filenames in os.walk(path):
                         for filename in filenames:
                             filelist_syt.append(os.path.join(root, filename))      
                    for ij in range(0,len(filelist_syt)):
                        if ("syt" in str(filelist_syt[ij])):
                            if (a.split('field')[0]+'field'+str(no)) in str(filelist_syt[ij]):
                                syt_image.append(filelist_syt[ij])
                    if len(syt_image)>0:
                        results["corresponding syt/clumps filename"].append(syt_image[:])
                        print(syt_image[:])
                    else:
                        results["corresponding syt/clumps filename"].append('no image')
# Out:
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps1/spontaneous/20x_spontaneous_activity_field3.tif
# spont
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps1/spontaneous/20x_spontaneous_activity_field3_syt_clumps.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps1/spontaneous/20x_spontaneous_activity_field2.tif
# spont
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps1/60x_post_ttx_stim/60x_field1_stim.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps1/60x_post_ttx_stim/60x_field1_syt_clumps.tif', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps1/60x_post_ttx_stim/60x_field1_syt_clumps_dendritesmask.mat']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps1/60x_post_ttx_stim/60x_field2_stim.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps1/60x_post_ttx_stim/60x_field2_syt_clumps.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps1/60x_post_ttx_stim/60x_field3_stim.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps1/60x_post_ttx_stim/60x_field3_syt_clumps.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps1/60x_post_ttx_stim/60x_field4_stim.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps1/60x_post_ttx_stim/60x_field4_syt_clumps.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps1/60x_post_ttx_stim/60x_field5_stim.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps1/60x_post_ttx_stim/60x_field5_syt_clumps.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps1/60x_post_ttx_stim/60x_field6_stim.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps1/60x_post_ttx_stim/60x_field6_syt_clumps.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps3/spontaneous/20x_field1.tif
# spont
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps3/spontaneous/20x_field1_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps3/post ttx 60x stim/60x_field1.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps3/post ttx 60x stim/60x_field1_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps3/post ttx 60x stim/60x_field2.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps3/post ttx 60x stim/60x_field2_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps3/post ttx 60x stim/60x_field3.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps3/post ttx 60x stim/60x_field3_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps3/post ttx 60x stim/60x_field4.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps3/post ttx 60x stim/60x_field4_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps3/post ttx 60x stim/60x_field5.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps3/post ttx 60x stim/60x_field5_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps4/spontaneous/20x_field1.tif
# spont
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps4/spontaneous/20x_field1_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps4/post ttx stim/60x_field3.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps4/post ttx stim/60x_field3_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps4/post ttx stim/60x_field2.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps4/post ttx stim/60x_field2_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Clumps1_20x/spontaneous/20191020_clump_prettx_field2.tif
# spont
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Clumps1_20x/spontaneous/20191020_clump_prettx_field2_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Clumps1_20x/spontaneous/20191020_clump_prettxspont_field1.tif
# spont
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Clumps1_20x/post ttx stim/20191020_clump_postttx_field1.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Clumps1_20x/post ttx stim/20191020_clump_postttx_field1_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Clumps1_20x/post ttx stim/20191020_clump_postttx_field2.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Clumps1_20x/post ttx stim/20191020_clump_postttx_field2_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Clumps1_20x/post ttx stim/20191020_clump_postttx_field3.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Clumps1_20x/post ttx stim/20191020_clump_postttx_field3_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Clumps1_20x/post ttx stim/20191020_clump_postttx_field4.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Clumps1_20x/post ttx stim/20191020_clump_postttx_field4_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Clumps1_20x/post ttx stim/20191020_clump_postttx_field5.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Clumps1_20x/post ttx stim/20191020_clump_postttx_field5_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Clumps1_20x/post ttx stim/20191020_clump_postttx_field6.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Clumps1_20x/post ttx stim/20191020_clump_postttx_field6_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Ctrl1_20x/spontaneous/20191020_ctrl_prettx.tif
# spont
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Ctrl1_20x/post ttx stim/20191020_ctrl_postttxstim_field1.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Ctrl1_20x/post ttx stim/20191020_ctrl_postttxstim_field1_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Ctrl1_20x/post ttx stim/20191020_ctrl_postttxstim_field2.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Ctrl1_20x/post ttx stim/20191020_ctrl_postttxstim_field2_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Ctrl1_20x/post ttx stim/20191020_ctrl_postttxstim_field3.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Ctrl1_20x/post ttx stim/20191020_ctrl_postttxstim_field3_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Ctrl1_20x/post ttx stim/20191020_ctrl_postttxstim_field4.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Ctrl1_20x/post ttx stim/20191020_ctrl_postttxstim_field4_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Ctrl1_20x/post ttx stim/20191020_ctrl_postttxstim_field5.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Ctrl1_20x/post ttx stim/20191020_ctrl_postttxstim_field5_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Ctrl2_20x/spontaneous/20191020_ctrl_field1_prettx.tif
# spont
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Ctrl2_20x/spontaneous/20191020_ctrl_field1_prettx_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Ctrl2_20x/post ttx stim/20191020_ctrl3l_postttx_field1.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Ctrl2_20x/post ttx stim/20191020_ctrl3l_postttx_field1_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Ctrl2_20x/post ttx stim/20191020_ctrl3l_postttx_field2.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Ctrl2_20x/post ttx stim/20191020_ctrl3l_postttx_field2_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Ctrl2_20x/post ttx stim/20191020_ctrl3l_postttx_field3.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Ctrl2_20x/post ttx stim/20191020_ctrl3l_postttx_field3_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Ctrl2_20x/post ttx stim/20191020_ctrl3l_postttx_field4.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Ctrl2_20x/post ttx stim/20191020_ctrl3l_postttx_field4_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Ctrl2_20x/post ttx stim/20191020_ctrl3l_postttx_field5.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191020_Ctrl2_20x/post ttx stim/20191020_ctrl3l_postttx_field5_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump1/post ttx/Ctrl1_stim_field1.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump1/post ttx/Ctrl1_stim_field1_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump1/post ttx/Ctrl1_stim_field1_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump1/post ttx/Ctrl1_stim_field2.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump1/post ttx/Ctrl1_stim_field2_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump1/post ttx/Ctrl1_stim_field2_syt001.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump1/post ttx/Ctrl1_stim_field2_syt.tif', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump1/post ttx/Ctrl1_stim_field2_syt001.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump1/post ttx/Ctrl1_stim_field3.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump1/post ttx/Ctrl1_stim_field3_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump1/post ttx/Ctrl1_stim_field3_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump1/post ttx/Ctrl1_stim_field4.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump1/post ttx/Ctrl1_stim_field4_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump1/post ttx/Ctrl1_stim_field4_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump1/post ttx/Ctrl1_stim_field5.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump1/post ttx/Ctrl1_stim_field5_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump1/post ttx/Ctrl1_stim_field5_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump1/spontaneous/Ctrl1_spont_field1.tif
# spont
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump1/spontaneous/Ctrl1_spont_field1_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump1/spontaneous/Ctrl1_spont_field1_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump1/spontaneous/Ctrl1_spont_field2.tif
# spont
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump1/spontaneous/Ctrl1_spont_field2_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump1/spontaneous/Ctrl1_spont_field2_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump2/post ttx/Ctrl1_stim_field1.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump2/post ttx/Ctrl1_stim_field1_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump2/post ttx/Ctrl1_stim_field1_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump2/post ttx/Ctrl1_stim_field2.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump2/post ttx/Ctrl1_stim_field2_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump2/post ttx/Ctrl1_stim_field2_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump2/post ttx/Ctrl1_stim_field3.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump2/post ttx/Ctrl1_stim_field3_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump2/post ttx/Ctrl1_stim_field3_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump2/post ttx/Ctrl1_stim_field4.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump2/post ttx/Ctrl1_stim_field4_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump2/post ttx/Ctrl1_stim_field4_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump2/post ttx/Ctrl1_stim_field5.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump2/post ttx/Ctrl1_stim_field5_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump2/post ttx/Ctrl1_stim_field5_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump2/spontaneous/Ctrl1_spont_field1.tif
# spont
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump2/spontaneous/Ctrl1_spont_field1_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Clump2/spontaneous/Ctrl1_spont_field1_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl1/post ttx/Ctrl1_stim_field1.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl1/post ttx/Ctrl1_stim_field1_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl1/post ttx/Ctrl1_stim_field1_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl1/post ttx/Ctrl1_stim_field2.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl1/post ttx/Ctrl1_stim_field2_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl1/post ttx/Ctrl1_stim_field2_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl1/post ttx/Ctrl1_stim_field3.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl1/post ttx/Ctrl1_stim_field3_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl1/post ttx/Ctrl1_stim_field3_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl1/post ttx/Ctrl1_stim_field41.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl1/post ttx/Ctrl1_stim_field4_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl1/post ttx/Ctrl1_stim_field4_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl1/post ttx/Ctrl1_stim_field5.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl1/post ttx/Ctrl1_stim_field5_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl1/post ttx/Ctrl1_stim_field5_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl1/spontaneous/Ctrl1_spont_field1.tif
# spont
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl1/spontaneous/Ctrl1_spont_field1_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl1/spontaneous/Ctrl1_spont_field1_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl1/spontaneous/Ctrl1_spont_field2.tif
# spont
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl1/spontaneous/Ctrl1_spont_field2_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl1/spontaneous/Ctrl1_spont_field2_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl2/post ttx/Ctrl1_stim_field5.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl2/post ttx/Ctrl1_stim_field5_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl2/post ttx/Ctrl1_stim_field5_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl2/post ttx/Ctrl1_stim_field4.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl2/post ttx/Ctrl1_stim_field4_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl2/post ttx/Ctrl1_stim_field4_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl2/post ttx/Ctrl1_stim_field3.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl2/post ttx/Ctrl1_stim_field3_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl2/post ttx/Ctrl1_stim_field3_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl2/post ttx/Ctrl1_stim_field2.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl2/post ttx/Ctrl1_stim_field2_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl2/post ttx/Ctrl1_stim_field2_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl2/post ttx/Ctrl1_stim_field1.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl2/post ttx/Ctrl1_stim_field1_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl2/post ttx/Ctrl1_stim_field1_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl2/spontaneous/Ctrl1_spont_field1.tif
# spont
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl2/spontaneous/Ctrl1_spont_field1_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl2/spontaneous/Ctrl1_spont_field1_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl2/spontaneous/Ctrl1_spont_field2.tif
# spont
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl2/spontaneous/Ctrl1_spont_field2_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl2/spontaneous/Ctrl1_spont_field2_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl3/post ttx/Ctrl1_stimt_field1.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl3/post ttx/Ctrl1_stimt_field1_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl3/post ttx/Ctrl1_stimt_field1_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl3/post ttx/Ctrl1_stimt_field2.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl3/post ttx/Ctrl1_stimt_field2_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl3/post ttx/Ctrl1_stimt_field2_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl3/post ttx/Ctrl1_stimt_field3.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl3/post ttx/Ctrl1_stimt_field3_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl3/post ttx/Ctrl1_stimt_field3_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl3/post ttx/Ctrl1_stimt_field4.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl3/post ttx/Ctrl1_stimt_field4_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl3/post ttx/Ctrl1_stimt_field4_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl3/post ttx/Ctrl1_stimt_field5.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl3/post ttx/Ctrl1_stimt_field5_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl3/post ttx/Ctrl1_stimt_field5_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl3/spontaneous/Ctrl1_spont_field1.tif
# spont
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl3/spontaneous/Ctrl1_spont_field1_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl3/spontaneous/Ctrl1_spont_field1_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl4/post ttx/Ctrl1_stim_field1.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl4/post ttx/Ctrl1_stim_field1_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl4/post ttx/Ctrl1_stim_field1_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl4/post ttx/Ctrl1_stim_field2.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl4/post ttx/Ctrl1_stim_field2_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl4/post ttx/Ctrl1_stim_field2_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl4/post ttx/Ctrl1_stim_field3.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl4/post ttx/Ctrl1_stim_field3_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl4/post ttx/Ctrl1_stim_field3_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl4/post ttx/Ctrl1_stim_field4.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl4/post ttx/Ctrl1_stim_field4_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl4/post ttx/Ctrl1_stim_field4_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl4/post ttx/Ctrl1_stim_field5.tif
# stim
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl4/post ttx/Ctrl1_stim_field5_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl4/post ttx/Ctrl1_stim_field5_syt.tif']
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl4/spontaneous/Ctrl1_spont_field1.tif
# spont
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl4/spontaneous/Ctrl1_spont_field1_syt.nd2', '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191029_Ctrl4/spontaneous/Ctrl1_spont_field1_syt.tif']

# %% [markdown]
# ## load matlab

# %%
for im in range(0,len(results["calcium recording filename"])): 
    file=results["calcium recording filename"][im][:-4]+'_dendritesmask.mat'
    from pathlib import Path
    my_file = Path(file)
    if my_file.exists():
        print(file)
        mat = spio.loadmat(file, squeeze_me=True)
        mask=mat['totMask']>0.99
        results["Manual mask from matlab GUI"].append(mask)
    else:
        results["Manual mask from matlab GUI"].append(np.nan)
clear_output()        
print("Done!")
# Out:
# Done!

# %% [markdown]
# ## loop over images

# %%
for im in range(0,len(results["calcium recording filename"])):
    
    image_name=results["calcium recording filename"][im]
    image = io.imread(image_name)
    matlab_mask=results["Manual mask from matlab GUI"][im]
    
    #background 
    bg=np.mean(ndi.median_filter(image[0],size=5))+0*np.std(ndi.median_filter(image[0],size=5))
    
    #segment
    image[0][~matlab_mask]=0
    labeled,cc_num=ndi.label(image[0])
    
    mean_int_all_spot_vector=[]
    df_over_f_all_spot_vector=[]
    
    for spot in range(0,cc_num):
        mean_int_spot=[]
        df_over_f_spot=[]
        
        first=image[0]
        first=np.subtract(first,bg)
        first[first<0]=0
        f0=first[labeled==spot].mean()
        if f0==0.:
            first=image[1]
            first=np.subtract(first,bg)
            first[first<0]=0
            f0=first[labeled==spot].mean()
        df_over_f_spot.append(0.)
        mean_int_spot.append(f0)
        
        for frame in range(1,len(image)):
            #bg subtract
            frameim=image[frame]
            frameim=np.subtract(frameim,bg)
            frameim[frameim<0]=0
            mean_int_spot.append(frameim[labeled==spot].mean())

            df_over_f_spoti=(frameim[labeled==spot].mean()-f0)/f0
            if df_over_f_spoti<0:
                df_over_f_spoti=0

            df_over_f_spot.append(df_over_f_spoti)
        
        mean_int_all_spot_vector.append(mean_int_spot)
        df_over_f_all_spot_vector.append(df_over_f_spot)
            
    mean_int_all_spot_vector=np.array(mean_int_all_spot_vector)
    df_over_f_all_spot_vector=np.array(df_over_f_all_spot_vector)
    
    #drop nans
    mask = np.all(np.isnan(mean_int_all_spot_vector) | np.equal(mean_int_all_spot_vector, 0), axis=1)
    mean_int_all_spot_vector=mean_int_all_spot_vector[~mask]
    
    mask = np.all(np.isnan(df_over_f_all_spot_vector) | np.equal(df_over_f_all_spot_vector, 0), axis=1)
    df_over_f_all_spot_vector=df_over_f_all_spot_vector[~mask]
    mask = np.all(np.isinf(df_over_f_all_spot_vector) | np.equal(df_over_f_all_spot_vector, 0), axis=1)
    df_over_f_all_spot_vector=df_over_f_all_spot_vector[~mask]
    
    mean_int_all_spots_in_image=np.nanmean(mean_int_all_spot_vector,axis=0)
    df_over_f_all_spots_in_image=np.nanmean(df_over_f_all_spot_vector,axis=0)
    aoc_all_spots_in_image= np.trapz(df_over_f_all_spots_in_image,axis=0)
    pearson_all_spots_in_image=np.mean(np.corrcoef(df_over_f_all_spot_vector))
    #no_peaks
    stack=df_over_f_all_spots_in_image
    prev = stack[0] or 0.01
    threshold = 10
    peaks = []
    for num, i in enumerate(stack[1:], 1):
        if (i - prev) / prev > threshold:
            peaks.append(num)
        prev = i or 0.001
    no_peaks_in_image=len(peaks)
    #if stimulated condition- lower threshold because peak is more gradual
    if results["spontaneous or stimulation"][im]=="stim":
        print('stim')
        threshold = 1
        peaks = []
        no_peaks_in_image=0
        for i in range(0,100):
            if no_peaks_in_image==int(0):
                for num, i in enumerate(stack[1:], 1):
                    if (i - prev) / prev > threshold:
                        peaks.append(num)
                    prev = i or 0.001
                    
                    
                threshold=threshold-0.1
                no_peaks_in_image=int(len(peaks))
                print(threshold)
                print(len(peaks))
            else:
                break
        #calculate slope
        if no_peaks_in_image==0:
            peaks=1
        else:
            peaks=peaks[0]
        X=np.arange(peaks,peaks+10)
        Y=df_over_f_all_spots_in_image[peaks:peaks+10]
        from scipy.stats import linregress
        slope,_,_,_,_=linregress(X, Y)
    else:
        slope=np.nan
        
    #mean intensity full image
    mean_int_full=[]
    for frame in range(0,len(image)):
        #bg subtract
        frameim=image[frame]
        frameim=np.subtract(frameim,bg)
        frameim[frameim<0]=0
        mean_int_full.append(frameim.mean())
    
    results["calcium mean intensity whole frame"].append(mean_int_full)
    results["calcium mean intensity in rois"].append(mean_int_all_spots_in_image)
    results["calcium [f(t)-f(0)]/f(0) in rois"].append(df_over_f_all_spots_in_image)
    results["total calcium influx (AOC of [f(t)-f(0)]/f(0) in rois)"].append(aoc_all_spots_in_image)
    results["calcium slope downwards"].append(slope)
    results["synchronicity (pearson)"].append(pearson_all_spots_in_image)
    results["synchronicity (no. of peaks)"].append(no_peaks_in_image)
# Out:
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: invalid value encountered in double_scalars
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-524-d40ddc434967> in <module>
#       9
#      10     #segment
# ---> 11     image[0][~matlab_mask]=0
#      12     labeled,cc_num=ndi.label(image[0])
#      13
#
# TypeError: bad operand type for unary ~: 'float'

# %%
for im in range(0,5):#len(results["calcium recording filename"])):

    image_name=results["calcium recording filename"][im]
    syt_image_name=results["corresponding syt/clumps filename"][im][0]
    print(syt_image_name)
    if syt_image_name=='n':
        results["synapse mask (dilated syt1)"].append(np.nan)
        results["df/f under dilated syt mask"].append(np.nan)
        continue
    image = io.imread(image_name)
    syt_image = io.imread(syt_image_name)[0]
    
    #mask from syt
    syt_image_threshold=threshold_li(syt_image)
    syt_image_thresholded=deepcopy(syt_image)
    syt_image_thresholded[syt_image_thresholded<syt_image_threshold]=0

    syt_mask=deepcopy(syt_image_thresholded)
    syt_mask[syt_mask>np.percentile(syt_mask,85)]=0

    syt_mask=ndi.gaussian_filter(syt_mask,sigma=.1)
    syt_mask[syt_mask>0]=1
    syt_mask=ndi.binary_dilation(syt_mask,iterations=1)
    syt_mask=ndi.binary_fill_holes(syt_mask)
    
    
    #background 
    bg=np.mean(ndi.median_filter(image[0],size=5))+0*np.std(ndi.median_filter(image[0],size=5))
    mean_int_under_syt=[]
    
            
    df_over_f_all_spot_vector=[]
        
    first=image[0]
    first=np.subtract(first,bg)
    first[first<0]=0
    f0=first[syt_mask].mean()
    df_over_f_all_spot_vector.append(0.)
        
    for frame in range(1,len(image)):
        #bg subtract
        frameim=image[frame]
        frameim=np.subtract(frameim,bg)
        frameim[frameim<0]=0
        
        df_over_f_spoti=(frameim[syt_mask].mean()-f0)/f0
        if df_over_f_spoti<0:
            df_over_f_spoti=0

        df_over_f_all_spot_vector.append(df_over_f_spoti)
        
    df_over_f_all_spots_in_image=np.nanmean(df_over_f_all_spot_vector,axis=0)
    
    
    results["synapse mask (dilated syt1)"].append(syt_mask)
    results["df/f under dilated syt mask"].append(df_over_f_all_spots_in_image)
# Out:
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps1/spontaneous/20x_spontaneous_activity_field3_syt_clumps.tif
# n
# n
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps1/60x_post_ttx_stim/60x_field1_syt_clumps.tif
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/201910_biotinclumps_tnr_calciumimaging/20191016_Clumps1/60x_post_ttx_stim/60x_field2_syt_clumps.tif

# %% [markdown]
# ## sanity check

# %%
randomno=np.random.randint(0,5)
image_name=results["calcium recording filename"][randomno]
image = io.imread(image_name)
print(results["spontaneous or stimulation"][randomno])
plt.figure()
plt.imshow(image[0])
plt.title('raw image first frame')
bg=np.mean(ndi.median_filter(image[0],size=5))+0*np.std(ndi.median_filter(image[0],size=5))
first=image[0]
first=np.subtract(first,bg)
first[first<0]=0
plt.figure()
plt.imshow(first)
plt.title('first frame bg subtracted')
plt.figure()
plt.imshow(results["synapse mask (dilated syt1)"][randomno])
plt.title('synapse mask')

pearson_all_spots_in_image=results["synchronicity (pearson)"][randomno]
aoc_all_spots_in_image=results["total calcium influx (AOC of [f(t)-f(0)]/f(0) in rois)"][randomno]
no_peaks_in_image=results["synchronicity (no. of peaks)"][randomno]
slope=results["calcium slope downwards"][randomno]

plt.figure()
plt.plot(results["calcium [f(t)-f(0)]/f(0) in rois"][randomno])
plt.title('df/f under rois')
plt.figure()
plt.plot(results["df/f under dilated syt mask"][randomno])
plt.title('df/f under syt')

print('pearson  '+str(pearson_all_spots_in_image))
print('aoc  '+str(aoc_all_spots_in_image))
print('no peaks '+str(no_peaks_in_image))
print('slope. '+str(slope))
# Out:
# stim
# pearson  1.0
# aoc  0.0004866671352416534
# no peaks 1
# slope. -2.6545480104090192e-05

# %%
df=pd.DataFrame(results)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-525-e1def8e106fb> in <module>
# ----> 1 df=pd.DataFrame(results)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      49     # figure out the index, if necessary
#      50     if index is None:
# ---> 51         index = extract_index(arrays)
#      52     else:
#      53         index = ensure_index(index)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     315             lengths = list(set(raw_lengths))
#     316             if len(lengths) > 1:
# --> 317                 raise ValueError('arrays must all be same length')
#     318
#     319             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
for key in results.keys():
    print(key)
    print(len(results[key]))
# Out:
# calcium recording filename
# 38
# corresponding syt/clumps filename
# 38
# clumpschannelno
# 38
# synapsechannelno
# 38
# spontaneous or stimulation
# 38
# magnification
# 38
# Manual mask from matlab GUI
# 38
# calcium mean intensity whole frame
# 1
# calcium mean intensity in rois
# 1
# calcium [f(t)-f(0)]/f(0) in rois
# 1
# total calcium influx (AOC of [f(t)-f(0)]/f(0) in rois)
# 1
# calcium slope downwards
# 1
# synchronicity (pearson)
# 1
# synchronicity (no. of peaks)
# 1

# %%
df=df.dropna(subset=['total calcium influx (AOC of [f(t)-f(0)]/f(0) in rois)'])
df=df.reset_index(drop=True)

# %%
df["condition"]='None'
df.loc[df["calcium recording filename"].str.contains("lump"),"condition"]="Clumps"
df.loc[df["calcium recording filename"].str.contains("trl"),"condition"]="Ctrl"

# %%
for i in range(0,len(df["spontaneous or stimulation"])):
    if df["spontaneous or stimulation"][i]=="spontaneous":
        print('yes')
        if len(df["calcium [f(t)-f(0)]/f(0) in rois"][i])<100:
            print(len(df["calcium [f(t)-f(0)]/f(0) in rois"][i]))
            df["spontaneous or stimulation"][i]="Ignore"
        else:
            print('bigger')
            continue
# Out:
# array(['Clumps', 'Ctrl'], dtype=object)

# %%
dfclumps=df[df["condition"]=="Clumps"]
dfctrl=df[df["condition"]=="Ctrl"]

plt.figure()
plt.plot(np.mean(dfclumps[dfclumps["spontaneous or stimulation"]=="stim"]["calcium mean intensity in rois"].values,axis=0),color='red')
plt.plot(np.mean(dfctrl[dfctrl["spontaneous or stimulation"]=="stim"]["calcium mean intensity in rois"].values,axis=0),color='black')

plt.figure()
plt.plot(np.mean(dfclumps[dfclumps["spontaneous or stimulation"]=="spontaneous"]["calcium mean intensity in rois"].values,axis=0),color='red')
plt.plot(np.mean(dfctrl[dfctrl["spontaneous or stimulation"]=="spontaneous"]["calcium mean intensity in rois"].values,axis=0),color='black')

# %%
dfctrl_sp=dfclumps[dfclumps["spontaneous or stimulation"]=="spontaneous"]

# %%
dfctrl_sp=dfctrl[dfctrl["spontaneous or stimulation"]=="stim"]

# %%
a=dfctrl_sp['calcium [f(t)-f(0)]/f(0) in rois']
list=[]
for i in range(0,len(a)):
    b=a.values[0].tolist()
    list.append(b)
y = np.vstack(list)

# %%
np.savetxt(expdir+'clumps_spont.csv',y)

# %%
b=np.array([1,a[0]])
for i in range(1,len(a)):
    c=np.array([1,a[i]])
    b=np.concatenate((b,c),axis=0)

# %%
a=np.ravel(a)

# %%
a.values
# Out:
# array([array([0.        , 0.00142097, 0.00298648, 0.00317065, 0.00588165,
#        0.00189476, 0.00732729, 0.00779963, 0.00598982, 0.00853209,
#        0.00869783, 0.00904683, 0.0131165 , 0.00772181, 0.01290271,
#        0.01645415, 0.0125631 , 0.01161183, 0.01246807, 0.01508171,
#        0.01863733, 0.01895013, 0.01877878, 0.02065756, 0.01695734,
#        0.01953147, 0.02157728, 0.02442192, 0.02852012, 0.02892457,
#        0.02400615, 0.02593943, 0.03362092, 0.03357389, 0.03145108,
#        0.0335222 , 0.03282558, 0.03659152, 0.03648877, 0.03689527,
#        0.03615102, 0.04190005, 0.04078333, 0.03636647, 0.03663552,
#        0.04142793, 0.04012966, 0.04000285, 0.04057385, 0.03690046,
#        0.0432099 , 0.04063107, 0.04394596, 0.04891844, 0.04805825,
#        0.04174333, 0.04310824, 0.0488251 , 0.04669268, 0.04978502,
#        0.05032298, 0.05182865, 0.05424959, 0.05497216, 0.05265099,
#        0.05873706, 0.06220309, 0.05767004, 0.06033984, 0.05739375,
#        0.06196822, 0.06425324, 0.05928367, 0.06266919, 0.06106458,
#        0.06582456, 0.06188505, 0.06471813, 0.06447199, 0.06853477,
#        0.06303348, 0.06855477, 0.06851226, 0.07207905, 0.06580299,
#        0.06966485, 0.07135991, 0.07523117, 0.07447624, 0.07598841,
#        0.07317694, 0.07847192, 0.075167  , 0.07494073, 0.08002988,
#        0.07745723, 0.08168469, 0.08249952, 0.08311315, 0.08559963,
#        0.08343403, 0.08591444, 0.09316069, 0.08983926, 0.08767623,
#        0.09308115, 0.09222607, 0.09073955, 0.08925206, 0.09329897,
#        0.09218226, 0.09151974, 0.09610198, 0.09227307, 0.10015752,
#        0.10053452, 0.09802151, 0.09421489, 0.09959475, 0.09538273,
#        0.09644875]),
#        array([0.        , 0.00180462, 0.00230757, 0.00236563, 0.00119005,
#        0.00279998, 0.0034406 , 0.00322447, 0.00424207, 0.00294364,
#        0.0032477 , 0.00893902, 0.00512245, 0.00274483, 0.00497578,
#        0.0049341 , 0.00433032, 0.00724517, 0.00648582, 0.00634451,
#        0.00707047, 0.00385848, 0.009662  , 0.00614834, 0.00857903,
#        0.00814536, 0.00921103, 0.00919699, 0.00819342, 0.0078253 ,
#        0.00876777, 0.01077598, 0.00774936, 0.00753614, 0.00984472,
#        0.00949169, 0.01239893, 0.01430726, 0.01321201, 0.01363055,
#        0.01274187, 0.01378399, 0.01488433, 0.01241763, 0.01513748,
#        0.01624398, 0.01641494, 0.01981216, 0.02191998, 0.02015229,
#        0.01633006, 0.02236219, 0.01978827, 0.02212688, 0.02070242,
#        0.02274466, 0.02013739, 0.02650569, 0.02533342, 0.02387015,
#        0.02461857, 0.02176224, 0.02133472, 0.02533128, 0.02141765,
#        0.02485853, 0.02249793, 0.02509153, 0.02396998, 0.02724631,
#        0.02476595, 0.02641984, 0.02817074, 0.02719613, 0.02633265,
#        0.02996737, 0.0309087 , 0.02948196, 0.0293703 , 0.02750267,
#        0.02690217, 0.03084552, 0.0322637 , 0.02939184, 0.0340995 ,
#        0.03140032, 0.03331096, 0.03390195, 0.03565414, 0.0378378 ,
#        0.03536952, 0.03608958, 0.03567394, 0.03871832, 0.03942331,
#        0.03484744, 0.03906743, 0.03942313, 0.04138235, 0.0411425 ,
#        0.04306141, 0.04353284, 0.04164052, 0.0422902 , 0.04258171,
#        0.04199547, 0.04595596, 0.04328399, 0.0470969 , 0.04572365,
#        0.04641343, 0.04336259, 0.04571062, 0.04623742, 0.04673954,
#        0.04561177, 0.04573832, 0.04737752, 0.05173092, 0.05086954,
#        0.05312619])], dtype=object)

# %%
np.savetxt(expdir+"ctrl_stim_df_over_f___.csv", a, delimiter=",",fmt='%s')

# %%
len(a)
# Out:
# 12

# %%
b=a[1].tolist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-758-40f140b93aee> in <module>
# ----> 1 b=a[1].tolist()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4372         try:
#    4373             return self._engine.get_value(s, k,
# -> 4374                                           tz=getattr(series.dtype, 'tz', None))
#    4375         except KeyError as e1:
#    4376             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1

# %%
b
# Out:
# [0.0,
#  0.0018046214801212069,
#  0.002307574164677437,
#  0.00236563216310065,
#  0.0011900493148277857,
#  0.002799975989851492,
#  0.003440596418238758,
#  0.003224466501908607,
#  0.004242072258083492,
#  0.002943637180088244,
#  0.003247699566118244,
#  0.008939021030091728,
#  0.005122449046963958,
#  0.0027448325757834886,
#  0.00497578122136399,
#  0.004934100846621038,
#  0.004330316526446239,
#  0.00724517370141526,
#  0.006485817969634221,
#  0.006344510751712546,
#  0.007070465541468313,
#  0.003858480594980218,
#  0.009662000015351061,
#  0.006148344848976899,
#  0.008579034160838215,
#  0.008145360343173659,
#  0.009211030607838832,
#  0.009196985440646802,
#  0.008193417803457156,
#  0.007825300300882255,
#  0.008767773560545799,
#  0.010775980563798464,
#  0.007749355911755901,
#  0.007536140061756931,
#  0.009844716786411481,
#  0.00949168704907848,
#  0.012398927896250016,
#  0.014307259444531314,
#  0.013212010870692233,
#  0.013630552953402,
#  0.012741872561868354,
#  0.013783985151489063,
#  0.014884334192050472,
#  0.012417629153895687,
#  0.015137476041952588,
#  0.01624398177123622,
#  0.01641493746934294,
#  0.019812156388562336,
#  0.021919983115849223,
#  0.020152288077321338,
#  0.01633006380630038,
#  0.02236218836784442,
#  0.01978827409974506,
#  0.02212687582767763,
#  0.020702423762168156,
#  0.022744657755864452,
#  0.020137389935682107,
#  0.02650569395884052,
#  0.025333416057699093,
#  0.023870154638804975,
#  0.024618571620704386,
#  0.02176224442616367,
#  0.021334715527526745,
#  0.0253312848013759,
#  0.021417650196044635,
#  0.024858527236665505,
#  0.02249792870592861,
#  0.02509152635578166,
#  0.023969979852358887,
#  0.027246307465974177,
#  0.024765954790500744,
#  0.02641983782787295,
#  0.02817073720344108,
#  0.027196125125232205,
#  0.026332648943274445,
#  0.02996736694190197,
#  0.03090870350391186,
#  0.029481959927090743,
#  0.029370300729641124,
#  0.027502669567803114,
#  0.026902169711291783,
#  0.03084551668471584,
#  0.03226370074825287,
#  0.029391839168027983,
#  0.034099498555828694,
#  0.031400321078582864,
#  0.03331095537646474,
#  0.03390195169495923,
#  0.03565414135707485,
#  0.03783780313134418,
#  0.03536952147731514,
#  0.0360895845221751,
#  0.03567394156464519,
#  0.03871831858446634,
#  0.0394233128413811,
#  0.0348474404562689,
#  0.03906742894883528,
#  0.03942313330130579,
#  0.04138234656029736,
#  0.041142499973678304,
#  0.04306141283227645,
#  0.043532837036771736,
#  0.04164051965988746,
#  0.042290200304170654,
#  0.042581705017314994,
#  0.04199546976366975,
#  0.04595596348133367,
#  0.04328398770281655,
#  0.04709690467892036,
#  0.04572364743268569,
#  0.04641342640827514,
#  0.04336258546041424,
#  0.0457106233271163,
#  0.04623741719466296,
#  0.046739539655855124,
#  0.045611769033855526,
#  0.045738318471604006,
#  0.0473775190766223,
#  0.05173091836652669,
#  0.050869535958044644,
#  0.053126190704179004]

# %%
a.to_csv(expdir+'ff.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-743-42266349f285> in <module>
# ----> 1 a.to_csv(expdir+'ff.csv')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_csv'

# %%
# import xlsxwriter module 
import xlsxwriter 
  
# Workbook() takes one, non-optional, argument  
# which is the filename that we want to create. 
workbook = xlsxwriter.Workbook(expdir+'ss.xlsx') 
  
# The workbook object is then used to add new  
# worksheet via the add_worksheet() method. 
ws = workbook.add_worksheet() 

for i,game in enumerate(list):
    ws.write(i,0,str(game))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-756-534c96da93ec> in <module>
#      11
#      12 for i,game in enumerate(list):
# ---> 13     ws.write(i,0,str(game))
#
# KeyboardInterrupt:

# %%
b

# %%
np.savetxt(expdir+"ctrl_stim_df_over_f_.csv", b, delimiter=";",fmt='%s')

# %%
b=b[:,0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-604-cb139a150b4f> in <module>
# ----> 1 b=b[:,0]
#
# IndexError: too many indices for array

# %%
b.squeeze(axis=1)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-606-6eed315aa079> in <module>
# ----> 1 b.squeeze(axis=1)
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
dfclumps=df[df["condition"]=="Clumps"]
dfctrl=df[df["condition"]=="Ctrl"]

plt.figure()
plt.plot(np.mean(dfclumps[dfclumps["spontaneous or stimulation"]=="stim"]["calcium [f(t)-f(0)]/f(0) in rois"].values,axis=0),color='red')
plt.plot(np.mean(dfctrl[dfctrl["spontaneous or stimulation"]=="stim"]["calcium [f(t)-f(0)]/f(0) in rois"].values,axis=0),color='black')

plt.figure()
plt.plot(np.mean(dfclumps[dfclumps["spontaneous or stimulation"]=="spontaneous"]["calcium [f(t)-f(0)]/f(0) in rois"].values,axis=0),color='red')
plt.plot(np.mean(dfctrl[dfctrl["spontaneous or stimulation"]=="spontaneous"]["calcium [f(t)-f(0)]/f(0) in rois"].values,axis=0),color='black')

# %%
df.columns
# Out:
# Index(['calcium recording filename', 'corresponding syt/clumps filename',
#        'clumpschannelno', 'synapsechannelno', 'spontaneous or stimulation',
#        'magnification', 'Manual mask from matlab GUI',
#        'calcium mean intensity whole frame', 'calcium mean intensity in rois',
#        'calcium [f(t)-f(0)]/f(0) in rois',
#        'total calcium influx (AOC of [f(t)-f(0)]/f(0) in rois)',
#        'calcium slope downwards', 'synchronicity (pearson)',
#        'synchronicity (no. of peaks)', 'condition'],
#       dtype='object')

# %%
#clumps
dfcalc=dfclumps[dfclumps["spontaneous or stimulation"]=="spontaneous"]
print('Area under curve: '+str(dfcalc["total calcium influx (AOC of [f(t)-f(0)]/f(0) in rois)"].mean()))
print('calcium slope downwards: '+str(dfcalc["calcium slope downwards"].mean()))
print('Pearson: '+str(dfcalc["synchronicity (pearson)"].mean()))
print('No peaks: '+str(dfcalc["synchronicity (no. of peaks)"].mean()))
# Out:
# Area under curve: 3.581823727921072
# calcium slope downwards: nan
# Pearson: 0.5475541996827961
# No peaks: 3.75

# %%
#clumps
dfcalc=dfclumps[dfclumps["spontaneous or stimulation"]=="stim"]
print('Area under curve: '+str(dfcalc["total calcium influx (AOC of [f(t)-f(0)]/f(0) in rois)"].mean()))
print('calcium slope downwards: '+str(dfcalc["calcium slope downwards"].mean()))
print('Pearson: '+str(dfcalc["synchronicity (pearson)"].mean()))
print('No peaks: '+str(dfcalc["synchronicity (no. of peaks)"].mean()))
# Out:
# Area under curve: 4.218678281203918
# calcium slope downwards: 0.01067066493792016
# Pearson: 0.8615785741369476
# No peaks: 2.4375

# %%
#ctrl
dfcalc=dfctrl[dfctrl["spontaneous or stimulation"]=="spontaneous"]
print('Area under curve: '+str(dfcalc["total calcium influx (AOC of [f(t)-f(0)]/f(0) in rois)"].mean()))
print('calcium slope downwards: '+str(dfcalc["calcium slope downwards"].mean()))
print('Pearson: '+str(dfcalc["synchronicity (pearson)"].mean()))
print('No peaks: '+str(dfcalc["synchronicity (no. of peaks)"].mean()))
# Out:
# Area under curve: 4.478627145507559
# calcium slope downwards: nan
# Pearson: 0.7116277763027656
# No peaks: 0.0

# %%
#clumps
dfcalc=dfctrl[dfctrl["spontaneous or stimulation"]=="stim"]
print('Area under curve: '+str(dfcalc["total calcium influx (AOC of [f(t)-f(0)]/f(0) in rois)"].mean()))
print('calcium slope downwards: '+str(dfcalc["calcium slope downwards"].mean()))
print('Pearson: '+str(dfcalc["synchronicity (pearson)"].mean()))
print('No peaks: '+str(dfcalc["synchronicity (no. of peaks)"].mean()))
# Out:
# Area under curve: 4.541653141332141
# calcium slope downwards: 0.01861793740546766
# Pearson: 0.6618777811686913
# No peaks: 3.5

# %%
df2show=df[df["spontaneous or stimulation"]=="spontaneous"]
var="synchronicity (no. of peaks)"
sns.barplot(x="condition",y=var,data=df2show)
sns.swarmplot(x="condition",y=var,data=df2show,color='k')
