# %%
import numpy as np
import os
from nd2reader import ND2Reader
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib_scalebar.scalebar import ScaleBar
import scipy.ndimage as ndi
from skimage.filters import rank 
from scipy.signal import butter, lfilter
import scipy.misc as misc
from skimage import exposure
from PIL import Image
import colorcet as cc
from scipy.misc import toimage
import matplotlib.colors as clr
import pandas as pd
import seaborn as sns
from scipy import stats
import cv2
from pyspark import SparkContext, SparkConf
import skimage
from pathlib import Path
# %matplotlib inline
def mean2(x):
    y = np.sum(x) / np.size(x);
    return y
def corr2(a,b):
    a = a - mean2(a)
    b = b - mean2(b)

    r = (a*b).sum() / np.sqrt((a*a).sum() * (b*b).sum());
    return r
from copy import deepcopy
from skimage.filters import threshold_otsu,threshold_li
import glob
from IPython.display import clear_output
import scipy.io as spio
import pims

# %% [markdown]
# ## Directory

# %%
expdir='/Volumes/ukps-all$/user/tdanko/Imaging/03_Collab/2020_Clara/All files/N1_HPN20DIV/SYT1/Calreticulin'

# %% [markdown]
# ## Read individual synapse files (spots.txt), and manual annotations made in Matlab

# %%
spots={"filename":[]}

path = os.path.dirname(expdir)  
filelist = []
for root, _, filenames in os.walk(path):
     for filename in filenames:
         filelist.append(os.path.join(root, filename))      
for i in range(0,len(filelist)):
    #print(str(i+1)+'out of '+str(len(filelist)))
    if filelist[i].endswith(".txt"): 
        #if ("samecellonly" in str(filelist[i]))==False:
            if ("_spot" in str(filelist[i]))==True:
                     #if ("backup" in str(filelist[i]))==False:
                        #if str(filelist[i][:-12]) not in str(spots["filename"]):
                            spots["filename"].append(filelist[i])

# %%
spotname=spots["filename"][0]

# %%
spotname
# Out:
# '/Volumes/ukps-all$/user/tdanko/Imaging/03_Collab/2020_Clara/All files/N1_HPN20DIV/SYT1/Calreticulin/stacked__055_HPN20DIV_Phalloidin-AF405_Homer-gp-seq-AF488_Calreticulin-rbt-AF594_Synaptotagmin1-Atto647N_PFA_series9_0_spots2.txt'

# %%
spot=np.asarray(np.loadtxt(spotname,delimiter=','))
plt.imshow(spot)

# %%
spot.shape
# Out:
# (301, 903)

# %%
imagename=str.join('_',spotname.split('_')[:-2])+'.tif'
matname=str.join('_',spotname.split('_')[:-2])+'.mat'
image=pims.open(imagename)

# %%
from scipy.io import loadmat
pos1 = loadmat(matname)['pos1'][0]
orangex = loadmat(matname)['orangex'][0]
orangey = loadmat(matname)['orangey'][0]
small_movi=loadmat(matname)['small_movi']

# %%
small_movii=image[8][pos1[0]-1:pos1[1],pos1[2]-1:pos1[3]]

# %%
ecm_image=full_image[3] #channel of changing protein (need to subtract 1)
    syt_image=full_image[1]

# %%
syt_image=image[1]
small_movi_syt=syt_image[pos1[0]-1:pos1[1],pos1[2]-1:pos1[3]]
plt.imshow(small_movi_syt)

# %%
spotcut=small_movi_syt[np.int(np.round(orangex[1]-150)):np.int(np.round(orangex[1]+151)),
                                                    np.int(np.round(orangey[1]-150)):np.int(np.round(orangey[1]+151))]

# %%
spotname
# Out:
# '/Volumes/ukps-all$/user/tdanko/Imaging/03_Collab/2020_Clara/All files/N1_HPN20DIV/SYT1/Calreticulin/stacked__055_HPN20DIV_Phalloidin-AF405_Homer-gp-seq-AF488_Calreticulin-rbt-AF594_Synaptotagmin1-Atto647N_PFA_series9_0_spots2.txt'

# %%
plt.imshow(spot)

# %%
a=np.concatenate([spot,spotcut],axis=1)

# %%
plt.imshow(a[:,600:901])

# %%
spotname.split('.txt')[0]+'_rerun.txt'
# Out:
# '/Volumes/ukps-all$/user/tdanko/Imaging/03_Collab/2020_Clara/All files/N1_HPN20DIV/SYT1/Calreticulin/stacked__055_HPN20DIV_Phalloidin-AF405_Homer-gp-seq-AF488_Calreticulin-rbt-AF594_Synaptotagmin1-Atto647N_PFA_series9_0_spots2_rerun.txt'

# %%
spotname.split('spots')[-1].split('.')[0]
# Out:
# '2'

# %%
for i in range(0,len(spots["filename"])):
    print('spot '+str(i+1)+' out of '+str(len(spots["filename"])))
    spotname=spots["filename"][i]
    spot=np.asarray(np.loadtxt(spotname,delimiter=','))
    imagename=str.join('_',spotname.split('_')[:-2])+'.tif'
    matname=str.join('_',spotname.split('_')[:-2])+'.mat'
    image=pims.open(imagename)
    pos1 = loadmat(matname)['pos1'][0]
    orangex = loadmat(matname)['orangex'][0]
    orangey = loadmat(matname)['orangey'][0]
    small_movi=loadmat(matname)['small_movi']
    
    syt_image=image[1]
    small_movi_syt=syt_image[pos1[0]-1:pos1[1],pos1[2]-1:pos1[3]]
    
    spotnumber=spotname.split('spots')[-1].split('.')[0]
    
    spotcut=small_movi_syt[np.int(np.round(orangex[np.int(spotnumber)-1]-150)):
                           np.int(np.round(orangex[np.int(spotnumber)-1]+151)),
                           np.int(np.round(orangey[np.int(spotnumber)-1]-150)):
                           np.int(np.round(orangey[np.int(spotnumber)-1]+151))]
    a=np.concatenate([spot,spotcut],axis=1)
    np.savetxt(spotname.split('.txt')[0]+'_rerun.txt',a)
# Out:
# spot 1 out of 1806
# spot 2 out of 1806
# spot 3 out of 1806
# spot 4 out of 1806
# spot 5 out of 1806
# spot 6 out of 1806
# spot 7 out of 1806
# spot 8 out of 1806
# spot 9 out of 1806
# spot 10 out of 1806
# spot 11 out of 1806
# spot 12 out of 1806
# spot 13 out of 1806
# spot 14 out of 1806
# spot 15 out of 1806
# spot 16 out of 1806
# spot 17 out of 1806
# spot 18 out of 1806
# spot 19 out of 1806
# spot 20 out of 1806
# spot 21 out of 1806
# spot 22 out of 1806
# spot 23 out of 1806
# spot 24 out of 1806
# spot 25 out of 1806
# spot 26 out of 1806
# spot 27 out of 1806
# spot 28 out of 1806
# spot 29 out of 1806
# spot 30 out of 1806
# spot 31 out of 1806
# spot 32 out of 1806
# spot 33 out of 1806
# spot 34 out of 1806
# spot 35 out of 1806
# spot 36 out of 1806
# spot 37 out of 1806
# spot 38 out of 1806
# spot 39 out of 1806
# spot 40 out of 1806
# spot 41 out of 1806
# spot 42 out of 1806
# spot 43 out of 1806
# spot 44 out of 1806
# spot 45 out of 1806
# spot 46 out of 1806
# spot 47 out of 1806
# spot 48 out of 1806
# spot 49 out of 1806
# spot 50 out of 1806
# spot 51 out of 1806
# spot 52 out of 1806
# spot 53 out of 1806
# spot 54 out of 1806
# spot 55 out of 1806
# spot 56 out of 1806
# spot 57 out of 1806
# spot 58 out of 1806
# spot 59 out of 1806
# spot 60 out of 1806
# spot 61 out of 1806
# spot 62 out of 1806
# spot 63 out of 1806
# spot 64 out of 1806
# spot 65 out of 1806
# spot 66 out of 1806
# spot 67 out of 1806
# spot 68 out of 1806
# spot 69 out of 1806
# spot 70 out of 1806
# spot 71 out of 1806
# spot 72 out of 1806
# spot 73 out of 1806
# spot 74 out of 1806
# spot 75 out of 1806
# spot 76 out of 1806
# spot 77 out of 1806
# spot 78 out of 1806
# spot 79 out of 1806
# spot 80 out of 1806
# spot 81 out of 1806
# spot 82 out of 1806
# spot 83 out of 1806
# spot 84 out of 1806
# spot 85 out of 1806
# spot 86 out of 1806
# spot 87 out of 1806
# spot 88 out of 1806
# spot 89 out of 1806
# spot 90 out of 1806
# spot 91 out of 1806
# spot 92 out of 1806
# spot 93 out of 1806
# spot 94 out of 1806
# spot 95 out of 1806
# spot 96 out of 1806
# spot 97 out of 1806
# spot 98 out of 1806
# spot 99 out of 1806
# spot 100 out of 1806
# spot 101 out of 1806
# spot 102 out of 1806
# spot 103 out of 1806
# spot 104 out of 1806
# spot 105 out of 1806
# spot 106 out of 1806
# spot 107 out of 1806
# spot 108 out of 1806
# spot 109 out of 1806
# spot 110 out of 1806
# spot 111 out of 1806
# spot 112 out of 1806
# spot 113 out of 1806
# spot 114 out of 1806
# spot 115 out of 1806
# spot 116 out of 1806
# spot 117 out of 1806
# spot 118 out of 1806
# spot 119 out of 1806
# spot 120 out of 1806
# spot 121 out of 1806
# spot 122 out of 1806
# spot 123 out of 1806
# spot 124 out of 1806
# spot 125 out of 1806
# spot 126 out of 1806
# spot 127 out of 1806
# spot 128 out of 1806
# spot 129 out of 1806
# spot 130 out of 1806
# spot 131 out of 1806
# spot 132 out of 1806
# spot 133 out of 1806
# spot 134 out of 1806
# spot 135 out of 1806
# spot 136 out of 1806
# spot 137 out of 1806
# spot 138 out of 1806
# spot 139 out of 1806
# spot 140 out of 1806
# spot 141 out of 1806
# spot 142 out of 1806
# spot 143 out of 1806
# spot 144 out of 1806
# spot 145 out of 1806
# spot 146 out of 1806
# spot 147 out of 1806
# spot 148 out of 1806
# spot 149 out of 1806
# spot 150 out of 1806
# spot 151 out of 1806
# spot 152 out of 1806
# spot 153 out of 1806
# spot 154 out of 1806
# spot 155 out of 1806
# spot 156 out of 1806
# spot 157 out of 1806
# spot 158 out of 1806
# spot 159 out of 1806
# spot 160 out of 1806
# spot 161 out of 1806
# spot 162 out of 1806
# spot 163 out of 1806
# spot 164 out of 1806
# spot 165 out of 1806
# spot 166 out of 1806
# spot 167 out of 1806
# spot 168 out of 1806
# spot 169 out of 1806
# spot 170 out of 1806
# spot 171 out of 1806
# spot 172 out of 1806
# spot 173 out of 1806
# spot 174 out of 1806
# spot 175 out of 1806
# spot 176 out of 1806
# spot 177 out of 1806
# spot 178 out of 1806
# spot 179 out of 1806
# spot 180 out of 1806
# spot 181 out of 1806
# spot 182 out of 1806
# spot 183 out of 1806
# spot 184 out of 1806
# spot 185 out of 1806
# spot 186 out of 1806
# spot 187 out of 1806
# spot 188 out of 1806
# spot 189 out of 1806
# spot 190 out of 1806
# spot 191 out of 1806
# spot 192 out of 1806
# spot 193 out of 1806
# spot 194 out of 1806
# spot 195 out of 1806
# spot 196 out of 1806
# spot 197 out of 1806
# spot 198 out of 1806
# spot 199 out of 1806
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-101-b45a624a0440> in <module>
#       9     orangex = loadmat(matname)['orangex'][0]
#      10     orangey = loadmat(matname)['orangey'][0]
# ---> 11     small_movi=loadmat(matname)['small_movi']
#      12
#      13     syt_image=image[1]
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/io/matlab/mio.py in loadmat(file_name, mdict, appendmat, **kwargs)
#     206     variable_names = kwargs.pop('variable_names', None)
#     207     MR, file_opened = mat_reader_factory(file_name, appendmat, **kwargs)
# --> 208     matfile_dict = MR.get_variables(variable_names)
#     209     if mdict is not None:
#     210         mdict.update(matfile_dict)
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/io/matlab/mio5.py in get_variables(self, variable_names)
#     290                 continue
#     291             try:
# --> 292                 res = self.read_var_array(hdr, process)
#     293             except MatReadError as err:
#     294                 warnings.warn(
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/io/matlab/mio5.py in read_var_array(self, header, process)
#     250            `process`.
#     251         '''
# --> 252         return self._matrix_reader.array_from_header(header, process)
#     253
#     254     def get_variables(self, variable_names=None):
#
# KeyboardInterrupt:

# %%
np.int(spotnumber)
# Out:
# 2
