# %% [markdown]
# ## Import modules and functions

# %%
import numpy as np
import os
from nd2reader import ND2Reader
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib_scalebar.scalebar import ScaleBar
import scipy.ndimage as ndi
from skimage.filters import rank 
from scipy.signal import butter, lfilter
import scipy.misc as misc
from skimage import exposure
from PIL import Image
import colorcet as cc
from scipy.misc import toimage
import matplotlib.colors as clr
import pandas as pd
import seaborn as sns
from scipy import stats
import cv2
from pyspark import SparkContext, SparkConf
import skimage
from pathlib import Path

def mean2(x):
    y = np.sum(x) / np.size(x);
    return y
def corr2(a,b):
    a = a - mean2(a)
    b = b - mean2(b)

    r = (a*b).sum() / np.sqrt((a*a).sum() * (b*b).sum());
    return r
from copy import deepcopy
from skimage.filters import threshold_otsu,threshold_li
import glob
from IPython.display import clear_output
import scipy.io as spio

# %% [markdown]
# ## Define directory of images

# %%
expdir='/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Controls/201912_tnrs_arent_preexisting_epitopes_analyse/Merged_images_from_exps_for_analysis/' #master folder

# %% [markdown]
# ## Make dictionary for storing results

# %%
results = {"filename":[],"exp":[],"coverslip":[],
           "Manual mask from matlab GUI":[],"bg sub int under mask":[]}
path = os.path.dirname(expdir)  
outputFolder = os.path.dirname(expdir + "/new/")
filelist = []
for root, _, filenames in os.walk(path):
     for filename in filenames:
         filelist.append(os.path.join(root, filename))      
for i in range(0,len(filelist)):
    #if "analyse" in str(filelist[i]):
        if ("backup" in str(filelist[i]))==False:
            if ("ignore" in str(filelist[i]))==False:
                if ("dditional" in str(filelist[i]))==False:
                    if filelist[i].endswith(".nd2"): 
                        results["filename"].append(filelist[i])
                        results["coverslip"].append(filelist[i].split('/')[-2])
                        results["exp"].append(filelist[i].split('/')[-4])

# %% [markdown]
# ## Read manual masks from Matlab GUI

# %%
## matlab files
for im in range(0,len(results["filename"])): 
    file=results["filename"][im][:-4]+'_dendritesmask.mat'
    from pathlib import Path
    my_file = Path(file)
    if my_file.exists():
        print(file)
        mat = spio.loadmat(file, squeeze_me=True)
        mask=mat['totMask']>0.99
        results["Manual mask from matlab GUI"].append(mask)
    else:
        results["Manual mask from matlab GUI"].append(np.nan)
clear_output()        
print("Done!")
# Out:
# Done!

# %% [markdown]
# ## Batch analysis of images - mean intensity

# %%
print('Total number of images: ' + str(len(results['filename'])))

for i in range(0,len(results["filename"])): 
    flag=False
    print('Calculating image no ' + str(i+1) + ' out of' + str(len(results["filename"])))
    #read the image
    with ND2Reader(results["filename"][i]) as images:
        ecm_image=images[0]
    #convert to numpy array - a format easier to manipunuclei with code
    ecm_image=ecm_image.astype(np.int16)
    #read masks 
    matlab_mask=results["Manual mask from matlab GUI"][i]
    if type(matlab_mask)==np.ndarray:
        flag=True
    #image after background subtraction
    #for ecm image
    if flag==True:
        ecm_matlabmasked_bgreduced=deepcopy(ecm_image)
        bg_matlabmask=np.mean(ndi.median_filter(ecm_image[matlab_mask],size=5))+0*np.std(ndi.median_filter(ecm_image[matlab_mask],size=5))
        ecm_matlabmasked_bgreduced=np.subtract(ecm_matlabmasked_bgreduced,bg_matlabmask)
        ecm_matlabmasked_bgreduced[ecm_matlabmasked_bgreduced<0]=0
        ecm_matlabmasked_bgreduced[~matlab_mask]=0
        
    if flag==True:
        results["bg sub int under mask"].append(ecm_matlabmasked_bgreduced[matlab_mask].mean())
    else:
        results["bg sub int under mask"].append(np.nan)
# Out:
# Total number of images: 200
# Calculating image no 1 out of200
# Calculating image no 2 out of200
# Calculating image no 3 out of200
# Calculating image no 4 out of200
# Calculating image no 5 out of200
# Calculating image no 6 out of200
# Calculating image no 7 out of200
# Calculating image no 8 out of200
# Calculating image no 9 out of200
# Calculating image no 10 out of200
# Calculating image no 11 out of200
# Calculating image no 12 out of200
# Calculating image no 13 out of200
# Calculating image no 14 out of200
# Calculating image no 15 out of200
# Calculating image no 16 out of200
# Calculating image no 17 out of200
# Calculating image no 18 out of200
# Calculating image no 19 out of200
# Calculating image no 20 out of200
# Calculating image no 21 out of200
# Calculating image no 22 out of200
# Calculating image no 23 out of200
# Calculating image no 24 out of200
# Calculating image no 25 out of200
# Calculating image no 26 out of200
# Calculating image no 27 out of200
# Calculating image no 28 out of200
# Calculating image no 29 out of200
# Calculating image no 30 out of200
# Calculating image no 31 out of200
# Calculating image no 32 out of200
# Calculating image no 33 out of200
# Calculating image no 34 out of200
# Calculating image no 35 out of200
# Calculating image no 36 out of200
# Calculating image no 37 out of200
# Calculating image no 38 out of200
# Calculating image no 39 out of200
# Calculating image no 40 out of200
# Calculating image no 41 out of200
# Calculating image no 42 out of200
# Calculating image no 43 out of200
# Calculating image no 44 out of200
# Calculating image no 45 out of200
# Calculating image no 46 out of200
# Calculating image no 47 out of200
# Calculating image no 48 out of200
# Calculating image no 49 out of200
# Calculating image no 50 out of200
# Calculating image no 51 out of200
# Calculating image no 52 out of200
# Calculating image no 53 out of200
# Calculating image no 54 out of200
# Calculating image no 55 out of200
# Calculating image no 56 out of200
# Calculating image no 57 out of200
# Calculating image no 58 out of200
# Calculating image no 59 out of200
# Calculating image no 60 out of200
# Calculating image no 61 out of200
# Calculating image no 62 out of200
# Calculating image no 63 out of200
# Calculating image no 64 out of200
# Calculating image no 65 out of200
# Calculating image no 66 out of200
# Calculating image no 67 out of200
# Calculating image no 68 out of200
# Calculating image no 69 out of200
# Calculating image no 70 out of200
# Calculating image no 71 out of200
# Calculating image no 72 out of200
# Calculating image no 73 out of200
# Calculating image no 74 out of200
# Calculating image no 75 out of200
# Calculating image no 76 out of200
# Calculating image no 77 out of200
# Calculating image no 78 out of200
# Calculating image no 79 out of200
# Calculating image no 80 out of200
# Calculating image no 81 out of200
# Calculating image no 82 out of200
# Calculating image no 83 out of200
# Calculating image no 84 out of200
# Calculating image no 85 out of200
# Calculating image no 86 out of200
# Calculating image no 87 out of200
# Calculating image no 88 out of200
# Calculating image no 89 out of200
# Calculating image no 90 out of200
# Calculating image no 91 out of200
# Calculating image no 92 out of200
# Calculating image no 93 out of200
# Calculating image no 94 out of200
# Calculating image no 95 out of200
# Calculating image no 96 out of200
# Calculating image no 97 out of200
# Calculating image no 98 out of200
# Calculating image no 99 out of200
# Calculating image no 100 out of200
# Calculating image no 101 out of200
# Calculating image no 102 out of200
# Calculating image no 103 out of200
# Calculating image no 104 out of200
# Calculating image no 105 out of200
# Calculating image no 106 out of200
# Calculating image no 107 out of200
# Calculating image no 108 out of200
# Calculating image no 109 out of200
# Calculating image no 110 out of200
# Calculating image no 111 out of200
# Calculating image no 112 out of200
# Calculating image no 113 out of200
# Calculating image no 114 out of200
# Calculating image no 115 out of200
# Calculating image no 116 out of200
# Calculating image no 117 out of200
# Calculating image no 118 out of200
# Calculating image no 119 out of200
# Calculating image no 120 out of200
# Calculating image no 121 out of200
# Calculating image no 122 out of200
# Calculating image no 123 out of200
# Calculating image no 124 out of200
# Calculating image no 125 out of200
# Calculating image no 126 out of200
# Calculating image no 127 out of200
# Calculating image no 128 out of200
# Calculating image no 129 out of200
# Calculating image no 130 out of200
# Calculating image no 131 out of200
# Calculating image no 132 out of200
# Calculating image no 133 out of200
# Calculating image no 134 out of200
# Calculating image no 135 out of200
# Calculating image no 136 out of200
# Calculating image no 137 out of200
# Calculating image no 138 out of200
# Calculating image no 139 out of200
# Calculating image no 140 out of200
# Calculating image no 141 out of200
# Calculating image no 142 out of200
# Calculating image no 143 out of200
# Calculating image no 144 out of200
# Calculating image no 145 out of200
# Calculating image no 146 out of200
# Calculating image no 147 out of200
# Calculating image no 148 out of200
# Calculating image no 149 out of200
# Calculating image no 150 out of200
# Calculating image no 151 out of200
# Calculating image no 152 out of200
# Calculating image no 153 out of200
# Calculating image no 154 out of200
# Calculating image no 155 out of200
# Calculating image no 156 out of200
# Calculating image no 157 out of200
# Calculating image no 158 out of200
# Calculating image no 159 out of200
# Calculating image no 160 out of200
# Calculating image no 161 out of200
# Calculating image no 162 out of200
# Calculating image no 163 out of200
# Calculating image no 164 out of200
# Calculating image no 165 out of200
# Calculating image no 166 out of200
# Calculating image no 167 out of200
# Calculating image no 168 out of200
# Calculating image no 169 out of200
# Calculating image no 170 out of200
# Calculating image no 171 out of200
# Calculating image no 172 out of200
# Calculating image no 173 out of200
# Calculating image no 174 out of200
# Calculating image no 175 out of200
# Calculating image no 176 out of200
# Calculating image no 177 out of200
# Calculating image no 178 out of200
# Calculating image no 179 out of200
# Calculating image no 180 out of200
# Calculating image no 181 out of200
# Calculating image no 182 out of200
# Calculating image no 183 out of200
# Calculating image no 184 out of200
# Calculating image no 185 out of200
# Calculating image no 186 out of200
# Calculating image no 187 out of200
# Calculating image no 188 out of200
# Calculating image no 189 out of200
# Calculating image no 190 out of200
# Calculating image no 191 out of200
# Calculating image no 192 out of200
# Calculating image no 193 out of200
# Calculating image no 194 out of200
# Calculating image no 195 out of200
# Calculating image no 196 out of200
# Calculating image no 197 out of200
# Calculating image no 198 out of200
# Calculating image no 199 out of200
# Calculating image no 200 out of200

# %% [markdown]
# ## Make a dataframe of the results

# %%
df=pd.DataFrame(results)
df2=deepcopy(df)
df2['Blocked or not']='None'
df2.loc[df2['filename'].str.contains('_fixedctrl'), 'Blocked or not'] = 'Blocked'
df2.loc[df2['filename'].str.contains('_fixingctrl'), 'Blocked or not'] = 'Blocked'
df2.loc[df2['filename'].str.contains('Additional'), 'Blocked or not'] = 'Blocked'
df2.loc[df2['filename'].str.contains('blocked'), 'Blocked or not'] = 'Blocked'
df2.loc[df2['filename'].str.contains('noblocking'), 'Blocked or not'] = 'Unblocked'
df2.loc[df2['filename'].str.contains('nblocked'), 'Blocked or not'] = 'Unblocked'
df2.loc[df2['filename'].str.contains('atto'), 'Blocked or not'] = 'Atto647@mouse'
df2.loc[(df2['filename'].str.contains('unblocked'))&(df2['filename'].str.contains('ctrl'))
        , 'Blocked or not'] = 'No Blocking'
df2.loc[(df2['filename'].str.contains('noblocking'))&(df2['filename'].str.contains('100x'))
        , 'Blocked or not'] = 'No Blocking'

df2['Condition']='None'
df2.loc[(df2['filename'].str.contains('20191212'))&(df2['filename'].str.contains('chabc'))
        , 'Condition'] = 'chABC - treated'
df2.loc[(df2['filename'].str.contains('gm6001'))&(df2['filename'].str.contains('gm6001_1to100'))
        , 'Condition'] = 'GM6001'
df2.loc[(df2['filename'].str.contains('gm6001'))&(df2['filename'].str.contains('gm60011to100'))
        , 'Condition'] = 'GM6001'
df2.loc[(df2['filename'].str.contains('gm6001'))&(df2['filename'].str.contains('dmso_1to100'))
        , 'Condition'] = 'DMSO'
df2.loc[(df2['filename'].str.contains('gm6001'))&(df2['filename'].str.contains('dmso1to100'))
        , 'Condition'] = 'DMSO'
df2.loc[(df2['filename'].str.contains('post_fixing'))&(df2['filename'].str.contains('post_fixing'))
        , 'Condition'] = 'PFA fixed'
df2.loc[(df2['filename'].str.contains('live_chabc_2'))&(df2['filename'].str.contains('treated'))
        , 'Condition'] = 'chABC - treated'
df2.loc[(df2['filename'].str.contains('live_chabc'))&(df2['filename'].str.contains('ctrl'))
        , 'Condition'] = 'chABC - ctrl'
df2.loc[(df2['filename'].str.contains('20191211_chabc'))&(df2['filename'].str.contains('treated'))
        , 'Condition'] = 'chABC - treated'

df2.loc[(df2['filename'].str.contains('chABC'))
        , 'Condition'] = 'chABC - treated'
df2.loc[(df2['filename'].str.contains('methanol'))&(df2['filename'].str.contains('methanol'))
        , 'Condition'] = 'Methanol fixed'
df2.loc[(df2['filename'].str.contains('pfa'))&(df2['filename'].str.contains('pfa'))
        , 'Condition'] = 'PFA fixed'
df2.loc[(df2['filename'].str.contains('atto'))
        , 'Condition'] = 'Atto647@mouse'
df2.loc[(df2['filename'].str.contains('Atto'))
        , 'Condition'] = 'Atto647@mouse'
df2.loc[(df2['filename'].str.contains('unblocked'))
        , 'Condition'] = 'No Blocking'
df2.loc[(df2['filename'].str.contains('noblocking'))&(df2['filename'].str.contains('post_fixing'))
        , 'Condition'] = 'No Blocking'
df2.loc[(df2['filename'].str.contains('unblocked'))&(df2['filename'].str.contains('ctrl'))
        , 'Condition'] = 'No Blocking'
df2.loc[(df2['filename'].str.contains('dditional'))&(df2['filename'].str.contains('unblocked'))
        , 'Condition'] = 'No Blocking'
df2.loc[(df2['filename'].str.contains('1to250'))
        , 'Condition'] = 'Ignore'


df2['Exp']='None'
df2.loc[(df2['filename'].str.contains('gm6001'))&(df2['filename'].str.contains('20191205'))
        , 'Exp'] = 'GM6001 20191205'
df2.loc[(df2['filename'].str.contains('gm6001'))&(df2['filename'].str.contains('20191203'))
        , 'Exp'] = 'GM6001 20191203'
df2.loc[(df2['filename'].str.contains('20191205_chabc'))&(df2['filename'].str.contains('live_chabc'))
        , 'Exp'] = 'chABC 20191205'
df2.loc[(df2['filename'].str.contains('20191212'))&(df2['filename'].str.contains('chabc'))
        , 'Exp'] = 'chABC 20191212'
df2.loc[(df2['filename'].str.contains('20191212'))&(df2['filename'].str.contains('methanol'))
        , 'Exp'] = 'methanol 20191212'
df2.loc[(df2['filename'].str.contains('20191212'))&(df2['filename'].str.contains('pfa'))
        , 'Exp'] = 'pfa 20191212'
df2.loc[(df2['filename'].str.contains('20191203'))&(df2['filename'].str.contains('post_fixing'))
        , 'Exp'] = 'pfa 20191203'
df2.loc[(df2['filename'].str.contains('20191223'))&(df2['filename'].str.contains('pfa'))
        , 'Exp'] = 'pfa 20191223'
df2.loc[(df2['filename'].str.contains('20191223'))&(df2['filename'].str.contains('methanol'))
        , 'Exp'] = 'methanol 20191223'

# %% [markdown]
# ## Check normality

# %%
var="bg sub int under mask"
variable=var #change me

x=df2[variable].values
normdvar=(x-x.mean())/x.std()
print(type(normdvar))

import scipy.stats as ss
[_,pval]=ss.kstest(normdvar,'norm')
if pval<0.05:
    print("The variable does not distribute normally")
else:
    print("The variable distributes normally")

sns.set(font_scale=1)
fig=plt.figure(figsize=(10,5))
fig.add_subplot(121)
sns.kdeplot(df2[variable],legend=False)
plt.title('Distribution of all conditions')
# Out:
# <class 'numpy.ndarray'>
# The variable distributes normally
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:1748: RuntimeWarning: invalid value encountered in greater_equal
#   cond2 = (x >= self.b) & cond0
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:448: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:448: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# Text(0.5, 1.0, 'Distribution of all conditions')

# %% [markdown]
# ## anova

# %%
df_pic=df2[df2["Blocked or not"]!="Unblocked"]
df_dmso=df_pic[df_pic["Condition"]=="DMSO"][var].dropna()
df_gm6001=df_pic[df_pic["Condition"]=="GM6001"][var].dropna()
df_atto=df_pic[df_pic["Condition"]=='Atto647@mouse'][var].dropna()
df_pfa=df_pic[df_pic["Condition"]=='PFA fixed'][var].dropna()
df_meth=df_pic[df_pic["Condition"]=='Methanol fixed'][var].dropna()
df_chabc=df_pic[df_pic["Condition"]=='chABC - treated'][var].dropna()
df_ubcontrol=df_pic[df_pic["Condition"]=="No Blocking"][var].dropna()


stats.f_oneway(df_atto, df_pfa, df_meth,df_chabc)
# Out:
# F_onewayResult(statistic=1.7065691041314166, pvalue=0.1680713214557669)

# %% [markdown]
# ## ttests

# %%
df_pic=df2[df2["Blocked or not"]!="Unblocked"]
df_dmso=df_pic[df_pic["Condition"]=="DMSO"][var].dropna()
df_gm6001=df_pic[df_pic["Condition"]=="GM6001"][var].dropna()
df_atto=df_pic[df_pic["Condition"]=='Atto647@mouse'][var].dropna()
df_pfa=df_pic[df_pic["Condition"]=='PFA fixed'][var].dropna()
df_meth=df_pic[df_pic["Condition"]=='Methanol fixed'][var].dropna()
df_chabc=df_pic[df_pic["Condition"]=='chABC - treated'][var].dropna()
df_ubcontrol=df_pic[df_pic["Condition"]=="No Blocking"][var].dropna()

[stat, pvalpfa]=stats.ttest_ind(df_atto,df_pfa)
[stat, pvalmeth]=stats.ttest_ind(df_atto,df_meth)
[stat, pvalchabc]=stats.ttest_ind(df_atto,df_chabc)

print('pfa: '+str(pvalpfa*3))
print('meth: '+str(pvalmeth*3))
print('chabc: '+str(pvalchabc*3))
# Out:
# pfa: 0.08993967743326758
# meth: 0.04234137163510033
# chabc: 1.772205448083976

# %%
sns.set(font_scale=2.5)
sns.set_style("ticks")
sns.set_palette("Set2")
from matplotlib import ticker

fig=plt.figure(figsize=(5,6))
df2plot=df2#[df2["Blocked or not"]!="Unblocked"]
#var="bg sub int under mask norm2med"
#var="ecm mean int norm2med"
var="bg sub int under mask"

order=['Atto647@mouse',
       'PFA fixed','Methanol fixed','chABC - treated','No Blocking'
       ]

paletteswarm ={"Atto647@mouse":"#2F67F8",
               'PFA fixed':"#2F67F8",
               "Methanol fixed":"#2F67F8",
               "chABC - treated":"#2F67F8",
               "No Blocking":"#333333"}
palette ={"Atto647@mouse":"#abc2fc",
               'PFA fixed':"#abc2fc",
               "Methanol fixed":"#abc2fc",
               "chABC - treated":"#abc2fc",
               "No Blocking":"#adadad"}


g=sns.barplot(data=df2plot,y=var,x="Condition",
            order=order,palette=palette,ci=None)

g=sns.swarmplot(data=df2plot,y=var,x="Condition",
            order=order,palette=paletteswarm,size=8)

def change_width(ax, new_value) :
    for patch in ax.patches :
        current_width = patch.get_width()
        diff = current_width - new_value
        
        # we change the bar width
        patch.set_width(new_value)

        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)
        
change_width(g, .8)

plt.errorbar(x=np.arange(0,len(order)),
             y=[df2plot[df2plot["Condition"]==condtype][var].mean() for condtype in order],
             yerr=[df2plot[df2plot["Condition"]==condtype][var].sem() for condtype in order],
             xerr=None,ecolor='black',fmt='none',capsize=10,linewidth=3,
             capthick=3,zorder=10,
            alpha=1)

plt.axhline(0, color='#333333',alpha=1,linewidth=4)

g.xaxis.set_tick_params(width=4)
g.yaxis.set_tick_params(width=4)

plt.rcParams['font.sans-serif'] = 'Helvetica'


g.set_ylabel('')
g.set_xlabel('',color='#333333',alpha=.7)


g.grid(False)


for axis in ['top','bottom','left','right']:
  g.spines[axis].set_linewidth(4)
  g.spines[axis].set_color('#333333')
  g.spines[axis].set_alpha(1)

plt.xticks(g.get_xticks(),['Neg ctrl',
       '4% PFA','Methanol','chABC','No blocking'
       ],
           rotation=75,size=24)
offsets={"left":10,"bottom":0}
trims={"left":True,"bottom":False,"right":False}
sns.despine(ax=g,right=True,top=True,bottom=True,trim=trims,offset=offsets)
#plt.yticks([0,2,4,6,8,10,12],fontsize=22,color='#333333')


scale_x=100
ticks_y=ticker.FuncFormatter(lambda x, pos: '{0:g}' .format(x/scale_x))
g=plt.gca()
g.yaxis.set_major_formatter(ticks_y)

#plt.ylim([0,12.5])
'''x1, x2 = 0,4
y= 640
h=10
col='black'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=3.5, c=col)
plt.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col,size=24, weight='bold')

x1, x2 = 1,4
y= 640
h=10
col='black'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=3.5, c=col)
plt.text((x1+x2)*.5, y+h, "", ha='center', va='bottom', color=col,size=24, weight='bold')

x1, x2 = 2,4
y= 640
h=10
col='black'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=3.5, c=col)
plt.text((x1+x2)*.5, y+h, "", ha='center', va='bottom', color=col,size=24, weight='bold')

x1, x2 = 3,4
y= 640
h=10
col='black'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=3.5, c=col)
plt.text((x1+x2)*.5, y+h, "", ha='center', va='bottom', color=col,size=24, weight='bold')'''

for number in range(4):
    plt.text(number, 230, "***", ha='center', va='bottom', color=col,size=20, weight='bold')





diri="/Volumes/Macintosh HD/Users/taldankovich/Downloads/figures/"

fig.savefig(diri+'supp_ctrl_notpreexistingepitopes_.svg', bbox_inches='tight', format='svg')

# %%
sns.set(font_scale=2.5)
sns.set_style("ticks")
sns.set_palette("Set2")
from matplotlib import ticker

fig=plt.figure(figsize=(2,6))
df2plot=df2[df2["Blocked or not"]!="Unblocked"]
var="bg sub int under mask norm2med"
#var="ecm mean int norm2med"

order=['DMSO',
       'GM6001'
       ]

'''paletteswarm ={"Background - Autofluorescence":"#2F67F8",
               "Unblocked TNR647":"#333333",
               "Background - Atto647":"#2F67F8",
               "Block+0, TNR647":"#2F67F8",
               "Block+12, TNR647":"#2F67F8"}
palette ={"Background - Autofluorescence":"#abc2fc",
          "Unblocked TNR647":"#adadad",
               "Background - Atto647":"#abc2fc",
               "Block+0, TNR647":"#abc2fc",
               "Block+12, TNR647":"#abc2fc"}'''


g=sns.barplot(data=df2plot,y=var,x="Condition",
            order=order,color="#abc2fc",ci=None)

g=sns.swarmplot(data=df2plot,y=var,x="Condition",
            order=order,color="#2F67F8",size=8)

def change_width(ax, new_value) :
    for patch in ax.patches :
        current_width = patch.get_width()
        diff = current_width - new_value
        
        # we change the bar width
        patch.set_width(new_value)

        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)
        
change_width(g, .8)

plt.errorbar(x=np.arange(0,len(order)),
             y=[df2plot[df2plot["Condition"]==condtype][var].mean() for condtype in order],
             yerr=[df2plot[df2plot["Condition"]==condtype][var].sem() for condtype in order],
             xerr=None,ecolor='black',fmt='none',capsize=10,linewidth=3,
             capthick=3,zorder=10,
            alpha=1)

plt.axhline(0, color='#333333',alpha=1,linewidth=4)

g.xaxis.set_tick_params(width=4)
g.yaxis.set_tick_params(width=4)

plt.rcParams['font.sans-serif'] = 'Helvetica'


g.set_ylabel('')
g.set_xlabel('',color='#333333',alpha=.7)


g.grid(False)


for axis in ['top','bottom','left','right']:
  g.spines[axis].set_linewidth(4)
  g.spines[axis].set_color('#333333')
  g.spines[axis].set_alpha(1)

plt.xticks(g.get_xticks(),order,
           rotation=75,size=24)
offsets={"left":10,"bottom":0}
trims={"left":True,"bottom":False,"right":False}
sns.despine(ax=g,right=True,top=True,bottom=True,trim=trims,offset=offsets)
#plt.yticks([0,2,4,6,8,10,12],fontsize=22,color='#333333')


scale_x=1
ticks_y=ticker.FuncFormatter(lambda x, pos: '{0:g}' .format(x/scale_x))
g=plt.gca()
g.yaxis.set_major_formatter(ticks_y)

#plt.ylim([0,12.5])
x1, x2 = 0,1
y= 1.65
h=0.05
col='black'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=3.5, c=col)
plt.text((x1+x2)*.5, y+h, "ns", ha='center', va='bottom', color=col,size=24, weight='bold')



diri="/Volumes/Macintosh HD/Users/taldankovich/Downloads/figures/"

fig.savefig(diri+'supp_ctrl_notpreexistingepitopes_gm6001.svg', bbox_inches='tight', format='svg')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-238d925247f0> in <module>
#      26
#      27 g=sns.barplot(data=df2plot,y=var,x="Condition",
# ---> 28             order=order,color=palette,ci=None)
#      29
#      30 g=sns.swarmplot(data=df2plot,y=var,x="Condition",
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1605         """Initialize the plotter."""
#    1606         self.establish_variables(x, y, hue, data, orient,
# -> 1607                                  order, hue_order, units)
#    1608         self.establish_colors(color, palette, saturation)
#    1609         self.estimate_statistic(estimator, ci, n_boot)
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153                 if isinstance(input, string_types):
#     154                     err = "Could not interpret input '{}'".format(input)
# --> 155                     raise ValueError(err)
#     156
#     157             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'bg sub int under mask norm2med'

# %% [markdown]
# ## Number of images in each condition

# %%
for condition in df2plot["Condition"].unique():
    print(condition+' ' + 
          str(len(df2plot[df2plot["Condition"]==condition]))+
          '  '+
         str(df2plot[df2plot["Condition"]==condition].mean()))
# Out:
# chABC - treated 40  bg sub int under mask    48.198975
# dtype: float64
# Atto647@mouse 40  bg sub int under mask    44.962387
# dtype: float64
# PFA fixed 40  bg sub int under mask    39.347514
# dtype: float64
# Methanol fixed 40  bg sub int under mask    39.036414
# dtype: float64
# No Blocking 40  bg sub int under mask    271.869076
# dtype: float64

# %% [markdown]
# ## find representative pics

# %%
len(df_dmso)

# %%
df_pic=df2[df2["Blocked or not"]!="Unblocked"]
df_dmso=df_pic[df_pic["Condition"]=="DMSO"]
df_gm6001=df_pic[df_pic["Condition"]=="GM6001"]
df_atto=df_pic[df_pic["Condition"]=='Atto647@mouse']
df_pfa=df_pic[df_pic["Condition"]=='PFA fixed']
df_meth=df_pic[df_pic["Condition"]=='Methanol fixed']
df_chabc=df_pic[df_pic["Condition"]=='chABC - treated']
df_ubcontrol=df_pic[df_pic["Condition"]=="No Blocking"]

df_2show=df_atto
df_2show=df_2show.reset_index()

minval=0
maxval=10000
num=1
leng=len(df_2show)
fig=plt.figure(figsize=(20,150))
for i in range(0,len(df_2show)):
    #print(i)
    fig.add_subplot(leng,1,num)
    with ND2Reader(df_2show["filename"][i]) as images:
        ecm_image=images[0]
        plt.imshow(ecm_image,interpolation='none',cmap='hot',vmin=minval,vmax=maxval)
        plt.title(df_2show["filename"][i][-40:], size=14)
        plt.yticks(visible=False)
        plt.xticks(visible=False)
        plt.grid(visible=False)
        plt.axis(visible=False)
        #scalebar = ScaleBar(107.1, 'nm', dimension='si-length',box_alpha=0,location='lower right',length_fraction=0.2,
        #                       font_properties={'size':0,'weight':'bold'},color='white',border_pad=0.5) # 1 pixel = 0.2 meter
        #plt.gca().add_artist(scalebar)
        num+=1

# %% [markdown]
# ## anova compare all including no blocking, followed by post hoc

# %%
df_pic=df2#[df2["Blocked or not"]!="Unblocked"]
df_dmso=df_pic[df_pic["Condition"]=="DMSO"][var].dropna()
df_gm6001=df_pic[df_pic["Condition"]=="GM6001"][var].dropna()
df_atto=df_pic[df_pic["Condition"]=='Atto647@mouse'][var].dropna()
df_pfa=df_pic[df_pic["Condition"]=='PFA fixed'][var].dropna()
df_meth=df_pic[df_pic["Condition"]=='Methanol fixed'][var].dropna()
df_chabc=df_pic[df_pic["Condition"]=='chABC - treated'][var].dropna()
df_ubcontrol=df_pic[df_pic["Condition"]=="No Blocking"][var].dropna()


stats.f_oneway(df_atto, df_pfa, df_meth,df_chabc,df_ubcontrol)
# Out:
# F_onewayResult(statistic=150.37785504103385, pvalue=9.832048858155624e-58)

# %%
df3=df2.dropna()
df3=df3.reset_index(drop=True)

# %%
import ipywidgets as widgets
from ipywidgets import interact
import scipy.stats as stats
import statsmodels.formula.api as smf
import statsmodels.stats.multicomp as multi
from statsmodels.stats.libqsturng import psturng

x = df3["Condition"]
y = df3[var]
# DataFrame.
mcDate = multi.MultiComparison(y,x)
Results = mcDate.tukeyhsd()
df = pd.DataFrame(data=Results._results_table.data[1:], columns=Results._results_table.data[0])
res=Results
pvals=psturng(np.abs(res.meandiffs / res.std_pairs),len(res.groupsunique), res.df_total)
df["pvals"]=pvals

df
# Out:
#            group1           group2  meandiff     lower     upper  reject  \
# 0   Atto647@mouse   Methanol fixed   -5.9260  -39.4913   27.6393   False
# 1   Atto647@mouse      No Blocking  226.9067  194.4795  259.3338    True
# 2   Atto647@mouse        PFA fixed   -5.6149  -38.0420   26.8123   False
# 3   Atto647@mouse  chABC - treated    3.2366  -29.1906   35.6637   False
# 4  Methanol fixed      No Blocking  232.8327  199.2674  266.3979    True
# 5  Methanol fixed        PFA fixed    0.3111  -33.2542   33.8764   False
# 6  Methanol fixed  chABC - treated    9.1626  -24.4027   42.7278   False
# 7     No Blocking        PFA fixed -232.5216 -264.9487 -200.0944    True
# 8     No Blocking  chABC - treated -223.6701 -256.0972 -191.2430    True
# 9       PFA fixed  chABC - treated    8.8515  -23.5757   41.2786   False
#
#    pvals
# 0  0.900
# 1  0.001
# 2  0.900
# 3  0.900
# 4  0.001
# 5  0.900
# 6  0.900
# 7  0.001
# 8  0.001
# 9  0.900
