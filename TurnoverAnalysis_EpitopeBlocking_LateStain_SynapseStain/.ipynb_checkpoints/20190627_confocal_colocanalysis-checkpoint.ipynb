# %%
import numpy as np
import os
from nd2reader import ND2Reader
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib_scalebar.scalebar import ScaleBar
import scipy.ndimage as ndi
from skimage.filters import rank 
from scipy.signal import butter, lfilter
import scipy.misc as misc
from skimage import exposure
from PIL import Image
import colorcet as cc
from scipy.misc import toimage
import matplotlib.colors as clr
import pandas as pd
import seaborn as sns
from scipy import stats
import cv2
from pyspark import SparkContext, SparkConf
import skimage
from pathlib import Path

def mean2(x):
    y = np.sum(x) / np.size(x);
    return y
def corr2(a,b):
    a = a - mean2(a)
    b = b - mean2(b)

    r = (a*b).sum() / np.sqrt((a*a).sum() * (b*b).sum());
    return r
from copy import deepcopy
from skimage.filters import threshold_otsu,threshold_li
import glob
from IPython.display import clear_output
import scipy.io as spio
import pims
from skimage.measure import label, regionprops
from skimage.color import label2rgb
import scipy

import warnings
warnings.filterwarnings('ignore')

# %%
expdir='/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Leica confocal/'
protein="TNR" #TNR,Agg,WFA,HABP

# %%
results = {"filename":[],
          "exp condition":[],
          "ecmchannelno":[],
          "endosomechannelno":[],
           "Manual ECM spots mask":[],
           "Manual endosome spots mask":[],
          }
           
path = os.path.dirname(expdir)  
outputFolder = os.path.dirname(expdir + "/new/")
filelist = []
for root, _, filenames in os.walk(path):
     for filename in filenames:
         filelist.append(os.path.join(root, filename))      
for i in range(0,len(filelist)):
    if "_analyse" in str(filelist[i]):
        if "2019" in str(filelist[i]):
            if ("posthoc" in str(filelist[i]))==False:
                #if (protein in str(filelist[i]))==True:
                    if filelist[i].endswith(".tif"): 
                        if str(filelist[i][:-12]) not in str(results["filename"]):
                            results["filename"].append(filelist[i][:-12])
                            results["exp condition"].append(filelist[i][:-12].split('/')[-2])
                            channeldir="/".join(filelist[i][:-12].split("/")[:-1])
                            exec(open(channeldir+"/channels.txt").read())
                            results["ecmchannelno"].append(ecmchannelno)
                            results["endosomechannelno"].append(endosomechannelno)

# %% [markdown]
# ## Loading a random image

# %%
randomno=np.random.randint(1,len(results["filename"]))
ecm_channel_no=results["ecmchannelno"][randomno]
endosome_channel_no=results["endosomechannelno"][randomno]

ecm_image_name=results["filename"][randomno]+"0_ch"+str(ecm_channel_no-1)+"_t0.tif"
endosome_image_name=results["filename"][randomno]+"0_ch"+str(endosome_channel_no-1)+"_t0.tif"

print("Image name:",results["filename"][randomno].split('/')[-1])
print("Experimental condition:",results["exp condition"][randomno])
ecm_image=pims.open(ecm_image_name)[0]
endosome_image=pims.open(endosome_image_name)[0]
   
figure=plt.figure(figsize=(15,15))
figure.add_subplot(131)
plt.imshow(ecm_image,interpolation='none',cmap='hot')
plt.title('ECM raw')
plt.grid(visible=False)
plt.xticks(visible=False)
plt.yticks(visible=False)
scalebar = ScaleBar(40, 'nm', dimension='si-length',box_alpha=0,location='lower right',length_fraction=0.2,
                       font_properties={'size':16,'weight':'bold'},color='white',border_pad=0.5) # 1 pixel = 0.2 meter
plt.gca().add_artist(scalebar)
figure.add_subplot(132)
plt.imshow(ecm_image,interpolation='none',cmap='hot',vmin=3*np.min(ecm_image),vmax=0.4*np.max(ecm_image))
plt.title('ECM scaled')
plt.grid(visible=False)
plt.xticks(visible=False)
plt.yticks(visible=False)
scalebar = ScaleBar(40, 'nm', dimension='si-length',box_alpha=0,location='lower right',length_fraction=0.2,
                       font_properties={'size':16,'weight':'bold'},color='white',border_pad=0.5) # 1 pixel = 0.2 meter
    
plt.gca().add_artist(scalebar)

figure.add_subplot(133)
plt.imshow(endosome_image,interpolation='none',cmap='hot')
plt.title('endosome raw')
plt.grid(visible=False)
plt.xticks(visible=False)
plt.yticks(visible=False)
scalebar = ScaleBar(40, 'nm', dimension='si-length',box_alpha=0,location='lower right',length_fraction=0.2,
                       font_properties={'size':16,'weight':'bold'},color='white',border_pad=0.5) # 1 pixel = 0.2 meter
    
plt.gca().add_artist(scalebar)
# Out:
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# Image name: 20190505_tnr550_blkplus12_postliveexp_rab11a_goodparams_Series0_z
# Experimental condition: 20190505_tnr550_blkplus12_postliveexp_rab11a_goodparams
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)

# %% [markdown]
# ## Load manual spots

# %%
for image in range(0,len(results["filename"])):
    results["Manual ECM spots mask"].append(np.load(results["filename"][image]+'_ecm_spots_mask.npy'))
    results["Manual endosome spots mask"].append(np.load(results["filename"][image]+'_endosome_spots_mask.npy'))

# %% [markdown]
# ### Sanity check

# %%
ecm_min_distances_array
# Out:
# array([[ 0.        ],
#        [ 9.43398113],
#        [ 0.        ],
#        [ 7.21110255],
#        [ 0.        ],
#        [19.31320792]])

# %%
rot_ecm_min_distances_array
# Out:
# array([[ 16.97056275],
#        [ 26.83281573],
#        [ 18.97366596],
#        [ 18.86796226],
#        [ 10.        ],
#        [102.1763182 ]])

# %%
rot_ecm_min_distances_array=np.amin(rot_distances[0],1,keepdims=True)
for blob in range(1,len(endosome_spots_results_sanity)):
    newmins=np.amin(rot_distances[blob],1,keepdims=True)
    concat=np.concatenate([deepcopy(rot_ecm_min_distances_array),newmins],1)
    rot_ecm_min_distances_array=np.amin(deepcopy(concat),1,keepdims=True)

# %%
randomno=np.random.randint(1,len(results["filename"]))
ecm_channel_no=results["ecmchannelno"][randomno]
endosome_channel_no=results["endosomechannelno"][randomno]

ecm_image_name=results["filename"][randomno]+"0_ch"+str(ecm_channel_no-1)+"_t0.tif"
endosome_image_name=results["filename"][randomno]+"0_ch"+str(endosome_channel_no-1)+"_t0.tif"

ecm_image=pims.open(ecm_image_name)[0]
endosome_image=pims.open(endosome_image_name)[0]

#read spots masks and label
ecm_mask=results["Manual ECM spots mask"][randomno]
endosome_mask=results["Manual endosome spots mask"][randomno]
#rotated ecm mask
rot_ecm_mask=deepcopy(ecm_mask)
rot_ecm_mask=np.rot90(rot_ecm_mask)
labeled_ecm=label(ecm_mask)
rot_labeled_ecm=label(rot_ecm_mask)
labeled_endosome=label(endosome_mask)

regionprops_ecm=regionprops(labeled_ecm)
regionprops_endosome=regionprops(labeled_endosome)
rot_regionprops_ecm=regionprops(rot_labeled_ecm)

ecm_spots_results_sanity=[]
rot_ecm_spots_results_sanity=[]
endosome_spots_results_sanity=[]
for i in range(0,len(regionprops_ecm)):
    ecm_spots_results_sanity.append(regionprops_ecm[i]['centroid'])
for i in range(0,len(rot_regionprops_ecm)):
    rot_ecm_spots_results_sanity.append(rot_regionprops_ecm[i]['centroid'])
for i in range(0,len(regionprops_endosome)):
    endosome_spots_results_sanity.append(regionprops_endosome[i]['coords'])

#minimum distance between spots
distances=[]
minimums=[]
rot_distances=[]
rot_minimums=[]
for blob in range(0,len(endosome_spots_results_sanity)):
    distances.append(scipy.spatial.distance.cdist
                     (np.round(ecm_spots_results_sanity),endosome_spots_results_sanity[blob],'euclidean'))
    minimums.append(scipy.spatial.distance.cdist
                     (np.round(ecm_spots_results_sanity),endosome_spots_results_sanity[blob],'euclidean').min())
    
    rot_distances.append(scipy.spatial.distance.cdist
                     (np.round(rot_ecm_spots_results_sanity),endosome_spots_results_sanity[blob],'euclidean'))
    rot_minimums.append(scipy.spatial.distance.cdist
                     (np.round(rot_ecm_spots_results_sanity),endosome_spots_results_sanity[blob],'euclidean').min())

#make array of min distance from each ecm centroid
ecm_min_distances_array=np.amin(distances[0],1,keepdims=True)
for blob in range(1,len(endosome_spots_results_sanity)):
    newmins=np.amin(distances[blob],1,keepdims=True)
    concat=np.concatenate([deepcopy(ecm_min_distances_array),newmins],1)
    ecm_min_distances_array=np.amin(deepcopy(concat),1,keepdims=True)
rot_ecm_min_distances_array=np.amin(rot_distances[0],1,keepdims=True)
for blob in range(1,len(endosome_spots_results_sanity)):
    newmins=np.amin(rot_distances[blob],1,keepdims=True)
    concat=np.concatenate([deepcopy(rot_ecm_min_distances_array),newmins],1)
    rot_ecm_min_distances_array=np.amin(deepcopy(concat),1,keepdims=True)
    

#find the coordinates of the closest ecm centroid and endosome boundary
endosomeblobcount=-1
for i in range(0,len(distances)):
    endosomeblobcount+=1
    l= np.where(distances[i]==np.min(minimums))
    if l[1].size:
        endosomeblob_ecmcentroid_endosomecoords=[endosomeblobcount,l[0][0],l[1][0]]

closest_ecm_coords=ecm_spots_results_sanity[endosomeblob_ecmcentroid_endosomecoords[1]]
closest_endosome_boundary_coords=endosome_spots_results_sanity[endosomeblob_ecmcentroid_endosomecoords[0]][endosomeblob_ecmcentroid_endosomecoords[2]]

endosomeblobcount=-1
for i in range(0,len(rot_distances)):
    endosomeblobcount+=1
    l= np.where(rot_distances[i]==np.min(rot_minimums))
    if l[1].size:
        rot_endosomeblob_ecmcentroid_endosomecoords=[endosomeblobcount,l[0][0],l[1][0]]

rot_closest_ecm_coords=rot_ecm_spots_results_sanity[rot_endosomeblob_ecmcentroid_endosomecoords[1]]
rot_closest_endosome_boundary_coords=endosome_spots_results_sanity[rot_endosomeblob_ecmcentroid_endosomecoords[0]][rot_endosomeblob_ecmcentroid_endosomecoords[2]]


print('Min distance for real image = '+str(np.min(minimums)))
print('Min distance for rotated image = '+str(np.min(rot_minimums)))
    
fig=plt.figure(figsize=(15,15))
fig.add_subplot(331)
plt.title('Raw ECM')
plt.imshow(ecm_image)
fig.add_subplot(332)
plt.title('Manual spots ECM')
plt.imshow(ecm_mask)
fig.add_subplot(333)
plt.title('Labeled ECM image with centroids')
plt.imshow(labeled_ecm)
for i in range(0,len(ecm_spots_results_sanity)):
    plt.plot(ecm_spots_results_sanity[i][1],ecm_spots_results_sanity[i][0],'+',color='r',markersize=12)

fig.add_subplot(334)
plt.title('Raw endosome')
plt.imshow(endosome_image)
fig.add_subplot(335)
plt.title('Manual spots endosome')
plt.imshow(endosome_mask)
fig.add_subplot(336)
plt.title('Labeled endosome image with centroids')
plt.imshow(labeled_endosome)
for i in range(0,len(endosome_spots_results_sanity)):
    for j in range(0,len(endosome_spots_results_sanity[i])):
        plt.plot(endosome_spots_results_sanity[i][j][1],endosome_spots_results_sanity[i][j][0],'+',color='r',markersize=12)

fig.add_subplot(337)
plt.title('Raw ECM rotated')
plt.imshow(np.rot90(ecm_image))
fig.add_subplot(338)
plt.title('Manual spots ECM rotated')
plt.imshow(rot_ecm_mask)
fig.add_subplot(339)
plt.title('Labeled ECM rotated image with centroids')
plt.imshow(rot_labeled_ecm)
for i in range(0,len(ecm_spots_results_sanity)):
    plt.plot(rot_ecm_spots_results_sanity[i][1],rot_ecm_spots_results_sanity[i][0],'+',color='r',markersize=12)

newfig=plt.figure(figsize=(10,10))
newfig.add_subplot(121)
plt.title('Overlap', size=20)
plt.imshow(endosome_mask,cmap='gray',alpha=0.3)
plt.imshow(ecm_mask,cmap='viridis',alpha=0.7)
plt.plot(closest_ecm_coords[1],closest_ecm_coords[0],'o',markersize=4,color='g')
plt.plot(closest_endosome_boundary_coords[1],closest_endosome_boundary_coords[0],'o',markersize=4,color='b')

newfig.add_subplot(122)
plt.title('Overlap for rotated', size=20)
plt.imshow(endosome_mask,cmap='gray',alpha=0.3)
plt.imshow(rot_ecm_mask,cmap='viridis',alpha=0.7)
plt.plot(rot_closest_ecm_coords[1],rot_closest_ecm_coords[0],'o',markersize=4,color='g')
plt.plot(rot_closest_endosome_boundary_coords[1],rot_closest_endosome_boundary_coords[0],'o',markersize=4,color='b')

##show percent of under 50nm (=1.24pxls)

percent_under=sum(np.array(ecm_min_distances_array)<1.24)/len(ecm_min_distances_array)*100
percent_under_rot=sum(np.array(rot_ecm_min_distances_array)<1.24)/len(rot_ecm_min_distances_array)*100

print('Min percent under 50nm for real image = '+str(percent_under[0]))
print('Min percent under 50nm for rotated image = '+str(percent_under_rot[0]))

fig=plt.figure(figsize=(10,10))
fig.add_subplot(121)
plt.title('Under 50nm distance', size=20)
plt.imshow(endosome_mask,cmap='gray',alpha=0.3)
plt.imshow(ecm_mask,cmap='viridis',alpha=0.7)
c=np.where(np.array(ecm_min_distances_array)<1.24)
if len(c[0])>0:
    for min in range(0,len(c[0])-1):
        plt.plot(ecm_spots_results_sanity[c[0][min]][1],ecm_spots_results_sanity[c[0][min]][0],'o',color='green',markersize=20)


fig.add_subplot(122)
plt.title('Under 50nm distance for rotated', size=20)
plt.imshow(endosome_mask,cmap='gray',alpha=0.3)
plt.imshow(rot_ecm_mask,cmap='viridis',alpha=0.7)
c=np.where(np.array(rot_ecm_min_distances_array)<1.24)
if len(c[0])>0:
    for min in range(0,len(c[0])-1):
        plt.plot(rot_ecm_spots_results_sanity[c[0][min]][1],rot_ecm_spots_results_sanity[c[0][min]][0],'o',color='green',markersize=20)
# Out:
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# Min distance for real image = 0.0
# Min distance for rotated image = 1.4142135623730951
# Min percent under 50nm for real image = 7.6923076923076925
# Min percent under 50nm for rotated image = 0.0

# %% [markdown]
# ## Batch analysis on spots

# %% [markdown]
# ### Dictionary of spot regionprops

# %%
#dictionary per image:
ecm_image_results={"filename":[],"exp condition":[],
                   "distances to nearest endosome boundary":[],
                  "distances to nearest endosome boundary [nms]":[],
                  "min distance to nearest endosome boundary for whole image":[],
                  "min distance to nearest endosome boundary for whole image [nms]":[],
                  "rotated - distances to nearest endosome boundary":[],
                  "rotated - distances to nearest endosome boundary [nms]":[],
                  "rotated - min distance to nearest endosome boundary for whole image":[],
                  "rotated - min distance to nearest endosome boundary for whole image [nms]":[]}

for image in range(0,len(results["filename"])):
    print('Calculating image no ' + str(image+1) + ' out of' + str(len(results["filename"])))
    #read images
    #ecm_channel_no=results["ecmchannelno"][image]
    #endosome_channel_no=results["endosomechannelno"][image]
    #ecm_image_name=results["filename"][image]+"0_ch"+str(ecm_channel_no-1)+"_t0.tif"
    #endosome_image_name=results["filename"][image]+"0_ch"+str(endosome_channel_no-1)+"_t0.tif"
    #ecm_image=pims.open(ecm_image_name)[0]
    #endosome_image=pims.open(endosome_image_name)[0]
    
    #read spots masks and label
    ecm_mask=results["Manual ECM spots mask"][image]
    if len(ecm_mask.shape)==0:
        ecm_mask=np.zeros(ecm_image.shape).astype(bool)
    endosome_mask=results["Manual endosome spots mask"][image]
    if len(endosome_mask.shape)==0:
        endosome_mask=np.zeros(endosome_image.shape).astype(bool)
    #rotated ecm mask
    rot_ecm_mask=deepcopy(ecm_mask)
    rot_ecm_mask=np.rot90(rot_ecm_mask)
    labeled_ecm=label(ecm_mask)
    rot_labeled_ecm=label(rot_ecm_mask)
    labeled_endosome=label(endosome_mask)
    #regionprops for labeled masks
    if np.sum(ecm_mask>0) & np.sum(endosome_mask>0):
        regionprops_ecm=regionprops(labeled_ecm)
        regionprops_endosome=regionprops(labeled_endosome)
        rot_regionprops_ecm=regionprops(rot_labeled_ecm) 
        ecm_spots_results=[]
        rot_ecm_spots_results=[]
        endosome_spots_results=[]
        for i in range(0,len(regionprops_ecm)):
            ecm_spots_results.append(regionprops_ecm[i]['centroid'])
        for i in range(0,len(rot_regionprops_ecm)):
            rot_ecm_spots_results.append(rot_regionprops_ecm[i]['centroid'])
        for i in range(0,len(regionprops_endosome)):
            endosome_spots_results.append(regionprops_endosome[i]['coords'])
        #minimum distance between spots
        distances=[]
        rot_distances=[]
        for blob in range(0,len(endosome_spots_results)):
            distances.append(scipy.spatial.distance.cdist
                             (np.round(ecm_spots_results),endosome_spots_results[blob],'euclidean'))
            rot_distances.append(scipy.spatial.distance.cdist
                             (np.round(rot_ecm_spots_results),endosome_spots_results[blob],'euclidean'))
        #make array of min distance from each ecm centroid
        ecm_min_distances_array=np.amin(distances[0],1,keepdims=True)
        for blob in range(1,len(endosome_spots_results)):
            newmins=np.amin(distances[blob],1,keepdims=True)
            concat=np.concatenate([deepcopy(ecm_min_distances_array),newmins],1)
            ecm_min_distances_array=np.amin(deepcopy(concat),1,keepdims=True)
        rot_ecm_min_distances_array=np.amin(rot_distances[0],1,keepdims=True)
        for blob in range(1,len(endosome_spots_results)):
            newmins=np.amin(rot_distances[blob],1,keepdims=True)
            concat=np.concatenate([deepcopy(rot_ecm_min_distances_array),newmins],1)
            rot_ecm_min_distances_array=np.amin(deepcopy(concat),1,keepdims=True)

        ecm_image_results["filename"].append(results["filename"][image])
        ecm_image_results["exp condition"].append(results["exp condition"][image])
        ecm_image_results["distances to nearest endosome boundary"].append(ecm_min_distances_array)
        ecm_image_results["rotated - distances to nearest endosome boundary"].append(rot_ecm_min_distances_array)
        ecm_image_results["distances to nearest endosome boundary [nms]"].append(ecm_min_distances_array*40.4)
        ecm_image_results["rotated - distances to nearest endosome boundary [nms]"].append(rot_ecm_min_distances_array*40.4)
        ecm_image_results["min distance to nearest endosome boundary for whole image"].append(np.min(ecm_min_distances_array))
        ecm_image_results["min distance to nearest endosome boundary for whole image [nms]"].append(np.min(ecm_min_distances_array)*40.4)
        ecm_image_results["rotated - min distance to nearest endosome boundary for whole image"].append(np.min(rot_ecm_min_distances_array))
        ecm_image_results["rotated - min distance to nearest endosome boundary for whole image [nms]"].append(np.min(rot_ecm_min_distances_array)*40.4)
# Out:
# Calculating image no 1 out of168
# Calculating image no 2 out of168
# Calculating image no 3 out of168
# Calculating image no 4 out of168
# Calculating image no 5 out of168
# Calculating image no 6 out of168
# Calculating image no 7 out of168
# Calculating image no 8 out of168
# Calculating image no 9 out of168
# Calculating image no 10 out of168
# Calculating image no 11 out of168
# Calculating image no 12 out of168
# Calculating image no 13 out of168
# Calculating image no 14 out of168
# Calculating image no 15 out of168
# Calculating image no 16 out of168
# Calculating image no 17 out of168
# Calculating image no 18 out of168
# Calculating image no 19 out of168
# Calculating image no 20 out of168
# Calculating image no 21 out of168
# Calculating image no 22 out of168
# Calculating image no 23 out of168
# Calculating image no 24 out of168
# Calculating image no 25 out of168
# Calculating image no 26 out of168
# Calculating image no 27 out of168
# Calculating image no 28 out of168
# Calculating image no 29 out of168
# Calculating image no 30 out of168
# Calculating image no 31 out of168
# Calculating image no 32 out of168
# Calculating image no 33 out of168
# Calculating image no 34 out of168
# Calculating image no 35 out of168
# Calculating image no 36 out of168
# Calculating image no 37 out of168
# Calculating image no 38 out of168
# Calculating image no 39 out of168
# Calculating image no 40 out of168
# Calculating image no 41 out of168
# Calculating image no 42 out of168
# Calculating image no 43 out of168
# Calculating image no 44 out of168
# Calculating image no 45 out of168
# Calculating image no 46 out of168
# Calculating image no 47 out of168
# Calculating image no 48 out of168
# Calculating image no 49 out of168
# Calculating image no 50 out of168
# Calculating image no 51 out of168
# Calculating image no 52 out of168
# Calculating image no 53 out of168
# Calculating image no 54 out of168
# Calculating image no 55 out of168
# Calculating image no 56 out of168
# Calculating image no 57 out of168
# Calculating image no 58 out of168
# Calculating image no 59 out of168
# Calculating image no 60 out of168
# Calculating image no 61 out of168
# Calculating image no 62 out of168
# Calculating image no 63 out of168
# Calculating image no 64 out of168
# Calculating image no 65 out of168
# Calculating image no 66 out of168
# Calculating image no 67 out of168
# Calculating image no 68 out of168
# Calculating image no 69 out of168
# Calculating image no 70 out of168
# Calculating image no 71 out of168
# Calculating image no 72 out of168
# Calculating image no 73 out of168
# Calculating image no 74 out of168
# Calculating image no 75 out of168
# Calculating image no 76 out of168
# Calculating image no 77 out of168
# Calculating image no 78 out of168
# Calculating image no 79 out of168
# Calculating image no 80 out of168
# Calculating image no 81 out of168
# Calculating image no 82 out of168
# Calculating image no 83 out of168
# Calculating image no 84 out of168
# Calculating image no 85 out of168
# Calculating image no 86 out of168
# Calculating image no 87 out of168
# Calculating image no 88 out of168
# Calculating image no 89 out of168
# Calculating image no 90 out of168
# Calculating image no 91 out of168
# Calculating image no 92 out of168
# Calculating image no 93 out of168
# Calculating image no 94 out of168
# Calculating image no 95 out of168
# Calculating image no 96 out of168
# Calculating image no 97 out of168
# Calculating image no 98 out of168
# Calculating image no 99 out of168
# Calculating image no 100 out of168
# Calculating image no 101 out of168
# Calculating image no 102 out of168
# Calculating image no 103 out of168
# Calculating image no 104 out of168
# Calculating image no 105 out of168
# Calculating image no 106 out of168
# Calculating image no 107 out of168
# Calculating image no 108 out of168
# Calculating image no 109 out of168
# Calculating image no 110 out of168
# Calculating image no 111 out of168
# Calculating image no 112 out of168
# Calculating image no 113 out of168
# Calculating image no 114 out of168
# Calculating image no 115 out of168
# Calculating image no 116 out of168
# Calculating image no 117 out of168
# Calculating image no 118 out of168
# Calculating image no 119 out of168
# Calculating image no 120 out of168
# Calculating image no 121 out of168
# Calculating image no 122 out of168
# Calculating image no 123 out of168
# Calculating image no 124 out of168
# Calculating image no 125 out of168
# Calculating image no 126 out of168
# Calculating image no 127 out of168
# Calculating image no 128 out of168
# Calculating image no 129 out of168
# Calculating image no 130 out of168
# Calculating image no 131 out of168
# Calculating image no 132 out of168
# Calculating image no 133 out of168
# Calculating image no 134 out of168
# Calculating image no 135 out of168
# Calculating image no 136 out of168
# Calculating image no 137 out of168
# Calculating image no 138 out of168
# Calculating image no 139 out of168
# Calculating image no 140 out of168
# Calculating image no 141 out of168
# Calculating image no 142 out of168
# Calculating image no 143 out of168
# Calculating image no 144 out of168
# Calculating image no 145 out of168
# Calculating image no 146 out of168
# Calculating image no 147 out of168
# Calculating image no 148 out of168
# Calculating image no 149 out of168
# Calculating image no 150 out of168
# Calculating image no 151 out of168
# Calculating image no 152 out of168
# Calculating image no 153 out of168
# Calculating image no 154 out of168
# Calculating image no 155 out of168
# Calculating image no 156 out of168
# Calculating image no 157 out of168
# Calculating image no 158 out of168
# Calculating image no 159 out of168
# Calculating image no 160 out of168
# Calculating image no 161 out of168
# Calculating image no 162 out of168
# Calculating image no 163 out of168
# Calculating image no 164 out of168
# Calculating image no 165 out of168
# Calculating image no 166 out of168
# Calculating image no 167 out of168
# Calculating image no 168 out of168

# %% [markdown]
# ## Plots

# %%
df_ecm=pd.DataFrame(ecm_image_results)

# %% [markdown]
# ### Backup

# %%
df_ecm.columns
# Out:
# Index(['filename', 'exp condition', 'distances to nearest endosome boundary',
#        'distances to nearest endosome boundary [nms]',
#        'min distance to nearest endosome boundary for whole image',
#        'min distance to nearest endosome boundary for whole image [nms]',
#        'rotated - distances to nearest endosome boundary',
#        'rotated - distances to nearest endosome boundary [nms]',
#        'rotated - min distance to nearest endosome boundary for whole image',
#        'rotated - min distance to nearest endosome boundary for whole image [nms]'],
#       dtype='object')

# %%
#os.mkdir(expdir+'results/')
df_ecm.to_csv(path_or_buf=expdir+'results/results_ecm.csv')

# %% [markdown]
# ## Quick look at distances

# %%
all_distances=[]
for i in range(0,len(df_ecm)):
    all_distances.append(df_ecm["distances to nearest endosome boundary [nms]"][i])
flat_list = []
for sublist in all_distances:
    for item in sublist:
        flat_list.append(item)
all_distances=np.array(flat_list)

all_distances_rot=[]
for i in range(0,len(df_ecm)):
    all_distances_rot.append(df_ecm["rotated - distances to nearest endosome boundary [nms]"][i])
flat_list = []
for sublist in all_distances_rot:
    for item in sublist:
        flat_list.append(item)
all_distances_rot=np.array(flat_list)

plt.figure()
plt.hist(all_distances,density=True,bins=200)
plt.hist(all_distances_rot,density=True,bins=200)
plt.legend(['Real','Rotated'])
plt.xlim([0,500])
# Out:
# (0, 500)

# %% [markdown]
# ## Add protein labels to df

# %%
df_ecm['Protein']='None'
df_ecm.loc[(df_ecm['exp condition'].str.contains('nt'))&(df_ecm['exp condition'].str.contains('12')), 'Protein'] = 'Int1b, all TNR Blk+12, stripped'
df_ecm.loc[(df_ecm['exp condition'].str.contains('nt'))&(df_ecm['exp condition'].str.contains('surface')), 'Protein'] = 'Int1b Blk/TNR Blk, +0, surface'
df_ecm.loc[df_ecm['exp condition'].str.contains('tgn'), 'Protein'] = 'TGN38/ TNR Blk, +12'
df_ecm.loc[df_ecm['exp condition'].str.contains('rab'), 'Protein'] = 'Rab11a/ TNR Blk, +12'
df_ecm.loc[df_ecm['exp condition'].str.contains('cav'), 'Protein'] = 'Cav1/ TNR Blk'

# %% [markdown]
# ## Real versus rotated - histogram for each protein

# %%
a=np.array(np.ones(len(all_distances)) / len(all_distances))

# %%
all_distances=[]
for i in range(0,len(df2plot)):
        all_distances.append(df2plot["distances to nearest endosome boundary [nms]"][i])

# %%
protein
# Out:
# 'Int1b Blk/TNR Blk, +0, surface'

# %%
np.sum(all_distances<50)/len(all_distances)*100
# Out:
# 7.819287576020852

# %%
import matplotlib.ticker as ticker
from matplotlib.ticker import PercentFormatter


for protein in df_ecm["Protein"].unique():
    df2plot=df_ecm[(df_ecm["Protein"]==protein)].reset_index()
    all_distances=[]
    for i in range(0,len(df2plot)):
        all_distances.append(df2plot["distances to nearest endosome boundary [nms]"][i])
    all_distances=np.concatenate(all_distances, axis=0 )

    all_distances_rot=[]
    for i in range(0,len(df2plot)):
        all_distances_rot.append(df2plot["rotated - distances to nearest endosome boundary [nms]"][i])
    all_distances_rot=np.concatenate(all_distances_rot, axis=0 )

    fig=plt.figure()
    p=fig.add_subplot(111)
    
    y,binEdges=np.histogram(all_distances,bins=1000,
                           density=True)
    bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
    p.plot(bincenters,y,'+-',color='red')
    
    y,binEdges=np.histogram(all_distances_rot,bins=1000,
                            density=True)
    bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
    p.plot(bincenters,y,'+-',color='blue')
    plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
    plt.title(protein)
    #plt.ylim([0,0.03])
    #scale_y=1/100
    #ticks_y = ticker.FuncFormatter(lambda x, pos: '{0:g}'.format(x/scale_y))
    #p.yaxis.set_major_formatter(ticks_y)
    plt.xlim([0,500])

# %%
len(df2plot["distances to nearest endosome boundary [nms]"].values.flatten())
# Out:
# 28

# %%
import matplotlib.ticker as ticker
from matplotlib.ticker import PercentFormatter


for protein in df_ecm["Protein"].unique():
    df2plot=df_ecm[(df_ecm["Protein"]==protein)].reset_index()
    all_distances=df2plot["distances to nearest endosome boundary [nms]"].values
    all_distances_rot=df2plot["rotated - distances to nearest endosome boundary [nms]"].values

    fig=plt.figure()
    p=fig.add_subplot(111)
    
    
    y,binEdges=np.histogram(all_distances,bins=1000,
                            weights=np.ones(len(all_distances)) / len(all_distances))
    bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
    p.plot(bincenters,y,'+-',color='red')
    
    y,binEdges=np.histogram(all_distances_rot,bins=1000,
                            weights=np.array(np.ones(len(all_distances_rot)) / len(all_distances_rot)))
    bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
    
    p.plot(bincenters,y,'+-',color='blue')
    plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
    plt.title(protein)
    #plt.ylim([0,0.03])
    #scale_y=1/100
    #ticks_y = ticker.FuncFormatter(lambda x, pos: '{0:g}'.format(x/scale_y))
    #p.yaxis.set_major_formatter(ticks_y)
    plt.xlim([0,500])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1490-e95bcc7e2ce5> in <module>
#      13
#      14     y,binEdges=np.histogram(all_distances,bins=1000,
# ---> 15                             weights=np.ones(len(all_distances)) / len(all_distances))
#      16     bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
#      17     p.plot(bincenters,y,'+-',color='red')
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py in histogram(a, bins, range, normed, weights, density)
#     778     a, weights = _ravel_and_check_weights(a, weights)
#     779
# --> 780     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     781
#     782     # Histogram is an integer or a float array depending on the weights.
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py in _get_bin_edges(a, bins, range, weights)
#     415             raise ValueError('`bins` must be positive, when an integer')
#     416
# --> 417         first_edge, last_edge = _get_outer_edges(a, range)
#     418
#     419     elif np.ndim(bins) == 1:
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py in _get_outer_edges(a, range)
#     310         first_edge, last_edge = 0, 1
#     311     else:
# --> 312         first_edge, last_edge = a.min(), a.max()
#     313         if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
#     314             raise ValueError(
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py in _amin(a, axis, out, keepdims, initial)
#      30 def _amin(a, axis=None, out=None, keepdims=False,
#      31           initial=_NoValue):
# ---> 32     return umr_minimum(a, axis, None, out, keepdims, initial)
#      33
#      34 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# ValueError: operands could not be broadcast together with shapes (34,1) (37,1)

# %% [markdown]
# ## Real versus rotated - min distance in each image, per protein

# %% [markdown]
# ## Real vs rot - percent under 50nm distance

# %%
np.sum(
        np.array(df_ecm["distances to nearest endosome boundary [nms]"][i])<nanometers)
# Out:
# 4

# %%
len(df_ecm["distances to nearest endosome boundary [nms]"])
# Out:
# 162

# %%
nanometers=50
df_ecm["df_percentunder"]=df_ecm["distances to nearest endosome boundary [nms]"]
df_ecm["rot_df_percentunder"]=df_ecm["rotated - distances to nearest endosome boundary [nms]"]
for i in range(0,len(df_ecm)):
    df_ecm["df_percentunder"][i]=np.sum(
        np.array(df_ecm["distances to nearest endosome boundary [nms]"][i])<nanometers)/len(df_ecm["distances to nearest endosome boundary [nms]"])*100
    df_ecm["rot_df_percentunder"][i]=np.sum(
        np.array(df_ecm["rotated - distances to nearest endosome boundary [nms]"][i])<nanometers)/len(df_ecm["rotated - distances to nearest endosome boundary [nms]"])*100
# Out:
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df2plot.head()
# Out:
#                                             filename  \
# 0  /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/F...
# 1  /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/F...
# 2  /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/F...
# 3  /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/F...
# 4  /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/F...
#
#                                  exp condition  \
# 0  20190612_tnr550_blkplus12_tgn38acy2_analyse
# 1  20190612_tnr550_blkplus12_tgn38acy2_analyse
# 2  20190612_tnr550_blkplus12_tgn38acy2_analyse
# 3  20190612_tnr550_blkplus12_tgn38acy2_analyse
# 4  20190612_tnr550_blkplus12_tgn38acy2_analyse
#
#               distances to nearest endosome boundary  \
# 0  [[81.12336284942828], [9.899494936611665], [43...
# 1  [[0.0], [9.0], [14.7648230602334], [53.9351462...
# 2  [[79.07591289387686], [4.0], [15.2643375224737...
# 3  [[40.8166632639171], [33.24154027718932], [2.0...
# 4  [[50.44799302251776], [32.202484376209235], [2...
#
#         distances to nearest endosome boundary [nms]  \
# 0  [[3277.3838591169024], [399.93959543911126], [...
# 1  [[0.0], [363.59999999999997], [596.49885163342...
# 2  [[3194.666880912625], [161.6], [616.6792359079...
# 3  [[1648.9931958622508], [1342.9582271984486], [...
# 4  [[2038.0989181097173], [1300.980368798853], [9...
#
#    min distance to nearest endosome boundary for whole image  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
# 3                                                2.0
# 4                                               15.0
#
#    min distance to nearest endosome boundary for whole image [nms]  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
# 3                                               80.8
# 4                                              606.0
#
#     rotated - distances to nearest endosome boundary  \
# 0  [[68.60029154456998], [100.60318086422517], [1...
# 1  [[43.41658669218482], [57.87054518492115], [10...
# 2  [[123.01625908797584], [24.596747752497688], [...
# 3  [[22.80350850198276], [11.40175425099138], [38...
# 4  [[0.0], [11.40175425099138], [35.1283361405005...
#
#   rotated - distances to nearest endosome boundary [nms]  \
# 0  [[2771.451778400627], [4064.3685069146964], [4...
# 1  [[1754.0301023642667], [2337.970025470814], [4...
# 2  [[4969.856867154223], [993.7086092009066], [54...
# 3  [[921.2617434801034], [460.6308717400517], [15...
# 4  [[0.0], [460.6308717400517], [1419.18478007622...
#
#    rotated - min distance to nearest endosome boundary for whole image  \
# 0                                            0.00000
# 1                                            0.00000
# 2                                            0.00000
# 3                                            5.09902
# 4                                            0.00000
#
#    rotated - min distance to nearest endosome boundary for whole image [nms]  \
# 0                                           0.000000
# 1                                           0.000000
# 2                                           0.000000
# 3                                         206.000388
# 4                                           0.000000
#
#                Protein df_percentunder rot_df_percentunder
# 0  TGN38/ TNR Blk, +12         1.23457             1.85185
# 1  TGN38/ TNR Blk, +12         2.46914             1.85185
# 2  TGN38/ TNR Blk, +12         4.32099             1.85185
# 3  TGN38/ TNR Blk, +12               0                   0
# 4  TGN38/ TNR Blk, +12               0             1.85185

# %%
type(df_ecm["df_percentunder"][0])
# Out:
# numpy.float64

# %%
sns.violinplot(y="df_percentunder",x="Protein",data=df_ecm)
    plt.xticks(rotation=90)

# %%
for protein in df_ecm["Protein"].unique():
    df2plot=df_ecm[df_ecm["Protein"]==protein]
    #statistic
    real=df2plot["df_percentunder"].values
    rot=df2plot["rot_df_percentunder"].values
    [t,pval]=scipy.stats.ttest_rel(real, rot, axis=0, nan_policy='propagate')
    print(protein+': '+str(pval))
    plt.figure(figsize=(5,5))
    #plt.bar([0,1],[df2plot["df_percentunder"].mean(),df2plot["rot_df_percentunder"].mean()])
    #plt.xticks([0,1],['Real','Rotated'])
    #plt.title(protein)
    #plt.text(3,0,str(pval))

# %%
newdict={"Protein":[],"Real or rot":[],"percent under":[]}
for i in range(0,len(df_ecm)):
    newdict['Protein'].append(df_ecm["Protein"][i])
    newdict["Real or rot"].append('Real')
    newdict["percent under"].append(df_ecm["df_percentunder"][i])
    newdict['Protein'].append(df_ecm["Protein"][i])
    newdict["Real or rot"].append('Rotated')
    newdict["percent under"].append(df_ecm["rot_df_percentunder"][i])
newdf=pd.DataFrame(newdict)

# %%
sns.barplot(x="Protein",y="percent under",data=newdf,hue="Real or rot",ci=None)#,showfliers=False)
plt.xticks(rotation=90)
plt.ylabel("% TNR spots < 50 nm from costaining boundary")

#number of images calc.
Protein_order=[]
No_images=[]
for protein in df_ecm["Protein"].unique():
    df2plot=df_ecm[df_ecm["Protein"]==protein]
    Protein_order.append(protein)
    No_images.append(len(df2plot))
for i in range(0,len(No_images)):
    print(str(Protein_order[i])+' : '+str(No_images[i])+' images')
# Out:
# TGN38/ TNR Blk, +12 : 28 images
# Int1b, all TNR Blk+12, stripped : 45 images
# Rab11a/ TNR Blk, +12 : 28 images
# Cav1/ TNR Blk : 30 images
# Int1b Blk/TNR Blk, +0, surface : 31 images

# %% [markdown]
# ## Find representative images for each condition

# %%
df2show.columns
# Out:
# Index(['filename', 'exp condition', 'distances to nearest endosome boundary',
#        'distances to nearest endosome boundary [nms]',
#        'min distance to nearest endosome boundary for whole image',
#        'min distance to nearest endosome boundary for whole image [nms]',
#        'rotated - distances to nearest endosome boundary',
#        'rotated - distances to nearest endosome boundary [nms]',
#        'rotated - min distance to nearest endosome boundary for whole image',
#        'rotated - min distance to nearest endosome boundary for whole image [nms]',
#        'Protein', 'df_percentunder', 'rot_df_percentunder'],
#       dtype='object')

# %%
df_originaldata=pd.DataFrame(results)
df_originaldata['Protein']='None'
df_originaldata.loc[(df_originaldata['exp condition'].str.contains('nt'))&(df_originaldata['exp condition'].str.contains('12')), 'Protein'] = 'Int1b, all TNR Blk+12, stripped'
df_originaldata.loc[(df_originaldata['exp condition'].str.contains('nt'))&(df_originaldata['exp condition'].str.contains('surface')), 'Protein'] = 'Int1b Blk/TNR Blk, +0, surface'
df_originaldata.loc[df_originaldata['exp condition'].str.contains('tgn'), 'Protein'] = 'TGN38/ TNR Blk, +12'
df_originaldata.loc[df_originaldata['exp condition'].str.contains('rab'), 'Protein'] = 'Rab11a/ TNR Blk, +12'
df_originaldata.loc[df_originaldata['exp condition'].str.contains('cav'), 'Protein'] = 'Cav1/ TNR Blk'

# %%
from IPython.display import HTML
HTML('''<script>
code_show_err=false; 
function code_toggle_err() {
 if (code_show_err){
 $('div.output_stderr').hide();
 } else {
 $('div.output_stderr').show();
 }
 code_show_err = !code_show_err
} 
$( document ).ready(code_toggle_err);
</script>
To toggle on/off output_stderr, click <a href="javascript:code_toggle_err()">here</a>.''')


protein='TGN38/ TNR Blk, +12'

df2show=df_originaldata[df_originaldata["Protein"]==protein]

for image in range(0,len(df2show)):
    ecm_channel_no=df_originaldata["ecmchannelno"][image]
    endosome_channel_no=df_originaldata["endosomechannelno"][image]
    ecm_image_name=df_originaldata["filename"][image]+"0_ch"+str(ecm_channel_no-1)+"_t0.tif"
    endosome_image_name=df_originaldata["filename"][image]+"0_ch"+str(endosome_channel_no-1)+"_t0.tif"
    ecm_image=pims.open(ecm_image_name)[0]
    endosome_image=pims.open(endosome_image_name)[0]
    fig=plt.figure(figsize=(9,3))
    fig.add_subplot(131)
    plt.imshow(ecm_image,cmap='viridis',vmin=0.2*np.mean(ecm_image),vmax=0.8*np.max(ecm_image))
    plt.axis(show=False)
    plt.title('TNR', fontsize=14)
    fig.add_subplot(132)
    plt.imshow(endosome_image,cmap='viridis',vmin=0.2*np.mean(endosome_image),vmax=0.8*np.max(endosome_image))
    plt.axis(show=False)
    plt.title(protein, fontsize=14)
    plt.tight_layout()
# Out:
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (268088)

# %%
results.keys()
# Out:
# dict_keys(['filename', 'exp condition', 'ecmchannelno', 'endosomechannelno', 'Manual ECM spots mask', 'Manual endosome spots mask'])
