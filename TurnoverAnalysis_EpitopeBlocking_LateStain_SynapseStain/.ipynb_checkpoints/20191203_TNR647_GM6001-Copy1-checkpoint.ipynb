# %% [markdown]
# ## Import modules and functions

# %%
import numpy as np
import os
from nd2reader import ND2Reader
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib_scalebar.scalebar import ScaleBar
import scipy.ndimage as ndi
from skimage.filters import rank 
from scipy.signal import butter, lfilter
import scipy.misc as misc
from skimage import exposure
from PIL import Image
import colorcet as cc
from scipy.misc import toimage
import matplotlib.colors as clr
import pandas as pd
import seaborn as sns
from scipy import stats
import cv2
from pyspark import SparkContext, SparkConf
import skimage
from pathlib import Path

def mean2(x):
    y = np.sum(x) / np.size(x);
    return y
def corr2(a,b):
    a = a - mean2(a)
    b = b - mean2(b)

    r = (a*b).sum() / np.sqrt((a*a).sum() * (b*b).sum());
    return r
from copy import deepcopy
from skimage.filters import threshold_otsu,threshold_li
import glob
from IPython.display import clear_output
import scipy.io as spio

# %% [markdown]
# ## Define directory of images

# %%
expdir='/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Controls/20191203_TNR647_vglut580_gm6001/' #master folder

# %% [markdown]
# ## Make dictionary for storing results

# %%
results = {"filename":[],"exp":[],"coverslip":[],
           "Manual mask from matlab GUI":[],"bg sub int under mask":[]}
path = os.path.dirname(expdir)  
outputFolder = os.path.dirname(expdir + "/new/")
filelist = []
for root, _, filenames in os.walk(path):
     for filename in filenames:
         filelist.append(os.path.join(root, filename))      
for i in range(0,len(filelist)):
    #if "analyse" in str(filelist[i]):
        if filelist[i].endswith(".nd2"): 
            results["filename"].append(filelist[i])
            results["coverslip"].append(filelist[i].split('/')[-2])
            results["exp"].append(filelist[i].split('/')[-4])

# %% [markdown]
# ## Read manual masks from Matlab GUI

# %%
## matlab files
for im in range(0,len(results["filename"])): 
    file=results["filename"][im][:-4]+'_dendritesmask.mat'
    from pathlib import Path
    my_file = Path(file)
    if my_file.exists():
        print(file)
        mat = spio.loadmat(file, squeeze_me=True)
        mask=mat['totMask']>0.99
        results["Manual mask from matlab GUI"].append(mask)
    else:
        results["Manual mask from matlab GUI"].append(np.nan)
clear_output()        
print("Done!")
# Out:
# Done!

# %% [markdown]
# ## Batch analysis of images - mean intensity

# %%
print('Total number of images: ' + str(len(results['filename'])))

for i in range(0,len(results["filename"])): 
    flag=False
    print('Calculating image no ' + str(i+1) + ' out of' + str(len(results["filename"])))
    #read the image
    with ND2Reader(results["filename"][i]) as images:
        ecm_image=images[0]
    #convert to numpy array - a format easier to manipunuclei with code
    ecm_image=ecm_image.astype(np.int16)
    #read masks 
    matlab_mask=results["Manual mask from matlab GUI"][i]
    if type(matlab_mask)==np.ndarray:
        flag=True
    #image after background subtraction
    #for ecm image
    if flag==True:
        ecm_matlabmasked_bgreduced=deepcopy(ecm_image)
        bg_matlabmask=np.mean(ndi.median_filter(ecm_image[matlab_mask],size=5))+0*np.std(ndi.median_filter(ecm_image[matlab_mask],size=5))
        ecm_matlabmasked_bgreduced=np.subtract(ecm_matlabmasked_bgreduced,bg_matlabmask)
        ecm_matlabmasked_bgreduced[ecm_matlabmasked_bgreduced<0]=0
        ecm_matlabmasked_bgreduced[~matlab_mask]=0
        
    if flag==True:
        results["bg sub int under mask"].append(ecm_matlabmasked_bgreduced[matlab_mask].mean())
    else:
        results["bg sub int under mask"].append(np.nan)
# Out:
# Total number of images: 160
# Calculating image no 1 out of160
# Calculating image no 2 out of160
# Calculating image no 3 out of160
# Calculating image no 4 out of160
# Calculating image no 5 out of160
# Calculating image no 6 out of160
# Calculating image no 7 out of160
# Calculating image no 8 out of160
# Calculating image no 9 out of160
# Calculating image no 10 out of160
# Calculating image no 11 out of160
# Calculating image no 12 out of160
# Calculating image no 13 out of160
# Calculating image no 14 out of160
# Calculating image no 15 out of160
# Calculating image no 16 out of160
# Calculating image no 17 out of160
# Calculating image no 18 out of160
# Calculating image no 19 out of160
# Calculating image no 20 out of160
# Calculating image no 21 out of160
# Calculating image no 22 out of160
# Calculating image no 23 out of160
# Calculating image no 24 out of160
# Calculating image no 25 out of160
# Calculating image no 26 out of160
# Calculating image no 27 out of160
# Calculating image no 28 out of160
# Calculating image no 29 out of160
# Calculating image no 30 out of160
# Calculating image no 31 out of160
# Calculating image no 32 out of160
# Calculating image no 33 out of160
# Calculating image no 34 out of160
# Calculating image no 35 out of160
# Calculating image no 36 out of160
# Calculating image no 37 out of160
# Calculating image no 38 out of160
# Calculating image no 39 out of160
# Calculating image no 40 out of160
# Calculating image no 41 out of160
# Calculating image no 42 out of160
# Calculating image no 43 out of160
# Calculating image no 44 out of160
# Calculating image no 45 out of160
# Calculating image no 46 out of160
# Calculating image no 47 out of160
# Calculating image no 48 out of160
# Calculating image no 49 out of160
# Calculating image no 50 out of160
# Calculating image no 51 out of160
# Calculating image no 52 out of160
# Calculating image no 53 out of160
# Calculating image no 54 out of160
# Calculating image no 55 out of160
# Calculating image no 56 out of160
# Calculating image no 57 out of160
# Calculating image no 58 out of160
# Calculating image no 59 out of160
# Calculating image no 60 out of160
# Calculating image no 61 out of160
# Calculating image no 62 out of160
# Calculating image no 63 out of160
# Calculating image no 64 out of160
# Calculating image no 65 out of160
# Calculating image no 66 out of160
# Calculating image no 67 out of160
# Calculating image no 68 out of160
# Calculating image no 69 out of160
# Calculating image no 70 out of160
# Calculating image no 71 out of160
# Calculating image no 72 out of160
# Calculating image no 73 out of160
# Calculating image no 74 out of160
# Calculating image no 75 out of160
# Calculating image no 76 out of160
# Calculating image no 77 out of160
# Calculating image no 78 out of160
# Calculating image no 79 out of160
# Calculating image no 80 out of160
# Calculating image no 81 out of160
# Calculating image no 82 out of160
# Calculating image no 83 out of160
# Calculating image no 84 out of160
# Calculating image no 85 out of160
# Calculating image no 86 out of160
# Calculating image no 87 out of160
# Calculating image no 88 out of160
# Calculating image no 89 out of160
# Calculating image no 90 out of160
# Calculating image no 91 out of160
# Calculating image no 92 out of160
# Calculating image no 93 out of160
# Calculating image no 94 out of160
# Calculating image no 95 out of160
# Calculating image no 96 out of160
# Calculating image no 97 out of160
# Calculating image no 98 out of160
# Calculating image no 99 out of160
# Calculating image no 100 out of160
# Calculating image no 101 out of160
# Calculating image no 102 out of160
# Calculating image no 103 out of160
# Calculating image no 104 out of160
# Calculating image no 105 out of160
# Calculating image no 106 out of160
# Calculating image no 107 out of160
# Calculating image no 108 out of160
# Calculating image no 109 out of160
# Calculating image no 110 out of160
# Calculating image no 111 out of160
# Calculating image no 112 out of160
# Calculating image no 113 out of160
# Calculating image no 114 out of160
# Calculating image no 115 out of160
# Calculating image no 116 out of160
# Calculating image no 117 out of160
# Calculating image no 118 out of160
# Calculating image no 119 out of160
# Calculating image no 120 out of160
# Calculating image no 121 out of160
# Calculating image no 122 out of160
# Calculating image no 123 out of160
# Calculating image no 124 out of160
# Calculating image no 125 out of160
# Calculating image no 126 out of160
# Calculating image no 127 out of160
# Calculating image no 128 out of160
# Calculating image no 129 out of160
# Calculating image no 130 out of160
# Calculating image no 131 out of160
# Calculating image no 132 out of160
# Calculating image no 133 out of160
# Calculating image no 134 out of160
# Calculating image no 135 out of160
# Calculating image no 136 out of160
# Calculating image no 137 out of160
# Calculating image no 138 out of160
# Calculating image no 139 out of160
# Calculating image no 140 out of160
# Calculating image no 141 out of160
# Calculating image no 142 out of160
# Calculating image no 143 out of160
# Calculating image no 144 out of160
# Calculating image no 145 out of160
# Calculating image no 146 out of160
# Calculating image no 147 out of160
# Calculating image no 148 out of160
# Calculating image no 149 out of160
# Calculating image no 150 out of160
# Calculating image no 151 out of160
# Calculating image no 152 out of160
# Calculating image no 153 out of160
# Calculating image no 154 out of160
# Calculating image no 155 out of160
# Calculating image no 156 out of160
# Calculating image no 157 out of160
# Calculating image no 158 out of160
# Calculating image no 159 out of160
# Calculating image no 160 out of160

# %% [markdown]
# ## Make a dataframe of the results

# %%
df=pd.DataFrame(results)
df2=deepcopy(df)
df2['Blocked or not']='None'
df2.loc[df2['exp'].str.contains('blocked'), 'Blocked or not'] = 'Blocked'
df2.loc[df2['exp'].str.contains('unblocked'), 'Blocked or not'] = 'Unblocked'

df2['Drug']='None'


df2.loc[df2['filename'].str.contains('gm6001_1to250'), 'Drug'] = 'GM6001'
df2.loc[df2['filename'].str.contains('gm6001_1to100'), 'Drug'] = 'GM6001'
df2.loc[df2['filename'].str.contains('dmso_1to250'), 'Drug'] = 'DMSO'
df2.loc[df2['filename'].str.contains('dmso_1to100'), 'Drug'] = 'DMSO'

df2['Treatment']='None'


df2.loc[df2['filename'].str.contains('gm6001_1to250'), 'Treatment'] = 'GM6001 1:250'
df2.loc[df2['filename'].str.contains('gm6001_1to100'), 'Treatment'] = 'GM6001 1:100'
df2.loc[df2['filename'].str.contains('dmso_1to250'), 'Treatment'] = 'DMSO 1:250'
df2.loc[df2['filename'].str.contains('dmso_1to100'), 'Treatment'] = 'DMSO 1:100'

# %%
var="bg sub int under mask"


from matplotlib import ticker
sns.set(font_scale=2.5)
sns.set_style("ticks")
sns.set_palette("Set2")

fig=plt.figure(figsize=(10,5))
df2plot=df2[df2["Blocked or not"]=="Blocked"]
fig.add_subplot(121)
sns.barplot(data=df2plot,x="Drug",y=var)
sns.swarmplot(data=df2plot,x="Drug",y=var,color="black")
scale_x=100
ticks_y=ticker.FuncFormatter(lambda x, pos: '{0:g}' .format(x/scale_x))
g=plt.gca()
g.yaxis.set_major_formatter(ticks_y)
plt.xticks(rotation=90)


plt.ylabel('Mean fluorescence intensity [AU]')
plt.xlabel('')

df2plot=df2[df2["Blocked or not"]=="Unblocked"]
fig.add_subplot(122)
sns.barplot(data=df2plot,x="Drug",y=var)
sns.swarmplot(data=df2plot,x="Drug",y=var,color="black")
scale_x=100
ticks_y=ticker.FuncFormatter(lambda x, pos: '{0:g}' .format(x/scale_x))
g=plt.gca()
g.yaxis.set_major_formatter(ticks_y)
plt.xticks(rotation=90)
#plt.ylabel('Mean fluorescence intensity [AU]')
plt.xlabel('')
# Out:
# Text(0.5, 0, '')

# %%
from matplotlib import ticker
sns.set(font_scale=2.5)
sns.set_style("ticks")
sns.set_palette("Set2")


dfblocked=df2[df2["Blocked or not"]=="Blocked"]
dfblocked=dfblocked.reset_index()
dfunblocked=df2[df2["Blocked or not"]=="Unblocked"]
dfunblocked=dfunblocked.reset_index()


plt.figure(figsize=(10,10))
sns.boxplot(x="Drug",y=var,hue="Blocked or not",data=df2)

sscale_x=100
ticks_y=ticker.FuncFormatter(lambda x, pos: '{0:g}' .format(x/scale_x))
g=plt.gca()
g.yaxis.set_major_formatter(ticks_y)
plt.legend(loc='upper left')
plt.ylabel('Mean fluorescence intensity [AU]')
# Out:
# Text(0, 0.5, 'Mean fluorescence intensity [AU]')

# %%
unblocked_dmso=dfunblocked[dfunblocked["Drug"]=="DMSO"][var].dropna()
unblocked_gm6=dfunblocked[dfunblocked["Drug"]=="GM6001"][var].dropna()

[stat, pval]=stats.ttest_ind(unblocked_dmso,unblocked_gm6)

pval
# Out:
# 0.034283198933021564

# %%
blocked_dmso=dfblocked[dfblocked["Drug"]=="DMSO"][var].dropna()
blocked_gm6=dfblocked[dfblocked["Drug"]=="GM6001"][var].dropna()

[stat, pval]=stats.ttest_ind(blocked_dmso,blocked_gm6)

pval

# %%
dfblocked=df2[df2["Blocked or not"]=="Blocked"]
dfblocked=dfblocked.reset_index()
with ND2Reader(dfblocked["filename"][1]) as images:
    ecm_image=images[0]
    #convert to numpy array - a format easier to manipunuclei with code
    ecm_imag_blockede=ecm_image.astype(np.int16)
dfunblocked=df2[df2["Blocked or not"]=="Unblocked"]
dfunblocked=dfunblocked.reset_index()
with ND2Reader(dfunblocked["filename"][1]) as images:
    ecm_image=images[0]
    #convert to numpy array - a format easier to manipunuclei with code
    ecm_imag_unblockede=ecm_image.astype(np.int16)

# %%
fig=plt.figure(figsize=(10,10))
fig.add_subplot(121)
plt.imshow(ecm_imag_blockede,vmin=np.min(ecm_imag_blockede),vmax=np.max(ecm_imag_unblockede))
plt.title('Blocked')
plt.grid(visible=False)
plt.xticks(visible=False)
plt.yticks(visible=False)
fig.add_subplot(122)
plt.imshow(ecm_imag_unblockede,vmin=np.min(ecm_imag_blockede),vmax=np.max(ecm_imag_unblockede))
plt.title('No blocking')
plt.grid(visible=False)
plt.xticks(visible=False)
plt.yticks(visible=False)
# Out:
# (array([-100.,    0.,  100.,  200.,  300.,  400.,  500.,  600.]),
#  <a list of 8 Text yticklabel objects>)

# %% [markdown]
# ## Make dataframe with means for individual experiments

# %%
var="bg sub int under mask"
means={"expname":[],"Condition":[],"intensity":[]}
df2read=df2
for exp in df2read["coverslip"].unique():
    dfcalc=df2read[df2read["coverslip"]==exp]
    dfcalc=dfcalc.reset_index()
    for condition in dfcalc["Blocked or not"].unique():
        dfcalc_cond=dfcalc[dfcalc["Blocked or not"]==condition]
        means["expname"].append(exp)
        means["Condition"].append(condition)
        means["intensity"].append(dfcalc_cond[var].mean())
dfmeans=pd.DataFrame(means)

# %% [markdown]
# ## Multiple ttests with Bonferroni correction (compare each group to no blocking condition)

# %%
from scipy import stats
negctrl=dfmeans[dfmeans["Condition"]=="Unblocked TNR647"]["intensity"].values
for item in ["Background - Autofluorescence","Background - Atto647","Block+0, TNR647","Block+12, TNR647"]:
    vals=dfmeans[dfmeans["Condition"]==item]["intensity"].values
    [stat, pval]=stats.ttest_ind(negctrl,vals)
    print('condition: '+item+' pval: '+str(pval*4))
# Out:
# condition: Background - Autofluorescence pval: nan
# condition: Background - Atto647 pval: nan
# condition: Block+0, TNR647 pval: nan
# condition: Block+12, TNR647 pval: nan

# %%
var="intensity"
bgauto=dfmeans[dfmeans["Condition"]=="Background - Autofluorescence"][var].dropna().values
bgatto=dfmeans[dfmeans["Condition"]=="Background - Atto647"][var].dropna().values
bgblockplus0=dfmeans[dfmeans["Condition"]=="Block+0, TNR647"][var].dropna().values
bgblockplus12=dfmeans[dfmeans["Condition"]=="Block+12, TNR647"][var].dropna().values
negctrl=dfmeans[dfmeans["Condition"]=="Unblocked TNR647"]["intensity"].dropna().values

stats.f_oneway(bgauto, bgatto, bgblockplus0,bgblockplus12,negctrl)
# Out:
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:2945: RuntimeWarning: Mean of empty slice.
#   offset = alldata.mean()
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:2948: RuntimeWarning: invalid value encountered in double_scalars
#   sstot = _sum_of_squares(alldata) - (_square_of_sums(alldata) / bign)
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:2951: RuntimeWarning: invalid value encountered in double_scalars
#   ssbn += _square_of_sums(a - offset) / len(a)
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:2955: RuntimeWarning: invalid value encountered in double_scalars
#   ssbn -= _square_of_sums(alldata) / bign
# F_onewayResult(statistic=nan, pvalue=nan)

# %%
import ipywidgets as widgets
from ipywidgets import interact
import scipy.stats as stats
import statsmodels.formula.api as smf
import statsmodels.stats.multicomp as multi
from statsmodels.stats.libqsturng import psturng

x = dfmeans["Condition"]
y = dfmeans[var]
# DataFrame.
mcDate = multi.MultiComparison(y,x)
Results = mcDate.tukeyhsd()
df = pd.DataFrame(data=Results._results_table.data[1:], columns=Results._results_table.data[0])
res=Results
pvals=psturng(np.abs(res.meandiffs / res.std_pairs),len(res.groupsunique), res.df_total)
df["pvals"]=pvals

df
# Out:
#                           group1                         group2  meandiff  \
# 0           Background - Atto647  Background - Autofluorescence   -0.1396
# 1           Background - Atto647                Block+0, TNR647    5.6641
# 2           Background - Atto647               Block+12, TNR647   -0.5246
# 3           Background - Atto647               Unblocked TNR647  269.9668
# 4  Background - Autofluorescence                Block+0, TNR647    5.8037
# 5  Background - Autofluorescence               Block+12, TNR647   -0.3850
# 6  Background - Autofluorescence               Unblocked TNR647  270.1064
# 7                Block+0, TNR647               Block+12, TNR647   -6.1887
# 8                Block+0, TNR647               Unblocked TNR647  264.3027
# 9               Block+12, TNR647               Unblocked TNR647  270.4914
#
#       lower     upper  reject  pvals
# 0  -51.1559   50.8767   False  0.900
# 1  -45.3522   56.6804   False  0.900
# 2  -51.5409   50.4917   False  0.900
# 3  218.9505  320.9831    True  0.001
# 4  -45.2126   56.8200   False  0.900
# 5  -51.4013   50.6313   False  0.900
# 6  219.0901  321.1227    True  0.001
# 7  -57.2050   44.8276   False  0.900
# 8  213.2864  315.3190    True  0.001
# 9  219.4751  321.5077    True  0.001

# %% [markdown]
# ## nice plot

# %%
dfmeans
# Out:
#   expname  Condition   intensity
# 0     cs1    Blocked   43.531080
# 1     cs1  Unblocked  327.906076
# 2     cs2    Blocked   38.997631
# 3     cs2  Unblocked  286.276365

# %%
sns.set(font_scale=2.5)
sns.set_style("ticks")
sns.set_palette("Set2")
from matplotlib import ticker

fig=plt.figure(figsize=(5,6))

df2plot=dfmeans
var='intensity'
order=['Background - Autofluorescence',
       'Background - Atto647',
      'Block+0, TNR647',
       'Block+12, TNR647',
       'Unblocked TNR647'
       ]

paletteswarm ={"Background - Autofluorescence":"#2F67F8",
               "Unblocked TNR647":"#333333",
               "Background - Atto647":"#2F67F8",
               "Block+0, TNR647":"#2F67F8",
               "Block+12, TNR647":"#2F67F8"}
palette ={"Background - Autofluorescence":"#abc2fc",
          "Unblocked TNR647":"#adadad",
               "Background - Atto647":"#abc2fc",
               "Block+0, TNR647":"#abc2fc",
               "Block+12, TNR647":"#abc2fc"}


g=sns.barplot(data=df2plot,y=var,x="Condition"
            ,order=order,palette=palette,ci=None)

g=sns.swarmplot(data=df2plot,y=var,x="Condition"
            ,order=order,palette=paletteswarm,size=8)

def change_width(ax, new_value) :
    for patch in ax.patches :
        current_width = patch.get_width()
        diff = current_width - new_value
        
        # we change the bar width
        patch.set_width(new_value)

        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)
        
change_width(g, .8)

plt.errorbar(x=np.arange(0,len(order)),
             y=[df2plot[df2plot["Condition"]==condtype][var].mean() for condtype in order],
             yerr=[df2plot[df2plot["Condition"]==condtype][var].sem() for condtype in order],
             xerr=None,ecolor='black',fmt='none',capsize=10,linewidth=3,
             capthick=3,zorder=10,
            alpha=1)

plt.axhline(0, color='#333333',alpha=1,linewidth=4)

g.xaxis.set_tick_params(width=4)
g.yaxis.set_tick_params(width=4)

plt.rcParams['font.sans-serif'] = 'Helvetica'


g.set_ylabel('')
g.set_xlabel('',color='#333333',alpha=.7)


g.grid(False)


for axis in ['top','bottom','left','right']:
  g.spines[axis].set_linewidth(4)
  g.spines[axis].set_color('#333333')
  g.spines[axis].set_alpha(1)

plt.xticks(g.get_xticks(),['Autofluorescence',
                           '@mouse\nAtto647N',
      'Block+0',
       'Block+12',
       'No Blocking'
       ],
           rotation=70,size=24)
offsets={"left":10,"bottom":0}
trims={"left":True,"bottom":False,"right":False}
sns.despine(ax=g,right=True,top=True,bottom=True,trim=trims,offset=offsets)
#plt.yticks([0,2,4,6,8,10,12],fontsize=22,color='#333333')


scale_x=100
ticks_y=ticker.FuncFormatter(lambda x, pos: '{0:g}' .format(x/scale_x))
g=plt.gca()
g.yaxis.set_major_formatter(ticks_y)

#plt.ylim([0,12.5])
x1, x2 = 0,4
y= 330
h=5
col='black'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=3.5, c=col)
plt.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col,size=24, weight='bold')

x1, x2 = 1,4
y= 330
h=5
col='black'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=3.5, c=col)

x1, x2 = 2,4
y= 330
h=5
col='black'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=3.5, c=col)

x1, x2 = 3,4
y= 330
h=5
col='black'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=3.5, c=col)


diri="/Volumes/Macintosh HD/Users/taldankovich/Downloads/figures/"

fig.savefig(diri+'supp1_fixedctrl.svg', bbox_inches='tight', format='svg')
