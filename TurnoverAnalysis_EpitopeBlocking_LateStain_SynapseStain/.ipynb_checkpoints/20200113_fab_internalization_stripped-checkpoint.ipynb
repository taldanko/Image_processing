# %% [markdown]
# ## Import modules and functions

# %%
import numpy as np
import os
from nd2reader import ND2Reader
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib_scalebar.scalebar import ScaleBar
import scipy.ndimage as ndi
from skimage.filters import rank 
from scipy.signal import butter, lfilter
import scipy.misc as misc
from skimage import exposure
from PIL import Image
import colorcet as cc
from scipy.misc import toimage
import matplotlib.colors as clr
import pandas as pd
import seaborn as sns
from scipy import stats
import cv2
from pyspark import SparkContext, SparkConf
import skimage
from pathlib import Path

def mean2(x):
    y = np.sum(x) / np.size(x);
    return y
def corr2(a,b):
    a = a - mean2(a)
    b = b - mean2(b)

    r = (a*b).sum() / np.sqrt((a*a).sum() * (b*b).sum());
    return r
from copy import deepcopy
from skimage.filters import threshold_otsu,threshold_li
import glob
from IPython.display import clear_output
import scipy.io as spio

# %% [markdown]
# ## Define directory of images

# %%
expdir='/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/' #master folder

# %% [markdown]
# ## Make dictionary for storing results

# %%
results = {"filename":[],"exp":[],"coverslip":[],
           "Manual mask from matlab GUI":[],"bg sub int under mask":[]}
path = os.path.dirname(expdir)  
outputFolder = os.path.dirname(expdir + "/new/")
filelist = []
for root, _, filenames in os.walk(path):
     for filename in filenames:
         filelist.append(os.path.join(root, filename))      
for i in range(0,len(filelist)):
    #if "analyse" in str(filelist[i]):
        if ("ignore" in str(filelist[i]))==False:
            if filelist[i].endswith(".nd2"): 
                results["filename"].append(filelist[i])
                results["coverslip"].append(filelist[i].split('/')[-2])
                results["exp"].append(filelist[i].split('/')[-4])

# %% [markdown]
# ## Read manual masks from Matlab GUI

# %%
## matlab files
for im in range(0,len(results["filename"])): 
    file=results["filename"][im][:-4]+'_dendritesmask.mat'
    from pathlib import Path
    my_file = Path(file)
    if my_file.exists():
        print(file)
        mat = spio.loadmat(file, squeeze_me=True)
        mask=mat['totMask']>0.99
        results["Manual mask from matlab GUI"].append(mask)
    else:
        results["Manual mask from matlab GUI"].append(np.nan)
clear_output()        
print("Done!")
# Out:
# Done!

# %% [markdown]
# ## Batch analysis of images - mean intensity

# %%
print('Total number of images: ' + str(len(results['filename'])))

for i in range(0,len(results["filename"])): 
    flag=False
    print('Calculating image no ' + str(i+1) + ' out of' + str(len(results["filename"])))
    #read the image
    with ND2Reader(results["filename"][i]) as images:
        ecm_image=images[0]
    #convert to numpy array - a format easier to manipunuclei with code
    ecm_image=ecm_image.astype(np.int16)
    #read masks 
    matlab_mask=results["Manual mask from matlab GUI"][i]
    if type(matlab_mask)==np.ndarray:
        flag=True
    #image after background subtraction
    #for ecm image
    if flag==True:
        ecm_matlabmasked_bgreduced=deepcopy(ecm_image)
        bg_matlabmask=np.mean(ndi.median_filter(ecm_image[matlab_mask],size=5))+0*np.std(ndi.median_filter(ecm_image[matlab_mask],size=5))
        ecm_matlabmasked_bgreduced=np.subtract(ecm_matlabmasked_bgreduced,bg_matlabmask)
        ecm_matlabmasked_bgreduced[ecm_matlabmasked_bgreduced<0]=0
        ecm_matlabmasked_bgreduced[~matlab_mask]=0
        
    if flag==True:
        results["bg sub int under mask"].append(ecm_matlabmasked_bgreduced[matlab_mask].mean())
    else:
        results["bg sub int under mask"].append(np.nan)
# Out:
# Total number of images: 147
# Calculating image no 1 out of147
# Calculating image no 2 out of147
# Calculating image no 3 out of147
# Calculating image no 4 out of147
# Calculating image no 5 out of147
# Calculating image no 6 out of147
# Calculating image no 7 out of147
# Calculating image no 8 out of147
# Calculating image no 9 out of147
# Calculating image no 10 out of147
# Calculating image no 11 out of147
# Calculating image no 12 out of147
# Calculating image no 13 out of147
# Calculating image no 14 out of147
# Calculating image no 15 out of147
# Calculating image no 16 out of147
# Calculating image no 17 out of147
# Calculating image no 18 out of147
# Calculating image no 19 out of147
# Calculating image no 20 out of147
# Calculating image no 21 out of147
# Calculating image no 22 out of147
# Calculating image no 23 out of147
# Calculating image no 24 out of147
# Calculating image no 25 out of147
# Calculating image no 26 out of147
# Calculating image no 27 out of147
# Calculating image no 28 out of147
# Calculating image no 29 out of147
# Calculating image no 30 out of147
# Calculating image no 31 out of147
# Calculating image no 32 out of147
# Calculating image no 33 out of147
# Calculating image no 34 out of147
# Calculating image no 35 out of147
# Calculating image no 36 out of147
# Calculating image no 37 out of147
# Calculating image no 38 out of147
# Calculating image no 39 out of147
# Calculating image no 40 out of147
# Calculating image no 41 out of147
# Calculating image no 42 out of147
# Calculating image no 43 out of147
# Calculating image no 44 out of147
# Calculating image no 45 out of147
# Calculating image no 46 out of147
# Calculating image no 47 out of147
# Calculating image no 48 out of147
# Calculating image no 49 out of147
# Calculating image no 50 out of147
# Calculating image no 51 out of147
# Calculating image no 52 out of147
# Calculating image no 53 out of147
# Calculating image no 54 out of147
# Calculating image no 55 out of147
# Calculating image no 56 out of147
# Calculating image no 57 out of147
# Calculating image no 58 out of147
# Calculating image no 59 out of147
# Calculating image no 60 out of147
# Calculating image no 61 out of147
# Calculating image no 62 out of147
# Calculating image no 63 out of147
# Calculating image no 64 out of147
# Calculating image no 65 out of147
# Calculating image no 66 out of147
# Calculating image no 67 out of147
# Calculating image no 68 out of147
# Calculating image no 69 out of147
# Calculating image no 70 out of147
# Calculating image no 71 out of147
# Calculating image no 72 out of147
# Calculating image no 73 out of147
# Calculating image no 74 out of147
# Calculating image no 75 out of147
# Calculating image no 76 out of147
# Calculating image no 77 out of147
# Calculating image no 78 out of147
# Calculating image no 79 out of147
# Calculating image no 80 out of147
# Calculating image no 81 out of147
# Calculating image no 82 out of147
# Calculating image no 83 out of147
# Calculating image no 84 out of147
# Calculating image no 85 out of147
# Calculating image no 86 out of147
# Calculating image no 87 out of147
# Calculating image no 88 out of147
# Calculating image no 89 out of147
# Calculating image no 90 out of147
# Calculating image no 91 out of147
# Calculating image no 92 out of147
# Calculating image no 93 out of147
# Calculating image no 94 out of147
# Calculating image no 95 out of147
# Calculating image no 96 out of147
# Calculating image no 97 out of147
# Calculating image no 98 out of147
# Calculating image no 99 out of147
# Calculating image no 100 out of147
# Calculating image no 101 out of147
# Calculating image no 102 out of147
# Calculating image no 103 out of147
# Calculating image no 104 out of147
# Calculating image no 105 out of147
# Calculating image no 106 out of147
# Calculating image no 107 out of147
# Calculating image no 108 out of147
# Calculating image no 109 out of147
# Calculating image no 110 out of147
# Calculating image no 111 out of147
# Calculating image no 112 out of147
# Calculating image no 113 out of147
# Calculating image no 114 out of147
# Calculating image no 115 out of147
# Calculating image no 116 out of147
# Calculating image no 117 out of147
# Calculating image no 118 out of147
# Calculating image no 119 out of147
# Calculating image no 120 out of147
# Calculating image no 121 out of147
# Calculating image no 122 out of147
# Calculating image no 123 out of147
# Calculating image no 124 out of147
# Calculating image no 125 out of147
# Calculating image no 126 out of147
# Calculating image no 127 out of147
# Calculating image no 128 out of147
# Calculating image no 129 out of147
# Calculating image no 130 out of147
# Calculating image no 131 out of147
# Calculating image no 132 out of147
# Calculating image no 133 out of147
# Calculating image no 134 out of147
# Calculating image no 135 out of147
# Calculating image no 136 out of147
# Calculating image no 137 out of147
# Calculating image no 138 out of147
# Calculating image no 139 out of147
# Calculating image no 140 out of147
# Calculating image no 141 out of147
# Calculating image no 142 out of147
# Calculating image no 143 out of147
# Calculating image no 144 out of147
# Calculating image no 145 out of147
# Calculating image no 146 out of147
# Calculating image no 147 out of147

# %% [markdown]
# ## Make a dataframe of the results

# %%
df["filename"].tolist()
# Out:
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191224_recycling2/day0/20191223_recycling_d0_001.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191224_recycling2/day0/20191223_recycling_d0_002.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191224_recycling2/
nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day1/20191227_d1_001.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day1/20191227_d1_002.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day1/20191227_d1_003.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day1/20191227_d1_004.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day1/20191227_d1_005.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day1/20191227_d1_006.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day1/20191227_d1_007.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day1/20191227_d1_008.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day1/20191227_d1_009.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day1/20191227_d1_010.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day1/20191227_d1_011.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day1/20191227_d1_012.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day1/20191227_d1_013.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day1/20191227_d1_014.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day1/20191227_d1_015.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day3/20191227_d3_001.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day3/20191227_d3_002.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day3/20191227_d3_003.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day3/20191227_d3_004.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day3/20191227_d3_005.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day3/20191227_d3_006.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day3/20191227_d3_007.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day3/20191227_d3_008.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day3/20191227_d3_009.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day3/20191227_d3_010.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day3/20191227_d3_011.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day3/20191227_d3_012.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day3/20191227_d3_013.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day3/20191227_d3_014.nd2',
#  '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Fab_resurfacing_Nikon/20191227_recycling4/day3/20191227_d3_015.nd2']

# %%
df=pd.DataFrame(results)
df2=deepcopy(df)
df2['Day']='None'
df2.loc[df2['filename'].str.contains('day0'), 'Day'] = '0'
df2.loc[df2['filename'].str.contains('day1'), 'Day'] = '1'
df2.loc[df2['filename'].str.contains('day2'), 'Day'] = '2'
df2.loc[df2['filename'].str.contains('day3'), 'Day'] = '3'

df2['Exp']='None'
df2.loc[df2['filename'].str.contains('recycling2'), 'Exp'] = '2'
df2.loc[df2['filename'].str.contains('recycling3'), 'Exp'] = '3'
df2.loc[df2['filename'].str.contains('recycling4'), 'Exp'] = '4'

# %%
df2["exp"].unique()
# Out:
# array(['2', '3', '4'], dtype=object)

# %%
df2plot=df2[df2["Exp"]!="2"]
var="bg sub int under mask norm2med"
sns.barplot(x="Day",y=var,data=df2plot)
sns.swarmplot(x="Day",y=var,data=df2plot)

# %%
expnam=[]
medi=[]
for exp in df2["Exp"].unique():
    dfexp=df2[df2["Exp"]==exp]
    med=dfexp["bg sub int under mask"].median()
    expnam.append(exp)
    medi.append(med)
df2["bg sub int under mask norm2med"]=np.nan
for i in range(0,len(df2)):
    for j in range(0,len(expnam)):
        if df2["Exp"][i]==expnam[j]:
            df2["bg sub int under mask norm2med"][i]=df2["bg sub int under mask"][i]/medi[j]
# Out:
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':

# %%
sns.set(font_scale=2.5)
sns.set_style("ticks")
sns.set_palette("Set2")
from matplotlib import ticker

fig=plt.figure(figsize=(5,6))
df2plot=df2[df2["Blocked or not"]!="Unblocked"]
var="bg sub int under mask norm2med"
#var="ecm mean int norm2med"

order=['0',
       '1','3'
       ]

'''paletteswarm ={"Background - Autofluorescence":"#2F67F8",
               "Unblocked TNR647":"#333333",
               "Background - Atto647":"#2F67F8",
               "Block+0, TNR647":"#2F67F8",
               "Block+12, TNR647":"#2F67F8"}
palette ={"Background - Autofluorescence":"#abc2fc",
          "Unblocked TNR647":"#adadad",
               "Background - Atto647":"#abc2fc",
               "Block+0, TNR647":"#abc2fc",
               "Block+12, TNR647":"#abc2fc"}'''


g=sns.barplot(data=df2plot,y=var,x="Condition",
            order=order,color="#abc2fc",ci=None)

g=sns.swarmplot(data=df2plot,y=var,x="Condition",
            order=order,color="#2F67F8",size=8)

def change_width(ax, new_value) :
    for patch in ax.patches :
        current_width = patch.get_width()
        diff = current_width - new_value
        
        # we change the bar width
        patch.set_width(new_value)

        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)
        
change_width(g, .8)

plt.errorbar(x=np.arange(0,len(order)),
             y=[df2plot[df2plot["Condition"]==condtype][var].mean() for condtype in order],
             yerr=[df2plot[df2plot["Condition"]==condtype][var].sem() for condtype in order],
             xerr=None,ecolor='black',fmt='none',capsize=10,linewidth=3,
             capthick=3,zorder=10,
            alpha=1)

plt.axhline(0, color='#333333',alpha=1,linewidth=4)

g.xaxis.set_tick_params(width=4)
g.yaxis.set_tick_params(width=4)

plt.rcParams['font.sans-serif'] = 'Helvetica'


g.set_ylabel('')
g.set_xlabel('',color='#333333',alpha=.7)


g.grid(False)


for axis in ['top','bottom','left','right']:
  g.spines[axis].set_linewidth(4)
  g.spines[axis].set_color('#333333')
  g.spines[axis].set_alpha(1)

plt.xticks(g.get_xticks(),order,
           rotation=75,size=24)
offsets={"left":10,"bottom":0}
trims={"left":True,"bottom":False,"right":False}
sns.despine(ax=g,right=True,top=True,bottom=True,trim=trims,offset=offsets)
#plt.yticks([0,2,4,6,8,10,12],fontsize=22,color='#333333')


scale_x=1
ticks_y=ticker.FuncFormatter(lambda x, pos: '{0:g}' .format(x/scale_x))
g=plt.gca()
g.yaxis.set_major_formatter(ticks_y)

#plt.ylim([0,12.5])
x1, x2 = 0,1
y= 3.2
h=0.1
col='black'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=3.5, c=col)
plt.text((x1+x2)*.5, y+h, "ns", ha='center', va='bottom', color=col,size=24, weight='bold')

x1, x2 = 2,0
y= 4
h=0.1
col='black'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=3.5, c=col)
plt.text((x1+x2)*.5, y+h, "ns", ha='center', va='bottom', color=col,size=24, weight='bold')

x1, x2 = 3,0
y= 4.8
h=0.1
col='black'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=3.5, c=col)
plt.text((x1+x2)*.5, y+h, "ns", ha='center', va='bottom', color=col,size=24, weight='bold')


diri="/Volumes/Macintosh HD/Users/taldankovich/Downloads/figures/"

fig.savefig(diri+'supp_ctrl_notpreexistingepitopes_.svg', bbox_inches='tight', format='svg')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Blocked or not'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-f3f324e7cbf8> in <module>
#       5
#       6 fig=plt.figure(figsize=(5,6))
# ----> 7 df2plot=df2[df2["Blocked or not"]!="Unblocked"]
#       8 var="bg sub int under mask norm2med"
#       9 #var="ecm mean int norm2med"
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
# -> 2658                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2659         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2660         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Blocked or not'

# %%
sns.set(font_scale=2.5)
sns.set_style("ticks")
sns.set_palette("Set2")
from matplotlib import ticker

fig=plt.figure(figsize=(2,6))
df2plot=df2[df2["Blocked or not"]!="Unblocked"]
var="bg sub int under mask norm2med"
#var="ecm mean int norm2med"

order=['DMSO',
       'GM6001'
       ]

'''paletteswarm ={"Background - Autofluorescence":"#2F67F8",
               "Unblocked TNR647":"#333333",
               "Background - Atto647":"#2F67F8",
               "Block+0, TNR647":"#2F67F8",
               "Block+12, TNR647":"#2F67F8"}
palette ={"Background - Autofluorescence":"#abc2fc",
          "Unblocked TNR647":"#adadad",
               "Background - Atto647":"#abc2fc",
               "Block+0, TNR647":"#abc2fc",
               "Block+12, TNR647":"#abc2fc"}'''


g=sns.barplot(data=df2plot,y=var,x="Condition",
            order=order,color="#abc2fc",ci=None)

g=sns.swarmplot(data=df2plot,y=var,x="Condition",
            order=order,color="#2F67F8",size=8)

def change_width(ax, new_value) :
    for patch in ax.patches :
        current_width = patch.get_width()
        diff = current_width - new_value
        
        # we change the bar width
        patch.set_width(new_value)

        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)
        
change_width(g, .8)

plt.errorbar(x=np.arange(0,len(order)),
             y=[df2plot[df2plot["Condition"]==condtype][var].mean() for condtype in order],
             yerr=[df2plot[df2plot["Condition"]==condtype][var].sem() for condtype in order],
             xerr=None,ecolor='black',fmt='none',capsize=10,linewidth=3,
             capthick=3,zorder=10,
            alpha=1)

plt.axhline(0, color='#333333',alpha=1,linewidth=4)

g.xaxis.set_tick_params(width=4)
g.yaxis.set_tick_params(width=4)

plt.rcParams['font.sans-serif'] = 'Helvetica'


g.set_ylabel('')
g.set_xlabel('',color='#333333',alpha=.7)


g.grid(False)


for axis in ['top','bottom','left','right']:
  g.spines[axis].set_linewidth(4)
  g.spines[axis].set_color('#333333')
  g.spines[axis].set_alpha(1)

plt.xticks(g.get_xticks(),order,
           rotation=75,size=24)
offsets={"left":10,"bottom":0}
trims={"left":True,"bottom":False,"right":False}
sns.despine(ax=g,right=True,top=True,bottom=True,trim=trims,offset=offsets)
#plt.yticks([0,2,4,6,8,10,12],fontsize=22,color='#333333')


scale_x=1
ticks_y=ticker.FuncFormatter(lambda x, pos: '{0:g}' .format(x/scale_x))
g=plt.gca()
g.yaxis.set_major_formatter(ticks_y)

#plt.ylim([0,12.5])
x1, x2 = 0,1
y= 1.65
h=0.05
col='black'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=3.5, c=col)
plt.text((x1+x2)*.5, y+h, "ns", ha='center', va='bottom', color=col,size=24, weight='bold')



diri="/Volumes/Macintosh HD/Users/taldankovich/Downloads/figures/"

fig.savefig(diri+'supp_ctrl_notpreexistingepitopes_gm6001.svg', bbox_inches='tight', format='svg')

# %% [markdown]
# ## find representative pics

# %%
num
# Out:
# 75

# %%
df_pic=df2[df2["Blocked or not"]!="Unblocked"]
df_dmso=df_pic[df_pic["Condition"]=="DMSO"]
df_gm6001=df_pic[df_pic["Condition"]=="GM6001"]
df_atto=df_pic[df_pic["Condition"]=='Atto647@mouse']
df_pfa=df_pic[df_pic["Condition"]=='PFA fixed']
df_meth=df_pic[df_pic["Condition"]=='Methanol fixed']
df_chabc=df_pic[df_pic["Condition"]=='chABC']
df_ubcontrol=df_pic[df_pic["Condition"]=="No Blocking"]

df_2show=df_meth
df_2show=df_2show.reset_index()

minval=50
maxval=5000
num=1
leng=len(df_2show)
fig=plt.figure(figsize=(20,150))
for i in range(0,len(df_2show)):
    #print(i)
    fig.add_subplot(leng,1,num)
    with ND2Reader(df_2show["filename"][i]) as images:
        ecm_image=images[0]
        plt.imshow(ecm_image,interpolation='none',cmap='hot',vmin=minval,vmax=maxval)
        plt.title(df_2show["filename"][i][-40:], size=14)
        plt.yticks(visible=False)
        plt.xticks(visible=False)
        plt.grid(visible=False)
        plt.axis(visible=False)
        #scalebar = ScaleBar(107.1, 'nm', dimension='si-length',box_alpha=0,location='lower right',length_fraction=0.2,
        #                       font_properties={'size':0,'weight':'bold'},color='white',border_pad=0.5) # 1 pixel = 0.2 meter
        #plt.gca().add_artist(scalebar)
        num+=1
