# %%
import numpy as np
import os
from nd2reader import ND2Reader
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib_scalebar.scalebar import ScaleBar
import scipy.ndimage as ndi
from skimage.filters import rank 
from scipy.signal import butter, lfilter
import scipy.misc as misc
from skimage import exposure
from PIL import Image
import colorcet as cc
from scipy.misc import toimage
import matplotlib.colors as clr
import pandas as pd
import seaborn as sns
from scipy import stats
import cv2
from pyspark import SparkContext, SparkConf
import skimage
from pathlib import Path

def mean2(x):
    y = np.sum(x) / np.size(x);
    return y
def corr2(a,b):
    a = a - mean2(a)
    b = b - mean2(b)

    r = (a*b).sum() / np.sqrt((a*a).sum() * (b*b).sum());
    return r
from copy import deepcopy
from skimage.filters import threshold_otsu,threshold_li
import glob
from IPython.display import clear_output
import scipy.io as spio
import pims
from skimage.measure import label, regionprops
from skimage.color import label2rgb
import scipy

# %%
expdir='/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Live Culture/20190307_posthocendosomes_confocal/20190307_endosomes_sameimagingparams/'
protein="TNR" #TNR,Agg,WFA,HABP

# %%
results = {"filename":[],
          "exp condition":[],
          "ecmchannelno":[],
          "endosomechannelno":[],
          "synapsechannelno":[]}
           
path = os.path.dirname(expdir)  
outputFolder = os.path.dirname(expdir + "/new/")
filelist = []
for root, _, filenames in os.walk(path):
     for filename in filenames:
         filelist.append(os.path.join(root, filename))      
for i in range(0,len(filelist)):
    if "_analyse" in str(filelist[i]):
        #if "DiO" in str(filelist[i]):
            #if ("Focus" in str(filelist[i]))==False:
                #if (protein in str(filelist[i]))==True:
                    if filelist[i].endswith(".tif"): 
                        if str(filelist[i][:-12]) not in str(results["filename"]):
                            results["filename"].append(filelist[i][:-12])
                            results["exp condition"].append(filelist[i][:-12].split('/')[-2])
                            channeldir="/".join(filelist[i][:-12].split("/")[:-2])
                            exec(open(channeldir+"/channels.txt").read())
                            results["ecmchannelno"].append(ecmchannelno)
                            results["endosomechannelno"].append(endosomechannelno)
                            results["synapsechannelno"].append(synapsechannelno)

# %% [markdown]
# ## Loading a random image

# %%
randomno=np.random.randint(1,len(results["filename"]))
ecm_channel_no=results["ecmchannelno"][randomno]
endosome_channel_no=results["endosomechannelno"][randomno]
synapse_channel_no=results["synapsechannelno"][randomno]

ecm_image_name=results["filename"][randomno]+"0_ch"+str(ecm_channel_no-1)+"_t0.tif"
endosome_image_name=results["filename"][randomno]+"0_ch"+str(endosome_channel_no-1)+"_t0.tif"
synapse_image_name=results["filename"][randomno]+"0_ch"+str(synapse_channel_no-1)+"_t0.tif"

print("Image name:",results["filename"][randomno].split('/')[-1])
print("Experimental condition:",results["exp condition"][randomno])
ecm_image=pims.open(ecm_image_name)[0]
endosome_image=pims.open(endosome_image_name)[0]
synapse_image=pims.open(synapse_image_name)[0]
   
figure=plt.figure(figsize=(15,15))
figure.add_subplot(221)
plt.imshow(ecm_image,interpolation='none',cmap='hot')
plt.title('ECM raw')
plt.grid(visible=False)
plt.xticks(visible=False)
plt.yticks(visible=False)
scalebar = ScaleBar(20, 'nm', dimension='si-length',box_alpha=0,location='lower right',length_fraction=0.2,
                       font_properties={'size':16,'weight':'bold'},color='white',border_pad=0.5) # 1 pixel = 0.2 meter
plt.gca().add_artist(scalebar)
figure.add_subplot(222)
plt.imshow(ecm_image,interpolation='none',cmap='hot',vmin=3*np.min(ecm_image),vmax=0.4*np.max(ecm_image))
plt.title('ECM scaled')
plt.grid(visible=False)
plt.xticks(visible=False)
plt.yticks(visible=False)
scalebar = ScaleBar(20, 'nm', dimension='si-length',box_alpha=0,location='lower right',length_fraction=0.2,
                       font_properties={'size':16,'weight':'bold'},color='white',border_pad=0.5) # 1 pixel = 0.2 meter
    
plt.gca().add_artist(scalebar)
figure.add_subplot(223)
plt.imshow(synapse_image,interpolation='none',cmap='hot')
plt.title('Synapses raw')
plt.grid(visible=False)
plt.xticks(visible=False)
plt.yticks(visible=False)
scalebar = ScaleBar(20, 'nm', dimension='si-length',box_alpha=0,location='lower right',length_fraction=0.2,
                       font_properties={'size':16,'weight':'bold'},color='white',border_pad=0.5) # 1 pixel = 0.2 meter
    
plt.gca().add_artist(scalebar)
figure.add_subplot(224)
plt.imshow(endosome_image,interpolation='none',cmap='hot')
plt.title('endosome raw')
plt.grid(visible=False)
plt.xticks(visible=False)
plt.yticks(visible=False)
scalebar = ScaleBar(20, 'nm', dimension='si-length',box_alpha=0,location='lower right',length_fraction=0.2,
                       font_properties={'size':16,'weight':'bold'},color='white',border_pad=0.5) # 1 pixel = 0.2 meter
    
plt.gca().add_artist(scalebar)
# Out:
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Image name: 20190307_LAMP647_Ctrl_Series4_z
# Experimental condition: 20190307_LAMP647_Ctrl_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)

# %% [markdown]
# ## Find spots

# %% [markdown]
# ### Random processed image

# %% [markdown]
# ### 2x2 binning

# %%
#backup
ecm_image_raw=deepcopy(ecm_image)
synapse_image_raw=deepcopy(synapse_image)
endosome_image_raw=deepcopy(endosome_image)

# %%
#2x2 binning --> new pixel size = 40nm
def rebin(arr, new_shape):
    shape = (new_shape[0], arr.shape[0] // new_shape[0],
             new_shape[1], arr.shape[1] // new_shape[1])
    return arr.reshape(shape).mean(-1).mean(1)
ecm_image=np.asarray(ecm_image_raw)
ecm_image=rebin(ecm_image,[512,512])
endosome_image=rebin(endosome_image_raw,[512,512])
synapse_image=rebin(synapse_image_raw,[512,512])

#bandpass
lowpass = ndi.gaussian_filter(ecm_image, 3)
ecm_image = ecm_image - lowpass
lowpass = ndi.gaussian_filter(endosome_image, 3)
endosome_image = endosome_image - lowpass
lowpass = ndi.gaussian_filter(synapse_image, 3)
synapse_image = synapse_image - lowpass

#binarize to find spots
ecm_image[ecm_image<1]=0
ecm_image[ecm_image>1]=1
endosome_image[endosome_image<8]=0
endosome_image[endosome_image>8]=1
synapse_image[synapse_image<18]=0
synapse_image[synapse_image>18]=1

#some morphological operations
#watershed attempt
'''from skimage.morphology import watershed
from skimage.feature import peak_local_max
distance = ndi.distance_transform_edt(ecm_image_high)
local_maxi = peak_local_max(distance, indices=False, 
                            footprint=np.ones((5, 5)), labels=ecm_image_high)
markers = ndi.label(local_maxi)[0]
labels = watershed(-distance, markers, mask=ecm_image_high)'''

ecm_image=ndi.binary_opening(ecm_image,iterations=2)
ecm_image=ndi.binary_closing(ecm_image,iterations=2)
endosome_image=ndi.binary_opening(endosome_image,iterations=2)
endosome_image=ndi.binary_closing(endosome_image,iterations=2)
synapse_image=ndi.binary_opening(synapse_image,iterations=2)
synapse_image=ndi.binary_closing(synapse_image,iterations=2)

figure=plt.figure(figsize=(15,15))
figure.add_subplot(231)
plt.imshow(ecm_image_raw,interpolation='none',cmap='hot')
plt.title('ECM raw')
plt.grid(visible=False)
plt.xticks(visible=False)
plt.yticks(visible=False)
scalebar = ScaleBar(20, 'nm', dimension='si-length',box_alpha=0,location='lower right',length_fraction=0.2,
                       font_properties={'size':16,'weight':'bold'},color='white',border_pad=0.5) # 1 pixel = 0.2 meter
plt.gca().add_artist(scalebar)

figure.add_subplot(232)
plt.imshow(ecm_image,interpolation='none',cmap='hot',vmin=3*np.min(ecm_image),vmax=0.4*np.max(ecm_image))
plt.title('ECM spots')
plt.grid(visible=False)
plt.xticks(visible=False)
plt.yticks(visible=False)
scalebar = ScaleBar(20, 'nm', dimension='si-length',box_alpha=0,location='lower right',length_fraction=0.2,
                       font_properties={'size':16,'weight':'bold'},color='white',border_pad=0.5) # 1 pixel = 0.2 meter
plt.gca().add_artist(scalebar)

figure=plt.figure(figsize=(15,15))
figure.add_subplot(231)
plt.imshow(endosome_image_raw,interpolation='none',cmap='hot')
plt.title('Endosome raw')
plt.grid(visible=False)
plt.xticks(visible=False)
plt.yticks(visible=False)
scalebar = ScaleBar(20, 'nm', dimension='si-length',box_alpha=0,location='lower right',length_fraction=0.2,
                       font_properties={'size':16,'weight':'bold'},color='white',border_pad=0.5) # 1 pixel = 0.2 meter
plt.gca().add_artist(scalebar)

figure.add_subplot(232)
plt.imshow(endosome_image,interpolation='none',cmap='hot',vmin=3*np.min(ecm_image),vmax=0.4*np.max(ecm_image))
plt.title('ECM spots')
plt.grid(visible=False)
plt.xticks(visible=False)
plt.yticks(visible=False)
scalebar = ScaleBar(40, 'nm', dimension='si-length',box_alpha=0,location='lower right',length_fraction=0.2,
                       font_properties={'size':16,'weight':'bold'},color='white',border_pad=0.5) # 1 pixel = 0.2 meter
plt.gca().add_artist(scalebar)

figure=plt.figure(figsize=(15,15))
figure.add_subplot(231)
plt.imshow(synapse_image_raw,interpolation='none',cmap='hot')
plt.title('Synapse raw')
plt.grid(visible=False)
plt.xticks(visible=False)
plt.yticks(visible=False)
scalebar = ScaleBar(40, 'nm', dimension='si-length',box_alpha=0,location='lower right',length_fraction=0.2,
                       font_properties={'size':16,'weight':'bold'},color='white',border_pad=0.5) # 1 pixel = 0.2 meter
plt.gca().add_artist(scalebar)

figure.add_subplot(232)
plt.imshow(synapse_image,interpolation='none',cmap='hot',vmin=3*np.min(ecm_image),vmax=0.4*np.max(ecm_image))
plt.title('Synapse spots')
plt.grid(visible=False)
plt.xticks(visible=False)
plt.yticks(visible=False)
scalebar = ScaleBar(40, 'nm', dimension='si-length',box_alpha=0,location='lower right',length_fraction=0.2,
                       font_properties={'size':16,'weight':'bold'},color='white',border_pad=0.5) # 1 pixel = 0.2 meter
plt.gca().add_artist(scalebar)

# %% [markdown]
# ## Batch analysis

# %%
print('number of ecm spots: ' + str(len(ecm_spots_results["filename"])))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6885e47aa447> in <module>
# ----> 1 print('number of ecm spots: ' + str(len(ecm_spots_results["filename"])))
#
# NameError: name 'ecm_spots_results' is not defined

# %% [markdown]
# ### Find the spots in all images

# %%
## make spots dictionaries
ecm_spots_results={"filename":[],
               "exp condition":[],
               "spotno":[],
                   "centroid":[],
                   "size":[],
               "distance to nearest endosome centroid":[],
                  "distance to nearest synapse centroid":[],
                 "distance to nearest endosome centroid [nms]":[],
                  "distance to nearest synapse centroid [nms]":[]}
endosome_spots_results={"filename":[],
               "exp condition":[],
               "spotno":[],
                   "centroid":[],
                   "size":[],
               "distance to nearest ecm centroid":[],
                  "distance to nearest synapse centroid":[],
                       "distance to nearest synapse centroid [nms]":[],
                       "distance to nearest ecm centroid [nms]":[]}
synapse_spots_results={"filename":[],
               "exp condition":[],
               "spotno":[],
                   "centroid":[],
                   "size":[],
               "distance to nearest endosome centroid":[],
                  "distance to nearest ecm centroid":[],
                      "distance to nearest endosome centroid [nms]":[],
                      "distance to nearest ecm centroid [nms]":[]}

for image in range(0,len(results["filename"])):
    print('Calculating image no ' + str(image+1) + ' out of' + str(len(results["filename"])))
    #read images
    ecm_channel_no=results["ecmchannelno"][image]
    endosome_channel_no=results["endosomechannelno"][image]
    synapse_channel_no=results["synapsechannelno"][image]

    ecm_image_name=results["filename"][image]+"0_ch"+str(ecm_channel_no-1)+"_t0.tif"
    endosome_image_name=results["filename"][image]+"0_ch"+str(endosome_channel_no-1)+"_t0.tif"
    synapse_image_name=results["filename"][image]+"0_ch"+str(synapse_channel_no-1)+"_t0.tif"

    print("Image name:",results["filename"][image].split('/')[-1])
    print("Experimental condition:",results["exp condition"][image])
    ecm_image=pims.open(ecm_image_name)[0]
    endosome_image=pims.open(endosome_image_name)[0]
    synapse_image=pims.open(synapse_image_name)[0]
    
    #backup
    ecm_image_raw=deepcopy(ecm_image)
    synapse_image_raw=deepcopy(synapse_image)
    endosome_image_raw=deepcopy(endosome_image)
    
    #2x2 binning --> new pixel size = 40nm
    ecm_image=np.asarray(ecm_image_raw)
    ecm_image=rebin(ecm_image,[512,512])
    endosome_image=rebin(endosome_image_raw,[512,512])
    synapse_image=rebin(synapse_image_raw,[512,512])

    #bandpass
    lowpass = ndi.gaussian_filter(ecm_image, 3)
    ecm_image = ecm_image - lowpass
    lowpass = ndi.gaussian_filter(endosome_image, 3)
    endosome_image = endosome_image - lowpass
    lowpass = ndi.gaussian_filter(synapse_image, 3)
    synapse_image = synapse_image - lowpass

    #binarize to find spots
    ecm_image[ecm_image<1]=0
    ecm_image[ecm_image>1]=1
    endosome_image[endosome_image<8]=0
    endosome_image[endosome_image>8]=1
    synapse_image[synapse_image<18]=0
    synapse_image[synapse_image>18]=1
    
    #morphological operations
    ecm_image=ndi.binary_opening(ecm_image,iterations=2)
    ecm_image=ndi.binary_closing(ecm_image,iterations=2)
    endosome_image=ndi.binary_opening(endosome_image,iterations=2)
    endosome_image=ndi.binary_closing(endosome_image,iterations=2)
    synapse_image=ndi.binary_opening(synapse_image,iterations=2)
    synapse_image=ndi.binary_closing(synapse_image,iterations=2)
    
    labeled_ecm=label(ecm_image)
    labeled_endosome=label(endosome_image)
    labeled_synapse=label(synapse_image)

    regionprops_ecm=regionprops(labeled_ecm)
    regionprops_endosome=regionprops(labeled_endosome)
    regionprops_synapse=regionprops(labeled_synapse)

    for i in range(0,len(regionprops_ecm)):
        ecm_spots_results["filename"].append(results["filename"][image])
        ecm_spots_results["exp condition"].append(results["exp condition"][image])
        ecm_spots_results["spotno"].append(i)
        ecm_spots_results["centroid"].append(regionprops_ecm[i]['centroid'])
        ecm_spots_results["size"].append(regionprops_ecm[i]['area'])
    for i in range(0,len(regionprops_endosome)):
        endosome_spots_results["filename"].append(results["filename"][image])
        endosome_spots_results["exp condition"].append(results["exp condition"][image])
        endosome_spots_results["spotno"].append(i)
        endosome_spots_results["centroid"].append(regionprops_endosome[i]['centroid'])
        endosome_spots_results["size"].append(regionprops_endosome[i]['area'])
    for i in range(0,len(regionprops_synapse)):
        synapse_spots_results["filename"].append(results["filename"][image])
        synapse_spots_results["exp condition"].append(results["exp condition"][image])
        synapse_spots_results["spotno"].append(i)
        synapse_spots_results["centroid"].append(regionprops_synapse[i]['centroid'])
        synapse_spots_results["size"].append(regionprops_synapse[i]['area'])
# Out:
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 1 out of44
# Image name: 20190307_postimaging_01_Series4_z
# Experimental condition: 20190307_postimaging_01_LAMP647_Ctrl_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 2 out of44
# Image name: 20190307_postimaging_01_Series3_z
# Experimental condition: 20190307_postimaging_01_LAMP647_Ctrl_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 3 out of44
# Image name: 20190307_postimaging_01_Series2_z
# Experimental condition: 20190307_postimaging_01_LAMP647_Ctrl_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 4 out of44
# Image name: 20190307_postimaging_01_Series1_z
# Experimental condition: 20190307_postimaging_01_LAMP647_Ctrl_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 5 out of44
# Image name: 20190307_postimaging_01_Series0_z
# Experimental condition: 20190307_postimaging_01_LAMP647_Ctrl_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 6 out of44
# Image name: 20190307_Rab7_647_blocked_Series3_z
# Experimental condition: 20190307_Rab7_647_Blk_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 7 out of44
# Image name: 20190307_Rab7_647_blocked_Series2_z
# Experimental condition: 20190307_Rab7_647_Blk_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 8 out of44
# Image name: 20190307_Rab7_647_blocked_Series1_z
# Experimental condition: 20190307_Rab7_647_Blk_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 9 out of44
# Image name: 20190307_Rab7_647_blocked_Series0_z
# Experimental condition: 20190307_Rab7_647_Blk_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 10 out of44
# Image name: 20190307_LAMP647_Ctrl_Series4_z
# Experimental condition: 20190307_LAMP647_Ctrl_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 11 out of44
# Image name: 20190307_LAMP647_Ctrl_Series3_z
# Experimental condition: 20190307_LAMP647_Ctrl_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 12 out of44
# Image name: 20190307_LAMP647_Ctrl_Series2_z
# Experimental condition: 20190307_LAMP647_Ctrl_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 13 out of44
# Image name: 20190307_LAMP647_Ctrl_Series1_z
# Experimental condition: 20190307_LAMP647_Ctrl_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 14 out of44
# Image name: 20190307_LAMP647_Ctrl_Series0_z
# Experimental condition: 20190307_LAMP647_Ctrl_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 15 out of44
# Image name: 20190307_Rab7_647_Ctrl_Series4_z
# Experimental condition: 20190307_Rab7_647_Ctrl_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 16 out of44
# Image name: 20190307_Rab7_647_Ctrl_Series3_z
# Experimental condition: 20190307_Rab7_647_Ctrl_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 17 out of44
# Image name: 20190307_Rab7_647_Ctrl_Series2_z
# Experimental condition: 20190307_Rab7_647_Ctrl_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 18 out of44
# Image name: 20190307_Rab7_647_Ctrl_Series1_z
# Experimental condition: 20190307_Rab7_647_Ctrl_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 19 out of44
# Image name: 20190307_Rab7_647_Ctrl_Series0_z
# Experimental condition: 20190307_Rab7_647_Ctrl_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 20 out of44
# Image name: 20190307_postimaging_02_Series4_z
# Experimental condition: 20190307_postimaging_02_LAMP647_Blk_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 21 out of44
# Image name: 20190307_postimaging_02_Series3_z
# Experimental condition: 20190307_postimaging_02_LAMP647_Blk_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 22 out of44
# Image name: 20190307_postimaging_02_Series2_z
# Experimental condition: 20190307_postimaging_02_LAMP647_Blk_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 23 out of44
# Image name: 20190307_postimaging_02_Series1_z
# Experimental condition: 20190307_postimaging_02_LAMP647_Blk_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 24 out of44
# Image name: 20190307_postimaging_02_Series0_z
# Experimental condition: 20190307_postimaging_02_LAMP647_Blk_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 25 out of44
# Image name: 20190307_postimaging_03_Series4_z
# Experimental condition: 20190307_postimaging_03_LAMP647_Blk2_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 26 out of44
# Image name: 20190307_postimaging_03_Series3_z
# Experimental condition: 20190307_postimaging_03_LAMP647_Blk2_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 27 out of44
# Image name: 20190307_postimaging_03_Series2_z
# Experimental condition: 20190307_postimaging_03_LAMP647_Blk2_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 28 out of44
# Image name: 20190307_postimaging_03_Series1_z
# Experimental condition: 20190307_postimaging_03_LAMP647_Blk2_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 29 out of44
# Image name: 20190307_postimaging_03_Series0_z
# Experimental condition: 20190307_postimaging_03_LAMP647_Blk2_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 30 out of44
# Image name: 20190307_postimaging_04_Series4_z
# Experimental condition: 20190307_postimaging_04_Rab5_647_Ctrl_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 31 out of44
# Image name: 20190307_postimaging_04_Series3_z
# Experimental condition: 20190307_postimaging_04_Rab5_647_Ctrl_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 32 out of44
# Image name: 20190307_postimaging_04_Series2_z
# Experimental condition: 20190307_postimaging_04_Rab5_647_Ctrl_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 33 out of44
# Image name: 20190307_postimaging_04_Series1_z
# Experimental condition: 20190307_postimaging_04_Rab5_647_Ctrl_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 34 out of44
# Image name: 20190307_postimaging_04_Series0_z
# Experimental condition: 20190307_postimaging_04_Rab5_647_Ctrl_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 35 out of44
# Image name: 20190307_postimaging_05_Series4_z
# Experimental condition: 20190307_postimaging_05_Rab5_647_Blk_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 36 out of44
# Image name: 20190307_postimaging_05_Series3_z
# Experimental condition: 20190307_postimaging_05_Rab5_647_Blk_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 37 out of44
# Image name: 20190307_postimaging_05_Series2_z
# Experimental condition: 20190307_postimaging_05_Rab5_647_Blk_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 38 out of44
# Image name: 20190307_postimaging_05_Series1_z
# Experimental condition: 20190307_postimaging_05_Rab5_647_Blk_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 39 out of44
# Image name: 20190307_postimaging_05_Series0_z
# Experimental condition: 20190307_postimaging_05_Rab5_647_Blk_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 40 out of44
# Image name: 20190307_postimaging_07_Series4_z
# Experimental condition: 20190307_postimaging_07_Rab7_647_Ctrl_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 41 out of44
# Image name: 20190307_postimaging_07_Series3_z
# Experimental condition: 20190307_postimaging_07_Rab7_647_Ctrl_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 42 out of44
# Image name: 20190307_postimaging_07_Series2_z
# Experimental condition: 20190307_postimaging_07_Rab7_647_Ctrl_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 43 out of44
# Image name: 20190307_postimaging_07_Series1_z
# Experimental condition: 20190307_postimaging_07_Rab7_647_Ctrl_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# Calculating image no 44 out of44
# Image name: 20190307_postimaging_07_Series0_z
# Experimental condition: 20190307_postimaging_07_Rab7_647_Ctrl_analyse
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)
# ImageJ series: invalid metadata or corrupted file
# TiffPages: invalid page offset (1058616)

# %% [markdown]
# ### Find the min distances between spots

# %%
for i in range(0,len(ecm_spots_results["filename"])):
    print(str(i+1)+' out of ' + str(len(ecm_spots_results["filename"])))
    ecm_spots_results["distance to nearest endosome centroid"].append(
        scipy.spatial.distance.cdist([ecm_spots_results["centroid"][i]],
                                     endosome_spots_results["centroid"],'euclidean').min())
    ecm_spots_results["distance to nearest synapse centroid"].append(
        scipy.spatial.distance.cdist([ecm_spots_results["centroid"][i]],
                                     synapse_spots_results["centroid"],'euclidean').min())
    ecm_spots_results["distance to nearest endosome centroid [nms]"].append(
        scipy.spatial.distance.cdist([ecm_spots_results["centroid"][i]],
                                     endosome_spots_results["centroid"],'euclidean').min()*40.6)
    ecm_spots_results["distance to nearest synapse centroid [nms]"].append(
        scipy.spatial.distance.cdist([ecm_spots_results["centroid"][i]],
                                     synapse_spots_results["centroid"],'euclidean').min()*40.6)
for i in range(0,len(endosome_spots_results["filename"])):
    print(str(i+1)+' out of ' + str(len(endosome_spots_results["filename"])))
    endosome_spots_results["distance to nearest ecm centroid"].append(
        scipy.spatial.distance.cdist([endosome_spots_results["centroid"][i]],
                                     ecm_spots_results["centroid"],'euclidean').min())
    endosome_spots_results["distance to nearest synapse centroid"].append(
        scipy.spatial.distance.cdist([endosome_spots_results["centroid"][i]],
                                     synapse_spots_results["centroid"],'euclidean').min())
    endosome_spots_results["distance to nearest ecm centroid [nms]"].append(
        scipy.spatial.distance.cdist([endosome_spots_results["centroid"][i]],
                                     ecm_spots_results["centroid"],'euclidean').min()*40.6)
    endosome_spots_results["distance to nearest synapse centroid [nms]"].append(
        scipy.spatial.distance.cdist([endosome_spots_results["centroid"][i]],
                                     synapse_spots_results["centroid"],'euclidean').min()*40.6)
for i in range(0,len(synapse_spots_results["filename"])):
    print(str(i+1)+' out of ' + str(len(synapse_spots_results["filename"])))
    synapse_spots_results["distance to nearest endosome centroid"].append(
        scipy.spatial.distance.cdist([synapse_spots_results["centroid"][i]],
                                     endosome_spots_results["centroid"],'euclidean').min())
    synapse_spots_results["distance to nearest ecm centroid"].append(
        scipy.spatial.distance.cdist([synapse_spots_results["centroid"][i]],
                                     ecm_spots_results["centroid"],'euclidean').min())
    synapse_spots_results["distance to nearest endosome centroid [nms]"].append(
        scipy.spatial.distance.cdist([synapse_spots_results["centroid"][i]],
                                     endosome_spots_results["centroid"],'euclidean').min()*40.6)
    synapse_spots_results["distance to nearest ecm centroid [nms]"].append(
        scipy.spatial.distance.cdist([synapse_spots_results["centroid"][i]],
                                     ecm_spots_results["centroid"],'euclidean').min()*40.6)
# Out:
# 1 out of 3171
# 2 out of 3171
# 3 out of 3171
# 4 out of 3171
# 5 out of 3171
# 6 out of 3171
# 7 out of 3171
# 8 out of 3171
# 9 out of 3171
# 10 out of 3171
# 11 out of 3171
# 12 out of 3171
# 13 out of 3171
# 14 out of 3171
# 15 out of 3171
# 16 out of 3171
# 17 out of 3171
# 18 out of 3171
# 19 out of 3171
# 20 out of 3171
# 21 out of 3171
# 22 out of 3171
# 23 out of 3171
# 24 out of 3171
# 25 out of 3171
# 26 out of 3171
# 27 out of 3171
# 28 out of 3171
# 29 out of 3171
# 30 out of 3171
# 31 out of 3171
# 32 out of 3171
# 33 out of 3171
# 34 out of 3171
# 35 out of 3171
# 36 out of 3171
# 37 out of 3171
# 38 out of 3171
# 39 out of 3171
# 40 out of 3171
# 41 out of 3171
# 42 out of 3171
# 43 out of 3171
# 44 out of 3171
# 45 out of 3171
# 46 out of 3171
# 47 out of 3171
# 48 out of 3171
# 49 out of 3171
# 50 out of 3171
# 51 out of 3171
# 52 out of 3171
# 53 out of 3171
# 54 out of 3171
# 55 out of 3171
# 56 out of 3171
# 57 out of 3171
# 58 out of 3171
# 59 out of 3171
# 60 out of 3171
# 61 out of 3171
# 62 out of 3171
# 63 out of 3171
# 64 out of 3171
# 65 out of 3171
# 66 out of 3171
# 67 out of 3171
# 68 out of 3171
# 69 out of 3171
# 70 out of 3171
# 71 out of 3171
# 72 out of 3171
# 73 out of 3171
# 74 out of 3171
# 75 out of 3171
# 76 out of 3171
# 77 out of 3171
# 78 out of 3171
# 79 out of 3171
# 80 out of 3171
# 81 out of 3171
# 82 out of 3171
# 83 out of 3171
# 84 out of 3171
# 85 out of 3171
# 86 out of 3171
# 87 out of 3171
# 88 out of 3171
# 89 out of 3171
# 90 out of 3171
# 91 out of 3171
# 92 out of 3171
# 93 out of 3171
# 94 out of 3171
# 95 out of 3171
# 96 out of 3171
# 97 out of 3171
# 98 out of 3171
# 99 out of 3171
# 100 out of 3171
# 101 out of 3171
# 102 out of 3171
# 103 out of 3171
# 104 out of 3171
# 105 out of 3171
# 106 out of 3171
# 107 out of 3171
# 108 out of 3171
# 109 out of 3171
# 110 out of 3171
# 111 out of 3171
# 112 out of 3171
# 113 out of 3171
# 114 out of 3171
# 115 out of 3171
# 116 out of 3171
# 117 out of 3171
# 118 out of 3171
# 119 out of 3171
# 120 out of 3171
# 121 out of 3171
# 122 out of 3171
# 123 out of 3171
# 124 out of 3171
# 125 out of 3171
# 126 out of 3171
# 127 out of 3171
# 128 out of 3171
# 129 out of 3171
# 1345 out of 1364
# 1346 out of 1364
# 1347 out of 1364
# 1348 out of 1364
# 1349 out of 1364
# 1350 out of 1364
# 1351 out of 1364
# 1352 out of 1364
# 1353 out of 1364
# 1354 out of 1364
# 1355 out of 1364
# 1356 out of 1364
# 1357 out of 1364
# 1358 out of 1364
# 1359 out of 1364
# 1360 out of 1364
# 1361 out of 1364
# 1362 out of 1364
# 1363 out of 1364
# 1364 out of 1364

# %% [markdown]
# ## Plots

# %%
df_synapses=pd.DataFrame(synapse_spots_results)
df_ecm=pd.DataFrame(ecm_spots_results)
df_endosome=pd.DataFrame(endosome_spots_results)

# %% [markdown]
# ### Backup

# %%
#os.mkdir(expdir+'results/')
df_ecm.to_csv(path_or_buf=expdir+'results/results_'+str(protein)+'_ecm.csv')
df_endosome.to_csv(path_or_buf=expdir+'results/results_'+str(protein)+'_endosome.csv')
df_synapses.to_csv(path_or_buf=expdir+'results/results_'+str(protein)+'_synapses.csv')

# %%
df_ecm=pd.read_csv(expdir+'results/results_'+str(protein)+'.csv')

# %%
fig=plt.figure(figsize=(10,5))
g=sns.distplot(df_ecm["distance to nearest endosome centroid [nms]"],label="Distance to nearest endosome")
#g=sns.kdeplot(df_endosome["distance to nearest ecm centroid [nms]"],shade=True)
g=sns.distplot(df_ecm["distance to nearest synapse centroid [nms]"],label="Distance to nearest synapse")
g.set_xticks(np.linspace(0,500,11))
g.set_xlim([-20,400])
plt.legend(fontsize=16)
g.set_xlabel('Distance (nms)',fontsize=14)
# Out:
# Text(0.5, 0, 'Distance (nms)')

# %%
df_ecm["exp condition"].unique()

# %%
df_ecm['Protein']='None'
df_ecm['Treatment']='None'
df_ecm.loc[df_ecm['exp condition'].str.contains('LAMP'), 'Protein'] = 'Lamp1'
df_ecm.loc[df_ecm['exp condition'].str.contains('Rab5'), 'Protein'] = 'Rab5'
df_ecm.loc[df_ecm['exp condition'].str.contains('Rab7'), 'Protein'] = 'Rab7'
df_ecm.loc[df_ecm['exp condition'].str.contains('Ctrl'), 'Treatment'] = 'Unblocked Control'
df_ecm.loc[df_ecm['exp condition'].str.contains('Blk'), 'Treatment'] = 'Blocked'
df_endosome['Protein']='None'
df_endosome['Treatment']='None'
df_endosome.loc[df_endosome['exp condition'].str.contains('LAMP'), 'Protein'] = 'Lamp1'
df_endosome.loc[df_endosome['exp condition'].str.contains('Rab5'), 'Protein'] = 'Rab5'
df_endosome.loc[df_endosome['exp condition'].str.contains('Rab7'), 'Protein'] = 'Rab7'
df_endosome.loc[df_endosome['exp condition'].str.contains('Ctrl'), 'Treatment'] = 'Unblocked Control'
df_endosome.loc[df_endosome['exp condition'].str.contains('Blk'), 'Treatment'] = 'Blocked'
df_synapses['Protein']='None'
df_synapses['Treatment']='None'
df_synapses.loc[df_synapses['exp condition'].str.contains('LAMP'), 'Protein'] = 'Lamp1'
df_synapses.loc[df_synapses['exp condition'].str.contains('Rab5'), 'Protein'] = 'Rab5'
df_synapses.loc[df_synapses['exp condition'].str.contains('Rab7'), 'Protein'] = 'Rab7'
df_synapses.loc[df_synapses['exp condition'].str.contains('Ctrl'), 'Treatment'] = 'Unblocked Control'
df_synapses.loc[df_synapses['exp condition'].str.contains('Blk'), 'Treatment'] = 'Blocked'

# %%
df_ecm['Distance to endosome']='>50nm'
df_ecm['Distance to synapse']='>50nm'
df_ecm.loc[df_ecm["distance to nearest endosome centroid [nms]"]<50,'Distance to endosome']='<50nm'
df_ecm.loc[df_ecm["distance to nearest synapse centroid [nms]"]<50,'Distance to synapse']='<50nm'

# %%
sns.countplot(x="Distance to endosome", data=df_ecm)

# %%
propbigger
# Out:
# 0.9301675977653632

# %%
dfprops
# Out:
#   Distance  Percentage
# 0    <50nm    0.069832
# 1    >50nm    0.930168

# %%
for protein in df_ecm["Protein"].unique():
    df2plot=df_ecm[(df_ecm["Treatment"]=="Unblocked Control")&(df_ecm["Protein"]==protein)]
    #df2plot=df_ecm[(df_ecm["Protein"]==protein)]
    fig=plt.figure(figsize=(10,5))
    fig.add_subplot(211)
    g=sns.distplot(df2plot["distance to nearest endosome centroid [nms]"],label="Distance to nearest endosome")
    g=sns.distplot(df2plot["distance to nearest synapse centroid [nms]"],label="Distance to nearest synapse")
    g.set_xticks(np.linspace(0,500,11))
    g.set_xlim([-20,700])
    plt.legend(fontsize=16)
    g.set_xlabel('Distance (nms)',fontsize=14)
    plt.title(protein)
    
    fig.add_subplot(223)
    dfcount=df2plot.groupby("Distance to endosome").count()
    smallerthan=dfcount["filename"].unique()[0]
    biggerthan=dfcount["filename"].unique()[1]
    propsmaller=smallerthan/(smallerthan+biggerthan)
    propbigger=biggerthan/(smallerthan+biggerthan)
    dfprops={'Distance':['<50nm','>50nm'],'Percentage':[propsmaller,propbigger]}
    dfprops=pd.DataFrame(dfprops)
    sns.barplot(x="Distance",y="Percentage",data=dfprops)
    plt.text(x=-0.1,y=0.2,s=np.round(propsmaller,3))
    plt.text(x=0.8,y=0.2,s=np.round(propbigger,3))
    
    fig.add_subplot(224)
    dfcount=df2plot.groupby("Distance to synapse").count()
    smallerthan=dfcount["filename"].unique()[0]
    biggerthan=dfcount["filename"].unique()[1]
    propsmaller=smallerthan/(smallerthan+biggerthan)
    propbigger=biggerthan/(smallerthan+biggerthan)
    dfprops={'Distance':['<50nm','>50nm'],'Percentage':[propsmaller,propbigger]}
    dfprops=pd.DataFrame(dfprops)
    sns.barplot(x="Distance",y="Percentage",data=dfprops)
    plt.text(x=-0.1,y=0.2,s=np.round(propsmaller,3))
    plt.text(x=0.8,y=0.2,s=np.round(propbigger,3))
    
    fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-148-126eafdce90f> in <module>
#       4     fig=plt.figure(figsize=(10,5))
#       5     fig.add_subplot(211)
# ----> 6     g=sns.hist(df2plot["distance to nearest endosome centroid [nms]"],label="Distance to nearest endosome")
#       7     g=sns.distplot(df2plot["distance to nearest synapse centroid [nms]"],label="Distance to nearest synapse")
#       8     g.set_xticks(np.linspace(0,500,11))
#
# AttributeError: module 'seaborn' has no attribute 'hist'
