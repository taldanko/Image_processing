# %% [markdown]
# ## Import modules and functions

# %%
import numpy as np
import os
from nd2reader import ND2Reader
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib_scalebar.scalebar import ScaleBar
import scipy.ndimage as ndi
from skimage.filters import rank 
from scipy.signal import butter, lfilter
import scipy.misc as misc
from skimage import exposure
from PIL import Image
import colorcet as cc
import matplotlib.colors as clr
import pandas as pd
import seaborn as sns
from scipy import stats
import cv2
from pyspark import SparkContext, SparkConf
import skimage
from pathlib import Path

def mean2(x):
    y = np.sum(x) / np.size(x);
    return y
def corr2(a,b):
    a = a - mean2(a)
    b = b - mean2(b)

    r = (a*b).sum() / np.sqrt((a*a).sum() * (b*b).sum());
    return r
from copy import deepcopy
from skimage.filters import threshold_otsu,threshold_li
import glob
from IPython.display import clear_output
import scipy.io as spio

# %% [markdown]
# ## Define directory of images

# %%
expdir='/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Fixed culture/Controls/20202_fab_fixedctrls/' #master folder

# %% [markdown]
# ## Make dictionary for storing results

# %%
results = {"filename":[],"exp":[],
           "Manual mask from matlab GUI":[],"bg sub int under mask":[]}
path = os.path.dirname(expdir)  
outputFolder = os.path.dirname(expdir + "/new/")
filelist = []
for root, _, filenames in os.walk(path):
     for filename in filenames:
         filelist.append(os.path.join(root, filename))      
for i in range(0,len(filelist)):
    if filelist[i].endswith(".nd2"): 
        results["filename"].append(filelist[i])
        results["exp"].append(filelist[i].split('/')[-3])

# %% [markdown]
# ## Read manual masks from Matlab GUI

# %%
## matlab files
for im in range(0,len(results["filename"])): 
    file=results["filename"][im][:-4]+'_dendritesmask.mat'
    from pathlib import Path
    my_file = Path(file)
    if my_file.exists():
        print(file)
        mat = spio.loadmat(file, squeeze_me=True)
        mask=mat['totMask']>0.99
        results["Manual mask from matlab GUI"].append(mask)
    else:
        results["Manual mask from matlab GUI"].append(np.nan)
clear_output()        
print("Done!")
# Out:
# Done!

# %% [markdown]
# ## Batch analysis of images - mean intensity

# %%
print('Total number of images: ' + str(len(results['filename'])))

for i in range(0,len(results["filename"])): 
    flag=False
    print('Calculating image no ' + str(i+1) + ' out of' + str(len(results["filename"])))
    #read the image
    with ND2Reader(results["filename"][i]) as images:
        ecm_image=images[0]
    #convert to numpy array - a format easier to manipunuclei with code
    ecm_image=ecm_image.astype(np.int16)
    #read masks 
    matlab_mask=results["Manual mask from matlab GUI"][i]
    if type(matlab_mask)==np.ndarray:
        flag=True
    #image after background subtraction
    #for ecm image
    if flag==True:
        ecm_matlabmasked_bgreduced=deepcopy(ecm_image)
        bg_matlabmask=np.mean(ndi.median_filter(ecm_image[matlab_mask],size=5))+2*np.std(ndi.median_filter(ecm_image[matlab_mask],size=5))
        ecm_matlabmasked_bgreduced=np.subtract(ecm_matlabmasked_bgreduced,bg_matlabmask)
        ecm_matlabmasked_bgreduced[ecm_matlabmasked_bgreduced<0]=0
        ecm_matlabmasked_bgreduced[~matlab_mask]=0
        
    if flag==True:
        results["bg sub int under mask"].append(ecm_matlabmasked_bgreduced[matlab_mask].mean())
    else:
        results["bg sub int under mask"].append(np.nan)
# Out:
# Total number of images: 151
# Calculating image no 1 out of151
# Calculating image no 2 out of151
# Calculating image no 3 out of151
# Calculating image no 4 out of151
# Calculating image no 5 out of151
# Calculating image no 6 out of151
# Calculating image no 7 out of151
# Calculating image no 8 out of151
# Calculating image no 9 out of151
# Calculating image no 10 out of151
# Calculating image no 11 out of151
# Calculating image no 12 out of151
# Calculating image no 13 out of151
# Calculating image no 14 out of151
# Calculating image no 15 out of151
# Calculating image no 16 out of151
# Calculating image no 17 out of151
# Calculating image no 18 out of151
# Calculating image no 19 out of151
# Calculating image no 20 out of151
# Calculating image no 21 out of151
# Calculating image no 22 out of151
# Calculating image no 23 out of151
# Calculating image no 24 out of151
# Calculating image no 25 out of151
# Calculating image no 26 out of151
# Calculating image no 27 out of151
# Calculating image no 28 out of151
# Calculating image no 29 out of151
# Calculating image no 30 out of151
# Calculating image no 31 out of151
# Calculating image no 32 out of151
# Calculating image no 33 out of151
# Calculating image no 34 out of151
# Calculating image no 35 out of151
# Calculating image no 36 out of151
# Calculating image no 37 out of151
# Calculating image no 38 out of151
# Calculating image no 39 out of151
# Calculating image no 40 out of151
# Calculating image no 41 out of151
# Calculating image no 42 out of151
# Calculating image no 43 out of151
# Calculating image no 44 out of151
# Calculating image no 45 out of151
# Calculating image no 46 out of151
# Calculating image no 47 out of151
# Calculating image no 48 out of151
# Calculating image no 49 out of151
# Calculating image no 50 out of151
# Calculating image no 51 out of151
# Calculating image no 52 out of151
# Calculating image no 53 out of151
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in less
# /Users/taldankovich/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:25: RuntimeWarning: Mean of empty slice.
# Calculating image no 54 out of151
# Calculating image no 55 out of151
# Calculating image no 56 out of151
# Calculating image no 57 out of151
# Calculating image no 58 out of151
# Calculating image no 59 out of151
# Calculating image no 60 out of151
# Calculating image no 61 out of151
# Calculating image no 62 out of151
# Calculating image no 63 out of151
# Calculating image no 64 out of151
# Calculating image no 65 out of151
# Calculating image no 66 out of151
# Calculating image no 67 out of151
# Calculating image no 68 out of151
# Calculating image no 69 out of151
# Calculating image no 70 out of151
# Calculating image no 71 out of151
# Calculating image no 72 out of151
# Calculating image no 73 out of151
# Calculating image no 74 out of151
# Calculating image no 75 out of151
# Calculating image no 76 out of151
# Calculating image no 77 out of151
# Calculating image no 78 out of151
# Calculating image no 79 out of151
# Calculating image no 80 out of151
# Calculating image no 81 out of151
# Calculating image no 82 out of151
# Calculating image no 83 out of151
# Calculating image no 84 out of151
# Calculating image no 85 out of151
# Calculating image no 86 out of151
# Calculating image no 87 out of151
# Calculating image no 88 out of151
# Calculating image no 89 out of151
# Calculating image no 90 out of151
# Calculating image no 91 out of151
# Calculating image no 92 out of151
# Calculating image no 93 out of151
# Calculating image no 94 out of151
# Calculating image no 95 out of151
# Calculating image no 96 out of151
# Calculating image no 97 out of151
# Calculating image no 98 out of151
# Calculating image no 99 out of151
# Calculating image no 100 out of151
# Calculating image no 101 out of151
# Calculating image no 102 out of151
# Calculating image no 103 out of151
# Calculating image no 104 out of151
# Calculating image no 105 out of151
# Calculating image no 106 out of151
# Calculating image no 107 out of151
# Calculating image no 108 out of151
# Calculating image no 109 out of151
# Calculating image no 110 out of151
# Calculating image no 111 out of151
# Calculating image no 112 out of151
# Calculating image no 113 out of151
# Calculating image no 114 out of151
# Calculating image no 115 out of151
# Calculating image no 116 out of151
# Calculating image no 117 out of151
# Calculating image no 118 out of151
# Calculating image no 119 out of151
# Calculating image no 120 out of151
# Calculating image no 121 out of151
# Calculating image no 122 out of151
# Calculating image no 123 out of151
# Calculating image no 124 out of151
# Calculating image no 125 out of151
# Calculating image no 126 out of151
# Calculating image no 127 out of151
# Calculating image no 128 out of151
# Calculating image no 129 out of151
# Calculating image no 130 out of151
# Calculating image no 131 out of151
# Calculating image no 132 out of151
# Calculating image no 133 out of151
# Calculating image no 134 out of151
# Calculating image no 135 out of151
# Calculating image no 136 out of151
# Calculating image no 137 out of151
# Calculating image no 138 out of151
# Calculating image no 139 out of151
# Calculating image no 140 out of151
# Calculating image no 141 out of151
# Calculating image no 142 out of151
# Calculating image no 143 out of151
# Calculating image no 144 out of151
# Calculating image no 145 out of151
# Calculating image no 146 out of151
# Calculating image no 147 out of151
# Calculating image no 148 out of151
# Calculating image no 149 out of151
# Calculating image no 150 out of151
# Calculating image no 151 out of151

# %% [markdown]
# ## Make a dataframe of the results

# %%
df=pd.DataFrame(results)
df2=deepcopy(df)
df2['Blocked or not']='None'
df2.loc[df2['exp'].str.contains('blk'), 'Blocked or not'] = 'Blocked'
df2.loc[df2['exp'].str.contains('unblk'), 'Blocked or not'] = 'Unblocked'

df2['Time']='Immediately'

df2['TNR or secondary']='None'
df2.loc[df2['exp'].str.contains('tnr'), 'TNR or secondary'] = 'TNR'
df2.loc[df2['exp'].str.contains('tnr'), 'TNR or secondary'] = 'TNR'

df2['expno']='None'
df2.loc[df2['filename'].str.contains('20200210_fixedctrl'), 'expno'] = 'exp1'
df2.loc[df2['filename'].str.contains('20200214_fixedctrl'), 'expno'] = 'exp2'
df2.loc[df2['filename'].str.contains('20200228_fixedctrl'), 'expno'] = 'exp3'

df2["Condition"]='None'
df2.loc[df2['filename'].str.contains('autofluorescence'), 'Condition'] = 'Background - Autofluorescence'
df2.loc[df2['filename'].str.contains('blk_plus12'), 'Condition'] = 'Block+12, TNR647'
df2.loc[df2['filename'].str.contains('blk_plus0'), 'Condition'] = 'Block+0, TNR647'
df2.loc[df2['filename'].str.contains('unblk'), 'Condition'] = 'Unblocked TNR647'
df2.loc[df2['filename'].str.contains('only580'), 'Condition'] = 'Background - Atto647'

# %%
df2.head()
# Out:
#                                             filename                 exp  \
# 0  /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/F...  20200228_fixedctrl
# 1  /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/F...  20200228_fixedctrl
# 2  /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/F...  20200228_fixedctrl
# 3  /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/F...  20200228_fixedctrl
# 4  /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/F...  20200228_fixedctrl
#
#                          Manual mask from matlab GUI  bg sub int under mask  \
# 0  [[False, False, False, False, False, False, Fa...               4.527833
# 1  [[False, False, False, False, False, False, Fa...               5.632084
# 2  [[False, False, False, False, False, False, Fa...               4.758060
# 3  [[False, False, False, False, False, False, Fa...               3.632771
# 4  [[False, False, False, False, False, False, Fa...               5.140619
#
#   Blocked or not         Time TNR or secondary expno  \
# 0           None  Immediately             None  exp3
# 1           None  Immediately             None  exp3
# 2           None  Immediately             None  exp3
# 3           None  Immediately             None  exp3
# 4           None  Immediately             None  exp3
#
#                        Condition
# 0  Background - Autofluorescence
# 1  Background - Autofluorescence
# 2  Background - Autofluorescence
# 3  Background - Autofluorescence
# 4  Background - Autofluorescence

# %% [markdown]
# ## Make dataframe with means for individual experiments

# %%
var="bg sub int under mask"
means={"expname":[],"Condition":[],"intensity":[]}
df2read=df2
for exp in df2read["exp"].unique():
    dfcalc=df2read[df2read["exp"]==exp]
    dfcalc=dfcalc.reset_index()
    for condition in dfcalc["Condition"].unique():
        dfcalc_cond=dfcalc[dfcalc["Condition"]==condition]
        means["expname"].append(exp)
        means["Condition"].append(condition)
        means["intensity"].append(dfcalc_cond[var].mean())
dfmeans=pd.DataFrame(means)

# %%
dfmeans
# Out:
#                expname                      Condition  intensity
# 0   20200228_fixedctrl  Background - Autofluorescence   4.619923
# 1   20200228_fixedctrl                Block+0, TNR647   6.634774
# 2   20200228_fixedctrl               Block+12, TNR647   6.671564
# 3   20200228_fixedctrl           Background - Atto647   5.256759
# 4   20200228_fixedctrl               Unblocked TNR647  59.761967
# 5   20200210_fixedctrl  Background - Autofluorescence   5.627987
# 6   20200210_fixedctrl                Block+0, TNR647   4.445640
# 7   20200210_fixedctrl               Block+12, TNR647   6.586755
# 8   20200210_fixedctrl           Background - Atto647   4.912618
# 9   20200210_fixedctrl               Unblocked TNR647  54.964676
# 10  20200214_fixedctrl  Background - Autofluorescence   4.664665
# 11  20200214_fixedctrl                Block+0, TNR647   6.217650
# 12  20200214_fixedctrl               Block+12, TNR647   8.917541
# 13  20200214_fixedctrl           Background - Atto647   5.485182
# 14  20200214_fixedctrl               Unblocked TNR647  52.952982

# %%
d={}
for condition in dfmeans["Condition"].unique():
    d["string{0}".format(condition)]=dfmeans[dfmeans["Condition"]==condition]["intensity"].values
d=pd.DataFrame(d)
d.to_csv("/Volumes/Macintosh HD/Users/taldankovich/Downloads/csvs/dfmeans.csv")

# %% [markdown]
# ## Multiple ttests with Bonferroni correction (compare each group to no blocking condition)

# %%
from scipy import stats
negctrl=dfmeans[dfmeans["Condition"]=="Unblocked TNR647"]["intensity"].values
for item in ["Background - Autofluorescence","Background - Atto647","Block+0, TNR647","Block+12, TNR647"]:
    vals=dfmeans[dfmeans["Condition"]==item]["intensity"].values
    [stat, pval]=stats.ttest_ind(negctrl,vals)
    print('condition: '+item+' pval: '+str(pval*4))
# Out:
# condition: Background - Autofluorescence pval: 0.002439279263708328
# condition: Background - Atto647 pval: 0.017911803377662107
# condition: Block+0, TNR647 pval: 0.002258493875043441
# condition: Block+12, TNR647 pval: 0.0025061461710793875

# %%
var="intensity"
bgauto=dfmeans[dfmeans["Condition"]=="Background - Autofluorescence"][var].dropna().values
bgatto=dfmeans[dfmeans["Condition"]=="Background - Atto647"][var].dropna().values
bgblockplus0=dfmeans[dfmeans["Condition"]=="Block+0, TNR647"][var].dropna().values
bgblockplus12=dfmeans[dfmeans["Condition"]=="Block+12, TNR647"][var].dropna().values
negctrl=dfmeans[dfmeans["Condition"]=="Unblocked TNR647"]["intensity"].dropna().values

stats.f_oneway(bgauto, bgatto, bgblockplus0,bgblockplus12,negctrl)
# Out:
# F_onewayResult(statistic=478.32413208721414, pvalue=2.2700435846308507e-11)

# %%
import ipywidgets as widgets
from ipywidgets import interact
import scipy.stats as stats
import statsmodels.formula.api as smf
import statsmodels.stats.multicomp as multi
from statsmodels.stats.libqsturng import psturng

x = dfmeans["Condition"]
y = dfmeans[var]
# DataFrame.
mcDate = multi.MultiComparison(y,x)
Results = mcDate.tukeyhsd()
df = pd.DataFrame(data=Results._results_table.data[1:], columns=Results._results_table.data[0])
res=Results
pvals=psturng(np.abs(res.meandiffs / res.std_pairs),len(res.groupsunique), res.df_total)
df["pvals"]=pvals

df
# Out:
#                           group1                         group2  meandiff  \
# 0           Background - Atto647  Background - Autofluorescence   -0.2473
# 1           Background - Atto647                Block+0, TNR647    0.5478
# 2           Background - Atto647               Block+12, TNR647    2.1738
# 3           Background - Atto647               Unblocked TNR647   50.6750
# 4  Background - Autofluorescence                Block+0, TNR647    0.7952
# 5  Background - Autofluorescence               Block+12, TNR647    2.4211
# 6  Background - Autofluorescence               Unblocked TNR647   50.9224
# 7                Block+0, TNR647               Block+12, TNR647    1.6259
# 8                Block+0, TNR647               Unblocked TNR647   50.1272
# 9               Block+12, TNR647               Unblocked TNR647   48.5013
#
#     p-adj    lower    upper  reject     pvals
# 0  0.9000  -5.0165   4.5218   False  0.900000
# 1  0.9000  -4.2213   5.3170   False  0.900000
# 2  0.5783  -2.5954   6.9429   False  0.578275
# 3  0.0010  45.9059  55.4442    True  0.001000
# 4  0.9000  -3.9740   5.5643   False  0.900000
# 5  0.4907  -2.3480   7.1902   False  0.490659
# 6  0.0010  46.1532  55.6915    True  0.001000
# 7  0.7726  -3.1432   6.3951   False  0.772558
# 8  0.0010  45.3581  54.8963    True  0.001000
# 9  0.0010  43.7321  53.2704    True  0.001000

# %% [markdown]
# ## nice plot

# %%
sns.set(font_scale=2.5)
sns.set_style("ticks")
sns.set_palette("Set2")
from matplotlib import ticker

fig=plt.figure(figsize=(5,6))

df2plot=dfmeans
var='intensity'
order=['Background - Autofluorescence',
       'Background - Atto647',
      'Block+0, TNR647',
       'Block+12, TNR647',
       'Unblocked TNR647'
       ]

paletteswarm ={"Background - Autofluorescence":"#2F67F8",
               "Unblocked TNR647":"#333333",
               "Background - Atto647":"#2F67F8",
               "Block+0, TNR647":"#2F67F8",
               "Block+12, TNR647":"#2F67F8"}
palette ={"Background - Autofluorescence":"#abc2fc",
          "Unblocked TNR647":"#adadad",
               "Background - Atto647":"#abc2fc",
               "Block+0, TNR647":"#abc2fc",
               "Block+12, TNR647":"#abc2fc"}


g=sns.barplot(data=df2plot,y=var,x="Condition"
            ,order=order,palette=palette,ci=None)

g=sns.swarmplot(data=df2plot,y=var,x="Condition"
            ,order=order,palette=paletteswarm,size=8)

def change_width(ax, new_value) :
    for patch in ax.patches :
        current_width = patch.get_width()
        diff = current_width - new_value
        
        # we change the bar width
        patch.set_width(new_value)

        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)
        
change_width(g, .8)

plt.errorbar(x=np.arange(0,len(order)),
             y=[df2plot[df2plot["Condition"]==condtype][var].mean() for condtype in order],
             yerr=[df2plot[df2plot["Condition"]==condtype][var].sem() for condtype in order],
             xerr=None,ecolor='black',fmt='none',capsize=10,linewidth=3,
             capthick=3,zorder=10,
            alpha=1)

plt.axhline(0, color='#333333',alpha=1,linewidth=4)

g.xaxis.set_tick_params(width=4)
g.yaxis.set_tick_params(width=4)

plt.rcParams['font.sans-serif'] = 'Helvetica'
col='black'



g.set_ylabel('')
g.set_xlabel('',color='#333333',alpha=.7)


g.grid(False)


for axis in ['top','bottom','left','right']:
  g.spines[axis].set_linewidth(4)
  g.spines[axis].set_color('#333333')
  g.spines[axis].set_alpha(1)

plt.xticks(g.get_xticks(),['Auto-\nfluorescence',
                           'Secondary\nantibody alone',
      'Block+0',
       'Block+12',
       'No blocking'
       ],
           rotation=70,size=24)
offsets={"left":10,"bottom":0}
trims={"left":True,"bottom":False,"right":False}
sns.despine(ax=g,right=True,top=True,bottom=True,trim=trims,offset=offsets)
#plt.yticks([0,2,4,6,8,10,12],fontsize=22,color='#333333')

plt.ylim([0,70])

scale_x=20
ticks_y=ticker.FuncFormatter(lambda x, pos: '{0:g}' .format(x/scale_x))
g=plt.gca()
g.yaxis.set_major_formatter(ticks_y)

for number in range(4):
    plt.text(number, 8, "***", ha='center', va='bottom', color=col,size=20, weight='bold')

'''x1, x2 = 0,4
y= 330
h=5
col='black'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=3.5, c=col)
plt.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col,size=24, weight='bold')

x1, x2 = 1,4
y= 330
h=5
col='black'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=3.5, c=col)

x1, x2 = 2,4
y= 330
h=5
col='black'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=3.5, c=col)

x1, x2 = 3,4
y= 330
h=5
col='black'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=3.5, c=col)'''


diri="/Volumes/Macintosh HD/Users/taldankovich/Downloads/figures/"

fig.savefig(diri+'supp_fixedctrl_fabs.svg', bbox_inches='tight', format='svg')

# %%
dfmeans.groupby("Condition").mean()
# Out:
#                                 intensity
# Condition
# Background - Atto647            48.862609
# Background - Autofluorescence   60.601335
# Block+0, TNR647                 52.940255
# Block+12, TNR647                66.039338
# Unblocked TNR647               558.912768

# %%
df_2show=df2[df2["Condition"]=="Block+12, TNR647"]
df_2show=df_2show.reset_index(drop=True)

minval=0
maxval=10000
num=1
leng=len(df_2show)
fig=plt.figure(figsize=(20,150))
for i in range(0,len(df_2show)):
    #print(i)
    fig.add_subplot(leng,1,num)
    with ND2Reader(df_2show["filename"][i]) as images:
        ecm_image=images[0]
        plt.imshow(ecm_image,interpolation='none',cmap='hot',vmin=minval,vmax=maxval)
        plt.title(df_2show["filename"][i][-40:], size=14)
        plt.yticks(visible=False)
        plt.xticks(visible=False)
        plt.grid(visible=False)
        plt.axis(visible=False)
        #scalebar = ScaleBar(107.1, 'nm', dimension='si-length',box_alpha=0,location='lower right',length_fraction=0.2,
        #                       font_properties={'size':0,'weight':'bold'},color='white',border_pad=0.5) # 1 pixel = 0.2 meter
        #plt.gca().add_artist(scalebar)
        num+=1
