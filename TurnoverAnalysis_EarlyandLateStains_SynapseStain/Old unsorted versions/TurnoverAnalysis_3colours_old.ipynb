# %% [markdown]
# ### Import modules

# %%
import numpy as np
import os
from nd2reader import ND2Reader
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib_scalebar.scalebar import ScaleBar
import scipy.ndimage as ndi
from skimage.filters import rank 
from scipy.signal import butter, lfilter
import scipy.misc as misc
from skimage import exposure
from PIL import Image
import colorcet as cc
from scipy.misc import toimage
import matplotlib.colors as clr
import pandas as pd
import seaborn as sns
from scipy import stats
import cv2
from pyspark import SparkContext, SparkConf
import skimage
from pathlib import Path
# %matplotlib inline
def mean2(x):
    y = np.sum(x) / np.size(x);
    return y
def corr2(a,b):
    a = a - mean2(a)
    b = b - mean2(b)

    r = (a*b).sum() / np.sqrt((a*a).sum() * (b*b).sum());
    return r
from copy import deepcopy

# %% [markdown]
# ### Specify experiment directory

# %%
expdir='/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/' #master folder

# %% [markdown]
# ### Make dictionary for storage of results

# %%
results = {"filename":[],"Autofluorescencedir":[],
           "earlychannelno":[],"latechannelno":[],"synapsechannelno":[],"exp_id":[],
           "Earlycontroldir":[],"Latecontroldir":[],
           "Early colour - spots mask":[],
           "Late colour - spots mask":[],
           "Late plus early colour - spots mask":[],
           "Synapse colour - spots mask":[],
           "exp condition":[],
           #results on raw whole images
           "Early colour - Raw mean intensity":[],
           "Late colour - Raw mean intensity":[],
           "Synapse colour - Raw mean intensity":[],
           "Mean colour bias of a pixel (early=-1<x<1=late) - Whole raw image":[],
           "Mean correlation coefficient early/late - Whole raw image":[],
           #results on early or late or synapse spots
           "Early colour - Mean intensity of spots":[], 
           "Late colour - Mean intensity of spots":[], 
           "Synapse colour - Mean intensity of spots":[],
           "Early colour - Mean intensity of spots Normd to early ctrl":[],
           "Late colour - Mean intensity of spots Normd to late ctrl":[],
           "Early colour - Total no. of spots in FOV":[],
           "Late colour - Total no. of spots in FOV":[],
           "Synapse colour - Total no. of spots in FOV":[],
           "Early colour - Mean spot area [nm]":[],
           "Late colour - Mean spot area [nm]":[],
           "Synapse colour - Mean spot area [nm]":[],
           #based on -late or early- and synapse spots
           "Early colour - Mean intensity of spots only under synapses":[],
           "Late colour - Mean intensity of spots only under synapses":[],
           "Early colour - Mean intensity of spots Normd to early ctrl - masked by synapses":[],
           "Late colour - Mean intensity of spots Normd to late ctrl - masked by synapses":[],
           "Early colour spots normd to early ctrl, corr to Synapse spots":[],
           "Late colour spots normd to late ctrl, corr to Synapse spots":[],
           #based on late+early spots
           "Mean colour bias of a pixel (early=-1<x<1=late) - under late+early spots":[],
            #based on late+early and synapse spots
           "Mean colour bias of a pixel, masked by early, late, synapses (early=-1<x<1=late)":[],
           "Mean colour bias of a pixel, masked by early, late, synapses (early=-1<x<1=late) - early and late normd to corresponding ctrls":[]}


histogram_results={"filename":[],"exp condition":[],
           "Early colour - Flattened histogram":[],
           "Late colour - Flattened histogram":[],
           "Synapse colour - Flattened histogram":[]}
                   
regionprops_results={"filename":[],
           "exp condition":[],"Early colour - regionprops":[],
           "Late colour - regionprops":[],
           "Synapse colour - regionprops":[],
           "Late + early colour combined - regionprops":[]}
    
synapse_results={"filename":[],
           "exp condition":[],
           "Early colour - Mean intensity":[], #based on spot segmentation
           "Late colour - Mean intensity":[],#based on spot segmentation
           "Synapse colour - Mean intensity":[],#based on spot segmentation
           "Synapse Area":[], 
           "Mean colour bias of synapse (early=-1<x<1=late)":[],
           "Is new synapse (1=new, 0=old)":[],
           "Correlation between late colour and synapse intensity":[]}

path = os.path.dirname(expdir)  
outputFolder = os.path.dirname(expdir + "/new/")
filelist = []
for root, _, filenames in os.walk(path):
     for filename in filenames:
         filelist.append(os.path.join(root, filename))
        
for i in range(0,len(filelist)):
    if "_use" in str(filelist[i]):
        if ("Agg" in str(filelist[i]))==False:
            if filelist[i].endswith(".nd2"): #& ("60x" in str(filelist[i]))==True:
                results["filename"].append(filelist[i])
                histogram_results["filename"].append(filelist[i])
                regionprops_results["filename"].append(filelist[i])
                results["exp condition"].append(filelist[i].split('/')[-2])
                histogram_results["exp condition"].append(filelist[i].split('/')[-2])
                regionprops_results["exp condition"].append(filelist[i].split('/')[-2])
                channeldir="/".join(filelist[i].split("/")[:-2])
                exec(open(channeldir+"/channels.txt").read())
                results["earlychannelno"].append(earlychannelno)
                results["latechannelno"].append(latechannelno)
                results["synapsechannelno"].append(synapsechannelno)
                results["exp_id"].append(channeldir)
                autofdir=channeldir+"/Ctrl_Autofluorescence"
                autofdircheck=Path(channeldir+"/Ctrl_Autofluorescence")
                if autofdircheck.exists():
                    results["Autofluorescencedir"].append(autofdir)
                else:
                    results["Autofluorescencedir"].append(0) 
                results["Earlycontroldir"].append(glob.glob(channeldir+'/*_earlycontrol'))
                results["Latecontroldir"].append(glob.glob(channeldir+'/*_latecontrol'))

# %%
results["Latecontroldir"][150]
# Out:
# ['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Livectrl_onlysecondcolour_1day_latecontrol']

# %% [markdown]
# ### Find the spots: Segmentation masked made by adaptive thresholding followed by binary morphology
# #### Play with sigma gauss and i (struct shape) to optimize first

# %%
fig=plt.figure(figsize=(20,50))
figno=1
for im in range(0,3):
    randomno=np.random.randint(1,len(results["filename"]))
    early_channel_no=results["earlychannelno"][randomno]
    late_channel_no=results["latechannelno"][randomno]
    synapse_channel_no=results["synapsechannelno"][randomno]
    with ND2Reader(results["filename"][randomno]) as images:
        print(results["filename"][randomno])
        early_image=images[early_channel_no-1]
        late_image=images[late_channel_no-1]
        if synapse_channel_no>0:
            synapse_image=images[synapse_channel_no-1]
            [channel1name, channel2name, channel3name]=early_image.metadata['channels']
            if early_channel_no==1:
                early_channelname=channel1name
                if late_channel_no==2:
                    late_channelname=channel2name
                    synapse_channelname=channel3name
                else:
                    late_channelname=channel3name
                    synapse_channelname=channel2name
            if early_channel_no==2:
                early_channelname=channel2name
                if late_channel_no==3:
                    late_channelname=channel3name
                    synapse_channelname=channel1name
                else:
                    late_channelname=channel1name
                    synapse_channelname=channel3name
            if early_channel_no==3:
                early_channelname=channel3name
                if late_channel_no==2:
                    late_channelname=channel2name
                    synapse_channelname=channel1name
                else:
                    late_channelname=channel1name
                    synapse_channelname=channel2name
        else:
            synapse_image=np.zeros((512,512))        
            [channel1name, channel2name]=early_image.metadata['channels']
        if early_channel_no==1:
            early_channelname=channel1name
            late_channelname=channel2name
        else:
            early_channelname=channel2name
            late_channelname=channel1name
            synapse_channelname='No staining'
    #smoothing with gaussian filter for noise reduction
    #can play with sigma
    sigmagauss=2 #should be roughly half the size of the object you are detecting
    early_smooth = ndi.filters.gaussian_filter(early_image,sigmagauss)
    late_smooth = ndi.filters.gaussian_filter(late_image,sigmagauss)
    synapse_smooth=ndi.filters.gaussian_filter(synapse_image,sigmagauss)
    #adaptive thresholding - bg found by mean filter with SE
    istruct=51 #for SE
    struct = (np.mgrid[:istruct,:istruct][0] - np.floor(istruct/2))**2 + (np.mgrid[:istruct,:istruct][1] - np.floor(istruct/2))**2 <= np.floor(istruct/2)**2
    bg_early = rank.mean(early_smooth, selem=struct)
    bg_late = rank.mean(late_smooth, selem=struct)
    bg_synapse = rank.mean(synapse_smooth, selem=struct)
    early_denoised = early_smooth >= bg_early
    late_denoised= late_smooth >= bg_late
    synapse_denoised = synapse_smooth >= bg_synapse
    
    early_not_toobright=np.logical_not(ndi.morphology.binary_dilation(early_image>np.percentile(early_image,99),iterations=5))
    late_not_toobright=np.logical_not(ndi.morphology.binary_dilation(late_image>np.percentile(late_image,99),iterations=5))
    synapse_not_toobright=np.logical_not(ndi.morphology.binary_dilation(synapse_image>np.percentile(synapse_image,99),iterations=3))

    #final spots
    early_spots=early_not_toobright & early_denoised
    late_spots=late_not_toobright & late_denoised
    synapse_spots=synapse_not_toobright & synapse_denoised
    lateplusearly_spots = np.add(late_spots,early_spots)
    lateplusearly_spots[lateplusearly_spots==2]=1

    #figures    
    fig.add_subplot(6,4,figno)
    plt.imshow(early_image,interpolation='none',cmap='hot',vmin=1.5*early_image.min(),vmax=0.95*early_image.max())
    plt.title('Early raw: '+early_channelname)
    ax=plt.gca()
    ax.grid(color='none')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    fig.add_subplot(6,4,figno+1)
    plt.imshow(late_image,interpolation='none',cmap='hot')
    plt.title('Late raw: '+late_channelname)
    ax=plt.gca()
    ax.grid(color='none')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    fig.add_subplot(6,4,figno+2)
    plt.imshow(synapse_image,interpolation='none',cmap='hot')
    plt.title('Synapse raw: '+synapse_channelname)
    ax=plt.gca()
    ax.grid(color='none')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    fig.add_subplot(6,4,figno+4)
    plt.imshow(early_spots,interpolation='none',cmap='gray')
    plt.title('Early spots')
    ax=plt.gca()
    ax.grid(color='none')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    fig.add_subplot(6,4,figno+5)
    plt.imshow(late_spots,interpolation='none',cmap='gray')
    plt.title('Late spots')
    ax=plt.gca()
    ax.grid(color='none')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    fig.add_subplot(6,4,figno+6)
    plt.imshow(synapse_spots,interpolation='none',cmap='gray')
    plt.title('Synapse spots')
    ax=plt.gca()
    ax.grid(color='none')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    fig.add_subplot(6,4,figno+7)
    plt.imshow(lateplusearly_spots,interpolation='none',cmap='gray')
    plt.title('Early plus Late spots')
    ax=plt.gca()
    ax.grid(color='none')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    figno=figno+8
# Out:
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180705_Turnover_Bic_TNR_Timepoints_nb580first_635second_use/12hr_Bic/20180705_19_011.nd2
# /anaconda3/lib/python3.6/site-packages/skimage/filters/rank/generic.py:102: UserWarning: Bitdepth of 12 may result in bad rank filter performance due to large number of bins.
#   "performance due to large number of bins." % bitdepth)
# /anaconda3/lib/python3.6/site-packages/skimage/filters/rank/generic.py:102: UserWarning: Bitdepth of 13 may result in bad rank filter performance due to large number of bins.
#   "performance due to large number of bins." % bitdepth)
# /anaconda3/lib/python3.6/site-packages/skimage/filters/rank/generic.py:102: UserWarning: Bitdepth of 11 may result in bad rank filter performance due to large number of bins.
#   "performance due to large number of bins." % bitdepth)
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180620_Turnover_Bic_TNR_Timepoints_nb635first_580second_use/Fixedctrl_early_immediatemount_earlycontrol/20180620_02_2_003.nd2
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/3DayBic/10_60x_014.nd2
# /anaconda3/lib/python3.6/site-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))

# %% [markdown]
# #### After optimizing, run below to make segmentation masks for all images

# %%
print('Total number of images: ' + str(len(results['filename'])))

for im in range(0,len(results["filename"])): 
#for im in range(1672,len(results["filename"])): 
    print('Calculating image no ' + str(im+1) + 'of ' + str(len(results['filename'])))
    early_channel_no=results["earlychannelno"][im]
    late_channel_no=results["latechannelno"][im]
    synapse_channel_no=results["synapsechannelno"][im]
    with ND2Reader(results["filename"][im]) as images:
        early_image=images[early_channel_no-1]
        late_image=images[late_channel_no-1]
        if synapse_channel_no>0:
            synapse_image=images[synapse_channel_no-1]
        else:
            synapse_image=np.zeros((512,512))       
    #smoothing with gaussian filter for noise reduction
    early_smooth = ndi.filters.gaussian_filter(early_image,sigmagauss)
    late_smooth = ndi.filters.gaussian_filter(late_image,sigmagauss)
    synapse_smooth=ndi.filters.gaussian_filter(synapse_image,sigmagauss)
    #adaptive thresholding - bg found by mean filter with SE
    struct = (np.mgrid[:istruct,:istruct][0] - np.floor(istruct/2))**2 + (np.mgrid[:istruct,:istruct][1] - np.floor(istruct/2))**2 <= np.floor(istruct/2)**2
    bg_early = rank.mean(early_smooth, selem=struct)
    bg_late = rank.mean(late_smooth, selem=struct)
    bg_synapse = rank.mean(synapse_smooth, selem=struct)
    early_denoised = early_smooth >= bg_early
    late_denoised= late_smooth >= bg_late
    synapse_denoised = synapse_smooth >= bg_synapse
    
    early_not_toobright=np.logical_not(ndi.morphology.binary_dilation(early_image>np.percentile(early_image,99),iterations=5))
    late_not_toobright=np.logical_not(ndi.morphology.binary_dilation(late_image>np.percentile(late_image,99),iterations=5))
    synapse_not_toobright=np.logical_not(ndi.morphology.binary_dilation(synapse_image>np.percentile(synapse_image,99),iterations=3))

    #final spots
    early_spots=early_not_toobright & early_denoised
    late_spots=late_not_toobright & late_denoised
    synapse_spots=synapse_not_toobright & synapse_denoised
    lateplusearly_spots = np.add(late_spots,early_spots)
    lateplusearly_spots[lateplusearly_spots==2]=1
    
    results["Early colour - spots mask"].append(early_spots)
    results["Late colour - spots mask"].append(late_spots)
    results["Synapse colour - spots mask"].append(synapse_spots)
    results["Late plus early colour - spots mask"].append(lateplusearly_spots)          
os.system('say "Segmentation complete"')
# Out:
# Total number of images: 1912
# Calculating image no 1of 1912
# /anaconda3/lib/python3.6/site-packages/skimage/filters/rank/generic.py:102: UserWarning: Bitdepth of 11 may result in bad rank filter performance due to large number of bins.
#   "performance due to large number of bins." % bitdepth)
# /anaconda3/lib/python3.6/site-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# Calculating image no 2of 1912
# /anaconda3/lib/python3.6/site-packages/skimage/filters/rank/generic.py:102: UserWarning: Bitdepth of 12 may result in bad rank filter performance due to large number of bins.
#   "performance due to large number of bins." % bitdepth)
# Calculating image no 3of 1912
# Calculating image no 4of 1912
# Calculating image no 5of 1912
# Calculating image no 6of 1912
# Calculating image no 7of 1912
# Calculating image no 8of 1912
# Calculating image no 9of 1912
# Calculating image no 10of 1912
# Calculating image no 11of 1912
# Calculating image no 12of 1912
# Calculating image no 13of 1912
# Calculating image no 14of 1912
# Calculating image no 15of 1912
# Calculating image no 16of 1912
# Calculating image no 17of 1912
# Calculating image no 18of 1912
# Calculating image no 19of 1912
# Calculating image no 20of 1912
# Calculating image no 21of 1912
# Calculating image no 22of 1912
# Calculating image no 23of 1912
# Calculating image no 24of 1912
# Calculating image no 25of 1912
# Calculating image no 26of 1912
# Calculating image no 27of 1912
# /anaconda3/lib/python3.6/site-packages/skimage/filters/rank/generic.py:102: UserWarning: Bitdepth of 13 may result in bad rank filter performance due to large number of bins.
#   "performance due to large number of bins." % bitdepth)
# Calculating image no 28of 1912
# Calculating image no 29of 1912
# Calculating image no 30of 1912
# Calculating image no 31of 1912
# Calculating image no 32of 1912
# Calculating image no 33of 1912
# Calculating image no 34of 1912
# Calculating image no 35of 1912
# Calculating image no 36of 1912
# Calculating image no 37of 1912
# Calculating image no 38of 1912
# Calculating image no 39of 1912
# Calculating image no 40of 1912
# Calculating image no 41of 1912
# Calculating image no 42of 1912
# Calculating image no 43of 1912
# Calculating image no 44of 1912
# Calculating image no 45of 1912
# Calculating image no 46of 1912
# Calculating image no 47of 1912
# Calculating image no 48of 1912
# Calculating image no 49of 1912
# Calculating image no 50of 1912
# Calculating image no 51of 1912
# Calculating image no 52of 1912
# Calculating image no 53of 1912
# Calculating image no 54of 1912
# Calculating image no 55of 1912
# Calculating image no 56of 1912
# Calculating image no 57of 1912
# Calculating image no 58of 1912
# Calculating image no 59of 1912
# Calculating image no 60of 1912
# Calculating image no 61of 1912
# Calculating image no 62of 1912
# Calculating image no 63of 1912
# Calculating image no 64of 1912
# Calculating image no 65of 1912
# Calculating image no 66of 1912
# Calculating image no 67of 1912
# Calculating image no 68of 1912
# Calculating image no 69of 1912
# Calculating image no 70of 1912
# Calculating image no 71of 1912
# Calculating image no 72of 1912
# Calculating image no 73of 1912
# Calculating image no 74of 1912
# Calculating image no 75of 1912
# Calculating image no 76of 1912
# Calculating image no 77of 1912
# Calculating image no 78of 1912
# Calculating image no 79of 1912
# Calculating image no 80of 1912
# Calculating image no 81of 1912
# Calculating image no 82of 1912
# Calculating image no 83of 1912
# Calculating image no 84of 1912
# Calculating image no 85of 1912
# Calculating image no 86of 1912
# Calculating image no 87of 1912
# Calculating image no 88of 1912
# Calculating image no 89of 1912
# Calculating image no 90of 1912
# Calculating image no 91of 1912
# Calculating image no 92of 1912
# Calculating image no 93of 1912
# Calculating image no 94of 1912
# Calculating image no 95of 1912
# Calculating image no 96of 1912
# Calculating image no 97of 1912
# Calculating image no 98of 1912
# Calculating image no 99of 1912
# Calculating image no 100of 1912
# Calculating image no 101of 1912
# Calculating image no 102of 1912
# Calculating image no 103of 1912
# Calculating image no 104of 1912
# Calculating image no 105of 1912
# Calculating image no 106of 1912
# Calculating image no 107of 1912
# Calculating image no 108of 1912
# Calculating image no 109of 1912
# Calculating image no 110of 1912
# Calculating image no 111of 1912
# Calculating image no 112of 1912
# Calculating image no 113of 1912
# Calculating image no 114of 1912
# Calculating image no 115of 1912
# Calculating image no 116of 1912
# Calculating image no 117of 1912
# Calculating image no 118of 1912
# Calculating image no 119of 1912
# Calculating image no 120of 1912
# Calculating image no 121of 1912
# Calculating image no 122of 1912
# Calculating image no 123of 1912
# Calculating image no 124of 1912
# Calculating image no 125of 1912
# Calculating image no 126of 1912
# Calculating image no 127of 1912
# Calculating image no 128of 1912
# Calculating image no 129of 1912
# Calculating image no 130of 1912
# Calculating image no 131of 1912
# Calculating image no 132of 1912
# Calculating image no 133of 1912
# Calculating image no 134of 1912
# Calculating image no 135of 1912
# Calculating image no 136of 1912
# Calculating image no 137of 1912
# Calculating image no 138of 1912
# Calculating image no 139of 1912
# Calculating image no 140of 1912
# Calculating image no 141of 1912
# Calculating image no 142of 1912
# Calculating image no 143of 1912
# Calculating image no 144of 1912
# Calculating image no 145of 1912
# Calculating image no 146of 1912
# Calculating image no 147of 1912
# Calculating image no 148of 1912
# Calculating image no 149of 1912
# Calculating image no 150of 1912
# Calculating image no 151of 1912
# Calculating image no 152of 1912
# Calculating image no 153of 1912
# Calculating image no 154of 1912
# Calculating image no 155of 1912
# Calculating image no 156of 1912
# Calculating image no 157of 1912
# Calculating image no 158of 1912
# Calculating image no 159of 1912
# Calculating image no 160of 1912
# Calculating image no 161of 1912
# Calculating image no 162of 1912
# Calculating image no 163of 1912
# Calculating image no 164of 1912
# Calculating image no 165of 1912
# Calculating image no 166of 1912
# Calculating image no 167of 1912
# Calculating image no 168of 1912
# Calculating image no 169of 1912
# Calculating image no 170of 1912
# Calculating image no 171of 1912
# Calculating image no 172of 1912
# Calculating image no 173of 1912
# Calculating image no 174of 1912
# Calculating image no 175of 1912
# Calculating image no 176of 1912
# Calculating image no 177of 1912
# Calculating image no 178of 1912
# Calculating image no 179of 1912
# Calculating image no 180of 1912
# Calculating image no 181of 1912
# Calculating image no 182of 1912
# Calculating image no 183of 1912
# Calculating image no 184of 1912
# Calculating image no 185of 1912
# Calculating image no 186of 1912
# Calculating image no 187of 1912
# Calculating image no 188of 1912
# Calculating image no 189of 1912
# Calculating image no 190of 1912
# Calculating image no 191of 1912
# Calculating image no 192of 1912
# Calculating image no 193of 1912
# Calculating image no 194of 1912
# Calculating image no 195of 1912
# Calculating image no 196of 1912
# Calculating image no 197of 1912
# Calculating image no 198of 1912
# Calculating image no 199of 1912
# Calculating image no 200of 1912
# Calculating image no 201of 1912
# Calculating image no 202of 1912
# Calculating image no 203of 1912
# Calculating image no 204of 1912
# Calculating image no 205of 1912
# Calculating image no 206of 1912
# Calculating image no 207of 1912
# Calculating image no 208of 1912
# Calculating image no 209of 1912
# Calculating image no 210of 1912
# Calculating image no 211of 1912
# Calculating image no 212of 1912
# Calculating image no 213of 1912
# Calculating image no 214of 1912
# Calculating image no 215of 1912
# Calculating image no 216of 1912
# Calculating image no 217of 1912
# Calculating image no 218of 1912
# Calculating image no 219of 1912
# Calculating image no 220of 1912
# Calculating image no 221of 1912
# Calculating image no 222of 1912
# Calculating image no 223of 1912
# Calculating image no 224of 1912
# Calculating image no 225of 1912
# Calculating image no 226of 1912
# Calculating image no 227of 1912
# Calculating image no 228of 1912
# Calculating image no 229of 1912
# Calculating image no 230of 1912
# Calculating image no 231of 1912
# Calculating image no 232of 1912
# Calculating image no 233of 1912
# Calculating image no 234of 1912
# Calculating image no 235of 1912
# Calculating image no 236of 1912
# Calculating image no 237of 1912
# Calculating image no 238of 1912
# Calculating image no 239of 1912
# Calculating image no 240of 1912
# Calculating image no 241of 1912
# Calculating image no 242of 1912
# Calculating image no 243of 1912
# Calculating image no 244of 1912
# Calculating image no 245of 1912
# Calculating image no 246of 1912
# Calculating image no 247of 1912
# Calculating image no 248of 1912
# Calculating image no 249of 1912
# Calculating image no 250of 1912
# Calculating image no 251of 1912
# Calculating image no 252of 1912
# Calculating image no 253of 1912
# Calculating image no 254of 1912
# Calculating image no 255of 1912
# Calculating image no 256of 1912
# Calculating image no 257of 1912
# Calculating image no 258of 1912
# Calculating image no 259of 1912
# Calculating image no 260of 1912
# Calculating image no 261of 1912
# Calculating image no 262of 1912
# Calculating image no 263of 1912
# Calculating image no 264of 1912
# Calculating image no 265of 1912
# Calculating image no 266of 1912
# Calculating image no 267of 1912
# Calculating image no 268of 1912
# Calculating image no 269of 1912
# Calculating image no 270of 1912
# Calculating image no 271of 1912
# Calculating image no 272of 1912
# Calculating image no 273of 1912
# Calculating image no 274of 1912
# Calculating image no 275of 1912
# Calculating image no 276of 1912
# Calculating image no 277of 1912
# Calculating image no 278of 1912
# Calculating image no 279of 1912
# Calculating image no 280of 1912
# Calculating image no 281of 1912
# Calculating image no 282of 1912
# Calculating image no 283of 1912
# Calculating image no 284of 1912
# Calculating image no 285of 1912
# Calculating image no 286of 1912
# Calculating image no 287of 1912
# Calculating image no 288of 1912
# Calculating image no 289of 1912
# Calculating image no 290of 1912
# Calculating image no 291of 1912
# Calculating image no 292of 1912
# Calculating image no 293of 1912
# Calculating image no 294of 1912
# Calculating image no 295of 1912
# Calculating image no 296of 1912
# Calculating image no 297of 1912
# Calculating image no 298of 1912
# Calculating image no 299of 1912
# Calculating image no 300of 1912
# Calculating image no 301of 1912
# Calculating image no 302of 1912
# Calculating image no 303of 1912
# Calculating image no 304of 1912
# Calculating image no 305of 1912
# Calculating image no 306of 1912
# Calculating image no 307of 1912
# Calculating image no 308of 1912
# Calculating image no 309of 1912
# Calculating image no 310of 1912
# Calculating image no 311of 1912
# Calculating image no 312of 1912
# Calculating image no 313of 1912
# Calculating image no 314of 1912
# Calculating image no 315of 1912
# Calculating image no 316of 1912
# Calculating image no 317of 1912
# Calculating image no 318of 1912
# Calculating image no 319of 1912
# Calculating image no 320of 1912
# Calculating image no 321of 1912
# Calculating image no 322of 1912
# Calculating image no 323of 1912
# Calculating image no 324of 1912
# Calculating image no 325of 1912
# Calculating image no 326of 1912
# Calculating image no 327of 1912
# Calculating image no 328of 1912
# Calculating image no 329of 1912
# Calculating image no 330of 1912
# Calculating image no 331of 1912
# Calculating image no 332of 1912
# Calculating image no 333of 1912
# Calculating image no 334of 1912
# Calculating image no 335of 1912
# Calculating image no 336of 1912
# Calculating image no 337of 1912
# Calculating image no 338of 1912
# Calculating image no 339of 1912
# Calculating image no 340of 1912
# Calculating image no 341of 1912
# Calculating image no 342of 1912
# Calculating image no 343of 1912
# Calculating image no 344of 1912
# Calculating image no 345of 1912
# Calculating image no 346of 1912
# Calculating image no 347of 1912
# Calculating image no 348of 1912
# Calculating image no 349of 1912
# Calculating image no 350of 1912
# Calculating image no 351of 1912
# Calculating image no 352of 1912
# Calculating image no 353of 1912
# Calculating image no 354of 1912
# Calculating image no 355of 1912
# Calculating image no 356of 1912
# Calculating image no 357of 1912
# Calculating image no 358of 1912
# Calculating image no 359of 1912
# Calculating image no 360of 1912
# Calculating image no 361of 1912
# Calculating image no 362of 1912
# Calculating image no 363of 1912
# Calculating image no 364of 1912
# Calculating image no 365of 1912
# Calculating image no 366of 1912
# Calculating image no 367of 1912
# Calculating image no 368of 1912
# Calculating image no 369of 1912
# Calculating image no 370of 1912
# Calculating image no 371of 1912
# Calculating image no 372of 1912
# Calculating image no 373of 1912
# Calculating image no 374of 1912
# Calculating image no 375of 1912
# Calculating image no 376of 1912
# Calculating image no 377of 1912
# Calculating image no 378of 1912
# Calculating image no 379of 1912
# Calculating image no 380of 1912
# Calculating image no 381of 1912
# Calculating image no 382of 1912
# Calculating image no 383of 1912
# Calculating image no 384of 1912
# Calculating image no 385of 1912
# Calculating image no 386of 1912
# Calculating image no 387of 1912
# Calculating image no 388of 1912
# Calculating image no 389of 1912
# Calculating image no 390of 1912
# Calculating image no 391of 1912
# Calculating image no 392of 1912
# Calculating image no 393of 1912
# Calculating image no 394of 1912
# Calculating image no 395of 1912
# Calculating image no 396of 1912
# Calculating image no 397of 1912
# Calculating image no 398of 1912
# Calculating image no 399of 1912
# Calculating image no 400of 1912
# Calculating image no 401of 1912
# Calculating image no 402of 1912
# Calculating image no 403of 1912
# Calculating image no 404of 1912
# Calculating image no 405of 1912
# Calculating image no 406of 1912
# Calculating image no 407of 1912
# Calculating image no 408of 1912
# Calculating image no 409of 1912
# Calculating image no 410of 1912
# Calculating image no 411of 1912
# Calculating image no 412of 1912
# Calculating image no 413of 1912
# Calculating image no 414of 1912
# Calculating image no 415of 1912
# Calculating image no 416of 1912
# Calculating image no 417of 1912
# Calculating image no 418of 1912
# Calculating image no 419of 1912
# Calculating image no 420of 1912
# Calculating image no 421of 1912
# Calculating image no 422of 1912
# Calculating image no 423of 1912
# Calculating image no 424of 1912
# Calculating image no 425of 1912
# Calculating image no 426of 1912
# Calculating image no 427of 1912
# Calculating image no 428of 1912
# Calculating image no 429of 1912
# Calculating image no 430of 1912
# Calculating image no 431of 1912
# Calculating image no 432of 1912
# Calculating image no 433of 1912
# Calculating image no 434of 1912
# Calculating image no 435of 1912
# Calculating image no 436of 1912
# Calculating image no 437of 1912
# Calculating image no 438of 1912
# Calculating image no 439of 1912
# Calculating image no 440of 1912
# Calculating image no 441of 1912
# Calculating image no 442of 1912
# Calculating image no 443of 1912
# Calculating image no 444of 1912
# Calculating image no 445of 1912
# Calculating image no 446of 1912
# Calculating image no 447of 1912
# Calculating image no 448of 1912
# Calculating image no 449of 1912
# Calculating image no 450of 1912
# Calculating image no 451of 1912
# Calculating image no 452of 1912
# Calculating image no 453of 1912
# Calculating image no 454of 1912
# Calculating image no 455of 1912
# Calculating image no 456of 1912
# Calculating image no 457of 1912
# Calculating image no 458of 1912
# Calculating image no 459of 1912
# Calculating image no 460of 1912
# Calculating image no 461of 1912
# Calculating image no 462of 1912
# Calculating image no 463of 1912
# Calculating image no 464of 1912
# Calculating image no 465of 1912
# Calculating image no 466of 1912
# Calculating image no 467of 1912
# Calculating image no 468of 1912
# Calculating image no 469of 1912
# Calculating image no 470of 1912
# Calculating image no 471of 1912
# Calculating image no 472of 1912
# Calculating image no 473of 1912
# Calculating image no 474of 1912
# Calculating image no 475of 1912
# Calculating image no 476of 1912
# Calculating image no 477of 1912
# Calculating image no 478of 1912
# Calculating image no 479of 1912
# Calculating image no 480of 1912
# Calculating image no 481of 1912
# Calculating image no 482of 1912
# Calculating image no 483of 1912
# Calculating image no 484of 1912
# Calculating image no 485of 1912
# Calculating image no 486of 1912
# Calculating image no 487of 1912
# Calculating image no 488of 1912
# Calculating image no 489of 1912
# Calculating image no 490of 1912
# Calculating image no 491of 1912
# Calculating image no 492of 1912
# Calculating image no 493of 1912
# Calculating image no 494of 1912
# Calculating image no 495of 1912
# Calculating image no 496of 1912
# Calculating image no 497of 1912
# Calculating image no 498of 1912
# Calculating image no 499of 1912
# Calculating image no 500of 1912
# Calculating image no 501of 1912
# Calculating image no 502of 1912
# Calculating image no 503of 1912
# Calculating image no 504of 1912
# Calculating image no 505of 1912
# Calculating image no 506of 1912
# Calculating image no 507of 1912
# Calculating image no 508of 1912
# Calculating image no 509of 1912
# Calculating image no 510of 1912
# Calculating image no 511of 1912
# Calculating image no 512of 1912
# Calculating image no 513of 1912
# Calculating image no 514of 1912
# Calculating image no 515of 1912
# Calculating image no 516of 1912
# Calculating image no 517of 1912
# Calculating image no 518of 1912
# Calculating image no 519of 1912
# Calculating image no 520of 1912
# Calculating image no 521of 1912
# Calculating image no 522of 1912
# Calculating image no 523of 1912
# Calculating image no 524of 1912
# Calculating image no 525of 1912
# Calculating image no 526of 1912
# Calculating image no 527of 1912
# Calculating image no 528of 1912
# Calculating image no 529of 1912
# Calculating image no 530of 1912
# Calculating image no 531of 1912
# Calculating image no 532of 1912
# Calculating image no 533of 1912
# Calculating image no 534of 1912
# Calculating image no 535of 1912
# Calculating image no 536of 1912
# Calculating image no 537of 1912
# Calculating image no 538of 1912
# Calculating image no 539of 1912
# Calculating image no 540of 1912
# Calculating image no 541of 1912
# Calculating image no 542of 1912
# Calculating image no 543of 1912
# Calculating image no 544of 1912
# Calculating image no 545of 1912
# Calculating image no 546of 1912
# Calculating image no 547of 1912
# Calculating image no 548of 1912
# Calculating image no 549of 1912
# Calculating image no 550of 1912
# Calculating image no 551of 1912
# Calculating image no 552of 1912
# Calculating image no 553of 1912
# Calculating image no 554of 1912
# Calculating image no 555of 1912
# Calculating image no 556of 1912
# Calculating image no 557of 1912
# Calculating image no 558of 1912
# Calculating image no 559of 1912
# Calculating image no 560of 1912
# Calculating image no 561of 1912
# Calculating image no 562of 1912
# Calculating image no 563of 1912
# Calculating image no 564of 1912
# Calculating image no 565of 1912
# Calculating image no 566of 1912
# Calculating image no 567of 1912
# Calculating image no 568of 1912
# Calculating image no 569of 1912
# Calculating image no 570of 1912
# Calculating image no 571of 1912
# Calculating image no 572of 1912
# Calculating image no 573of 1912
# Calculating image no 574of 1912
# Calculating image no 575of 1912
# Calculating image no 576of 1912
# Calculating image no 577of 1912
# Calculating image no 578of 1912
# Calculating image no 579of 1912
# Calculating image no 580of 1912
# Calculating image no 581of 1912
# Calculating image no 582of 1912
# Calculating image no 583of 1912
# Calculating image no 584of 1912
# Calculating image no 585of 1912
# Calculating image no 586of 1912
# Calculating image no 587of 1912
# Calculating image no 588of 1912
# Calculating image no 589of 1912
# Calculating image no 590of 1912
# Calculating image no 591of 1912
# Calculating image no 592of 1912
# Calculating image no 593of 1912
# Calculating image no 594of 1912
# Calculating image no 595of 1912
# Calculating image no 596of 1912
# Calculating image no 597of 1912
# Calculating image no 598of 1912
# Calculating image no 599of 1912
# Calculating image no 600of 1912
# Calculating image no 601of 1912
# Calculating image no 602of 1912
# Calculating image no 603of 1912
# Calculating image no 604of 1912
# Calculating image no 605of 1912
# Calculating image no 606of 1912
# Calculating image no 607of 1912
# Calculating image no 608of 1912
# Calculating image no 609of 1912
# Calculating image no 610of 1912
# Calculating image no 611of 1912
# Calculating image no 612of 1912
# Calculating image no 613of 1912
# Calculating image no 614of 1912
# Calculating image no 615of 1912
# Calculating image no 616of 1912
# Calculating image no 617of 1912
# Calculating image no 618of 1912
# Calculating image no 619of 1912
# Calculating image no 620of 1912
# Calculating image no 621of 1912
# Calculating image no 622of 1912
# Calculating image no 623of 1912
# Calculating image no 624of 1912
# Calculating image no 625of 1912
# Calculating image no 626of 1912
# Calculating image no 627of 1912
# Calculating image no 628of 1912
# Calculating image no 629of 1912
# Calculating image no 630of 1912
# Calculating image no 631of 1912
# Calculating image no 632of 1912
# Calculating image no 633of 1912
# Calculating image no 634of 1912
# Calculating image no 635of 1912
# Calculating image no 636of 1912
# Calculating image no 637of 1912
# Calculating image no 638of 1912
# Calculating image no 639of 1912
# Calculating image no 640of 1912
# Calculating image no 641of 1912
# Calculating image no 642of 1912
# Calculating image no 643of 1912
# Calculating image no 644of 1912
# Calculating image no 645of 1912
# Calculating image no 646of 1912
# Calculating image no 647of 1912
# Calculating image no 648of 1912
# Calculating image no 649of 1912
# Calculating image no 650of 1912
# Calculating image no 651of 1912
# Calculating image no 652of 1912
# Calculating image no 653of 1912
# Calculating image no 654of 1912
# Calculating image no 655of 1912
# Calculating image no 656of 1912
# Calculating image no 657of 1912
# Calculating image no 658of 1912
# Calculating image no 659of 1912
# Calculating image no 660of 1912
# Calculating image no 661of 1912
# Calculating image no 662of 1912
# Calculating image no 663of 1912
# Calculating image no 664of 1912
# Calculating image no 665of 1912
# Calculating image no 666of 1912
# Calculating image no 667of 1912
# Calculating image no 668of 1912
# Calculating image no 669of 1912
# Calculating image no 670of 1912
# Calculating image no 671of 1912
# Calculating image no 672of 1912
# Calculating image no 673of 1912
# Calculating image no 674of 1912
# Calculating image no 675of 1912
# Calculating image no 676of 1912
# Calculating image no 677of 1912
# Calculating image no 678of 1912
# Calculating image no 679of 1912
# Calculating image no 680of 1912
# Calculating image no 681of 1912
# Calculating image no 682of 1912
# Calculating image no 683of 1912
# Calculating image no 684of 1912
# Calculating image no 685of 1912
# Calculating image no 686of 1912
# Calculating image no 687of 1912
# Calculating image no 688of 1912
# Calculating image no 689of 1912
# Calculating image no 690of 1912
# Calculating image no 691of 1912
# Calculating image no 692of 1912
# Calculating image no 693of 1912
# Calculating image no 694of 1912
# Calculating image no 695of 1912
# Calculating image no 696of 1912
# Calculating image no 697of 1912
# Calculating image no 698of 1912
# Calculating image no 699of 1912
# Calculating image no 700of 1912
# Calculating image no 701of 1912
# Calculating image no 702of 1912
# Calculating image no 703of 1912
# Calculating image no 704of 1912
# Calculating image no 705of 1912
# Calculating image no 706of 1912
# Calculating image no 707of 1912
# Calculating image no 708of 1912
# Calculating image no 709of 1912
# Calculating image no 710of 1912
# Calculating image no 711of 1912
# Calculating image no 712of 1912
# Calculating image no 713of 1912
# Calculating image no 714of 1912
# Calculating image no 715of 1912
# Calculating image no 716of 1912
# Calculating image no 717of 1912
# Calculating image no 718of 1912
# Calculating image no 719of 1912
# Calculating image no 720of 1912
# Calculating image no 721of 1912
# Calculating image no 722of 1912
# Calculating image no 723of 1912
# Calculating image no 724of 1912
# Calculating image no 725of 1912
# Calculating image no 726of 1912
# Calculating image no 727of 1912
# Calculating image no 728of 1912
# Calculating image no 729of 1912
# Calculating image no 730of 1912
# Calculating image no 731of 1912
# Calculating image no 732of 1912
# Calculating image no 733of 1912
# Calculating image no 734of 1912
# Calculating image no 735of 1912
# Calculating image no 736of 1912
# Calculating image no 737of 1912
# Calculating image no 738of 1912
# Calculating image no 739of 1912
# Calculating image no 740of 1912
# Calculating image no 741of 1912
# Calculating image no 742of 1912
# Calculating image no 743of 1912
# Calculating image no 744of 1912
# Calculating image no 745of 1912
# Calculating image no 746of 1912
# Calculating image no 747of 1912
# Calculating image no 748of 1912
# Calculating image no 749of 1912
# Calculating image no 750of 1912
# Calculating image no 751of 1912
# Calculating image no 752of 1912
# Calculating image no 753of 1912
# Calculating image no 754of 1912
# Calculating image no 755of 1912
# Calculating image no 756of 1912
# Calculating image no 757of 1912
# Calculating image no 758of 1912
# Calculating image no 759of 1912
# Calculating image no 760of 1912
# Calculating image no 761of 1912
# Calculating image no 762of 1912
# Calculating image no 763of 1912
# Calculating image no 764of 1912
# Calculating image no 765of 1912
# Calculating image no 766of 1912
# Calculating image no 767of 1912
# Calculating image no 768of 1912
# Calculating image no 769of 1912
# Calculating image no 770of 1912
# Calculating image no 771of 1912
# Calculating image no 772of 1912
# Calculating image no 773of 1912
# Calculating image no 774of 1912
# Calculating image no 775of 1912
# Calculating image no 776of 1912
# Calculating image no 777of 1912
# Calculating image no 778of 1912
# Calculating image no 779of 1912
# Calculating image no 780of 1912
# Calculating image no 781of 1912
# Calculating image no 782of 1912
# Calculating image no 783of 1912
# Calculating image no 784of 1912
# Calculating image no 785of 1912
# Calculating image no 786of 1912
# Calculating image no 787of 1912
# Calculating image no 788of 1912
# Calculating image no 789of 1912
# Calculating image no 790of 1912
# Calculating image no 791of 1912
# Calculating image no 792of 1912
# Calculating image no 793of 1912
# Calculating image no 794of 1912
# Calculating image no 795of 1912
# Calculating image no 796of 1912
# Calculating image no 797of 1912
# Calculating image no 798of 1912
# Calculating image no 799of 1912
# Calculating image no 800of 1912
# Calculating image no 801of 1912
# Calculating image no 802of 1912
# Calculating image no 803of 1912
# Calculating image no 804of 1912
# Calculating image no 805of 1912
# Calculating image no 806of 1912
# Calculating image no 807of 1912
# Calculating image no 808of 1912
# Calculating image no 809of 1912
# Calculating image no 810of 1912
# Calculating image no 811of 1912
# Calculating image no 812of 1912
# Calculating image no 813of 1912
# Calculating image no 814of 1912
# Calculating image no 815of 1912
# Calculating image no 816of 1912
# Calculating image no 817of 1912
# Calculating image no 818of 1912
# Calculating image no 819of 1912
# Calculating image no 820of 1912
# Calculating image no 821of 1912
# Calculating image no 822of 1912
# Calculating image no 823of 1912
# Calculating image no 824of 1912
# Calculating image no 825of 1912
# Calculating image no 826of 1912
# Calculating image no 827of 1912
# Calculating image no 828of 1912
# Calculating image no 829of 1912
# Calculating image no 830of 1912
# Calculating image no 831of 1912
# Calculating image no 832of 1912
# Calculating image no 833of 1912
# Calculating image no 834of 1912
# Calculating image no 835of 1912
# Calculating image no 836of 1912
# Calculating image no 837of 1912
# Calculating image no 838of 1912
# Calculating image no 839of 1912
# Calculating image no 840of 1912
# Calculating image no 841of 1912
# Calculating image no 842of 1912
# Calculating image no 843of 1912
# Calculating image no 844of 1912
# Calculating image no 845of 1912
# Calculating image no 846of 1912
# Calculating image no 847of 1912
# Calculating image no 848of 1912
# Calculating image no 849of 1912
# Calculating image no 850of 1912
# Calculating image no 851of 1912
# Calculating image no 852of 1912
# Calculating image no 853of 1912
# Calculating image no 854of 1912
# Calculating image no 855of 1912
# Calculating image no 856of 1912
# Calculating image no 857of 1912
# Calculating image no 858of 1912
# Calculating image no 859of 1912
# Calculating image no 860of 1912
# Calculating image no 861of 1912
# Calculating image no 862of 1912
# Calculating image no 863of 1912
# Calculating image no 864of 1912
# Calculating image no 865of 1912
# Calculating image no 866of 1912
# Calculating image no 867of 1912
# Calculating image no 868of 1912
# Calculating image no 869of 1912
# Calculating image no 870of 1912
# Calculating image no 871of 1912
# Calculating image no 872of 1912
# Calculating image no 873of 1912
# Calculating image no 874of 1912
# Calculating image no 875of 1912
# Calculating image no 876of 1912
# Calculating image no 877of 1912
# Calculating image no 878of 1912
# Calculating image no 879of 1912
# Calculating image no 880of 1912
# Calculating image no 881of 1912
# Calculating image no 882of 1912
# Calculating image no 883of 1912
# Calculating image no 884of 1912
# Calculating image no 885of 1912
# Calculating image no 886of 1912
# Calculating image no 887of 1912
# Calculating image no 888of 1912
# Calculating image no 889of 1912
# Calculating image no 890of 1912
# Calculating image no 891of 1912
# Calculating image no 892of 1912
# Calculating image no 893of 1912
# Calculating image no 894of 1912
# Calculating image no 895of 1912
# Calculating image no 896of 1912
# Calculating image no 897of 1912
# Calculating image no 898of 1912
# Calculating image no 899of 1912
# Calculating image no 900of 1912
# Calculating image no 901of 1912
# Calculating image no 902of 1912
# Calculating image no 903of 1912
# Calculating image no 904of 1912
# Calculating image no 905of 1912
# Calculating image no 906of 1912
# Calculating image no 907of 1912
# Calculating image no 908of 1912
# Calculating image no 909of 1912
# Calculating image no 910of 1912
# Calculating image no 911of 1912
# Calculating image no 912of 1912
# Calculating image no 913of 1912
# Calculating image no 914of 1912
# Calculating image no 915of 1912
# Calculating image no 916of 1912
# Calculating image no 917of 1912
# Calculating image no 918of 1912
# Calculating image no 919of 1912
# Calculating image no 920of 1912
# Calculating image no 921of 1912
# Calculating image no 922of 1912
# Calculating image no 923of 1912
# Calculating image no 924of 1912
# Calculating image no 925of 1912
# Calculating image no 926of 1912
# Calculating image no 927of 1912
# Calculating image no 928of 1912
# Calculating image no 929of 1912
# Calculating image no 930of 1912
# Calculating image no 931of 1912
# Calculating image no 932of 1912
# Calculating image no 933of 1912
# Calculating image no 934of 1912
# Calculating image no 935of 1912
# Calculating image no 936of 1912
# Calculating image no 937of 1912
# Calculating image no 938of 1912
# Calculating image no 939of 1912
# Calculating image no 940of 1912
# Calculating image no 941of 1912
# Calculating image no 942of 1912
# Calculating image no 943of 1912
# Calculating image no 944of 1912
# Calculating image no 945of 1912
# Calculating image no 946of 1912
# Calculating image no 947of 1912
# Calculating image no 948of 1912
# Calculating image no 949of 1912
# Calculating image no 950of 1912
# Calculating image no 951of 1912
# Calculating image no 952of 1912
# Calculating image no 953of 1912
# Calculating image no 954of 1912
# Calculating image no 955of 1912
# Calculating image no 956of 1912
# Calculating image no 957of 1912
# Calculating image no 958of 1912
# Calculating image no 959of 1912
# Calculating image no 960of 1912
# Calculating image no 961of 1912
# Calculating image no 962of 1912
# Calculating image no 963of 1912
# Calculating image no 964of 1912
# Calculating image no 965of 1912
# Calculating image no 966of 1912
# Calculating image no 967of 1912
# Calculating image no 968of 1912
# Calculating image no 969of 1912
# Calculating image no 970of 1912
# Calculating image no 971of 1912
# Calculating image no 972of 1912
# Calculating image no 973of 1912
# Calculating image no 974of 1912
# Calculating image no 975of 1912
# Calculating image no 976of 1912
# Calculating image no 977of 1912
# Calculating image no 978of 1912
# Calculating image no 979of 1912
# Calculating image no 980of 1912
# Calculating image no 981of 1912
# Calculating image no 982of 1912
# Calculating image no 983of 1912
# Calculating image no 984of 1912
# Calculating image no 985of 1912
# Calculating image no 986of 1912
# Calculating image no 987of 1912
# Calculating image no 988of 1912
# Calculating image no 989of 1912
# Calculating image no 990of 1912
# Calculating image no 991of 1912
# Calculating image no 992of 1912
# Calculating image no 993of 1912
# Calculating image no 994of 1912
# Calculating image no 995of 1912
# Calculating image no 996of 1912
# Calculating image no 997of 1912
# Calculating image no 998of 1912
# Calculating image no 999of 1912
# Calculating image no 1000of 1912
# Calculating image no 1001of 1912
# Calculating image no 1002of 1912
# Calculating image no 1003of 1912
# Calculating image no 1004of 1912
# Calculating image no 1005of 1912
# Calculating image no 1006of 1912
# Calculating image no 1007of 1912
# Calculating image no 1008of 1912
# Calculating image no 1009of 1912
# Calculating image no 1010of 1912
# Calculating image no 1011of 1912
# Calculating image no 1012of 1912
# Calculating image no 1013of 1912
# Calculating image no 1014of 1912
# Calculating image no 1015of 1912
# Calculating image no 1016of 1912
# Calculating image no 1017of 1912
# Calculating image no 1018of 1912
# Calculating image no 1019of 1912
# Calculating image no 1020of 1912
# Calculating image no 1021of 1912
# Calculating image no 1022of 1912
# Calculating image no 1023of 1912
# Calculating image no 1024of 1912
# Calculating image no 1025of 1912
# Calculating image no 1026of 1912
# Calculating image no 1027of 1912
# Calculating image no 1028of 1912
# Calculating image no 1029of 1912
# Calculating image no 1030of 1912
# Calculating image no 1031of 1912
# Calculating image no 1032of 1912
# Calculating image no 1033of 1912
# Calculating image no 1034of 1912
# Calculating image no 1035of 1912
# Calculating image no 1036of 1912
# Calculating image no 1037of 1912
# Calculating image no 1038of 1912
# Calculating image no 1039of 1912
# Calculating image no 1040of 1912
# Calculating image no 1041of 1912
# Calculating image no 1042of 1912
# Calculating image no 1043of 1912
# Calculating image no 1044of 1912
# Calculating image no 1045of 1912
# Calculating image no 1046of 1912
# Calculating image no 1047of 1912
# Calculating image no 1048of 1912
# Calculating image no 1049of 1912
# Calculating image no 1050of 1912
# Calculating image no 1051of 1912
# Calculating image no 1052of 1912
# Calculating image no 1053of 1912
# Calculating image no 1054of 1912
# Calculating image no 1055of 1912
# Calculating image no 1056of 1912
# Calculating image no 1057of 1912
# Calculating image no 1058of 1912
# Calculating image no 1059of 1912
# Calculating image no 1060of 1912
# Calculating image no 1061of 1912
# Calculating image no 1062of 1912
# Calculating image no 1063of 1912
# Calculating image no 1064of 1912
# Calculating image no 1065of 1912
# Calculating image no 1066of 1912
# Calculating image no 1067of 1912
# Calculating image no 1068of 1912
# Calculating image no 1069of 1912
# Calculating image no 1070of 1912
# Calculating image no 1071of 1912
# Calculating image no 1072of 1912
# Calculating image no 1073of 1912
# Calculating image no 1074of 1912
# Calculating image no 1075of 1912
# Calculating image no 1076of 1912
# Calculating image no 1077of 1912
# Calculating image no 1078of 1912
# Calculating image no 1079of 1912
# Calculating image no 1080of 1912
# Calculating image no 1081of 1912
# Calculating image no 1082of 1912
# Calculating image no 1083of 1912
# Calculating image no 1084of 1912
# Calculating image no 1085of 1912
# Calculating image no 1086of 1912
# Calculating image no 1087of 1912
# Calculating image no 1088of 1912
# Calculating image no 1089of 1912
# Calculating image no 1090of 1912
# Calculating image no 1091of 1912
# Calculating image no 1092of 1912
# Calculating image no 1093of 1912
# Calculating image no 1094of 1912
# Calculating image no 1095of 1912
# Calculating image no 1096of 1912
# Calculating image no 1097of 1912
# Calculating image no 1098of 1912
# Calculating image no 1099of 1912
# Calculating image no 1100of 1912
# Calculating image no 1101of 1912
# Calculating image no 1102of 1912
# Calculating image no 1103of 1912
# Calculating image no 1104of 1912
# Calculating image no 1105of 1912
# Calculating image no 1106of 1912
# Calculating image no 1107of 1912
# Calculating image no 1108of 1912
# Calculating image no 1109of 1912
# Calculating image no 1110of 1912
# Calculating image no 1111of 1912
# Calculating image no 1112of 1912
# Calculating image no 1113of 1912
# Calculating image no 1114of 1912
# Calculating image no 1115of 1912
# Calculating image no 1116of 1912
# Calculating image no 1117of 1912
# Calculating image no 1118of 1912
# Calculating image no 1119of 1912
# Calculating image no 1120of 1912
# Calculating image no 1121of 1912
# Calculating image no 1122of 1912
# Calculating image no 1123of 1912
# Calculating image no 1124of 1912
# Calculating image no 1125of 1912
# Calculating image no 1126of 1912
# Calculating image no 1127of 1912
# Calculating image no 1128of 1912
# Calculating image no 1129of 1912
# Calculating image no 1130of 1912
# Calculating image no 1131of 1912
# Calculating image no 1132of 1912
# Calculating image no 1133of 1912
# Calculating image no 1134of 1912
# Calculating image no 1135of 1912
# Calculating image no 1136of 1912
# Calculating image no 1137of 1912
# Calculating image no 1138of 1912
# Calculating image no 1139of 1912
# Calculating image no 1140of 1912
# Calculating image no 1141of 1912
# Calculating image no 1142of 1912
# Calculating image no 1143of 1912
# Calculating image no 1144of 1912
# Calculating image no 1145of 1912
# Calculating image no 1146of 1912
# Calculating image no 1147of 1912
# Calculating image no 1148of 1912
# Calculating image no 1149of 1912
# Calculating image no 1150of 1912
# Calculating image no 1151of 1912
# Calculating image no 1152of 1912
# Calculating image no 1153of 1912
# Calculating image no 1154of 1912
# Calculating image no 1155of 1912
# Calculating image no 1156of 1912
# Calculating image no 1157of 1912
# Calculating image no 1158of 1912
# Calculating image no 1159of 1912
# Calculating image no 1160of 1912
# Calculating image no 1161of 1912
# Calculating image no 1162of 1912
# Calculating image no 1163of 1912
# Calculating image no 1164of 1912
# Calculating image no 1165of 1912
# Calculating image no 1166of 1912
# Calculating image no 1167of 1912
# Calculating image no 1168of 1912
# Calculating image no 1169of 1912
# Calculating image no 1170of 1912
# Calculating image no 1171of 1912
# Calculating image no 1172of 1912
# Calculating image no 1173of 1912
# Calculating image no 1174of 1912
# Calculating image no 1175of 1912
# Calculating image no 1176of 1912
# Calculating image no 1177of 1912
# Calculating image no 1178of 1912
# Calculating image no 1179of 1912
# Calculating image no 1180of 1912
# Calculating image no 1181of 1912
# Calculating image no 1182of 1912
# Calculating image no 1183of 1912
# Calculating image no 1184of 1912
# Calculating image no 1185of 1912
# Calculating image no 1186of 1912
# Calculating image no 1187of 1912
# Calculating image no 1188of 1912
# Calculating image no 1189of 1912
# Calculating image no 1190of 1912
# Calculating image no 1191of 1912
# Calculating image no 1192of 1912
# Calculating image no 1193of 1912
# Calculating image no 1194of 1912
# Calculating image no 1195of 1912
# Calculating image no 1196of 1912
# Calculating image no 1197of 1912
# Calculating image no 1198of 1912
# Calculating image no 1199of 1912
# Calculating image no 1200of 1912
# Calculating image no 1201of 1912
# Calculating image no 1202of 1912
# Calculating image no 1203of 1912
# Calculating image no 1204of 1912
# Calculating image no 1205of 1912
# Calculating image no 1206of 1912
# Calculating image no 1207of 1912
# Calculating image no 1208of 1912
# Calculating image no 1209of 1912
# Calculating image no 1210of 1912
# Calculating image no 1211of 1912
# Calculating image no 1212of 1912
# Calculating image no 1213of 1912
# Calculating image no 1214of 1912
# Calculating image no 1215of 1912
# Calculating image no 1216of 1912
# Calculating image no 1217of 1912
# Calculating image no 1218of 1912
# Calculating image no 1219of 1912
# Calculating image no 1220of 1912
# Calculating image no 1221of 1912
# Calculating image no 1222of 1912
# Calculating image no 1223of 1912
# Calculating image no 1224of 1912
# Calculating image no 1225of 1912
# Calculating image no 1226of 1912
# Calculating image no 1227of 1912
# Calculating image no 1228of 1912
# Calculating image no 1229of 1912
# Calculating image no 1230of 1912
# Calculating image no 1231of 1912
# Calculating image no 1232of 1912
# Calculating image no 1233of 1912
# Calculating image no 1234of 1912
# Calculating image no 1235of 1912
# Calculating image no 1236of 1912
# Calculating image no 1237of 1912
# Calculating image no 1238of 1912
# Calculating image no 1239of 1912
# Calculating image no 1240of 1912
# Calculating image no 1241of 1912
# Calculating image no 1242of 1912
# Calculating image no 1243of 1912
# Calculating image no 1244of 1912
# Calculating image no 1245of 1912
# Calculating image no 1246of 1912
# Calculating image no 1247of 1912
# Calculating image no 1248of 1912
# Calculating image no 1249of 1912
# Calculating image no 1250of 1912
# Calculating image no 1251of 1912
# Calculating image no 1252of 1912
# Calculating image no 1253of 1912
# Calculating image no 1254of 1912
# Calculating image no 1255of 1912
# Calculating image no 1256of 1912
# Calculating image no 1257of 1912
# Calculating image no 1258of 1912
# Calculating image no 1259of 1912
# Calculating image no 1260of 1912
# Calculating image no 1261of 1912
# Calculating image no 1262of 1912
# Calculating image no 1263of 1912
# Calculating image no 1264of 1912
# Calculating image no 1265of 1912
# Calculating image no 1266of 1912
# Calculating image no 1267of 1912
# Calculating image no 1268of 1912
# Calculating image no 1269of 1912
# Calculating image no 1270of 1912
# Calculating image no 1271of 1912
# Calculating image no 1272of 1912
# Calculating image no 1273of 1912
# Calculating image no 1274of 1912
# Calculating image no 1275of 1912
# Calculating image no 1276of 1912
# Calculating image no 1277of 1912
# Calculating image no 1278of 1912
# Calculating image no 1279of 1912
# Calculating image no 1280of 1912
# Calculating image no 1281of 1912
# Calculating image no 1282of 1912
# Calculating image no 1283of 1912
# Calculating image no 1284of 1912
# Calculating image no 1285of 1912
# Calculating image no 1286of 1912
# Calculating image no 1287of 1912
# Calculating image no 1288of 1912
# Calculating image no 1289of 1912
# Calculating image no 1290of 1912
# Calculating image no 1291of 1912
# Calculating image no 1292of 1912
# Calculating image no 1293of 1912
# Calculating image no 1294of 1912
# Calculating image no 1295of 1912
# Calculating image no 1296of 1912
# Calculating image no 1297of 1912
# Calculating image no 1298of 1912
# Calculating image no 1299of 1912
# Calculating image no 1300of 1912
# Calculating image no 1301of 1912
# Calculating image no 1302of 1912
# Calculating image no 1303of 1912
# Calculating image no 1304of 1912
# Calculating image no 1305of 1912
# Calculating image no 1306of 1912
# Calculating image no 1307of 1912
# Calculating image no 1308of 1912
# Calculating image no 1309of 1912
# Calculating image no 1310of 1912
# Calculating image no 1311of 1912
# Calculating image no 1312of 1912
# Calculating image no 1313of 1912
# Calculating image no 1314of 1912
# Calculating image no 1315of 1912
# Calculating image no 1316of 1912
# Calculating image no 1317of 1912
# Calculating image no 1318of 1912
# Calculating image no 1319of 1912
# Calculating image no 1320of 1912
# Calculating image no 1321of 1912
# Calculating image no 1322of 1912
# Calculating image no 1323of 1912
# Calculating image no 1324of 1912
# Calculating image no 1325of 1912
# Calculating image no 1326of 1912
# Calculating image no 1327of 1912
# Calculating image no 1328of 1912
# Calculating image no 1329of 1912
# Calculating image no 1330of 1912
# Calculating image no 1331of 1912
# Calculating image no 1332of 1912
# Calculating image no 1333of 1912
# Calculating image no 1334of 1912
# Calculating image no 1335of 1912
# Calculating image no 1336of 1912
# Calculating image no 1337of 1912
# Calculating image no 1338of 1912
# Calculating image no 1339of 1912
# Calculating image no 1340of 1912
# Calculating image no 1341of 1912
# Calculating image no 1342of 1912
# Calculating image no 1343of 1912
# Calculating image no 1344of 1912
# Calculating image no 1345of 1912
# Calculating image no 1346of 1912
# Calculating image no 1347of 1912
# Calculating image no 1348of 1912
# Calculating image no 1349of 1912
# Calculating image no 1350of 1912
# Calculating image no 1351of 1912
# Calculating image no 1352of 1912
# Calculating image no 1353of 1912
# Calculating image no 1354of 1912
# Calculating image no 1355of 1912
# Calculating image no 1356of 1912
# Calculating image no 1357of 1912
# Calculating image no 1358of 1912
# Calculating image no 1359of 1912
# Calculating image no 1360of 1912
# Calculating image no 1361of 1912
# Calculating image no 1362of 1912
# Calculating image no 1363of 1912
# Calculating image no 1364of 1912
# Calculating image no 1365of 1912
# Calculating image no 1366of 1912
# Calculating image no 1367of 1912
# Calculating image no 1368of 1912
# Calculating image no 1369of 1912
# Calculating image no 1370of 1912
# Calculating image no 1371of 1912
# Calculating image no 1372of 1912
# Calculating image no 1373of 1912
# Calculating image no 1374of 1912
# Calculating image no 1375of 1912
# Calculating image no 1376of 1912
# Calculating image no 1377of 1912
# Calculating image no 1378of 1912
# Calculating image no 1379of 1912
# Calculating image no 1380of 1912
# Calculating image no 1381of 1912
# Calculating image no 1382of 1912
# Calculating image no 1383of 1912
# Calculating image no 1384of 1912
# Calculating image no 1385of 1912
# Calculating image no 1386of 1912
# Calculating image no 1387of 1912
# Calculating image no 1388of 1912
# Calculating image no 1389of 1912
# Calculating image no 1390of 1912
# Calculating image no 1391of 1912
# Calculating image no 1392of 1912
# Calculating image no 1393of 1912
# Calculating image no 1394of 1912
# Calculating image no 1395of 1912
# Calculating image no 1396of 1912
# Calculating image no 1397of 1912
# Calculating image no 1398of 1912
# Calculating image no 1399of 1912
# Calculating image no 1400of 1912
# Calculating image no 1401of 1912
# Calculating image no 1402of 1912
# Calculating image no 1403of 1912
# Calculating image no 1404of 1912
# Calculating image no 1405of 1912
# Calculating image no 1406of 1912
# Calculating image no 1407of 1912
# Calculating image no 1408of 1912
# Calculating image no 1409of 1912
# Calculating image no 1410of 1912
# Calculating image no 1411of 1912
# Calculating image no 1412of 1912
# Calculating image no 1413of 1912
# Calculating image no 1414of 1912
# Calculating image no 1415of 1912
# Calculating image no 1416of 1912
# Calculating image no 1417of 1912
# Calculating image no 1418of 1912
# Calculating image no 1419of 1912
# Calculating image no 1420of 1912
# Calculating image no 1421of 1912
# Calculating image no 1422of 1912
# Calculating image no 1423of 1912
# Calculating image no 1424of 1912
# Calculating image no 1425of 1912
# Calculating image no 1426of 1912
# Calculating image no 1427of 1912
# Calculating image no 1428of 1912
# Calculating image no 1429of 1912
# Calculating image no 1430of 1912
# Calculating image no 1431of 1912
# Calculating image no 1432of 1912
# Calculating image no 1433of 1912
# Calculating image no 1434of 1912
# Calculating image no 1435of 1912
# Calculating image no 1436of 1912
# Calculating image no 1437of 1912
# Calculating image no 1438of 1912
# Calculating image no 1439of 1912
# Calculating image no 1440of 1912
# Calculating image no 1441of 1912
# Calculating image no 1442of 1912
# Calculating image no 1443of 1912
# Calculating image no 1444of 1912
# Calculating image no 1445of 1912
# Calculating image no 1446of 1912
# Calculating image no 1447of 1912
# Calculating image no 1448of 1912
# Calculating image no 1449of 1912
# Calculating image no 1450of 1912
# Calculating image no 1451of 1912
# Calculating image no 1452of 1912
# Calculating image no 1453of 1912
# Calculating image no 1454of 1912
# Calculating image no 1455of 1912
# Calculating image no 1456of 1912
# Calculating image no 1457of 1912
# Calculating image no 1458of 1912
# Calculating image no 1459of 1912
# Calculating image no 1460of 1912
# Calculating image no 1461of 1912
# Calculating image no 1462of 1912
# Calculating image no 1463of 1912
# Calculating image no 1464of 1912
# Calculating image no 1465of 1912
# Calculating image no 1466of 1912
# Calculating image no 1467of 1912
# Calculating image no 1468of 1912
# Calculating image no 1469of 1912
# Calculating image no 1470of 1912
# Calculating image no 1471of 1912
# Calculating image no 1472of 1912
# Calculating image no 1473of 1912
# Calculating image no 1474of 1912
# Calculating image no 1475of 1912
# Calculating image no 1476of 1912
# Calculating image no 1477of 1912
# Calculating image no 1478of 1912
# Calculating image no 1479of 1912
# Calculating image no 1480of 1912
# Calculating image no 1481of 1912
# Calculating image no 1482of 1912
# Calculating image no 1483of 1912
# Calculating image no 1484of 1912
# Calculating image no 1485of 1912
# Calculating image no 1486of 1912
# Calculating image no 1487of 1912
# Calculating image no 1488of 1912
# Calculating image no 1489of 1912
# Calculating image no 1490of 1912
# Calculating image no 1491of 1912
# Calculating image no 1492of 1912
# Calculating image no 1493of 1912
# Calculating image no 1494of 1912
# Calculating image no 1495of 1912
# Calculating image no 1496of 1912
# Calculating image no 1497of 1912
# Calculating image no 1498of 1912
# Calculating image no 1499of 1912
# Calculating image no 1500of 1912
# Calculating image no 1501of 1912
# Calculating image no 1502of 1912
# Calculating image no 1503of 1912
# Calculating image no 1504of 1912
# Calculating image no 1505of 1912
# Calculating image no 1506of 1912
# Calculating image no 1507of 1912
# Calculating image no 1508of 1912
# Calculating image no 1509of 1912
# Calculating image no 1510of 1912
# Calculating image no 1511of 1912
# Calculating image no 1512of 1912
# Calculating image no 1513of 1912
# Calculating image no 1514of 1912
# Calculating image no 1515of 1912
# Calculating image no 1516of 1912
# Calculating image no 1517of 1912
# Calculating image no 1518of 1912
# Calculating image no 1519of 1912
# Calculating image no 1520of 1912
# Calculating image no 1521of 1912
# Calculating image no 1522of 1912
# Calculating image no 1523of 1912
# Calculating image no 1524of 1912
# Calculating image no 1525of 1912
# Calculating image no 1526of 1912
# Calculating image no 1527of 1912
# Calculating image no 1528of 1912
# Calculating image no 1529of 1912
# Calculating image no 1530of 1912
# Calculating image no 1531of 1912
# Calculating image no 1532of 1912
# Calculating image no 1533of 1912
# Calculating image no 1534of 1912
# Calculating image no 1535of 1912
# Calculating image no 1536of 1912
# Calculating image no 1537of 1912
# Calculating image no 1538of 1912
# Calculating image no 1539of 1912
# Calculating image no 1540of 1912
# Calculating image no 1541of 1912
# Calculating image no 1542of 1912
# Calculating image no 1543of 1912
# Calculating image no 1544of 1912
# Calculating image no 1545of 1912
# Calculating image no 1546of 1912
# Calculating image no 1547of 1912
# Calculating image no 1548of 1912
# Calculating image no 1549of 1912
# Calculating image no 1550of 1912
# Calculating image no 1551of 1912
# Calculating image no 1552of 1912
# Calculating image no 1553of 1912
# Calculating image no 1554of 1912
# Calculating image no 1555of 1912
# Calculating image no 1556of 1912
# Calculating image no 1557of 1912
# Calculating image no 1558of 1912
# Calculating image no 1559of 1912
# Calculating image no 1560of 1912
# Calculating image no 1561of 1912
# Calculating image no 1562of 1912
# Calculating image no 1563of 1912
# Calculating image no 1564of 1912
# Calculating image no 1565of 1912
# Calculating image no 1566of 1912
# Calculating image no 1567of 1912
# Calculating image no 1568of 1912
# Calculating image no 1569of 1912
# Calculating image no 1570of 1912
# Calculating image no 1571of 1912
# Calculating image no 1572of 1912
# Calculating image no 1573of 1912
# Calculating image no 1574of 1912
# Calculating image no 1575of 1912
# Calculating image no 1576of 1912
# Calculating image no 1577of 1912
# Calculating image no 1578of 1912
# Calculating image no 1579of 1912
# Calculating image no 1580of 1912
# Calculating image no 1581of 1912
# Calculating image no 1582of 1912
# Calculating image no 1583of 1912
# Calculating image no 1584of 1912
# Calculating image no 1585of 1912
# Calculating image no 1586of 1912
# Calculating image no 1587of 1912
# Calculating image no 1588of 1912
# Calculating image no 1589of 1912
# Calculating image no 1590of 1912
# Calculating image no 1591of 1912
# Calculating image no 1592of 1912
# Calculating image no 1593of 1912
# Calculating image no 1594of 1912
# Calculating image no 1595of 1912
# Calculating image no 1596of 1912
# Calculating image no 1597of 1912
# Calculating image no 1598of 1912
# Calculating image no 1599of 1912
# Calculating image no 1600of 1912
# Calculating image no 1601of 1912
# Calculating image no 1602of 1912
# Calculating image no 1603of 1912
# Calculating image no 1604of 1912
# Calculating image no 1605of 1912
# Calculating image no 1606of 1912
# Calculating image no 1607of 1912
# Calculating image no 1608of 1912
# Calculating image no 1609of 1912
# Calculating image no 1610of 1912
# Calculating image no 1611of 1912
# Calculating image no 1612of 1912
# Calculating image no 1613of 1912
# Calculating image no 1614of 1912
# Calculating image no 1615of 1912
# Calculating image no 1616of 1912
# Calculating image no 1617of 1912
# Calculating image no 1618of 1912
# Calculating image no 1619of 1912
# Calculating image no 1620of 1912
# Calculating image no 1621of 1912
# Calculating image no 1622of 1912
# Calculating image no 1623of 1912
# Calculating image no 1624of 1912
# Calculating image no 1625of 1912
# Calculating image no 1626of 1912
# Calculating image no 1627of 1912
# Calculating image no 1628of 1912
# Calculating image no 1629of 1912
# Calculating image no 1630of 1912
# Calculating image no 1631of 1912
# Calculating image no 1632of 1912
# Calculating image no 1633of 1912
# Calculating image no 1634of 1912
# Calculating image no 1635of 1912
# Calculating image no 1636of 1912
# Calculating image no 1637of 1912
# Calculating image no 1638of 1912
# Calculating image no 1639of 1912
# Calculating image no 1640of 1912
# Calculating image no 1641of 1912
# Calculating image no 1642of 1912
# Calculating image no 1643of 1912
# Calculating image no 1644of 1912
# Calculating image no 1645of 1912
# Calculating image no 1646of 1912
# Calculating image no 1647of 1912
# Calculating image no 1648of 1912
# Calculating image no 1649of 1912
# Calculating image no 1650of 1912
# Calculating image no 1651of 1912
# Calculating image no 1652of 1912
# Calculating image no 1653of 1912
# Calculating image no 1654of 1912
# Calculating image no 1655of 1912
# Calculating image no 1656of 1912
# Calculating image no 1657of 1912
# Calculating image no 1658of 1912
# Calculating image no 1659of 1912
# Calculating image no 1660of 1912
# Calculating image no 1661of 1912
# Calculating image no 1662of 1912
# Calculating image no 1663of 1912
# Calculating image no 1664of 1912
# Calculating image no 1665of 1912
# Calculating image no 1666of 1912
# Calculating image no 1667of 1912
# Calculating image no 1668of 1912
# Calculating image no 1669of 1912
# Calculating image no 1670of 1912
# Calculating image no 1671of 1912
# Calculating image no 1672of 1912
# Calculating image no 1673of 1912
# Calculating image no 1674of 1912
# Calculating image no 1675of 1912
# Calculating image no 1676of 1912
# Calculating image no 1677of 1912
# Calculating image no 1678of 1912
# Calculating image no 1679of 1912
# Calculating image no 1680of 1912
# Calculating image no 1681of 1912
# Calculating image no 1682of 1912
# Calculating image no 1683of 1912
# Calculating image no 1684of 1912
# Calculating image no 1685of 1912
# Calculating image no 1686of 1912
# Calculating image no 1687of 1912
# Calculating image no 1688of 1912
# Calculating image no 1689of 1912
# Calculating image no 1690of 1912
# Calculating image no 1691of 1912
# Calculating image no 1692of 1912
# Calculating image no 1693of 1912
# Calculating image no 1694of 1912
# Calculating image no 1695of 1912
# Calculating image no 1696of 1912
# Calculating image no 1697of 1912
# Calculating image no 1698of 1912
# Calculating image no 1699of 1912
# Calculating image no 1700of 1912
# Calculating image no 1701of 1912
# Calculating image no 1702of 1912
# Calculating image no 1703of 1912
# Calculating image no 1704of 1912
# Calculating image no 1705of 1912
# Calculating image no 1706of 1912
# Calculating image no 1707of 1912
# Calculating image no 1708of 1912
# Calculating image no 1709of 1912
# Calculating image no 1710of 1912
# Calculating image no 1711of 1912
# Calculating image no 1712of 1912
# Calculating image no 1713of 1912
# Calculating image no 1714of 1912
# Calculating image no 1715of 1912
# Calculating image no 1716of 1912
# Calculating image no 1717of 1912
# Calculating image no 1718of 1912
# Calculating image no 1719of 1912
# Calculating image no 1720of 1912
# Calculating image no 1721of 1912
# Calculating image no 1722of 1912
# Calculating image no 1723of 1912
# Calculating image no 1724of 1912
# Calculating image no 1725of 1912
# Calculating image no 1726of 1912
# Calculating image no 1727of 1912
# Calculating image no 1728of 1912
# Calculating image no 1729of 1912
# Calculating image no 1730of 1912
# Calculating image no 1731of 1912
# Calculating image no 1732of 1912
# Calculating image no 1733of 1912
# Calculating image no 1734of 1912
# Calculating image no 1735of 1912
# Calculating image no 1736of 1912
# Calculating image no 1737of 1912
# Calculating image no 1738of 1912
# Calculating image no 1739of 1912
# Calculating image no 1740of 1912
# Calculating image no 1741of 1912
# Calculating image no 1742of 1912
# Calculating image no 1743of 1912
# Calculating image no 1744of 1912
# Calculating image no 1745of 1912
# Calculating image no 1746of 1912
# Calculating image no 1747of 1912
# Calculating image no 1748of 1912
# Calculating image no 1749of 1912
# Calculating image no 1750of 1912
# Calculating image no 1751of 1912
# Calculating image no 1752of 1912
# Calculating image no 1753of 1912
# Calculating image no 1754of 1912
# Calculating image no 1755of 1912
# Calculating image no 1756of 1912
# Calculating image no 1757of 1912
# Calculating image no 1758of 1912
# Calculating image no 1759of 1912
# Calculating image no 1760of 1912
# Calculating image no 1761of 1912
# Calculating image no 1762of 1912
# Calculating image no 1763of 1912
# Calculating image no 1764of 1912
# Calculating image no 1765of 1912
# Calculating image no 1766of 1912
# Calculating image no 1767of 1912
# Calculating image no 1768of 1912
# Calculating image no 1769of 1912
# Calculating image no 1770of 1912
# Calculating image no 1771of 1912
# Calculating image no 1772of 1912
# Calculating image no 1773of 1912
# Calculating image no 1774of 1912
# Calculating image no 1775of 1912
# Calculating image no 1776of 1912
# Calculating image no 1777of 1912
# Calculating image no 1778of 1912
# Calculating image no 1779of 1912
# Calculating image no 1780of 1912
# Calculating image no 1781of 1912
# Calculating image no 1782of 1912
# Calculating image no 1783of 1912
# Calculating image no 1784of 1912
# Calculating image no 1785of 1912
# Calculating image no 1786of 1912
# Calculating image no 1787of 1912
# Calculating image no 1788of 1912
# Calculating image no 1789of 1912
# Calculating image no 1790of 1912
# Calculating image no 1791of 1912
# Calculating image no 1792of 1912
# Calculating image no 1793of 1912
# Calculating image no 1794of 1912
# Calculating image no 1795of 1912
# Calculating image no 1796of 1912
# Calculating image no 1797of 1912
# Calculating image no 1798of 1912
# Calculating image no 1799of 1912
# Calculating image no 1800of 1912
# Calculating image no 1801of 1912
# Calculating image no 1802of 1912
# Calculating image no 1803of 1912
# Calculating image no 1804of 1912
# Calculating image no 1805of 1912
# Calculating image no 1806of 1912
# Calculating image no 1807of 1912
# Calculating image no 1808of 1912
# Calculating image no 1809of 1912
# Calculating image no 1810of 1912
# Calculating image no 1811of 1912
# Calculating image no 1812of 1912
# Calculating image no 1813of 1912
# Calculating image no 1814of 1912
# Calculating image no 1815of 1912
# Calculating image no 1816of 1912
# Calculating image no 1817of 1912
# Calculating image no 1818of 1912
# Calculating image no 1819of 1912
# Calculating image no 1820of 1912
# Calculating image no 1821of 1912
# Calculating image no 1822of 1912
# Calculating image no 1823of 1912
# Calculating image no 1824of 1912
# Calculating image no 1825of 1912
# Calculating image no 1826of 1912
# Calculating image no 1827of 1912
# Calculating image no 1828of 1912
# Calculating image no 1829of 1912
# Calculating image no 1830of 1912
# Calculating image no 1831of 1912
# Calculating image no 1832of 1912
# Calculating image no 1833of 1912
# Calculating image no 1834of 1912
# Calculating image no 1835of 1912
# Calculating image no 1836of 1912
# Calculating image no 1837of 1912
# Calculating image no 1838of 1912
# Calculating image no 1839of 1912
# Calculating image no 1840of 1912
# Calculating image no 1841of 1912
# Calculating image no 1842of 1912
# Calculating image no 1843of 1912
# Calculating image no 1844of 1912
# Calculating image no 1845of 1912
# Calculating image no 1846of 1912
# Calculating image no 1847of 1912
# Calculating image no 1848of 1912
# Calculating image no 1849of 1912
# Calculating image no 1850of 1912
# Calculating image no 1851of 1912
# Calculating image no 1852of 1912
# Calculating image no 1853of 1912
# Calculating image no 1854of 1912
# Calculating image no 1855of 1912
# Calculating image no 1856of 1912
# Calculating image no 1857of 1912
# Calculating image no 1858of 1912
# Calculating image no 1859of 1912
# Calculating image no 1860of 1912
# Calculating image no 1861of 1912
# Calculating image no 1862of 1912
# Calculating image no 1863of 1912
# Calculating image no 1864of 1912
# Calculating image no 1865of 1912
# Calculating image no 1866of 1912
# Calculating image no 1867of 1912
# Calculating image no 1868of 1912
# Calculating image no 1869of 1912
# Calculating image no 1870of 1912
# Calculating image no 1871of 1912
# Calculating image no 1872of 1912
# Calculating image no 1873of 1912
# Calculating image no 1874of 1912
# Calculating image no 1875of 1912
# Calculating image no 1876of 1912
# Calculating image no 1877of 1912
# Calculating image no 1878of 1912
# Calculating image no 1879of 1912
# Calculating image no 1880of 1912
# Calculating image no 1881of 1912
# Calculating image no 1882of 1912
# Calculating image no 1883of 1912
# Calculating image no 1884of 1912
# Calculating image no 1885of 1912
# Calculating image no 1886of 1912
# Calculating image no 1887of 1912
# Calculating image no 1888of 1912
# Calculating image no 1889of 1912
# Calculating image no 1890of 1912
# Calculating image no 1891of 1912
# Calculating image no 1892of 1912
# Calculating image no 1893of 1912
# Calculating image no 1894of 1912
# Calculating image no 1895of 1912
# Calculating image no 1896of 1912
# Calculating image no 1897of 1912
# Calculating image no 1898of 1912
# Calculating image no 1899of 1912
# Calculating image no 1900of 1912
# Calculating image no 1901of 1912
# Calculating image no 1902of 1912
# Calculating image no 1903of 1912
# Calculating image no 1904of 1912
# Calculating image no 1905of 1912
# Calculating image no 1906of 1912
# Calculating image no 1907of 1912
# Calculating image no 1908of 1912
# Calculating image no 1909of 1912
# Calculating image no 1910of 1912
# Calculating image no 1911of 1912
# Calculating image no 1912of 1912
# 0

# %% [markdown]
# ### Make folder for results and save segmentation

# %%
resultsbackup2=deepcopy(results)

# %%
results=deepcopy(resultsbackup2)

# %%
# Store data (serialize)
output = open('myfile.pkl', 'wb')
pickle.dump(resultsbackup2, output)
output.close()

# %%
# Load data (deserialize)
pkl_file = open('myfile.pkl', 'rb')
mydict2 = pickle.load(pkl_file)
pkl_file.close()

# %% [markdown]
# ### Calculate mean intensity of controls - under spots

# %%
Controls_intensity={"exp_id":[],"earlycontrol_meanint":[],"latecontrol_meanint":[]}

for exps in list(set(results["exp_id"])):
    print(exps)
    type(exps)
    
    exec(open(exps+"/channels.txt").read())
    early_chanel_no=earlychannelno
    late_channel_no=latechannelno
    
    ctrlearlys={"filename":[]}
    pathearly=os.path.dirname(glob.glob(exps+'/*_earlycontrol')[0])
    filelistearly = []
    for root, _, filenames in os.walk(pathearly):
         for filename in filenames:
             filelistearly.append(os.path.join(root, filename)) #make a list of all images in early control folder
    for l in range(0,len(filelistearly)):
        if filelistearly[l].endswith(".nd2"): 
            ctrlearlys["filename"].append(filelistearly[l])
    earlycolour_ctrls=np.zeros((len(ctrlearlys["filename"]),1)) #make empty vector to store mean intensity of each image
    earlycolour_spotsonly_ctrls=np.zeros((len(ctrlearlys["filename"]),1))
    for im in range(0,len(ctrlearlys["filename"])):
        with ND2Reader(ctrlearlys["filename"][im]) as images:
            early_image_ctrl=images[early_channel_no-1]
        #convert to array
        early_image_ctrl=early_image_ctrl.astype(np.int16)
        #normalize intensity to value between 0 and 1
        early_image_ctrl=np.divide(early_image_ctrl,16383.)
        #append raw mean intensity to vector
        earlycolour_ctrls[im]=np.mean(early_image_ctrl)
        ##### calculate the intensity for the cleaned image separately- i.e. only for the spots #########
        early_spots=results["Early colour - spots mask"][im] #read the spots mask
        spots_early_labels,_ = ndi.label(early_spots) #label the spots with unique IDs
        early_spots_intensities=np.zeros((len(np.unique(spots_early_labels)),1)) #make empty vector to store intensity results
        for spotno in np.unique(spots_early_labels)[1:]: #loop over early spots
            early_spots_mask = spots_early_labels==spotno
            early_spots_intensities[spotno]=np.nanmean(early_image_ctrl[early_spots_mask])
        earlycolour_spotsonly_ctrls[im]=np.nanmean(early_spots_intensities)
        
    ctrllates={"filename":[]}
    pathlate=os.path.dirname(glob.glob(exps+'/*_latecontrol')[0])
    filelistlate = []
    for root, _, filenames in os.walk(pathlate):
         for filename in filenames:
             filelistlate.append(os.path.join(root, filename)) #make a list of all images in early control folder
    for l in range(0,len(filelistlate)):
        if filelistlate[l].endswith(".nd2"): 
            ctrllates["filename"].append(filelistlate[l])
    latecolour_ctrls=np.zeros((len(ctrllates["filename"]),1)) #make empty vector to store mean intensity of each image
    latecolour_spotsonly_ctrls=np.zeros((len(ctrllates["filename"]),1))
    for im in range(0,len(ctrllates["filename"])):
        with ND2Reader(ctrllates["filename"][im]) as images:
            late_image_ctrl=images[late_channel_no-1]
        #convert to array
        late_image_ctrl=late_image_ctrl.astype(np.int16)
        #normalize intensity to value between 0 and 1
        late_image_ctrl=np.divide(late_image_ctrl,16383.)
        #append raw mean intensity to vector
        latecolour_ctrls[im]=np.mean(late_image_ctrl)
        ##### calculate the intensity for the cleaned image separately- i.e. only for the spots #########
        late_spots=results["Late colour - spots mask"][im] #read the spots mask
        spots_late_labels,_ = ndi.label(late_spots) #label the spots with unique IDs
        late_spots_intensities=np.zeros((len(np.unique(spots_late_labels)),1)) #make empty vector to store intensity results
        for spotno in np.unique(spots_late_labels)[1:]: #loop over early spots
            late_spots_mask = spots_late_labels==spotno
            late_spots_intensities[spotno]=np.nanmean(late_image_ctrl[late_spots_mask])
        latecolour_spotsonly_ctrls[im]=np.nanmean(late_spots_intensities)
        #average the vector
    early_ctrl_mean=np.nanmean(earlycolour_ctrls)
    early_spotsonly_ctrl_mean=np.nanmean(earlycolour_spotsonly_ctrls)
    late_ctrl_mean=np.nanmean(latecolour_ctrls)
    late_spotsonly_ctrl_mean=np.nanmean(latecolour_spotsonly_ctrls)
    
    Controls_intensity["exp_id"].append(exps)
    Controls_intensity["earlycontrol_meanint"].append(early_spotsonly_ctrl_mean)
    Controls_intensity["latecontrol_meanint"].append(late_spotsonly_ctrl_mean)


    print(early_ctrl_mean)
    print(early_spotsonly_ctrl_mean)
    print(late_ctrl_mean)
    print(late_spotsonly_ctrl_mean)
    
df_ctrlsintensity=pd.DataFrame(Controls_intensity)
# Out:
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR
# 0.016149446092017388
# 0.016196930094151577
# 0.016149446092017388
# 0.01624752291608934
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second
# 0.030198246749674945
# 0.030290218959988083
# 0.025934140744747192
# 0.02628743528424992
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second
# 0.03243118096409953
# 0.032228297567795404
# 0.016552885160105654
# 0.016444647773006305
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR
# 0.04105667629498159
# 0.04117715762368485
# 0.020585550052161488
# 0.020721047740004928
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180214_Turnover_Bic_TNR_nb580first_nb653psecond_use
# 0.029865512024793827
# 0.02947406625097506
# 0.029865512024793827
# 0.029984849510088535
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180602_Turnover_Bic_Timepoints_nb635first_580second_use
# 0.040530735644405874
# 0.040355991260602596
# 0.033419114276384325
# 0.033371554163355244
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180705_Turnover_Bic_TNR_Timepoints_nb580first_635second_use
# 0.062448603586053815
# 0.06253295419860462
# 0.04487861410815753
# 0.045182459991797715
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use
# 0.03622287383954413
# 0.04371975054082635
# 0.03622287383954413
# 0.0459525051160354
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use
# 0.013802732754882745
# 0.013771662131429364
# 0.032721842716222936
# 0.03260113009560982
# /Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180620_Turnover_Bic_TNR_Timepoints_nb635first_580second_use
# 0.04887768768429925
# 0.04892606790612502
# 0.04887768768429925
# 0.04886106291627689

# %%
#small detour to calculate the autofluorescence
    autof={"filename":[]}
    autofpath=results["Autofluorescencedir"][i]
    if autofpath==0:
        early_autoint_mean=0
        late_autoint_mean=0
        if synapse_flag:
            synapse_autoint_mean=0
    else:
        pathy = os.path.dirname(autofpath+"/")  
        autoffilelist = []
        for root, _, filenames in os.walk(pathy):
             for filename in filenames:
                 autoffilelist.append(os.path.join(root, filename))
        for l in range(0,len(autoffilelist)):
            if autoffilelist[l].endswith(".nd2"): 
                autof["filename"].append(autoffilelist[l])
        earlycolour_autoint=np.zeros((len(autof["filename"]),1))
        latecolour_autoint=np.zeros((len(autof["filename"]),1))
        if synapse_flag:
            synapsecolour_autoint=np.zeros((len(autof["filename"]),1))
        for im in range(0,len(autof["filename"])):
            with ND2Reader(autof["filename"][im]) as images:
                early_image_auto=images[early_channel_no-1]
                late_image_auto=images[late_channel_no-1]
                if synapse_flag:
                    synapse_image_auto=images[synapse_channel_no-1]
            #convert to array
            early_image_auto=early_image_auto.astype(np.int16)
            late_image_auto=late_image_auto.astype(np.int16)
            if synapse_flag:
                synapse_image_auto=synapse_image_auto.astype(np.int16)
            #normalize intensity to value between 0 and 1
            early_image_auto=np.divide(early_image_auto,16383.)
            late_image_auto=np.divide(late_image_auto,16383.)
            if synapse_flag:
                synapse_image_auto=np.divide(synapse_image_auto,16383.)
            #append mean intensity
            earlycolour_autoint[im]=np.mean(early_image_auto)
            latecolour_autoint[im]=np.mean(late_image_auto)  
            if synapse_flag:
                synapsecolour_autoint[im]=np.mean(synapse_image_auto)
        #average the vectors
        early_autoint_mean=np.mean(earlycolour_autoint)
        late_autoint_mean=np.mean(latecolour_autoint)
        if synapse_flag:
            synapse_autoint_mean=np.mean(synapsecolour_autoint)
# Out:
# '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180620_Turnover_Bic_TNR_Timepoints_nb635first_580second_use'

# %% [markdown]
# ### Batch analyse images, after creating the segmentation masks

# %%
print('Total number of images: ' + str(len(results['filename'])))

#for i in range(0,len(results["filename"])): 
for i in range(0,len(results["filename"])):
    print('Calculating image no ' + str(i+1) + ' out of' + str(len(results["filename"])))
    #read the image
    early_channel_no=results["earlychannelno"][i]
    late_channel_no=results["latechannelno"][i]
    synapse_channel_no=results["synapsechannelno"][i]
    if synapse_channel_no>0:
        synapse_flag=True
        print('has synapse values')
    else:
        synapse_flag=False
    with ND2Reader(results["filename"][i]) as images:
        early_image=images[early_channel_no-1]
        late_image=images[late_channel_no-1]
        if synapse_flag:
            synapse_image=images[synapse_channel_no-1]
    #convert to array
    early_image=early_image.astype(np.int16)
    late_image=late_image.astype(np.int16)
    if synapse_flag:
        synapse_image=synapse_image.astype(np.int16)
    
    ###################analyses for the raw images -before processing##############
    #preserve the raw images
    early_image_raw = deepcopy(early_image)
    late_image_raw=deepcopy(late_image)
    if synapse_flag:
        synapse_image_raw=deepcopy(synapse_image)
    #normalize intensity to value between 0 and 1
    early_image=np.divide(early_image,16383.)
    late_image=np.divide(late_image,16383.)
    if synapse_flag:
        synapse_image=np.divide(synapse_image,16383.)
    #make image histograms of raw images
    early_hist,_ = np.histogram(early_image,bins=np.linspace(0.,1.,50))
    late_hist,_ = np.histogram(late_image,bins=np.linspace(0.,1.,50))
    if synapse_flag:
        synapse_hist,_ = np.histogram(synapse_image,bins=np.linspace(0.,1.,50))
    #makes images normd to controls
    currentexp=results["exp_id"][i]
    earlyctrlmean=df_ctrlsintensity[df_ctrlsintensity["exp_id"]==currentexp]["earlycontrol_meanint"].values[0]
    latectrlmean=df_ctrlsintensity[df_ctrlsintensity["exp_id"]==currentexp]["latecontrol_meanint"].values[0]
    early_image_normtoearlyctrl=deepcopy(early_image)
    early_image_normtoearlyctrl=early_image_normtoearlyctrl/earlyctrlmean
    late_image_normtolatectrl=deepcopy(late_image)
    late_image_normtolatectrl=late_image_normtolatectrl/latectrlmean

    ##################################################################################

    ###############analyses for the cleaned images - after processing##############
    #read spots masks
    early_spots=results["Early colour - spots mask"][i]
    late_spots=results["Late colour - spots mask"][i]
    lateplusearly_spots=results["Late plus early colour - spots mask"][i]
    if synapse_flag:
        synapse_spots=results["Synapse colour - spots mask"][i]
    #label the spots with unique IDs
    spots_early_labels,_ = ndi.label(early_spots)
    spots_late_labels,_ = ndi.label(late_spots)
    spots_earlypluslate_labels,_ = ndi.label(lateplusearly_spots)
    if synapse_flag:
        spots_synapse_labels,_ = ndi.label(synapse_spots)
    #make empty vectors for results                                  
    early_spots_intensities=np.zeros((len(np.unique(spots_early_labels)),1))
    early_spots_intensities_normtoearlyctrl=np.zeros((len(np.unique(spots_early_labels)),1))
    early_spots_areas=np.zeros((len(np.unique(spots_early_labels)),1))
    late_spots_intensities=np.zeros((len(np.unique(spots_late_labels)),1))
    late_spots_intensities_normtolatectrl=np.zeros((len(np.unique(spots_late_labels)),1))
    late_spots_areas=np.zeros((len(np.unique(spots_late_labels)),1))
    if synapse_flag:
        synapse_spots_intensities=np.zeros((len(np.unique(spots_synapse_labels)),1))
        synapse_spots_areas=np.zeros((len(np.unique(spots_synapse_labels)),1))
        early_atsynapses_intensities=np.zeros((len(np.unique(spots_synapse_labels)),1))   
        late_atsynapses_intensities=np.zeros((len(np.unique(spots_synapse_labels)),1)) 
        early_atsynapses_intensities_normtoearlyctrl=np.zeros((len(np.unique(spots_synapse_labels)),1))   
        late_atsynapses_intensities_normtolatectrl=np.zeros((len(np.unique(spots_synapse_labels)),1)) 
    #loop over early spots
    for spotno in np.unique(spots_early_labels)[1:]:
        early_spots_mask = spots_early_labels==spotno
        early_spots_intensities[spotno]=np.nanmean(early_image[early_spots_mask])
        early_spots_intensities_normtoearlyctrl[spotno]=np.nanmean(early_image_normtoearlyctrl[early_spots_mask])
        early_spots_areas[spotno]=np.sum(early_spots_mask)
    #loop over late spots
    for spotnol in np.unique(spots_late_labels)[1:]:
        late_spots_mask= spots_late_labels==spotnol
        late_spots_intensities[spotnol]=np.nanmean(late_image[late_spots_mask])
        late_spots_intensities_normtolatectrl[spotnol]=np.nanmean(late_image_normtolatectrl[late_spots_mask])
        late_spots_areas[spotnol]=np.sum(late_spots_mask)
    #loop over synapse spots   
    if synapse_flag:
        for spotnos in np.unique(spots_synapse_labels)[1:]:
            synapse_spots_mask= spots_synapse_labels==spotnos
            synapse_spots_intensities[spotnos]=np.nanmean(synapse_image[synapse_spots_mask])
            synapse_spots_areas[spotnos]=np.sum(synapse_spots_mask)
            #intensities masked by synapses, calculation
            early_atsynapses_intensities[spotnos]=np.nanmean(early_image[synapse_spots_mask & early_spots_mask])
            late_atsynapses_intensities[spotnos]=np.nanmean(late_image[synapse_spots_mask & late_spots_mask])
            early_atsynapses_intensities_normtoearlyctrl[spotnos]=np.nanmean(early_image_normtoearlyctrl[synapse_spots_mask & early_spots_mask])
            late_atsynapses_intensities_normtolatectrl[spotnos]=np.nanmean(late_image_normtolatectrl[synapse_spots_mask & late_spots_mask])
    #calculate bias image at cross of late/early spots
    a=late_image[lateplusearly_spots]
    b=early_image[lateplusearly_spots]
    spots_bias_image=np.divide([a-b],[a+b])                               
    #bias image calculation for normalized images
    a=late_image_normtolatectrl[lateplusearly_spots]
    b=early_image_normtoearlyctrl[lateplusearly_spots]
    spots_bias_image=np.divide([a-b],[a+b])     
    
    #results based on raw
    results["Early colour - Raw mean intensity"].append(np.nanmean(early_image_raw))
    results["Late colour - Raw mean intensity"].append(np.nanmean(late_image_raw))
    if synapse_flag:
        results["Synapse colour - Raw mean intensity"].append(np.nanmean(synapse_image_raw))
    else:
        results["Synapse colour - Raw mean intensity"].append(np.nan)
    histogram_results["Early colour - Flattened histogram"].append(early_hist) 
    histogram_results["Late colour - Flattened histogram"].append(late_hist)
    if synapse_flag:
        histogram_results["Synapse colour - Flattened histogram"].append(synapse_hist)
    else:
        histogram_results["Synapse colour - Flattened histogram"].append(np.nan)
    bias_image_raw_full=np.divide([late_image-early_image],[late_image+early_image]).reshape(512,512)
    bias_image_at_synapses_full=bias_image_raw_full[synapse_spots]
    bias_image_norm_full=np.divide([late_image_normtolatectrl-early_image_normtoearlyctrl],[late_image_normtolatectrl+early_image_normtoearlyctrl]).reshape(512,512)
    bias_image_norm_at_synapses_full=bias_image_norm_full[synapse_spots]
    bias_image_raw = bias_image_raw_full[~np.isnan(bias_image_raw_full)]
    bias_image_at_synapses=bias_image_at_synapses_full[~np.isnan(bias_image_at_synapses_full)]
    bias_image_norm_at_synapses=bias_image_norm_at_synapses_full[~np.isnan(bias_image_norm_at_synapses_full)]

    
    results["Mean colour bias of a pixel (early=-1<x<1=late) - Whole raw image"].append(np.nanmean(bias_image_raw_full))
    results["Mean correlation coefficient early/late - Whole raw image"].append(corr2(early_image,late_image))
    
    #results based on spots
    results["Early colour - Mean intensity of spots"].append(np.nanmean(early_spots_intensities))
    results["Late colour - Mean intensity of spots"].append(np.nanmean(late_spots_intensities))
    results["Early colour - Mean intensity of spots Normd to early ctrl"].append(np.nanmean(early_spots_intensities_normtoearlyctrl))
    results["Late colour - Mean intensity of spots Normd to late ctrl"].append(np.nanmean(late_spots_intensities_normtolatectrl))
    if synapse_flag:
        results["Synapse colour - Mean intensity of spots"].append(np.nanmean(synapse_spots_intensities))
    else:
        results["Synapse colour - Mean intensity of spots"].append(np.nan) 
    results["Early colour - Total no. of spots in FOV"].append(len(early_spots_intensities))
    results["Late colour - Total no. of spots in FOV"].append(len(late_spots_intensities))
    if synapse_flag:
        results["Synapse colour - Total no. of spots in FOV"].append(len(synapse_spots_intensities))
    else:
        results["Synapse colour - Total no. of spots in FOV"].append(np.nan)
    results["Early colour - Mean spot area [nm]"].append(np.nanmean(early_spots_areas))
    results["Late colour - Mean spot area [nm]"].append(np.nanmean(late_spots_areas))
    if synapse_flag:
        results["Synapse colour - Mean spot area [nm]"].append(np.nanmean(synapse_spots_areas))
        results["Early colour - Mean intensity of spots only under synapses"].append(np.nanmean(early_atsynapses_intensities))
        results["Early colour - Mean intensity of spots Normd to early ctrl - masked by synapses"].append(np.nanmean(early_atsynapses_intensities_normtoearlyctrl))
        results["Late colour - Mean intensity of spots only under synapses"].append(np.nanmean(late_atsynapses_intensities))
        results["Late colour - Mean intensity of spots Normd to late ctrl - masked by synapses"].append(np.nanmean(late_atsynapses_intensities_normtolatectrl))
    else:
        results["Synapse colour - Mean spot area [nm]"].append(np.nanmean(synapse_spots_areas))
        results["Early colour - Mean intensity of spots only under synapses"].append(np.nan)
        results["Early colour - Mean intensity of spots Normd to early ctrl - masked by synapses"].append(np.nan)
        results["Late colour - Mean intensity of spots only under synapses"].append(np.nan)
        results["Late colour - Mean intensity of spots Normd to late ctrl - masked by synapses"].append(np.nan)
    if synapse_flag:
        results["Early colour spots normd to early ctrl, corr to Synapse spots"].append(corr2(early_image[early_spots & synapse_spots],synapse_image[early_spots & synapse_spots]))
        results["Late colour spots normd to late ctrl, corr to Synapse spots"].append(corr2(late_image[late_spots & synapse_spots],synapse_image[late_spots & synapse_spots]))
    else:
        results["Early colour spots normd to early ctrl, corr to Synapse spots"].append(np.nan)
        results["Late colour spots normd to late ctrl, corr to Synapse spots"].append(np.nan)
    
    results["Mean colour bias of a pixel (early=-1<x<1=late) - under late+early spots"].append(np.nanmean(spots_bias_image))
    if synapse_flag:
        results["Mean colour bias of a pixel, masked by early, late, synapses (early=-1<x<1=late)"].append(np.nanmean(bias_image_at_synapses))
        results["Mean colour bias of a pixel, masked by early, late, synapses (early=-1<x<1=late) - early and late normd to corresponding ctrls"].append(np.nanmean(bias_image_norm_at_synapses))
    else:
        results["Mean colour bias of a pixel, masked by early, late, synapses (early=-1<x<1=late)"].append(np.nan)
        results["Mean colour bias of a pixel, masked by early, late, synapses (early=-1<x<1=late) - early and late normd to corresponding ctrls"].append(np.nan)

    earlyprops=skimage.measure.regionprops(spots_early_labels)
    lateprops=skimage.measure.regionprops(spots_late_labels)
    if synapse_flag:
        synapseprops=skimage.measure.regionprops(spots_synapse_labels)                                 
    earlypluslateprops=skimage.measure.regionprops(spots_earlypluslate_labels)
    regionprops_results["Early colour - regionprops"].append(earlyprops)
    regionprops_results["Late colour - regionprops"].append(lateprops)
    if synapse_flag:
        regionprops_results["Synapse colour - regionprops"].append(synapseprops)
    else:
        regionprops_results["Synapse colour - regionprops"].append(np.nan)
    regionprops_results["Late + early colour combined - regionprops"].append(earlypluslateprops)
    
os.system('say "Finished batch analyzing"')
# Out:
# Total number of images: 1912
# Calculating image no 1 out of1912
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'early_spotsonly_ctrl_mean'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-95-0e886812993b> in <module>()
#      42     #makes images normd to controls
#      43     currentexp=results["exp_id"][i]
# ---> 44     earlyctrlmean=df_ctrlsintensity[df_ctrlsintensity["exp_id"]==currentexp]["early_spotsonly_ctrl_mean"].values[0]
#      45     latectrlmean=df_ctrlsintensity[df_ctrlsintensity["exp_id"]==currentexp]["late_spotsonly_ctrl_mean"].values[0]
#      46     early_image_normtoearlyctrl=deepcopy(early_image)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'early_spotsonly_ctrl_mean'

# %% [markdown]
# ### Plots

# %%
df=pd.DataFrame(results)
dfhists=pd.DataFrame(histogram_results)
dfregionprops=pd.DataFrame(regionprops_results)
df.to_csv(path_or_buf=expdir+'/results/results_20180909.csv')
#dfhists.to_csv(path_or_buf=expdir+'/results/histogram_results_180801.csv')
#dfregionprops.to_csv(path_or_buf=expdir+'/results/regionprops_results_180801.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-8b7b7fe18a8b> in <module>()
#       1 df=pd.DataFrame(results)
# ----> 2 dfhists=pd.DataFrame(histogram_results)
#       3 dfregionprops=pd.DataFrame(regionprops_results)
#       4 df.to_csv(path_or_buf=expdir+'/results/results_20180909.csv')
#       5 dfhists.to_csv(path_or_buf=expdir+'/results/histogram_results_180909.csv')
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     328                                  dtype=dtype, copy=copy)
#     329         elif isinstance(data, dict):
# --> 330             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     331         elif isinstance(data, ma.MaskedArray):
#     332             import numpy.ma.mrecords as mrecords
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     459             arrays = [data[k] for k in keys]
#     460
# --> 461         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     462
#     463     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    6161     # figure out the index, if necessary
#    6162     if index is None:
# -> 6163         index = extract_index(arrays)
#    6164     else:
#    6165         index = _ensure_index(index)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in extract_index(data)
#    6209             lengths = list(set(raw_lengths))
#    6210             if len(lengths) > 1:
# -> 6211                 raise ValueError('arrays must all be same length')
#    6212
#    6213             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
dfregionprops=pd.read_csv(expdir+'results_noctrls/results_regionprops.csv')

# %%
df2=pd.read_csv(expdir+'results/results_20180909.csv')
#dfhists=pd.read_csv(§expdir+'results/histogram_results.csv')

# %%
vars=['Early colour - Mean intensity of spots',
       'Early colour - Mean intensity of spots Normd to early ctrl',
       'Early colour - Mean intensity of spots Normd to early ctrl - masked by synapses',
       'Early colour - Mean intensity of spots only under synapses',
       'Early colour - Mean spot area [nm]',
       'Early colour - Raw mean intensity',
       'Early colour - Total no. of spots in FOV', 
       'Early colour spots normd to early ctrl, corr to Synapse spots',
       'Late colour - Mean intensity of spots',
       'Late colour - Mean intensity of spots Normd to late ctrl',
       'Late colour - Mean intensity of spots Normd to late ctrl - masked by synapses',
       'Late colour - Mean intensity of spots only under synapses',
       'Late colour - Mean spot area [nm]', 'Late colour - Raw mean intensity',
       'Late colour - Total no. of spots in FOV', 
       'Late colour spots normd to late ctrl, corr to Synapse spots',
       
       'Mean colour bias of a pixel (early=-1<x<1=late) - Whole raw image',
       'Mean colour bias of a pixel (early=-1<x<1=late) - under late+early spots',
       'Mean colour bias of a pixel, masked by early, late, synapses (early=-1<x<1=late)',
       'Mean colour bias of a pixel, masked by early, late, synapses (early=-1<x<1=late) - early and late normd to corresponding ctrls',
       'Mean correlation coefficient early/late - Whole raw image',
       'Synapse colour - Mean intensity of spots',
       'Synapse colour - Mean spot area [nm]',
       'Synapse colour - Raw mean intensity',
       'Synapse colour - Total no. of spots in FOV']
sns.set(font_scale=2.2)
for plot in vars:
    plt.figure(figsize=(40,10))
    sns.boxplot(x="Timeframe",y=plot,data=df2,order=orderlab,hue="Drug")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-635461c05c8f> in <module>()
#      27 for plot in vars:
#      28     plt.figure(figsize=(40,10))
# ---> 29     sns.boxplot(x="Timeframe",y=plot,data=df2,order=orderlab,hue="Drug")
#
# NameError: name 'orderlab' is not defined

# %% [markdown]
# ### Plot without controls "ctrl" in bla ==false or "Ctrl"

# %%
from copy import deepcopy
df3=deepcopy(df)
df2=deepcopy(df)
#dfhists3=deepcopy(dfhists)
#dfhists2=deepcopy(dfhists)

# %%
df2[df2[""]]

# %%
df2regionprops=deepcopy(dfregionprops)

# %%
#os.mkdir(expdir+'results_noctrls/')
df2=df2[df2["exp condition"].str.contains('ctrl|Ctrl')==False]
#dfhists2=dfhists2[dfhists2["exp condition"].str.contains('ctrl|Ctrl')==False]
df2=df2[df2["exp condition"].str.contains('TTX')==False]
#dfhists2=dfhists2[dfhists2["exp condition"].str.contains('TTX')==False]
df2.to_csv(path_or_buf=expdir+'/results_noctrls/results.csv')
#dfhists2.to_csv(path_or_buf=expdir+'/results_noctrls/histogram_results.csv')

# %%
#os.mkdir(expdir+'results_noctrls/')
df2regionprops=df2regionprops[df2regionprops["exp condition"].str.contains('ctrl|Ctrl')==False]
df2regionprops=df2regionprops[df2regionprops["exp condition"].str.contains('TTX')==False]

df2regionprops.to_csv(path_or_buf=expdir+'/results_noctrls/results_regionprops.csv')

# %%
df2.to_csv(path_or_buf=expdir+'/results_noctrls/results_180801.csv')

# %%
df=pd.read_csv(expdir+'/results/results.csv')

# %%
df2=pd.read_csv(expdir+'/results_noctrls/results.csv')

# %%
df2=pd.read_csv(expdir+'/results_noctrls/results_20180909.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-930a6f9550f8> in <module>()
# ----> 1 df2=pd.read_csv(expdir+'/results_noctrls/results_20180909.csv')
#
# NameError: name 'pd' is not defined

# %%
onedaylabel='17_24hr'
onedaybiclabel='18_24hr_Bic'
onehourlabel='03_01hr'
onehourbiclabel='04_1hr_Bic'
sevenhourlabel='007hr'
sevenhourbiclabel='007hr_Bic'
thirtyminslabel='01_30mis'
thirtyminsbiclabel='02_30mins_Bic'
twohourlabel='05_2hr'
twohourbiclabel='06_2hr_Bic'
sixhourlabel='09_6hr'
sixhourbiclabel='10_6hr_Bic'
ninehourlabel='13_9hr'
ninehourbiclabel='14_9hr_Bic'
threehourlabel='07_3hr'
threehourbiclabel='08_3hr_Bic'
twelvehourlabel='15_12hr'
twelvehourbiclabel='16_12hr_Bic'
eighthourlabel='11_8hr'
eighthourbiclabel='12_8hr_Bic'
twodaylabel='19_48hr'
twodaybiclabel='20_48hr_Bic'
threedaylabel='21_72hr'
threedaybiclabel='22_72hr_Bic'

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'Autofluorescencedir',
#        'Early colour - Mean intensity of spots',
#        'Early colour - Mean intensity of spots Normd to early ctrl',
#        'Early colour - Mean intensity of spots Normd to early ctrl - masked by synapses',
#        'Early colour - Mean intensity of spots only under synapses',
#        'Early colour - Mean spot area [nm]',
#        'Early colour - Raw mean intensity',
#        'Early colour - Total no. of spots in FOV', 'Early colour - spots mask',
#        'Early colour spots normd to early ctrl, corr to Synapse spots',
#        'Earlycontroldir', 'Late colour - Mean intensity of spots',
#        'Late colour - Mean intensity of spots Normd to late ctrl',
#        'Late colour - Mean intensity of spots Normd to late ctrl - masked by synapses',
#        'Late colour - Mean intensity of spots only under synapses',
#        'Late colour - Mean spot area [nm]', 'Late colour - Raw mean intensity',
#        'Late colour - Total no. of spots in FOV', 'Late colour - spots mask',
#        'Late colour spots normd to late ctrl, corr to Synapse spots',
#        'Late plus early colour - spots mask', 'Latecontroldir',
#        'Mean colour bias of a pixel (early=-1<x<1=late) - Whole raw image',
#        'Mean colour bias of a pixel (early=-1<x<1=late) - under late+early spots',
#        'Mean colour bias of a pixel, masked by early, late, synapses (early=-1<x<1=late)',
#        'Mean colour bias of a pixel, masked by early, late, synapses (early=-1<x<1=late) - early and late normd to corresponding ctrls',
#        'Mean correlation coefficient early/late - Whole raw image',
#        'Synapse colour - Mean intensity of spots',
#        'Synapse colour - Mean spot area [nm]',
#        'Synapse colour - Raw mean intensity',
#        'Synapse colour - Total no. of spots in FOV',
#        'Synapse colour - spots mask', 'earlychannelno', 'exp condition',
#        'exp_id', 'filename', 'latechannelno', 'synapsechannelno'],
#       dtype='object')

# %%
df2=df2.replace(to_replace='1Day_Untreated', value=onedaylabel)
df2=df2.replace(to_replace='1DayBic', value=onedaybiclabel)
df2=df2.replace(to_replace='1day_Untreated', value=onedaylabel)
df2=df2.replace(to_replace='1daybic', value=onedaybiclabel)
df2=df2.replace(to_replace='1Day_DMSO', value=onedaylabel)
df2=df2.replace(to_replace='1Day_Bic', value=onedaybiclabel)
df2=df2.replace(to_replace='1hr_DMSO', value=onehourlabel)
df2=df2.replace(to_replace='1hr_Bic', value=onehourbiclabel)
df2=df2.replace(to_replace='7hr_DMSO', value=sevenhourlabel)
df2=df2.replace(to_replace='7hr_Bic', value=sevenhourbiclabel)
df2=df2.replace(to_replace='30mins_DMSO', value=thirtyminslabel)
df2=df2.replace(to_replace='30mins_Bic', value=thirtyminsbiclabel)
df2=df2.replace(to_replace='2hr_DMSO', value=twohourlabel)
df2=df2.replace(to_replace='2hr_Bic', value=twohourbiclabel)
df2=df2.replace(to_replace='6hr_DMSO', value=sixhourlabel)
df2=df2.replace(to_replace='6hr_Bic', value=sixhourbiclabel)
df2=df2.replace(to_replace='9hr_DMSO', value=ninehourlabel)
df2=df2.replace(to_replace='9hr_Bic', value=ninehourbiclabel)
df2=df2.replace(to_replace='3hr_DMSO', value=threehourlabel)
df2=df2.replace(to_replace='3hr_Bic', value=threehourbiclabel)
df2=df2.replace(to_replace='12hr_DMSO', value=twelvehourlabel)
df2=df2.replace(to_replace='12hr_Bic', value=twelvehourbiclabel)
df2=df2.replace(to_replace='8hr_DMSO', value=eighthourlabel)
df2=df2.replace(to_replace='8hr_Bic', value=eighthourbiclabel)
df2=df2.replace(to_replace='2Day', value=twodaylabel)
df2=df2.replace(to_replace='2DayBic', value=twodaybiclabel)
df2=df2.replace(to_replace='3Day', value=threedaylabel)
df2=df2.replace(to_replace='3DayBic', value=threedaybiclabel)

# %%
df2regionprops=df2regionprops.replace(to_replace='1Day_Untreated', value=onedaylabel)
df2regionprops=df2regionprops.replace(to_replace='1DayBic', value=onedaybiclabel)
df2regionprops=df2regionprops.replace(to_replace='1day_Untreated', value=onedaylabel)
df2regionprops=df2regionprops.replace(to_replace='1daybic', value=onedaybiclabel)
df2regionprops=df2regionprops.replace(to_replace='1Day_DMSO', value=onedaylabel)
df2regionprops=df2regionprops.replace(to_replace='1Day_Bic', value=onedaybiclabel)
df2regionprops=df2regionprops.replace(to_replace='1hr_DMSO', value=onehourlabel)
df2regionprops=df2regionprops.replace(to_replace='1hr_Bic', value=onehourbiclabel)
df2regionprops=df2regionprops.replace(to_replace='7hr_DMSO', value=sevenhourlabel)
df2regionprops=df2regionprops.replace(to_replace='7hr_Bic', value=sevenhourbiclabel)
df2regionprops=df2regionprops.replace(to_replace='30mins_DMSO', value=thirtyminslabel)
df2regionprops=df2regionprops.replace(to_replace='30mins_Bic', value=thirtyminsbiclabel)
df2regionprops=df2regionprops.replace(to_replace='2hr_DMSO', value=twohourlabel)
df2regionprops=df2regionprops.replace(to_replace='2hr_Bic', value=twohourbiclabel)
df2regionprops=df2regionprops.replace(to_replace='6hr_DMSO', value=sixhourlabel)
df2regionprops=df2regionprops.replace(to_replace='6hr_Bic', value=sixhourbiclabel)
df2regionprops=df2regionprops.replace(to_replace='9hr_DMSO', value=ninehourlabel)
df2regionprops=df2regionprops.replace(to_replace='9hr_Bic', value=ninehourbiclabel)
df2regionprops=df2regionprops.replace(to_replace='3hr_DMSO', value=threehourlabel)
df2regionprops=df2regionprops.replace(to_replace='3hr_Bic', value=threehourbiclabel)
df2regionprops=df2regionprops.replace(to_replace='12hr_DMSO', value=twelvehourlabel)
df2regionprops=df2regionprops.replace(to_replace='12hr_Bic', value=twelvehourbiclabel)
df2regionprops=df2regionprops.replace(to_replace='8hr_DMSO', value=eighthourlabel)
df2regionprops=df2regionprops.replace(to_replace='8hr_Bic', value=eighthourbiclabel)
df2regionprops=df2regionprops.replace(to_replace='2Day', value=twodaylabel)
df2regionprops=df2regionprops.replace(to_replace='2DayBic', value=twodaybiclabel)
df2regionprops=df2regionprops.replace(to_replace='3Day', value=threedaylabel)
df2regionprops=df2regionprops.replace(to_replace='3DayBic', value=threedaybiclabel)

# %%
dfhists2=dfhists2.replace(to_replace='1Day_Untreated', value=onedaylabel)
dfhists2=dfhists2.replace(to_replace='1DayBic', value=onedaybiclabel)
dfhists2=dfhists2.replace(to_replace='1day_Untreated', value=onedaylabel)
dfhists2=dfhists2.replace(to_replace='1daybic', value=onedaybiclabel)
dfhists2=dfhists2.replace(to_replace='1Day_DMSO', value=onedaylabel)
dfhists2=dfhists2.replace(to_replace='1Day_Bic', value=onedaybiclabel)
dfhists2=dfhists2.replace(to_replace='1hr_DMSO', value=onehourlabel)
dfhists2=dfhists2.replace(to_replace='1hr_Bic', value=onehourbiclabel)
dfhists2=dfhists2.replace(to_replace='7hr_DMSO', value=sevenhourlabel)
dfhists2=dfhists2.replace(to_replace='7hr_Bic', value=sevenhourbiclabel)
dfhists2=dfhists2.replace(to_replace='30mins_DMSO', value=thirtyminslabel)
dfhists2=dfhists2.replace(to_replace='30mins_Bic', value=thirtyminsbiclabel)
dfhists2=dfhists2.replace(to_replace='2hr_DMSO', value=twohourlabel)
dfhists2=dfhists2.replace(to_replace='2hr_Bic', value=twohourbiclabel)
dfhists2=dfhists2.replace(to_replace='6hr_DMSO', value=sixhourlabel)
dfhists2=dfhists2.replace(to_replace='6hr_Bic', value=sixhourbiclabel)
dfhists2=dfhists2.replace(to_replace='9hr_DMSO', value=ninehourlabel)
dfhists2=dfhists2.replace(to_replace='9hr_Bic', value=ninehourbiclabel)
dfhists2=dfhists2.replace(to_replace='3hr_DMSO', value=threehourlabel)
dfhists2=dfhists2.replace(to_replace='3hr_Bic', value=threehourbiclabel)
dfhists2=dfhists2.replace(to_replace='12hr_DMSO', value=twelvehourlabel)
dfhists2=dfhists2.replace(to_replace='12hr_Bic', value=twelvehourbiclabel)
dfhists2=dfhists2.replace(to_replace='8hr_DMSO', value=eighthourlabel)
dfhists2=dfhists2.replace(to_replace='8hr_Bic', value=eighthourbiclabel)
dfhists2=dfhists2.replace(to_replace='2Day', value=twodaylabel)
dfhists2=dfhists2.replace(to_replace='2DayBic', value=twodaybiclabel)
dfhists2=dfhists2.replace(to_replace='3Day', value=threedaylabel)
dfhists2=dfhists2.replace(to_replace='3DayBic', value=threedaybiclabel)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-b13d67a776bf> in <module>()
# ----> 1 dfhists2=dfhists2.replace(to_replace='1Day_Untreated', value=onedaylabel)
#       2 dfhists2=dfhists2.replace(to_replace='1DayBic', value=onedaybiclabel)
#       3 dfhists2=dfhists2.replace(to_replace='1day_Untreated', value=onedaylabel)
#       4 dfhists2=dfhists2.replace(to_replace='1daybic', value=onedaybiclabel)
#       5 dfhists2=dfhists2.replace(to_replace='1Day_DMSO', value=onedaylabel)
#
# NameError: name 'dfhists2' is not defined

# %%
#other plots

# %%
df2.columns

# %%
vari='Early colour - Mean intensity of spots Normd to ctrls'
mean_1daybic=np.mean(df2[df2['exp condition']==onedaybiclabel][vari])
mean_1day=np.mean(df2[df2['exp condition']==onedaylabel][vari])
mean_1hourbic=np.mean(df2[df2['exp condition']==onehourbiclabel][vari])
mean_1hour=np.mean(df2[df2['exp condition']==onehourlabel][vari])
mean_7hourbic=np.mean(df2[df2['exp condition']==sevenhourbiclabel][vari])
mean_7hour=np.mean(df2[df2['exp condition']==sevenhourlabel][vari])
mean30minbic=np.mean(df2[df2['exp condition']==thirtyminsbiclabel][vari])
mean_30min=np.mean(df2[df2['exp condition']==thirtyminslabel][vari])
#mean_2hourbic=np.mean(df2[df2['exp condition']==twohourbiclabel][vari])
#mean_2hour=np.mean(df2[df2['exp condition']==twohourlabel][vari])
mean_6hourbic=np.mean(df2[df2['exp condition']==sixhourbiclabel][vari])
mean_6hour=np.mean(df2[df2['exp condition']==sixhourlabel][vari])
mean_9hourbic=np.mean(df2[df2['exp condition']==ninehourbiclabel][vari])
mean_9hour=np.mean(df2[df2['exp condition']==ninehourlabel][vari])
mean_3hourbic=np.mean(df2[df2['exp condition']==threehourbiclabel][vari])
mean_3hour=np.mean(df2[df2['exp condition']==threehourlabel][vari])
mean_12hourbic=np.mean(df2[df2['exp condition']==twelvehourbiclabel][vari])
mean_12hour=np.mean(df2[df2['exp condition']==twelvehourlabel][vari])
mean_8hourbic=np.mean(df2[df2['exp condition']==eighthourbiclabel][vari])
mean_8hour=np.mean(df2[df2['exp condition']==eighthourlabel][vari])
mean_48hourbic=np.mean(df2[df2['exp condition']==twodaybiclabel][vari])
mean_48hour=np.mean(df2[df2['exp condition']==twodaylabel][vari])
mean_72hourbic=np.mean(df2[df2['exp condition']==threedaybiclabel][vari])
mean_72hour=np.mean(df2[df2['exp condition']==threedaylabel][vari])


ratiohalfhour=mean30minbic/mean_30min
ratio1hr=mean_1hourbic/mean_1hour
#ratio2hr=mean_2hourbic/mean_2hour
ratio3hr=mean_3hourbic/mean_3hour
ratio6hr=mean_6hourbic/mean_6hour
ratio7hr=mean_7hourbic/mean_7hour
ratio8hr=mean_8hourbic/mean_8hour
ratio9hr=mean_9hourbic/mean_9hour
ratio12hr=mean_12hourbic/mean_12hour
ratio24hr=mean_1daybic/mean_1day
ratio48hr=mean_48hourbic/mean_48hour
ratio72hr=mean_72hourbic/mean_72hour

mean_1day
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Early colour - Mean intensity of spots Normd to ctrls'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-4ad77e3e94d6> in <module>()
#       1 vari='Early colour - Mean intensity of spots Normd to ctrls'
# ----> 2 mean_1daybic=np.mean(df2[df2['exp condition']==onedaybiclabel][vari])
#       3 mean_1day=np.mean(df2[df2['exp condition']==onedaylabel][vari])
#       4 mean_1hourbic=np.mean(df2[df2['exp condition']==onehourbiclabel][vari])
#       5 mean_1hour=np.mean(df2[df2['exp condition']==onehourlabel][vari])
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Early colour - Mean intensity of spots Normd to ctrls'

# %%
y=[ratiohalfhour,ratio1hr,ratio2hr,ratio3hr,ratio6hr,ratio7hr,ratio8hr,ratio9hr,ratio12hr,ratio24hr]
x=np.arange(1,len(y)+1)
labels=['30mins','1','2','3','6','7','8','9','12','24']
plt.bar(x,height=np.log(y))
plt.xticks(x,labels)
plt.title('Bic induced shift of late colour bias')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-053602fc05f0> in <module>()
# ----> 1 y=[ratiohalfhour,ratio1hr,ratio2hr,ratio3hr,ratio6hr,ratio7hr,ratio8hr,ratio9hr,ratio12hr,ratio24hr]
#       2 x=np.arange(1,len(y)+1)
#       3 labels=['30mins','1','2','3','6','7','8','9','12','24']
#       4 plt.bar(x,height=np.log(y))
#       5 plt.xticks(x,labels)
#
# NameError: name 'ratiohalfhour' is not defined

# %%
df2['Time']='None'
df2.loc[df2['exp condition'].str.contains('30'), 'Time'] = '30mins'
df2.loc[df2['exp condition'].str.contains('1hr'), 'Time'] = '1hr'
df2.loc[df2['exp condition'].str.contains('2hr'), 'Time'] = '2hr'
df2.loc[df2['exp condition'].str.contains('3hr'), 'Time'] = '3hr'
df2.loc[df2['exp condition'].str.contains('6hr'), 'Time'] = '6hr'
df2.loc[df2['exp condition'].str.contains('7hr'), 'Time'] = '7hr'
df2.loc[df2['exp condition'].str.contains('8hr'), 'Time'] = '8hr'
df2.loc[df2['exp condition'].str.contains('9hr'), 'Time'] = '9hr'
df2.loc[df2['exp condition'].str.contains('12hr'), 'Time'] = '12hr'
df2.loc[df2['exp condition'].str.contains('24hr'), 'Time'] = '24hr'

# %%
df2regionprops['Time']='None'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('30'), 'Time'] = '30mins'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('1hr'), 'Time'] = '1hr'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('2hr'), 'Time'] = '2hr'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('3hr'), 'Time'] = '3hr'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('6hr'), 'Time'] = '6hr'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('7hr'), 'Time'] = '7hr'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('8hr'), 'Time'] = '8hr'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('9hr'), 'Time'] = '9hr'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('12hr'), 'Time'] = '12hr'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('24hr'), 'Time'] = '24hr'
df2regionprops['Timeframe']='None'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('30'), 'Timeframe'] = np.nan
df2regionprops.loc[df2regionprops['exp condition'].str.contains('1hr'), 'Timeframe'] = '1-3hrs'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('2hr'), 'Timeframe'] = '1-3hrs'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('3hr'), 'Timeframe'] = '1-3hrs'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('6hr'), 'Timeframe'] = '6-9hrs'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('7hr'), 'Timeframe'] = '6-9hrs'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('8hr'), 'Timeframe'] = '6-9hrs'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('9hr'), 'Timeframe'] = '6-9hrs'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('12hr'), 'Timeframe'] = '12hrs'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('24hr'), 'Timeframe'] = '24hrs'

# %%
df2['Timeframe']='None'
df2.loc[df2['exp condition'].str.contains('30'), 'Timeframe'] = np.nan
df2.loc[df2['exp condition'].str.contains('1hr'), 'Timeframe'] = '1-3hrs'
df2.loc[df2['exp condition'].str.contains('2hr'), 'Timeframe'] = '1-3hrs'
df2.loc[df2['exp condition'].str.contains('3hr'), 'Timeframe'] = '1-3hrs'
df2.loc[df2['exp condition'].str.contains('6hr'), 'Timeframe'] = '6-9hrs'
df2.loc[df2['exp condition'].str.contains('7hr'), 'Timeframe'] = '6-9hrs'
df2.loc[df2['exp condition'].str.contains('8hr'), 'Timeframe'] = '6-9hrs'
df2.loc[df2['exp condition'].str.contains('9hr'), 'Timeframe'] = '6-9hrs'
df2.loc[df2['exp condition'].str.contains('12hr'), 'Timeframe'] = '12hrs'
df2.loc[df2['exp condition'].str.contains('24hr'), 'Timeframe'] = '24hrs'

# %%
df2['Drug']='None'
df2.loc[df2['exp condition'].str.contains('Bic'), 'Drug'] = 'Bic'

# %%
df2regionprops['Drug']='None'
df2regionprops.loc[df2regionprops['exp condition'].str.contains('Bic'), 'Drug'] = 'Bic'

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'Autofluorescencedir',
#        'Early colour - Mean intensity of spots',
#        'Early colour - Mean intensity of spots Normd to early ctrl',
#        'Early colour - Mean intensity of spots Normd to early ctrl - masked by synapses',
#        'Early colour - Mean intensity of spots only under synapses',
#        'Early colour - Mean spot area [nm]',
#        'Early colour - Raw mean intensity',
#        'Early colour - Total no. of spots in FOV', 'Early colour - spots mask',
#        'Early colour spots normd to early ctrl, corr to Synapse spots',
#        'Earlycontroldir', 'Late colour - Mean intensity of spots',
#        'Late colour - Mean intensity of spots Normd to late ctrl',
#        'Late colour - Mean intensity of spots Normd to late ctrl - masked by synapses',
#        'Late colour - Mean intensity of spots only under synapses',
#        'Late colour - Mean spot area [nm]', 'Late colour - Raw mean intensity',
#        'Late colour - Total no. of spots in FOV', 'Late colour - spots mask',
#        'Late colour spots normd to late ctrl, corr to Synapse spots',
#        'Late plus early colour - spots mask', 'Latecontroldir',
#        'Mean colour bias of a pixel (early=-1<x<1=late) - Whole raw image',
#        'Mean colour bias of a pixel (early=-1<x<1=late) - under late+early spots',
#        'Mean colour bias of a pixel, masked by early, late, synapses (early=-1<x<1=late)',
#        'Mean colour bias of a pixel, masked by early, late, synapses (early=-1<x<1=late) - early and late normd to corresponding ctrls',
#        'Mean correlation coefficient early/late - Whole raw image',
#        'Synapse colour - Mean intensity of spots',
#        'Synapse colour - Mean spot area [nm]',
#        'Synapse colour - Raw mean intensity',
#        'Synapse colour - Total no. of spots in FOV',
#        'Synapse colour - spots mask', 'earlychannelno', 'exp condition',
#        'exp_id', 'filename', 'latechannelno', 'synapsechannelno', 'Time',
#        'Timeframe', 'Drug'],
#       dtype='object')

# %%
len(df2[(df2["Drug"]=="None") & (df2["Timeframe"]=="24hrs")])
# Out:
# 202

# %%
vari="Late colour - Raw mean intensity"

'''mean30minbic=df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="30mins")].mean()
n30minbic=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="30mins")])
mean30min=df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="30mins")].mean()
n30min=len(df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="30mins")])

mean_1hourbic=df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="1hr")].mean()
n1hrbic=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="1hr")])
mean_1hour=df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="1hr")].mean()
n1hr=len(df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="1hr")])

mean_2hourbic=df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="2hr")].mean()
n2hrbic=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="2hr")])
mean_2hour=df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="2hr")].mean()
n2hr=len(df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="2hr")])

mean_3hourbic=df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="3hr")].mean()
n3hrbic=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="3hr")])
mean_3hour=df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="3hr")].mean()
n3hr=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="3hr")])

mean_6hourbic=df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="6hr")].mean()
n6hrbic=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="6hr")])
mean_6hour=df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="6hr")].mean()
n6hr=len(df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="6hr")])

mean_7hourbic=df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="7hr")].mean()
n7hrbic=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="7hr")])
mean_7hour=df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="7hr")].mean()
n7hr=len(df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="7hr")])

mean_8hourbic=df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="8hr")].mean()
n8hrbic=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="8hr")])
mean_8hour=df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="8hr")].mean()
n8hr=len(df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="8hr")])

mean_9hourbic=df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="9hr")].mean()
n9hrbic=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="9hr")])
mean_9hour=df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="9hr")].mean()
n9hr=len(df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="9hr")])

mean_12hourbic=df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="12hr")].mean()
n12hrbic=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="12hr")])
mean_12hour=df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="12hr")].mean()
n12hr=len(df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="12hr")])

mean_24hourbic=df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="24hr")].mean()
n24hrbic=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Time"]=="24hr")])
mean_24hour=df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="24hr")].mean()
n24hr=len(df2[vari][(df2["Drug"]=="None") & (df2["Time"]=="24hr")])'''

mean1to3bic=df2[vari][(df2["Drug"]=="Bic") & (df2["Timeframe"]=="1-3hrs")].mean()
n1to3bic=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Timeframe"]=="1-3hrs")])
mean1to3=df2[vari][(df2["Drug"]=="None") & (df2["Timeframe"]=="1-3hrs")].mean()
n1to3=len(df2[vari][(df2["Drug"]=="None") & (df2["Timeframe"]=="1-3hrs")])
mean6to9bic=df2[vari][(df2["Drug"]=="Bic") & (df2["Timeframe"]=="6-9hrs")].mean()
n6to9bic=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Timeframe"]=="6-9hrs")])
mean6to9=df2[vari][(df2["Drug"]=="None") & (df2["Timeframe"]=="6-9hrs")].mean()
n6to9=len(df2[vari][(df2["Drug"]=="None") & (df2["Timeframe"]=="6-9hrs")])
mean12bic=df2[vari][(df2["Drug"]=="Bic") & (df2["Timeframe"]=="12hrs")].mean()
n12bic=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Timeframe"]=="12hrs")])
mean12=df2[vari][(df2["Drug"]=="None") & (df2["Timeframe"]=="12hrs")].mean()
n12=len(df2[vari][(df2["Drug"]=="None") & (df2["Timeframe"]=="12hrs")])
mean24bic=df2[vari][(df2["Drug"]=="Bic") & (df2["Timeframe"]=="24hrs")].mean()
n24bic=len(df2[vari][(df2["Drug"]=="Bic") & (df2["Timeframe"]=="24hrs")])
mean24=df2[vari][(df2["Drug"]=="None") & (df2["Timeframe"]=="24hrs")].mean()
n24=len(df2[vari][(df2["Drug"]=="None") & (df2["Timeframe"]=="24hrs")])
ratio1to3=mean1to3bic/mean1to3
ratio6to9=mean6to9bic/mean6to9
#ratio12=mean12bic/mean12
ratio24=mean24bic/mean24



diff30=mean30minbic-mean30min
diff1=mean_1hourbic-mean_1hour
diff2=mean_2hourbic-mean_2hour
diff3=mean_3hourbic-mean_3hour
diff6=mean_6hourbic-mean_6hour
diff7=mean_7hourbic-mean_7hour
diff8=mean_8hourbic-mean_8hour
diff9=mean_9hourbic-mean_9hour
diff12=mean_12hourbic-mean_12hour
diff24=mean_24hourbic-mean_24hour

'''ratiohalfhour=mean30minbic/mean30min
ratio1hr=mean_1hourbic/mean_1hour
#ratio2hr=mean_2hourbic/mean_2hour
ratio3hr=mean_3hourbic/mean_3hour
ratio6hr=mean_6hourbic/mean_6hour
ratio7hr=mean_7hourbic/mean_7hour
ratio8hr=mean_8hourbic/mean_8hour
ratio9hr=mean_9hourbic/mean_9hour
ratio12hr=mean_12hourbic/mean_12hour
ratio24hr=mean_24hourbic/mean_24hour'''

twofoldchange_halfhour=np.log2(mean30minbic)-np.log2(mean30min)
twofoldchange_1hr=np.log2(mean_1hourbic)-np.log2(mean_1hour)
twofoldchange_2hr=np.log2(mean_2hourbic)-np.log2(mean_2hour)
twofoldchange_3hr=np.log2(mean_3hourbic)-np.log2(mean_3hour)
twofoldchange_6hr=np.log2(mean_6hourbic)-np.log2(mean_6hour)
twofoldchange_7hr=np.log2(mean_7hourbic)-np.log2(mean_7hour)
twofoldchange_8hr=np.log2(mean_8hourbic)-np.log2(mean_8hour)
twofoldchange_9hr=np.log2(mean_9hourbic)-np.log2(mean_9hour)
twofoldchange_12hr=np.log2(mean_12hourbic)-np.log2(mean_12hour)
twofoldchange_24hr=np.log2(mean_24hourbic)-np.log2(mean_24hour)


#ns=[n1hr+n1hrbic,n2hr+n2hrbic,n3hr+n3hrbic,n6hr+n6hrbic,n7hr+n7hrbic,n8hr+n8hrbic,n9hr+n9hrbic,n12hr+n12hrbic,n24hr+n24hrbic]
ns=[n1to3bic+n1to3,n6to9bic+n6to9,n24+n24bic]

print(ratiohalfhour,ratio1hr,ratio2hr,ratio3hr,mean_2hour,mean_3hourbic,mean_3hour,mean_6hourbic,mean_6hour,
     mean_7hourbic,mean_7hour,mean_8hourbic,mean_8hour,mean_9hourbic,mean_9hour,mean_12hourbic,mean_12hour,
     mean_24hourbic,mean_24hour)

print(twofoldchange_halfhour,twofoldchange_1hr,twofoldchange_2hr,twofoldchange_3hr,twofoldchange_6hr,
     twofoldchange_7hr,twofoldchange_8hr,twofoldchange_9hr,twofoldchange_12hr,twofoldchange_24hr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-7ac1f5ced50d> in <module>()
#      74
#      75
# ---> 76 diff30=mean30minbic-mean30min
#      77 diff1=mean_1hourbic-mean_1hour
#      78 diff2=mean_2hourbic-mean_2hour
#
# NameError: name 'mean30minbic' is not defined

# %%
y1 = np.log2([ratio1to3,ratio6to9,ratio12hr,ratio24hr])
print(y1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-422edde8ba71> in <module>()
# ----> 1 y1 = np.log2([ratio1to3,ratio6to9,ratio12hr,ratio24hr])
#       2 print(y1)
#
# NameError: name 'ratio12hr' is not defined

# %%
sns.set(style="white", context="talk")
# Set up the matplotlib figure
f, ax1 = plt.subplots(1, 1, figsize=(9, 5))

# Generate some sequential data
y2 = np.log2([ratio1hr,ratio2hr,ratio3hr,ratio6hr,ratio7hr,ratio8hr,ratio9hr,ratio12hr,ratio24hr])
#labels=['1hr','2hr','3hr','6hr','7hr','8hr','9hr','12hr','24hr']
labels=['1-3hrs','6-9hrs','24hrs']
y1 = ([twofoldchange_1hr,twofoldchange_2hr,twofoldchange_3hr,twofoldchange_6hr,
     twofoldchange_7hr,twofoldchange_8hr,twofoldchange_9hr,twofoldchange_24hr])
y1=([diff1,diff2,diff3,diff6,diff7,diff8,diff9,diff12,diff24])
y3 = np.log2([ratio1to3,ratio6to9,ratio24])


x1 = np.array(labels)
sns.barplot(x=x1, y=y3, palette="GnBu_d", ax=ax1)
ax1.axhline(0, color="k", clip_on=False)
ax1.set_ylabel("log(Bic/Ctrl)")
plt.xticks(rotation=45)
ax1.set_title('Bic-induced change in '+vari)
ax1.set_ylim(top=np.max(y3)+0.2,bottom=np.min(y3)-0.2)
#ax1.set_xlim(left=0,right=5)
ax2=plt.bar(x=np.arange(0,len(y3)),height=y3,visible=False)
counter=0
for i in ax2:
    samples=ns[counter]
    counter=counter+1
    height=i.get_height()
    print(height)
    ax1.text(i.get_x() + i.get_width()/2.0, height+np.sign(height)*0.05, str(samples), ha='center',va='bottom',
             fontsize=15,fontstyle='italic')

sns.despine(bottom=True)
plt.tight_layout(h_pad=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-0842de212779> in <module>()
#       4
#       5 # Generate some sequential data
# ----> 6 y2 = np.log2([ratio1hr,ratio2hr,ratio3hr,ratio6hr,ratio7hr,ratio8hr,ratio9hr,ratio12hr,ratio24hr])
#       7 #labels=['1hr','2hr','3hr','6hr','7hr','8hr','9hr','12hr','24hr']
#       8 labels=['1-3hrs','6-9hrs','24hrs']
#
# NameError: name 'ratio1hr' is not defined

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'Autofluorescencedir',
#        'Early colour - Mean intensity of spots',
#        'Early colour - Mean intensity of spots Normd to early ctrl',
#        'Early colour - Mean intensity of spots Normd to early ctrl - masked by synapses',
#        'Early colour - Mean intensity of spots only under synapses',
#        'Early colour - Mean spot area [nm]',
#        'Early colour - Raw mean intensity',
#        'Early colour - Total no. of spots in FOV', 'Early colour - spots mask',
#        'Early colour spots normd to early ctrl, corr to Synapse spots',
#        'Earlycontroldir', 'Late colour - Mean intensity of spots',
#        'Late colour - Mean intensity of spots Normd to late ctrl',
#        'Late colour - Mean intensity of spots Normd to late ctrl - masked by synapses',
#        'Late colour - Mean intensity of spots only under synapses',
#        'Late colour - Mean spot area [nm]', 'Late colour - Raw mean intensity',
#        'Late colour - Total no. of spots in FOV', 'Late colour - spots mask',
#        'Late colour spots normd to late ctrl, corr to Synapse spots',
#        'Late plus early colour - spots mask', 'Latecontroldir',
#        'Mean colour bias of a pixel (early=-1<x<1=late) - Whole raw image',
#        'Mean colour bias of a pixel (early=-1<x<1=late) - under late+early spots',
#        'Mean colour bias of a pixel, masked by early, late, synapses (early=-1<x<1=late)',
#        'Mean colour bias of a pixel, masked by early, late, synapses (early=-1<x<1=late) - early and late normd to corresponding ctrls',
#        'Mean correlation coefficient early/late - Whole raw image',
#        'Synapse colour - Mean intensity of spots',
#        'Synapse colour - Mean spot area [nm]',
#        'Synapse colour - Raw mean intensity',
#        'Synapse colour - Total no. of spots in FOV',
#        'Synapse colour - spots mask', 'earlychannelno', 'exp condition',
#        'exp_id', 'filename', 'latechannelno', 'synapsechannelno', 'Time',
#        'Timeframe', 'Drug'],
#       dtype='object')

# %%
def expname(x):
    return("/".join(x.split("/")[:-2]))

# %%
df2[df2["Timeframe"]=="24hrs"]["exp_id"].iloc[400]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-b2d5ab15d383> in <module>()
# ----> 1 df2[df2["Timeframe"]=="24hrs"]["exp_id"].iloc[400]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1371
#    1372             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1373             return self._getitem_axis(maybe_callable, axis=axis)
#    1374
#    1375     def _is_scalar_access(self, key):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1828
#    1829             # validate the location
# -> 1830             self._is_valid_integer(key, axis)
#    1831
#    1832             return self._get_loc(key, axis=axis)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _is_valid_integer(self, key, axis)
#    1711         l = len(ax)
#    1712         if key >= l or key < -l:
# -> 1713             raise IndexError("single positional indexer is out-of-bounds")
#    1714         return True
#    1715
#
# IndexError: single positional indexer is out-of-bounds

# %%
df2["expdate"]=df2.apply(lambda row: expname(row["filename"]),axis=1)

# %%
df2["expdate"].unique()
# Out:
# array(['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180602_Turnover_Bic_Timepoints_nb635first_580second_use',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180214_Turnover_Bic_TNR_nb580first_nb653psecond_use',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180620_Turnover_Bic_TNR_Timepoints_nb635first_580second_use',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180705_Turnover_Bic_TNR_Timepoints_nb580first_635second_use',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use'],
#       dtype=object)

# %%
df2=df2.append({'Timeframe':'Total','Early colour - Mean intensity Normd to ctrls':1.,'Late colour - Mean intensity Normd to ctrls':1.,'Drug':'Bic'},ignore_index=True)

# %%
df2['Early colour - Mean intensity of spots norm2max'] = df2["Early colour - Mean intensity of spots"]/df2.groupby(["expdate"])["Early colour - Mean intensity of spots"].transform('max')
df2['Late colour - Mean intensity of spots norm2max'] = df2["Late colour - Mean intensity of spots"]/df2.groupby(["expdate"])["Late colour - Mean intensity of spots"].transform('max')

# %%
df2['Synapse colour - Mean intensity of spots norm2max'] = df2["Synapse colour - Mean intensity of spots"]/df2.groupby(["expdate"])["Synapse colour - Mean intensity of spots"].transform('max')

# %%
df2.loc[df2['expdate'].str.contains("20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use"), 'expid'] = "20180220"
df2.loc[df2['expdate'].str.contains("20180511_Turnover_Bic_nb580first_635psecond_use/TNR"), 'expid'] = "20180511"
df2.loc[df2['expdate'].str.contains("20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second"), 'expid'] = "20180710_TP"
df2.loc[df2['expdate'].str.contains("20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second"), 'expid'] = "20180710_TP2"
df2.loc[df2['expdate'].str.contains("20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR"), 'expid'] = "20180501"
df2.loc[df2['expdate'].str.contains("20180602_Turnover_Bic_Timepoints_nb635first_580second_use"), 'expid'] = "20180602_TP"
df2.loc[df2['expdate'].str.contains("20180214_Turnover_Bic_TNR_nb580first_nb653psecond_use"), 'expid'] = "20180214"
df2.loc[df2['expdate'].str.contains("20180620_Turnover_Bic_TNR_Timepoints_nb635first_580second_use"), 'expid'] = "20180620_TP"
df2.loc[df2['expdate'].str.contains("20180705_Turnover_Bic_TNR_Timepoints_nb580first_635second_use"), 'expid'] = "20180705_TP"
df2.loc[df2['expdate'].str.contains("20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use"), 'expid'] = "20180426"

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'Autofluorescencedir',
#        'Early colour - Mean intensity of spots',
#        'Early colour - Mean intensity of spots Normd to early ctrl',
#        'Early colour - Mean intensity of spots Normd to early ctrl - masked by synapses',
#        'Early colour - Mean intensity of spots only under synapses',
#        'Early colour - Mean spot area [nm]',
#        'Early colour - Raw mean intensity',
#        'Early colour - Total no. of spots in FOV', 'Early colour - spots mask',
#        'Early colour spots normd to early ctrl, corr to Synapse spots',
#        'Earlycontroldir', 'Late colour - Mean intensity of spots',
#        'Late colour - Mean intensity of spots Normd to late ctrl',
#        'Late colour - Mean intensity of spots Normd to late ctrl - masked by synapses',
#        'Late colour - Mean intensity of spots only under synapses',
#        'Late colour - Mean spot area [nm]', 'Late colour - Raw mean intensity',
#        'Late colour - Total no. of spots in FOV', 'Late colour - spots mask',
#        'Late colour spots normd to late ctrl, corr to Synapse spots',
#        'Late plus early colour - spots mask', 'Latecontroldir',
#        'Mean colour bias of a pixel (early=-1<x<1=late) - Whole raw image',
#        'Mean colour bias of a pixel (early=-1<x<1=late) - under late+early spots',
#        'Mean colour bias of a pixel, masked by early, late, synapses (early=-1<x<1=late)',
#        'Mean colour bias of a pixel, masked by early, late, synapses (early=-1<x<1=late) - early and late normd to corresponding ctrls',
#        'Mean correlation coefficient early/late - Whole raw image',
#        'Synapse colour - Mean intensity of spots',
#        'Synapse colour - Mean spot area [nm]',
#        'Synapse colour - Raw mean intensity',
#        'Synapse colour - Total no. of spots in FOV',
#        'Synapse colour - spots mask', 'earlychannelno', 'exp condition',
#        'exp_id', 'filename', 'latechannelno', 'synapsechannelno', 'Time',
#        'Timeframe', 'Drug', 'expdate',
#        'Early colour - Mean intensity of spots norm2max',
#        'Late colour - Mean intensity of spots norm2max', 'expid'],
#       dtype='object')

# %%
vari="Early colour - Mean intensity of spots Normd to early ctrl"
#vari2="Mean colour bias of a pixel (early=-1<x<1=late) - under late+early spots"


sns.set(font_scale=1)


#orderlab=['30mins','1hr','2hr','3hr','6hr','7hr','8hr','9hr','12hr','24hr']
orderlab=['Total','1-3hrs','6-9hrs','24hrs']
orderlabfull=['1hr','2hr','3hr','6hr','7hr','8hr','9hr','12hr','24hr']
fig10=plt.figure(figsize=(30,20))#

#sns.pointplot('size', 'total_bill', 'sex', tips, dodge=True)
d=sns.pointplot(y=vari, x='Time',data=df3,hue='expid',
                 ci=None,
                 order=orderlabfull)
'''d=sns.pointplot(y=vari, x='Timeframe',data=df3[df3["Drug"]=="None"],hue='expid',
                 ci=None,
                 order=orderlab)'''
# Out:
# 'd=sns.pointplot(y=vari, x=\'Timeframe\',data=df3[df3["Drug"]=="None"],hue=\'expid\',\n                 ci=None,\n                 order=orderlab)'

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'Autofluorescencedir',
#        'Early colour - Mean intensity of spots',
#        'Early colour - Mean intensity of spots Normd to early ctrl',
#        'Early colour - Mean intensity of spots Normd to early ctrl - masked by synapses',
#        'Early colour - Mean intensity of spots only under synapses',
#        'Early colour - Mean spot area [nm]',
#        'Early colour - Raw mean intensity',
#        'Early colour - Total no. of spots in FOV', 'Early colour - spots mask',
#        'Early colour spots normd to early ctrl, corr to Synapse spots',
#        'Earlycontroldir', 'Late colour - Mean intensity of spots',
#        'Late colour - Mean intensity of spots Normd to late ctrl',
#        'Late colour - Mean intensity of spots Normd to late ctrl - masked by synapses',
#        'Late colour - Mean intensity of spots only under synapses',
#        'Late colour - Mean spot area [nm]', 'Late colour - Raw mean intensity',
#        'Late colour - Total no. of spots in FOV', 'Late colour - spots mask',
#        'Late colour spots normd to late ctrl, corr to Synapse spots',
#        'Late plus early colour - spots mask', 'Latecontroldir',
#        'Mean colour bias of a pixel (early=-1<x<1=late) - Whole raw image',
#        'Mean colour bias of a pixel (early=-1<x<1=late) - under late+early spots',
#        'Mean colour bias of a pixel, masked by early, late, synapses (early=-1<x<1=late)',
#        'Mean colour bias of a pixel, masked by early, late, synapses (early=-1<x<1=late) - early and late normd to corresponding ctrls',
#        'Mean correlation coefficient early/late - Whole raw image',
#        'Synapse colour - Mean intensity of spots',
#        'Synapse colour - Mean spot area [nm]',
#        'Synapse colour - Raw mean intensity',
#        'Synapse colour - Total no. of spots in FOV',
#        'Synapse colour - spots mask', 'earlychannelno', 'exp condition',
#        'exp_id', 'filename', 'latechannelno', 'synapsechannelno', 'Time',
#        'Timeframe', 'Drug', 'expdate', 'expid'],
#       dtype='object')

# %%
df3=df2[df2["expdate"].str.contains("Timepoints")]

vari="Early colour - Mean intensity of spots"

vari2="Late colour - Mean intensity of spots"

sns.set(font_scale=1)

early1to3=df3[df3["Time"]=="1-3hrs"][vari]
late1to3=df3[df3["Time"]=="1-3hrs"][vari2]
early6to9=df3[df3["Time"]=="6-9hrs"][vari]
late6to9=df3[df3["Time"]=="6-9hrs"][vari2]
early24=df3[df3["Time"]=="24hrs"][vari]
late24=df3[df3["Time"]=="24hrs"][vari2]

earlyBic1to3=df3[(df3["Drug"]=="Bic")&(df3["Time"]=="1-3hrs")][vari]
earlyNoBic1to3=df3[(df3["Drug"]=="None")&(df3["Time"]=="1-3hrs")][vari]
lateBic1to3=df3[(df3["Drug"]=="Bic")&(df3["Time"]=="1-3hrs")][vari2]
lateNoBic1to3=df3[(df3["Drug"]=="None")&(df3["Time"]=="1-3hrs")][vari2]
earlyBic6to9=df3[(df3["Drug"]=="Bic")&(df3["Time"]=="6-9hrs")][vari]
earlyNoBic6to9=df3[(df3["Drug"]=="None")&(df3["Time"]=="6-9hrs")][vari]
lateBic6to9=df3[(df3["Drug"]=="Bic")&(df3["Time"]=="6-9hrs")][vari2]
lateNoBic6to9=df3[(df3["Drug"]=="None")&(df3["Time"]=="6-9hrs")][vari2]
earlyBic24=df3[(df3["Drug"]=="Bic")&(df3["Time"]=="24hrs")][vari]
earlyNoBic24=df3[(df3["Drug"]=="None")&(df3["Time"]=="24hrs")][vari]
lateBic24=df3[(df3["Drug"]=="Bic")&(df3["Time"]=="24hrs")][vari2]
lateNoBic24=df3[(df3["Drug"]=="None")&(df3["Time"]=="24hrs")][vari2]
#all
#orderlab=['30mins','1hr','2hr','3hr','6hr','7hr','8hr','9hr','12hr','24hr']
orderlab=['Total','1-3hrs','6-9hrs','24hrs']
orderlabfull=['1hr','2hr','3hr','6hr','7hr','8hr','9hr','12hr','24hr']

fig10=plt.figure(figsize=(10,10))#
fig10.add_subplot(221)
d=sns.barplot(y=vari, x='Time',data=df3,ci=None,
                 order=orderlabfull)
plt.errorbar(x=[1,2,3],
             y=[early1to3.mean(),early6to9.mean(),early24.mean()],
             yerr=[early1to3.sem(),early6to9.sem(),early24.sem()],xerr=None,ecolor='black',fmt='none',capsize=2,capthick=2)

fig10.add_subplot(223)
d=sns.barplot(y=vari2, x='Time',data=df3,ci=None,
                 order=orderlabfull)
plt.errorbar(x=[1,2,3],
             y=[late1to3.mean(),late6to9.mean(),late24.mean()],
             yerr=[late1to3.sem(),late6to9.sem(),late24.sem()],xerr=None,ecolor='black',fmt='none',capsize=2,capthick=2)

fig10.add_subplot(222)
d=sns.barplot(y=vari, x='Time',data=df3,hue="Drug",hue_order=["None","Bic"],ci=None,
                 order=orderlabfull)
plt.errorbar(x=[.8,1.2,1.8,2.2,2.8,3.2],
             y=[earlyNoBic1to3.mean(),earlyBic1to3.mean(),earlyNoBic6to9.mean(),earlyBic6to9.mean(),earlyNoBic24.mean(),earlyBic24.mean()],
             yerr=[earlyNoBic1to3.sem(),earlyBic1to3.sem(),earlyNoBic6to9.sem(),earlyBic6to9.sem(),earlyNoBic24.sem(),earlyBic24.sem()],
             xerr=None,ecolor='black',fmt='none',capsize=2,capthick=2)

fig10.add_subplot(224)
d=sns.barplot(y=vari2, x='Time',data=df3,hue="Drug",hue_order=["None","Bic"],ci=None,
                 order=orderlabfull)
plt.errorbar(x=[.8,1.2,1.8,2.2,2.8,3.2],
             y=[lateNoBic1to3.mean(),lateBic1to3.mean(),lateNoBic6to9.mean(),lateBic6to9.mean(),lateNoBic24.mean(),lateBic24.mean()],
             yerr=[lateNoBic1to3.sem(),lateBic1to3.sem(),lateNoBic6to9.sem(),lateBic6to9.sem(),lateNoBic24.sem(),lateBic24.sem()],
             xerr=None,ecolor='black',fmt='none',capsize=2,capthick=2)
# Out:
# <Container object of 3 artists>

# %%
#vari="Early colour - Mean intensity of spots Normd to ctrls"

#vari2="Late colour - Mean intensity of spots Normd to ctrls"


sns.set(font_scale=2)


#orderlab=['30mins','1hr','2hr','3hr','6hr','7hr','8hr','9hr','12hr','24hr']
orderlab=['Total','1-3hrs','6-9hrs','24hrs']
orderlabi=['1hr','2hr','3hr','6hr','7hr','8hr','9hr','12hr','24hr']
fig10=plt.figure(figsize=(30,20))#
fig10.add_subplot(121)
d=sns.pointplot(y=vari, x='Time',data=df2[df2["expdate"].str.contains("Timepoints")],hue='Drug',
                 hue_order=['None','Bic'],ci=None,
                 split=True,order=orderlab,legend_out=True)

NoBic0=1
Bic0=1
Bic1to3=df2[(df2["Drug"]=="Bic")&(df2["Timeframe"]=="1-3hrs")][vari]
NoBic1to3=df2[(df2["Drug"]=="None")&(df2["Timeframe"]=="1-3hrs")][vari]
Bic6to9=df2[(df2["Drug"]=="Bic")&(df2["Timeframe"]=="6-9hrs")][vari]
NoBic6to9=df2[(df2["Drug"]=="None")&(df2["Timeframe"]=="6-9hrs")][vari]
#Bic12=df2[(df2["Drug"]=="Bic")&(df2["Timeframe"]=="12hrs")][vari]
#NoBic12=df2[(df2["Drug"]=="None")&(df2["Timeframe"]=="12hrs")][vari]
Bic24=df2[(df2["Drug"]=="Bic")&(df2["Timeframe"]=="24hrs")][vari]
NoBic24=df2[(df2["Drug"]=="None")&(df2["Timeframe"]=="24hrs")][vari]

yerrorsbic=[Bic1to3.sem(),Bic6to9.sem(),Bic24.sem()]
yerrorsnobic=[NoBic1to3.sem(),NoBic6to9.sem(),NoBic24.sem()]

plt.errorbar(x=[1,2,3],
             y=[Bic1to3.mean(),Bic6to9.mean(),Bic24.mean()],
             yerr=yerrorsbic,xerr=None,ecolor='orange',fmt='none',capsize=2)
plt.errorbar(x=[1,2,3],
             y=[NoBic1to3.mean(),NoBic6to9.mean(),NoBic24.mean()],
             yerr=yerrorsnobic,xerr=None,ecolor='blue',fmt='none',capsize=2)

fig10.add_subplot(122)
d=sns.pointplot(y=vari2, x='Time',data=df2[df2["expdate"].str.contains("Timepoints")],hue='Drug',
                 hue_order=['None','Bic'],ci=None,
                 split=True,order=orderlab,legend_out=True,row="expdate")

NoBic0=1
Bic0=1
aBic1to3=df2[(df2["Drug"]=="Bic")&(df2["Timeframe"]=="1-3hrs")][vari2]
aNoBic1to3=df2[(df2["Drug"]=="None")&(df2["Timeframe"]=="1-3hrs")][vari2]
aBic6to9=df2[(df2["Drug"]=="Bic")&(df2["Timeframe"]=="6-9hrs")][vari2]
aNoBic6to9=df2[(df2["Drug"]=="None")&(df2["Timeframe"]=="6-9hrs")][vari2]
aBic12=df2[(df2["Drug"]=="Bic")&(df2["Timeframe"]=="12hrs")][vari]
aNoBic12=df2[(df2["Drug"]=="None")&(df2["Timeframe"]=="12hrs")][vari]
aBic24=df2[(df2["Drug"]=="Bic")&(df2["Timeframe"]=="24hrs")][vari2]
aNoBic24=df2[(df2["Drug"]=="None")&(df2["Timeframe"]=="24hrs")][vari2]

yerrorsbic=[aBic1to3.sem(),aBic6to9.sem(),aBic24.sem()]
yerrorsnobic=[aNoBic1to3.sem(),aNoBic6to9.sem(),aNoBic24.sem()]

plt.errorbar(x=[1,2,3],
             y=[aBic1to3.mean(),aBic6to9.mean(),aBic24.mean()],
             yerr=yerrorsbic,xerr=None,ecolor='orange',fmt='none',capsize=2)
plt.errorbar(x=[1,2,3],
             y=[aNoBic1to3.mean(),aNoBic6to9.mean(),aNoBic24.mean()],
             yerr=yerrorsnobic,xerr=None,ecolor='blue',fmt='none',capsize=2)
# Out:
# <Container object of 3 artists>

# %%
df2[df2["Timeframe"]=="24hrs"]["Earlycontroldir"][0]

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'Autofluorescencedir',
#        'Early colour - Mean intensity of spots',
#        'Early colour - Mean intensity of spots Normd to early ctrl',
#        'Early colour - Mean intensity of spots Normd to early ctrl - masked by synapses',
#        'Early colour - Mean intensity of spots only under synapses',
#        'Early colour - Mean spot area [nm]',
#        'Early colour - Raw mean intensity',
#        'Early colour - Total no. of spots in FOV', 'Early colour - spots mask',
#        'Early colour spots normd to early ctrl, corr to Synapse spots',
#        'Earlycontroldir', 'Late colour - Mean intensity of spots',
#        'Late colour - Mean intensity of spots Normd to late ctrl',
#        'Late colour - Mean intensity of spots Normd to late ctrl - masked by synapses',
#        'Late colour - Mean intensity of spots only under synapses',
#        'Late colour - Mean spot area [nm]', 'Late colour - Raw mean intensity',
#        'Late colour - Total no. of spots in FOV', 'Late colour - spots mask',
#        'Late colour spots normd to late ctrl, corr to Synapse spots',
#        'Late plus early colour - spots mask', 'Latecontroldir',
#        'Mean colour bias of a pixel (early=-1<x<1=late) - Whole raw image',
#        'Mean colour bias of a pixel (early=-1<x<1=late) - under late+early spots',
#        'Mean colour bias of a pixel, masked by early, late, synapses (early=-1<x<1=late)',
#        'Mean colour bias of a pixel, masked by early, late, synapses (early=-1<x<1=late) - early and late normd to corresponding ctrls',
#        'Mean correlation coefficient early/late - Whole raw image',
#        'Synapse colour - Mean intensity of spots',
#        'Synapse colour - Mean spot area [nm]',
#        'Synapse colour - Raw mean intensity',
#        'Synapse colour - Total no. of spots in FOV',
#        'Synapse colour - spots mask', 'earlychannelno', 'exp condition',
#        'exp_id', 'filename', 'latechannelno', 'synapsechannelno', 'Time',
#        'Timeframe', 'Drug', 'expdate', 'expid',
#        'Early colour - Mean intensity of spots norm2max',
#        'Late colour - Mean intensity of spots norm2max'],
#       dtype='object')

# %%
#df3=df2[df2["expdate"].str.contains("Timepoints")]
df3=df2
vars=[
       'Early colour - Mean intensity of spots',
       'Early colour - Mean intensity of spots Normd to early ctrl',
       'Early colour - Mean intensity of spots Normd to early ctrl - masked by synapses',
       'Early colour - Mean intensity of spots only under synapses',
       'Early colour - Mean spot area [nm]',
       'Early colour - Raw mean intensity',
       'Early colour - Total no. of spots in FOV', 
       'Early colour spots normd to early ctrl, corr to Synapse spots',
       'Late colour - Mean intensity of spots',
       'Late colour - Mean intensity of spots Normd to late ctrl',
       'Late colour - Mean intensity of spots Normd to late ctrl - masked by synapses',
       'Late colour - Mean intensity of spots only under synapses',
       'Late colour - Mean spot area [nm]', 'Late colour - Raw mean intensity',
       'Late colour - Total no. of spots in FOV', 
       'Late colour spots normd to late ctrl, corr to Synapse spots',
       'Mean colour bias of a pixel (early=-1<x<1=late) - Whole raw image',
       'Mean colour bias of a pixel (early=-1<x<1=late) - under late+early spots',
       'Mean colour bias of a pixel, masked by early, late, synapses (early=-1<x<1=late)',
       'Mean colour bias of a pixel, masked by early, late, synapses (early=-1<x<1=late) - early and late normd to corresponding ctrls',
       'Mean correlation coefficient early/late - Whole raw image',
       'Synapse colour - Mean intensity of spots',
       'Synapse colour - Mean spot area [nm]',
       'Synapse colour - Raw mean intensity',
       'Synapse colour - Total no. of spots in FOV',
       'Early colour - Mean intensity of spots norm2max',
       'Late colour - Mean intensity of spots norm2max']

orderlab=['1-3hrs','6-9hrs','24hrs']

sns.set_style(style='white') 
for var2plot in vars:
    plt.figure(figsize=(5,5))
    d=sns.boxplot(y=var2plot, x='Timeframe',data=df3,order=orderlab)#,hue="Drug",hue_order=["None","Bic"],
                 #order=orderlab,ci=None)
    d.grid(False)
    
    aBic1to3=df3[(df3["Drug"]=="Bic")&(df3["Timeframe"]=="1-3hrs")][var2plot]
    aNoBic1to3=df3[(df3["Drug"]=="None")&(df3["Timeframe"]=="1-3hrs")][var2plot]
    aBic6to9=df3[(df3["Drug"]=="Bic")&(df3["Timeframe"]=="6-9hrs")][var2plot]
    aNoBic6to9=df3[(df3["Drug"]=="None")&(df3["Timeframe"]=="6-9hrs")][var2plot]
    aBic12=df3[(df3["Drug"]=="Bic")&(df3["Timeframe"]=="12hrs")][var2plot]
    aNoBic12=df3[(df3["Drug"]=="None")&(df3["Timeframe"]=="12hrs")][var2plot]
    aBic24=df3[(df3["Drug"]=="Bic")&(df3["Timeframe"]=="24hrs")][var2plot]
    aNoBic24=df3[(df3["Drug"]=="None")&(df3["Timeframe"]=="24hrs")][var2plot]

    yerrorsbic=[aBic1to3.sem(),aBic6to9.sem(),aBic24.sem()]
    yerrorsnobic=[aNoBic1to3.sem(),aNoBic6to9.sem(),aNoBic24.sem()]

    plt.errorbar(x=[0.2,1.2,2.2],
             y=[aBic1to3.mean(),aBic6to9.mean(),aBic24.mean()],
             yerr=yerrorsbic,xerr=None,ecolor='black',fmt='none',capsize=2,capwidth=2)
    plt.errorbar(x=[-0.2,0.8,1.8],
             y=[aNoBic1to3.mean(),aNoBic6to9.mean(),aNoBic24.mean()],
             yerr=yerrorsnobic,xerr=None,ecolor='black',fmt='none',capsize=2,capwidth=2)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
df2[df2["Timeframe"]=="None"]["filename"].values
# Out:
# array(['/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/FixedCtrl_early_immediatelate/02_60x_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/FixedCtrl_early_immediatelate/02_60x_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/FixedCtrl_early_immediatelate/02_60x_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/FixedCtrl_early_immediatelate/02_60x_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/FixedCtrl_early_immediatelate/02_60x_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/FixedCtrl_early_immediatelate/02_60x_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/FixedCtrl_early_immediatelate/02_60x_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/FixedCtrl_early_immediatelate/02_60x_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/FixedCtrl_early_immediatelate/02_60x_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/FixedCtrl_early_immediatelate/02_60x_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_backininc_1day/04_60x_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_backininc_1day/04_60x_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_backininc_1day/04_60x_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_backininc_1day/04_60x_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_backininc_1day/04_60x_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_backininc_1day/04_60x_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_backininc_1day/04_60x_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_backininc_1day/04_60x_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_backininc_1day/04_60x_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_backininc_1day/04_60x_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_backininc_3day/5_60x_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_backininc_3day/5_60x_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_backininc_3day/5_60x_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_backininc_3day/5_60x_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_backininc_3day/5_60x_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_backininc_3day/5_60x_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_backininc_3day/5_60x_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_backininc_3day/5_60x_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_backininc_3day/5_60x_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_backininc_3day/5_60x_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_backininc_3day/5_60x_011.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_immediatemount_earlycontrol/03_60x_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_immediatemount_earlycontrol/03_60x_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_immediatemount_earlycontrol/03_60x_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_immediatemount_earlycontrol/03_60x_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_immediatemount_earlycontrol/03_60x_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_immediatemount_earlycontrol/03_60x_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_immediatemount_earlycontrol/03_60x_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_immediatemount_earlycontrol/03_60x_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_immediatemount_earlycontrol/03_60x_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Fixedctrl_early_immediatemount_earlycontrol/03_60x_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/FixedCtrl_latecolour/01_60x_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/FixedCtrl_latecolour/01_60x_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/FixedCtrl_latecolour/01_60x_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/FixedCtrl_latecolour/01_60x_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/FixedCtrl_latecolour/01_60x_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/FixedCtrl_latecolour/01_60x_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/FixedCtrl_latecolour/01_60x_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/FixedCtrl_latecolour/01_60x_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/FixedCtrl_latecolour/01_60x_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/FixedCtrl_latecolour/01_60x_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Livectrl_lateafter3day/12_2_60x_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Livectrl_lateafter3day/12_2_60x_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Livectrl_lateafter3day/12_2_60x_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Livectrl_lateafter3day/12_2_60x_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Livectrl_lateafter3day/12_2_60x_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Livectrl_lateafter3day/12_2_60x_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Livectrl_lateafter3day/12_2_60x_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Livectrl_lateafter3day/12_2_60x_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Livectrl_lateafter3day/12_2_60x_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Livectrl_lateafter3day/12_2_60x_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Livectrl_onlysecondcolour_1day_latecontrol/12_1_60x_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Livectrl_onlysecondcolour_1day_latecontrol/12_1_60x_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Livectrl_onlysecondcolour_1day_latecontrol/12_1_60x_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Livectrl_onlysecondcolour_1day_latecontrol/12_1_60x_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Livectrl_onlysecondcolour_1day_latecontrol/12_1_60x_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Livectrl_onlysecondcolour_1day_latecontrol/12_1_60x_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Livectrl_onlysecondcolour_1day_latecontrol/12_1_60x_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Livectrl_onlysecondcolour_1day_latecontrol/12_1_60x_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Livectrl_onlysecondcolour_1day_latecontrol/12_1_60x_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180220_Turnover_Bic_TNR_nb580first_nb653psecond_use/Livectrl_onlysecondcolour_1day_latecontrol/12_1_60x_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Ctrl_Autofluorescence/20180511_12_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Ctrl_Autofluorescence/20180511_12_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Ctrl_Autofluorescence/20180511_12_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Ctrl_Autofluorescence/20180511_12_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Ctrl_Autofluorescence/20180511_12_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Ctrl_Autofluorescence/20180511_12_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Ctrl_Autofluorescence/20180511_12_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Ctrl_Autofluorescence/20180511_12_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Ctrl_Autofluorescence/20180511_12_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Ctrl_Autofluorescence/20180511_12_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_FirstImmediatelySecond/20180511_02_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_FirstImmediatelySecond/20180511_02_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_FirstImmediatelySecond/20180511_02_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_FirstImmediatelySecond/20180511_02_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_FirstImmediatelySecond/20180511_02_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_FirstImmediatelySecond/20180511_02_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_FirstImmediatelySecond/20180511_02_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_FirstImmediatelySecond/20180511_02_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_FirstImmediatelySecond/20180511_02_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_FirstImmediatelySecond/20180511_02_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_FirstBackinInc1Day/20180511_04_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_FirstBackinInc1Day/20180511_04_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_FirstBackinInc1Day/20180511_04_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_FirstBackinInc1Day/20180511_04_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_FirstBackinInc1Day/20180511_04_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_FirstBackinInc1Day/20180511_04_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_FirstBackinInc1Day/20180511_04_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_FirstBackinInc1Day/20180511_04_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_FirstBackinInc1Day/20180511_04_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_FirstBackinInc1Day/20180511_04_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_09_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_09_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_09_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_09_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_09_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_09_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_09_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_09_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_09_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_09_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_09_011.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_09_012.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_09_013.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_09_014.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_09_015.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_09_016.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_09_017.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_10_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_10_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_10_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_10_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_10_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_10_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_10_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_10_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_10_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_10_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_10_011.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_10_012.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_10_013.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_10_014.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/1Day_TTX/20180511_10_015.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Fixedctrl_early_immediatemount_earlycontrol/20180511_03_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Fixedctrl_early_immediatemount_earlycontrol/20180511_03_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Fixedctrl_early_immediatemount_earlycontrol/20180511_03_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Fixedctrl_early_immediatemount_earlycontrol/20180511_03_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Fixedctrl_early_immediatemount_earlycontrol/20180511_03_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Fixedctrl_early_immediatemount_earlycontrol/20180511_03_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Fixedctrl_early_immediatemount_earlycontrol/20180511_03_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Fixedctrl_early_immediatemount_earlycontrol/20180511_03_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Fixedctrl_early_immediatemount_earlycontrol/20180511_03_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Fixedctrl_early_immediatemount_earlycontrol/20180511_03_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Livectrl_onlysecondcolour_1day_latecontrol/20180511_11_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Livectrl_onlysecondcolour_1day_latecontrol/20180511_11_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Livectrl_onlysecondcolour_1day_latecontrol/20180511_11_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Livectrl_onlysecondcolour_1day_latecontrol/20180511_11_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Livectrl_onlysecondcolour_1day_latecontrol/20180511_11_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Livectrl_onlysecondcolour_1day_latecontrol/20180511_11_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Livectrl_onlysecondcolour_1day_latecontrol/20180511_11_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Livectrl_onlysecondcolour_1day_latecontrol/20180511_11_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Livectrl_onlysecondcolour_1day_latecontrol/20180511_11_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/Livectrl_onlysecondcolour_1day_latecontrol/20180511_11_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_OnlySecondColor/20180511_01_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_OnlySecondColor/20180511_01_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_OnlySecondColor/20180511_01_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_OnlySecondColor/20180511_01_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_OnlySecondColor/20180511_01_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_OnlySecondColor/20180511_01_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_OnlySecondColor/20180511_01_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_OnlySecondColor/20180511_01_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180511_Turnover_Bic_nb580first_635psecond_use/TNR/FixedCtrl_OnlySecondColor/20180511_01_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Ctrl_Autofluorescence/180710_03_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Ctrl_Autofluorescence/180710_03_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Ctrl_Autofluorescence/180710_03_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Ctrl_Autofluorescence/180710_03_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Ctrl_Autofluorescence/180710_03_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Bad_Livectrl_onlysecondcolour_1day/180710_24_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Bad_Livectrl_onlysecondcolour_1day/180710_24_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Bad_Livectrl_onlysecondcolour_1day/180710_24_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Bad_Livectrl_onlysecondcolour_1day/180710_24_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Bad_Livectrl_onlysecondcolour_1day/180710_24_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Fixedctrl_early_immediatemount_earlycontrol/20180620_02_2_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Fixedctrl_early_immediatemount_earlycontrol/20180620_02_2_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Fixedctrl_early_immediatemount_earlycontrol/20180620_02_2_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Fixedctrl_early_immediatemount_earlycontrol/20180620_02_2_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Fixedctrl_early_immediatemount_earlycontrol/20180620_02_2_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Fixedctrl_early_immediatemount_earlycontrol/20180620_02_2_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Fixedctrl_early_immediatemount_earlycontrol/20180620_02_2_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Fixedctrl_early_immediatemount_earlycontrol/20180620_02_2_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Fixedctrl_early_immediatemount_earlycontrol/20180620_02_2_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Fixedctrl_early_immediatemount_earlycontrol/20180620_02_2_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Livectrl_onlysecondcolour_1day_latecontrol/20180620_24_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Livectrl_onlysecondcolour_1day_latecontrol/20180620_24_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Livectrl_onlysecondcolour_1day_latecontrol/20180620_24_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Livectrl_onlysecondcolour_1day_latecontrol/20180620_24_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Livectrl_onlysecondcolour_1day_latecontrol/20180620_24_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Livectrl_onlysecondcolour_1day_latecontrol/20180620_24_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Livectrl_onlysecondcolour_1day_latecontrol/20180620_24_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Livectrl_onlysecondcolour_1day_latecontrol/20180620_24_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Livectrl_onlysecondcolour_1day_latecontrol/20180620_24_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/635first_580second/Livectrl_onlysecondcolour_1day_latecontrol/20180620_24_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/LiveCtrl_FirstImmediatelySecond/180710_02_1_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/LiveCtrl_FirstImmediatelySecond/180710_02_1_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/LiveCtrl_FirstImmediatelySecond/180710_02_1_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/LiveCtrl_FirstImmediatelySecond/180710_02_1_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/Livectrl_onlysecondcolouratt0/180710_01_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/Livectrl_onlysecondcolouratt0/180710_01_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/Livectrl_onlysecondcolouratt0/180710_01_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/Livectrl_onlysecondcolouratt0/180710_01_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/Livectrl_onlysecondcolouratt0/180710_01_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/Ctrl_Autofluorescence/180710_03_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/Ctrl_Autofluorescence/180710_03_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/Ctrl_Autofluorescence/180710_03_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/Ctrl_Autofluorescence/180710_03_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/Ctrl_Autofluorescence/180710_03_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/Livectrl_early_immediatemount_earlycontrol/180710_02_2_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/Livectrl_early_immediatemount_earlycontrol/180710_02_2_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/Livectrl_early_immediatemount_earlycontrol/180710_02_2_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/Livectrl_early_immediatemount_earlycontrol/180710_02_2_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/Livectrl_early_immediatemount_earlycontrol/180710_02_2_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/Livectrl_early_immediatemount_earlycontrol/180710_02_2_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/Livectrl_early_immediatemount_earlycontrol/180710_02_2_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/Livectrl_early_immediatemount_earlycontrol/180710_02_2_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/Livectrl_early_immediatemount_earlycontrol/180710_02_2_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/Livectrl_early_immediatemount_earlycontrol/180710_02_2_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/LiveCtrl_onlysecondcolour_1day_latecontrol/180710_12_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/LiveCtrl_onlysecondcolour_1day_latecontrol/180710_12_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/LiveCtrl_onlysecondcolour_1day_latecontrol/180710_12_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/LiveCtrl_onlysecondcolour_1day_latecontrol/180710_12_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/LiveCtrl_onlysecondcolour_1day_latecontrol/180710_12_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/LiveCtrl_onlysecondcolour_1day_latecontrol/180710_12_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/LiveCtrl_onlysecondcolour_1day_latecontrol/180710_12_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/LiveCtrl_onlysecondcolour_1day_latecontrol/180710_12_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/LiveCtrl_onlysecondcolour_1day_latecontrol/180710_12_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180710_Turnover_Bic_Timepoints_TNR_nb_use/580first_635second/LiveCtrl_onlysecondcolour_1day_latecontrol/180710_12_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_09_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_09_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_09_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_09_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_09_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_09_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_09_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_09_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_09_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_09_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_09_011.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_09_012.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_09_013.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_09_014.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_09_015.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_10_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_10_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_10_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_10_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_10_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_10_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_10_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_10_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_10_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_10_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_10_011.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_10_012.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_10_013.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_10_014.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/1DayTTX/20180501_TNR_10_015.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/Ctrl_Autofluorescence/20180501_TNR_12_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/Ctrl_Autofluorescence/20180501_TNR_12_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/Ctrl_Autofluorescence/20180501_TNR_12_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/Ctrl_Autofluorescence/20180501_TNR_12_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/Ctrl_Autofluorescence/20180501_TNR_12_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/Ctrl_Autofluorescence/20180501_TNR_12_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/Ctrl_Autofluorescence/20180501_TNR_12_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/Ctrl_Autofluorescence/20180501_TNR_12_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/Ctrl_Autofluorescence/20180501_TNR_12_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/Ctrl_Autofluorescence/20180501_TNR_12_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/FixedCtrl_FirstBackinInc1Day/20180501_TNR_04_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/FixedCtrl_FirstBackinInc1Day/20180501_TNR_04_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/FixedCtrl_FirstBackinInc1Day/20180501_TNR_04_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/FixedCtrl_FirstBackinInc1Day/20180501_TNR_04_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/FixedCtrl_FirstBackinInc1Day/20180501_TNR_04_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/FixedCtrl_FirstBackinInc1Day/20180501_TNR_04_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/FixedCtrl_FirstBackinInc1Day/20180501_TNR_04_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/FixedCtrl_FirstBackinInc1Day/20180501_TNR_04_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/FixedCtrl_FirstBackinInc1Day/20180501_TNR_04_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/FixedCtrl_FirstBackinInc1Day/20180501_TNR_04_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/FixedCtrl_FirstImmediatelySecond/20180501_TNR_02_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/FixedCtrl_FirstImmediatelySecond/20180501_TNR_02_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/FixedCtrl_FirstImmediatelySecond/20180501_TNR_02_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/FixedCtrl_FirstImmediatelySecond/20180501_TNR_02_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/FixedCtrl_FirstImmediatelySecond/20180501_TNR_02_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/FixedCtrl_FirstImmediatelySecond/20180501_TNR_02_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/FixedCtrl_FirstImmediatelySecond/20180501_TNR_02_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/FixedCtrl_FirstImmediatelySecond/20180501_TNR_02_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180501_Turnover_3colours_Bic_TTX_nb580first_635second_use/TNR/FixedCtrl_FirstImmediatelySecond/20180501_TNR_02_009.nd2',
# ...
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180705_Turnover_Bic_TNR_Timepoints_nb580first_635second_use/Fixectrl_early_immediatemount_earlycontrol/180705_02_2_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180705_Turnover_Bic_TNR_Timepoints_nb580first_635second_use/Fixectrl_early_immediatemount_earlycontrol/180705_02_2_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180705_Turnover_Bic_TNR_Timepoints_nb580first_635second_use/Fixectrl_early_immediatemount_earlycontrol/180705_02_2_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180705_Turnover_Bic_TNR_Timepoints_nb580first_635second_use/Fixectrl_early_immediatemount_earlycontrol/180705_02_2_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180705_Turnover_Bic_TNR_Timepoints_nb580first_635second_use/Fixectrl_early_immediatemount_earlycontrol/180705_02_2_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180705_Turnover_Bic_TNR_Timepoints_nb580first_635second_use/Fixectrl_early_immediatemount_earlycontrol/180705_02_2_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180705_Turnover_Bic_TNR_Timepoints_nb580first_635second_use/Fixectrl_early_immediatemount_earlycontrol/180705_02_2_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180705_Turnover_Bic_TNR_Timepoints_nb580first_635second_use/Livectrl_onlysecondcolour_1day_latecontrol/20180705_24_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180705_Turnover_Bic_TNR_Timepoints_nb580first_635second_use/Livectrl_onlysecondcolour_1day_latecontrol/20180705_24_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180705_Turnover_Bic_TNR_Timepoints_nb580first_635second_use/Livectrl_onlysecondcolour_1day_latecontrol/20180705_24_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180705_Turnover_Bic_TNR_Timepoints_nb580first_635second_use/Livectrl_onlysecondcolour_1day_latecontrol/20180705_24_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180705_Turnover_Bic_TNR_Timepoints_nb580first_635second_use/Livectrl_onlysecondcolour_1day_latecontrol/20180705_24_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180705_Turnover_Bic_TNR_Timepoints_nb580first_635second_use/Livectrl_onlysecondcolour_1day_latecontrol/20180705_24_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180705_Turnover_Bic_TNR_Timepoints_nb580first_635second_use/Livectrl_onlysecondcolour_1day_latecontrol/20180705_24_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180705_Turnover_Bic_TNR_Timepoints_nb580first_635second_use/Livectrl_onlysecondcolour_1day_latecontrol/20180705_24_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180705_Turnover_Bic_TNR_Timepoints_nb580first_635second_use/Livectrl_onlysecondcolour_1day_latecontrol/20180705_24_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180705_Turnover_Bic_TNR_Timepoints_nb580first_635second_use/Livectrl_onlysecondcolour_1day_latecontrol/20180705_24_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_09_015.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_08_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_08_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_08_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_08_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_08_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_08_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_08_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_08_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_08_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_08_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_08_011.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_08_012.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_08_013.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_08_014.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_08_015.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_09_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_09_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_09_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_09_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_09_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_09_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_09_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_09_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_09_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_09_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_09_011.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_09_012.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_09_013.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/1DayTTX/20180426_TNR_09_014.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Fixedctrl_onlysecondcolour_1day/20180426_TNR_01_1_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Fixedctrl_onlysecondcolour_1day/20180426_TNR_01_1_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Fixedctrl_onlysecondcolour_1day/20180426_TNR_01_1_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Fixedctrl_onlysecondcolour_1day/20180426_TNR_01_1_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Fixedctrl_onlysecondcolour_1day/20180426_TNR_01_1_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Fixedctrl_onlysecondcolour_1day/20180426_TNR_01_1_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Fixedctrl_onlysecondcolour_1day/20180426_TNR_01_1_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Fixedctrl_onlysecondcolour_1day/20180426_TNR_01_1_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Fixedctrl_onlysecondcolour_1day/20180426_TNR_01_1_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Fixedctrl_onlysecondcolour_1day/20180426_TNR_01_1_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Fixedctrl_early_immediatemount_earlycontrol/20180426_TNR_02_1_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Fixedctrl_early_immediatemount_earlycontrol/20180426_TNR_02_1_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Fixedctrl_early_immediatemount_earlycontrol/20180426_TNR_02_1_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Fixedctrl_early_immediatemount_earlycontrol/20180426_TNR_02_1_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Fixedctrl_early_immediatemount_earlycontrol/20180426_TNR_02_1_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Fixedctrl_early_immediatemount_earlycontrol/20180426_TNR_02_1_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Fixedctrl_early_immediatemount_earlycontrol/20180426_TNR_02_1_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Fixedctrl_early_immediatemount_earlycontrol/20180426_TNR_02_1_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Fixedctrl_early_immediatemount_earlycontrol/20180426_TNR_02_1_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Fixedctrl_early_immediatemount_earlycontrol/20180426_TNR_02_1_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Ctrl_SecondColourAfter1Day_latecontrol/20180426_TNR_10_013.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Ctrl_SecondColourAfter1Day_latecontrol/20180426_TNR_10_014.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Ctrl_SecondColourAfter1Day_latecontrol/20180426_TNR_10_015.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Ctrl_SecondColourAfter1Day_latecontrol/20180426_TNR_10_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Ctrl_SecondColourAfter1Day_latecontrol/20180426_TNR_10_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Ctrl_SecondColourAfter1Day_latecontrol/20180426_TNR_10_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Ctrl_SecondColourAfter1Day_latecontrol/20180426_TNR_10_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Ctrl_SecondColourAfter1Day_latecontrol/20180426_TNR_10_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Ctrl_SecondColourAfter1Day_latecontrol/20180426_TNR_10_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Ctrl_SecondColourAfter1Day_latecontrol/20180426_TNR_10_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Ctrl_SecondColourAfter1Day_latecontrol/20180426_TNR_10_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Ctrl_SecondColourAfter1Day_latecontrol/20180426_TNR_10_009.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Ctrl_SecondColourAfter1Day_latecontrol/20180426_TNR_10_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Ctrl_SecondColourAfter1Day_latecontrol/20180426_TNR_10_011.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/Ctrl_SecondColourAfter1Day_latecontrol/20180426_TNR_10_012.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/FixedCtrl_FirstColour_ImmediatelySecond/20180426_TNR_01_2_010.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/FixedCtrl_FirstColour_ImmediatelySecond/20180426_TNR_01_2_001.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/FixedCtrl_FirstColour_ImmediatelySecond/20180426_TNR_01_2_002.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/FixedCtrl_FirstColour_ImmediatelySecond/20180426_TNR_01_2_003.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/FixedCtrl_FirstColour_ImmediatelySecond/20180426_TNR_01_2_004.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/FixedCtrl_FirstColour_ImmediatelySecond/20180426_TNR_01_2_005.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/FixedCtrl_FirstColour_ImmediatelySecond/20180426_TNR_01_2_006.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/FixedCtrl_FirstColour_ImmediatelySecond/20180426_TNR_01_2_007.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/FixedCtrl_FirstColour_ImmediatelySecond/20180426_TNR_01_2_008.nd2',
#        '/Volumes/ukps-all$/user/tdanko/Imaging/1_ECM/Culture/20180426_Turnover_TNR_Bic_TTX_nb635first_580second_use/FixedCtrl_FirstColour_ImmediatelySecond/20180426_TNR_01_2_009.nd2'],
#       dtype=object)

# %%
x=df2[varpl].values
normdvar=(x-x.mean())/x.std()
print(type(normdvar))

import scipy.stats as ss
[_,pval]=ss.kstest(normdvar,'norm')
if pval<0.05:
    print("The variable does not distribute normally")
else:
    print("The variable distributes normally")

    sns.set(font_scale=1)
fig=plt.figure(figsize=(10,5))
fig.add_subplot(121)
sns.kdeplot(df2[varpl],legend=False)
plt.title('Distribution of all conditions')
fig.add_subplot(122)
for condition in list(set(df2["Timeframe"])):
    sns.kdeplot(df2[df2["Timeframe"]==condition][varpl],legend=False)
    
    plt.legend(list(set(df2["Timeframe"])),loc='upper right')
    plt.title('Individual distribution of conditions')
# Out:
# <class 'numpy.ndarray'>
# The variable does not distribute normally

# %%
df2["Timeframe"].unique()
# Out:
# array(['None', '24hrs', '1-3hrs', '6-9hrs', nan, '12hrs'], dtype=object)

# %%
from scipy.stats import chisquare

dfchi1=pd.DataFrame()
dfchi2=pd.DataFrame()
dfchi3=pd.DataFrame()



dfchi1['1-3hrs']=(df2[df2["Timeframe"]=="1-3hrs"][varpl])
dfchi1=dfchi1.reset_index()
dfchi1=dfchi1.drop(['index'],axis=1)

dfchi2['6-9hrs']=(df2[df2["Timeframe"]=="6-9hrs"][varpl])
dfchi2=dfchi2.reset_index()
dfchi2=dfchi2.drop(['index'],axis=1)


dfchi3['24hrs']=df2[df2["Timeframe"]=="24hrs"][varpl]
dfchi3=dfchi3.reset_index()
dfchi3=dfchi3.drop(['index'],axis=1)

dfchi = pd.concat([dfchi1, dfchi2], axis=1)
dfchi=pd.concat([dfchi,dfchi3],axis=1)

dfchi['p_value']=chisquare((dfchi['1-3hrs'],dfchi['6-9hrs'],dfchi['24hrs'])).pvalue
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
from scipy.stats import chi2_contingency

class ChiSquare:
    def __init__(self, dataframe):
        self.df = dataframe
        self.p = None #P-Value
        self.chi2 = None #Chi Test Statistic
        self.dof = None
        
        self.dfTabular = None
        self.dfExpected = None
        
    def _print_chisquare_result(self, colX, alpha):
            result = ""
            if self.p<alpha:
                result="{0} is IMPORTANT for Prediction".format(colX)
            else:
                result="{0} is NOT an important predictor. (Discard {0} from model)".format(colX)

            print(result)

    def TestIndependence(self,colX,colY, alpha=0.05):
            X = self.df[colX].astype(str)
            Y = self.df[colY].astype(str)

            self.dfObserved = pd.crosstab(Y,X) 
            chi2, p, dof, expected = stats.chi2_contingency(self.dfObserved.values)
            self.p = p
            self.chi2 = chi2
            self.dof = dof 

            self.dfExpected = pd.DataFrame(expected, columns=self.dfObserved.columns, index = self.dfObserved.index)

            self._print_chisquare_result(colX, alpha)

#df = pd.pandas.read_csv("train.csv")
#df['dummyCat'] = np.random.choice([0, 1], size=(len(df),), p=[0.5, 0.5])

#Initialize ChiSquare Class

# %%
cT = ChiSquare(dfchi)

#Feature Selection
testColumns = ['6-9hrs','24hrs']
for var in testColumns:
    cT.TestIndependence(colX=var,colY="1-3hrs" )
# Out:
# 6-9hrs is NOT an important predictor. (Discard 6-9hrs from model)
# 24hrs is IMPORTANT for Prediction

# %%
###anova

stats.f_oneway(df2[varpl][df2['Timeframe'] =='1-3hrs'], 
             df2[varpl][df2['Timeframe'] =='6-9hrs'],
             df2[varpl][df2['Timeframe'] =='24hrs'])
# Out:
# F_onewayResult(statistic=46.01045668280624, pvalue=5.934597920216592e-20)

# %%
df3["Timeframe"].values.astype(str)
# Out:
# array(['24hrs', '24hrs', '24hrs', ..., '24hrs', '24hrs', '24hrs'],
#       dtype='<U6')

# %%
##tukey
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison

df3=df2[(df2["Timeframe"]!="None")&(df2["Timeframe"]!="nan")&(df2["Timeframe"]!="12hrs")]

mc = MultiComparison(df3[varpl].values,df3['Timeframe'].values.astype(str))
mc2=pairwise_tukeyhsd(df3[varpl].values,df3['Timeframe'].values.astype(str))
mc_results = mc.tukeyhsd()
print(mc_results)

''''from statsmodels.stats.libqsturng import psturng

rs = res2[1][2] / res2[1][3]

pvalues = psturng(np.abs(rs), 3, 27)
pvalues'''
# Out:
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ============================================
# group1 group2 meandiff  lower  upper  reject
# --------------------------------------------
# 1-3hrs 24hrs   0.0698   0.0443 0.0954  True
# 1-3hrs 6-9hrs  0.061    0.0355 0.0865  True
# 1-3hrs  nan    0.062    0.025  0.099   True
# 24hrs  6-9hrs -0.0088  -0.0335 0.0158 False
# 24hrs   nan   -0.0078  -0.0443 0.0286 False
# 6-9hrs  nan    0.001   -0.0354 0.0374 False
# --------------------------------------------
# "'from statsmodels.stats.libqsturng import psturng\n\nrs = res2[1][2] / res2[1][3]\n\npvalues = psturng(np.abs(rs), 3, 27)\npvalues"

# %%
from scikitposthocs import sp
sp.posthoc_conover(df3, val_col=varbl, group_col="Timeframe", p_adjust=None, sort=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-164-55ac2bb4a89b> in <module>()
# ----> 1 from scikitposthocs import sp
#       2 sp.posthoc_conover(df3, val_col=varbl, group_col="Timeframe", p_adjust=None, sort=True)
#
# ModuleNotFoundError: No module named 'scikitposthocs'

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'Autofluorescencedir',
#        'Early colour - Mean intensity of spots',
#        'Early colour - Mean intensity of spots Normd to early ctrl',
#        'Early colour - Mean intensity of spots Normd to early ctrl - masked by synapses',
#        'Early colour - Mean intensity of spots only under synapses',
#        'Early colour - Mean spot area [nm]',
#        'Early colour - Raw mean intensity',
#        'Early colour - Total no. of spots in FOV', 'Early colour - spots mask',
#        'Early colour spots normd to early ctrl, corr to Synapse spots',
#        'Earlycontroldir', 'Late colour - Mean intensity of spots',
#        'Late colour - Mean intensity of spots Normd to late ctrl',
#        'Late colour - Mean intensity of spots Normd to late ctrl - masked by synapses',
#        'Late colour - Mean intensity of spots only under synapses',
#        'Late colour - Mean spot area [nm]', 'Late colour - Raw mean intensity',
#        'Late colour - Total no. of spots in FOV', 'Late colour - spots mask',
#        'Late colour spots normd to late ctrl, corr to Synapse spots',
#        'Late plus early colour - spots mask', 'Latecontroldir',
#        'Mean colour bias of a pixel (early=-1<x<1=late) - Whole raw image',
#        'Mean colour bias of a pixel (early=-1<x<1=late) - under late+early spots',
#        'Mean colour bias of a pixel, masked by early, late, synapses (early=-1<x<1=late)',
#        'Mean colour bias of a pixel, masked by early, late, synapses (early=-1<x<1=late) - early and late normd to corresponding ctrls',
#        'Mean correlation coefficient early/late - Whole raw image',
#        'Synapse colour - Mean intensity of spots',
#        'Synapse colour - Mean spot area [nm]',
#        'Synapse colour - Raw mean intensity',
#        'Synapse colour - Total no. of spots in FOV',
#        'Synapse colour - spots mask', 'earlychannelno', 'exp condition',
#        'exp_id', 'filename', 'latechannelno', 'synapsechannelno', 'Time',
#        'Timeframe', 'Drug', 'expdate',
#        'Early colour - Mean intensity of spots norm2max',
#        'Late colour - Mean intensity of spots norm2max', 'expid'],
#       dtype='object')

# %%
varpl='Early colour - Mean intensity of spots norm2max'
varpl2='Early colour - Mean spot area [nm]'
sns.set(font_scale=2)

fig=plt.figure(figsize=(10,10))
#fig.add_subplot(121)
d=sns.boxplot(y=varpl, x='Timeframe',data=df3,order=orderlab,hue="Drug",hue_order=["None","Bic"])
                 #order=orderlab,ci=None)
d.set(ylim=(0,1.2))
d.set_ylabel('')
plt.title("Late-to-early bias")
d.grid(False)

'''x1, x2 = 0, 1   # columns 'HFS' and 'LFS'
y, h, col = df3[varpl].max() - 0.1, 0.05, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)

plt.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col)

x1, x2 = 0, 2   # columns 'HFS' and 'LFS'
y, h, col = df3[varpl].max() +0.05 , 0.05, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)

plt.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col)

##t tests
Nobic = df3[df3["Timeframe"]=="24hrs"][varpl]
Bic = df3[df3["Timeframe"]=="1-3hrs"][varpl]
[stat,pval]=stats.ttest_ind(Nobic, Bic,nan_policy='omit')
print(pval)'''

#fig.add_subplot(122)
#d=sns.boxplot(y=varpl2, x='Timeframe',data=df3[df3["Timeframe"]!="24hrs"],order=["1-3hrs","6-9hrs"],hue="Drug")#,hue="Drug",hue_order=["None","Bic"],
                 #order=orderlab,ci=None)
#d.set(ylim=(0, 1.2))
#d.set_ylabel('Pixels')
#plt.title("Mean area of 'spots'")
#d.grid(False)

x1, x2 = -0.2, 0.2   # columns 'HFS' and 'LFS'
y, h, col = df3[varpl].max() +0.06, 0.03, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)

plt.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col)

x1, x2 = 0.8, 1.2   # columns 'HFS' and 'LFS'
y, h, col = df3[varpl].max()+0.06 , 0.03, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)

plt.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col)

##t tests
Nobic = df3[(df3["Drug"]=="None")&(df3["Timeframe"]=="24hrs")][varpl]
Bic = df3[(df3["Drug"]=="Bic")&(df3["Timeframe"]=="24hrs")][varpl]
[stat,pval]=stats.ttest_ind(Nobic, Bic,nan_policy='omit')
print(pval)
# Out:
# 0.9515925767950131

# %%
df4=df2

vars=[
       'Early colour - Mean intensity of spots',
       'Early colour - Mean intensity of spots Normd to early ctrl',
       'Early colour - Mean intensity of spots Normd to early ctrl - masked by synapses',
       'Early colour - Mean intensity of spots only under synapses',
       'Early colour - Mean spot area [nm]',
       'Early colour - Raw mean intensity',
       'Early colour - Total no. of spots in FOV', 
       'Early colour spots normd to early ctrl, corr to Synapse spots',
       'Late colour - Mean intensity of spots',
       'Late colour - Mean intensity of spots Normd to late ctrl',
       'Late colour - Mean intensity of spots Normd to late ctrl - masked by synapses',
       'Late colour - Mean intensity of spots only under synapses',
       'Late colour - Mean spot area [nm]', 'Late colour - Raw mean intensity',
       'Late colour - Total no. of spots in FOV', 
       'Late colour spots normd to late ctrl, corr to Synapse spots',
       'Mean colour bias of a pixel (early=-1<x<1=late) - Whole raw image',
       'Mean colour bias of a pixel (early=-1<x<1=late) - under late+early spots',
       'Mean colour bias of a pixel, masked by early, late, synapses (early=-1<x<1=late)',
       'Mean colour bias of a pixel, masked by early, late, synapses (early=-1<x<1=late) - early and late normd to corresponding ctrls',
       'Mean correlation coefficient early/late - Whole raw image',
       'Synapse colour - Mean intensity of spots',
       'Synapse colour - Mean spot area [nm]',
       'Synapse colour - Raw mean intensity',
       'Synapse colour - Total no. of spots in FOV',
       'Early colour - Mean intensity of spots norm2max',
       'Late colour - Mean intensity of spots norm2max',
'Synapse colour - Mean intensity of spots norm2max']

orderlabi=['24hrs']
sns.set(font_scale=1.3)
sns.set_style(style='white') 
for var2plot in vars:
    plt.figure(figsize=(5,5))
    d=sns.boxplot(y=var2plot, x='Timeframe',data=df4,#,hue="Drug",hue_order=["None","Bic"],
                 order=orderlab)
    d.grid(False)
    
    aBic1to3=df4[(df4["Drug"]=="Bic")&(df4["Timeframe"]=="1-3hrs")][var2plot]
    aNoBic1to3=df4[(df4["Drug"]=="None")&(df4["Timeframe"]=="1-3hrs")][var2plot]
    aBic6to9=df4[(df4["Drug"]=="Bic")&(df4["Timeframe"]=="6-9hrs")][var2plot]
    aNoBic6to9=df4[(df4["Drug"]=="None")&(df4["Timeframe"]=="6-9hrs")][var2plot]
    aBic12=df4[(df4["Drug"]=="Bic")&(df4["Timeframe"]=="12hrs")][var2plot]
    aNoBic12=df4[(df4["Drug"]=="None")&(df4["Timeframe"]=="12hrs")][var2plot]
    aBic24=df4[(df4["Drug"]=="Bic")&(df4["Timeframe"]=="24hrs")][var2plot]
    aNoBic24=df4[(df4["Drug"]=="None")&(df4["Timeframe"]=="24hrs")][var2plot]

    yerrorsbic=[aBic24.sem()]
    yerrorsnobic=[aNoBic24.sem()]

    plt.errorbar(x=[0.2],
             y=[aBic24.mean()],
             yerr=yerrorsbic,xerr=None,ecolor='black',fmt='none',capsize=2,capwidth=2)
    plt.errorbar(x=[-0.2],
             y=[aNoBic24.mean()],
             yerr=yerrorsnobic,xerr=None,ecolor='black',fmt='none',capsize=2,capwidth=2)
    
    Nobic = df4[df4["Drug"]=="None"][var2plot]
    Bic = df4[df4["Drug"]=="Bic"][var2plot]
    [stat,pval]=stats.ttest_ind(Nobic, Bic,nan_policy='omit')
    print(pval)
    x1, x2 = 0, 1   # columns 'HFS' and 'LFS'
    y, h, col = df4[var2plot].mean() + 0.15, 0.001, 'k'
    plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
    if pval<0.001:
        plt.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col)
    elif pval<0.01:
        plt.text((x1+x2)*.5, y+h, "**", ha='center', va='bottom', color=col)
    elif pval<0.05:
        plt.text((x1+x2)*.5, y+h, "*", ha='center', va='bottom', color=col)
    else:
        plt.text((x1+x2)*.5, y+h, "ns", ha='center', va='bottom', color=col)
# Out:
# 3.2236798291764134e-06
# 0.016403081008358876
# 0.002378634289210692
# 0.9691815706653238
# 9.706234951249556e-10
# 3.629864005114475e-06
# 4.881442870184351e-05
# 5.816186116154323e-13
# 0.005966030231519798
# 0.1351957351894816
# 0.005832312450363144
# 0.48404079093467567
# 0.1885714962561447
# 0.004050274547541228
# 2.132355301032585e-05
# 0.000169888035877318
# 0.38389348922480027
# 0.04974041866644546
# 0.5150376588876135
# 0.09695627168611745
# 5.920362859352407e-07
# /anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# 0.0003735613477130815
# 0.0038116679600745957
# 4.168326678664641e-05
# 0.011413090832966334
# 0.8038817380554694
# 0.14969690855839626
# 0.0675429874964329

# %%
vari3="Late colour - Mean intensity of spots norm2max"
vari1="Early colour - Mean intensity of spots norm2max"
vari2="Synapse colour - Mean intensity of spots norm2max"

sns.set(font_scale=2)
sns.set_palette("colorblind")

#orderlab=['30mins','1hr','2hr','3hr','6hr','7hr','8hr','9hr','12hr','24hr']
orderlab=['1-3hrs','6-9hrs','12hrs','24hrs']
fig=plt.figure(figsize=(20,10)) #
fig.add_subplot(121)
#sns.pointplot('size', 'total_bill', 'sex', tips, dodge=True)
d=sns.regplot(x=vari1, y=vari2,data=df2[df2["Drug"]=="None"],truncate=True,
               color='b', scatter_kws={'s':20})
d.grid(False)

#plt.title("Synapses: Normalized fluorescence")


d=sns.regplot(x=vari1, y=vari2,data=df2[df2["Drug"]=="Bic"],truncate=True,
            color='darkorange', scatter_kws={'s':20})
d.grid(False)
d.set_ylabel('Synapses: Normalized fluorescence')
d.set_xlabel('Early colour: Normalized fluorescence')


fig.add_subplot(122)
#sns.pointplot('size', 'total_bill', 'sex', tips, dodge=True)
g=sns.regplot(x=vari3, y=vari2,data=df2[df2["Drug"]=="None"],truncate=True,
               color='b', scatter_kws={'s':20})
                 
g=sns.regplot(x=vari3, y=vari2,data=df2[df2["Drug"]=="Bic"],truncate=True,
             color='darkorange', scatter_kws={'s':20})
g.grid(False)
g.set_ylabel('')
g.set_xlabel('Late colour: Normalized fluorescence')
plt.legend(['None','Bic'])

# %%
sns.set(font_scale=1)
varib="Mean colour bias of a pixel (early=-1<x<1=late) Normd to ctrls"

orderlab=['30mins','1hr','2hr','3hr','6hr','7hr','8hr','9hr','12hr','24hr']

fig10=plt.figure(figsize=(4,4)) #
#sns.pointplot('size', 'total_bill', 'sex', tips, dodge=True)
d=sns.barplot(y=varib, x='Drug',data=df2[df2["Timeframe"]=="24hrs"],ci=90,)
Nobic = df2[(df2["Timeframe"]=="24hrs") & (df2["Drug"]=="None")][varib]
Bic = df2[(df2["Timeframe"]=="24hrs") & (df2["Drug"]=="Bic")][varib]
[stat,pval]=stats.ttest_ind(Nobic, Bic,nan_policy='omit')
print(pval)
x1, x2 = 0, 1   # columns 'HFS' and 'LFS'
y, h, col = df2[df2["Timeframe"]=="24hrs"][varib].mean() + 0.15, 0.001, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
if pval<0.001:
    plt.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col)
elif pval<0.01:
    plt.text((x1+x2)*.5, y+h, "**", ha='center', va='bottom', color=col)
elif pval<0.05:
    plt.text((x1+x2)*.5, y+h, "*", ha='center', va='bottom', color=col)
else:
    plt.text((x1+x2)*.5, y+h, "ns", ha='center', va='bottom', color=col)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-125-16f43bb545e3> in <module>()
#       6 fig10=plt.figure(figsize=(4,4)) #
#       7 #sns.pointplot('size', 'total_bill', 'sex', tips, dodge=True)
# ----> 8 d=sns.barplot(y=varib, x='Drug',data=df2[df2["Timeframe"]=="24hrs"],ci=90,)
#       9 Nobic = df2[(df2["Timeframe"]=="24hrs") & (df2["Drug"]=="None")][varib]
#      10 Bic = df2[(df2["Timeframe"]=="24hrs") & (df2["Drug"]=="Bic")][varib]
#
# /anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# /anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1605         """Initialize the plotter."""
#    1606         self.establish_variables(x, y, hue, data, orient,
# -> 1607                                  order, hue_order, units)
#    1608         self.establish_colors(color, palette, saturation)
#    1609         self.estimate_statistic(estimator, ci, n_boot)
#
# /anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153                 if isinstance(input, string_types):
#     154                     err = "Could not interpret input '{}'".format(input)
# --> 155                     raise ValueError(err)
#     156
#     157             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'Mean colour bias of a pixel (early=-1<x<1=late) Normd to ctrls'

# %%
sns.set(font_scale=2)


orderlab=['30mins','1hr','2hr','3hr','6hr','7hr','8hr','9hr','12hr','24hr']

fig10=plt.figure(figsize=(30,10)) #
#sns.pointplot('size', 'total_bill', 'sex', tips, dodge=True)
d=sns.pointplot(y='Late colour - Raw mean intensity', x='Time',data=df2,hue='Drug',
                 order=orderlab,hue_order=['None','Bic'],
                 split=True)
#d=sns.swarmplot(x='Mean colour bias of a pixel (early=-1<x<1=late) Raw', y='exp condition',data=df2,color='black')

# %%
sns.set(font_scale=2)


orderlab=['30mins','1hr','2hr','3hr','6hr','7hr','8hr','9hr','12hr','24hr']

fig10=plt.figure(figsize=(30,10)) #
#sns.pointplot('size', 'total_bill', 'sex', tips, dodge=True)
d=sns.pointplot(y='Late colour - Mean intensity of spots', x='Time',data=df2,hue='Drug',
                 order=orderlab,hue_order=['None','Bic'],
                 split=True)
#d=sns.swarmplot(x='Mean colour bias of a pixel (early=-1<x<1=late) Raw', y='exp condition',data=df2,color='black')

# %%
mean_1daybic=np.mean(df2[df2['exp condition']==onedaybiclabel]['Late colour - Mean intensity of spots'])
mean_1day=np.mean(df2[df2['exp condition']==onedaylabel]['Late colour - Mean intensity of spots'])
mean_1hourbic=np.mean(df2[df2['exp condition']==onehourbiclabel]['Late colour - Mean intensity of spots'])
mean_1hour=np.mean(df2[df2['exp condition']==onehourlabel]['Late colour - Mean intensity of spots'])
mean_7hourbic=np.mean(df2[df2['exp condition']==sevenhourbiclabel]['Late colour - Mean intensity of spots'])
mean_7hour=np.mean(df2[df2['exp condition']==sevenhourlabel]['Late colour - Mean intensity of spots'])
mean30minbic=np.mean(df2[df2['exp condition']==thirtyminsbiclabel]['Late colour - Mean intensity of spots'])
mean_30min=np.mean(df2[df2['exp condition']==thirtyminslabel]['Late colour - Mean intensity of spots'])
mean_2hourbic=np.mean(df2[df2['exp condition']==twohourbiclabel]['Late colour - Mean intensity of spots'])
mean_2hour=np.mean(df2[df2['exp condition']==twohourlabel]['Late colour - Mean intensity of spots'])
mean_6hourbic=np.mean(df2[df2['exp condition']==sixhourbiclabel]['Late colour - Mean intensity of spots'])
mean_6hour=np.mean(df2[df2['exp condition']==sixhourlabel]['Late colour - Mean intensity of spots'])
mean_9hourbic=np.mean(df2[df2['exp condition']==ninehourbiclabel]['Late colour - Mean intensity of spots'])
mean_9hour=np.mean(df2[df2['exp condition']==ninehourlabel]['Late colour - Mean intensity of spots'])
mean_3hourbic=np.mean(df2[df2['exp condition']==threehourbiclabel]['Late colour - Mean intensity of spots'])
mean_3hour=np.mean(df2[df2['exp condition']==threehourlabel]['Late colour - Mean intensity of spots'])
mean_12hourbic=np.mean(df2[df2['exp condition']==twelvehourbiclabel]['Late colour - Mean intensity of spots'])
mean_12hour=np.mean(df2[df2['exp condition']==twelvehourlabel]['Late colour - Mean intensity of spots'])
mean_8hourbic=np.mean(df2[df2['exp condition']==eighthourbiclabel]['Late colour - Mean intensity of spots'])
mean_8hour=np.mean(df2[df2['exp condition']==eighthourlabel]['Late colour - Mean intensity of spots'])
mean_48hourbic=np.mean(df2[df2['exp condition']==twodaybiclabel]['Late colour - Mean intensity of spots'])
mean_48hour=np.mean(df2[df2['exp condition']==twodaylabel]['Late colour - Mean intensity of spots'])
mean_72hourbic=np.mean(df2[df2['exp condition']==threedaybiclabel]['Late colour - Mean intensity of spots'])
mean_72hour=np.mean(df2[df2['exp condition']==threedaylabel]['Late colour - Mean intensity of spots'])


ratiohalfhour=mean30minbic/mean_30min
ratio1hr=mean_1hourbic/mean_1hour
ratio2hr=mean_2hourbic/mean_2hour
ratio3hr=mean_3hourbic/mean_3hour
ratio6hr=mean_6hourbic/mean_6hour
ratio7hr=mean_7hourbic/mean_7hour
ratio8hr=mean_8hourbic/mean_8hour
ratio9hr=mean_9hourbic/mean_9hour
ratio12hr=mean_12hourbic/mean_12hour
ratio24hr=mean_1daybic/mean_1day
ratio48hr=mean_48hourbic/mean_48hour
ratio72hr=mean_72hourbic/mean_72hour

y=[ratiohalfhour,ratio1hr,ratio2hr,ratio3hr,ratio6hr,ratio7hr,ratio8hr,ratio9hr,ratio12hr,ratio24hr]
x=np.arange(1,len(x)+1)
labels=['30mins','1','2','3','6','7','8','9','12','24']
plt.bar(x,height=np.log10(y))
plt.xticks(x,labels)
plt.title('Bic induced shift of Late colour bias')

# %%
props=df2regionprops["Early colour - regionprops"].iloc[0]

# %%
df3regionprops.columns

# %%
df3regionprops=deepcopy(df2regionprops)

# %%
for j in range(0,len(props)):
    print(props[j].perimeter)

# %%
df3regionprops['Eccentricity early']=[list() for x in range(len(df3regionprops.index))]
df3regionprops['Eccentricity late']=[list() for x in range(len(df3regionprops.index))]
df3regionprops['Eccentricity early plus late']=[list() for x in range(len(df3regionprops.index))]

# %%
for i in range(0,len(df3regionprops)):
    #empty vecs
    
    props_early=df3regionprops["Early colour - regionprops"].iloc[i]
    props_early_perim=np.zeros((len(props_early),1))
    for j in range(0,len(props_early)):
        props_early_perim[j]=props_early[j].perimeter
    df3regionprops['Perimeter early'].iloc[i]=props_early_perim
    
    props_late=df3regionprops["Late colour - regionprops"].iloc[i]
    props_late_perim=np.zeros((len(props_late),1))
    for j in range(0,len(props_late)):
        props_late_perim[j]=props_late[j].perimeter
    df3regionprops['Perimeter late'].iloc[i]=props_late_perim
    
    props_earlylate=df3regionprops["Late + early colour combined - regionprops"].iloc[i]
    props_earlylate_perim=np.zeros((len(props_earlylate),1))
    for j in range(0,len(props_earlylate)):
        props_earlylate_perim[j]=props_earlylate[j].perimeter
    df3regionprops['Perimeter early plus late'].iloc[i]=props_earlylate_perim

# %% [markdown]
# ### Regionprops plots

# %%
df3regionprops['Eccentricity early plus late mean']=np.nan

# %%
for i in range(0,len(df3regionprops)):
    
    df3regionprops['Perimeter early plus late mean'].iloc[i]=df3regionprops["Perimeter early plus late"].iloc[i].mean()

# %%
sns.set(font_scale=1)
varib1=df3regionprops["Perimeter early mean"].values.tolist()
varib2=df3regionprops["Perimeter early plus late mean"].values.tolist()

sns.kdeplot(varib1, shade=True, cut=0, label="early")
sns.kdeplot(varib2, shade=True, cut=0,label="early+late")

# %%
sns.set(font_scale=1)
varib="Perimeter early mean"

orderlab=['30mins','1hr','2hr','3hr','6hr','7hr','8hr','9hr','12hr','24hr']

fig10=plt.figure(figsize=(4,4)) #
#sns.pointplot('size', 'total_bill', 'sex', tips, dodge=True)
d=sns.barplot(y=varib, x='Drug',data=df3regionprops,hue="Timeframe",ci=90,)
Nobic = df3regionprops[(df3regionprops["Timeframe"]=="24hrs") & (df3regionprops["Drug"]=="None")][varib]
Bic = df3regionprops[(df3regionprops["Timeframe"]=="24hrs") & (df3regionprops["Drug"]=="Bic")][varib]
[stat,pval]=stats.ttest_ind(Nobic, Bic,nan_policy='omit')
print(pval)
x1, x2 = 0, 1   # columns 'HFS' and 'LFS'
y, h, col = df3regionprops[df3regionprops["Timeframe"]=="24hrs"][varib].mean() + 0.15, 0.001, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
if pval<0.001:
    plt.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col)
elif pval<0.01:
    plt.text((x1+x2)*.5, y+h, "**", ha='center', va='bottom', color=col)
elif pval<0.05:
    plt.text((x1+x2)*.5, y+h, "*", ha='center', va='bottom', color=col)
else:
    plt.text((x1+x2)*.5, y+h, "ns", ha='center', va='bottom', color=col)

# %%
sns.set(font_scale=1)
varib="Perimeter early mean"

orderlab=['30mins','1hr','2hr','3hr','6hr','7hr','8hr','9hr','12hr','24hr']

fig10=plt.figure(figsize=(4,4)) #
#sns.pointplot('size', 'total_bill', 'sex', tips, dodge=True)
d=sns.barplot(y=varib, x='Drug',data=df3regionprops[df3regionprops["Timeframe"]=="1-3hrs"],ci=None,)
Nobic = df3regionprops[(df3regionprops["Timeframe"]=="1-3hrs") & (df3regionprops["Drug"]=="None")][varib]
Bic = df3regionprops[(df3regionprops["Timeframe"]=="1-3hrs") & (df3regionprops["Drug"]=="Bic")][varib]
[stat,pval]=stats.ttest_ind(Nobic, Bic,nan_policy='omit')
print(pval)
x1, x2 = 0, 1   # columns 'HFS' and 'LFS'
y, h, col = df3regionprops[df3regionprops["Timeframe"]=="1-3hrs"][varib].mean() + 50, 0.001, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
#plt.errorbar(theta, E, yerr=0.09, xerr=0.023, capsize=0, color='#0000ff', fmt='none')

if pval<0.001:
    plt.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col)
elif pval<0.01:
    plt.text((x1+x2)*.5, y+h, "**", ha='center', va='bottom', color=col)
elif pval<0.05:
    plt.text((x1+x2)*.5, y+h, "*", ha='center', va='bottom', color=col)
else:
    plt.text((x1+x2)*.5, y+h, "ns", ha='center', va='bottom', color=col)


    
#ax2=plt.bar(x=[0,1],height=[Nobic.mean(),Bic.mean()],visible=False)
yerrors=[Nobic.sem(),Bic.sem()]
plt.errorbar(x=[0,1],y=[Nobic.mean(),Bic.mean()],yerr=yerrors,xerr=None,ecolor='black',fmt='none',capsize=2)

# %%
yerrors

# %% [markdown]
# ### Make bias image files for printing

# %%
from matplotlib.backends.backend_pdf import PdfPages


'''for condition in np.unique(df["exp condition"]):
    pdf_pages = PdfPages(expdir+'/results/'+condition + '_images_print.pdf')

    #make dictionary for files in this condition only
    exp_condition_images = [df["filename"][idx] for idx, x in enumerate(df["exp condition"]) if x == condition ]
    exp_condition_images=np.unique(exp_condition_images)
    no_images_cond=len(exp_condition_images)

    figno=1
    fig=plt.figure(figsize=(20,70))'''

for i in range(1600,1601):    
    print('Calculating image no ' + str(i+1) + ' out of' + str(len(results["filename"])))
    early_channel_no=results["earlychannelno"][i]
    late_channel_no=results["latechannelno"][i]
    synapse_channel_no=results["synapsechannelno"][i]
    with ND2Reader(results["filename"][i]) as images:
        #read the images
        early_image=images[early_channel_no-1]
        late_image=images[late_channel_no-1]
        #convert to array
        early_image=early_image.astype(np.int16)
        late_image=late_image.astype(np.int16)
        #normalize intensity to value between 0 and 1
        early_image=np.divide(early_image,16383.)
        late_image=np.divide(late_image,16383.)
        #small detour to calculate the autofluorescence
        autof={"filename":[]}
        autofpath=results["Autofluorescencedir"][i]
        if autofpath==0:
            early_autoint_mean=0
            late_autoint_mean=0
            if synapse_flag:
                synapse_autoint_mean=0
        else:
            pathy = os.path.dirname(autofpath+"/")  
            autoffilelist = []
            for root, _, filenames in os.walk(pathy):
                 for filename in filenames:
                     autoffilelist.append(os.path.join(root, filename))
            for i in range(0,len(autoffilelist)):
                if autoffilelist[i].endswith(".nd2"): 
                    autof["filename"].append(autoffilelist[i])
            earlycolour_autoint=np.zeros((len(autof["filename"]),1))
            latecolour_autoint=np.zeros((len(autof["filename"]),1))
            if synapse_flag:
                synapsecolour_autoint=np.zeros((len(autof["filename"]),1))
            for im in range(0,len(autof["filename"])):
                with ND2Reader(autof["filename"][im]) as images:
                    early_image=images[early_channel_no-1]
                    late_image=images[late_channel_no-1]
                    if synapse_flag:
                        synapse_image=images[synapse_channel_no-1]
                    #convert to array
                    early_image=early_image.astype(np.int16)
                    late_image=late_image.astype(np.int16)
                    if synapse_flag:
                        synapse_image=synapse_image.astype(np.int16)
                    #normalize intensity to value between 0 and 1
                    early_image=np.divide(early_image,16383.)
                    late_image=np.divide(late_image,16383.)
                    if synapse_flag:
                        synapse_image=np.divide(synapse_image,16383.)
                    #append mean intensity
                    earlycolour_autoint[i]=np.mean(early_image)
                    latecolour_autoint[i]=np.mean(late_image)  
                    if synapse_flag:
                        synapsecolour_autoint[i]=np.mean(synapse_image)
            #average the vectors
            early_autoint_mean=np.mean(earlycolour_autoint)
            late_autoint_mean=np.mean(latecolour_autoint) 
        #subtract autofluorescence in each channel; subtract the normalized pixel value times the max autofluorescence int
        early_image=np.subtract(early_image,early_autoint_mean)
        early_image[early_image<0]=0
        late_image=np.subtract(late_image,late_autoint_mean)
        late_image[late_image<0]=0
        #read spots masks
        early_spots=results["Early colour - spots mask"][i]
        late_spots=results["Late colour - spots mask"][i]
        lateplusearly_spots=results["Late plus early colour - spots mask"][i]
        a=late_image#[lateplusearly_spots]
        b=early_image#[lateplusearly_spots]
        spots_bias_image=(a-b)/(a+b)
        biastoearly=deepcopy(spots_bias_image)
        biasonlylate_image=deepcopy(spots_bias_image)
        biasonlylate_image=biasonlylate_image-biasonlylate_image.min()
        biasonlylate_image[~lateplusearly_spots]=0
        biasonlylate_image[biasonlylate_image<0.6*biasonlylate_image.max()]=0
        biasonlylate_mask=biasonlylate_image>0
        earlyimageverylatebias=deepcopy(early_image)
        earlyimageverylatebias[biasonlylate_mask]=np.nan

# %%
cmap = plt.cm.jet
cmap.set_bad('r',1.)
plt.imshow(earlyimageverylatebias, interpolation='none', cmap=cmap,
           vmin=3*early_image.min(),
           vmax=0.65*early_image.max())

# %%
fig=plt.figure()
fig.add_subplot(121)
plt.imshow(verybiased,cmap='gray',vmin=verybiased.min(),vmax=verybiased.max())
plt.colorbar()
fig.add_subplot(122)
plt.imshow(early_image,interpolation='none',cmap='gray')

# %%
    
sns.set(font_scale=1.3)


fig1=plt.figure()
d=sns.barplot(y="Early colour - Raw mean intensity", x="exp condition",data=df_corrected.loc[df_corrected['exp condition'].isin(['1Day','1DayBic'])],ci=95)
#d=sns.swarmplot(y="Early colour - Raw mean intensity", x="exp condition",data=df_corrected.loc[df_corrected['exp condition'].isin(['1Day','1DayBic'])],color='black')
#ig1.savefig(expdir+'plot1.png',bbox_inches='tight')
Nobic = df_corrected[df_corrected['exp condition'] == '1Day']['Early colour - Raw mean intensity']
Bic = df_corrected[df_corrected['exp condition'] == '1DayBic']['Early colour - Raw mean intensity']
[stat,pval]=stats.ttest_ind(Nobic, Bic,nan_policy='omit')
print(pval)
x1, x2 = 0, 1   # columns 'HFS' and 'LFS'
y, h, col = df_corrected['Early colour - Raw mean intensity'].mean() + 0.005, 0.001, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
if pval<0.001:
    plt.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col)
elif pval<0.01:
    plt.text((x1+x2)*.5, y+h, "**", ha='center', va='bottom', color=col)
elif pval<0.05:
    plt.text((x1+x2)*.5, y+h, "*", ha='center', va='bottom', color=col)
else:
    plt.text((x1+x2)*.5, y+h, "ns", ha='center', va='bottom', color=col)

fig2=plt.figure()
d=sns.barplot(y="Late colour - Raw mean intensity", x="exp condition",data=df_corrected.loc[df_corrected['exp condition'].isin(['1Day','1DayBic'])],ci=95)
#d=sns.swarmplot(y="Late colour - Raw mean intensity", x="exp condition",data=df_corrected.loc[df_corrected['exp condition'].isin(['1Day','1DayBic'])],color='black')
#ig1.savefig(expdir+'plot1.png',bbox_inches='tight')
Nobic = df_corrected[df_corrected['exp condition'] == '1Day']['Late colour - Raw mean intensity']
Bic = df_corrected[df_corrected['exp condition'] == '1DayBic']['Late colour - Raw mean intensity']
[stat,pval]=stats.ttest_ind(Nobic, Bic,nan_policy='omit')
print(pval)
x1, x2 = 0, 1   # columns 'HFS' and 'LFS'
y, h, col = df_corrected['Late colour - Raw mean intensity'].mean() + 0.005, 0.001, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
if pval<0.001:
    plt.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col)
elif pval<0.01:
    plt.text((x1+x2)*.5, y+h, "**", ha='center', va='bottom', color=col)
elif pval<0.05:
    plt.text((x1+x2)*.5, y+h, "*", ha='center', va='bottom', color=col)
else:
    plt.text((x1+x2)*.5, y+h, "ns", ha='center', va='bottom', color=col)
#fig2.savefig(expdir+'plot2.png',bbox_inches='tight')

fig10=plt.figure()
Nobic = df_corrected[df_corrected['exp condition'] == '1Day']['Mean colour bias of a pixel (early=-1<x<1=late)']
Bic = df_corrected[df_corrected['exp condition'] == '1DayBic']['Mean colour bias of a pixel (early=-1<x<1=late)']
[stat,pval]=stats.ttest_ind(Nobic, Bic,nan_policy='omit')
print(pval)
d=sns.barplot(y="Mean colour bias of a pixel (early=-1<x<1=late)", x="exp condition",data=df_corrected.loc[df_corrected['exp condition'].isin(['1Day','1DayBic'])],ci=95)
#d=sns.swarmplot(y="Mean colour bias of a pixel (early=-1<x<1=late)", x="exp condition",data=df_corrected,color='black')
#fig10.savefig(expdir+'plot10.png',bbox_inches='tight')
x1, x2 = 0, 1   # columns 'HFS' and 'LFS'
y, h, col = df_corrected['Mean colour bias of a pixel (early=-1<x<1=late)'].mean() + 0.25, 0.01, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
if pval<0.001:
    plt.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col)
elif pval<0.01:
    plt.text((x1+x2)*.5, y+h, "**", ha='center', va='bottom', color=col)
elif pval<0.05:
    plt.text((x1+x2)*.5, y+h, "*", ha='center', va='bottom', color=col)
else:
    plt.text((x1+x2)*.5, y+h, "ns", ha='center', va='bottom', color=col)

# %%
data=df_corrected.loc[df_corrected['exp condition'].isin(['1Day','1DayBic'])]

# %%
'''fig10=plt.figure()
Nobic = df[df['exp condition'] == '1Day']['Mean colour bias of a pixel (early=-1<x<1=late)']
Bic = df[df['exp condition'] == '2Day']['Mean colour bias of a pixel (early=-1<x<1=late)']
[stat,pval]=stats.ttest_ind(Nobic, Bic)
print(pval)
d=sns.barplot(x='Mean colour bias of a pixel (early=-1<x<1=late)', y='exp condition',data=df_corrected[df_corrected['exp condition'].isin(['1Day', '2Day'])], ci='sd')
d=sns.swarmplot(x='Mean colour bias of a pixel (early=-1<x<1=late)', y='exp condition',data=df_corrected[df_corrected['exp condition'].isin(['1Day', '2Day'])],color='black')
fig10.savefig(expdir+'plot10.png',bbox_inches='tight')'''


fig10=plt.figure()
Nobic = df_corrected[df_corrected['exp condition'] == '1Day']['Mean colour bias of a pixel (early=-1<x<1=late)']
Bic = df_corrected[df_corrected['exp condition'] == '2Day']['Mean colour bias of a pixel (early=-1<x<1=late)']
[stat,pval]=stats.ttest_ind(Nobic, Bic,nan_policy='omit')
print(pval)
d=sns.barplot(y="Mean colour bias of a pixel (early=-1<x<1=late)", x="exp condition",data=df_corrected.loc[df_corrected['exp condition'].isin(['1Day','2Day'])])
#d=sns.swarmplot(y="Mean colour bias of a pixel (early=-1<x<1=late)", x="exp condition",data=df_corrected,color='black')
#fig10.savefig(expdir+'plot10.png',bbox_inches='tight')
x1, x2 = 0, 1   # columns 'HFS' and 'LFS'
y, h, col = df_corrected['Mean colour bias of a pixel (early=-1<x<1=late)'].mean() + 0.8, 0.01, 'k'
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
if pval<0.001:
    plt.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col)
elif pval<0.01:
    plt.text((x1+x2)*.5, y+h, "**", ha='center', va='bottom', color=col)
elif pval<0.05:
    plt.text((x1+x2)*.5, y+h, "*", ha='center', va='bottom', color=col)
else:
    plt.text((x1+x2)*.5, y+h, "ns", ha='center', va='bottom', color=col)
